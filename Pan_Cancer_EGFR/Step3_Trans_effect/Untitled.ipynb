# %%
import pandas as pd
import numpy as np
import re 
import matplotlib.pyplot as plt
from scipy import stats
import gseapy as gp
from gseapy.plot import barplot, dotplot

# %%
df = pd.read_csv('GBM_EGFR_Not_interacting_pearson_sig.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df
df = df.set_index('Comparison')
df1_transposed = df.T 
GBM_genes_prot = df1_transposed.columns.values.tolist()

# %%
GBM_genes = []
for gene in GBM_genes_prot:
    GBM_genes.append((re.sub("_proteomics", "", gene)))
    
GBM_genes
# Out:
# ['PHLDA1',
#  'SOCS2',
#  'PLA2G15',
#  'DAB2',
#  'GLA',
#  'CTSC',
#  'CKB',
#  'DCBLD2',
#  'ARNT2',
#  'SCPEP1',
#  'ROBO2',
#  'PHLDA3',
#  'BLOC1S2',
#  'ATP7A',
#  'MEOX2',
#  'CD180',
#  'FAM129B',
#  'SEC23IP',
#  'TOR4A',
#  'XRN1',
#  'PCDH17',
#  'LRP4',
#  'ARHGAP4',
#  'GPRIN3',
#  'PPP1R18',
#  'NEO1',
#  'EPHB3',
#  'KYNU',
#  'LRRC75A',
#  'CLIP2',
#  'STAB1',
#  'ARHGAP45',
#  'HSD17B11',
#  'SVIL',
#  'DOCK10',
#  'MITF',
#  'SH3BP1',
#  'GPHN',
#  'DPP6',
#  'ENG',
#  'ST14',
#  'ARHGAP27',
#  'OSTF1',
#  'APBB1IP',
#  'HAAO',
#  'CTSZ',
#  'THEMIS2',
#  'NFIA',
#  'NIPSNAP2',
#  'LANCL2',
#  'RNF130',
#  'ARHGAP15',
#  'KCND3',
#  'FCGRT',
#  'ABCA1',
#  'ZYG11B',
#  'ARMT1',
#  'DOCK11',
#  'GGA2',
#  'GBA',
#  'PROCR',
#  'UAP1',
#  'CTNND2',
#  'GMIP',
#  'ARHGAP24',
#  'CD4',
#  'NCKAP1L',
#  'ARHGAP30',
#  'PI4K2A',
#  'SCRN1',
#  'BLOC1S1',
#  'LDLRAP1',
#  'NPAS3',
#  'FYB1',
#  'ADAP2',
#  'FAM19A5',
#  'DOCK8',
#  'MAN2A1',
#  'LCP2',
#  'EHBP1L1',
#  'DNAJC21',
#  'ABI3',
#  'RAB3IL1',
#  'MLC1',
#  'TRAF3IP3',
#  'INPP5F',
#  'MSR1',
#  'TBXAS1',
#  'NAIP',
#  'OTULINL',
#  'FGD3',
#  'RIN2',
#  'RGS12',
#  'GAS2',
#  'PHLDB2',
#  'TNFAIP8',
#  'MYO10',
#  'FCGR3A',
#  'MAN2B1',
#  'HEXB',
#  'IL18',
#  'LIG4',
#  'B4GALT1',
#  'GAA',
#  'ST6GAL1',
#  'EMILIN3',
#  'TBC1D2B',
#  'RNASET2',
#  'ACSL1',
#  'TMX2',
#  'AFAP1L1',
#  'PTBP3',
#  'GPSM3',
#  'CTSS']

# %%
tumor_enr = gp.enrichr(gene_list = GBM_genes, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='test/enrichr_kegg')

# %%
tumor_enr.res2d.head()
# Out:
#     Gene_set                                               Term Overlap  \
# 0  KEGG_2016                     Lysosome Homo sapiens hsa04142  10/123
# 1  KEGG_2016     Other glycan degradation Homo sapiens hsa00511    3/18
# 2  KEGG_2016         Galactose metabolism Homo sapiens hsa00052    3/30
# 3  KEGG_2016        N-Glycan biosynthesis Homo sapiens hsa00510    3/49
# 4  KEGG_2016  Glycosphingolipid biosynthesis - globo series ...    2/14
#
#         P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0  2.121576e-09      6.216218e-07            0                     0
# 1  1.382670e-04      2.025612e-02            0                     0
# 2  6.545248e-04      6.392525e-02            0                     0
# 3  2.745789e-03      2.011290e-01            0                     0
# 4  2.802403e-03      1.642208e-01            0                     0
#
#    Odds Ratio  Combined Score  \
# 0   14.263301      284.853896
# 1   29.239766      259.834025
# 2   17.543860      128.624581
# 3   10.741139       63.347873
# 4   25.062657      147.300199
#
#                                                Genes
# 0  GGA2;PLA2G15;GAA;HEXB;CTSZ;GBA;MAN2B1;GLA;CTSS...
# 1                                    HEXB;GBA;MAN2B1
# 2                                    B4GALT1;GAA;GLA
# 3                             ST6GAL1;B4GALT1;MAN2A1
# 4                                           HEXB;GLA

# %% [markdown]
# # Kidney

# %%
df = pd.read_csv('Kidney_EGFR_Not_interacting_pearson_sig.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df
df = df.set_index('Comparison')
df1_transposed = df.T 
Kidney_genes_prot = df1_transposed.columns.values.tolist()

# %%
Kidney_genes = []
for gene in Kidney_genes_prot:
    Kidney_genes.append((re.sub("_proteomics", "", gene)))

# %%
tumor_enr = gp.enrichr(gene_list = Kidney_genes, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='test/enrichr_kegg')

# %%
tumor_enr.res2d.head()
# Out:
#     Gene_set                                               Term Overlap  \
# 0  KEGG_2016          Parkinson's disease Homo sapiens hsa05012   6/142
# 1  KEGG_2016          Alzheimer's disease Homo sapiens hsa05010   6/168
# 2  KEGG_2016         Huntington's disease Homo sapiens hsa05016   6/193
# 3  KEGG_2016    Oxidative phosphorylation Homo sapiens hsa00190   5/133
# 4  KEGG_2016  Non-alcoholic fatty liver disease (NAFLD) Homo...   5/151
#
#     P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0  0.000007          0.002161            0                     0   12.804097
# 1  0.000019          0.002818            0                     0   10.822511
# 2  0.000042          0.004098            0                     0    9.420631
# 3  0.000078          0.005702            0                     0   11.392117
# 4  0.000142          0.008297            0                     0   10.034116
#
#    Combined Score                                       Genes
# 0      151.312247  COX7A2L;APAF1;UQCRB;NDUFS4;NDUFA4L2;NDUFS1
# 1      117.518878  COX7A2L;APAF1;UQCRB;NDUFS4;NDUFA4L2;NDUFS1
# 2       94.948784  COX7A2L;APAF1;UQCRB;NDUFS4;NDUFA4L2;NDUFS1
# 3      107.777958        COX7A2L;UQCRB;NDUFS4;NDUFA4L2;NDUFS1
# 4       88.927786        COX7A2L;UQCRB;NDUFS4;NDUFA4L2;NDUFS1

# %% [markdown]
# # Ovarian

# %%
df = pd.read_csv('Ovar_EGFR_Not_interacting_pearson_sig.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df
df = df.set_index('Comparison')
df1_transposed = df.T 
Ovar_genes_prot = df1_transposed.columns.values.tolist()

# %%
Ovar_genes = []
for gene in Ovar_genes_prot:
    Ovar_genes.append((re.sub("_proteomics", "", gene)))

# %%
tumor_enr = gp.enrichr(gene_list = Ovar_genes, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='test/enrichr_kegg')
# Out:
# 2020-04-08 13:58:57,665 Warning: No enrich terms using library KEGG_2016 when cutoff = 0.05

# %%
tumor_enr.res2d.head()
# Out:
#     Gene_set                                               Term Overlap  \
# 0  KEGG_2016    One carbon pool by folate Homo sapiens hsa00670    1/20
# 1  KEGG_2016  Porphyrin and chlorophyll metabolism Homo sapi...    1/42
# 2  KEGG_2016            Insulin secretion Homo sapiens hsa04911    1/85
#
#     P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0  0.007973               1.0            0                     0  125.000000
# 1  0.016680               1.0            0                     0   59.523810
# 2  0.033504               1.0            0                     0   29.411765
#
#    Combined Score    Genes
# 0      603.956216  ALDH1L1
# 1      243.664108       CP
# 2       99.884920    TRPM4

# %% [markdown]
# # Colon

# %%
df = pd.read_csv('Colon_EGFR_Not_interacting_pearson_sig.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df
df = df.set_index('Comparison')
df1_transposed = df.T 
Colon_genes_prot = df1_transposed.columns.values.tolist()

# %%
Colon_genes = []
for gene in Colon_genes_prot:
    Colon_genes.append((re.sub("_proteomics", "", gene)))

# %%
tumor_enr = gp.enrichr(gene_list = Colon_genes, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='test/enrichr_kegg')
# Out:
# 2020-04-08 13:58:59,543 Warning: No enrich terms using library KEGG_2016 when cutoff = 0.05

# %%
tumor_enr.res2d.head()
# Out:
#     Gene_set                                               Term Overlap  \
# 0  KEGG_2016  Ribosome biogenesis in eukaryotes Homo sapiens...    2/89
# 1  KEGG_2016                RNA transport Homo sapiens hsa03013   2/172
# 2  KEGG_2016         Huntington's disease Homo sapiens hsa05016   2/193
# 3  KEGG_2016  Other types of O-glycan biosynthesis Homo sapi...    1/31
# 4  KEGG_2016    Oxidative phosphorylation Homo sapiens hsa00190   1/133
#
#     P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0  0.001721          0.504226            0                     0   32.102729
# 1  0.006252          0.915907            0                     0   16.611296
# 2  0.007811          0.762876            0                     0   14.803849
# 3  0.021489          1.000000            0                     0   46.082949
# 4  0.089208          1.000000            0                     0   10.741139
#
#    Combined Score         Genes
# 0      204.330776     UTP6;GAR1
# 1       84.300099   NUP153;RAE1
# 2       71.831526  NDUFAB1;TFAM
# 3      176.967364        POFUT1
# 4       25.958980       NDUFAB1

# %% [markdown]
# # Brca

# %%
df = pd.read_csv('Brca_EGFR_Not_interacting_pearson_sig.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df
df = df.set_index('Comparison')
df1_transposed = df.T 
Brca_genes_prot = df1_transposed.columns.values.tolist()

# %%
Brca_genes = []
for gene in Brca_genes_prot:
    Brca_genes.append((re.sub("_proteomics", "", gene)))

# %%
tumor_enr = gp.enrichr(gene_list = Brca_genes, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='test/enrichr_kegg')
# Out:
# 2020-04-08 13:59:01,802 Warning: No enrich terms using library KEGG_2016 when cutoff = 0.05

# %%
tumor_enr.res2d.head()
# Out:
#     Gene_set                                               Term  Overlap  \
# 0  KEGG_2016  Alanine, aspartate and glutamate metabolism Ho...     5/35
# 1  KEGG_2016  2-Oxocarboxylic acid metabolism Homo sapiens h...     3/17
# 2  KEGG_2016           Metabolic pathways Homo sapiens hsa01100  31/1239
# 3  KEGG_2016           Lysine degradation Homo sapiens hsa00310     4/52
# 4  KEGG_2016  Nicotinate and nicotinamide metabolism Homo sa...     3/29
#
#     P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0  0.000198          0.057962            0                     0    9.157509
# 1  0.002174          0.318465            0                     0   11.312217
# 2  0.006482          0.633036            0                     0    1.603858
# 3  0.008737          0.639985            0                     0    4.930966
# 4  0.010178          0.596408            0                     0    6.631300
#
#    Combined Score                                              Genes
# 0       78.096509                            GPT2;GFPT2;CAD;ABAT;GLS
# 1       69.358224                                   AADAT;GPT2;BCAT2
# 2        8.081498  HAAO;COX17;NDUFA4L2;ABAT;ENO1;NT5C2;GLS;NSDHL;...
# 3       23.373713                         AADAT;PLOD3;PLOD1;COLGALT1
# 4       30.421520                                 NAMPT;NT5C2;NUDT12

# %% [markdown]
# # Luad

# %%
df = pd.read_csv('Luad_EGFR_Not_interacting_pearson_sig.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df
df = df.set_index('Comparison')
df1_transposed = df.T 
Luad_genes_prot = df1_transposed.columns.values.tolist()

# %%
Luad_genes = []
for gene in Luad_genes_prot:
    Luad_genes.append((re.sub("_proteomics", "", gene)))

# %%
tumor_enr = gp.enrichr(gene_list = Luad_genes, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='test/enrichr_kegg')
# Out:
# 2020-04-08 13:59:03,708 Warning: No enrich terms using library KEGG_2016 when cutoff = 0.05

# %%
tumor_enr.res2d.head()
# Out:
#     Gene_set                                               Term Overlap  \
# 0  KEGG_2016  Porphyrin and chlorophyll metabolism Homo sapi...    2/42
# 1  KEGG_2016           Mineral absorption Homo sapiens hsa04978    2/51
# 2  KEGG_2016    mRNA surveillance pathway Homo sapiens hsa03015    2/91
# 3  KEGG_2016         Steroid biosynthesis Homo sapiens hsa00100    1/20
# 4  KEGG_2016        Wnt signaling pathway Homo sapiens hsa04310   2/142
#
#     P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0  0.011975               1.0            0                     0   12.055455
# 1  0.017333               1.0            0                     0    9.928022
# 2  0.050334               1.0            0                     0    5.564056
# 3  0.076139               1.0            0                     0   12.658228
# 4  0.108414               1.0            0                     0    3.565698
#
#    Combined Score          Genes
# 0       53.344391    HMOX2;BLVRA
# 1       40.259582  SLC34A2;HMOX2
# 2       16.631376     ETF1;GSPT1
# 3       32.597374          NSDHL
# 4        7.922263     DAAM1;GPC4

# %% [markdown]
# # Hnscc

# %%
df = pd.read_csv('Hnscc_EGFR_Not_interacting_pearson_sig.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df
df = df.set_index('Comparison')
df1_transposed = df.T 
Hnscc_genes_prot = df1_transposed.columns.values.tolist()

# %%
Hnscc_genes = []
for gene in Hnscc_genes_prot:
    Hnscc_genes.append((re.sub("_proteomics", "", gene)))

# %%
tumor_enr = gp.enrichr(gene_list = Hnscc_genes, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='test/enrichr_kegg')
# Out:
# 2020-04-08 13:59:22,581 Warning: No enrich terms using library KEGG_2016 when cutoff = 0.05

# %%
tumor_enr.res2d.head()
# Out:
#     Gene_set                                               Term Overlap  \
# 0  KEGG_2016  B cell receptor signaling pathway Homo sapiens...    3/73
# 1  KEGG_2016   cGMP-PKG signaling pathway Homo sapiens hsa04022   4/167
# 2  KEGG_2016         Pancreatic secretion Homo sapiens hsa04972    3/96
# 3  KEGG_2016  Phosphatidylinositol signaling system Homo sap...    3/98
# 4  KEGG_2016          Platelet activation Homo sapiens hsa04611   3/122
#
#     P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0  0.004100          1.000000            0                     0    9.339975
# 1  0.006348          0.929923            0                     0    5.443658
# 2  0.008761          0.855629            0                     0    7.102273
# 3  0.009267          0.678840            0                     0    6.957328
# 4  0.016687          0.977880            0                     0    5.588674
#
#    Combined Score                       Genes
# 0       51.340292           INPP5D;BTK;NFATC2
# 1       27.543161  ITPR1;ATP2B4;ATP2A3;NFATC2
# 2       33.646863         ITPR1;ATP2B4;ATP2A3
# 3       32.568983        INPP5D;ITPR1;PIP4K2A
# 4       22.875019            ITPR1;BTK;FERMT3
