# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest

import cptac
import cptac.utils as u
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv("pancan_EGFR_pearson.csv")
df = df.drop(['Unnamed: 0'], axis=1)
#filtered_data = df[df["Comparison"]== "ARG1"]
df= df.dropna(thresh = 14)
df["SD_Correlation"] = (df.loc[:,["Correlation_Gbm","Correlation_kidney","Correlation_Ovar","Correlation_Brca","Correlation_Luad","Correlation_hnscc","Correlation_colon","Correlation_Lscc"]].std(axis = 1))
#df["Average_Correlation"] = (df.loc[:,["Correlation_Gbm","Correlation_kidney","Correlation_Ovar","Correlation_Brca","Correlation_Luad","Correlation_hnscc","Correlation_colon","Correlation_Lscc"]].mean(axis = 1))
#df["SD_Pval"] = df.loc[:,["P_value_Gbm","P_value_kidney","P_value_Ovar","P_value_Brca","P_value_Luad","P_value_hnscc","P_value_colon","P_value_Lscc"]].std(axis = 1)
#df["Average_Pval"] = df.loc[:,["P_value_Gbm","P_value_kidney","P_value_Ovar","P_value_Brca","P_value_Luad","P_value_hnscc","P_value_colon","P_value_Lscc"]].mean(axis = 1)

#df = df.drop([0])
df
# Out:
#              Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0       EGFR_proteomics         1.000000  0.000000e+00            1.000000
# 1       GRB2_proteomics        -0.610889  1.886384e-11           -0.217427
# 3       SHC1_proteomics        -0.540524  7.695118e-09           -0.102065
# 4        WAS_proteomics        -0.501918  1.205168e-07           -0.279814
# 5       NPC2_proteomics        -0.498791  1.484249e-07           -0.319133
# ...                 ...              ...           ...                 ...
# 1205   LAMA3_proteomics              NaN           NaN            0.026510
# 1209   ZFP36_proteomics              NaN           NaN            0.035245
# 1213   LAMB3_proteomics              NaN           NaN           -0.032217
# 1215  MAP4K1_proteomics              NaN           NaN           -0.024209
# 1224   GNG10_proteomics              NaN           NaN           -0.001988
#
#       P_value_kidney  Correlation_Endo  P_value_Endo  Correlation_Ovar  \
# 0           0.000000          1.000000      0.000000          1.000000
# 1           0.022506         -0.437336      0.000009         -0.190090
# 3           0.288685         -0.208383      0.042716          0.175098
# 4           0.003071         -0.238306      0.020041         -0.090413
# 5           0.000678          0.026214      0.800915         -0.183193
# ...              ...               ...           ...               ...
# 1205        0.783381         -0.009692      0.925734          0.280294
# 1209        0.814060         -0.284847      0.052302               NaN
# 1213        0.827914         -0.011152      0.914581          0.324377
# 1215        0.855579         -0.008992      0.935696         -0.326826
# 1224        0.983552               NaN           NaN         -0.080171
#
#       P_value_Ovar  Correlation_Brca  P_value_Brca  Correlation_Luad  \
# 0         0.000000          1.000000      0.000000          1.000000
# 1         0.085202         -0.177379      0.057899         -0.302439
# 3         0.113358          0.090908      0.333927         -0.135844
# 4         0.416288          0.153496      0.101463         -0.337909
# 5         0.097375          0.279599      0.002476          0.292520
# ...            ...               ...           ...               ...
# 1205      0.010272          0.065620      0.485955         -0.291187
# 1209           NaN          0.205473      0.033739         -0.299990
# 1213      0.002774          0.394351      0.000013         -0.153787
# 1215      0.003957          0.080551      0.405053         -0.377548
# 1224      0.471231          0.061879      0.511206         -0.011259
#
#       P_value_Luad  Correlation_hnscc  P_value_hnscc  Correlation_colon  \
# 0         0.000000           1.000000   0.000000e+00           1.000000
# 1         0.001321          -0.532341   2.559824e-09           0.150960
# 3         0.262164          -0.085910   3.744159e-01           0.203250
# 4         0.000306          -0.503427   2.411333e-08           0.282401
# 5         0.001928          -0.073050   4.503201e-01           0.040840
# ...            ...                ...            ...                ...
# 1205      0.002027           0.240877   1.163259e-02           0.315727
# 1209      0.002983           0.129523   1.794886e-01           0.104687
# 1213      0.108699           0.373225   6.412704e-05           0.195785
# 1215      0.000048          -0.423254   4.531560e-06                NaN
# 1224      0.907063          -0.092667   3.378709e-01          -0.003380
#
#       P_value_colon  Correlation_Lscc  P_value_Lscc  SD_Correlation
# 0          0.000000          1.000000  0.000000e+00    1.186878e-16
# 1          0.139949         -0.174810  6.776395e-02    2.356400e-01
# 3          0.045855          0.123922  1.971088e-01    2.434330e-01
# 4          0.005070         -0.177954  6.289182e-02    2.868968e-01
# 5          0.691234         -0.013310  8.902375e-01    2.743765e-01
# ...             ...               ...           ...             ...
# 1205       0.001631          0.211879  2.627535e-02    2.112718e-01
# 1209       0.307497          0.005728  9.537562e-01    1.765128e-01
# 1213       0.054618          0.492286  4.697496e-08    2.388899e-01
# 1215            NaN         -0.264277  5.272744e-03    2.040244e-01
# 1224       0.976108         -0.108125  2.608570e-01    6.156238e-02
#
# [920 rows x 20 columns]

# %%
df = df.set_index('Comparison')

# %%
df
# Out:
#                    Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# Comparison
# EGFR_proteomics           1.000000  0.000000e+00            1.000000
# GRB2_proteomics          -0.610889  1.886384e-11           -0.217427
# SHC1_proteomics          -0.540524  7.695118e-09           -0.102065
# WAS_proteomics           -0.501918  1.205168e-07           -0.279814
# NPC2_proteomics          -0.498791  1.484249e-07           -0.319133
# ...                            ...           ...                 ...
# LAMA3_proteomics               NaN           NaN            0.026510
# ZFP36_proteomics               NaN           NaN            0.035245
# LAMB3_proteomics               NaN           NaN           -0.032217
# MAP4K1_proteomics              NaN           NaN           -0.024209
# GNG10_proteomics               NaN           NaN           -0.001988
#
#                    P_value_kidney  Correlation_Endo  P_value_Endo  \
# Comparison
# EGFR_proteomics          0.000000          1.000000      0.000000
# GRB2_proteomics          0.022506         -0.437336      0.000009
# SHC1_proteomics          0.288685         -0.208383      0.042716
# WAS_proteomics           0.003071         -0.238306      0.020041
# NPC2_proteomics          0.000678          0.026214      0.800915
# ...                           ...               ...           ...
# LAMA3_proteomics         0.783381         -0.009692      0.925734
# ZFP36_proteomics         0.814060         -0.284847      0.052302
# LAMB3_proteomics         0.827914         -0.011152      0.914581
# MAP4K1_proteomics        0.855579         -0.008992      0.935696
# GNG10_proteomics         0.983552               NaN           NaN
#
#                    Correlation_Ovar  P_value_Ovar  Correlation_Brca  \
# Comparison
# EGFR_proteomics            1.000000      0.000000          1.000000
# GRB2_proteomics           -0.190090      0.085202         -0.177379
# SHC1_proteomics            0.175098      0.113358          0.090908
# WAS_proteomics            -0.090413      0.416288          0.153496
# NPC2_proteomics           -0.183193      0.097375          0.279599
# ...                             ...           ...               ...
# LAMA3_proteomics           0.280294      0.010272          0.065620
# ZFP36_proteomics                NaN           NaN          0.205473
# LAMB3_proteomics           0.324377      0.002774          0.394351
# MAP4K1_proteomics         -0.326826      0.003957          0.080551
# GNG10_proteomics          -0.080171      0.471231          0.061879
#
#                    P_value_Brca  Correlation_Luad  P_value_Luad  \
# Comparison
# EGFR_proteomics        0.000000          1.000000      0.000000
# GRB2_proteomics        0.057899         -0.302439      0.001321
# SHC1_proteomics        0.333927         -0.135844      0.262164
# WAS_proteomics         0.101463         -0.337909      0.000306
# NPC2_proteomics        0.002476          0.292520      0.001928
# ...                         ...               ...           ...
# LAMA3_proteomics       0.485955         -0.291187      0.002027
# ZFP36_proteomics       0.033739         -0.299990      0.002983
# LAMB3_proteomics       0.000013         -0.153787      0.108699
# MAP4K1_proteomics      0.405053         -0.377548      0.000048
# GNG10_proteomics       0.511206         -0.011259      0.907063
#
#                    Correlation_hnscc  P_value_hnscc  Correlation_colon  \
# Comparison
# EGFR_proteomics             1.000000   0.000000e+00           1.000000
# GRB2_proteomics            -0.532341   2.559824e-09           0.150960
# SHC1_proteomics            -0.085910   3.744159e-01           0.203250
# WAS_proteomics             -0.503427   2.411333e-08           0.282401
# NPC2_proteomics            -0.073050   4.503201e-01           0.040840
# ...                              ...            ...                ...
# LAMA3_proteomics            0.240877   1.163259e-02           0.315727
# ZFP36_proteomics            0.129523   1.794886e-01           0.104687
# LAMB3_proteomics            0.373225   6.412704e-05           0.195785
# MAP4K1_proteomics          -0.423254   4.531560e-06                NaN
# GNG10_proteomics           -0.092667   3.378709e-01          -0.003380
#
#                    P_value_colon  Correlation_Lscc  P_value_Lscc  \
# Comparison
# EGFR_proteomics         0.000000          1.000000  0.000000e+00
# GRB2_proteomics         0.139949         -0.174810  6.776395e-02
# SHC1_proteomics         0.045855          0.123922  1.971088e-01
# WAS_proteomics          0.005070         -0.177954  6.289182e-02
# NPC2_proteomics         0.691234         -0.013310  8.902375e-01
# ...                          ...               ...           ...
# LAMA3_proteomics        0.001631          0.211879  2.627535e-02
# ZFP36_proteomics        0.307497          0.005728  9.537562e-01
# LAMB3_proteomics        0.054618          0.492286  4.697496e-08
# MAP4K1_proteomics            NaN         -0.264277  5.272744e-03
# GNG10_proteomics        0.976108         -0.108125  2.608570e-01
#
#                    SD_Correlation
# Comparison
# EGFR_proteomics      1.186878e-16
# GRB2_proteomics      2.356400e-01
# SHC1_proteomics      2.434330e-01
# WAS_proteomics       2.868968e-01
# NPC2_proteomics      2.743765e-01
# ...                           ...
# LAMA3_proteomics     2.112718e-01
# ZFP36_proteomics     1.765128e-01
# LAMB3_proteomics     2.388899e-01
# MAP4K1_proteomics    2.040244e-01
# GNG10_proteomics     6.156238e-02
#
# [920 rows x 19 columns]

# %%
df1_subset = df[["Average_Pval","SD_Pval"]]
#df1_subset.columns = df1_subset.columns.droplevel(1)
#def create_lin_reg_graph(df1, df2, x_axis, y_axis, title):
df1_subset = df1_subset.dropna(axis=0, how="any")

x1 = df1_subset[["Average_Pval"]].values
y1 = df1_subset[["SD_Pval"]].values
x1 = x1[:,0]
y1 = y1[:,0]
plt.hist2d(x1,y1,bins=50)
plt.title("Average P value vs SD P value")
cbar = plt.colorbar()
cbar.ax.set_ylabel('Counts')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-7a3a6e54a215> in <module>
# ----> 1 df1_subset = df[["Average_Pval","SD_Pval"]]
#       2 #df1_subset.columns = df1_subset.columns.droplevel(1)
#       3 #def create_lin_reg_graph(df1, df2, x_axis, y_axis, title):
#       4 df1_subset = df1_subset.dropna(axis=0, how="any")
#       5
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1637             if missing == len(indexer):
#    1638                 axis_name = self.obj._get_axis_name(axis)
# -> 1639                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1640
#    1641             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Average_Pval', 'SD_Pval'], dtype='object')] are in the [columns]"

# %%
g = (sns.jointplot(x1, y1, kind="hex")
        .set_axis_labels("mean p vaule", "SD p value"))

plt.show()
g.savefig("Step3C_Pval_EGFR.png")

# %%
df1_subset = df[["Average_Correlation","SD_Correlation"]]
#df1_subset.columns = df1_subset.columns.droplevel(1)
#def create_lin_reg_graph(df1, df2, x_axis, y_axis, title):
df1_subset = df1_subset.dropna(axis=0, how="any")

x1 = df1_subset[["Average_Correlation"]].values
y1 = df1_subset[["SD_Correlation"]].values
x1 = x1[:,0]
y1 = y1[:,0]
plt.hist2d(x1,y1,bins=50)
plt.title("Average Correlation vs SD Correlation")
# Out:
# Text(0.5, 1.0, 'Average Correlation vs SD Correlation')

# %%
g = (sns.jointplot(x1, y1, kind="hex")
        .set_axis_labels("Mean Correlation", "SD Correlation"))

plt.show()
g.savefig("Step3C_corr_EGFR.png")

# %%
df1_subset = df[["SD_Pval","SD_Correlation"]]
#df1_subset.columns = df1_subset.columns.droplevel(1)
#def create_lin_reg_graph(df1, df2, x_axis, y_axis, title):
df1_subset = df1_subset.dropna(axis=0, how="any")

x1 = df1_subset[["SD_Pval"]].values
y1 = df1_subset[["SD_Correlation"]].values
x1 = x1[:,0]
y1 = y1[:,0]

g = (sns.jointplot(x1, y1, kind="hex")
        .set_axis_labels("SD Pval", "SD Correlation"))

plt.show()

# %%
#pd.set_option('display.max_columns', 25)
df = df.set_index('Comparison')
pathway = ["NRAS_proteomics","KRAS_proteomics","HRAS_proteomics","RASGRP2_proteomics","RAF1_proteomics","MAP3K1_proteomics","MAP3K2_proteomics","MAPK1_proteomics","MAPK3_proteomics"]


#MapKinase.to_csv(r'/Users/Lindsey/Documents/MapKinase2.csv')

# %%
#df.loc[df['Comparison'] == "KRAS_proteomics"]
#df = df.drop(columns=['Correlation_Endo', 'P_value_Endo']) # drop less freq EGFR mutation cancers
#df = df.drop(columns=['Average_Correlation', 'SD_Pval',"Average_Pval","SD_Correlation"])
#pd.set_option("display.precision", 3)
df1_transposed = df.T # or df1.transpose()
#MapKinase = df1_transposed[pathway]
df1_transposed
#MapKinase
# Out:
# Comparison          EGFR_proteomics  GRB2_proteomics  SHC1_proteomics  \
# Correlation_Gbm        1.000000e+00    -6.108891e-01    -5.405245e-01
# P_value_Gbm            0.000000e+00     1.886384e-11     7.695118e-09
# Correlation_kidney     1.000000e+00    -2.174268e-01    -1.020648e-01
# P_value_kidney         0.000000e+00     2.250643e-02     2.886854e-01
# Correlation_Endo       1.000000e+00    -4.373359e-01    -2.083825e-01
# P_value_Endo           0.000000e+00     9.358121e-06     4.271583e-02
# Correlation_Ovar       1.000000e+00    -1.900897e-01     1.750975e-01
# P_value_Ovar           0.000000e+00     8.520228e-02     1.133577e-01
# Correlation_Brca       1.000000e+00    -1.773788e-01     9.090809e-02
# P_value_Brca           0.000000e+00     5.789878e-02     3.339275e-01
# Correlation_Luad       1.000000e+00    -3.024386e-01    -1.358436e-01
# P_value_Luad           0.000000e+00     1.321265e-03     2.621637e-01
# Correlation_hnscc      1.000000e+00    -5.323412e-01    -8.591023e-02
# P_value_hnscc          0.000000e+00     2.559824e-09     3.744159e-01
# Correlation_colon      1.000000e+00     1.509598e-01     2.032502e-01
# P_value_colon          0.000000e+00     1.399493e-01     4.585504e-02
# Correlation_Lscc       1.000000e+00    -1.748103e-01     1.239217e-01
# P_value_Lscc           0.000000e+00     6.776395e-02     1.971088e-01
# SD_Correlation         1.186878e-16     2.356400e-01     2.434330e-01
#
# Comparison          WAS_proteomics  NPC2_proteomics  IKBKE_proteomics  \
# Correlation_Gbm      -5.019180e-01    -4.987906e-01     -5.197345e-01
# P_value_Gbm           1.205168e-07     1.484249e-07      1.525615e-07
# Correlation_kidney   -2.798139e-01    -3.191335e-01      6.043326e-02
# P_value_kidney        3.070750e-03     6.783668e-04      7.383175e-01
# Correlation_Endo     -2.383056e-01     2.621397e-02     -1.943371e-01
# P_value_Endo          2.004107e-02     8.009150e-01      9.034205e-02
# Correlation_Ovar     -9.041309e-02    -1.831929e-01      1.282507e-01
# P_value_Ovar          4.162884e-01     9.737460e-02      2.478946e-01
# Correlation_Brca      1.534960e-01     2.795993e-01      1.199723e-01
# P_value_Brca          1.014634e-01     2.476401e-03      2.015588e-01
# Correlation_Luad     -3.379087e-01     2.925198e-01      4.013915e-02
# P_value_Luad          3.058061e-04     1.928339e-03      6.887508e-01
# Correlation_hnscc    -5.034269e-01    -7.305004e-02     -1.058128e-01
# P_value_hnscc         2.411333e-08     4.503201e-01      2.997509e-01
# Correlation_colon     2.824011e-01     4.084025e-02               NaN
# P_value_colon         5.069925e-03     6.912338e-01               NaN
# Correlation_Lscc     -1.779544e-01    -1.330959e-02      4.779096e-02
# P_value_Lscc          6.289182e-02     8.902375e-01      6.200402e-01
# SD_Correlation        2.868968e-01     2.743765e-01      2.281155e-01
#
# Comparison          CTSB_proteomics  SOX9_proteomics  PPP2R3A_proteomics  \
# Correlation_Gbm       -4.968953e-01     4.906701e-01       -5.037773e-01
# P_value_Gbm            1.682242e-07     2.524741e-07        4.157858e-07
# Correlation_kidney    -2.263099e-01     6.918633e-03        2.857350e-01
# P_value_kidney         1.743635e-02     9.611753e-01        2.478699e-03
# Correlation_Endo       7.179313e-02     2.116198e-01        6.181955e-02
# P_value_Endo           4.893253e-01     4.650252e-02        5.517529e-01
# Correlation_Ovar      -3.321077e-02     9.605410e-02        1.038304e-01
# P_value_Ovar           7.656588e-01     3.876852e-01        3.502411e-01
# Correlation_Brca       3.410479e-01     2.529196e-01        4.461368e-01
# P_value_Brca           1.915971e-04     6.389000e-03        5.820667e-07
# Correlation_Luad      -2.493331e-01              NaN        3.484898e-01
# P_value_Luad           8.619764e-03              NaN        1.907963e-04
# Correlation_hnscc      2.123974e-01     2.629522e-01        2.644406e-01
# P_value_hnscc          2.660313e-02     1.504243e-02        5.458422e-03
# Correlation_colon      9.610549e-02    -6.971728e-03                 NaN
# P_value_colon          3.490525e-01     9.495075e-01                 NaN
# Correlation_Lscc       1.427038e-01     7.306231e-02        2.355225e-01
# P_value_Lscc           1.369579e-01     5.333213e-01        1.325248e-02
# SD_Correlation         2.794690e-01     1.784633e-01        3.143931e-01
#
# Comparison          COL6A2_proteomics  ...  COL2A1_proteomics  \
# Correlation_Gbm         -4.827741e-01  ...                NaN
# P_value_Gbm              4.177381e-07  ...                NaN
# Correlation_kidney       2.288086e-01  ...          -0.079021
# P_value_kidney           1.620173e-02  ...           0.444091
# Correlation_Endo         2.430062e-01  ...           0.010921
# P_value_Endo             1.765087e-02  ...           0.916345
# Correlation_Ovar         1.700106e-01  ...           0.232207
# P_value_Ovar             1.243938e-01  ...           0.034653
# Correlation_Brca         1.580210e-01  ...          -0.063834
# P_value_Brca             1.007775e-01  ...           0.497926
# Correlation_Luad         6.043932e-02  ...           0.176636
# P_value_Luad             6.324650e-01  ...           0.064899
# Correlation_hnscc        6.452861e-02  ...          -0.144351
# P_value_hnscc            5.050106e-01  ...           0.143749
# Correlation_colon        3.035094e-01  ...          -0.054264
# P_value_colon            2.510296e-03  ...           0.667694
# Correlation_Lscc        -6.658367e-03  ...          -0.108509
# P_value_Lscc             9.462537e-01  ...           0.259157
# SD_Correlation           2.415840e-01  ...           0.147622
#
# Comparison          CD209_proteomics  MAP3K8_proteomics  ITGA11_proteomics  \
# Correlation_Gbm                  NaN                NaN                NaN
# P_value_Gbm                      NaN                NaN                NaN
# Correlation_kidney         -0.067331          -0.086107          -0.052775
# P_value_kidney              0.501334           0.564957           0.743136
# Correlation_Endo            0.007584          -0.112536           0.019631
# P_value_Endo                0.945752           0.350103           0.850228
# Correlation_Ovar            0.279752           0.292158          -0.037524
# P_value_Ovar                0.010426           0.010440           0.736273
# Correlation_Brca            0.282232           0.007177           0.126626
# P_value_Brca                0.004442           0.939316           0.177493
# Correlation_Luad           -0.350835          -0.357422           0.177402
# P_value_Luad                0.000171           0.000243           0.063726
# Correlation_hnscc          -0.217135          -0.197603           0.184117
# P_value_hnscc               0.023332           0.068197           0.062642
# Correlation_colon           0.143620           0.035051          -0.016826
# P_value_colon               0.184472           0.733224           0.887642
# Correlation_Lscc           -0.055363          -0.085864          -0.029907
# P_value_Lscc                0.565658           0.383797           0.756443
# SD_Correlation              0.243701           0.202567           0.107365
#
# Comparison          GPX2_proteomics  LAMA3_proteomics  ZFP36_proteomics  \
# Correlation_Gbm                 NaN               NaN               NaN
# P_value_Gbm                     NaN               NaN               NaN
# Correlation_kidney         0.053646          0.026510          0.035245
# P_value_kidney             0.749062          0.783381          0.814060
# Correlation_Endo           0.019047         -0.009692         -0.284847
# P_value_Endo               0.854636          0.925734          0.052302
# Correlation_Ovar          -0.219369          0.280294               NaN
# P_value_Ovar               0.179662          0.010272               NaN
# Correlation_Brca                NaN          0.065620          0.205473
# P_value_Brca                    NaN          0.485955          0.033739
# Correlation_Luad          -0.437351         -0.291187         -0.299990
# P_value_Luad               0.000007          0.002027          0.002983
# Correlation_hnscc          0.057474          0.240877          0.129523
# P_value_hnscc              0.552770          0.011633          0.179489
# Correlation_colon         -0.352451          0.315727          0.104687
# P_value_colon              0.000399          0.001631          0.307497
# Correlation_Lscc           0.167784          0.211879          0.005728
# P_value_Lscc               0.079760          0.026275          0.953756
# SD_Correlation             0.248625          0.211272          0.176513
#
# Comparison          LAMB3_proteomics  MAP4K1_proteomics  GNG10_proteomics
# Correlation_Gbm                  NaN                NaN               NaN
# P_value_Gbm                      NaN                NaN               NaN
# Correlation_kidney     -3.221695e-02          -0.024209         -0.001988
# P_value_kidney          8.279136e-01           0.855579          0.983552
# Correlation_Endo       -1.115221e-02          -0.008992               NaN
# P_value_Endo            9.145806e-01           0.935696               NaN
# Correlation_Ovar        3.243775e-01          -0.326826         -0.080171
# P_value_Ovar            2.773881e-03           0.003957          0.471231
# Correlation_Brca        3.943511e-01           0.080551          0.061879
# P_value_Brca            1.295748e-05           0.405053          0.511206
# Correlation_Luad       -1.537873e-01          -0.377548         -0.011259
# P_value_Luad            1.086991e-01           0.000048          0.907063
# Correlation_hnscc       3.732248e-01          -0.423254         -0.092667
# P_value_hnscc           6.412704e-05           0.000005          0.337871
# Correlation_colon       1.957850e-01                NaN         -0.003380
# P_value_colon           5.461773e-02                NaN          0.976108
# Correlation_Lscc        4.922860e-01          -0.264277         -0.108125
# P_value_Lscc            4.697496e-08           0.005273          0.260857
# SD_Correlation          2.388899e-01           0.204024          0.061562
#
# [19 rows x 920 columns]

# %%
df1_transposed.filter(like='ITGB1', axis=1)
# Out:
# Comparison          ITGB1_proteomics
# Correlation_Gbm        -4.123639e-01
# P_value_Gbm             2.223482e-05
# Correlation_kidney      2.760275e-01
# P_value_kidney          3.513143e-03
# Correlation_Endo        5.949754e-01
# P_value_Endo            2.041718e-10
# Correlation_Ovar        2.774720e-01
# P_value_Ovar            1.109692e-02
# Correlation_Brca        4.105299e-01
# P_value_Brca            5.191577e-06
# Correlation_Luad       -6.322311e-02
# P_value_Luad            5.117137e-01
# Correlation_hnscc       3.473603e-01
# P_value_hnscc           2.150377e-04
# Correlation_colon       1.586882e-01
# P_value_colon           1.205446e-01
# Correlation_Lscc        2.881393e-01
# P_value_Lscc            2.269263e-03
# SD_Correlation          2.722868e-01

# %%
#df.loc[df['Comparison'] == "KRAS_proteomics"]
#df = df.drop(columns=['Correlation_Endo', 'P_value_Endo']) # drop less freq EGFR mutation cancers
#df = df.drop(columns=['Average_Correlation', 'SD_Pval',"Average_Pval","SD_Correlation"])
#pd.set_option("display.precision", 3)
#df1_transposed = df.T # or df1.transpose()

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

pathway2 = ["CBL_proteomics","VAV1_proteomics","RAC1_proteomics","PAK1_proteomics","MAP3K1_proteomics","MAP2K4_proteomics","MAP2K7_proteomics","MAPK1_proteomics","MAPK7_proteomics","NCK1_proteomics"]
pathway1 = ["GRB2_proteomics", "SHC1_proteomics","SOS1_proteomics","HRAS_proteomics","NRAS_proteomics","KRAS_proteomics","RASGRP2_proteomics"]

pathway2 = df1_transposed[pathway1]

pathway2
# Out:
# <style>.container { width:100% !important; }</style>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-a4531930af91> in <module>
#      11 pathway1 = ["HBEGF_proteomics","GRB2_proteomics", "SHC1_proteomics","SOS1_proteomics","HRAS_proteomics","NRAS_proteomics","KRAS_proteomics","RASGRP2_proteomics"]
#      12
# ---> 13 pathway2 = df1_transposed[pathway1]
#      14
#      15 pathway2
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1643             if not (self.name == "loc" and not raise_missing):
#    1644                 not_found = list(set(key) - set(ax))
# -> 1645                 raise KeyError(f"{not_found} not in index")
#    1646
#    1647             # we skip the warning on Categorical/Interval
#
# KeyError: "['HBEGF_proteomics'] not in index"

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

pathway2 = ["STAT1_proteomics","JAK1_proteomics","JAK2_proteomics","STAT3_proteomics","SRC_proteomics"]

pathway2 = df1_transposed[pathway2]

pathway2
# Out:
# <style>.container { width:100% !important; }</style>
# Comparison          STAT1_proteomics  JAK1_proteomics  JAK2_proteomics  \
# Correlation_Gbm                0.231        9.096e-02           -0.169
# P_value_Gbm                    0.021        3.706e-01            0.095
# Correlation_kidney            -0.070        9.447e-02           -0.235
# P_value_kidney                 0.465        3.263e-01            0.014
# Correlation_Ovar              -0.144       -3.466e-02            0.064
# P_value_Ovar                   0.193        7.558e-01            0.694
# Correlation_Brca               0.069       -1.379e-01            0.142
# P_value_Brca                   0.463        1.417e-01            0.142
# Correlation_Luad               0.018       -1.576e-01           -0.188
# P_value_Luad                   0.852        1.001e-01            0.049
# Correlation_hnscc             -0.212       -3.911e-01           -0.249
# P_value_hnscc                  0.027        2.607e-05            0.013
# Correlation_colon              0.156        1.724e-01              NaN
# P_value_colon                  0.126        9.135e-02              NaN
# Correlation_Lscc               0.032       -1.644e-01           -0.075
# P_value_Lscc                   0.749        8.616e-02            0.437
#
# Comparison          STAT3_proteomics  SRC_proteomics
# Correlation_Gbm               -0.042       8.643e-02
# P_value_Gbm                    0.683       3.950e-01
# Correlation_kidney            -0.075      -1.890e-01
# P_value_kidney                 0.688       4.803e-02
# Correlation_Ovar               0.119      -4.705e-02
# P_value_Ovar                   0.285       6.728e-01
# Correlation_Brca              -0.133       2.841e-01
# P_value_Brca                   0.171       2.088e-03
# Correlation_Luad              -0.112      -1.162e-01
# P_value_Luad                   0.244       2.266e-01
# Correlation_hnscc              0.146       2.151e-01
# P_value_hnscc                  0.129       2.471e-02
# Correlation_colon              0.222      -2.941e-01
# P_value_colon                  0.029       3.453e-03
# Correlation_Lscc               0.123       4.662e-01
# P_value_Lscc                   0.213       2.861e-07

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

pathwayAKT = ["PIP5K1C_proteomics","PIP5K1A_proteomics","PDPK1_proteomics","AKT1_proteomics","AKT2_proteomics","AKT3_proteomics","MTOR_proteomics","TP53_proteomics","CASP3_proteomics","CASP7_proteomics","CASP9_proteomics","CASP8_proteomics"]

pathwayAKTdf = df1_transposed[pathwayAKT]

pathwayAKTdf
# Out:
# <style>.container { width:100% !important; }</style>
# Comparison          PIP5K1C_proteomics  PIP5K1A_proteomics  PDPK1_proteomics  \
# Correlation_Gbm                  0.239               0.041            -0.125
# P_value_Gbm                      0.017               0.684             0.216
# Correlation_kidney              -0.111              -0.069             0.177
# P_value_kidney                   0.249               0.480             0.064
# Correlation_Ovar                -0.014              -0.022             0.067
# P_value_Ovar                     0.901               0.842             0.545
# Correlation_Brca                 0.116                 NaN            -0.254
# P_value_Brca                     0.216                 NaN             0.006
# Correlation_Luad                -0.121              -0.191               NaN
# P_value_Luad                     0.207               0.046               NaN
# Correlation_hnscc               -0.177              -0.127             0.164
# P_value_hnscc                    0.065               0.189             0.088
# Correlation_colon                0.220               0.291            -0.259
# P_value_colon                    0.035               0.132             0.010
# Correlation_Lscc                -0.074              -0.034             0.155
# P_value_Lscc                     0.443               0.721             0.107
#
# Comparison          AKT1_proteomics  AKT2_proteomics  AKT3_proteomics  \
# Correlation_Gbm               0.078            0.210       -7.373e-02
# P_value_Gbm                   0.441            0.037        4.683e-01
# Correlation_kidney            0.034            0.111       -7.967e-02
# P_value_kidney                0.721            0.246        4.080e-01
# Correlation_Ovar             -0.101           -0.146       -1.180e-01
# P_value_Ovar                  0.363            0.188        2.882e-01
# Correlation_Brca             -0.131           -0.095        3.070e-01
# P_value_Brca                  0.164            0.311        8.461e-04
# Correlation_Luad              0.045            0.058       -2.595e-01
# P_value_Luad                  0.644            0.548        6.194e-03
# Correlation_hnscc             0.030           -0.230       -1.851e-01
# P_value_hnscc                 0.755            0.016        6.799e-02
# Correlation_colon             0.280            0.025        2.621e-01
# P_value_colon                 0.005            0.823        9.505e-03
# Correlation_Lscc              0.071            0.005       -7.481e-02
# P_value_Lscc                  0.460            0.962        4.373e-01
#
# Comparison          MTOR_proteomics  TP53_proteomics  CASP3_proteomics  \
# Correlation_Gbm               0.204           -0.246             0.246
# P_value_Gbm                   0.042            0.036             0.014
# Correlation_kidney           -0.155           -0.072            -0.199
# P_value_kidney                0.106            0.711             0.037
# Correlation_Ovar             -0.109           -0.070            -0.319
# P_value_Ovar                  0.327            0.531             0.003
# Correlation_Brca             -0.125            0.190             0.097
# P_value_Brca                  0.184            0.042             0.304
# Correlation_Luad                NaN            0.022            -0.051
# P_value_Luad                    NaN            0.844             0.599
# Correlation_hnscc             0.070            0.075            -0.156
# P_value_hnscc                 0.468            0.462             0.104
# Correlation_colon            -0.020           -0.303             0.061
# P_value_colon                 0.842            0.029             0.555
# Correlation_Lscc                NaN           -0.054             0.090
# P_value_Lscc                    NaN            0.573             0.349
#
# Comparison          CASP7_proteomics  CASP9_proteomics  CASP8_proteomics
# Correlation_Gbm           -3.380e-01        -5.809e-02            -0.312
# P_value_Gbm                6.230e-04         5.679e-01             0.002
# Correlation_kidney         6.022e-02         8.118e-02               NaN
# P_value_kidney             5.320e-01         3.992e-01               NaN
# Correlation_Ovar           4.202e-02        -3.719e-01            -0.140
# P_value_Ovar               7.061e-01         9.401e-04             0.207
# Correlation_Brca          -7.037e-02        -1.092e-01             0.090
# P_value_Brca               4.549e-01         2.455e-01             0.338
# Correlation_Luad          -3.039e-03        -9.008e-03             0.079
# P_value_Luad               9.749e-01         9.256e-01             0.568
# Correlation_hnscc         -1.144e-01        -7.038e-02            -0.110
# P_value_hnscc              2.361e-01         4.821e-01             0.255
# Correlation_colon          2.459e-01        -1.234e-01            -0.223
# P_value_colon              1.521e-02         4.194e-01             0.032
# Correlation_Lscc           1.341e-01         1.333e-02             0.151
# P_value_Lscc               1.625e-01         8.901e-01             0.124

# %%
# boolean series returned with False at place of NaN 
bool_series = df["Comparison"].str.startswith("VAV1", na = False) 
  
# displaying filtered dataframe 
df[bool_series]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Comparison'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-89d75d50e69b> in <module>
#       1 # boolean series returned with False at place of NaN
# ----> 2 bool_series = df["Comparison"].str.startswith("VAV1", na = False)
#       3
#       4 # displaying filtered dataframe
#       5 df[bool_series]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Comparison'

# %%
#df["ranking_slope+pvalue"] = df1_merged1["ranking_slope"] + df1_merged1["ranking_pvalue"]
#df1_merged1.nlargest(20,"ranking_slope+pvalue")

# %%
brain = cptac.Gbm()

# %%
prot = brain.get_proteomics()
prot_list = prot.columns.values.tolist()
prot_list
for item in prot_list:
    if item.startswith('PAK'):
        print(item)

# %%
df.hist(column='SD_Correlation', bins = 50)

# %%
df_slope.hist(column='mean', bins = 50)

# %%
plt.rcParams["figure.figsize"] = (12,10)
sns.set(font_scale = 1.3)
a = sns.distplot(df_slope["SD"], bins = 100).set_title('Histogram of SD of the Slopes from Regression Plots for Interacting EGFR Trans Effects')

# %%
plt.rcParams["figure.figsize"] = (12,10)
sns.set(font_scale = 1.3)
a = sns.distplot(df_slope["mean"], bins = 100).set_title('Histogram of Mean of the Slope from Regression Plots for interacting EGFR and Trans Effects')

# %%
plt.rcParams["figure.figsize"] = (12,10)
sns.set(font_scale = 1.3)
a = sns.distplot(df_pvalue["SD"], bins = 100).set_title('Histogram of SD of the P_value from Regression Plots for Interacting EGFR Trans Effects')

# %%
df_other = pd.read_csv('pancan_EGFR_other.csv')
df_other = df_other.drop(['Unnamed: 0'], axis=1)
df_other

# %%
df_pvalue_other = df_other.loc[:,["Comparison","P_value_Gbm","P_value_kidney","P_value_Endo","P_value_Ovar","P_value_Brca","P_value_Luad","P_value_hnscc","P_value_colon"]]
df_pvalue_other= df_pvalue_other.dropna(thresh = 6)
df_pvalue_other["SD_other"] = (df_pvalue_other.loc[:,["Comparison","P_value_Gbm","P_value_kidney","P_value_Endo","P_value_Ovar","P_value_Brca","P_value_Luad","P_value_hnscc","P_value_colon"]].std(axis = 1))
df_pvalue_other.nlargest(10, 'SD_other')

#df_pvalue_other = df_other.loc[:,["Comparison","SD"]]
#df_pvalue = df_pvalue.loc[:,["Comparison","SD"]]
merged =  pd.concat([df_pvalue, df_pvalue_other], axis=1, sort=False)
merged

# %%
# Method 1: on the same Axis
sns.distplot( merged["SD_other"].dropna() , color="red", label="not interacting")
sns.distplot( merged["SD"].dropna() , color="skyblue", label="interacting")

plt.legend()

plt.title('Distribution of pvalues for interacting and non interacting EGFR trans effects')
plt.xlabel('pvalue')

# %%
df_slope_other = df_other.loc[:,["Comparison","Slope_Gbm","Slope_kidney","Slope_Endo","Slope_Ovar","Slope_Brca","Slope_Luad","Slope_hnscc","Slope_colon"]]
df_slope_other= df_slope_other.dropna(thresh = 6)
df_slope_other["SD_other"] = (df_slope_other.loc[:,["Comparison","Slope_Gbm","Slope_kidney","Slope_Endo","Slope_Ovar","Slope_Brca","Slope_Luad","Slope_hnscc","Slope_colon"]].std(axis = 1))
df_slope_other.nlargest(10, 'SD_other')

#df_pvalue_other = df_other.loc[:,["Comparison","SD"]]
#df_pvalue = df_pvalue.loc[:,["Comparison","SD"]]
merged2 =  pd.concat([df_slope, df_slope_other], axis=1, sort=False)
merged2

# %%
# Method 1: on the same Axis
sns.distplot( merged2["SD_other"].dropna() , color="red", label="not interacting")
sns.distplot( merged2["SD"].dropna() , color="skyblue", label="interacting")

plt.legend()

plt.title('Distribution of Correlation for interacting and non interacting EGFR trans effects')
plt.xlabel('pvalue')
