# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest
#sys.path.append('C:\\Users\\brittany\\henderson\\GitHub\\GBM_for_CPTAC\\')
#import cis_functions as f
#sys.path.append('C:\\Users\\Lindsey\\Documents\\GitHub\\WhenMutationsDontMatter\\')
#import plot_utils as p


import cptac
import cptac.utils as u
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # GBM

# %%
df = pd.read_csv("GBM_EGFR_all_pearson_sig.csv")
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#              Comparison  Correlation       P_value
# 0       EGFR_proteomics     1.000000  0.000000e+00
# 1     PHLDA1_proteomics     0.816848  6.553435e-25
# 2       GRB2_proteomics    -0.610889  1.886384e-11
# 3      SOCS2_proteomics     0.562720  1.343464e-09
# 4       CDH4_proteomics     0.559180  1.790048e-09
# ..                  ...          ...           ...
# 137  RNASET2_proteomics    -0.444693  4.000047e-06
# 138    ACSL1_proteomics    -0.443099  4.371271e-06
# 139     TMX2_proteomics     0.442471  4.526188e-06
# 140  AFAP1L1_proteomics     0.442470  4.526445e-06
# 141    PTBP3_proteomics    -0.442173  4.601691e-06
#
# [142 rows x 3 columns]

# %% [markdown]
# # Kidney

# %%
df2 = pd.read_csv("Kidney_EGFR_all_pearson_sig.csv")

# %%
df2 = df2.drop(['Unnamed: 0'], axis=1)
df2
# Out:
#             Comparison  Correlation       P_value
# 0      EGFR_proteomics     1.000000  0.000000e+00
# 1    ATP11A_proteomics     0.577079  4.144636e-11
# 2     PLCB1_proteomics     0.561952  1.684847e-10
# 3     APAF1_proteomics     0.560909  1.851119e-10
# 4    HPCAL1_proteomics     0.556681  2.701940e-10
# ..                 ...          ...           ...
# 81     GGA1_proteomics    -0.422912  4.169534e-06
# 82    TULP3_proteomics     0.421794  4.447417e-06
# 83    ABCC3_proteomics     0.421532  4.514914e-06
# 84  CSNK2A1_proteomics     0.420678  4.741825e-06
# 85    PHKA2_proteomics     0.420110  4.898825e-06
#
# [86 rows x 3 columns]

# %%
Gbm_kidney = pd.merge(df, df2, on="Comparison", how = "outer")
Gbm_kidney = Gbm_kidney.rename(columns={"Correlation_x": "Correlation_Gbm","P_value_x":"P_value_Gbm" ,"Correlation_y":"Correlation_kidney","P_value_y": "P_value_kidney" })
Gbm_kidney
# Out:
#              Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0       EGFR_proteomics         1.000000  0.000000e+00            1.000000
# 1     PHLDA1_proteomics         0.816848  6.553435e-25                 NaN
# 2       GRB2_proteomics        -0.610889  1.886384e-11                 NaN
# 3      SOCS2_proteomics         0.562720  1.343464e-09                 NaN
# 4       CDH4_proteomics         0.559180  1.790048e-09                 NaN
# ..                  ...              ...           ...                 ...
# 221     GGA1_proteomics              NaN           NaN           -0.422912
# 222    TULP3_proteomics              NaN           NaN            0.421794
# 223    ABCC3_proteomics              NaN           NaN            0.421532
# 224  CSNK2A1_proteomics              NaN           NaN            0.420678
# 225    PHKA2_proteomics              NaN           NaN            0.420110
#
#      P_value_kidney
# 0          0.000000
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 221        0.000004
# 222        0.000004
# 223        0.000005
# 224        0.000005
# 225        0.000005
#
# [226 rows x 5 columns]

# %% [markdown]
# # Ovarian

# %%
df_Ovar = pd.read_csv("Ovar_EGFR_all_pearson_sig.csv")
df_Ovar = df_Ovar.drop(['Unnamed: 0'], axis=1)
df_Ovar
# Out:
#            Comparison  Correlation       P_value
# 0     EGFR_proteomics     1.000000  0.000000e+00
# 1    ERO1A_proteomics     0.512158  7.452351e-07
# 2   CGGBP1_proteomics    -0.492993  2.192339e-06
# 3  PROSER2_proteomics     0.524593  2.244019e-06
# 4       CP_proteomics     0.489328  2.675011e-06
# 5  ALDH1L1_proteomics     0.486761  3.070806e-06
# 6    TRPM4_proteomics     0.483859  3.584502e-06

# %%
pancan = pd.merge(Gbm_kidney, df_Ovar, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_Ovar","P_value": "P_value_Ovar" })
pancan
# Out:
#              Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0       EGFR_proteomics         1.000000  0.000000e+00                 1.0
# 1     PHLDA1_proteomics         0.816848  6.553435e-25                 NaN
# 2       GRB2_proteomics        -0.610889  1.886384e-11                 NaN
# 3      SOCS2_proteomics         0.562720  1.343464e-09                 NaN
# 4       CDH4_proteomics         0.559180  1.790048e-09                 NaN
# ..                  ...              ...           ...                 ...
# 227   CGGBP1_proteomics              NaN           NaN                 NaN
# 228  PROSER2_proteomics              NaN           NaN                 NaN
# 229       CP_proteomics              NaN           NaN                 NaN
# 230  ALDH1L1_proteomics              NaN           NaN                 NaN
# 231    TRPM4_proteomics              NaN           NaN                 NaN
#
#      P_value_kidney  Correlation_Ovar  P_value_Ovar
# 0               0.0          1.000000      0.000000
# 1               NaN               NaN           NaN
# 2               NaN               NaN           NaN
# 3               NaN               NaN           NaN
# 4               NaN               NaN           NaN
# ..              ...               ...           ...
# 227             NaN         -0.492993      0.000002
# 228             NaN          0.524593      0.000002
# 229             NaN          0.489328      0.000003
# 230             NaN          0.486761      0.000003
# 231             NaN          0.483859      0.000004
#
# [232 rows x 7 columns]

# %% [markdown]
# # BRCA

# %%
df_Brca = pd.read_csv("Brca_EGFR_all_pearson_sig.csv")
df_Brca = df_Brca.drop(['Unnamed: 0'], axis=1)
df_Brca
# Out:
#             Comparison  Correlation       P_value
# 0      EGFR_proteomics     1.000000  0.000000e+00
# 1      MPP6_proteomics     0.648202  4.834438e-15
# 2     CPNE8_proteomics     0.616453  2.229263e-13
# 3    CRYBG3_proteomics     0.609997  4.612176e-13
# 4     PSAT1_proteomics     0.609319  4.973595e-13
# ..                 ...          ...           ...
# 362   CD2AP_proteomics    -0.411948  4.780738e-06
# 363    FLNA_proteomics     0.411763  4.832382e-06
# 364    RPS2_proteomics     0.411744  4.837874e-06
# 365   FOXC1_proteomics     0.437118  4.867852e-06
# 366   DACH1_proteomics    -0.411551  4.892327e-06
#
# [367 rows x 3 columns]

# %%
pancan = pd.merge(pancan, df_Brca, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_Brca","P_value": "P_value_Brca" })
pancan
# Out:
#             Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0      EGFR_proteomics         1.000000  0.000000e+00                 1.0
# 1    PHLDA1_proteomics         0.816848  6.553435e-25                 NaN
# 2      GRB2_proteomics        -0.610889  1.886384e-11                 NaN
# 3     SOCS2_proteomics         0.562720  1.343464e-09                 NaN
# 4      CDH4_proteomics         0.559180  1.790048e-09                 NaN
# ..                 ...              ...           ...                 ...
# 580   CD2AP_proteomics              NaN           NaN                 NaN
# 581    FLNA_proteomics              NaN           NaN                 NaN
# 582    RPS2_proteomics              NaN           NaN                 NaN
# 583   FOXC1_proteomics              NaN           NaN                 NaN
# 584   DACH1_proteomics              NaN           NaN                 NaN
#
#      P_value_kidney  Correlation_Ovar  P_value_Ovar  Correlation_Brca  \
# 0               0.0               1.0           0.0          1.000000
# 1               NaN               NaN           NaN               NaN
# 2               NaN               NaN           NaN               NaN
# 3               NaN               NaN           NaN               NaN
# 4               NaN               NaN           NaN               NaN
# ..              ...               ...           ...               ...
# 580             NaN               NaN           NaN         -0.411948
# 581             NaN               NaN           NaN          0.411763
# 582             NaN               NaN           NaN          0.411744
# 583             NaN               NaN           NaN          0.437118
# 584             NaN               NaN           NaN         -0.411551
#
#      P_value_Brca
# 0        0.000000
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 580      0.000005
# 581      0.000005
# 582      0.000005
# 583      0.000005
# 584      0.000005
#
# [585 rows x 9 columns]

# %% [markdown]
# # Luad

# %%
df_Luad = pd.read_csv("Luad_EGFR_all_pearson_sig.csv")
df_Luad = df_Luad.drop(['Unnamed: 0'], axis=1)
df_Luad
# Out:
#              Comparison  Correlation       P_value
# 0       EGFR_proteomics     1.000000  0.000000e+00
# 1       GGCT_proteomics     0.609006  1.676601e-12
# 2     LANCL2_proteomics     0.588808  1.328507e-11
# 3     NUDCD3_proteomics     0.568383  9.362813e-11
# 4    TAX1BP1_proteomics     0.561554  1.746498e-10
# ..                  ...          ...           ...
# 85     ACAP1_proteomics    -0.424040  3.905935e-06
# 86  NIPSNAP2_proteomics     0.421557  4.508491e-06
# 87     GSPT1_proteomics     0.421196  4.602934e-06
# 88   FAM120C_proteomics     0.421091  4.630755e-06
# 89      EMC3_proteomics     0.420933  4.673110e-06
#
# [90 rows x 3 columns]

# %%
pancan = pd.merge(pancan, df_Luad, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_Luad","P_value": "P_value_Luad" })
pancan
# Out:
#              Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0       EGFR_proteomics         1.000000  0.000000e+00                 1.0
# 1     PHLDA1_proteomics         0.816848  6.553435e-25                 NaN
# 2       GRB2_proteomics        -0.610889  1.886384e-11                 NaN
# 3      SOCS2_proteomics         0.562720  1.343464e-09                 NaN
# 4       CDH4_proteomics         0.559180  1.790048e-09                 NaN
# ..                  ...              ...           ...                 ...
# 661     ODR4_proteomics              NaN           NaN                 NaN
# 662    ACAP1_proteomics              NaN           NaN                 NaN
# 663    GSPT1_proteomics              NaN           NaN                 NaN
# 664  FAM120C_proteomics              NaN           NaN                 NaN
# 665     EMC3_proteomics              NaN           NaN                 NaN
#
#      P_value_kidney  Correlation_Ovar  P_value_Ovar  Correlation_Brca  \
# 0               0.0               1.0           0.0               1.0
# 1               NaN               NaN           NaN               NaN
# 2               NaN               NaN           NaN               NaN
# 3               NaN               NaN           NaN               NaN
# 4               NaN               NaN           NaN               NaN
# ..              ...               ...           ...               ...
# 661             NaN               NaN           NaN               NaN
# 662             NaN               NaN           NaN               NaN
# 663             NaN               NaN           NaN               NaN
# 664             NaN               NaN           NaN               NaN
# 665             NaN               NaN           NaN               NaN
#
#      P_value_Brca  Correlation_Luad  P_value_Luad
# 0             0.0          1.000000      0.000000
# 1             NaN               NaN           NaN
# 2             NaN               NaN           NaN
# 3             NaN               NaN           NaN
# 4             NaN               NaN           NaN
# ..            ...               ...           ...
# 661           NaN          0.424936      0.000004
# 662           NaN         -0.424040      0.000004
# 663           NaN          0.421196      0.000005
# 664           NaN          0.421091      0.000005
# 665           NaN          0.420933      0.000005
#
# [666 rows x 11 columns]

# %% [markdown]
# # HNSCC

# %%
df_hnscc = pd.read_csv("Hnscc_EGFR_all_pearson_sig.csv")
df_hnscc = df_hnscc.drop(['Unnamed: 0'], axis=1)
df_hnscc
# Out:
#             Comparison  Correlation       P_value
# 0      EGFR_proteomics     1.000000  0.000000e+00
# 1    LANCL2_proteomics     0.796728  3.798194e-25
# 2    PHLDA3_proteomics     0.763784  4.542521e-22
# 3    PHLDA1_proteomics     0.664271  3.426615e-15
# 4    PHLDA2_proteomics     0.649034  2.302129e-14
# ..                 ...          ...           ...
# 101  PTPN18_proteomics    -0.425870  3.897970e-06
# 102    FADD_proteomics     0.425363  4.013867e-06
# 103  RASAL3_proteomics    -0.424931  4.115124e-06
# 104  MAP4K1_proteomics    -0.423254  4.531560e-06
# 105   ADPRH_proteomics    -0.423192  4.547617e-06
#
# [106 rows x 3 columns]

# %%
pancan = pd.merge(pancan, df_hnscc, on="Comparison", how = "outer")
pancan = pancan.rename(columns={ "Correlation": "Correlation_hnscc","P_value": "P_value_hnscc" })
pancan
# Out:
#             Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0      EGFR_proteomics         1.000000  0.000000e+00                 1.0
# 1    PHLDA1_proteomics         0.816848  6.553435e-25                 NaN
# 2      GRB2_proteomics        -0.610889  1.886384e-11                 NaN
# 3     SOCS2_proteomics         0.562720  1.343464e-09                 NaN
# 4      CDH4_proteomics         0.559180  1.790048e-09                 NaN
# ..                 ...              ...           ...                 ...
# 737  CADPS2_proteomics              NaN           NaN                 NaN
# 738  PTPN18_proteomics              NaN           NaN                 NaN
# 739    FADD_proteomics              NaN           NaN                 NaN
# 740  MAP4K1_proteomics              NaN           NaN                 NaN
# 741   ADPRH_proteomics              NaN           NaN                 NaN
#
#      P_value_kidney  Correlation_Ovar  P_value_Ovar  Correlation_Brca  \
# 0               0.0               1.0           0.0               1.0
# 1               NaN               NaN           NaN               NaN
# 2               NaN               NaN           NaN               NaN
# 3               NaN               NaN           NaN               NaN
# 4               NaN               NaN           NaN               NaN
# ..              ...               ...           ...               ...
# 737             NaN               NaN           NaN               NaN
# 738             NaN               NaN           NaN               NaN
# 739             NaN               NaN           NaN               NaN
# 740             NaN               NaN           NaN               NaN
# 741             NaN               NaN           NaN               NaN
#
#      P_value_Brca  Correlation_Luad  P_value_Luad  Correlation_hnscc  \
# 0             0.0               1.0           0.0           1.000000
# 1             NaN               NaN           NaN           0.664271
# 2             NaN               NaN           NaN          -0.532341
# 3             NaN               NaN           NaN                NaN
# 4             NaN               NaN           NaN                NaN
# ..            ...               ...           ...                ...
# 737           NaN               NaN           NaN          -0.448984
# 738           NaN               NaN           NaN          -0.425870
# 739           NaN               NaN           NaN           0.425363
# 740           NaN               NaN           NaN          -0.423254
# 741           NaN               NaN           NaN          -0.423192
#
#      P_value_hnscc
# 0     0.000000e+00
# 1     3.426615e-15
# 2     2.559824e-09
# 3              NaN
# 4              NaN
# ..             ...
# 737   3.534188e-06
# 738   3.897970e-06
# 739   4.013867e-06
# 740   4.531560e-06
# 741   4.547617e-06
#
# [742 rows x 13 columns]

# %% [markdown]
# # Colon

# %%
df_colon = pd.read_csv("Colon_EGFR_all_pearson_sig.csv")
df_colon = df_colon.drop(['Unnamed: 0'], axis=1)
df_colon
# Out:
#             Comparison  Correlation       P_value
# 0      EGFR_proteomics     1.000000  0.000000e+00
# 1      UTP6_proteomics    -0.510343  1.733748e-07
# 2      RAE1_proteomics    -0.498802  1.993818e-07
# 3      GAR1_proteomics    -0.489788  3.550550e-07
# 4     RALYL_proteomics    -0.485763  4.569947e-07
# 5      TFAM_proteomics    -0.470185  1.178068e-06
# 6    NUP153_proteomics    -0.470155  1.180163e-06
# 7      SCG2_proteomics     0.455901  2.696792e-06
# 8   PPP2R5D_proteomics    -0.455111  2.820289e-06
# 9      SBF1_proteomics     0.452041  3.352031e-06
# 10   MAMDC2_proteomics     0.530627  3.858198e-06
# 11    SNU13_proteomics    -0.448374  4.111219e-06
# 12     RALY_proteomics    -0.444764  5.014786e-06
# 13    DDX27_proteomics    -0.443171  5.470378e-06
# 14  NDUFAB1_proteomics    -0.442201  5.766711e-06
# 15   POFUT1_proteomics    -0.441381  6.028671e-06

# %%
pancan = pd.merge(pancan, df_colon, on="Comparison", how = "outer")
pancan = pancan.rename(columns={ "Correlation": "Correlation_colon","P_value": "P_value_colon" })
pancan
# Out:
#              Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0       EGFR_proteomics         1.000000  0.000000e+00                 1.0
# 1     PHLDA1_proteomics         0.816848  6.553435e-25                 NaN
# 2       GRB2_proteomics        -0.610889  1.886384e-11                 NaN
# 3      SOCS2_proteomics         0.562720  1.343464e-09                 NaN
# 4       CDH4_proteomics         0.559180  1.790048e-09                 NaN
# ..                  ...              ...           ...                 ...
# 752    SNU13_proteomics              NaN           NaN                 NaN
# 753     RALY_proteomics              NaN           NaN                 NaN
# 754    DDX27_proteomics              NaN           NaN                 NaN
# 755  NDUFAB1_proteomics              NaN           NaN                 NaN
# 756   POFUT1_proteomics              NaN           NaN                 NaN
#
#      P_value_kidney  Correlation_Ovar  P_value_Ovar  Correlation_Brca  \
# 0               0.0               1.0           0.0               1.0
# 1               NaN               NaN           NaN               NaN
# 2               NaN               NaN           NaN               NaN
# 3               NaN               NaN           NaN               NaN
# 4               NaN               NaN           NaN               NaN
# ..              ...               ...           ...               ...
# 752             NaN               NaN           NaN               NaN
# 753             NaN               NaN           NaN               NaN
# 754             NaN               NaN           NaN               NaN
# 755             NaN               NaN           NaN               NaN
# 756             NaN               NaN           NaN               NaN
#
#      P_value_Brca  Correlation_Luad  P_value_Luad  Correlation_hnscc  \
# 0             0.0               1.0           0.0           1.000000
# 1             NaN               NaN           NaN           0.664271
# 2             NaN               NaN           NaN          -0.532341
# 3             NaN               NaN           NaN                NaN
# 4             NaN               NaN           NaN                NaN
# ..            ...               ...           ...                ...
# 752           NaN               NaN           NaN                NaN
# 753           NaN               NaN           NaN                NaN
# 754           NaN               NaN           NaN                NaN
# 755           NaN               NaN           NaN                NaN
# 756           NaN               NaN           NaN                NaN
#
#      P_value_hnscc  Correlation_colon  P_value_colon
# 0     0.000000e+00           1.000000       0.000000
# 1     3.426615e-15                NaN            NaN
# 2     2.559824e-09                NaN            NaN
# 3              NaN                NaN            NaN
# 4              NaN                NaN            NaN
# ..             ...                ...            ...
# 752            NaN          -0.448374       0.000004
# 753            NaN          -0.444764       0.000005
# 754            NaN          -0.443171       0.000005
# 755            NaN          -0.442201       0.000006
# 756            NaN          -0.441381       0.000006
#
# [757 rows x 15 columns]

# %% [markdown]
# # LSCC

# %%
df_Lscc = pd.read_csv("Lscc_EGFR_all_pearson_sig.csv")
df_Lscc = df_Lscc.drop(['Unnamed: 0'], axis=1)
df_Lscc
# Out:
#              Comparison  Correlation       P_value
# 0       EGFR_proteomics     1.000000  0.000000e+00
# 1     PHLDA1_proteomics     0.709812  3.919195e-18
# 2     PHLDA3_proteomics     0.685644  1.412309e-16
# 3     LANCL2_proteomics     0.572261  6.528910e-11
# 4      ITGB4_proteomics     0.567380  1.026981e-10
# ..                  ...          ...           ...
# 62     TTYH3_proteomics     0.440551  2.562184e-06
# 63      NPTN_proteomics     0.427819  3.133199e-06
# 64   PLEKHA1_proteomics     0.426354  3.413811e-06
# 65  FAM160A1_proteomics     0.423148  4.113199e-06
# 66     JADE3_proteomics    -0.422132  4.361691e-06
#
# [67 rows x 3 columns]

# %%
pancan = pd.merge(pancan, df_Lscc, on="Comparison", how = "outer")
pancan = pancan.rename(columns={ "Correlation": "Correlation_Lscc","P_value": "P_value_Lscc" })
pancan
# Out:
#               Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0        EGFR_proteomics         1.000000  0.000000e+00                 1.0
# 1      PHLDA1_proteomics         0.816848  6.553435e-25                 NaN
# 2        GRB2_proteomics        -0.610889  1.886384e-11                 NaN
# 3       SOCS2_proteomics         0.562720  1.343464e-09                 NaN
# 4        CDH4_proteomics         0.559180  1.790048e-09                 NaN
# ..                   ...              ...           ...                 ...
# 797       WLS_proteomics              NaN           NaN                 NaN
# 798      NPTN_proteomics              NaN           NaN                 NaN
# 799   PLEKHA1_proteomics              NaN           NaN                 NaN
# 800  FAM160A1_proteomics              NaN           NaN                 NaN
# 801     JADE3_proteomics              NaN           NaN                 NaN
#
#      P_value_kidney  Correlation_Ovar  P_value_Ovar  Correlation_Brca  \
# 0               0.0               1.0           0.0               1.0
# 1               NaN               NaN           NaN               NaN
# 2               NaN               NaN           NaN               NaN
# 3               NaN               NaN           NaN               NaN
# 4               NaN               NaN           NaN               NaN
# ..              ...               ...           ...               ...
# 797             NaN               NaN           NaN               NaN
# 798             NaN               NaN           NaN               NaN
# 799             NaN               NaN           NaN               NaN
# 800             NaN               NaN           NaN               NaN
# 801             NaN               NaN           NaN               NaN
#
#      P_value_Brca  Correlation_Luad  P_value_Luad  Correlation_hnscc  \
# 0             0.0               1.0           0.0           1.000000
# 1             NaN               NaN           NaN           0.664271
# 2             NaN               NaN           NaN          -0.532341
# 3             NaN               NaN           NaN                NaN
# 4             NaN               NaN           NaN                NaN
# ..            ...               ...           ...                ...
# 797           NaN               NaN           NaN                NaN
# 798           NaN               NaN           NaN                NaN
# 799           NaN               NaN           NaN                NaN
# 800           NaN               NaN           NaN                NaN
# 801           NaN               NaN           NaN                NaN
#
#      P_value_hnscc  Correlation_colon  P_value_colon  Correlation_Lscc  \
# 0     0.000000e+00                1.0            0.0          1.000000
# 1     3.426615e-15                NaN            NaN          0.709812
# 2     2.559824e-09                NaN            NaN               NaN
# 3              NaN                NaN            NaN               NaN
# 4              NaN                NaN            NaN               NaN
# ..             ...                ...            ...               ...
# 797            NaN                NaN            NaN          0.431664
# 798            NaN                NaN            NaN          0.427819
# 799            NaN                NaN            NaN          0.426354
# 800            NaN                NaN            NaN          0.423148
# 801            NaN                NaN            NaN         -0.422132
#
#      P_value_Lscc
# 0    0.000000e+00
# 1    3.919195e-18
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 797  2.496726e-06
# 798  3.133199e-06
# 799  3.413811e-06
# 800  4.113199e-06
# 801  4.361691e-06
#
# [802 rows x 17 columns]

# %%
pancan.to_csv("pancan_EGFR_all_sig.csv")
