# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest
#sys.path.append('C:\\Users\\brittany\\henderson\\GitHub\\GBM_for_CPTAC\\')
#import cis_functions as f
#sys.path.append('C:\\Users\\Lindsey\\Documents\\GitHub\\WhenMutationsDontMatter\\')
#import plot_utils as p


import cptac
import cptac.utils as u
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # GBM

# %%
df = pd.read_csv("GBM_EGFR_all_pearson_sig_type.csv")
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#              Comparison  Correlation       P_value Cancer Type
# 0       EGFR_proteomics     1.000000  0.000000e+00         GBM
# 1     PHLDA1_proteomics     0.816848  6.553435e-25         GBM
# 2       GRB2_proteomics    -0.610889  1.886384e-11         GBM
# 3      SOCS2_proteomics     0.562720  1.343464e-09         GBM
# 4       CDH4_proteomics     0.559180  1.790048e-09         GBM
# ..                  ...          ...           ...         ...
# 137  RNASET2_proteomics    -0.444693  4.000047e-06         GBM
# 138    ACSL1_proteomics    -0.443099  4.371271e-06         GBM
# 139     TMX2_proteomics     0.442471  4.526188e-06         GBM
# 140  AFAP1L1_proteomics     0.442470  4.526445e-06         GBM
# 141    PTBP3_proteomics    -0.442173  4.601691e-06         GBM
#
# [142 rows x 4 columns]

# %% [markdown]
# # Kidney

# %%
df2 = pd.read_csv("Kidney_EGFR_all_pearson_sig_type.csv")

# %%
df2 = df2.drop(['Unnamed: 0'], axis=1)
df2
# Out:
#             Comparison  Correlation       P_value Cancer Type
# 0      EGFR_proteomics     1.000000  0.000000e+00      Kidney
# 1    ATP11A_proteomics     0.577079  4.144636e-11      Kidney
# 2     PLCB1_proteomics     0.561952  1.684847e-10      Kidney
# 3     APAF1_proteomics     0.560909  1.851119e-10      Kidney
# 4    HPCAL1_proteomics     0.556681  2.701940e-10      Kidney
# ..                 ...          ...           ...         ...
# 81     GGA1_proteomics    -0.422912  4.169534e-06      Kidney
# 82    TULP3_proteomics     0.421794  4.447417e-06      Kidney
# 83    ABCC3_proteomics     0.421532  4.514914e-06      Kidney
# 84  CSNK2A1_proteomics     0.420678  4.741825e-06      Kidney
# 85    PHKA2_proteomics     0.420110  4.898825e-06      Kidney
#
# [86 rows x 4 columns]

# %%
Gbm_kidney = df.append(df2)
Gbm_kidney
# Out:
#             Comparison  Correlation       P_value Cancer Type
# 0      EGFR_proteomics     1.000000  0.000000e+00         GBM
# 1    PHLDA1_proteomics     0.816848  6.553435e-25         GBM
# 2      GRB2_proteomics    -0.610889  1.886384e-11         GBM
# 3     SOCS2_proteomics     0.562720  1.343464e-09         GBM
# 4      CDH4_proteomics     0.559180  1.790048e-09         GBM
# ..                 ...          ...           ...         ...
# 81     GGA1_proteomics    -0.422912  4.169534e-06      Kidney
# 82    TULP3_proteomics     0.421794  4.447417e-06      Kidney
# 83    ABCC3_proteomics     0.421532  4.514914e-06      Kidney
# 84  CSNK2A1_proteomics     0.420678  4.741825e-06      Kidney
# 85    PHKA2_proteomics     0.420110  4.898825e-06      Kidney
#
# [228 rows x 4 columns]

# %% [markdown]
# # Ovarian

# %%
df_Ovar = pd.read_csv("Ovar_EGFR_all_pearson_sig_type.csv")
df_Ovar = df_Ovar.drop(['Unnamed: 0'], axis=1)
df_Ovar
# Out:
#            Comparison  Correlation       P_value Cancer Type
# 0     EGFR_proteomics     1.000000  0.000000e+00     Ovarian
# 1    ERO1A_proteomics     0.512158  7.452351e-07     Ovarian
# 2   CGGBP1_proteomics    -0.492993  2.192339e-06     Ovarian
# 3  PROSER2_proteomics     0.524593  2.244019e-06     Ovarian
# 4       CP_proteomics     0.489328  2.675011e-06     Ovarian
# 5  ALDH1L1_proteomics     0.486761  3.070806e-06     Ovarian
# 6    TRPM4_proteomics     0.483859  3.584502e-06     Ovarian

# %%
pancan = Gbm_kidney.append(df_Ovar)
pancan
# Out:
#             Comparison  Correlation       P_value Cancer Type
# 0      EGFR_proteomics     1.000000  0.000000e+00         GBM
# 1    PHLDA1_proteomics     0.816848  6.553435e-25         GBM
# 2      GRB2_proteomics    -0.610889  1.886384e-11         GBM
# 3     SOCS2_proteomics     0.562720  1.343464e-09         GBM
# 4      CDH4_proteomics     0.559180  1.790048e-09         GBM
# ..                 ...          ...           ...         ...
# 2    CGGBP1_proteomics    -0.492993  2.192339e-06     Ovarian
# 3   PROSER2_proteomics     0.524593  2.244019e-06     Ovarian
# 4        CP_proteomics     0.489328  2.675011e-06     Ovarian
# 5   ALDH1L1_proteomics     0.486761  3.070806e-06     Ovarian
# 6     TRPM4_proteomics     0.483859  3.584502e-06     Ovarian
#
# [235 rows x 4 columns]

# %% [markdown]
# # BRCA

# %%
df_Brca = pd.read_csv("Brca_EGFR_all_pearson_sig_type.csv")
df_Brca = df_Brca.drop(['Unnamed: 0'], axis=1)
df_Brca
# Out:
#             Comparison  Correlation       P_value Cancer Type
# 0      EGFR_proteomics     1.000000  0.000000e+00        Brca
# 1      MPP6_proteomics     0.648202  4.834438e-15        Brca
# 2     CPNE8_proteomics     0.616453  2.229263e-13        Brca
# 3    CRYBG3_proteomics     0.609997  4.612176e-13        Brca
# 4     PSAT1_proteomics     0.609319  4.973595e-13        Brca
# ..                 ...          ...           ...         ...
# 362   CD2AP_proteomics    -0.411948  4.780738e-06        Brca
# 363    FLNA_proteomics     0.411763  4.832382e-06        Brca
# 364    RPS2_proteomics     0.411744  4.837874e-06        Brca
# 365   FOXC1_proteomics     0.437118  4.867852e-06        Brca
# 366   DACH1_proteomics    -0.411551  4.892327e-06        Brca
#
# [367 rows x 4 columns]

# %%
pancan = pancan.append(df_Brca)
pancan
# Out:
#             Comparison  Correlation       P_value Cancer Type
# 0      EGFR_proteomics     1.000000  0.000000e+00         GBM
# 1    PHLDA1_proteomics     0.816848  6.553435e-25         GBM
# 2      GRB2_proteomics    -0.610889  1.886384e-11         GBM
# 3     SOCS2_proteomics     0.562720  1.343464e-09         GBM
# 4      CDH4_proteomics     0.559180  1.790048e-09         GBM
# ..                 ...          ...           ...         ...
# 362   CD2AP_proteomics    -0.411948  4.780738e-06        Brca
# 363    FLNA_proteomics     0.411763  4.832382e-06        Brca
# 364    RPS2_proteomics     0.411744  4.837874e-06        Brca
# 365   FOXC1_proteomics     0.437118  4.867852e-06        Brca
# 366   DACH1_proteomics    -0.411551  4.892327e-06        Brca
#
# [602 rows x 4 columns]

# %% [markdown]
# # Luad

# %%
df_Luad = pd.read_csv("Luad_EGFR_all_pearson_sig_type.csv")
df_Luad = df_Luad.drop(['Unnamed: 0'], axis=1)
df_Luad
# Out:
#              Comparison  Correlation       P_value Cancer Type
# 0       EGFR_proteomics     1.000000  0.000000e+00        Luad
# 1       GGCT_proteomics     0.609006  1.676601e-12        Luad
# 2     LANCL2_proteomics     0.588808  1.328507e-11        Luad
# 3     NUDCD3_proteomics     0.568383  9.362813e-11        Luad
# 4    TAX1BP1_proteomics     0.561554  1.746498e-10        Luad
# ..                  ...          ...           ...         ...
# 85     ACAP1_proteomics    -0.424040  3.905935e-06        Luad
# 86  NIPSNAP2_proteomics     0.421557  4.508491e-06        Luad
# 87     GSPT1_proteomics     0.421196  4.602934e-06        Luad
# 88   FAM120C_proteomics     0.421091  4.630755e-06        Luad
# 89      EMC3_proteomics     0.420933  4.673110e-06        Luad
#
# [90 rows x 4 columns]

# %%
pancan = pancan.append(df_Luad)
pancan
# Out:
#              Comparison  Correlation       P_value Cancer Type
# 0       EGFR_proteomics     1.000000  0.000000e+00         GBM
# 1     PHLDA1_proteomics     0.816848  6.553435e-25         GBM
# 2       GRB2_proteomics    -0.610889  1.886384e-11         GBM
# 3      SOCS2_proteomics     0.562720  1.343464e-09         GBM
# 4       CDH4_proteomics     0.559180  1.790048e-09         GBM
# ..                  ...          ...           ...         ...
# 85     ACAP1_proteomics    -0.424040  3.905935e-06        Luad
# 86  NIPSNAP2_proteomics     0.421557  4.508491e-06        Luad
# 87     GSPT1_proteomics     0.421196  4.602934e-06        Luad
# 88   FAM120C_proteomics     0.421091  4.630755e-06        Luad
# 89      EMC3_proteomics     0.420933  4.673110e-06        Luad
#
# [692 rows x 4 columns]

# %% [markdown]
# # HNSCC

# %%
df_hnscc = pd.read_csv("Hnscc_EGFR_all_pearson_sig_type.csv")
df_hnscc = df_hnscc.drop(['Unnamed: 0'], axis=1)
df_hnscc
# Out:
#             Comparison  Correlation       P_value Cancer Type
# 0      EGFR_proteomics     1.000000  0.000000e+00       Hnscc
# 1    LANCL2_proteomics     0.796728  3.798194e-25       Hnscc
# 2    PHLDA3_proteomics     0.763784  4.542521e-22       Hnscc
# 3    PHLDA1_proteomics     0.664271  3.426615e-15       Hnscc
# 4    PHLDA2_proteomics     0.649034  2.302129e-14       Hnscc
# ..                 ...          ...           ...         ...
# 101  PTPN18_proteomics    -0.425870  3.897970e-06       Hnscc
# 102    FADD_proteomics     0.425363  4.013867e-06       Hnscc
# 103  RASAL3_proteomics    -0.424931  4.115124e-06       Hnscc
# 104  MAP4K1_proteomics    -0.423254  4.531560e-06       Hnscc
# 105   ADPRH_proteomics    -0.423192  4.547617e-06       Hnscc
#
# [106 rows x 4 columns]

# %%
pancan = pancan.append(df_hnscc)
pancan
# Out:
#             Comparison  Correlation       P_value Cancer Type
# 0      EGFR_proteomics     1.000000  0.000000e+00         GBM
# 1    PHLDA1_proteomics     0.816848  6.553435e-25         GBM
# 2      GRB2_proteomics    -0.610889  1.886384e-11         GBM
# 3     SOCS2_proteomics     0.562720  1.343464e-09         GBM
# 4      CDH4_proteomics     0.559180  1.790048e-09         GBM
# ..                 ...          ...           ...         ...
# 101  PTPN18_proteomics    -0.425870  3.897970e-06       Hnscc
# 102    FADD_proteomics     0.425363  4.013867e-06       Hnscc
# 103  RASAL3_proteomics    -0.424931  4.115124e-06       Hnscc
# 104  MAP4K1_proteomics    -0.423254  4.531560e-06       Hnscc
# 105   ADPRH_proteomics    -0.423192  4.547617e-06       Hnscc
#
# [798 rows x 4 columns]

# %% [markdown]
# # Colon

# %%
df_colon = pd.read_csv("Colon_EGFR_all_pearson_sig_type.csv")
df_colon = df_colon.drop(['Unnamed: 0'], axis=1)
df_colon
# Out:
#             Comparison  Correlation       P_value Cancer Type
# 0      EGFR_proteomics     1.000000  0.000000e+00       Colon
# 1      UTP6_proteomics    -0.510343  1.733748e-07       Colon
# 2      RAE1_proteomics    -0.498802  1.993818e-07       Colon
# 3      GAR1_proteomics    -0.489788  3.550550e-07       Colon
# 4     RALYL_proteomics    -0.485763  4.569947e-07       Colon
# 5      TFAM_proteomics    -0.470185  1.178068e-06       Colon
# 6    NUP153_proteomics    -0.470155  1.180163e-06       Colon
# 7      SCG2_proteomics     0.455901  2.696792e-06       Colon
# 8   PPP2R5D_proteomics    -0.455111  2.820289e-06       Colon
# 9      SBF1_proteomics     0.452041  3.352031e-06       Colon
# 10   MAMDC2_proteomics     0.530627  3.858198e-06       Colon
# 11    SNU13_proteomics    -0.448374  4.111219e-06       Colon
# 12     RALY_proteomics    -0.444764  5.014786e-06       Colon
# 13    DDX27_proteomics    -0.443171  5.470378e-06       Colon
# ...

# %%
pancan = pancan.append(df_colon)
pancan
# Out:
#             Comparison  Correlation       P_value Cancer Type
# 0      EGFR_proteomics     1.000000  0.000000e+00         GBM
# 1    PHLDA1_proteomics     0.816848  6.553435e-25         GBM
# 2      GRB2_proteomics    -0.610889  1.886384e-11         GBM
# 3     SOCS2_proteomics     0.562720  1.343464e-09         GBM
# 4      CDH4_proteomics     0.559180  1.790048e-09         GBM
# ..                 ...          ...           ...         ...
# 11    SNU13_proteomics    -0.448374  4.111219e-06       Colon
# 12     RALY_proteomics    -0.444764  5.014786e-06       Colon
# 13    DDX27_proteomics    -0.443171  5.470378e-06       Colon
# 14  NDUFAB1_proteomics    -0.442201  5.766711e-06       Colon
# 15   POFUT1_proteomics    -0.441381  6.028671e-06       Colon
#
# [814 rows x 4 columns]

# %% [markdown]
# # LSCC

# %%
df_lscc = pd.read_csv("Lscc_EGFR_all_pearson_sig_type.csv")
df_lscc = df_lscc.drop(['Unnamed: 0'], axis=1)

df_lscc
# Out:
#              Comparison  Correlation       P_value Cancer Type
# 0       EGFR_proteomics     1.000000  0.000000e+00        Lscc
# 1     PHLDA1_proteomics     0.709812  3.919195e-18        Lscc
# 2     PHLDA3_proteomics     0.685644  1.412309e-16        Lscc
# 3     LANCL2_proteomics     0.572261  6.528910e-11        Lscc
# 4      ITGB4_proteomics     0.567380  1.026981e-10        Lscc
# ..                  ...          ...           ...         ...
# 62     TTYH3_proteomics     0.440551  2.562184e-06        Lscc
# 63      NPTN_proteomics     0.427819  3.133199e-06        Lscc
# 64   PLEKHA1_proteomics     0.426354  3.413811e-06        Lscc
# 65  FAM160A1_proteomics     0.423148  4.113199e-06        Lscc
# 66     JADE3_proteomics    -0.422132  4.361691e-06        Lscc
#
# [67 rows x 4 columns]

# %%
pancan = pancan.append(df_lscc)
pancan
# Out:
#              Comparison  Correlation       P_value Cancer Type
# 0       EGFR_proteomics     1.000000  0.000000e+00         GBM
# 1     PHLDA1_proteomics     0.816848  6.553435e-25         GBM
# 2       GRB2_proteomics    -0.610889  1.886384e-11         GBM
# 3      SOCS2_proteomics     0.562720  1.343464e-09         GBM
# 4       CDH4_proteomics     0.559180  1.790048e-09         GBM
# ..                  ...          ...           ...         ...
# 62     TTYH3_proteomics     0.440551  2.562184e-06        Lscc
# 63      NPTN_proteomics     0.427819  3.133199e-06        Lscc
# 64   PLEKHA1_proteomics     0.426354  3.413811e-06        Lscc
# 65  FAM160A1_proteomics     0.423148  4.113199e-06        Lscc
# 66     JADE3_proteomics    -0.422132  4.361691e-06        Lscc
#
# [881 rows x 4 columns]

# %%
pancan.to_csv("pancan_EGFR_pearson_sig_all_prot.csv")
