# %% [markdown]
# # Reactome Pathways Brca

# %% [markdown]
# This notebook uses reactome to visualize the different pathways that have many EGFR trans effects.
# Specifically it looks at Hemostasis and Metabolism

# %%
import pandas as pd
import numpy as np
import cptac
import cptac.utils as ut
import operator
from IPython.display import Image


import re 
import matplotlib.pyplot as plt
from scipy import stats
import gseapy as gp
from gseapy.plot import barplot, dotplot

import plot_utils as p
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Load Brca trans effects df 
df_pancan= pd.read_csv("../Step3.2_combining_pearson_dfs/csv_files/pancan_EGFR_all_FDR_wide.csv")
df_pancan= df_pancan.drop(['Unnamed: 0'], axis=1)

df_pancan = df_pancan[1:]

df_pancan
# Out:
#                   Comparison  Correlation_Gbm   P_value_Gbm  \
# 1          PHLDA1_proteomics         0.816848  6.553435e-25
# 2            GRB2_proteomics        -0.610889  1.886384e-11
# 3           SOCS2_proteomics         0.562720  1.343464e-09
# 4            CDH4_proteomics         0.559180  1.790048e-09
# 5         PLA2G15_proteomics        -0.556624  2.197562e-09
# ...                      ...              ...           ...
# 6002        SLIT3_proteomics              NaN           NaN
# 6003         AAK1_proteomics              NaN           NaN
# 6004  COMMD3-BMI1_proteomics              NaN           NaN
# 6005        LIMA1_proteomics              NaN           NaN
# 6006        RFXAP_proteomics              NaN           NaN
#
#       Correlation_kidney  P_value_kidney  Correlation_Ovar  P_value_Ovar  \
# 1                    NaN             NaN               NaN           NaN
# 2                    NaN             NaN               NaN           NaN
# ...

# %%
#take out proteomics and set index
df_pancan = df_pancan.replace(to_replace ='_proteomics', value = '', regex = True)
df_pancan = df_pancan.set_index("Comparison")
#df_pancan = df_pancan.rename(columns={"Correlation": "Brca_Correlation"})
df_pancan = df_pancan["Correlation_hnscc"]
df_pancan
# Out:
# Comparison
# PHLDA1         0.664271
# GRB2          -0.532341
# SOCS2               NaN
# CDH4                NaN
# PLA2G15             NaN
#                  ...
# SLIT3               NaN
# AAK1                NaN
# COMMD3-BMI1         NaN
# LIMA1               NaN
# RFXAP               NaN
# Name: Correlation_hnscc, Length: 6006, dtype: float64

# %%
#immune system
ut.reactome_pathway_overlay(
    df_pancan, 
    "R-HSA-168256", 
    open_browser=True)
# Out:
# 'https://reactome.org/PathwayBrowser/#/R-HSA-168256&DTAB=AN&ANALYSIS=MjAyMDA2MDgyMjMwMzZfMjE5Mzg%3D'

# %%
#Hemostasis pathway
ut.pathway_overlay(
    df_Brca, 
    "R-HSA-109582.2", 
    open_browser=True)
# Out:
# 'https://reactome.org/PathwayBrowser/#/R-HSA-109582.2&DTAB=AN&ANALYSIS=MjAyMDA1MjMwMTEyMTdfMTE5ODE%3D'

# %%
image_path = ut.pathway_overlay(
    df=df_heme_brca,
    pathway="R-HSA-109582.2",
    open_browser=False,
    export_path="test.png")

Image(image_path)
