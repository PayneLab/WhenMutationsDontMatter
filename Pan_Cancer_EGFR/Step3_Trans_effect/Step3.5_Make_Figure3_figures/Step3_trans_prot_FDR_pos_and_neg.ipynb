# %% [markdown]
# # Figure 3 Circle Heatmap all trans Proteins

# %% [markdown]
# This notebook take lists of genes from the enrichment analysis and graphs the correlation in circle heat maps.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math as math
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest

import cptac
import cptac.utils as u

# %%
import pandas as pd
import numpy as np
from bokeh.palettes import RdBu
from bokeh.models import LinearColorMapper, ColumnDataSource, ColorBar
from bokeh.models.ranges import FactorRange
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.io import export_png
from bokeh.io import export_svgs


'''
@Param df: Dataframe. Contains column with x-axis categorical variables, y-axis categorical variables,
and columns for circle size and color gradient. 
@Param circle_var. String. Name of column for numeric data to base circle size off of 
@Param color_var. String. Name of column of numeric data to base color gradient off of. Can be the same or different as circle_var
@Param x_axis String. Name of column for x-axis categorical labels
@Param y_axis String. Name of column for y-axis categorical labels
@Param x_axis_lab. String. Default is no label. 
@Param y_axis_lab. String. Default is no label. 

This function creates a bokeh map that is heat map with extra variable of size of the circles. 

'''
def plotCircleHeatMap ( df, circle_var, color_var, x_axis, y_axis,x_axis_lab = "no_label", y_axis_lab = "no_label"):
  


    #added a new column to make the plot size
    df["size"] = (np.log10(df[circle_var]))
    df["size"] = np.abs(df["size"])
    df['size'] = np.where(df["size"]<0, np.abs(df["size"]), (df["size"]))*5
    
    colors = list((RdBu[9]))
    exp_cmap = LinearColorMapper(palette=colors, low = -.6, high =.6)
    p = figure(x_range = FactorRange(), y_range = FactorRange(), plot_width=1000, 
               plot_height=650, 
               toolbar_location=None, tools="hover")

    p.scatter(x_axis,y_axis,source=df, fill_alpha=1,  line_width=0, size="size", 
              fill_color={"field":color_var, "transform":exp_cmap})

    p.x_range.factors = sorted(df[x_axis].unique().tolist())
    p.y_range.factors = sorted(df[y_axis].unique().tolist(), reverse = True)
    p.xaxis.major_label_orientation = math.pi/2
    
    if (x_axis_lab != "no_label" ):
        p.xaxis.axis_label = x_axis_lab
    if (x_axis_lab != "no_label" ):   
        p.yaxis.axis_label = y_axis_lab

    bar = ColorBar(color_mapper=exp_cmap, location=(0,0))
    p.add_layout(bar, "right")
    output_notebook()
    #return df
    show(p)

# %% [markdown]
# # Complement Genes

# %% [markdown]
# Insert list from enrichment analysis and add back proteomics to name

# %%
complement_pos_neg = ['FGB','ITGAM','VWF','F10','SERPIND1','SERPINC1','PROS1','SERPINE1','PLAUR','F2','C8A','CLU','KNG1','C2','C3','PROCR','C5','C8G','C6','PROC','A2M','KLKB1','CFB']
complement_genes = ['CFD','CPB2','ITGAM','CFH','C1S','C1R','SERPINC1','PROS1','SERPINE1','ITGB2','F13A1','PLG','C8B','C8A','CLU','KNG1','C2','C3','THBD','C5','C8G','C6','C7','PLAU','VSIG4','A2M','FGB','FGA','CR2','SERPINB2','VWF','F10','FGG','SERPINF2','F11','PLAUR','F2','F3','PROCR','F9','PROC','SERPING1','F13B','KLKB1','CFB']
complement_column_names = []
for gene in complement_pos_neg:
    gene += "_proteomics"
    complement_column_names.append(gene)
len(complement_column_names)
# Out:
# 23

# %% [markdown]
# Load appended version of data frame with correlations with FDR correction. Subset down dataframe to only have complement genes

# %%
df_FDR_append = pd.read_csv("../Step3.2_combining_pearson_dfs/csv_files/pancan_EGFR_pearson_sig_all_prot_append_FDR.csv")
df_FDR_append = df_FDR_append.drop(['Unnamed: 0'], axis=1)

df_FDR_complement = df_FDR_append[df_FDR_append.Comparison.isin(complement_column_names)]
df_FDR_complement
# Out:
#                 Comparison  Correlation       P_value Cancer Type
# 77        PROCR_proteomics    -0.470784  8.763500e-07         GBM
# 196       PLAUR_proteomics    -0.425639  1.122876e-05         GBM
# 305         FGB_proteomics    -0.404936  3.218521e-05         GBM
# 482          C2_proteomics    -0.373811  1.382574e-04         GBM
# 532         F10_proteomics    -0.367388  1.834809e-04         GBM
# ...                    ...          ...           ...         ...
# 77361       FGB_proteomics    -0.039068  6.853102e-01        Lscc
# 77584  SERPIND1_proteomics    -0.035328  7.140663e-01        Lscc
# 77647       CLU_proteomics    -0.034342  7.217108e-01        Lscc
# 77872  SERPINC1_proteomics    -0.030863  7.489112e-01        Lscc
# 79271       A2M_proteomics     0.008291  9.314930e-01        Lscc
#
# [184 rows x 4 columns]

# %% [markdown]
# Make figure size of circles base on p_values and color based on correlation. Non sigificant correlations included.

# %%
plotCircleHeatMap(df_FDR_complement, "P_value","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="17163">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8faa074c-9f19-472d-9ef6-7d97cdd909a2" data-root-id="17138"></div>

# %% [markdown]
# Make same graph, but filter out non significant values

# %%
df_FDR_append_sig_only = df_FDR_complement[df_FDR_complement["P_value"] < 0.005]

# %%
plotCircleHeatMap(df_FDR_append_sig_only,"P_value","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="17732">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="32b889f3-51ed-43ac-a951-8811308146d0" data-root-id="17707"></div>

# %% [markdown]
# Load in wide data frame and subset with genes in figure in order to see raw numbers associated with figure

# %%
df_FDR_wide = pd.read_csv("../Step3.2_combining_pearson_dfs/csv_files/pancan_EGFR_all_FDR_wide.csv")
df_FDR_wide = df_FDR_wide.drop(['Unnamed: 0'], axis=1)

df_FDR_wide_complement = df_FDR_wide[df_FDR_wide.Comparison.isin(complement_column_names)]
df_FDR_wide_complement
# Out:
#                Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 77       PROCR_proteomics        -0.470784  8.763500e-07            0.284925
# 196      PLAUR_proteomics        -0.425639  1.122876e-05                 NaN
# 305        FGB_proteomics        -0.404936  3.218521e-05                 NaN
# 482         C2_proteomics        -0.373811  1.382574e-04                 NaN
# 532        F10_proteomics        -0.367388  1.834809e-04                 NaN
# 631        C8A_proteomics        -0.354680  3.157269e-04                 NaN
# 810        A2M_proteomics        -0.333010  7.571685e-04                 NaN
# 833      PROS1_proteomics        -0.331142  8.141044e-04                 NaN
# 838      ITGAM_proteomics        -0.330556  8.327428e-04                 NaN
# 903         C6_proteomics        -0.324377  1.054494e-03                 NaN
# 922         C3_proteomics        -0.322886  1.115525e-03                 NaN
# 1033       CFB_proteomics        -0.312097  1.661827e-03                 NaN
# 1057  SERPINC1_proteomics        -0.310060  1.788772e-03                 NaN
# 1078        F2_proteomics        -0.308253  1.908694e-03                 NaN
# 1097  SERPINE1_proteomics        -0.306814  2.009326e-03                 NaN
# 1119       C8G_proteomics        -0.305199  2.127970e-03                 NaN
# 1134      KNG1_proteomics        -0.303476  2.261491e-03                 NaN
# 1166     KLKB1_proteomics        -0.300436  2.515530e-03                 NaN
# 1376  SERPIND1_proteomics        -0.281792  4.717876e-03                 NaN
# 2496        C5_proteomics              NaN           NaN                 NaN
# 2539       CLU_proteomics              NaN           NaN                 NaN
# 2548      PROC_proteomics              NaN           NaN                 NaN
# 4761       VWF_proteomics              NaN           NaN                 NaN
#
#       P_value_kidney  Correlation_Ovar  P_value_Ovar  Correlation_Brca  \
# 77          0.002553               NaN           NaN          0.336022
# 196              NaN               NaN           NaN          0.467428
# 305              NaN               NaN           NaN          0.303047
# 482              NaN          0.368573      0.000607          0.267613
# 532              NaN               NaN           NaN          0.306660
# 631              NaN          0.430970      0.000048          0.244053
# 810              NaN               NaN           NaN          0.272221
# 833              NaN               NaN           NaN          0.384178
# 838              NaN               NaN           NaN          0.388339
# 903              NaN          0.405493      0.000143          0.287137
# 922              NaN          0.439657      0.000032          0.309240
# 1033             NaN          0.411782      0.000110               NaN
# 1057             NaN               NaN           NaN               NaN
# 1078             NaN               NaN           NaN          0.368861
# 1097             NaN               NaN           NaN          0.484666
# 1119             NaN          0.394244      0.000226          0.255793
# 1134             NaN               NaN           NaN               NaN
# 1166             NaN               NaN           NaN          0.300161
# 1376             NaN          0.366931      0.000645          0.271473
# 2496             NaN          0.406272      0.000138          0.330283
# 2539             NaN          0.376210      0.000456               NaN
# 2548             NaN          0.372340      0.000528               NaN
# 4761             NaN               NaN           NaN               NaN
#
#       P_value_Brca  Correlation_Luad  P_value_Luad  Correlation_hnscc  \
# 77    2.412023e-04               NaN           NaN                NaN
# 196   1.389846e-07               NaN           NaN           0.278504
# 305   9.944820e-04               NaN           NaN                NaN
# 482   5.781507e-03               NaN           NaN                NaN
# 532   8.581297e-04               NaN           NaN                NaN
# 631   8.577330e-03               NaN           NaN                NaN
# 810   3.248877e-03               NaN           NaN                NaN
# 833   2.248290e-05         -0.281229      0.002919                NaN
# 838   1.798502e-05               NaN           NaN                NaN
# 903   1.862266e-03               NaN           NaN                NaN
# 922   7.714888e-04         -0.281247      0.002917                NaN
# 1033           NaN               NaN           NaN                NaN
# 1057           NaN               NaN           NaN                NaN
# 1078  4.984037e-05               NaN           NaN                NaN
# 1097  3.706793e-07               NaN           NaN           0.440590
# 1119  5.794838e-03         -0.276216      0.003490                NaN
# 1134           NaN               NaN           NaN                NaN
# 1166  1.117267e-03               NaN           NaN                NaN
# 1376  3.338243e-03         -0.306864      0.001111                NaN
# 2496  3.122619e-04         -0.303305      0.002528                NaN
# 2539           NaN         -0.325038      0.000531                NaN
# 2548           NaN         -0.304222      0.001233                NaN
# 4761           NaN         -0.329460      0.000440          -0.300045
#
#       P_value_hnscc  Correlation_colon  P_value_colon  Correlation_Lscc  \
# 77              NaN                NaN            NaN               NaN
# 196        0.003364                NaN            NaN               NaN
# 305             NaN                NaN            NaN               NaN
# 482             NaN                NaN            NaN               NaN
# 532             NaN                NaN            NaN               NaN
# 631             NaN                NaN            NaN               NaN
# 810             NaN           0.311803       0.001877               NaN
# 833             NaN                NaN            NaN               NaN
# 838             NaN                NaN            NaN               NaN
# 903             NaN                NaN            NaN               NaN
# 922             NaN                NaN            NaN               NaN
# 1033            NaN                NaN            NaN               NaN
# 1057            NaN           0.400614       0.000048               NaN
# 1078            NaN                NaN            NaN               NaN
# 1097       0.000002                NaN            NaN               NaN
# 1119            NaN                NaN            NaN               NaN
# 1134            NaN           0.302283       0.002619               NaN
# 1166            NaN           0.359907       0.000294               NaN
# 1376            NaN           0.351169       0.000421               NaN
# 2496            NaN                NaN            NaN               NaN
# 2539            NaN                NaN            NaN               NaN
# 2548            NaN                NaN            NaN               NaN
# 4761       0.001525           0.341362       0.000622               NaN
#
#       P_value_Lscc
# 77             NaN
# 196            NaN
# 305            NaN
# 482            NaN
# 532            NaN
# 631            NaN
# 810            NaN
# 833            NaN
# 838            NaN
# 903            NaN
# 922            NaN
# 1033           NaN
# 1057           NaN
# 1078           NaN
# 1097           NaN
# 1119           NaN
# 1134           NaN
# 1166           NaN
# 1376           NaN
# 2496           NaN
# 2539           NaN
# 2548           NaN
# 4761           NaN

# %% [markdown]
# # Endocytosis genes

# %%
endocytosis = ['SH3GLB1','ARFGEF1','PRKCI','SMAD3','WIPF2','CAV1','VPS4B','PARD6G','ARPC4','ARPC5','IGF1R','EPN3','ACAP2','DAB2','PARD6B','ZFYVE16','ERBB3','ARPC3','NEDD4','CAPZA1','KIT','CHMP4C','MET']
endocytosis_column_names = []
for gene in endocytosis:
    gene += "_proteomics"
    endocytosis_column_names.append(gene)
len(endocytosis_column_names)
# Out:
# 23

# %%
df_FDR_endocytosis = df_FDR_append[df_FDR_append.Comparison.isin(endocytosis_column_names)]
df_FDR_endocytosis
# Out:
#               Comparison  Correlation       P_value Cancer Type
# 6        DAB2_proteomics    -0.556402  2.237010e-09         GBM
# 164     NEDD4_proteomics    -0.434925  6.843176e-06         GBM
# 206     ARPC3_proteomics    -0.423330  1.267190e-05         GBM
# 291      CAV1_proteomics    -0.407997  2.766397e-05         GBM
# 399    CAPZA1_proteomics    -0.387765  7.323051e-05         GBM
# ...                  ...          ...           ...         ...
# 75498   ARPC4_proteomics     0.071803  4.560076e-01        Lscc
# 75838    DAB2_proteomics    -0.066031  4.931051e-01        Lscc
# 76307   ERBB3_proteomics    -0.057605  5.500006e-01        Lscc
# 77330   ARPC3_proteomics     0.039662  6.807908e-01        Lscc
# 79736   ARPC5_proteomics    -0.000894  9.926056e-01        Lscc
#
# [177 rows x 4 columns]

# %%
plotCircleHeatMap(df_FDR_endocytosis,"P_value","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="18311">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6ea7ce0e-a335-40d6-91c0-a13596db5b1d" data-root-id="18286"></div>

# %%
df_FDR_wide_endocytosis = df_FDR_wide[df_FDR_wide.Comparison.isin(endocytosis_column_names)]
df_FDR_wide_endocytosis
# Out:
#               Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 6        DAB2_proteomics        -0.556402  2.237010e-09                 NaN
# 164     NEDD4_proteomics        -0.434925  6.843176e-06            0.321219
# 206     ARPC3_proteomics        -0.423330  1.267190e-05                 NaN
# 291      CAV1_proteomics        -0.407997  2.766397e-05            0.344889
# 399    CAPZA1_proteomics        -0.387765  7.323051e-05                 NaN
# 449   ZFYVE16_proteomics        -0.379396  1.075736e-04                 NaN
# 472   SH3GLB1_proteomics        -0.375266  1.295641e-04                 NaN
# 601     ARPC4_proteomics        -0.357529  2.800944e-04           -0.264291
# 662     ARPC5_proteomics        -0.349300  3.946124e-04                 NaN
# 697       MET_proteomics        -0.344604  4.779015e-04                 NaN
# 984      EPN3_proteomics         0.320454  1.457335e-03                 NaN
# 1405    VPS4B_proteomics        -0.279137  5.142913e-03                 NaN
# 1895    WIPF2_proteomics              NaN           NaN            0.342057
# 2075    ERBB3_proteomics              NaN           NaN            0.309626
# 2104   CHMP4C_proteomics              NaN           NaN            0.305454
# 2197   PARD6B_proteomics              NaN           NaN            0.292206
# 2995  ARFGEF1_proteomics              NaN           NaN                 NaN
# 3242      KIT_proteomics              NaN           NaN                 NaN
# 3261   PARD6G_proteomics              NaN           NaN                 NaN
# 3307    SMAD3_proteomics              NaN           NaN                 NaN
# 3377    IGF1R_proteomics              NaN           NaN                 NaN
# 3463    PRKCI_proteomics              NaN           NaN                 NaN
# 4678    ACAP2_proteomics              NaN           NaN                 NaN
#
#       P_value_kidney  Correlation_Ovar  P_value_Ovar  Correlation_Brca  \
# 6                NaN               NaN           NaN          0.326055
# 164         0.000622               NaN           NaN               NaN
# 206              NaN               NaN           NaN          0.311784
# 291         0.000224               NaN           NaN               NaN
# 399              NaN               NaN           NaN          0.311677
# 449              NaN               NaN           NaN               NaN
# 472              NaN               NaN           NaN          0.316491
# 601         0.005270               NaN           NaN          0.354157
# 662              NaN               NaN           NaN          0.353939
# 697              NaN               NaN           NaN          0.451064
# 984              NaN               NaN           NaN         -0.373965
# 1405             NaN               NaN           NaN               NaN
# 1895        0.000255               NaN           NaN         -0.366653
# 2075        0.000996               NaN           NaN         -0.389507
# 2104        0.001175         -0.374791      0.000481               NaN
# 2197        0.001951               NaN           NaN         -0.567350
# 2995             NaN               NaN           NaN         -0.366465
# 3242             NaN               NaN           NaN          0.331345
# 3261             NaN               NaN           NaN         -0.329156
# 3307             NaN               NaN           NaN         -0.324801
# 3377             NaN               NaN           NaN         -0.317128
# 3463             NaN               NaN           NaN         -0.307493
# 4678             NaN               NaN           NaN               NaN
#
#       P_value_Brca  Correlation_Luad  P_value_Luad  Correlation_hnscc  \
# 6     3.764707e-04               NaN           NaN                NaN
# 164            NaN               NaN           NaN                NaN
# 206   6.939810e-04         -0.301699  1.359677e-03                NaN
# 291            NaN               NaN           NaN                NaN
# 399   6.970752e-04               NaN           NaN                NaN
# 449            NaN               NaN           NaN                NaN
# 472   5.690949e-04               NaN           NaN                NaN
# 601   1.031524e-04         -0.294842  1.767048e-03                NaN
# 662   1.042416e-04         -0.270303  4.290947e-03                NaN
# 697   7.889147e-05          0.485692  7.518188e-08                NaN
# 984   3.839688e-05               NaN           NaN                NaN
# 1405           NaN         -0.348294  1.924969e-04                NaN
# 1895  5.571818e-05          0.316661  7.506056e-04                NaN
# 2075  1.688367e-05               NaN           NaN                NaN
# 2104           NaN               NaN           NaN                NaN
# 2197  3.815436e-11          0.332874  3.805421e-04                NaN
# 2995  5.624888e-05          0.362215  1.008895e-04                NaN
# 3242  2.978114e-04         -0.326711  4.948361e-04                NaN
# 3261  3.283119e-04               NaN           NaN           0.327749
# 3307  3.977456e-04               NaN           NaN                NaN
# 3377  5.538717e-04               NaN           NaN           0.330395
# 3463  8.292301e-04          0.303722  1.256956e-03                NaN
# 4678           NaN         -0.352302  1.603106e-04                NaN
#
#       P_value_hnscc  Correlation_colon  P_value_colon  Correlation_Lscc  \
# 6               NaN                NaN            NaN               NaN
# 164             NaN                NaN            NaN               NaN
# 206             NaN                NaN            NaN               NaN
# 291             NaN                NaN            NaN               NaN
# 399             NaN                NaN            NaN               NaN
# 449             NaN           0.390961       0.000075               NaN
# 472             NaN                NaN            NaN               NaN
# 601             NaN                NaN            NaN               NaN
# 662             NaN                NaN            NaN               NaN
# 697             NaN                NaN            NaN               NaN
# 984             NaN                NaN            NaN               NaN
# 1405            NaN           0.367059       0.000217               NaN
# 1895            NaN                NaN            NaN               NaN
# 2075            NaN                NaN            NaN               NaN
# 2104            NaN                NaN            NaN          0.309115
# 2197            NaN                NaN            NaN               NaN
# 2995            NaN                NaN            NaN               NaN
# 3242            NaN                NaN            NaN               NaN
# 3261       0.000503                NaN            NaN          0.344047
# 3307            NaN                NaN            NaN          0.323183
# 3377       0.000450                NaN            NaN               NaN
# 3463            NaN                NaN            NaN               NaN
# 4678            NaN           0.304544       0.002422               NaN
#
#       P_value_Lscc
# 6              NaN
# 164            NaN
# 206            NaN
# 291            NaN
# 399            NaN
# 449            NaN
# 472            NaN
# 601            NaN
# 662            NaN
# 697            NaN
# 984            NaN
# 1405           NaN
# 1895           NaN
# 2075           NaN
# 2104      0.001017
# 2197           NaN
# 2995           NaN
# 3242           NaN
# 3261      0.000233
# 3307      0.000574
# 3377           NaN
# 3463           NaN
# 4678           NaN

# %% [markdown]
# # Aktin Genes

# %%
aktin_genes = ['ITGB1','GSN','ITGAM','ITGB5','ITGA3','ITGB3','LIMK2','ARPC4','ARPC5','F2','BAIAP2','ARHGAP35','NRAS','DIAPH2','ARPC3','ARHGEF1','PFN1','VCL']

# %%
aktin_column_names = []
for gene in aktin_genes:
    gene += "_proteomics"
    aktin_column_names.append(gene)
len(aktin_column_names)
# Out:
# 18

# %%
df_FDR_aktin = df_FDR_append[df_FDR_append.Comparison.isin(aktin_column_names)]
df_FDR_aktin
# Out:
#              Comparison  Correlation   P_value Cancer Type
# 206    ARPC3_proteomics    -0.423330  0.000013         GBM
# 271    ITGB1_proteomics    -0.412364  0.000022         GBM
# 315     PFN1_proteomics    -0.402695  0.000036         GBM
# 526      VCL_proteomics    -0.368318  0.000176         GBM
# 601    ARPC4_proteomics    -0.357529  0.000280         GBM
# ...                 ...          ...       ...         ...
# 75970    GSN_proteomics     0.077248  0.510065        Lscc
# 76446   NRAS_proteomics    -0.054907  0.568870        Lscc
# 77330  ARPC3_proteomics     0.039662  0.680791        Lscc
# 79285    VCL_proteomics     0.008139  0.932744        Lscc
# 79736  ARPC5_proteomics    -0.000894  0.992606        Lscc
#
# [143 rows x 4 columns]

# %%
plotCircleHeatMap(df_FDR_aktin,"P_value","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="18900">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="3ef56d42-5104-4abb-92c1-5d6d1e8a4875" data-root-id="18875"></div>
