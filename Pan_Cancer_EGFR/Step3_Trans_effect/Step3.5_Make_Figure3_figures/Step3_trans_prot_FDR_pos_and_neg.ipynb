# %% [markdown]
# # Figure 3 Circle Heatmap all trans Proteins

# %% [markdown]
# This notebook take lists of genes from the enrichment analysis and graphs the correlation in circle heat maps.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math as math
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest

import cptac
import cptac.utils as u
import plot_utils as p
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Complement Genes

# %% [markdown]
# Insert list from enrichment analysis and add back proteomics to name

# %%
complement_pos_neg = ['FGB','ITGAM','VWF','F10','SERPIND1','SERPINC1','PROS1','SERPINE1','PLAUR','F2','C8A','CLU','KNG1','C2','C3','PROCR','C5','C8G','C6','PROC','A2M','KLKB1','CFB']
complement_genes = ['CFD','CPB2','ITGAM','CFH','C1S','C1R','SERPINC1','PROS1','SERPINE1','ITGB2','F13A1','PLG','C8B','C8A','CLU','KNG1','C2','C3','THBD','C5','C8G','C6','C7','PLAU','VSIG4','A2M','FGB','FGA','CR2','SERPINB2','VWF','F10','FGG','SERPINF2','F11','PLAUR','F2','F3','PROCR','F9','PROC','SERPING1','F13B','KLKB1','CFB']
complement_column_names = []
for gene in complement_genes:
    gene += "_proteomics"
    complement_column_names.append(gene)
len(complement_column_names)
# Out:
# 45

# %% [markdown]
# Load appended version of data frame with correlations with FDR correction. Subset down dataframe to only have complement genes

# %%
df_FDR_append = pd.read_csv("../Step3.2_combining_pearson_dfs/csv_files/pancan_EGFR_pearson_sig_all_prot_append_FDR.csv")
df_FDR_append = df_FDR_append.drop(['Unnamed: 0'], axis=1)

df_FDR_complement = df_FDR_append[df_FDR_append.Comparison.isin(complement_column_names)]
df_FDR_complement
# Out:
#                Comparison  Correlation       P_value Cancer Type
# 77       PROCR_proteomics    -0.470784  8.763500e-07         GBM
# 196      PLAUR_proteomics    -0.425639  1.122876e-05         GBM
# 244   SERPINB2_proteomics    -0.482756  1.749352e-05         GBM
# 305        FGB_proteomics    -0.404936  3.218521e-05         GBM
# 350        FGG_proteomics    -0.396275  4.899957e-05         GBM
# ...                   ...          ...           ...         ...
# 8091        C7_proteomics     0.324477  1.184867e-03       Colon
# 8166       A2M_proteomics     0.311803  1.877305e-03       Colon
# 8233      KNG1_proteomics     0.302283  2.618696e-03       Colon
# 8479      PLAU_proteomics     0.385665  3.170871e-05        Lscc
# 8714       CR2_proteomics    -0.322460  1.068204e-03        Lscc
#
# [113 rows x 4 columns]

# %% [markdown]
# Make figure size of circles base on p_values and color based on correlation. Non sigificant correlations included.

# %%
p.plotCircleHeatMap(df_FDR_complement, "P_value","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/plot_utils/__init__.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["size2"] = df[circle_var].apply(lambda x: -1*(np.log(x)))
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/plot_utils/__init__.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['size'] = (df["size2"])*3
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1029">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="72df3cc7-f7ef-4513-9cc3-fd6172d785c9" data-root-id="1004"></div>

# %% [markdown]
# Make same graph, but filter out non significant values

# %%
df_FDR_append_sig_only = df_FDR_complement[df_FDR_complement["P_value"] < 0.005]

# %%
p.plotCircleHeatMap(df_FDR_append_sig_only,"P_value","Correlation","Comparison","Cancer Type")
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1237">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9b4ef96c-2528-42bd-9362-49ba6e9085b5" data-root-id="1212"></div>

# %% [markdown]
# Load in wide data frame and subset with genes in figure in order to see raw numbers associated with figure

# %%
df_FDR_wide = pd.read_csv("../Step3.2_combining_pearson_dfs/csv_files/pancan_EGFR_all_FDR_wide.csv")
df_FDR_wide = df_FDR_wide.drop(['Unnamed: 0'], axis=1)

df = df_FDR_wide.rename(columns={"Comparison": "Genes"})

df_FDR_wide_complement = df_FDR_wide[df_FDR_wide.Comparison.isin(complement_column_names)]

df = df.set_index('Genes')
df
# Out:
#                         Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# Genes
# EGFR_proteomics                1.000000  0.000000e+00                 1.0
# PHLDA1_proteomics              0.816848  6.553435e-25                 NaN
# GRB2_proteomics               -0.610889  1.886384e-11                 NaN
# SOCS2_proteomics               0.562720  1.343464e-09                 NaN
# CDH4_proteomics                0.559180  1.790048e-09                 NaN
# ...                                 ...           ...                 ...
# SLIT3_proteomics                    NaN           NaN                 NaN
# AAK1_proteomics                     NaN           NaN                 NaN
# COMMD3-BMI1_proteomics              NaN           NaN                 NaN
# LIMA1_proteomics                    NaN           NaN                 NaN
# RFXAP_proteomics                    NaN           NaN                 NaN
#
#                         P_value_kidney  Correlation_Ovar  P_value_Ovar  \
# Genes
# EGFR_proteomics                    0.0               1.0           0.0
# PHLDA1_proteomics                  NaN               NaN           NaN
# GRB2_proteomics                    NaN               NaN           NaN
# SOCS2_proteomics                   NaN               NaN           NaN
# CDH4_proteomics                    NaN               NaN           NaN
# ...                                ...               ...           ...
# SLIT3_proteomics                   NaN               NaN           NaN
# AAK1_proteomics                    NaN               NaN           NaN
# COMMD3-BMI1_proteomics             NaN               NaN           NaN
# LIMA1_proteomics                   NaN               NaN           NaN
# RFXAP_proteomics                   NaN               NaN           NaN
#
#                         Correlation_Brca  P_value_Brca  Correlation_Luad  \
# Genes
# EGFR_proteomics                 1.000000       0.00000          1.000000
# PHLDA1_proteomics               0.364797       0.00019               NaN
# GRB2_proteomics                      NaN           NaN         -0.302439
# SOCS2_proteomics                     NaN           NaN               NaN
# CDH4_proteomics                      NaN           NaN               NaN
# ...                                  ...           ...               ...
# SLIT3_proteomics                     NaN           NaN               NaN
# AAK1_proteomics                      NaN           NaN               NaN
# COMMD3-BMI1_proteomics               NaN           NaN               NaN
# LIMA1_proteomics                     NaN           NaN               NaN
# RFXAP_proteomics                     NaN           NaN               NaN
#
#                         P_value_Luad  Correlation_hnscc  P_value_hnscc  \
# Genes
# EGFR_proteomics             0.000000           1.000000   0.000000e+00
# PHLDA1_proteomics                NaN           0.664271   3.426615e-15
# GRB2_proteomics             0.001321          -0.532341   2.559824e-09
# SOCS2_proteomics                 NaN                NaN            NaN
# CDH4_proteomics                  NaN                NaN            NaN
# ...                              ...                ...            ...
# SLIT3_proteomics                 NaN                NaN            NaN
# AAK1_proteomics                  NaN                NaN            NaN
# COMMD3-BMI1_proteomics           NaN                NaN            NaN
# LIMA1_proteomics                 NaN                NaN            NaN
# RFXAP_proteomics                 NaN                NaN            NaN
#
#                         Correlation_colon  P_value_colon  Correlation_Lscc  \
# Genes
# EGFR_proteomics                       1.0            0.0          1.000000
# PHLDA1_proteomics                     NaN            NaN          0.709812
# GRB2_proteomics                       NaN            NaN               NaN
# SOCS2_proteomics                      NaN            NaN          0.478574
# CDH4_proteomics                       NaN            NaN               NaN
# ...                                   ...            ...               ...
# SLIT3_proteomics                      NaN            NaN         -0.291391
# AAK1_proteomics                       NaN            NaN          0.290954
# COMMD3-BMI1_proteomics                NaN            NaN         -0.290800
# LIMA1_proteomics                      NaN            NaN          0.290115
# RFXAP_proteomics                      NaN            NaN         -0.289937
#
#                         P_value_Lscc
# Genes
# EGFR_proteomics         0.000000e+00
# PHLDA1_proteomics       3.919195e-18
# GRB2_proteomics                  NaN
# SOCS2_proteomics        2.191662e-04
# CDH4_proteomics                  NaN
# ...                              ...
# SLIT3_proteomics        2.011415e-03
# AAK1_proteomics         2.044509e-03
# COMMD3-BMI1_proteomics  2.056267e-03
# LIMA1_proteomics        2.109252e-03
# RFXAP_proteomics        2.123227e-03
#
# [6007 rows x 16 columns]

# %% [markdown]
# # Endocytosis genes

# %%
endocytosis = ['SH3GLB1','ARFGEF1','PRKCI','SMAD3','WIPF2','CAV1','VPS4B','PARD6G','ARPC4','ARPC5','IGF1R','EPN3','ACAP2','DAB2','PARD6B','ZFYVE16','ERBB3','ARPC3','NEDD4','CAPZA1','KIT','CHMP4C','MET']
endocytosis_column_names = []
for gene in endocytosis:
    gene += "_proteomics"
    endocytosis_column_names.append(gene)
len(endocytosis_column_names)
# Out:
# 23

# %%
df_FDR_endocytosis = df_FDR_append[df_FDR_append.Comparison.isin(endocytosis_column_names)]
df_FDR_endocytosis
# Out:
#               Comparison  Correlation       P_value Cancer Type
# 6        DAB2_proteomics    -0.556402  2.237010e-09         GBM
# 164     NEDD4_proteomics    -0.434925  6.843176e-06         GBM
# 206     ARPC3_proteomics    -0.423330  1.267190e-05         GBM
# 291      CAV1_proteomics    -0.407997  2.766397e-05         GBM
# 399    CAPZA1_proteomics    -0.387765  7.323051e-05         GBM
# ...                  ...          ...           ...         ...
# 75498   ARPC4_proteomics     0.071803  4.560076e-01        Lscc
# 75838    DAB2_proteomics    -0.066031  4.931051e-01        Lscc
# 76307   ERBB3_proteomics    -0.057605  5.500006e-01        Lscc
# 77330   ARPC3_proteomics     0.039662  6.807908e-01        Lscc
# 79736   ARPC5_proteomics    -0.000894  9.926056e-01        Lscc
#
# [177 rows x 4 columns]

# %%
plotCircleHeatMap(df_FDR_endocytosis,"P_value","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="18311">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6ea7ce0e-a335-40d6-91c0-a13596db5b1d" data-root-id="18286"></div>

# %%
df_FDR_wide_endocytosis = df_FDR_wide[df_FDR_wide.Comparison.isin(endocytosis_column_names)]
df_FDR_wide_endocytosis
# Out:
#               Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 6        DAB2_proteomics        -0.556402  2.237010e-09                 NaN
# 164     NEDD4_proteomics        -0.434925  6.843176e-06            0.321219
# 206     ARPC3_proteomics        -0.423330  1.267190e-05                 NaN
# 291      CAV1_proteomics        -0.407997  2.766397e-05            0.344889
# 399    CAPZA1_proteomics        -0.387765  7.323051e-05                 NaN
# 449   ZFYVE16_proteomics        -0.379396  1.075736e-04                 NaN
# 472   SH3GLB1_proteomics        -0.375266  1.295641e-04                 NaN
# 601     ARPC4_proteomics        -0.357529  2.800944e-04           -0.264291
# 662     ARPC5_proteomics        -0.349300  3.946124e-04                 NaN
# 697       MET_proteomics        -0.344604  4.779015e-04                 NaN
# 984      EPN3_proteomics         0.320454  1.457335e-03                 NaN
# 1405    VPS4B_proteomics        -0.279137  5.142913e-03                 NaN
# 1895    WIPF2_proteomics              NaN           NaN            0.342057
# 2075    ERBB3_proteomics              NaN           NaN            0.309626
# 2104   CHMP4C_proteomics              NaN           NaN            0.305454
# 2197   PARD6B_proteomics              NaN           NaN            0.292206
# 2995  ARFGEF1_proteomics              NaN           NaN                 NaN
# 3242      KIT_proteomics              NaN           NaN                 NaN
# 3261   PARD6G_proteomics              NaN           NaN                 NaN
# 3307    SMAD3_proteomics              NaN           NaN                 NaN
# 3377    IGF1R_proteomics              NaN           NaN                 NaN
# 3463    PRKCI_proteomics              NaN           NaN                 NaN
# 4678    ACAP2_proteomics              NaN           NaN                 NaN
#
#       P_value_kidney  Correlation_Ovar  P_value_Ovar  Correlation_Brca  \
# 6                NaN               NaN           NaN          0.326055
# 164         0.000622               NaN           NaN               NaN
# 206              NaN               NaN           NaN          0.311784
# 291         0.000224               NaN           NaN               NaN
# 399              NaN               NaN           NaN          0.311677
# 449              NaN               NaN           NaN               NaN
# 472              NaN               NaN           NaN          0.316491
# 601         0.005270               NaN           NaN          0.354157
# 662              NaN               NaN           NaN          0.353939
# 697              NaN               NaN           NaN          0.451064
# 984              NaN               NaN           NaN         -0.373965
# 1405             NaN               NaN           NaN               NaN
# 1895        0.000255               NaN           NaN         -0.366653
# 2075        0.000996               NaN           NaN         -0.389507
# 2104        0.001175         -0.374791      0.000481               NaN
# 2197        0.001951               NaN           NaN         -0.567350
# 2995             NaN               NaN           NaN         -0.366465
# 3242             NaN               NaN           NaN          0.331345
# 3261             NaN               NaN           NaN         -0.329156
# 3307             NaN               NaN           NaN         -0.324801
# 3377             NaN               NaN           NaN         -0.317128
# 3463             NaN               NaN           NaN         -0.307493
# 4678             NaN               NaN           NaN               NaN
#
#       P_value_Brca  Correlation_Luad  P_value_Luad  Correlation_hnscc  \
# 6     3.764707e-04               NaN           NaN                NaN
# 164            NaN               NaN           NaN                NaN
# 206   6.939810e-04         -0.301699  1.359677e-03                NaN
# 291            NaN               NaN           NaN                NaN
# 399   6.970752e-04               NaN           NaN                NaN
# 449            NaN               NaN           NaN                NaN
# 472   5.690949e-04               NaN           NaN                NaN
# 601   1.031524e-04         -0.294842  1.767048e-03                NaN
# 662   1.042416e-04         -0.270303  4.290947e-03                NaN
# 697   7.889147e-05          0.485692  7.518188e-08                NaN
# 984   3.839688e-05               NaN           NaN                NaN
# 1405           NaN         -0.348294  1.924969e-04                NaN
# 1895  5.571818e-05          0.316661  7.506056e-04                NaN
# 2075  1.688367e-05               NaN           NaN                NaN
# 2104           NaN               NaN           NaN                NaN
# 2197  3.815436e-11          0.332874  3.805421e-04                NaN
# 2995  5.624888e-05          0.362215  1.008895e-04                NaN
# 3242  2.978114e-04         -0.326711  4.948361e-04                NaN
# 3261  3.283119e-04               NaN           NaN           0.327749
# 3307  3.977456e-04               NaN           NaN                NaN
# 3377  5.538717e-04               NaN           NaN           0.330395
# 3463  8.292301e-04          0.303722  1.256956e-03                NaN
# 4678           NaN         -0.352302  1.603106e-04                NaN
#
#       P_value_hnscc  Correlation_colon  P_value_colon  Correlation_Lscc  \
# 6               NaN                NaN            NaN               NaN
# 164             NaN                NaN            NaN               NaN
# 206             NaN                NaN            NaN               NaN
# 291             NaN                NaN            NaN               NaN
# 399             NaN                NaN            NaN               NaN
# 449             NaN           0.390961       0.000075               NaN
# 472             NaN                NaN            NaN               NaN
# 601             NaN                NaN            NaN               NaN
# 662             NaN                NaN            NaN               NaN
# 697             NaN                NaN            NaN               NaN
# 984             NaN                NaN            NaN               NaN
# 1405            NaN           0.367059       0.000217               NaN
# 1895            NaN                NaN            NaN               NaN
# 2075            NaN                NaN            NaN               NaN
# 2104            NaN                NaN            NaN          0.309115
# 2197            NaN                NaN            NaN               NaN
# 2995            NaN                NaN            NaN               NaN
# 3242            NaN                NaN            NaN               NaN
# 3261       0.000503                NaN            NaN          0.344047
# 3307            NaN                NaN            NaN          0.323183
# 3377       0.000450                NaN            NaN               NaN
# 3463            NaN                NaN            NaN               NaN
# 4678            NaN           0.304544       0.002422               NaN
#
#       P_value_Lscc
# 6              NaN
# 164            NaN
# 206            NaN
# 291            NaN
# 399            NaN
# 449            NaN
# 472            NaN
# 601            NaN
# 662            NaN
# 697            NaN
# 984            NaN
# 1405           NaN
# 1895           NaN
# 2075           NaN
# 2104      0.001017
# 2197           NaN
# 2995           NaN
# 3242           NaN
# 3261      0.000233
# 3307      0.000574
# 3377           NaN
# 3463           NaN
# 4678           NaN

# %% [markdown]
# # Aktin Genes

# %%
aktin_genes = ['ITGB1','GSN','ITGAM','ITGB5','ITGA3','ITGB3','LIMK2','ARPC4','ARPC5','F2','BAIAP2','ARHGAP35','NRAS','DIAPH2','ARPC3','ARHGEF1','PFN1','VCL']

# %%
aktin_column_names = []
for gene in aktin_genes:
    gene += "_proteomics"
    aktin_column_names.append(gene)
len(aktin_column_names)
# Out:
# 18

# %%
df_FDR_aktin = df_FDR_append[df_FDR_append.Comparison.isin(aktin_column_names)]
df_FDR_aktin
# Out:
#              Comparison  Correlation   P_value Cancer Type
# 206    ARPC3_proteomics    -0.423330  0.000013         GBM
# 271    ITGB1_proteomics    -0.412364  0.000022         GBM
# 315     PFN1_proteomics    -0.402695  0.000036         GBM
# 526      VCL_proteomics    -0.368318  0.000176         GBM
# 601    ARPC4_proteomics    -0.357529  0.000280         GBM
# ...                 ...          ...       ...         ...
# 75970    GSN_proteomics     0.077248  0.510065        Lscc
# 76446   NRAS_proteomics    -0.054907  0.568870        Lscc
# 77330  ARPC3_proteomics     0.039662  0.680791        Lscc
# 79285    VCL_proteomics     0.008139  0.932744        Lscc
# 79736  ARPC5_proteomics    -0.000894  0.992606        Lscc
#
# [143 rows x 4 columns]

# %%
plotCircleHeatMap(df_FDR_aktin,"P_value","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="18900">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="3ef56d42-5104-4abb-92c1-5d6d1e8a4875" data-root-id="18875"></div>

# %%
df_FDR_wide_T = df.T 
df_FDR_wide_T

df_FDR_wide_T.filter(like='CDH1', axis=1)
# Out:
# Genes               PCDH17_proteomics  PCDH19_proteomics  CDH10_proteomics  \
# Correlation_Gbm          5.060447e-01           0.437346          0.296208
# P_value_Gbm              9.126316e-08           0.000006          0.002912
# Correlation_kidney                NaN                NaN               NaN
# P_value_kidney                    NaN                NaN               NaN
# Correlation_Ovar                  NaN                NaN               NaN
# P_value_Ovar                      NaN                NaN               NaN
# Correlation_Brca                  NaN                NaN               NaN
# P_value_Brca                      NaN                NaN               NaN
# Correlation_Luad                  NaN                NaN               NaN
# P_value_Luad                      NaN                NaN               NaN
# Correlation_hnscc                 NaN                NaN               NaN
# P_value_hnscc                     NaN                NaN               NaN
# Correlation_colon                 NaN                NaN               NaN
# P_value_colon                     NaN                NaN               NaN
# Correlation_Lscc                  NaN                NaN               NaN
# P_value_Lscc                      NaN                NaN               NaN
#
# Genes               CDH13_proteomics  CDH1_proteomics  CDH17_proteomics
# Correlation_Gbm                  NaN              NaN               NaN
# P_value_Gbm                      NaN              NaN               NaN
# Correlation_kidney               NaN              NaN               NaN
# P_value_kidney                   NaN              NaN               NaN
# Correlation_Ovar                 NaN              NaN               NaN
# P_value_Ovar                     NaN              NaN               NaN
# Correlation_Brca            0.390674              NaN               NaN
# P_value_Brca                0.000016              NaN               NaN
# Correlation_Luad                 NaN         0.299164         -0.475269
# P_value_Luad                     NaN         0.001499          0.003398
# Correlation_hnscc                NaN              NaN               NaN
# P_value_hnscc                    NaN              NaN               NaN
# Correlation_colon                NaN              NaN               NaN
# P_value_colon                    NaN              NaN               NaN
# Correlation_Lscc                 NaN         0.385724               NaN
# P_value_Lscc                     NaN         0.000032               NaN

# %% [markdown]
# # Hemostasis Genes

# %%
hemostasis = ['ITGB1','ITIH4','ITGAM','SERPINC1','DGKB','DGKA','PROS1','ITGB3','SERPINE1','ATP2A3','ITPR3','A1BG','RASGRP2','CLU','KNG1','NRAS','GNG2','GNG7','KIF13B','QSOX1','A2M','FGB','CXADR','SERPIND1','F10','VWF','PRKCB','ITGA3','CAV1','PLAUR','PLA2G4A','PPP2R5A','ATP1B3','F2','SERPINB8','APBB1IP','PROCR','PROC','CAPZA1','PECAM1','PFN1','KLKB1','VCL']

# %%
hemo_column_names = []
for gene in hemostasis:
    gene += "_proteomics"
    hemo_column_names.append(gene)
len(hemo_column_names)
# Out:
# 43

# %%
df_FDR_hemo = df_FDR_append[df_FDR_append.Comparison.isin(hemo_column_names)]
df_FDR_hemo
# Out:
#                 Comparison  Correlation       P_value Cancer Type
# 53      APBB1IP_proteomics    -0.483056  4.103970e-07         GBM
# 77        PROCR_proteomics    -0.470784  8.763500e-07         GBM
# 196       PLAUR_proteomics    -0.425639  1.122876e-05         GBM
# 198    SERPINB8_proteomics    -0.425614  1.124355e-05         GBM
# 271       ITGB1_proteomics    -0.412364  2.223482e-05         GBM
# ...                    ...          ...           ...         ...
# 77647       CLU_proteomics    -0.034342  7.217108e-01        Lscc
# 77872  SERPINC1_proteomics    -0.030863  7.489112e-01        Lscc
# 78145     QSOX1_proteomics     0.026299  7.850674e-01        Lscc
# 79271       A2M_proteomics     0.008291  9.314930e-01        Lscc
# 79285       VCL_proteomics     0.008139  9.327439e-01        Lscc
#
# [335 rows x 4 columns]

# %%
plotCircleHeatMap(df_FDR_hemo,"P_value","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2469">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="68c334d1-d061-4767-ae91-8b628732c60a" data-root-id="2444"></div>

# %%
df_FDR_append_sig_only = df_FDR_hemo[df_FDR_hemo["P_value"] < 0.005]

# %%
plotCircleHeatMap(df_FDR_append_sig_only,"P_value","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2668">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8518c222-1195-4050-ba4a-ff773a544340" data-root-id="2643"></div>

# %%
df_FDR_wide_hemo = df_FDR_wide[df_FDR_wide.Comparison.isin(hemo_column_names)]
df_FDR_wide_hemo
# Out:
#                Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 53     APBB1IP_proteomics        -0.483056  4.103970e-07                 NaN
# 77       PROCR_proteomics        -0.470784  8.763500e-07            0.284925
# 196      PLAUR_proteomics        -0.425639  1.122876e-05                 NaN
# 198   SERPINB8_proteomics        -0.425614  1.124355e-05                 NaN
# 271      ITGB1_proteomics        -0.412364  2.223482e-05            0.276027
# 291       CAV1_proteomics        -0.407997  2.766397e-05            0.344889
# 305        FGB_proteomics        -0.404936  3.218521e-05                 NaN
# 315       PFN1_proteomics        -0.402695  3.592363e-05                 NaN
# 348       DGKA_proteomics        -0.396497  4.848305e-05           -0.324800
# 399     CAPZA1_proteomics        -0.387765  7.323051e-05                 NaN
# 460     PECAM1_proteomics        -0.377454  1.174424e-04                 NaN
# 526        VCL_proteomics        -0.368318  1.761740e-04                 NaN
# 532        F10_proteomics        -0.367388  1.834809e-04                 NaN
# 595       A1BG_proteomics        -0.358499  2.688409e-04                 NaN
# 633      ITGA3_proteomics        -0.354667  3.158987e-04            0.274453
# 745      ITPR3_proteomics        -0.339657  5.828449e-04            0.403668
# 810        A2M_proteomics        -0.333010  7.571685e-04                 NaN
# 817      ITGB3_proteomics        -0.332311  7.780124e-04                 NaN
# 820    PPP2R5A_proteomics         0.332076  7.851652e-04            0.340577
# 833      PROS1_proteomics        -0.331142  8.141044e-04                 NaN
# 838      ITGAM_proteomics        -0.330556  8.327428e-04                 NaN
# 954      ITIH4_proteomics        -0.319610  1.260981e-03                 NaN
# 1057  SERPINC1_proteomics        -0.310060  1.788772e-03                 NaN
# 1078        F2_proteomics        -0.308253  1.908694e-03                 NaN
# 1097  SERPINE1_proteomics        -0.306814  2.009326e-03                 NaN
# 1107     QSOX1_proteomics        -0.305866  2.078241e-03                 NaN
# 1134      KNG1_proteomics        -0.303476  2.261491e-03                 NaN
# 1136      DGKB_proteomics         0.303363  2.270507e-03                 NaN
# 1166     KLKB1_proteomics        -0.300436  2.515530e-03                 NaN
# 1319   RASGRP2_proteomics         0.286756  4.006639e-03                 NaN
# 1376  SERPIND1_proteomics        -0.281792  4.717876e-03                 NaN
# 1971      NRAS_proteomics              NaN           NaN            0.325546
# 1986   PLA2G4A_proteomics              NaN           NaN           -0.323166
# 1988     PRKCB_proteomics              NaN           NaN           -0.322809
# 2067    KIF13B_proteomics              NaN           NaN           -0.310972
# 2539       CLU_proteomics              NaN           NaN                 NaN
# 2548      PROC_proteomics              NaN           NaN                 NaN
# 2592    ATP1B3_proteomics              NaN           NaN                 NaN
# 2676     CXADR_proteomics              NaN           NaN                 NaN
# 3623      GNG2_proteomics              NaN           NaN                 NaN
# 4761       VWF_proteomics              NaN           NaN                 NaN
# 5185    ATP2A3_proteomics              NaN           NaN                 NaN
# 5219      GNG7_proteomics              NaN           NaN                 NaN
#
#       P_value_kidney  Correlation_Ovar  P_value_Ovar  Correlation_Brca  \
# 53               NaN               NaN           NaN               NaN
# 77          0.002553               NaN           NaN          0.336022
# 196              NaN               NaN           NaN          0.467428
# 198              NaN               NaN           NaN               NaN
# 271         0.003513               NaN           NaN          0.410530
# 291         0.000224               NaN           NaN               NaN
# 305              NaN               NaN           NaN          0.303047
# 315              NaN               NaN           NaN          0.303084
# 348         0.000536               NaN           NaN               NaN
# 399              NaN               NaN           NaN          0.311677
# 460              NaN               NaN           NaN          0.359035
# 526              NaN               NaN           NaN          0.322037
# 532              NaN               NaN           NaN          0.306660
# 595              NaN          0.371225      0.000550               NaN
# 633         0.003713               NaN           NaN               NaN
# 745         0.000012               NaN           NaN               NaN
# 810              NaN               NaN           NaN          0.272221
# 817              NaN               NaN           NaN          0.304221
# 820         0.000272               NaN           NaN         -0.380247
# 833              NaN               NaN           NaN          0.384178
# 838              NaN               NaN           NaN          0.388339
# 954              NaN          0.362646      0.000754               NaN
# 1057             NaN               NaN           NaN               NaN
# 1078             NaN               NaN           NaN          0.368861
# 1097             NaN               NaN           NaN          0.484666
# 1107             NaN               NaN           NaN               NaN
# 1134             NaN               NaN           NaN               NaN
# 1136             NaN               NaN           NaN               NaN
# 1166             NaN               NaN           NaN          0.300161
# 1319             NaN               NaN           NaN               NaN
# 1376             NaN          0.366931      0.000645          0.271473
# 1971        0.000520               NaN           NaN          0.237926
# 1986        0.000574               NaN           NaN          0.582162
# 1988        0.000583               NaN           NaN               NaN
# 2067        0.000944          0.439778      0.000032         -0.312353
# 2539             NaN          0.376210      0.000456               NaN
# 2548             NaN          0.372340      0.000528               NaN
# 2592             NaN               NaN           NaN          0.579135
# 2676             NaN               NaN           NaN          0.464852
# 3623             NaN               NaN           NaN          0.295121
# 4761             NaN               NaN           NaN               NaN
# 5185             NaN               NaN           NaN               NaN
# 5219             NaN               NaN           NaN               NaN
#
#       P_value_Brca  Correlation_Luad  P_value_Luad  Correlation_hnscc  \
# 53             NaN         -0.277151  3.376269e-03          -0.382555
# 77    2.412023e-04               NaN           NaN                NaN
# 196   1.389846e-07               NaN           NaN           0.278504
# 198            NaN               NaN           NaN                NaN
# 271   5.191577e-06               NaN           NaN           0.347360
# 291            NaN               NaN           NaN                NaN
# 305   9.944820e-04               NaN           NaN                NaN
# 315   9.929697e-04         -0.370262  6.849871e-05                NaN
# 348            NaN               NaN           NaN                NaN
# 399   6.970752e-04               NaN           NaN                NaN
# 460   8.135457e-05               NaN           NaN          -0.477933
# 526   4.485785e-04               NaN           NaN                NaN
# 532   8.581297e-04               NaN           NaN                NaN
# 595            NaN               NaN           NaN                NaN
# 633            NaN               NaN           NaN           0.288002
# 745            NaN               NaN           NaN           0.292537
# 810   3.248877e-03               NaN           NaN                NaN
# 817   1.443570e-03               NaN           NaN                NaN
# 820   2.768480e-05               NaN           NaN                NaN
# 833   2.248290e-05         -0.281229  2.918698e-03                NaN
# 838   1.798502e-05               NaN           NaN                NaN
# 954            NaN               NaN           NaN                NaN
# 1057           NaN               NaN           NaN                NaN
# 1078  4.984037e-05               NaN           NaN                NaN
# 1097  3.706793e-07               NaN           NaN           0.440590
# 1107           NaN               NaN           NaN                NaN
# 1134           NaN               NaN           NaN                NaN
# 1136           NaN         -0.300881  3.956687e-03                NaN
# 1166  1.117267e-03               NaN           NaN                NaN
# 1319           NaN         -0.473197  1.784433e-07          -0.404658
# 1376  3.338243e-03         -0.306864  1.111406e-03                NaN
# 1971  1.045276e-02               NaN           NaN                NaN
# 1986  8.850043e-12               NaN           NaN                NaN
# 1988           NaN         -0.447001  9.811529e-07          -0.454258
# 2067  6.776348e-04         -0.272975  3.910471e-03          -0.440949
# 2539           NaN         -0.325038  5.309078e-04                NaN
# 2548           NaN         -0.304222  1.232696e-03                NaN
# 2592  1.200161e-11               NaN           NaN                NaN
# 2676  1.661454e-07               NaN           NaN                NaN
# 3623  1.365367e-03         -0.306084  1.146033e-03          -0.272129
# 4761           NaN         -0.329460  4.404313e-04          -0.300045
# 5185           NaN               NaN           NaN          -0.468225
# 5219           NaN               NaN           NaN          -0.404730
#
#       P_value_hnscc  Correlation_colon  P_value_colon  Correlation_Lscc  \
# 53     4.039015e-05           0.404376       0.000040               NaN
# 77              NaN                NaN            NaN               NaN
# 196    3.363640e-03                NaN            NaN               NaN
# 198             NaN           0.430563       0.000011               NaN
# 271    2.150377e-04                NaN            NaN               NaN
# 291             NaN                NaN            NaN               NaN
# 305             NaN                NaN            NaN               NaN
# 315             NaN           0.332115       0.000889               NaN
# 348             NaN                NaN            NaN          0.363821
# 399             NaN                NaN            NaN               NaN
# 460    1.476329e-07                NaN            NaN         -0.341103
# 526             NaN                NaN            NaN               NaN
# 532             NaN                NaN            NaN               NaN
# 595             NaN           0.334008       0.000827               NaN
# 633    2.391229e-03           0.317570       0.001526               NaN
# 745    2.023314e-03                NaN            NaN               NaN
# 810             NaN           0.311803       0.001877               NaN
# 817             NaN                NaN            NaN               NaN
# 820             NaN                NaN            NaN               NaN
# 833             NaN                NaN            NaN               NaN
# 838             NaN                NaN            NaN               NaN
# 954             NaN                NaN            NaN               NaN
# 1057            NaN           0.400614       0.000048               NaN
# 1078            NaN                NaN            NaN               NaN
# 1097   1.631017e-06                NaN            NaN               NaN
# 1107            NaN           0.392392       0.000070               NaN
# 1134            NaN           0.302283       0.002619               NaN
# 1136            NaN                NaN            NaN               NaN
# 1166            NaN           0.359907       0.000294               NaN
# 1319   1.275756e-05           0.734812       0.000065               NaN
# 1376            NaN           0.351169       0.000421               NaN
# 1971            NaN          -0.439191       0.000317               NaN
# 1986            NaN                NaN            NaN               NaN
# 1988   6.996893e-07           0.395927       0.000060               NaN
# 2067   1.595866e-06                NaN            NaN         -0.377294
# 2539            NaN                NaN            NaN               NaN
# 2548            NaN                NaN            NaN               NaN
# 2592            NaN          -0.329942       0.000966               NaN
# 2676            NaN          -0.331827       0.000899               NaN
# 3623   4.202010e-03           0.303755       0.002489               NaN
# 4761   1.525360e-03           0.341362       0.000622               NaN
# 5185   2.834172e-07           0.349198       0.000455               NaN
# 5219   2.231757e-05           0.354152       0.002273               NaN
#
#       P_value_Lscc
# 53             NaN
# 77             NaN
# 196            NaN
# 198            NaN
# 271            NaN
# 291            NaN
# 305            NaN
# 315            NaN
# 348       0.000093
# 399            NaN
# 460       0.000266
# 526            NaN
# 532            NaN
# 595            NaN
# 633            NaN
# 745            NaN
# 810            NaN
# 817            NaN
# 820            NaN
# 833            NaN
# 838            NaN
# 954            NaN
# 1057           NaN
# 1078           NaN
# 1097           NaN
# 1107           NaN
# 1134           NaN
# 1136           NaN
# 1166           NaN
# 1319           NaN
# 1376           NaN
# 1971           NaN
# 1986           NaN
# 1988           NaN
# 2067      0.000048
# 2539           NaN
# 2548           NaN
# 2592           NaN
# 2676           NaN
# 3623           NaN
# 4761           NaN
# 5185           NaN
# 5219           NaN

# %%
immune_sys = ['ITGB1','LRSAM1','ITGAM','AHCYL1','ITGB5','PROS1','WIPF2','ITGB3','NCF4','ICAM3','PTPRJ','IFI30','CLU','C8A','PVR','PSTPIP1','ACTR1A','C8G','CASP10','MRC1','FBXO6','LBP','KPNA3','CTSC','CTSB','FGB','ACTR2','CXADR','VWF','PRKCB','PPP2R5A','IL16','GFRA1','CYBA','TMEM173','APBB1IP','HCK','KIT','RAPGEF2','BPI','CFB','VCL','TLR2','UBA7','ITPR3','BCL10','RASAL3','RASGRP2','MALT1','C2','C3','C5','NRAS','C6','ERBB3','STAT6','FLNB','GBP4','AP1M2','LAIR1','VASP','ARPC4','ARPC5','BAIAP2','LILRB4','NFKB2','ISG20','FCGR2A','ARPC3','NEDD4','CAPZA1','REL','STUB1','FCGR2B','PIK3AP1','PTPN2','LGMN']

# %%
immune_column_names = []
for gene in immune_sys:
    gene += "_proteomics"
    immune_column_names.append(gene)
len(immune_column_names)
# Out:
# 77

# %%
df_FDR_immune = df_FDR_append[df_FDR_append.Comparison.isin(immune_column_names)]
df_FDR_immune
# Out:
#                Comparison  Correlation       P_value Cancer Type
# 8         CTSC_proteomics    -0.546285  4.951742e-09         GBM
# 33        CTSB_proteomics    -0.496895  1.682242e-07         GBM
# 53     APBB1IP_proteomics    -0.483056  4.103970e-07         GBM
# 93      RASAL3_proteomics    -0.464579  1.271949e-06         GBM
# 99         REL_proteomics    -0.461185  1.554594e-06         GBM
# ...                   ...          ...           ...         ...
# 78336     GBP4_proteomics     0.023132  8.104270e-01        Lscc
# 78502    FBXO6_proteomics     0.020502  8.316445e-01        Lscc
# 79285      VCL_proteomics     0.008139  9.327439e-01        Lscc
# 79363    ACTR2_proteomics     0.006766  9.440729e-01        Lscc
# 79736    ARPC5_proteomics    -0.000894  9.926056e-01        Lscc
#
# [605 rows x 4 columns]

# %%
plotCircleHeatMap(df_FDR_immune,"P_value","Correlation","Comparison","Cancer Type")

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3325">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b2bf8ceb-c261-405b-91d8-d77fc869ec1e" data-root-id="3300"></div>
# <style>.container { width:100% !important; }</style>

# %%
df_FDR_append_sig_only = df_FDR_immune[df_FDR_immune["P_value"] < 0.005]

# %%
plotCircleHeatMap(df_FDR_append_sig_only,"P_value","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3564">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="edc7e8e7-bb15-4a8b-9e1d-f83fc500c455" data-root-id="3539"></div>
