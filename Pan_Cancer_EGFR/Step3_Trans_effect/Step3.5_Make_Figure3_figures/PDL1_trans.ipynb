# %% [markdown]
# # PDL1 Circle Heatmap

# %% [markdown]
# This notebooks takes the genes in EGFR pathway and shows

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest

import gseapy as gp
from gseapy.plot import barplot, dotplot

import cptac
import cptac.utils as u
import plot_utils as p

# %% [markdown]
# Load df with all of the genes that are FDR significant. Then get list of just the gene names and use them to run a GSEA.

# %%
#Get append version of the df with all cancer type, fdr sig trans results
df_FDR_append = pd.read_csv("../Step3.2_combining_pearson_dfs/csv_files/pancan_PDL1_FDR_trans.csv")
df_FDR_append = df_FDR_append.drop(['Unnamed: 0'], axis=1)

# %%
EGFR_path = ["JAK1","STAT1","VAV1","CD8A","AKT3","JAK2","MAPK3"]

# %%
#filter down df with just
column_names = []
for gene in EGFR_path:
    gene += "_proteomics"
    column_names.append(gene)

df_FDR_pdl1 = df_FDR_append[df_FDR_append.Comparison.isin(column_names)]

# %%
#Make plot using plot utils
p.plotCircleHeatMap(df_FDR_pdl1, "P_value","Correlation","Comparison","Cancer Type",plot_width= 800, plot_height = 650)
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/plot_utils/__init__.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["size2"] = df[circle_var].apply(lambda x: -1*(np.log(x)))
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/plot_utils/__init__.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['size'] = (df["size2"])*3
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
# ...

# %%
bcell = ["CD79A","CD79B","BLK","BTK","LCK","LYN","SYK","BLNK","CD19","PLCG2","PI3K","CD5","CD22","PCK","HS1","CCL3","CCL4","PTPN6"]

# %%
immune_all_genes = []
for gene in bcell:
    gene += "_proteomics"
    immune_all_genes.append(gene)

# %%
df_FDR_pdl1 = df_FDR_append[df_FDR_append.Comparison.isin(immune_all_genes)]
df_FDR_pdl1
# Out:
#           Comparison  Correlation       P_value Cancer Type
# 1     LYN_proteomics     0.580608  2.987873e-10         GBM
# 2   PLCG2_proteomics     0.526120  2.236260e-08         GBM
# 6     BTK_proteomics     0.504094  1.041317e-07         GBM
# 7   PTPN6_proteomics     0.492678  2.216784e-07         GBM
# 9     SYK_proteomics     0.484445  3.759062e-07         GBM
# 11   BLNK_proteomics     0.450345  2.909398e-06         GBM
# 25    LYN_proteomics     0.438430  2.162957e-05        Luad
# 32  PTPN6_proteomics     0.334110  8.783168e-04        Luad
# 35    BTK_proteomics     0.320302  1.465358e-03        Luad
# 38    LCK_proteomics     0.278893  5.930301e-03        Luad
# 39    LCK_proteomics     0.278893  5.930301e-03        Luad
# 42    SYK_proteomics     0.265052  9.059374e-03        Luad
# 45    CD5_proteomics     0.241923  1.756358e-02        Luad
# 50    LCK_proteomics     0.361633  7.250789e-04       Hnscc
# 51    LCK_proteomics     0.361633  7.250789e-04       Hnscc
# ...

# %%
#Make plot using plot utils
p.plotCircleHeatMap(df_FDR_pdl1, "P_value","Correlation","Comparison","Cancer Type",plot_width= 800, plot_height = 650)
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/plot_utils/__init__.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["size2"] = df[circle_var].apply(lambda x: -1*(np.log(x)))
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/plot_utils/__init__.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['size'] = (df["size2"])*3
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
# ...

# %%
df_FDR_append
# Out:
#           Comparison  Correlation       P_value Cancer Type
# 0   CD274_proteomics     1.000000  0.000000e+00         GBM
# 1    VAV1_proteomics     0.519056  3.706348e-08         GBM
# 2    JAK2_proteomics     0.486955  3.204668e-07         GBM
# 3    AKT3_proteomics    -0.421760  1.375108e-05         GBM
# 4    EGFR_proteomics    -0.315042  1.492646e-03         GBM
# 5   STAT3_proteomics     0.244581  1.469443e-02         GBM
# 6    BRAF_proteomics    -0.242042  1.579093e-02         GBM
# 7    AKT2_proteomics     0.234563  1.944240e-02         GBM
# 8   CD274_proteomics     1.000000  0.000000e+00        Luad
# 9   STAT1_proteomics     0.749028  1.698691e-18        Luad
# 10   VAV1_proteomics     0.442933  6.211477e-06        Luad
# 11  MAPK3_proteomics    -0.395006  6.811141e-05        Luad
# 12   JAK2_proteomics     0.385540  1.048407e-04        Luad
# 13   CD8A_proteomics     0.371430  1.946995e-04        Luad
# 14   NRAS_proteomics     0.326978  1.147500e-03        Luad
# ...
