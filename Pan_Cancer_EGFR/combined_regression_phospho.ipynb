# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest
#sys.path.append('C:\\Users\\brittany\\henderson\\GitHub\\GBM_for_CPTAC\\')
#import cis_functions as f
#sys.path.append('C:\\Users\\Lindsey\\Documents\\GitHub\\WhenMutationsDontMatter\\')
#import plot_utils as p


import cptac
import cptac.utils as u
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # GBM

# %%
df = pd.read_csv("GBM_EGFR_all_phospho.csv")
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#                                 Comparison  Correlation       P_value
# 0             EGFR_phosphoproteomics_S1166     0.836375  4.540027e-27
# 1             EGFR_phosphoproteomics_T1046     0.823906  2.067960e-25
# 2             EGFR_phosphoproteomics_Y1172     0.819459  3.490814e-25
# 3              EGFR_phosphoproteomics_S991     0.790899  2.079575e-22
# 4             EGFR_phosphoproteomics_Y1197     0.807444  4.155461e-22
# ...                                    ...          ...           ...
# 46393          GMPS_phosphoproteomics_S313    -0.000064  9.997020e-01
# 46394          ANXA6_phosphoproteomics_Y10     0.000042  9.997074e-01
# 46395  DOCK11_phosphoproteomics_S1237S1240    -0.000051  9.997090e-01
# 46396           VAT1_phosphoproteomics_S18     0.000040  9.998165e-01
# 46397  PPP1R13L_phosphoproteomics_S102S113     0.000012  9.999400e-01
#
# [46398 rows x 3 columns]

# %% [markdown]
# # Kidney

# %%
df2 = pd.read_csv("Kidney_EGFR_all_phospho.csv")

# %%
df2 = df2.drop(['Unnamed: 0'], axis=1)
df2
# Out:
#                              Comparison  Correlation       P_value
# 0          EGFR_phosphoproteomics_S1113     0.640306  4.996706e-14
# 1           EGFR_phosphoproteomics_T640     0.600529  4.068052e-12
# 2          EGFR_phosphoproteomics_Y1119     0.642668  1.477123e-11
# 3      HIF1A_phosphoproteomics_S475T479     0.662293  4.264192e-10
# 4          USP11_phosphoproteomics_S648    -0.523648  4.356763e-09
# ...                                 ...          ...           ...
# 40194   SVIL_phosphoproteomics_S221S226     0.000036  9.998746e-01
# 40195        MBD3_phosphoproteomics_S85    -0.000013  9.998920e-01
# 40196   LMNA_phosphoproteomics_S407T409     0.000006  9.999567e-01
# 40197       SNX2_phosphoproteomics_S117     0.000004  9.999745e-01
# 40198      ABCF3_phosphoproteomics_S155    -0.000004  9.999769e-01
#
# [40199 rows x 3 columns]

# %%
Gbm_kidney = pd.merge(df, df2, on="Comparison", how = "outer")
Gbm_kidney = Gbm_kidney.rename(columns={"Correlation_x": "Correlation_Gbm","P_value_x":"P_value_Gbm" ,"Correlation_y":"Correlation_kidney","P_value_y": "P_value_kidney" })
#Gbm_kidney = Gbm_kidney.rename(columns={"Slope_y": "slope_kidney", "R_squared_y": "R_squared_kidney","P_value_y": "P_value_kidney" })
#Gbm_kidney.to_csv("GBM_Kidney_EGFR_all.csv")
Gbm_kidney
# Out:
#                               Comparison  Correlation_Gbm   P_value_Gbm  \
# 0           EGFR_phosphoproteomics_S1166         0.836375  4.540027e-27
# 1           EGFR_phosphoproteomics_T1046         0.823906  2.067960e-25
# 2           EGFR_phosphoproteomics_Y1172         0.819459  3.490814e-25
# 3            EGFR_phosphoproteomics_S991         0.790899  2.079575e-22
# 4           EGFR_phosphoproteomics_Y1197         0.807444  4.155461e-22
# ...                                  ...              ...           ...
# 69702     IRF2BP2_phosphoproteomics_T366              NaN           NaN
# 69703  ZNF148_phosphoproteomics_T669T670              NaN           NaN
# 69704    SVIL_phosphoproteomics_S221S226              NaN           NaN
# 69705    LMNA_phosphoproteomics_S407T409              NaN           NaN
# 69706       ABCF3_phosphoproteomics_S155              NaN           NaN
#
#        Correlation_kidney  P_value_kidney
# 0                     NaN             NaN
# 1                     NaN             NaN
# 2                     NaN             NaN
# 3                     NaN             NaN
# 4                     NaN             NaN
# ...                   ...             ...
# 69702           -0.000053        0.999697
# 69703           -0.000030        0.999813
# 69704            0.000036        0.999875
# 69705            0.000006        0.999957
# 69706           -0.000004        0.999977
#
# [69707 rows x 5 columns]

# %% [markdown]
# # Ovarian

# %%
df_Ovar = pd.read_csv("Ovar_EGFR_all_phospho.csv")
df_Ovar = df_Ovar.drop(['Unnamed: 0'], axis=1)
df_Ovar
# Out:
#                            Comparison  Correlation   P_value
# 0          SAV1_phosphoproteomics_S94     0.596355  0.000005
# 1       SORBS2_phosphoproteomics_S378     0.466413  0.000009
# 2         MDC1_phosphoproteomics_S780     0.582111  0.000022
# 3          FLNA_phosphoproteomics_S11     0.662220  0.000027
# 4          NHS_phosphoproteomics_S739     0.637454  0.000029
# ...                               ...          ...       ...
# 12984  ARHGEF15_phosphoproteomics_S42    -0.000060  0.999657
# 12985     IRS2_phosphoproteomics_T350    -0.000050  0.999767
# 12986   TGOLN2_phosphoproteomics_S154    -0.000062  0.999783
# 12987   AHNAK_phosphoproteomics_S5400    -0.000048  0.999783
# 12988  IGF2BP2_phosphoproteomics_S168     0.000021  0.999909
#
# [12989 rows x 3 columns]

# %%
pancan = pd.merge(Gbm_kidney, df_Ovar, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_Ovar","P_value": "P_value_Ovar" })
pancan
# Out:
#                            Comparison  Correlation_Gbm   P_value_Gbm  \
# 0        EGFR_phosphoproteomics_S1166         0.836375  4.540027e-27
# 1        EGFR_phosphoproteomics_T1046         0.823906  2.067960e-25
# 2        EGFR_phosphoproteomics_Y1172         0.819459  3.490814e-25
# 3         EGFR_phosphoproteomics_S991         0.790899  2.079575e-22
# 4        EGFR_phosphoproteomics_Y1197         0.807444  4.155461e-22
# ...                               ...              ...           ...
# 72630    CDK11A_phosphoproteomics_S47              NaN           NaN
# 72631   PDXDC1_phosphoproteomics_T691              NaN           NaN
# 72632     IL16_phosphoproteomics_S683              NaN           NaN
# 72633     APC_phosphoproteomics_S1360              NaN           NaN
# 72634  EHBP1L1_phosphoproteomics_T454              NaN           NaN
#
#        Correlation_kidney  P_value_kidney  Correlation_Ovar  P_value_Ovar
# 0                     NaN             NaN          0.435473      0.000084
# 1                     NaN             NaN               NaN           NaN
# 2                     NaN             NaN          0.420270      0.011948
# 3                     NaN             NaN               NaN           NaN
# 4                     NaN             NaN               NaN           NaN
# ...                   ...             ...               ...           ...
# 72630                 NaN             NaN         -0.000358      0.997672
# 72631                 NaN             NaN          0.000192      0.998868
# 72632                 NaN             NaN          0.000273      0.999064
# 72633                 NaN             NaN         -0.000212      0.999064
# 72634                 NaN             NaN          0.000109      0.999562
#
# [72635 rows x 7 columns]

# %% [markdown]
# # BRCA

# %%
df_Brca = pd.read_csv("Brca_EGFR_all_phospho.csv")
df_Brca = df_Brca.drop(['Unnamed: 0'], axis=1)
df_Brca
# Out:
#                                  Comparison  Correlation       P_value
# 0              EGFR_phosphoproteomics_S1166     0.758593  9.308668e-23
# 1               EGFR_phosphoproteomics_T693     0.744355  2.773845e-17
# 2         PARD6B_phosphoproteomics_S291N301    -0.639906  2.000658e-13
# 3               MAPT_phosphoproteomics_S508    -0.598498  1.617844e-12
# 4           LRBA_phosphoproteomics_S979N988    -0.596900  1.918647e-12
# ...                                     ...          ...           ...
# 38560  STK26_phosphoproteomics_S304S306S309     0.000057  9.996682e-01
# 38561            DLC1_phosphoproteomics_S22     0.000038  9.997380e-01
# 38562         CCDC15_phosphoproteomics_S709     0.000035  9.998113e-01
# 38563          SIPA1_phosphoproteomics_S839     0.000002  9.999852e-01
# 38564         PPP1R3E_phosphoproteomics_S16     0.000001  9.999936e-01
#
# [38565 rows x 3 columns]

# %%
pancan = pd.merge(pancan, df_Brca, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_Brca","P_value": "P_value_Brca" })
pancan
# Out:
#                                  Comparison  Correlation_Gbm   P_value_Gbm  \
# 0              EGFR_phosphoproteomics_S1166         0.836375  4.540027e-27
# 1              EGFR_phosphoproteomics_T1046         0.823906  2.067960e-25
# 2              EGFR_phosphoproteomics_Y1172         0.819459  3.490814e-25
# 3               EGFR_phosphoproteomics_S991         0.790899  2.079575e-22
# 4              EGFR_phosphoproteomics_Y1197         0.807444  4.155461e-22
# ...                                     ...              ...           ...
# 86083          BRCA1_phosphoproteomics_T967              NaN           NaN
# 86084           TNK1_phosphoproteomics_S463              NaN           NaN
# 86085  STK26_phosphoproteomics_S304S306S309              NaN           NaN
# 86086            DLC1_phosphoproteomics_S22              NaN           NaN
# 86087         CCDC15_phosphoproteomics_S709              NaN           NaN
#
#        Correlation_kidney  P_value_kidney  Correlation_Ovar  P_value_Ovar  \
# 0                     NaN             NaN          0.435473      0.000084
# 1                     NaN             NaN               NaN           NaN
# 2                     NaN             NaN          0.420270      0.011948
# 3                     NaN             NaN               NaN           NaN
# 4                     NaN             NaN               NaN           NaN
# ...                   ...             ...               ...           ...
# 86083                 NaN             NaN               NaN           NaN
# 86084                 NaN             NaN               NaN           NaN
# 86085                 NaN             NaN               NaN           NaN
# 86086                 NaN             NaN               NaN           NaN
# 86087                 NaN             NaN               NaN           NaN
#
#        Correlation_Brca  P_value_Brca
# 0              0.758593  9.308668e-23
# 1                   NaN           NaN
# 2                   NaN           NaN
# 3              0.332646  3.597030e-02
# 4                   NaN           NaN
# ...                 ...           ...
# 86083          0.000093  9.994509e-01
# 86084          0.000089  9.995584e-01
# 86085          0.000057  9.996682e-01
# 86086          0.000038  9.997380e-01
# 86087          0.000035  9.998113e-01
#
# [86088 rows x 9 columns]

# %% [markdown]
# # Luad

# %%
df_Luad = pd.read_csv("Luad_EGFR_all_phospho.csv")
df_Luad = df_Luad.drop(['Unnamed: 0'], axis=1)
df_Luad
# Out:
#                               Comparison  Correlation       P_value
# 0           EGFR_phosphoproteomics_S1064     0.808056  1.430853e-26
# 1            EGFR_phosphoproteomics_T693     0.760275  5.838451e-22
# 2           EGFR_phosphoproteomics_Y1197     0.694622  2.994042e-15
# 3           EGFR_phosphoproteomics_Y1172     0.656540  6.792539e-14
# 4            EGFR_phosphoproteomics_S991     0.637149  7.252109e-14
# ...                                  ...          ...           ...
# 40807   DCLK1_phosphoproteomics_S347S352    -0.000016  9.998996e-01
# 40808       SNTB2_phosphoproteomics_S129     0.000011  9.999078e-01
# 40809  ZDHHC5_phosphoproteomics_S587S593     0.000017  9.999210e-01
# 40810     STK11IP_phosphoproteomics_S389     0.000012  9.999331e-01
# 40811      ZC3H14_phosphoproteomics_S252     0.000007  9.999506e-01
#
# [40812 rows x 3 columns]

# %%
pancan = pd.merge(pancan, df_Luad, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_Luad", "P_value": "P_value_Luad" })
pancan
# Out:
#                                Comparison  Correlation_Gbm   P_value_Gbm  \
# 0            EGFR_phosphoproteomics_S1166         0.836375  4.540027e-27
# 1            EGFR_phosphoproteomics_T1046         0.823906  2.067960e-25
# 2            EGFR_phosphoproteomics_Y1172         0.819459  3.490814e-25
# 3             EGFR_phosphoproteomics_S991         0.790899  2.079575e-22
# 4            EGFR_phosphoproteomics_Y1197         0.807444  4.155461e-22
# ...                                   ...              ...           ...
# 94987  DMXL1_phosphoproteomics_S1907S1908              NaN           NaN
# 94988        CDKL5_phosphoproteomics_S543              NaN           NaN
# 94989        STRN4_phosphoproteomics_T163              NaN           NaN
# 94990    LRCH4_phosphoproteomics_S279S281              NaN           NaN
# 94991      STK11IP_phosphoproteomics_S389              NaN           NaN
#
#        Correlation_kidney  P_value_kidney  Correlation_Ovar  P_value_Ovar  \
# 0                     NaN             NaN          0.435473      0.000084
# 1                     NaN             NaN               NaN           NaN
# 2                     NaN             NaN          0.420270      0.011948
# 3                     NaN             NaN               NaN           NaN
# 4                     NaN             NaN               NaN           NaN
# ...                   ...             ...               ...           ...
# 94987                 NaN             NaN               NaN           NaN
# 94988                 NaN             NaN               NaN           NaN
# 94989                 NaN             NaN               NaN           NaN
# 94990                 NaN             NaN               NaN           NaN
# 94991                 NaN             NaN               NaN           NaN
#
#        Correlation_Brca  P_value_Brca  Correlation_Luad  P_value_Luad
# 0              0.758593  9.308668e-23          0.614808  9.001613e-13
# 1                   NaN           NaN               NaN           NaN
# 2                   NaN           NaN          0.656540  6.792539e-14
# 3              0.332646  3.597030e-02          0.637149  7.252109e-14
# 4                   NaN           NaN          0.694622  2.994042e-15
# ...                 ...           ...               ...           ...
# 94987               NaN           NaN          0.000187  9.986722e-01
# 94988               NaN           NaN          0.000201  9.988184e-01
# 94989               NaN           NaN          0.000161  9.991038e-01
# 94990               NaN           NaN         -0.000131  9.992119e-01
# 94991               NaN           NaN          0.000012  9.999331e-01
#
# [94992 rows x 11 columns]

# %% [markdown]
# # HNSCC

# %%
df_Hnscc = pd.read_csv("Hnscc_EGFR_all_phospho.csv")
df_Hnscc = df_Hnscc.drop(['Unnamed: 0'], axis=1)
df_Hnscc
# Out:
#                            Comparison  Correlation       P_value
# 0        EGFR_phosphoproteomics_Y1197     0.841558  4.871114e-29
# 1         EGFR_phosphoproteomics_S991     0.754687  2.631905e-21
# 2         EGFR_phosphoproteomics_T693     0.723745  6.088243e-19
# 3        EGFR_phosphoproteomics_Y1172     0.833804  7.375490e-17
# 4        EGFR_phosphoproteomics_S1166     0.790180  1.136463e-15
# ...                               ...          ...           ...
# 32560    SRRM1_phosphoproteomics_S628    -0.000048  9.996015e-01
# 32561   NRIP1_phosphoproteomics_T1013    -0.000048  9.996859e-01
# 32562  PLEKHG3_phosphoproteomics_S870    -0.000041  9.997673e-01
# 32563    EEF2K_phosphoproteomics_S492     0.000044  9.998376e-01
# 32564    PHF14_phosphoproteomics_T287     0.000014  9.999361e-01
#
# [32565 rows x 3 columns]

# %%
pancan = pd.merge(pancan, df_Hnscc, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_hnscc","P_value": "P_value_hnscc" })
pancan
# Out:
#                                 Comparison  Correlation_Gbm   P_value_Gbm  \
# 0             EGFR_phosphoproteomics_S1166         0.836375  4.540027e-27
# 1             EGFR_phosphoproteomics_T1046         0.823906  2.067960e-25
# 2             EGFR_phosphoproteomics_Y1172         0.819459  3.490814e-25
# 3              EGFR_phosphoproteomics_S991         0.790899  2.079575e-22
# 4             EGFR_phosphoproteomics_Y1197         0.807444  4.155461e-22
# ...                                    ...              ...           ...
# 101113         ANLN_phosphoproteomics_S524              NaN           NaN
# 101114         LIG1_phosphoproteomics_S819              NaN           NaN
# 101115  TTN_phosphoproteomics_T35269T35272              NaN           NaN
# 101116         MYPN_phosphoproteomics_S561              NaN           NaN
# 101117      PLEKHG3_phosphoproteomics_S870              NaN           NaN
#
#         Correlation_kidney  P_value_kidney  Correlation_Ovar  P_value_Ovar  \
# 0                      NaN             NaN          0.435473      0.000084
# 1                      NaN             NaN               NaN           NaN
# 2                      NaN             NaN          0.420270      0.011948
# 3                      NaN             NaN               NaN           NaN
# 4                      NaN             NaN               NaN           NaN
# ...                    ...             ...               ...           ...
# 101113                 NaN             NaN               NaN           NaN
# 101114                 NaN             NaN               NaN           NaN
# 101115                 NaN             NaN               NaN           NaN
# 101116                 NaN             NaN               NaN           NaN
# 101117                 NaN             NaN               NaN           NaN
#
#         Correlation_Brca  P_value_Brca  Correlation_Luad  P_value_Luad  \
# 0               0.758593  9.308668e-23          0.614808  9.001613e-13
# 1                    NaN           NaN               NaN           NaN
# 2                    NaN           NaN          0.656540  6.792539e-14
# 3               0.332646  3.597030e-02          0.637149  7.252109e-14
# 4                    NaN           NaN          0.694622  2.994042e-15
# ...                  ...           ...               ...           ...
# 101113               NaN           NaN               NaN           NaN
# 101114               NaN           NaN               NaN           NaN
# 101115               NaN           NaN               NaN           NaN
# 101116               NaN           NaN               NaN           NaN
# 101117               NaN           NaN               NaN           NaN
#
#         Correlation_hnscc  P_value_hnscc
# 0                0.790180   1.136463e-15
# 1                     NaN            NaN
# 2                0.833804   7.375490e-17
# 3                0.754687   2.631905e-21
# 4                0.841558   4.871114e-29
# ...                   ...            ...
# 101113          -0.000312   9.987925e-01
# 101114          -0.000173   9.992644e-01
# 101115          -0.000103   9.994951e-01
# 101116          -0.000103   9.994976e-01
# 101117          -0.000041   9.997673e-01
#
# [101118 rows x 13 columns]

# %% [markdown]
# # Colon

# %%
df_Colon = pd.read_csv("colon_EGFR_all_phospho.csv")
df_Colon = df_Colon.drop(['Unnamed: 0'], axis=1)
df_Colon
# Out:
#                            Comparison   Correlation       P_value
# 0         NRBP1_phosphoproteomics_S49  5.944902e-01  1.417846e-07
# 1       ZC3H13_phosphoproteomics_S198 -5.049624e-01  2.850161e-07
# 2       ANKS1A_phosphoproteomics_S382 -5.175621e-01  4.620559e-07
# 3       RBM12B_phosphoproteomics_S280 -4.935741e-01  1.027604e-06
# 4       RBM12B_phosphoproteomics_S278 -5.034072e-01  1.431433e-06
# ...                               ...           ...           ...
# 18715     GAB1_phosphoproteomics_T365 -4.042992e-05  9.998189e-01
# 18716    DOCK7_phosphoproteomics_S900 -2.027453e-05  9.998576e-01
# 18717  PLEKHA6_phosphoproteomics_S251 -7.480675e-06  9.999488e-01
# 18718    STIM1_phosphoproteomics_S567 -7.272453e-06  9.999690e-01
# 18719      SMG9_phosphoproteomics_S53  8.949538e-07  9.999950e-01
#
# [18720 rows x 3 columns]

# %%
pancan = pd.merge(pancan, df_Colon, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_colon", "P_value": "P_value_colon" })
pancan
# Out:
#                            Comparison  Correlation_Gbm   P_value_Gbm  \
# 0        EGFR_phosphoproteomics_S1166         0.836375  4.540027e-27
# 1        EGFR_phosphoproteomics_T1046         0.823906  2.067960e-25
# 2        EGFR_phosphoproteomics_Y1172         0.819459  3.490814e-25
# 3         EGFR_phosphoproteomics_S991         0.790899  2.079575e-22
# 4        EGFR_phosphoproteomics_Y1197         0.807444  4.155461e-22
# ...                               ...              ...           ...
# 105255  PDLIM2_phosphoproteomics_S124              NaN           NaN
# 105256   PEAK1_phosphoproteomics_T574              NaN           NaN
# 105257   KRT20_phosphoproteomics_S387              NaN           NaN
# 105258  CENPF_phosphoproteomics_S3150              NaN           NaN
# 105259    GAB1_phosphoproteomics_T365              NaN           NaN
#
#         Correlation_kidney  P_value_kidney  Correlation_Ovar  P_value_Ovar  \
# 0                      NaN             NaN          0.435473      0.000084
# 1                      NaN             NaN               NaN           NaN
# 2                      NaN             NaN          0.420270      0.011948
# 3                      NaN             NaN               NaN           NaN
# 4                      NaN             NaN               NaN           NaN
# ...                    ...             ...               ...           ...
# 105255                 NaN             NaN               NaN           NaN
# 105256                 NaN             NaN               NaN           NaN
# 105257                 NaN             NaN               NaN           NaN
# 105258                 NaN             NaN               NaN           NaN
# 105259                 NaN             NaN               NaN           NaN
#
#         Correlation_Brca  P_value_Brca  Correlation_Luad  P_value_Luad  \
# 0               0.758593  9.308668e-23          0.614808  9.001613e-13
# 1                    NaN           NaN               NaN           NaN
# 2                    NaN           NaN          0.656540  6.792539e-14
# 3               0.332646  3.597030e-02          0.637149  7.252109e-14
# 4                    NaN           NaN          0.694622  2.994042e-15
# ...                  ...           ...               ...           ...
# 105255               NaN           NaN               NaN           NaN
# 105256               NaN           NaN               NaN           NaN
# 105257               NaN           NaN               NaN           NaN
# 105258               NaN           NaN               NaN           NaN
# 105259               NaN           NaN               NaN           NaN
#
#         Correlation_hnscc  P_value_hnscc  Correlation_colon  P_value_colon
# 0                0.790180   1.136463e-15           0.284183       0.004787
# 1                     NaN            NaN                NaN            NaN
# 2                0.833804   7.375490e-17                NaN            NaN
# 3                0.754687   2.631905e-21           0.171256       0.183228
# 4                0.841558   4.871114e-29                NaN            NaN
# ...                   ...            ...                ...            ...
# 105255                NaN            NaN          -0.000144       0.999117
# 105256                NaN            NaN           0.000217       0.999178
# 105257                NaN            NaN           0.000182       0.999281
# 105258                NaN            NaN          -0.000084       0.999712
# 105259                NaN            NaN          -0.000040       0.999819
#
# [105260 rows x 15 columns]

# %%
df_Lscc = pd.read_csv("Lscc_EGFR_all_phospho.csv")
df_Lscc = df_Lscc.drop(['Unnamed: 0'], axis=1)
df_Lscc
# Out:
#                                    Comparison  Correlation       P_value
# 0                EGFR_phosphoproteomics_S1064     0.892423  2.202225e-37
# 1                 EGFR_phosphoproteomics_T693     0.815182  2.274316e-27
# 2                EGFR_phosphoproteomics_S1039     0.800521  9.217794e-26
# 3                EGFR_phosphoproteomics_Y1172     0.800729  5.791519e-22
# 4      EGFR_phosphoproteomics_S1042S1045N1053     0.773589  3.975640e-20
# ...                                       ...          ...           ...
# 42665       ZBTB7A_phosphoproteomics_T517S526     0.000017  9.998748e-01
# 42666              FGA_phosphoproteomics_S294    -0.000024  9.998838e-01
# 42667             PNKP_phosphoproteomics_T118     0.000009  9.999259e-01
# 42668         SLC39A10_phosphoproteomics_T536     0.000003  9.999827e-01
# 42669       FBXO28_phosphoproteomics_M328S330    -0.000002  9.999868e-01
#
# [42670 rows x 3 columns]

# %%
pancan = pd.merge(pancan, df_Lscc, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_Lscc", "P_value": "P_value_Lscc" })
pancan
# Out:
#                                  Comparison  Correlation_Gbm   P_value_Gbm  \
# 0              EGFR_phosphoproteomics_S1166         0.836375  4.540027e-27
# 1              EGFR_phosphoproteomics_T1046         0.823906  2.067960e-25
# 2              EGFR_phosphoproteomics_Y1172         0.819459  3.490814e-25
# 3               EGFR_phosphoproteomics_S991         0.790899  2.079575e-22
# 4              EGFR_phosphoproteomics_Y1197         0.807444  4.155461e-22
# ...                                     ...              ...           ...
# 110131      TNS3_phosphoproteomics_S953S959              NaN           NaN
# 110132          EYA3_phosphoproteomics_S297              NaN           NaN
# 110133  ARHGAP45_phosphoproteomics_M652T655              NaN           NaN
# 110134     SNX29_phosphoproteomics_S330N332              NaN           NaN
# 110135    ZBTB7A_phosphoproteomics_T517S526              NaN           NaN
#
#         Correlation_kidney  P_value_kidney  Correlation_Ovar  P_value_Ovar  \
# 0                      NaN             NaN          0.435473      0.000084
# 1                      NaN             NaN               NaN           NaN
# 2                      NaN             NaN          0.420270      0.011948
# 3                      NaN             NaN               NaN           NaN
# 4                      NaN             NaN               NaN           NaN
# ...                    ...             ...               ...           ...
# 110131                 NaN             NaN               NaN           NaN
# 110132                 NaN             NaN               NaN           NaN
# 110133                 NaN             NaN               NaN           NaN
# 110134                 NaN             NaN               NaN           NaN
# 110135                 NaN             NaN               NaN           NaN
#
#         Correlation_Brca  P_value_Brca  Correlation_Luad  P_value_Luad  \
# 0               0.758593  9.308668e-23          0.614808  9.001613e-13
# 1                    NaN           NaN               NaN           NaN
# 2                    NaN           NaN          0.656540  6.792539e-14
# 3               0.332646  3.597030e-02          0.637149  7.252109e-14
# 4                    NaN           NaN          0.694622  2.994042e-15
# ...                  ...           ...               ...           ...
# 110131               NaN           NaN               NaN           NaN
# 110132               NaN           NaN               NaN           NaN
# 110133               NaN           NaN               NaN           NaN
# 110134               NaN           NaN               NaN           NaN
# 110135               NaN           NaN               NaN           NaN
#
#         Correlation_hnscc  P_value_hnscc  Correlation_colon  P_value_colon  \
# 0                0.790180   1.136463e-15           0.284183       0.004787
# 1                     NaN            NaN                NaN            NaN
# 2                0.833804   7.375490e-17                NaN            NaN
# 3                0.754687   2.631905e-21           0.171256       0.183228
# 4                0.841558   4.871114e-29                NaN            NaN
# ...                   ...            ...                ...            ...
# 110131                NaN            NaN                NaN            NaN
# 110132                NaN            NaN                NaN            NaN
# 110133                NaN            NaN                NaN            NaN
# 110134                NaN            NaN                NaN            NaN
# 110135                NaN            NaN                NaN            NaN
#
#         Correlation_Lscc  P_value_Lscc
# 0               0.724484  3.700113e-19
# 1                    NaN           NaN
# 2               0.800729  5.791519e-22
# 3               0.608766  1.719937e-12
# 4               0.765197  4.598745e-20
# ...                  ...           ...
# 110131          0.000261  9.981903e-01
# 110132         -0.000252  9.984742e-01
# 110133         -0.000161  9.992249e-01
# 110134          0.000092  9.992423e-01
# 110135          0.000017  9.998748e-01
#
# [110136 rows x 17 columns]

# %%
pancan.to_csv("pancan_EGFR_phospho.csv")
