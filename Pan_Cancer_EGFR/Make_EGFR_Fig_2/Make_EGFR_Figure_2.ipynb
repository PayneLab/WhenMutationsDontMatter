# %% [markdown]
# # PDGFR Circle Heatmap

# %% [markdown]
# This notebooks takes the genes that are a hit from the Brca NCI-Nature_2016 (PDGFR-beta pathway) and maps them on a large circle heat map.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest

import gseapy as gp
from gseapy.plot import barplot, dotplot

import cptac
import cptac.utils as u
import plot_utils as p
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Load df with all of the genes that are FDR significant. Then get list of just the gene names and use them to run a GSEA.

# %%
FDR_sig = pd.read_csv("Pval_corr_table_Fig_3_return_sig.csv")
FDR_sig= FDR_sig.drop(['Unnamed: 0'], axis=1)
FDR_sig = FDR_sig.set_index("Comparison")
FDR_sig = FDR_sig[1:] #Drop EGFR 
FDR_sig
# Out:
#                     Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# Comparison
# PHLDA1_proteomics          0.816848  3.507071e-21                 NaN
# GRB2_proteomics           -0.610889  6.729990e-08                 NaN
# CDH4_proteomics            0.559180  3.420388e-06                 NaN
# SOCS2_proteomics           0.562720  3.420388e-06                 NaN
# PLA2G15_proteomics        -0.556624  3.420388e-06                 NaN
# ...                             ...           ...                 ...
# LSR_proteomics                  NaN           NaN                 NaN
# APEX1_proteomics                NaN           NaN                 NaN
# RNF126_proteomics               NaN           NaN                 NaN
# BTBD11_proteomics               NaN           NaN                 NaN
# SNX7_proteomics                 NaN           NaN                 NaN
#
#                     P_value_kidney  Correlation_Ovar  P_value_Ovar  \
# Comparison
# PHLDA1_proteomics              NaN               NaN           NaN
# GRB2_proteomics                NaN               NaN           NaN
# CDH4_proteomics                NaN               NaN           NaN
# SOCS2_proteomics               NaN               NaN           NaN
# PLA2G15_proteomics             NaN               NaN           NaN
# ...                            ...               ...           ...
# LSR_proteomics                 NaN               NaN           NaN
# APEX1_proteomics               NaN               NaN           NaN
# RNF126_proteomics              NaN               NaN           NaN
# BTBD11_proteomics              NaN               NaN           NaN
# SNX7_proteomics                NaN               NaN           NaN
#
#                     Correlation_Brca  P_value_Brca  Correlation_Luad  \
# Comparison
# PHLDA1_proteomics           0.364797      0.002164               NaN
# GRB2_proteomics                  NaN           NaN               NaN
# CDH4_proteomics                  NaN           NaN               NaN
# SOCS2_proteomics                 NaN           NaN               NaN
# PLA2G15_proteomics               NaN           NaN               NaN
# ...                              ...           ...               ...
# LSR_proteomics                   NaN           NaN               NaN
# APEX1_proteomics                 NaN           NaN               NaN
# RNF126_proteomics                NaN           NaN               NaN
# BTBD11_proteomics                NaN           NaN               NaN
# SNX7_proteomics                  NaN           NaN               NaN
#
#                     P_value_Luad  Correlation_hnscc  P_value_hnscc  \
# Comparison
# PHLDA1_proteomics            NaN           0.664271   8.888640e-12
# GRB2_proteomics              NaN          -0.532341   3.320092e-06
# CDH4_proteomics              NaN                NaN            NaN
# SOCS2_proteomics             NaN                NaN            NaN
# PLA2G15_proteomics           NaN                NaN            NaN
# ...                          ...                ...            ...
# LSR_proteomics               NaN                NaN            NaN
# APEX1_proteomics             NaN                NaN            NaN
# RNF126_proteomics            NaN                NaN            NaN
# BTBD11_proteomics            NaN                NaN            NaN
# SNX7_proteomics              NaN                NaN            NaN
#
#                     Correlation_Lscc  P_value_Lscc
# Comparison
# PHLDA1_proteomics           0.713420  2.644826e-14
# GRB2_proteomics                  NaN           NaN
# CDH4_proteomics                  NaN           NaN
# SOCS2_proteomics                 NaN           NaN
# PLA2G15_proteomics               NaN           NaN
# ...                              ...           ...
# LSR_proteomics              0.356431  8.801761e-03
# APEX1_proteomics           -0.353686  9.741073e-03
# RNF126_proteomics           0.353190  9.914599e-03
# BTBD11_proteomics           0.376929  9.991267e-03
# SNX7_proteomics             0.352596  9.991267e-03
#
# [3254 rows x 14 columns]

# %%
def HasPosNeg(row):
    hasPos = False
    hasNeg= False

    for item in row:
        if pd.isnull(item):
            continue
        if item < 0:
            hasNeg = True
        if item > 0:
            hasPos = True
            
    if hasPos & hasNeg:
        return True
    return False

# %%
col = ["Correlation_Gbm","Correlation_kidney","Correlation_Ovar","Correlation_Brca","Correlation_Luad","Correlation_hnscc","Correlation_Lscc"]
FDR_corr = FDR_sig[col]
FDR_corr["Pos_Neg"] = FDR_corr.apply(HasPosNeg, axis = 1)
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
FDR_corr_True = FDR_corr[FDR_corr['Pos_Neg']==True]
FDR_corr_True
# Out:
#                       Correlation_Gbm  Correlation_kidney  Correlation_Ovar  \
# Comparison
# DAB2_proteomics             -0.556402                 NaN               NaN
# SCPEP1_proteomics           -0.531494           -0.386583               NaN
# FAM129B_proteomics          -0.514984                 NaN               NaN
# CTSB_proteomics             -0.496895                 NaN               NaN
# PPP1R18_proteomics          -0.497202                 NaN               NaN
# ...                               ...                 ...               ...
# MPP1_proteomics                   NaN                 NaN               NaN
# METTL7A_proteomics                NaN                 NaN               NaN
# GSPT1_proteomics                  NaN                 NaN               NaN
# RAB11FIP4_proteomics              NaN                 NaN               NaN
# CNKSR1_proteomics                 NaN                 NaN               NaN
#
#                       Correlation_Brca  Correlation_Luad  Correlation_hnscc  \
# Comparison
# DAB2_proteomics               0.326055               NaN                NaN
# SCPEP1_proteomics             0.399187               NaN                NaN
# FAM129B_proteomics            0.344093               NaN                NaN
# CTSB_proteomics               0.341048               NaN                NaN
# PPP1R18_proteomics            0.359142               NaN                NaN
# ...                                ...               ...                ...
# MPP1_proteomics               0.298670               NaN          -0.508400
# METTL7A_proteomics            0.298234               NaN          -0.359487
# GSPT1_proteomics             -0.296472          0.421196                NaN
# RAB11FIP4_proteomics         -0.294174          0.334533                NaN
# CNKSR1_proteomics            -0.293614          0.458742                NaN
#
#                       Correlation_Lscc  Pos_Neg
# Comparison
# DAB2_proteomics                    NaN     True
# SCPEP1_proteomics                  NaN     True
# FAM129B_proteomics            0.360092     True
# CTSB_proteomics                    NaN     True
# PPP1R18_proteomics                 NaN     True
# ...                                ...      ...
# MPP1_proteomics                    NaN     True
# METTL7A_proteomics                 NaN     True
# GSPT1_proteomics                   NaN     True
# RAB11FIP4_proteomics               NaN     True
# CNKSR1_proteomics                  NaN     True
#
# [220 rows x 8 columns]

# %%
df1_transposed = FDR_corr_True.T 
df1_transposed
pos_neg_prot = df1_transposed.columns.values.tolist()
pos_neg_genes = []
for gene in pos_neg_prot :
    pos_neg_genes.append((re.sub("_proteomics", "", gene)))
len(pos_neg_genes)
# Out:
# 220

# %% [markdown]
# Run GSEA using reactome 2016 set

# %%
pos_neg_enr = gp.enrichr(gene_list = pos_neg_genes, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='test/enrichr_kegg')
pos_neg_enr.res2d.head(5)
# Out:
#     Gene_set                                               Term Overlap  \
# 0  KEGG_2016  Bacterial invasion of epithelial cells Homo sa...    8/78
# 1  KEGG_2016                  Endocytosis Homo sapiens hsa04144  13/259
# 2  KEGG_2016  Fc gamma R-mediated phagocytosis Homo sapiens ...    8/93
# 3  KEGG_2016      Proteoglycans in cancer Homo sapiens hsa05205  11/203
# 4  KEGG_2016  Regulation of actin cytoskeleton Homo sapiens ...  11/214
#
#     P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0  0.000002          0.000669            0                     0    9.324009
# 1  0.000006          0.000918            0                     0    4.563005
# 2  0.000009          0.000841            0                     0    7.820137
# 3  0.000016          0.001179            0                     0    4.926108
# 4  0.000026          0.001539            0                     0    4.672897
#
#    Combined Score                                              Genes
# 0      121.113694      ITGB1;ARHGAP10;ARPC3;CAV1;ARPC4;ARPC5;MET;VCL
# 1       54.664482  SH3GLB1;ARFGEF1;CAV1;WIPF2;ARPC4;ARPC5;IGF1R;P...
# 2       91.197700     VASP;HCK;FCGR2A;ARPC3;LIMK2;ARPC4;ARPC5;FCGR2B
# 3       54.367910  ITGB1;ITGB5;CTSL;CAV1;PLAUR;SDC1;FLNB;ITPR3;ME...
# 4       49.285307  ITGB1;DIAPH2;ITGB5;ARPC3;LIMK2;ARPC4;ARPC5;PFN...

# %%
#get just the pdgfr genes
pos_neg_df = pos_neg_enr.res2d
comp_coag = pos_neg_df.iloc[1,9]
comp_coag = comp_coag.split(';')
len(comp_coag)
# Out:
# 48

# %%
#Get append version of the df with all cancer type, fdr sig trans results
df_FDR_append = pd.read_csv("../Step3.2_combining_pearson_dfs/csv_files/pancan_EGFR_pearson_sig_all_prot_append_FDR.csv")
df_FDR_append = df_FDR_append.drop(['Unnamed: 0'], axis=1)

# %%
#filter down df with just pdgfr genes 
pdgfr_column_names = []
for gene in pdgfr:
    gene += "_proteomics"
    pdgfr_column_names.append(gene)

df_FDR_pdgfr = df_FDR_append[df_FDR_append.Comparison.isin(pdgfr_column_names)]
df_FDR_pdgfr
# Out:
#              Comparison  Correlation       P_value  fdr_bh_p_val Cancer Type
# 175   ARPC1B_proteomics    -0.431473  8.240555e-06      0.000500         GBM
# 194      HCK_proteomics    -0.426001  1.101720e-05      0.000605         GBM
# 206    ARPC3_proteomics    -0.423330  1.267190e-05      0.000655         GBM
# 299    ARPC2_proteomics    -0.406327  3.005095e-05      0.001072         GBM
# 416     YES1_proteomics     0.383762  8.813311e-05      0.002262         GBM
# ...                 ...          ...           ...           ...         ...
# 8605     SRC_proteomics     0.480798  1.389641e-07      0.000060        Lscc
# 8712  BAIAP2_proteomics     0.379219  5.180059e-05      0.004465        Lscc
# 8815   ITGAV_proteomics     0.342779  2.818073e-04      0.013723        Lscc
# 8916     JUN_proteomics     0.317601  8.099733e-04      0.027683        Lscc
# 9064    YES1_proteomics     0.294206  1.997518e-03      0.047575        Lscc
#
# [103 rows x 5 columns]

# %%
#Make plot using plot utils
p.plotCircleHeatMap(df_FDR_pdgfr, "P_value","Correlation","Comparison","Cancer Type",plot_width= 1200, plot_height = 650)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7110dc29409d> in <module>
#       1 #Make plot using plot utils
# ----> 2 plotCircleHeatMap(df_FDR_pdgfr, "P_value","Correlation","Comparison","Cancer Type",plot_width= 1200, plot_height = 650)
#
# NameError: name 'plotCircleHeatMap' is not defined
