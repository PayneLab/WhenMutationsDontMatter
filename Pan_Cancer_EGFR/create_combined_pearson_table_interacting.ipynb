# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest
#sys.path.append('C:\\Users\\brittany\\henderson\\GitHub\\GBM_for_CPTAC\\')
#import cis_functions as f
#sys.path.append('C:\\Users\\Lindsey\\Documents\\GitHub\\WhenMutationsDontMatter\\')
#import plot_utils as p


import cptac
import cptac.utils as u
# Out:
# cptac warning: Your version of cptac (0.7.0) is out-of-date. Latest is 0.7.1. Please run 'pip install --upgrade cptac' to update it. (/Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py, line 15)

# %% [markdown]
# # GBM

# %%
df = pd.read_csv('GBM_EGFR_interacting_pearson.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#               Comparison  Correlation       P_value
# 0        EGFR_proteomics     1.000000  0.000000e+00
# 1        GRB2_proteomics    -0.610889  1.886384e-11
# 2        CDH4_proteomics     0.559180  1.790048e-09
# 3        SHC1_proteomics    -0.540524  7.695118e-09
# 4         WAS_proteomics    -0.501918  1.205168e-07
# ...                  ...          ...           ...
# 1068     GCC1_proteomics    -0.000768  9.939836e-01
# 1069     MDM4_proteomics     0.000601  9.965602e-01
# 1070  ARHGEF6_proteomics    -0.000342  9.973166e-01
# 1071   CALML3_proteomics     0.000327  9.975628e-01
# 1072     DLL3_proteomics     0.000357  9.976111e-01
#
# [1073 rows x 3 columns]

# %% [markdown]
# # Kidney

# %%
df2 = pd.read_csv('Kidney_EGFR_interacting_pearson.csv')

# %%
df2 = df2.drop(['Unnamed: 0'], axis=1)
df2
# Out:
#              Comparison  Correlation       P_value
# 0       EGFR_proteomics     1.000000  0.000000e+00
# 1      PLCB1_proteomics     0.561952  1.684847e-10
# 2      ENPP3_proteomics     0.554497  3.278203e-10
# 3       PGK1_proteomics     0.532450  2.138266e-09
# 4      CDC42_proteomics     0.532450  2.138266e-09
# ...                 ...          ...           ...
# 1085   PARVA_proteomics     0.000716  9.940744e-01
# 1086   RPTOR_proteomics    -0.000549  9.954617e-01
# 1087     FGR_proteomics    -0.000667  9.958584e-01
# 1088   GSTA1_proteomics     0.000486  9.959811e-01
# 1089  PIK3R1_proteomics     0.000251  9.979209e-01
#
# [1090 rows x 3 columns]

# %%
Gbm_kidney = pd.merge(df, df2, on="Comparison", how = "outer")
Gbm_kidney = Gbm_kidney.rename(columns={"Correlation_x": "Correlation_Gbm","P_value_x": "P_value_Gbm" })
Gbm_kidney = Gbm_kidney.rename(columns={"Correlation_y": "Correlation_kidney","P_value_y": "P_value_kidney" })
#Gbm_kidney.to_csv("GBM_Kidney_EGFR_all.csv")
Gbm_kidney
# Out:
#              Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0       EGFR_proteomics         1.000000  0.000000e+00            1.000000
# 1       GRB2_proteomics        -0.610889  1.886384e-11           -0.217427
# 2       CDH4_proteomics         0.559180  1.790048e-09            0.148407
# 3       SHC1_proteomics        -0.540524  7.695118e-09           -0.102065
# 4        WAS_proteomics        -0.501918  1.205168e-07           -0.279814
# ...                 ...              ...           ...                 ...
# 1220  UGT2B7_proteomics              NaN           NaN           -0.010829
# 1221   ABCC5_proteomics              NaN           NaN           -0.025235
# 1222  SLC5A9_proteomics              NaN           NaN            0.010137
# 1223  SLC5A1_proteomics              NaN           NaN           -0.005984
# 1224   GNG10_proteomics              NaN           NaN           -0.001988
#
#       P_value_kidney
# 0           0.000000
# 1           0.022506
# 2           0.257781
# 3           0.288685
# 4           0.003071
# ...              ...
# 1220        0.910602
# 1221        0.911241
# 1222        0.919863
# 1223        0.950529
# 1224        0.983552
#
# [1225 rows x 5 columns]

# %% [markdown]
# # Endometrial

# %%
df3 = pd.read_csv("Endo_EGFR_interacting_pearson.csv")
df3 = df3.drop(['Unnamed: 0'], axis=1)
df3
# Out:
#               Comparison  Correlation       P_value
# 0        EGFR_proteomics     1.000000  0.000000e+00
# 1       LPAR1_proteomics     0.672282  2.158643e-11
# 2        FZD1_proteomics     0.611734  4.532118e-11
# 3     SLC27A1_proteomics     0.609468  5.583582e-11
# 4       ITGA6_proteomics     0.600443  1.261442e-10
# ...                  ...          ...           ...
# 1041      RB1_proteomics     0.001400  9.892544e-01
# 1042    ACTR2_proteomics     0.001189  9.908794e-01
# 1043   PFKFB2_proteomics    -0.000916  9.929710e-01
# 1044   TXNRD3_proteomics    -0.000847  9.934995e-01
# 1045   TSG101_proteomics    -0.000746  9.942719e-01
#
# [1046 rows x 3 columns]

# %%
pancan = pd.merge(Gbm_kidney, df3, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_Endo","P_value": "P_value_Endo" })
pancan
# Out:
#               Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0        EGFR_proteomics         1.000000  0.000000e+00            1.000000
# 1        GRB2_proteomics        -0.610889  1.886384e-11           -0.217427
# 2        CDH4_proteomics         0.559180  1.790048e-09            0.148407
# 3        SHC1_proteomics        -0.540524  7.695118e-09           -0.102065
# 4         WAS_proteomics        -0.501918  1.205168e-07           -0.279814
# ...                  ...              ...           ...                 ...
# 1264   ATP2C2_proteomics              NaN           NaN                 NaN
# 1265     KLF4_proteomics              NaN           NaN                 NaN
# 1266     MYL2_proteomics              NaN           NaN                 NaN
# 1267   CYP2A6_proteomics              NaN           NaN                 NaN
# 1268  CREB3L1_proteomics              NaN           NaN                 NaN
#
#       P_value_kidney  Correlation_Endo  P_value_Endo
# 0           0.000000          1.000000      0.000000
# 1           0.022506         -0.437336      0.000009
# 2           0.257781               NaN           NaN
# 3           0.288685         -0.208383      0.042716
# 4           0.003071         -0.238306      0.020041
# ...              ...               ...           ...
# 1264             NaN         -0.037859      0.761000
# 1265             NaN          0.032605      0.771211
# 1266             NaN         -0.026765      0.796820
# 1267             NaN          0.021376      0.837094
# 1268             NaN         -0.017740      0.934430
#
# [1269 rows x 7 columns]

# %% [markdown]
# # Ovarian

# %%
df_Ovar = pd.read_csv("Ovar_EGFR_interacting_pearson.csv")
df_Ovar = df_Ovar.drop(['Unnamed: 0'], axis=1)
df_Ovar
# Out:
#              Comparison  Correlation   P_value
# 0       EGFR_proteomics     1.000000  0.000000
# 1     SLC2A4_proteomics     0.677795  0.000015
# 2     LGALS3_proteomics     0.444479  0.000026
# 3      DOCK1_proteomics     0.439921  0.000032
# 4      GNG12_proteomics     0.437288  0.000036
# ...                 ...          ...       ...
# 1002    RGL1_proteomics    -0.001514  0.992602
# 1003    TAB2_proteomics    -0.000324  0.997677
# 1004  NFATC3_proteomics    -0.000159  0.998861
# 1005    FGD1_proteomics    -0.000223  0.998971
# 1006   CALM2_proteomics    -0.000068  0.999511
#
# [1007 rows x 3 columns]

# %%
pancan = pd.merge(pancan, df_Ovar, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_Ovar","P_value": "P_value_Ovar" })
pancan
# Out:
#              Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0       EGFR_proteomics         1.000000  0.000000e+00            1.000000
# 1       GRB2_proteomics        -0.610889  1.886384e-11           -0.217427
# 2       CDH4_proteomics         0.559180  1.790048e-09            0.148407
# 3       SHC1_proteomics        -0.540524  7.695118e-09           -0.102065
# 4        WAS_proteomics        -0.501918  1.205168e-07           -0.279814
# ...                 ...              ...           ...                 ...
# 1284  COL6A6_proteomics              NaN           NaN                 NaN
# 1285   MYLK2_proteomics              NaN           NaN                 NaN
# 1286    TFF2_proteomics              NaN           NaN                 NaN
# 1287  COL6A5_proteomics              NaN           NaN                 NaN
# 1288  WNT10A_proteomics              NaN           NaN                 NaN
#
#       P_value_kidney  Correlation_Endo  P_value_Endo  Correlation_Ovar  \
# 0           0.000000          1.000000      0.000000          1.000000
# 1           0.022506         -0.437336      0.000009         -0.190090
# 2           0.257781               NaN           NaN               NaN
# 3           0.288685         -0.208383      0.042716          0.175098
# 4           0.003071         -0.238306      0.020041         -0.090413
# ...              ...               ...           ...               ...
# 1284             NaN               NaN           NaN          0.056142
# 1285             NaN               NaN           NaN          0.055288
# 1286             NaN               NaN           NaN         -0.046400
# 1287             NaN               NaN           NaN          0.028812
# 1288             NaN               NaN           NaN          0.056333
#
#       P_value_Ovar
# 0         0.000000
# 1         0.085202
# 2              NaN
# 3         0.113358
# 4         0.416288
# ...            ...
# 1284      0.614179
# 1285      0.637550
# 1286      0.677014
# 1287      0.795971
# 1288      0.808366
#
# [1289 rows x 9 columns]

# %% [markdown]
# # BRCA

# %%
df_Brca = pd.read_csv("Brca_EGFR_interacting_pearson.csv")
df_Brca = df_Brca.drop(['Unnamed: 0'], axis=1)
df_Brca
# Out:
#               Comparison  Correlation       P_value
# 0        EGFR_proteomics     1.000000  0.000000e+00
# 1       PSAT1_proteomics     0.609319  4.973595e-13
# 2     ANGPTL4_proteomics     0.592730  2.980158e-12
# 3     PLA2G4A_proteomics     0.582162  8.850043e-12
# 4        PFKP_proteomics     0.557645  9.562825e-11
# ..                   ...          ...           ...
# 948      PAK4_proteomics    -0.000950  9.919574e-01
# 949  HSP90AA1_proteomics    -0.000908  9.923200e-01
# 950      TNXB_proteomics     0.000828  9.929931e-01
# 951     RASA4_proteomics     0.000308  9.973927e-01
# 952      GNG5_proteomics    -0.000010  9.999172e-01
#
# [953 rows x 3 columns]

# %%
pancan = pd.merge(pancan, df_Brca, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_Brca","P_value": "P_value_Brca" })
pancan
# Out:
#                Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0         EGFR_proteomics         1.000000  0.000000e+00            1.000000
# 1         GRB2_proteomics        -0.610889  1.886384e-11           -0.217427
# 2         CDH4_proteomics         0.559180  1.790048e-09            0.148407
# 3         SHC1_proteomics        -0.540524  7.695118e-09           -0.102065
# 4          WAS_proteomics        -0.501918  1.205168e-07           -0.279814
# ...                   ...              ...           ...                 ...
# 1298      ZIC2_proteomics              NaN           NaN                 NaN
# 1299    MAPK15_proteomics              NaN           NaN                 NaN
# 1300  HLA-DQA2_proteomics              NaN           NaN                 NaN
# 1301     LAMB4_proteomics              NaN           NaN                 NaN
# 1302       ZAK_proteomics              NaN           NaN                 NaN
#
#       P_value_kidney  Correlation_Endo  P_value_Endo  Correlation_Ovar  \
# 0           0.000000          1.000000      0.000000          1.000000
# 1           0.022506         -0.437336      0.000009         -0.190090
# 2           0.257781               NaN           NaN               NaN
# 3           0.288685         -0.208383      0.042716          0.175098
# 4           0.003071         -0.238306      0.020041         -0.090413
# ...              ...               ...           ...               ...
# 1298             NaN               NaN           NaN               NaN
# 1299             NaN               NaN           NaN               NaN
# 1300             NaN               NaN           NaN               NaN
# 1301             NaN               NaN           NaN               NaN
# 1302             NaN               NaN           NaN               NaN
#
#       P_value_Ovar  Correlation_Brca  P_value_Brca
# 0         0.000000          1.000000      0.000000
# 1         0.085202         -0.177379      0.057899
# 2              NaN               NaN           NaN
# 3         0.113358          0.090908      0.333927
# 4         0.416288          0.153496      0.101463
# ...            ...               ...           ...
# 1298           NaN         -0.110913      0.525886
# 1299           NaN          0.053951      0.566876
# 1300           NaN          0.063123      0.609084
# 1301           NaN          0.032213      0.771134
# 1302           NaN          0.020061      0.831480
#
# [1303 rows x 11 columns]

# %% [markdown]
# # Luad

# %%
df_Luad = pd.read_csv("Luad_EGFR_interacting_pearson.csv")
df_Luad = df_Luad.drop(['Unnamed: 0'], axis=1)
df_Luad
# Out:
#               Comparison  Correlation       P_value
# 0        EGFR_proteomics     1.000000  0.000000e+00
# 1         MET_proteomics     0.485692  7.518188e-08
# 2     RASGRP2_proteomics    -0.473197  1.784433e-07
# 3      STAT5B_proteomics    -0.454585  6.077744e-07
# 4      PPP3CB_proteomics    -0.448729  8.806545e-07
# ...                  ...          ...           ...
# 1000     STOM_proteomics     0.001770  9.853579e-01
# 1001     GJA1_proteomics    -0.001077  9.910871e-01
# 1002     RHOA_proteomics    -0.000277  9.977073e-01
# 1003   MAP4K4_proteomics     0.000314  9.977546e-01
# 1004     THBD_proteomics    -0.000050  9.995897e-01
#
# [1005 rows x 3 columns]

# %%
pancan = pd.merge(pancan, df_Luad, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_Luad","P_value": "P_value_Luad" })
pancan
# Out:
#                Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0         EGFR_proteomics         1.000000  0.000000e+00            1.000000
# 1         GRB2_proteomics        -0.610889  1.886384e-11           -0.217427
# 2         CDH4_proteomics         0.559180  1.790048e-09            0.148407
# 3         SHC1_proteomics        -0.540524  7.695118e-09           -0.102065
# 4          WAS_proteomics        -0.501918  1.205168e-07           -0.279814
# ...                   ...              ...           ...                 ...
# 1314     CALM3_proteomics              NaN           NaN                 NaN
# 1315  HLA-DQB2_proteomics              NaN           NaN                 NaN
# 1316      IL7R_proteomics              NaN           NaN                 NaN
# 1317      AGER_proteomics              NaN           NaN                 NaN
# 1318      FLT3_proteomics              NaN           NaN                 NaN
#
#       P_value_kidney  Correlation_Endo  P_value_Endo  Correlation_Ovar  \
# 0           0.000000          1.000000      0.000000          1.000000
# 1           0.022506         -0.437336      0.000009         -0.190090
# 2           0.257781               NaN           NaN               NaN
# 3           0.288685         -0.208383      0.042716          0.175098
# 4           0.003071         -0.238306      0.020041         -0.090413
# ...              ...               ...           ...               ...
# 1314             NaN               NaN           NaN               NaN
# 1315             NaN               NaN           NaN               NaN
# 1316             NaN               NaN           NaN               NaN
# 1317             NaN               NaN           NaN               NaN
# 1318             NaN               NaN           NaN               NaN
#
#       P_value_Ovar  Correlation_Brca  P_value_Brca  Correlation_Luad  \
# 0         0.000000          1.000000      0.000000          1.000000
# 1         0.085202         -0.177379      0.057899         -0.302439
# 2              NaN               NaN           NaN               NaN
# 3         0.113358          0.090908      0.333927         -0.135844
# 4         0.416288          0.153496      0.101463         -0.337909
# ...            ...               ...           ...               ...
# 1314           NaN               NaN           NaN         -0.087184
# 1315           NaN               NaN           NaN          0.077845
# 1316           NaN               NaN           NaN         -0.071003
# 1317           NaN               NaN           NaN         -0.032950
# 1318           NaN               NaN           NaN         -0.024042
#
#       P_value_Luad
# 0         0.000000
# 1         0.001321
# 2              NaN
# 3         0.262164
# 4         0.000306
# ...            ...
# 1314      0.365109
# 1315      0.484233
# 1316      0.577162
# 1317      0.732554
# 1318      0.803118
#
# [1319 rows x 13 columns]

# %% [markdown]
# # HNSCC

# %%
df_hnscc = pd.read_csv("Hnscc_EGFR_interacting_pearson.csv")
df_hnscc = df_hnscc.drop(['Unnamed: 0'], axis=1)
df_hnscc
# Out:
#              Comparison  Correlation       P_value
# 0       EGFR_proteomics     1.000000  0.000000e+00
# 1       GRB2_proteomics    -0.532341  2.559824e-09
# 2       JAG1_proteomics     0.519368  7.186589e-09
# 3       PKN1_proteomics    -0.508498  1.651710e-08
# 4        WAS_proteomics    -0.503427  2.411333e-08
# ...                 ...          ...           ...
# 1135  CLEC4G_proteomics     0.001142  9.926247e-01
# 1136   LTB4R_proteomics    -0.000567  9.964836e-01
# 1137    MBL2_proteomics    -0.000381  9.968607e-01
# 1138   FANCI_proteomics    -0.000379  9.968831e-01
# 1139  PRKAG1_proteomics    -0.000159  9.986890e-01
#
# [1140 rows x 3 columns]

# %%
pancan = pd.merge(pancan, df_hnscc, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_hnscc","P_value": "P_value_hnscc" })
pancan
# Out:
#               Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0        EGFR_proteomics         1.000000  0.000000e+00            1.000000
# 1        GRB2_proteomics        -0.610889  1.886384e-11           -0.217427
# 2        CDH4_proteomics         0.559180  1.790048e-09            0.148407
# 3        SHC1_proteomics        -0.540524  7.695118e-09           -0.102065
# 4         WAS_proteomics        -0.501918  1.205168e-07           -0.279814
# ...                  ...              ...           ...                 ...
# 1343    CALM1_proteomics              NaN           NaN                 NaN
# 1344   UGT1A7_proteomics              NaN           NaN                 NaN
# 1345  PLA2G4D_proteomics              NaN           NaN                 NaN
# 1346    RAD51_proteomics              NaN           NaN                 NaN
# 1347   CLEC4G_proteomics              NaN           NaN                 NaN
#
#       P_value_kidney  Correlation_Endo  P_value_Endo  Correlation_Ovar  \
# 0           0.000000          1.000000      0.000000          1.000000
# 1           0.022506         -0.437336      0.000009         -0.190090
# 2           0.257781               NaN           NaN               NaN
# 3           0.288685         -0.208383      0.042716          0.175098
# 4           0.003071         -0.238306      0.020041         -0.090413
# ...              ...               ...           ...               ...
# 1343             NaN               NaN           NaN               NaN
# 1344             NaN               NaN           NaN               NaN
# 1345             NaN               NaN           NaN               NaN
# 1346             NaN               NaN           NaN               NaN
# 1347             NaN               NaN           NaN               NaN
#
#       P_value_Ovar  Correlation_Brca  P_value_Brca  Correlation_Luad  \
# 0         0.000000          1.000000      0.000000          1.000000
# 1         0.085202         -0.177379      0.057899         -0.302439
# 2              NaN               NaN           NaN               NaN
# 3         0.113358          0.090908      0.333927         -0.135844
# 4         0.416288          0.153496      0.101463         -0.337909
# ...            ...               ...           ...               ...
# 1343           NaN               NaN           NaN               NaN
# 1344           NaN               NaN           NaN               NaN
# 1345           NaN               NaN           NaN               NaN
# 1346           NaN               NaN           NaN               NaN
# 1347           NaN               NaN           NaN               NaN
#
#       P_value_Luad  Correlation_hnscc  P_value_hnscc
# 0         0.000000           1.000000   0.000000e+00
# 1         0.001321          -0.532341   2.559824e-09
# 2              NaN          -0.155826   1.056600e-01
# 3         0.262164          -0.085910   3.744159e-01
# 4         0.000306          -0.503427   2.411333e-08
# ...            ...                ...            ...
# 1343           NaN          -0.040614   6.749904e-01
# 1344           NaN           0.037388   6.995134e-01
# 1345           NaN           0.045101   7.128887e-01
# 1346           NaN           0.050904   7.582732e-01
# 1347           NaN           0.001142   9.926247e-01
#
# [1348 rows x 15 columns]

# %% [markdown]
# # Colon

# %%
df_colon = pd.read_csv("Colon_EGFR_interacting_pearson.csv")
df_colon = df_colon.drop(['Unnamed: 0'], axis=1)
df_colon
# Out:
#              Comparison  Correlation   P_value
# 0       EGFR_proteomics     1.000000  0.000000
# 1    PPP2R5D_proteomics    -0.455111  0.000003
# 2     TBC1D1_proteomics     0.429879  0.000017
# 3       PLD1_proteomics     0.419219  0.000029
# 4     PPP1CC_proteomics     0.400391  0.000048
# ..                  ...          ...       ...
# 825  LAMTOR3_proteomics     0.001425  0.988950
# 826    WASF2_proteomics    -0.001342  0.989588
# 827  CYP4F12_proteomics    -0.000797  0.994736
# 828   TSG101_proteomics    -0.000449  0.996519
# 829    MAPK1_proteomics    -0.000399  0.996904
#
# [830 rows x 3 columns]

# %%
pancan = pd.merge(pancan, df_colon, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Correlation": "Correlation_colon","P_value": "P_value_colon" })
pancan
# Out:
#               Comparison  Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# 0        EGFR_proteomics         1.000000  0.000000e+00            1.000000
# 1        GRB2_proteomics        -0.610889  1.886384e-11           -0.217427
# 2        CDH4_proteomics         0.559180  1.790048e-09            0.148407
# 3        SHC1_proteomics        -0.540524  7.695118e-09           -0.102065
# 4         WAS_proteomics        -0.501918  1.205168e-07           -0.279814
# ...                  ...              ...           ...                 ...
# 1344   UGT1A7_proteomics              NaN           NaN                 NaN
# 1345  PLA2G4D_proteomics              NaN           NaN                 NaN
# 1346    RAD51_proteomics              NaN           NaN                 NaN
# 1347   CLEC4G_proteomics              NaN           NaN                 NaN
# 1348   CYP3A4_proteomics              NaN           NaN                 NaN
#
#       P_value_kidney  Correlation_Endo  P_value_Endo  Correlation_Ovar  \
# 0           0.000000          1.000000      0.000000          1.000000
# 1           0.022506         -0.437336      0.000009         -0.190090
# 2           0.257781               NaN           NaN               NaN
# 3           0.288685         -0.208383      0.042716          0.175098
# 4           0.003071         -0.238306      0.020041         -0.090413
# ...              ...               ...           ...               ...
# 1344             NaN               NaN           NaN               NaN
# 1345             NaN               NaN           NaN               NaN
# 1346             NaN               NaN           NaN               NaN
# 1347             NaN               NaN           NaN               NaN
# 1348             NaN               NaN           NaN               NaN
#
#       P_value_Ovar  Correlation_Brca  P_value_Brca  Correlation_Luad  \
# 0         0.000000          1.000000      0.000000          1.000000
# 1         0.085202         -0.177379      0.057899         -0.302439
# 2              NaN               NaN           NaN               NaN
# 3         0.113358          0.090908      0.333927         -0.135844
# 4         0.416288          0.153496      0.101463         -0.337909
# ...            ...               ...           ...               ...
# 1344           NaN               NaN           NaN               NaN
# 1345           NaN               NaN           NaN               NaN
# 1346           NaN               NaN           NaN               NaN
# 1347           NaN               NaN           NaN               NaN
# 1348           NaN               NaN           NaN               NaN
#
#       P_value_Luad  Correlation_hnscc  P_value_hnscc  Correlation_colon  \
# 0         0.000000           1.000000   0.000000e+00           1.000000
# 1         0.001321          -0.532341   2.559824e-09           0.150960
# 2              NaN          -0.155826   1.056600e-01                NaN
# 3         0.262164          -0.085910   3.744159e-01           0.203250
# 4         0.000306          -0.503427   2.411333e-08           0.282401
# ...            ...                ...            ...                ...
# 1344           NaN           0.037388   6.995134e-01                NaN
# 1345           NaN           0.045101   7.128887e-01                NaN
# 1346           NaN           0.050904   7.582732e-01                NaN
# 1347           NaN           0.001142   9.926247e-01                NaN
# 1348           NaN                NaN            NaN           0.086745
#
#       P_value_colon
# 0          0.000000
# 1          0.139949
# 2               NaN
# 3          0.045855
# 4          0.005070
# ...             ...
# 1344            NaN
# 1345            NaN
# 1346            NaN
# 1347            NaN
# 1348       0.549176
#
# [1349 rows x 17 columns]

# %%
pancan.to_csv("pancan_EGFR_pearson.csv")
