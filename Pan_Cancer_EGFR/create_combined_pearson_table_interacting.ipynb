# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest
#sys.path.append('C:\\Users\\brittany\\henderson\\GitHub\\GBM_for_CPTAC\\')
#import cis_functions as f
#sys.path.append('C:\\Users\\Lindsey\\Documents\\GitHub\\WhenMutationsDontMatter\\')
#import plot_utils as p


import cptac
import cptac.utils as u
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # GBM

# %%
df = pd.read_csv('GBM_EGFR_all_phospho.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#                                 Comparison  Correlation       P_value  \
# 0             EGFR_phosphoproteomics_S1166     0.836375  4.540027e-27
# 1             EGFR_phosphoproteomics_T1046     0.823906  2.067960e-25
# 2             EGFR_phosphoproteomics_Y1172     0.819459  3.490814e-25
# 3              EGFR_phosphoproteomics_S991     0.790899  2.079575e-22
# 4             EGFR_phosphoproteomics_Y1197     0.807444  4.155461e-22
# ...                                    ...          ...           ...
# 46393          GMPS_phosphoproteomics_S313    -0.000064  9.997020e-01
# 46394          ANXA6_phosphoproteomics_Y10     0.000042  9.997074e-01
# 46395  DOCK11_phosphoproteomics_S1237S1240    -0.000051  9.997090e-01
# 46396           VAT1_phosphoproteomics_S18     0.000040  9.998165e-01
# 46397  PPP1R13L_phosphoproteomics_S102S113     0.000012  9.999400e-01
#
#       Cancer Type
# 0             GBM
# 1             GBM
# 2             GBM
# 3             GBM
# 4             GBM
# ...           ...
# 46393         GBM
# 46394         GBM
# 46395         GBM
# 46396         GBM
# 46397         GBM
#
# [46398 rows x 4 columns]

# %% [markdown]
# # Kidney

# %%
df2 = pd.read_csv('Kidney_EGFR_all_phospho.csv')

# %%
df2 = df2.drop(['Unnamed: 0'], axis=1)
df2
# Out:
#                              Comparison  Correlation       P_value Cancer Type
# 0          EGFR_phosphoproteomics_S1113     0.640306  4.996706e-14      Kidney
# 1           EGFR_phosphoproteomics_T640     0.600529  4.068052e-12      Kidney
# 2          EGFR_phosphoproteomics_Y1119     0.642668  1.477123e-11      Kidney
# 3      HIF1A_phosphoproteomics_S475T479     0.662293  4.264192e-10      Kidney
# 4          USP11_phosphoproteomics_S648    -0.523648  4.356763e-09      Kidney
# ...                                 ...          ...           ...         ...
# 40194   SVIL_phosphoproteomics_S221S226     0.000036  9.998746e-01      Kidney
# 40195        MBD3_phosphoproteomics_S85    -0.000013  9.998920e-01      Kidney
# 40196   LMNA_phosphoproteomics_S407T409     0.000006  9.999567e-01      Kidney
# 40197       SNX2_phosphoproteomics_S117     0.000004  9.999745e-01      Kidney
# 40198      ABCF3_phosphoproteomics_S155    -0.000004  9.999769e-01      Kidney
#
# [40199 rows x 4 columns]

# %%
Gbm_kidney = df.append(df2)
Gbm_kidney
# Out:
#                             Comparison  Correlation       P_value Cancer Type
# 0         EGFR_phosphoproteomics_S1166     0.836375  4.540027e-27         GBM
# 1         EGFR_phosphoproteomics_T1046     0.823906  2.067960e-25         GBM
# 2         EGFR_phosphoproteomics_Y1172     0.819459  3.490814e-25         GBM
# 3          EGFR_phosphoproteomics_S991     0.790899  2.079575e-22         GBM
# 4         EGFR_phosphoproteomics_Y1197     0.807444  4.155461e-22         GBM
# ...                                ...          ...           ...         ...
# 40194  SVIL_phosphoproteomics_S221S226     0.000036  9.998746e-01      Kidney
# 40195       MBD3_phosphoproteomics_S85    -0.000013  9.998920e-01      Kidney
# 40196  LMNA_phosphoproteomics_S407T409     0.000006  9.999567e-01      Kidney
# 40197      SNX2_phosphoproteomics_S117     0.000004  9.999745e-01      Kidney
# 40198     ABCF3_phosphoproteomics_S155    -0.000004  9.999769e-01      Kidney
#
# [86597 rows x 4 columns]

# %% [markdown]
# # Ovarian

# %%
df_Ovar = pd.read_csv("Ovar_EGFR_all_phospho.csv")
df_Ovar = df_Ovar.drop(['Unnamed: 0'], axis=1)
df_Ovar
# Out:
#                            Comparison  Correlation   P_value Cancer Type
# 0          SAV1_phosphoproteomics_S94     0.596355  0.000005     Ovarian
# 1       SORBS2_phosphoproteomics_S378     0.466413  0.000009     Ovarian
# 2         MDC1_phosphoproteomics_S780     0.582111  0.000022     Ovarian
# 3          FLNA_phosphoproteomics_S11     0.662220  0.000027     Ovarian
# 4          NHS_phosphoproteomics_S739     0.637454  0.000029     Ovarian
# ...                               ...          ...       ...         ...
# 12984  ARHGEF15_phosphoproteomics_S42    -0.000060  0.999657     Ovarian
# 12985     IRS2_phosphoproteomics_T350    -0.000050  0.999767     Ovarian
# 12986   TGOLN2_phosphoproteomics_S154    -0.000062  0.999783     Ovarian
# 12987   AHNAK_phosphoproteomics_S5400    -0.000048  0.999783     Ovarian
# 12988  IGF2BP2_phosphoproteomics_S168     0.000021  0.999909     Ovarian
#
# [12989 rows x 4 columns]

# %%
pancan = Gbm_kidney.append(df_Ovar)
pancan
# Out:
#                            Comparison  Correlation       P_value Cancer Type
# 0        EGFR_phosphoproteomics_S1166     0.836375  4.540027e-27         GBM
# 1        EGFR_phosphoproteomics_T1046     0.823906  2.067960e-25         GBM
# 2        EGFR_phosphoproteomics_Y1172     0.819459  3.490814e-25         GBM
# 3         EGFR_phosphoproteomics_S991     0.790899  2.079575e-22         GBM
# 4        EGFR_phosphoproteomics_Y1197     0.807444  4.155461e-22         GBM
# ...                               ...          ...           ...         ...
# 12984  ARHGEF15_phosphoproteomics_S42    -0.000060  9.996570e-01     Ovarian
# 12985     IRS2_phosphoproteomics_T350    -0.000050  9.997670e-01     Ovarian
# 12986   TGOLN2_phosphoproteomics_S154    -0.000062  9.997825e-01     Ovarian
# 12987   AHNAK_phosphoproteomics_S5400    -0.000048  9.997829e-01     Ovarian
# 12988  IGF2BP2_phosphoproteomics_S168     0.000021  9.999089e-01     Ovarian
#
# [99586 rows x 4 columns]

# %% [markdown]
# # BRCA

# %%
df_Brca = pd.read_csv("Brca_EGFR_all_phospho.csv")
df_Brca = df_Brca.drop(['Unnamed: 0'], axis=1)
df_Brca
# Out:
#                                  Comparison  Correlation       P_value  \
# 0              EGFR_phosphoproteomics_S1166     0.758593  9.308668e-23
# 1               EGFR_phosphoproteomics_T693     0.744355  2.773845e-17
# 2         PARD6B_phosphoproteomics_S291N301    -0.639906  2.000658e-13
# 3               MAPT_phosphoproteomics_S508    -0.598498  1.617844e-12
# 4           LRBA_phosphoproteomics_S979N988    -0.596900  1.918647e-12
# ...                                     ...          ...           ...
# 38560  STK26_phosphoproteomics_S304S306S309     0.000057  9.996682e-01
# 38561            DLC1_phosphoproteomics_S22     0.000038  9.997380e-01
# 38562         CCDC15_phosphoproteomics_S709     0.000035  9.998113e-01
# 38563          SIPA1_phosphoproteomics_S839     0.000002  9.999852e-01
# 38564         PPP1R3E_phosphoproteomics_S16     0.000001  9.999936e-01
#
#       Cancer Type
# 0            Brca
# 1            Brca
# 2            Brca
# 3            Brca
# 4            Brca
# ...           ...
# 38560        Brca
# 38561        Brca
# 38562        Brca
# 38563        Brca
# 38564        Brca
#
# [38565 rows x 4 columns]

# %%
pancan = pancan.append(df_Brca)
pancan
# Out:
#                                  Comparison  Correlation       P_value  \
# 0              EGFR_phosphoproteomics_S1166     0.836375  4.540027e-27
# 1              EGFR_phosphoproteomics_T1046     0.823906  2.067960e-25
# 2              EGFR_phosphoproteomics_Y1172     0.819459  3.490814e-25
# 3               EGFR_phosphoproteomics_S991     0.790899  2.079575e-22
# 4              EGFR_phosphoproteomics_Y1197     0.807444  4.155461e-22
# ...                                     ...          ...           ...
# 38560  STK26_phosphoproteomics_S304S306S309     0.000057  9.996682e-01
# 38561            DLC1_phosphoproteomics_S22     0.000038  9.997380e-01
# 38562         CCDC15_phosphoproteomics_S709     0.000035  9.998113e-01
# 38563          SIPA1_phosphoproteomics_S839     0.000002  9.999852e-01
# 38564         PPP1R3E_phosphoproteomics_S16     0.000001  9.999936e-01
#
#       Cancer Type
# 0             GBM
# 1             GBM
# 2             GBM
# 3             GBM
# 4             GBM
# ...           ...
# 38560        Brca
# 38561        Brca
# 38562        Brca
# 38563        Brca
# 38564        Brca
#
# [138151 rows x 4 columns]

# %% [markdown]
# # Luad

# %%
df_Luad = pd.read_csv("luad_EGFR_all_phospho.csv")
df_Luad = df_Luad.drop(['Unnamed: 0'], axis=1)
df_Luad
# Out:
#                               Comparison  Correlation       P_value  \
# 0           EGFR_phosphoproteomics_S1064     0.808056  1.430853e-26
# 1            EGFR_phosphoproteomics_T693     0.760275  5.838451e-22
# 2           EGFR_phosphoproteomics_Y1197     0.694622  2.994042e-15
# 3           EGFR_phosphoproteomics_Y1172     0.656540  6.792539e-14
# 4            EGFR_phosphoproteomics_S991     0.637149  7.252109e-14
# ...                                  ...          ...           ...
# 40807   DCLK1_phosphoproteomics_S347S352    -0.000016  9.998996e-01
# 40808       SNTB2_phosphoproteomics_S129     0.000011  9.999078e-01
# 40809  ZDHHC5_phosphoproteomics_S587S593     0.000017  9.999210e-01
# 40810     STK11IP_phosphoproteomics_S389     0.000012  9.999331e-01
# 40811      ZC3H14_phosphoproteomics_S252     0.000007  9.999506e-01
#
#       Cancer Type
# 0            Luad
# 1            Luad
# 2            Luad
# 3            Luad
# 4            Luad
# ...           ...
# 40807        Luad
# 40808        Luad
# 40809        Luad
# 40810        Luad
# 40811        Luad
#
# [40812 rows x 4 columns]

# %%
pancan = pancan.append(df_Luad)
pancan
# Out:
#                               Comparison  Correlation       P_value  \
# 0           EGFR_phosphoproteomics_S1166     0.836375  4.540027e-27
# 1           EGFR_phosphoproteomics_T1046     0.823906  2.067960e-25
# 2           EGFR_phosphoproteomics_Y1172     0.819459  3.490814e-25
# 3            EGFR_phosphoproteomics_S991     0.790899  2.079575e-22
# 4           EGFR_phosphoproteomics_Y1197     0.807444  4.155461e-22
# ...                                  ...          ...           ...
# 40807   DCLK1_phosphoproteomics_S347S352    -0.000016  9.998996e-01
# 40808       SNTB2_phosphoproteomics_S129     0.000011  9.999078e-01
# 40809  ZDHHC5_phosphoproteomics_S587S593     0.000017  9.999210e-01
# 40810     STK11IP_phosphoproteomics_S389     0.000012  9.999331e-01
# 40811      ZC3H14_phosphoproteomics_S252     0.000007  9.999506e-01
#
#       Cancer Type
# 0             GBM
# 1             GBM
# 2             GBM
# 3             GBM
# 4             GBM
# ...           ...
# 40807        Luad
# 40808        Luad
# 40809        Luad
# 40810        Luad
# 40811        Luad
#
# [178963 rows x 4 columns]

# %% [markdown]
# # HNSCC

# %%
df_hnscc = pd.read_csv("Hnscc_EGFR_all_phospho.csv")
df_hnscc = df_hnscc.drop(['Unnamed: 0'], axis=1)
df_hnscc
# Out:
#                            Comparison  Correlation       P_value Cancer Type
# 0        EGFR_phosphoproteomics_Y1197     0.841558  4.871114e-29       Hnscc
# 1         EGFR_phosphoproteomics_S991     0.754687  2.631905e-21       Hnscc
# 2         EGFR_phosphoproteomics_T693     0.723745  6.088243e-19       Hnscc
# 3        EGFR_phosphoproteomics_Y1172     0.833804  7.375490e-17       Hnscc
# 4        EGFR_phosphoproteomics_S1166     0.790180  1.136463e-15       Hnscc
# ...                               ...          ...           ...         ...
# 32560    SRRM1_phosphoproteomics_S628    -0.000048  9.996015e-01       Hnscc
# 32561   NRIP1_phosphoproteomics_T1013    -0.000048  9.996859e-01       Hnscc
# 32562  PLEKHG3_phosphoproteomics_S870    -0.000041  9.997673e-01       Hnscc
# 32563    EEF2K_phosphoproteomics_S492     0.000044  9.998376e-01       Hnscc
# 32564    PHF14_phosphoproteomics_T287     0.000014  9.999361e-01       Hnscc
#
# [32565 rows x 4 columns]

# %%
pancan = pancan.append(df_hnscc)
pancan
# Out:
#                            Comparison  Correlation       P_value Cancer Type
# 0        EGFR_phosphoproteomics_S1166     0.836375  4.540027e-27         GBM
# 1        EGFR_phosphoproteomics_T1046     0.823906  2.067960e-25         GBM
# 2        EGFR_phosphoproteomics_Y1172     0.819459  3.490814e-25         GBM
# 3         EGFR_phosphoproteomics_S991     0.790899  2.079575e-22         GBM
# 4        EGFR_phosphoproteomics_Y1197     0.807444  4.155461e-22         GBM
# ...                               ...          ...           ...         ...
# 32560    SRRM1_phosphoproteomics_S628    -0.000048  9.996015e-01       Hnscc
# 32561   NRIP1_phosphoproteomics_T1013    -0.000048  9.996859e-01       Hnscc
# 32562  PLEKHG3_phosphoproteomics_S870    -0.000041  9.997673e-01       Hnscc
# 32563    EEF2K_phosphoproteomics_S492     0.000044  9.998376e-01       Hnscc
# 32564    PHF14_phosphoproteomics_T287     0.000014  9.999361e-01       Hnscc
#
# [211528 rows x 4 columns]

# %% [markdown]
# # Colon

# %%
df_colon = pd.read_csv("Colon_EGFR_all_phospho.csv")
df_colon = df_colon.drop(['Unnamed: 0'], axis=1)
df_colon
# Out:
#                            Comparison   Correlation       P_value Cancer Type
# 0         NRBP1_phosphoproteomics_S49  5.944902e-01  1.417846e-07       Colon
# 1       ZC3H13_phosphoproteomics_S198 -5.049624e-01  2.850161e-07       Colon
# 2       ANKS1A_phosphoproteomics_S382 -5.175621e-01  4.620559e-07       Colon
# 3       RBM12B_phosphoproteomics_S280 -4.935741e-01  1.027604e-06       Colon
# 4       RBM12B_phosphoproteomics_S278 -5.034072e-01  1.431433e-06       Colon
# ...                               ...           ...           ...         ...
# 18715     GAB1_phosphoproteomics_T365 -4.042992e-05  9.998189e-01       Colon
# 18716    DOCK7_phosphoproteomics_S900 -2.027453e-05  9.998576e-01       Colon
# 18717  PLEKHA6_phosphoproteomics_S251 -7.480675e-06  9.999488e-01       Colon
# 18718    STIM1_phosphoproteomics_S567 -7.272453e-06  9.999690e-01       Colon
# 18719      SMG9_phosphoproteomics_S53  8.949538e-07  9.999950e-01       Colon
#
# [18720 rows x 4 columns]

# %%
pancan = pancan.append(df_colon)
pancan
# Out:
#                            Comparison   Correlation       P_value Cancer Type
# 0        EGFR_phosphoproteomics_S1166  8.363745e-01  4.540027e-27         GBM
# 1        EGFR_phosphoproteomics_T1046  8.239064e-01  2.067960e-25         GBM
# 2        EGFR_phosphoproteomics_Y1172  8.194589e-01  3.490814e-25         GBM
# 3         EGFR_phosphoproteomics_S991  7.908987e-01  2.079575e-22         GBM
# 4        EGFR_phosphoproteomics_Y1197  8.074435e-01  4.155461e-22         GBM
# ...                               ...           ...           ...         ...
# 18715     GAB1_phosphoproteomics_T365 -4.042992e-05  9.998189e-01       Colon
# 18716    DOCK7_phosphoproteomics_S900 -2.027453e-05  9.998576e-01       Colon
# 18717  PLEKHA6_phosphoproteomics_S251 -7.480675e-06  9.999488e-01       Colon
# 18718    STIM1_phosphoproteomics_S567 -7.272453e-06  9.999690e-01       Colon
# 18719      SMG9_phosphoproteomics_S53  8.949538e-07  9.999950e-01       Colon
#
# [230248 rows x 4 columns]

# %% [markdown]
# # LSCC

# %%
df_lscc = pd.read_csv("Lscc_EGFR_all_phospho.csv")
df_lscc = df_lscc.drop(['Unnamed: 0'], axis=1)

df_lscc
# Out:
#                                    Comparison  Correlation       P_value  \
# 0                EGFR_phosphoproteomics_S1064     0.892423  2.202225e-37
# 1                 EGFR_phosphoproteomics_T693     0.815182  2.274316e-27
# 2                EGFR_phosphoproteomics_S1039     0.800521  9.217794e-26
# 3                EGFR_phosphoproteomics_Y1172     0.800729  5.791519e-22
# 4      EGFR_phosphoproteomics_S1042S1045N1053     0.773589  3.975640e-20
# ...                                       ...          ...           ...
# 42665       ZBTB7A_phosphoproteomics_T517S526     0.000017  9.998748e-01
# 42666              FGA_phosphoproteomics_S294    -0.000024  9.998838e-01
# 42667             PNKP_phosphoproteomics_T118     0.000009  9.999259e-01
# 42668         SLC39A10_phosphoproteomics_T536     0.000003  9.999827e-01
# 42669       FBXO28_phosphoproteomics_M328S330    -0.000002  9.999868e-01
#
#       Cancer Type
# 0            Lscc
# 1            Lscc
# 2            Lscc
# 3            Lscc
# 4            Lscc
# ...           ...
# 42665        Lscc
# 42666        Lscc
# 42667        Lscc
# 42668        Lscc
# 42669        Lscc
#
# [42670 rows x 4 columns]

# %%
pancan = pancan.append(df_lscc)
pancan
# Out:
#                               Comparison  Correlation       P_value  \
# 0           EGFR_phosphoproteomics_S1166     0.836375  4.540027e-27
# 1           EGFR_phosphoproteomics_T1046     0.823906  2.067960e-25
# 2           EGFR_phosphoproteomics_Y1172     0.819459  3.490814e-25
# 3            EGFR_phosphoproteomics_S991     0.790899  2.079575e-22
# 4           EGFR_phosphoproteomics_Y1197     0.807444  4.155461e-22
# ...                                  ...          ...           ...
# 42665  ZBTB7A_phosphoproteomics_T517S526     0.000017  9.998748e-01
# 42666         FGA_phosphoproteomics_S294    -0.000024  9.998838e-01
# 42667        PNKP_phosphoproteomics_T118     0.000009  9.999259e-01
# 42668    SLC39A10_phosphoproteomics_T536     0.000003  9.999827e-01
# 42669  FBXO28_phosphoproteomics_M328S330    -0.000002  9.999868e-01
#
#       Cancer Type
# 0             GBM
# 1             GBM
# 2             GBM
# 3             GBM
# 4             GBM
# ...           ...
# 42665        Lscc
# 42666        Lscc
# 42667        Lscc
# 42668        Lscc
# 42669        Lscc
#
# [272918 rows x 4 columns]

# %%
pancan.to_csv("pancan_EGFR_pearson_append_prot_phospho.csv")
