# %% [markdown]
# # Phosphoproteomics GSEA and Heatmap

# %% [markdown]
# This notebook looks at the significant phosphosites in at least one cancer. Pancancer heatmaps are created with circle size showing significance and color showing differences in median.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u
import plot_utils as p

# %% [markdown]
# # Sig in mult cancers

# %%
mult_df = pd.read_csv('Make_Tables\csv\mult_sig_heatmap_phospho.csv')
print('sig in mult cancers:', len(mult_df.Phospho.unique()))
# Out:
# sig in mult cancers: 12

# %%
# Get list of just proteins
mult_df['Gene'] = mult_df['Phospho']
mult_df['Gene'] = mult_df['Gene'].replace(r'(_[\w][\d]*[\w]?[\d]*[\w]?[\d]*)*$', '', regex=True)
prot_list = list(mult_df.Gene.unique()) 
mult_df.head()
# Out:
#           Phospho   P_Value  Medians Cancer      Gene
# 0     DNMBP_S1436  0.000425  1.63160   Luad     DNMBP
# 1      SOS1_S1161  0.000547  1.30250   Luad      SOS1
# 2     PARP4_S1186  0.009200  1.54200   Luad     PARP4
# 3  KIAA1217_S1568  0.022649  1.69130   Luad  KIAA1217
# 4      PDAP1_S170  0.025903 -1.01535   Luad     PDAP1

# %%
prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='Reactome_2016', 
                       outdir='/Enrichr')
# Out:
# 2020-08-10 13:49:21,573 Warning: No enrich terms using library Reactome_2016 when cutoff = 0.05

# %%
prot_enr.res2d.head()
# Out:
#                                                 Term Overlap   P-value  \
# 0  Interleukin-1 processing Homo sapiens R-HSA-44...     1/7  0.004193
# 1  IkBA variant leads to EDA-ID Homo sapiens R-HS...     1/7  0.004193
# 2  IKBKG deficiency causes anhidrotic ectodermal ...     1/8  0.004791
# 3  Type I hemidesmosome assembly Homo sapiens R-H...     1/9  0.005388
# 4  EGFR Transactivation by Gastrin Homo sapiens R...     1/9  0.005388
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0               1.0            0                     0  238.095238
# 1               1.0            0                     0  238.095238
# 2               1.0            0                     0  208.333333
# 3               1.0            0                     0  185.185185
# 4               1.0            0                     0  185.185185
#
#    Combined Score  Genes       Gene_set
# 0     1303.413145  NFKB2  Reactome_2016
# 1     1303.413145  NFKB2  Reactome_2016
# 2     1112.724603  NFKB2  Reactome_2016
# 3      967.327670   PLEC  Reactome_2016
# 4      967.327670   SOS1  Reactome_2016

# %% [markdown]
# # Sig in one cancer

# %%
sig_df = pd.read_csv('Make_Tables\csv\sig_pval_heatmap_phospho.csv')
print('sig in one cancer:', len(sig_df.Phospho.unique()))
# Out:
# sig in one cancer: 889

# %%
# Get list of just proteins
sig_df['Gene'] = sig_df['Phospho']
sig_df['Gene'] = sig_df['Gene'].replace(r'(_[\w][\d]*[\w]?[\d]*[\w]?[\d]*)*$', '', regex=True)
prot_list = list(sig_df.Gene.unique()) 
sig_df.head()
# Out:
#        Phospho   P_Value  Medians Cancer    Gene
# 0    EEF1B2_S8  0.000107   2.1124   Luad  EEF1B2
# 1  DNMBP_S1436  0.000425   1.6316   Luad   DNMBP
# 2   CTBP2_S905  0.000450   1.2298   Luad   CTBP2
# 3   SOS1_S1161  0.000547   1.3025   Luad    SOS1
# 4    XPO5_S416  0.000726   2.6570   Luad    XPO5

# %%
prot_enr = gp.enrichr(gene_list = one, description='Tumor_partition', gene_sets='Reactome_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d[['Term', 'Overlap', 'Adjusted P-value', 'Genes']].head(15)
# Out:
#                                                  Term Overlap  \
# 0   Signaling by Rho GTPases Homo sapiens R-HSA-19...  26/367
# 1          Rho GTPase cycle Homo sapiens R-HSA-194840  14/122
# 2   Interactions of Rev with host cellular protein...    8/35
# 3   SUMO E3 ligases SUMOylate target proteins Homo...   12/96
# 4              SUMOylation Homo sapiens R-HSA-2990846  12/101
# 5               Cell Cycle Homo sapiens R-HSA-1640170  30/566
# 6   NEP/NS2 Interacts with the Cellular Export Mac...    7/30
# 7   Export of Viral Ribonucleoproteins from Nucleu...    7/31
# 8        Cell Cycle, Mitotic Homo sapiens R-HSA-69278  26/462
# 9   Signaling by Robo receptor Homo sapiens R-HSA-...    7/32
# 10  Nuclear import of Rev protein Homo sapiens R-H...    7/32
# 11  NRAGE signals death through JNK Homo sapiens R...    8/45
# 12  Transport of the SLBP independent Mature mRNA ...    7/33
# 13  Rev-mediated nuclear export of HIV RNA Homo sa...    7/33
# 14  Transport of the SLBP Dependant Mature mRNA Ho...    7/34
#
#     Adjusted P-value                                              Genes
# 0           0.000039  ARHGAP5;FGD1;ARHGAP35;AKAP13;XPO1;ABL1;SRGAP2;...
# 1           0.000113  ARHGEF12;ARHGEF18;ARHGAP5;ARHGAP35;FGD1;VAV2;B...
# 2           0.000172     RANBP2;NUP214;NPM1;XPO1;TPR;NUP35;NUP153;NUP98
# 3           0.000173  NUP214;RANBP2;TOP2B;MDC1;TPR;NUP35;NUP153;NUP9...
# 4           0.000242  NUP214;RANBP2;MDC1;TOP2B;TPR;NUP35;NUP153;NUP9...
# 5           0.000316  MDC1;GOLGA2;PCM1;XPO1;TPR;RBBP8;E2F4;TP53BP1;B...
# 6           0.000351          RANBP2;NUP214;XPO1;TPR;NUP35;NUP153;NUP98
# 7           0.000390          RANBP2;NUP214;XPO1;TPR;NUP35;NUP153;NUP98
# 8           0.000371  GOLGA2;PCM1;XPO1;TPR;E2F4;BTRC;SKP2;CLASP1;CDK...
# 9           0.000393           ENAH;ABL1;NCK2;SRGAP2;SOS1;CLASP1;CLASP2
# 10          0.000357          RANBP2;NUP214;NPM1;TPR;NUP35;NUP153;NUP98
# 11          0.000331  AKAP13;ARHGEF12;BAD;ARHGEF18;ARHGEF2;SOS1;FGD1...
# 12          0.000377         RANBP2;NUP214;NCBP1;TPR;NUP35;NUP153;NUP98
# 13          0.000350          RANBP2;NUP214;XPO1;TPR;NUP35;NUP153;NUP98
# 14          0.000405         RANBP2;NUP214;NCBP1;TPR;NUP35;NUP153;NUP98

# %%
prot_enr.res2d['Term']
# Out:
# 0      Signaling by Rho GTPases Homo sapiens R-HSA-19...
# 1             Rho GTPase cycle Homo sapiens R-HSA-194840
# 2      Interactions of Rev with host cellular protein...
# 3      SUMO E3 ligases SUMOylate target proteins Homo...
# 4                 SUMOylation Homo sapiens R-HSA-2990846
#                              ...
# 741    Extracellular matrix organization Homo sapiens...
# 742    Metabolism of lipids and lipoproteins Homo sap...
# 743    Metabolism of amino acids and derivatives Homo...
# 744    GPCR downstream signaling Homo sapiens R-HSA-3...
# 745                Metabolism Homo sapiens R-HSA-1430728
# Name: Term, Length: 746, dtype: object

# %% [markdown]
# # Make Heatmap

# %%
i = 4
genes = prot_enr.res2d.Genes[i]
g_list = genes.split(';')
print(prot_enr.res2d.Term[i])
print('Num genes:', len(g_list))
# Out:
# SUMO E3 ligases SUMOylate target proteins Homo sapiens R-HSA-3108232
# Num genes: 17

# %%
# only one cancer

c = 'Endo' #'Luad'
sig_df = sig_df.loc[sig_df['P_Value'] < 0.05]
one_df = sig_df.loc[sig_df['Cancer'] == c]
len(one_df)
one = list(one_df.Gene)

# %%
get = sig_df['Gene'].isin(g_list)
plot_df = sig_df[get]
plot_df = plot_df.loc[sig_df['P_Value'] < 0.05]

# %%
p.plotCircleHeatMap(plot_df, circle_var = 'P_Value', color_var='Medians', x_axis= 'Phospho', y_axis = 'Cancer',
                    plot_height=400, plot_width= 1500, legend_min = .01, legend_max = 0.05) #,save_png = '.png')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5158">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d2d9e664-eed6-47eb-8df9-dffc444e7b13" data-root-id="5159"></div>
