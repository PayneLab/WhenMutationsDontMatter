# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats
import matplotlib.pyplot as plt
import sys 
import re
import cptac
import statsmodels.stats.multitest
import operator
import cptac.utils as u
import warnings
warnings.filterwarnings('ignore')

# %%
br = cptac.Brca()

# %%
def get_all_interacting_proteins(gene, num_results_in = 25):
    bioplex_list = list(u.get_interacting_proteins_bioplex(gene))
    wiki_list = list(u.get_interacting_proteins_wikipathways(gene))

    biogrid_list = list(u.get_interacting_proteins_biogrid(gene, num_results=num_results_in))
    string_list = list(u.get_interacting_proteins_string(gene, num_results=num_results_in))

    all_int = bioplex_list + wiki_list + biogrid_list + string_list
    interacting_list = list(set(all_int))
    
    #print('Total interacting proteins: ', len(interacting_list))
    return interacting_list

# %%
def rename_duplicate_cols(df):
    cols = pd.Series(df.columns[:])

    for dup in cols[cols.duplicated()].unique(): 
        cols[cols[cols == dup].index.values.tolist()] = [dup + '_' + str(i) if i != 0 else dup for i in range(sum(cols == dup))]

    # rename the columns with the cols list.
    df.columns=cols
    return df

# %%
prot_list =  list(u.get_interacting_proteins_wikipathways("PIK3CA"))
phos_list = ["PIK3CA_Location","PIK3CA_Mutation"]
for gene in prot_list:
    phos = gene + "_phosphoproteomics"
    phos_list.append(phos)
len(phos_list)
# Out:
# 1599

# %%
phospho_sites = ["PIK3CA_phosphoproteomics","AKT1_phosphoproteomics","AKT2_phosphoproteomics","AKT3_phosphoproteomics","MTOR_phosphoproteomics","PDK1_phosphoproteomics","CASP3_phosphoproteomics","CASP7_phosphoproteomics","CASP9_phosphoproteomics","PIK3CA_Mutation","PIK3CA_Location"]
len(phospho_sites)
# Out:
# 11

# %%
phos = br.join_omics_to_mutations(omics_df_name = "phosphoproteomics",mutations_genes="PIK3CA", tissue_type="tumor")
phos = u.reduce_multiindex(df=phos, levels_to_drop=["Database_ID","Peptide"])

genefilter = phos.columns.get_level_values("Name").isin(phos_list)
phos_pik3ca = phos[phos.columns[genefilter]]
phos_pik3ca = cptac.utils.reduce_multiindex(phos_pik3ca, flatten=True)
phos_pik3ca['PIK3CA_Mutation'] = [','.join(map(str, l)) for l in phos_pik3ca['PIK3CA_Mutation']]
phos_pik3ca['PIK3CA_Location'] = [','.join(map(str, l)) for l in phos_pik3ca['PIK3CA_Location']]
phos_pik3ca  = rename_duplicate_cols(phos_pik3ca)
phos_pik3ca.head()
# Out:
# Name        ABI2_phosphoproteomics_S177  ABI2_phosphoproteomics_S190  \
# Patient_ID
# CPT000814                       -1.5722                          NaN
# CPT001846                       -0.4410                      -0.4350
# X01BR001                        -0.3495                      -1.0537
# X01BR008                        -1.0367                      -1.4796
# X01BR009                         0.0747                       0.5357
#
# Name        ABI2_phosphoproteomics_S221  ABI2_phosphoproteomics_S221S227  \
# Patient_ID
# CPT000814                       -3.4370                              NaN
# CPT001846                        0.0899                           0.0802
# X01BR001                        -1.1101                              NaN
# X01BR008                        -1.2161                              NaN
# X01BR009                         0.2893                              NaN
#
# Name        ABI2_phosphoproteomics_S236  ABI2_phosphoproteomics_S301  \
# Patient_ID
# CPT000814                           NaN                      -0.3903
# CPT001846                           NaN                       1.0720
# X01BR001                        -2.2091                      -1.2214
# X01BR008                            NaN                      -1.5208
# X01BR009                            NaN                      -0.4937
#
# Name        ABI2_phosphoproteomics_T169  ABI2_phosphoproteomics_T169S177  \
# Patient_ID
# CPT000814                           NaN                          -0.9325
# CPT001846                           NaN                              NaN
# X01BR001                        -0.1209                              NaN
# X01BR008                        -0.1525                          -0.9875
# X01BR009                         0.4178                          -0.6766
#
# Name        ABL1_phosphoproteomics_S16  ABL1_phosphoproteomics_S199  ...  \
# Patient_ID                                                           ...
# CPT000814                       1.2810                      -2.3591  ...
# CPT001846                       1.1842                          NaN  ...
# X01BR001                        1.8240                          NaN  ...
# X01BR008                       -0.9621                      -0.7081  ...
# X01BR009                       -0.4015                       0.4450  ...
#
# Name        ZYX_phosphoproteomics_S267  ZYX_phosphoproteomics_S267T270  \
# Patient_ID
# CPT000814                      -1.1836                          0.3134
# CPT001846                       2.5682                          1.0165
# X01BR001                        0.1382                         -0.5599
# X01BR008                        0.0126                          0.3983
# X01BR009                        0.2107                         -0.5149
#
# Name        ZYX_phosphoproteomics_S281  ZYX_phosphoproteomics_S290  \
# Patient_ID
# CPT000814                      -0.3471                     -1.4587
# CPT001846                       2.5392                         NaN
# X01BR001                       -0.1956                      2.5434
# X01BR008                       -0.4144                      0.0094
# X01BR009                       -0.2564                     -1.0923
#
# Name        ZYX_phosphoproteomics_S308  ZYX_phosphoproteomics_S344  \
# Patient_ID
# CPT000814                       0.7852                      0.6045
# CPT001846                       1.0189                      2.1206
# X01BR001                        0.0833                      0.6686
# X01BR008                       -0.5811                     -0.2351
# X01BR009                       -0.4257                      0.6808
#
# Name        ZYX_phosphoproteomics_S505  ZYX_phosphoproteomics_S7  \
# Patient_ID
# CPT000814                      -0.3887                    0.9004
# CPT001846                       0.6196                    1.3242
# X01BR001                       -0.2657                   -0.0371
# X01BR008                       -1.3669                   -1.1367
# X01BR009                       -1.0500                   -1.7817
#
# Name          PIK3CA_Mutation  PIK3CA_Location
# Patient_ID
# CPT000814      Wildtype_Tumor      No_mutation
# CPT001846   Missense_Mutation          p.E542K
# X01BR001       Wildtype_Tumor      No_mutation
# X01BR008       Wildtype_Tumor      No_mutation
# X01BR009       Wildtype_Tumor      No_mutation
#
# [5 rows x 4622 columns]

# %%
hotspot = phos_pik3ca[(phos_pik3ca.PIK3CA_Location.str.contains('E542K'))| 
                    phos_pik3ca.PIK3CA_Location.str.contains('E545K')| 
                    phos_pik3ca.PIK3CA_Location.str.contains('H1047R')]
hotspot["PIK3CA_Mutation"] = "Hotspot"
wt = phos_pik3ca[(phos_pik3ca.PIK3CA_Mutation.str.contains('Wildtype'))]
hotspot_wt = pd.concat([hotspot, wt])

hotspot_wt.head(50)
cols = hotspot_wt.columns.to_list()
cols.remove("PIK3CA_Mutation")
cols.remove("PIK3CA_Location")
brca_phos_pval = u.wrap_ttest(hotspot_wt, 'PIK3CA_Mutation', cols,return_all=True, pval_return_corrected= True, correction_method= "FDR_bh")
brca_pak2 = brca_phos_pval.P_Value[1]
brca_pak2
# Out:
# 0.034737004885570556

# %%
brca_phos_df = hotspot_wt[["PIK3CA_Mutation","PAK2_phosphoproteomics_S141T143","DOCK1_phosphoproteomics_S1764"]]
brca_phos_df
# Out:
# Name       PIK3CA_Mutation  PAK2_phosphoproteomics_S141T143  \
# Patient_ID
# CPT001846          Hotspot                           3.7494
# X06BR014           Hotspot                           2.4621
# X11BR004           Hotspot                           0.4110
# X11BR013           Hotspot                          -1.6906
# X11BR014           Hotspot                           1.3605
# ...                    ...                              ...
# X20BR001    Wildtype_Tumor                          -0.3777
# X20BR002    Wildtype_Tumor                          -0.0222
# X20BR005    Wildtype_Tumor                           0.8970
# X20BR007    Wildtype_Tumor                          -1.8977
# X21BR001    Wildtype_Tumor                          -0.2188
#
# Name        DOCK1_phosphoproteomics_S1764
# Patient_ID
# CPT001846                          0.7414
# X06BR014                           3.9312
# X11BR004                          -0.4643
# X11BR013                          -0.1602
# X11BR014                           2.9832
# ...                                   ...
# X20BR001                           0.3711
# X20BR002                           0.7149
# X20BR005                          -0.9955
# X20BR007                           0.7149
# X21BR001                          -1.4648
#
# [103 rows x 3 columns]

# %% [markdown]
# # Endo

# %%
endo = cptac.Endometrial()

# %%
phos = endo.join_omics_to_mutations(omics_df_name = "phosphoproteomics",mutations_genes="PIK3CA", tissue_type="tumor")

genefilter = phos.columns.get_level_values("Name").isin(phos_list)

phos_pik3ca = phos[phos.columns[genefilter]]
phos_pik3ca = cptac.utils.reduce_multiindex(phos_pik3ca, flatten=True)
phos_pik3ca['PIK3CA_Mutation'] = [','.join(map(str, l)) for l in phos_pik3ca['PIK3CA_Mutation']]
phos_pik3ca['PIK3CA_Location'] = [','.join(map(str, l)) for l in phos_pik3ca['PIK3CA_Location']]
phos_pik3ca  = rename_duplicate_cols(phos_pik3ca)
phos_pik3ca.head()
# Out:
# Name        ABI2_phosphoproteomics_S183  ABI2_phosphoproteomics_S196  \
# Patient_ID
# C3L-00006                        0.2225                          NaN
# C3L-00008                       -0.3310                          NaN
# C3L-00032                       -0.2620                       -0.176
# C3L-00090                       -0.0035                          NaN
# C3L-00098                       -0.8805                          NaN
#
# Name        ABI2_phosphoproteomics_S216  ABI2_phosphoproteomics_S224  \
# Patient_ID
# C3L-00006                           NaN                          NaN
# C3L-00008                           NaN                          NaN
# C3L-00032                           NaN                          NaN
# C3L-00090                           NaN                          NaN
# C3L-00098                         0.726                          NaN
#
# Name        ABI2_phosphoproteomics_S227  ABI2_phosphoproteomics_S233  \
# Patient_ID
# C3L-00006                        0.6465                       -0.136
# C3L-00008                       -0.5680                        0.239
# C3L-00032                       -0.2490                          NaN
# C3L-00090                       -0.5130                       -0.227
# C3L-00098                           NaN                       -0.140
#
# Name        ABI2_phosphoproteomics_S243  ABI2_phosphoproteomics_S244  \
# Patient_ID
# C3L-00006                           NaN                          NaN
# C3L-00008                           NaN                          NaN
# C3L-00032                           NaN                          NaN
# C3L-00090                         0.603                          NaN
# C3L-00098                           NaN                          NaN
#
# Name        ABI2_phosphoproteomics_S368  ABI2_phosphoproteomics_T175  ...  \
# Patient_ID                                                            ...
# C3L-00006                       -0.1650                        0.184  ...
# C3L-00008                       -0.7620                          NaN  ...
# C3L-00032                       -0.2930                          NaN  ...
# C3L-00090                       -0.8330                        0.520  ...
# C3L-00098                       -0.0897                       -0.800  ...
#
# Name        ZYX_phosphoproteomics_S545  ZYX_phosphoproteomics_T179  \
# Patient_ID
# C3L-00006                          NaN                         NaN
# C3L-00008                          NaN                         NaN
# C3L-00032                          NaN                      -0.112
# C3L-00090                          NaN                         NaN
# C3L-00098                          NaN                      -0.253
#
# Name        ZYX_phosphoproteomics_T220  ZYX_phosphoproteomics_T270  \
# Patient_ID
# C3L-00006                        -1.66                     -0.6340
# C3L-00008                          NaN                      0.3055
# C3L-00032                          NaN                      0.1410
# C3L-00090                          NaN                     -0.2530
# C3L-00098                          NaN                     -0.7980
#
# Name        ZYX_phosphoproteomics_T274  ZYX_phosphoproteomics_T306  \
# Patient_ID
# C3L-00006                          NaN                      -0.133
# C3L-00008                          NaN                         NaN
# C3L-00032                          NaN                         NaN
# C3L-00090                        -1.04                         NaN
# C3L-00098                          NaN                         NaN
#
# Name        ZYX_phosphoproteomics_T520  ZYX_phosphoproteomics_Y172  \
# Patient_ID
# C3L-00006                          NaN                      -0.378
# C3L-00008                       -0.262                      -1.230
# C3L-00032                          NaN                       0.700
# C3L-00090                          NaN                      -1.020
# C3L-00098                          NaN                      -0.636
#
# Name          PIK3CA_Mutation  PIK3CA_Location
# Patient_ID
# C3L-00006   Missense_Mutation          p.E545K
# C3L-00008      Wildtype_Tumor      No_mutation
# C3L-00032   Missense_Mutation          p.E545K
# C3L-00090      Wildtype_Tumor      No_mutation
# C3L-00098      Wildtype_Tumor      No_mutation
#
# [5 rows x 8459 columns]

# %%
hotspot = phos_pik3ca[(phos_pik3ca.PIK3CA_Location.str.contains('E542K'))| 
                    phos_pik3ca.PIK3CA_Location.str.contains('E545K')| 
                    phos_pik3ca.PIK3CA_Location.str.contains('H1047R')]
hotspot["PIK3CA_Mutation"] = "Hotspot"
wt = phos_pik3ca[(phos_pik3ca.PIK3CA_Mutation.str.contains('Wildtype'))]
hotspot_wt = pd.concat([hotspot, wt])

cols = hotspot_wt.columns.to_list()
cols.remove("PIK3CA_Mutation")
cols.remove("PIK3CA_Location")
endo_phos_pval = u.wrap_ttest(hotspot_wt, 'PIK3CA_Mutation', cols,return_all=True, pval_return_corrected= True, correction_method= "FDR_bh")
endo_phos_pval
# Out:
#                            Comparison   P_Value
# 0     PPP1R12A_phosphoproteomics_Y769  0.974884
# 1         PKP2_phosphoproteomics_S183  0.974884
# 2     PPP1R12B_phosphoproteomics_S903  0.999730
# 3     PPP1R12B_phosphoproteomics_S900  0.999730
# 4     PPP1R12B_phosphoproteomics_S447  0.999730
# ...                               ...       ...
# 4919    PARD3_phosphoproteomics_S1261  0.999894
# 4920    ARID4B_phosphoproteomics_Y795  0.999894
# 4921      TYK2_phosphoproteomics_S884  0.999894
# 4922     FLNA_phosphoproteomics_T2336  0.999894
# 4923     EPHB3_phosphoproteomics_S795  0.999949
#
# [4924 rows x 2 columns]

# %% [markdown]
# # Colon

# %%
col = cptac.Colon()

# %%
phos = col.join_omics_to_mutations(omics_df_name = "phosphoproteomics",mutations_genes="PIK3CA", tissue_type="tumor")
phos = u.reduce_multiindex(df=phos, levels_to_drop=["Database_ID"])
genefilter = phos.columns.get_level_values("Name").isin(phos_list)
phos_pik3ca = phos[phos.columns[genefilter]]
phos_pik3ca = cptac.utils.reduce_multiindex(phos_pik3ca, flatten=True)

phos_pik3ca['PIK3CA_Mutation'] = [','.join(map(str, l)) for l in phos_pik3ca['PIK3CA_Mutation']]
phos_pik3ca['PIK3CA_Location'] = [','.join(map(str, l)) for l in phos_pik3ca['PIK3CA_Location']]
phos_pik3ca  = rename_duplicate_cols(phos_pik3ca)
phos_pik3ca.head()
# Out:
# Name        ABI2_phosphoproteomics_S183  ABI2_phosphoproteomics_S227  \
# Patient_ID
# 01CO001                             NaN                          NaN
# 01CO005                          -0.581                       -1.001
# 01CO006                          -0.515                       -0.251
# 01CO008                          -0.340                       -0.684
# 01CO013                          -0.988                       -1.164
#
# Name        ABI2_phosphoproteomics_S233  ABI2_phosphoproteomics_S242  \
# Patient_ID
# 01CO001                             NaN                          NaN
# 01CO005                             NaN                          NaN
# 01CO006                             NaN                          NaN
# 01CO008                             NaN                          NaN
# 01CO013                             NaN                          NaN
#
# Name        ABI2_phosphoproteomics_S368  ABL1_phosphoproteomics_S16  \
# Patient_ID
# 01CO001                             NaN                         NaN
# 01CO005                          -1.231                      -1.725
# 01CO006                          -0.244                      -0.420
# 01CO008                          -0.866                      -0.681
# 01CO013                          -0.741                       0.254
#
# Name        ABL1_phosphoproteomics_S569  ABL1_phosphoproteomics_S620  \
# Patient_ID
# 01CO001                             NaN                          NaN
# 01CO005                          -1.032                       -0.408
# 01CO006                          -0.304                        0.033
# 01CO008                             NaN                          NaN
# 01CO013                           0.339                          NaN
#
# Name        ABL1_phosphoproteomics_S683  ABL1_phosphoproteomics_S690  ...  \
# Patient_ID                                                            ...
# 01CO001                             NaN                          NaN  ...
# 01CO005                          -1.429                          NaN  ...
# 01CO006                          -0.175                          NaN  ...
# 01CO008                          -0.302                          NaN  ...
# 01CO013                             NaN                          NaN  ...
#
# Name        ZYX_phosphoproteomics_S278  ZYX_phosphoproteomics_S281  \
# Patient_ID
# 01CO001                            NaN                         NaN
# 01CO005                            NaN                     -1.3025
# 01CO006                            NaN                     -0.8200
# 01CO008                            NaN                     -1.0385
# 01CO013                            NaN                     -1.9990
#
# Name        ZYX_phosphoproteomics_S303  ZYX_phosphoproteomics_S308  \
# Patient_ID
# 01CO001                            NaN                         NaN
# 01CO005                            NaN                      -1.421
# 01CO006                         -0.916                      -0.105
# 01CO008                         -0.887                      -0.885
# 01CO013                         -0.124                      -0.764
#
# Name        ZYX_phosphoproteomics_S344  ZYX_phosphoproteomics_S505  \
# Patient_ID
# 01CO001                            NaN                         NaN
# 01CO005                        -1.9950                         NaN
# 01CO006                        -0.6145                         NaN
# 01CO008                        -0.4760                         NaN
# 01CO013                        -0.3070                         NaN
#
# Name        ZYX_phosphoproteomics_S508  ZYX_phosphoproteomics_T270  \
# Patient_ID
# 01CO001                            NaN                         NaN
# 01CO005                            NaN                         NaN
# 01CO006                         -0.098                         NaN
# 01CO008                            NaN                         NaN
# 01CO013                         -0.518                         NaN
#
# Name        PIK3CA_Mutation  PIK3CA_Location
# Patient_ID
# 01CO001      Wildtype_Tumor      No_mutation
# 01CO005      Wildtype_Tumor      No_mutation
# 01CO006      Wildtype_Tumor      No_mutation
# 01CO008      Wildtype_Tumor      No_mutation
# 01CO013      Wildtype_Tumor      No_mutation
#
# [5 rows x 4027 columns]

# %%
hotspot = phos_pik3ca[(phos_pik3ca.PIK3CA_Location.str.contains('E542K'))| 
                    phos_pik3ca.PIK3CA_Location.str.contains('E545K')| 
                    phos_pik3ca.PIK3CA_Location.str.contains('H1047R')]
hotspot["PIK3CA_Mutation"] = "Hotspot"
wt = phos_pik3ca[(phos_pik3ca.PIK3CA_Mutation.str.contains('Wildtype'))]
hotspot_wt = pd.concat([hotspot, wt])

cols = hotspot_wt.columns.to_list()
cols.remove("PIK3CA_Mutation")
cols.remove("PIK3CA_Location")
col_phos_pval = u.wrap_ttest(hotspot_wt, 'PIK3CA_Mutation', cols,return_all=True, pval_return_corrected= True, correction_method= "FDR_bh")
col_phos_pval
# Out:
#                          Comparison   P_Value
# 0       RGL1_phosphoproteomics_T636  0.242819
# 1     SCRIB_phosphoproteomics_S1348  0.242819
# 2      FLNC_phosphoproteomics_S1728  0.242819
# 3     ARID4B_phosphoproteomics_S790  0.242819
# 4      TSC2_phosphoproteomics_S1420  0.242819
# ...                             ...       ...
# 1728   PRKD1_phosphoproteomics_S249  0.999293
# 1729     PXN_phosphoproteomics_S130  0.999293
# 1730     PKN1_phosphoproteomics_S69  0.999293
# 1731  MAP4K4_phosphoproteomics_S842  0.999399
# 1732    GAB2_phosphoproteomics_T391  0.999679
#
# [1733 rows x 2 columns]

# %% [markdown]
# # Test Plots

# %%
endo_pval = endo_phos_pval.loc[endo_phos_pval.Comparison == "PAK2_phosphoproteomics_S141"]
endo_p = endo_pval.P_Value
col_pval = col_phos_pval.loc[col_phos_pval.Comparison == "PAK2_phosphoproteomics_S141"]
col_p = col_pval.P_Value
brca_pval = brca_phos_pval.loc[brca_phos_pval.Comparison == "PAK2_phosphoproteomics_S141"]
brca_p = brca_pval.P_Value
brca_p
# Out:
# 192    0.539053
# Name: P_Value, dtype: float64

# %%
col_phos_df = col_phos_df.assign(cancer = 'Colon')
brca_phos_df = brca_phos_df.assign(cancer = 'Brca')
brca_phos_df = brca_phos_df.rename(columns={"PAK2_phosphoproteomics_S141T143":"PAK2_phosphoproteomics_S141"})
endo_phos_df = endo_phos_df.assign(cancer = 'Endometrial')
df = brca_phos_df.append(col_phos_df)
df2_hotspot = df.append(endo_phos_df)
df2_hotspot.columns
# Out:
# Index(['PIK3CA_Mutation', ' PAK2_phosphoproteomics_S141',
#        'DOCK1_phosphoproteomics_S1764', 'cancer'],
#       dtype='object', name='Name')

# %%
endo_phos_df = hotspot_wt[["PIK3CA_Mutation","PAK2_phosphoproteomics_S141","DOCK1_phosphoproteomics_S1764"]]
# Out:
# Name       PIK3CA_Mutation  PAK2_phosphoproteomics_S141  \
# Patient_ID
# CPT001846          Hotspot                       2.4512
# X06BR014           Hotspot                       1.4548
# X11BR004           Hotspot                       0.7981
# X11BR013           Hotspot                      -0.7098
# X11BR014           Hotspot                       1.1592
# ...                    ...                          ...
# X20BR001    Wildtype_Tumor                      -0.4082
# X20BR002    Wildtype_Tumor                       1.0835
# X20BR005    Wildtype_Tumor                       0.0916
# X20BR007    Wildtype_Tumor                      -0.6278
# X21BR001    Wildtype_Tumor                      -0.3417
#
# Name        DOCK1_phosphoproteomics_S1764
# Patient_ID
# CPT001846                          0.7414
# X06BR014                           3.9312
# X11BR004                          -0.4643
# X11BR013                          -0.1602
# X11BR014                           2.9832
# ...                                   ...
# X20BR001                           0.3711
# X20BR002                           0.7149
# X20BR005                          -0.9955
# X20BR007                           0.7149
# X21BR001                          -1.4648
#
# [103 rows x 3 columns]

# %%
# cis plot
gene = 'PIK3CA'
plt.rcParams['figure.figsize']=(11.7, 8.5) #size of plot
sns.set(font_scale = 1.4)

boxplot = sns.boxplot(x='cancer', y=" PAK2_phosphoproteomics_S141", data = df2_hotspot, hue = 'PIK3CA_Mutation'
                      ,hue_order = ["Wildtype_Tumor", "Hotspot"], showfliers = False)   
#boxplot.set_title('Pancancer cis effect of PIK3CA Missense')
boxplot = sns.stripplot(x='cancer', y=" PAK2_phosphoproteomics_S141", data = df2_hotspot, jitter = True, 
                           color = ".3", hue = 'PIK3CA_Mutation', hue_order = ["Wildtype_Tumor", "Hotspot"], dodge = True)
boxplot.set(xlabel = "\nPIK3CA Mutation Status", ylabel = "PAK2_S141"+' phosphoproteomics')

# format legend
handles, labels = boxplot.get_legend_handles_labels()
plt.legend(handles[0:3], labels[0:3])

# Create significance symbols:
# * P < 0.015   ** P < 0.001   *** P < 0.0001 
cancer_pvals = {'Brca':lp_hotspot, 'Colon':col_hotspot, 'Endo':en_hotspot}

# create pval annotations
symbols = {}
print('p-values: \n')
for cancer in cancer_pvals:
    val = str(cancer_pvals[cancer])
    if cancer_pvals[cancer]  < 0.0001:
        symbols[cancer] = '***'
    elif cancer_pvals[cancer]  < 0.001:
        symbols[cancer] = '**'  
    elif cancer_pvals[cancer]  < 0.05:
        symbols[cancer] = '*'
    elif cancer_pvals[cancer]  > 0.05:
        symbols[cancer] = 'ns'
    print(cancer, val, '\n')


format_pval_annotation(symbols['Brca'], -0.5, 0.5, 2.5)  # Luad
format_pval_annotation(symbols['Colon'], 0.6, 1.4, 1.5)  # Colon
format_pval_annotation(symbols['Endo'], 1.7, 2.4, 1) # Endometrial
plt.show()
plt.clf()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-4dac6b9e8f0b> in <module>
#      17 # Create significance symbols:
#      18 # * P < 0.015   ** P < 0.001   *** P < 0.0001
# ---> 19 cancer_pvals = {'Luad':lp_hotspot, 'Colon':col_hotspot, 'Endo':en_hotspot}
#      20
#      21 # create pval annotations
#
# NameError: name 'lp_hotspot' is not defined
