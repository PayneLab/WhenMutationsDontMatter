# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import gseapy as gp
from gseapy.plot import barplot, dotplot

# %% [markdown]
# # Read in the dataframe that contains the genes that have a positive and negative correlation

# %%
df = pd.read_csv('~/WhenMutationsDontMatter/PIK3CA/csv_files/hotspot_higher_in_one_cancer.csv', index_col=0)
df.head()
# Out:
#           Difference_In_Median_Brca  Difference_In_Median_Endo  \
# A2ML1                           NaN                    1.10585
# ACVR1                       1.24605                        NaN
# ADAMTS12                    1.01320                        NaN
# ANXA8                       1.41075                        NaN
# ARL4C                       1.19120                        NaN
#
#           Difference_In_Median  present_absent
# A2ML1                      NaN            True
# ACVR1                      NaN            True
# ADAMTS12                   NaN            True
# ANXA8                      NaN            True
# ARL4C                      NaN            True

# %%
pos_and_neg_genes = list(df.index)
len(pos_and_neg_genes)
# Out:
# 71

# %% [markdown]
# # Perform enrichment analysis

# %%
enr = gp.enrichr(gene_list = pos_and_neg_genes, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='test/enrichr_kegg__hotspot_up_in_one')
# Out:
# 2020-05-11 11:24:25,859 Warning: No enrich terms using library KEGG_2016 when cutoff = 0.05

# %% [markdown]
# The Gene Set Enrichment Analysis returns a list of pathways the genes provided are involved in, based on a significant adjusted P-value.

# %%
enr.res2d
# Out:
#      Gene_set                                               Term Overlap  \
# 0   KEGG_2016  Protein digestion and absorption Homo sapiens ...    4/90
# 1   KEGG_2016  Intestinal immune network for IgA production H...    3/48
# 2   KEGG_2016                Toxoplasmosis Homo sapiens hsa05145   4/118
# 3   KEGG_2016  Staphylococcus aureus infection Homo sapiens h...    3/56
# 4   KEGG_2016  Inflammatory bowel disease (IBD) Homo sapiens ...    3/65
# ..        ...                                                ...     ...
# 69  KEGG_2016      Proteoglycans in cancer Homo sapiens hsa05205   1/203
# 70  KEGG_2016       Rap1 signaling pathway Homo sapiens hsa04015   1/211
# 71  KEGG_2016  Regulation of actin cytoskeleton Homo sapiens ...   1/214
# 72  KEGG_2016        Ras signaling pathway Homo sapiens hsa04014   1/227
# 73  KEGG_2016       MAPK signaling pathway Homo sapiens hsa04010   1/255
#
#      P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0   0.000296          0.086708            0                     0   12.519562
# 1   0.000661          0.096870            0                     0   17.605634
# 2   0.000825          0.080563            0                     0    9.548818
# 3   0.001038          0.076067            0                     0   15.090543
# 4   0.001599          0.093728            0                     0   13.001083
# ..       ...               ...          ...                   ...         ...
# 69  0.515970          1.000000            0                     0    1.387636
# 70  0.529686          1.000000            0                     0    1.335024
# 71  0.534731          1.000000            0                     0    1.316309
# 72  0.555980          1.000000            0                     0    1.240926
# 73  0.598552          1.000000            0                     0    1.104667
#
#     Combined Score                          Genes
# 0       101.726175  COL17A1;COL24A1;COL5A3;COL5A2
# 1       128.897998         PIGR;HLA-DRB5;HLA-DRB3
# 2        67.799265  HLA-DRB5;TGFB3;LAMC2;HLA-DRB3
# 3       103.672350          C4B;HLA-DRB5;HLA-DRB3
# 4        83.702134        HLA-DRB5;TGFB3;HLA-DRB3
# ..             ...                            ...
# 69        0.918209                          WNT5A
# 70        0.848368                          EFNA1
# 71        0.823999                          DOCK1
# 72        0.728451                          EFNA1
# 73        0.566962                          TGFB3
#
# [74 rows x 10 columns]
