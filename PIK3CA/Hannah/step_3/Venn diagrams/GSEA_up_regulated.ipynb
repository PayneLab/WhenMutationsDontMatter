# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import gseapy as gp
from gseapy.plot import barplot, dotplot

# %%
sig = pd.read_csv('~/WhenMutationsDontMatter/PIK3CA/csv_files/proteomics_sig.csv', index_col=0)
sig.head()
# Out:
#           Difference_In_Median_Brca  P_Value_Brca  Difference_In_Median_Endo  \
# A2ML1                           NaN           NaN                    1.10585
# AADAT                      -1.33200      0.027477                        NaN
# AAGAB                           NaN           NaN                        NaN
# AASDHPPT                    0.51445      0.003620                        NaN
# AATF                       -0.16905      0.042271                        NaN
#
#           P_Value_Endo  Difference_In_Median   P_Value
# A2ML1         0.037044                   NaN       NaN
# AADAT              NaN                   NaN       NaN
# AAGAB              NaN                 0.139  0.039189
# AASDHPPT           NaN                   NaN       NaN
# AATF               NaN                   NaN       NaN

# %%
enr = gp.enrichr(gene_list = list(sig.index), description='up_in_colon', gene_sets='Reactome_2016', 
                       outdir='test/enrichr_kegg__pos_neg_corr')
enr.res2d.head(20)
# Out:
#          Gene_set                                               Term  \
# 0   Reactome_2016  Mitochondrial translation Homo sapiens R-HSA-5...
# 1   Reactome_2016  Mitochondrial translation termination Homo sap...
# 2   Reactome_2016  Mitochondrial translation initiation Homo sapi...
# 3   Reactome_2016  Mitochondrial translation elongation Homo sapi...
# 4   Reactome_2016  Organelle biogenesis and maintenance Homo sapi...
# 5   Reactome_2016  The citric acid (TCA) cycle and respiratory el...
# 6   Reactome_2016  Respiratory electron transport, ATP synthesis ...
# 7   Reactome_2016  Mitochondrial protein import Homo sapiens R-HS...
# 8   Reactome_2016  Respiratory electron transport Homo sapiens R-...
# 9   Reactome_2016  Pyruvate metabolism and Citric Acid (TCA) cycl...
# 10  Reactome_2016              Metabolism Homo sapiens R-HSA-1430728
# 11  Reactome_2016  Citric acid cycle (TCA cycle) Homo sapiens R-H...
# 12  Reactome_2016  Metabolism of amino acids and derivatives Homo...
# 13  Reactome_2016  Glyoxylate metabolism and glycine degradation ...
# 14  Reactome_2016  Mitochondrial tRNA aminoacylation Homo sapiens...
# 15  Reactome_2016  Branched-chain amino acid catabolism Homo sapi...
# 16  Reactome_2016      tRNA Aminoacylation Homo sapiens R-HSA-379724
# 17  Reactome_2016  Regulation of pyruvate dehydrogenase (PDH) com...
# 18  Reactome_2016  TP53 Regulates Metabolic Genes Homo sapiens R-...
# 19  Reactome_2016  Formation of ATP by chemiosmotic coupling Homo...
#
#      Overlap       P-value  Adjusted P-value  Old P-value  \
# 0      73/90  7.657956e-70      1.171667e-66            0
# 1      70/84  1.233126e-68      9.433414e-66            0
# 2      69/84  8.485989e-67      4.327854e-64            0
# 3      68/84  5.392099e-65      2.062478e-62            0
# 4     90/326  3.282902e-32      1.004568e-29            0
# 5     57/153  3.163895e-28      8.067932e-26            0
# 6     37/109  3.159841e-17      6.906509e-15            0
# 7      25/54  8.577364e-16      1.640421e-13            0
# 8      30/88  2.741857e-14      4.661158e-12            0
# 9      21/48  6.995127e-13      1.070254e-10            0
# 10  202/1908  1.142881e-11      1.589644e-09            0
# 11     12/19  2.442622e-10      3.114343e-08            0
# 12    49/335  1.842010e-07      2.167904e-05            0
# 13     11/25  2.112398e-07      2.308549e-05            0
# 14     10/21  3.055591e-07      3.116702e-05            0
# 15     10/23  8.758576e-07      8.375389e-05            0
# 16     12/42  1.268939e-05      1.142045e-03            0
# 17      7/14  1.321105e-05      1.122940e-03            0
# 18     17/84  3.360647e-05      2.706205e-03            0
# 19      7/16  3.909867e-05      2.991048e-03            0
#
#     Old Adjusted P-value  Odds Ratio  Combined Score  \
# 0                      0   12.142382     1932.401935
# 1                      0   12.475050     1950.676570
# 2                      0   12.296835     1870.776331
# 3                      0   12.118620     1793.350896
# 4                      0    4.132839      299.605983
# 5                      0    5.577081      353.144005
# 6                      0    5.081580      193.066627
# 7                      0    6.930583      240.437423
# 8                      0    5.103430      159.367629
# 9                      0    6.549401      183.307211
# 10                     0    1.584881       39.930881
# 11                     0    9.454775      209.260438
# 12                     0    2.189651       33.955433
# 13                     0    6.586826      101.241311
# 14                     0    7.128600      106.937003
# 15                     0    6.508722       90.784055
# 16                     0    4.277160       48.223886
# 17                     0    7.485030       84.090245
# 18                     0    3.029655       31.207846
# 19                     0    6.549401       66.472638
#
#                                                 Genes
# 0   MRPS17;MRPS15;MTFMT;MRPS16;GFM2;MRPS11;MRPS12;...
# 1   MRPS17;MRPS15;MRPS16;GFM2;MRPS11;MRPS12;MRPL38...
# 2   MRPS17;MRPS15;MTFMT;MRPS16;MRPS11;MRPS12;MRPL3...
# 3   MRPS17;MRPS15;MRPS16;MRPS11;MRPS12;MRPL38;MRPL...
# 4   MRPS17;MRPS15;MTFMT;MRPS16;GFM2;MRPS11;MRPS12;...
# 5   COX7B;ATP5C1;ETFA;ETFB;COX6A1;ECSIT;IDH3B;UQCR...
# 6   ATP5S;COX19;COX7B;UQCRB;ATP5A1;ATP5C1;ATP5J;ET...
# 7   COX19;TOMM40;TIMM9;ATP5A1;TIMM13;HSCB;TIMM10;T...
# 8   COX19;COX7B;UQCRB;ETFA;ETFB;ECSIT;COX6A1;COX5B...
# 9   PDHX;PDHA1;MDH2;IDH3G;IDH2;DLST;PDHB;SDHA;LDHB...
# 10  NUP107;MTRR;ATP5C1;NUDT5;ENO2;NUBP1;GLS;GCSH;P...
# 11  SUCLA2;MDH2;IDH3G;IDH2;IDH3B;OGDH;DLST;SUCLG1;...
# 12  MTRR;HIBADH;TAT;GLS;DHTKD1;GCSH;PSMD9;AUH;PSMD...
# 13  GCSH;PDHX;PDHA1;DBT;NDUFAB1;OGDH;DLST;PDHB;DLA...
# 14  LARS2;SARS2;KARS;MARS2;PARS2;NARS2;VARS2;HARS2...
# 15  TMLHE;HIBADH;AUH;IVD;MCCC1;DBT;HSD17B10;DLD;HI...
# 16  YARS;LARS2;SARS2;KARS;PPA1;PARS2;MARS2;NARS2;V...
# 17                 PDHX;PDHA1;PDPR;RXRA;PDHB;DLAT;DLD
# 18  COX8A;COX19;COX7B;NDUFA4;TSC1;COX6A1;COX5B;COX...
# 19        ATP5S;ATP5B;ATP5A1;ATP5C1;ATP5J;ATP5H;ATP5O
