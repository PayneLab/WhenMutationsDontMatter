# %%
import pandas as pd
import numpy as np
import plot_utils
# Out:
# /Users/hannahboekweg/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sig = pd.read_csv('~/WhenMutationsDontMatter/PIK3CA/csv_files/proteomics_sig.csv', index_col=0)
sig.head()
# Out:
#           Difference_In_Median_Brca  P_Value_Brca  Difference_In_Median_Endo  \
# A2ML1                           NaN           NaN                    1.10585
# AADAT                      -1.33200      0.027477                        NaN
# AAGAB                           NaN           NaN                        NaN
# AASDHPPT                    0.51445      0.003620                        NaN
# AATF                       -0.16905      0.042271                        NaN
#
#           P_Value_Endo  Difference_In_Median   P_Value
# A2ML1         0.037044                   NaN       NaN
# AADAT              NaN                   NaN       NaN
# AAGAB              NaN                 0.139  0.039189
# AASDHPPT           NaN                   NaN       NaN
# AATF               NaN                   NaN       NaN

# %%
def colon(row):
    if (row["Difference_In_Median"] < 0):
        return True
    else: 
        return False

# %%
def endo(row):
    if (row["Difference_In_Median_Endo"] < 0):
        return True
    else: 
        return False

# %%
def brca(row):
    if (row["Difference_In_Median_Brca"] < 0):
        return True
    else: 
        return False

# %%
medians = sig.drop(columns= ['P_Value_Brca','P_Value_Endo','P_Value'])
medians.head()
# Out:
#           Difference_In_Median_Brca  Difference_In_Median_Endo  \
# A2ML1                           NaN                    1.10585
# AADAT                      -1.33200                        NaN
# AAGAB                           NaN                        NaN
# AASDHPPT                    0.51445                        NaN
# AATF                       -0.16905                        NaN
#
#           Difference_In_Median
# A2ML1                      NaN
# AADAT                      NaN
# AAGAB                    0.139
# AASDHPPT                   NaN
# AATF                       NaN

# %%
medians["Pos_Neg"] = medians.apply(colon, axis = 1)
pos_and_neg = medians.loc[medians['Pos_Neg'] == True]
colon_genes = list(pos_and_neg.index)
len(colon_genes)
# Out:
# 95

# %%
medians["Pos_Neg"] = medians.apply(endo, axis = 1)
pos_and_neg = medians.loc[medians['Pos_Neg'] == True]
endo_genes = list(pos_and_neg.index)
len(endo_genes)
# Out:
# 227

# %%
medians["Pos_Neg"] = medians.apply(brca, axis = 1)
pos_and_neg = medians.loc[medians['Pos_Neg'] == True]
brca_genes = list(pos_and_neg.index)
len(brca_genes)
# Out:
# 589

# %%
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt

# %%
venn3([set(colon_genes), set(endo_genes), set(brca_genes)], 
      set_labels = ('Colon', 'Endo', 'Brca'))

# %%
print("The intersection of colon and endo: ", list(set(colon_genes).intersection(set(endo_genes))))
print("The intersection of colon and brca: ", list(set(colon_genes).intersection(set(brca_genes))))
print("The intersection of brca and endo: ", list(set(brca_genes).intersection(set(endo_genes))))
# Out:
# The intersection of colon and endo:  ['CBLB']
# The intersection of colon and brca:  ['GABARAPL2', 'IDH3A', 'GDAP2', 'SUDS3', 'COQ8A', 'IDH3G', 'PRKAR1B', 'AIFM1', 'OXSM', 'C12orf57', 'COQ7', 'COX6C']
# The intersection of brca and endo:  ['MAPRE2', 'PCSK1', 'SMOC1', 'STEAP4', 'PARVB', 'FTH1', 'GSTM1', 'ACTR8', 'PPDPF']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import gseapy as gp
from gseapy.plot import barplot, dotplot

# %%
only_colon = set(colon_genes).difference(set(endo_genes))
only_colon = set(only_colon).difference(set(brca_genes))
len(only_colon)

only_brca = set(brca_genes).difference(set(endo_genes))
only_brca = set(only_brca).difference(set(colon_genes))
len(only_brca)

only_endo = set(endo_genes).difference(set(brca_genes))
only_endo = set(only_endo).difference(set(colon_genes))
len(only_endo)
# Out:
# 216

# %%
enr = gp.enrichr(gene_list = list(only_colon), description='up_in_colon', gene_sets='Reactome_2016', 
                       outdir='test/enrichr_kegg__pos_neg_corr')
enr.res2d
# Out:
# 2020-06-08 09:57:44,266 Warning: No enrich terms using library Reactome_2016 when cutoff = 0.05
#           Gene_set                                               Term Overlap  \
# 0    Reactome_2016  Retrograde transport at the Trans-Golgi-Networ...    3/49
# 1    Reactome_2016  Energy dependent regulation of mTOR by LKB1-AM...    2/28
# 2    Reactome_2016  Cellular response to heat stress Homo sapiens ...    3/96
# 3    Reactome_2016      Mitotic Prometaphase Homo sapiens R-HSA-68877   3/107
# 4    Reactome_2016          mTOR signalling Homo sapiens R-HSA-165159    2/39
# ..             ...                                                ...     ...
# 330  Reactome_2016  Metabolism of amino acids and derivatives Homo...   1/335
# 331  Reactome_2016      Infectious disease Homo sapiens R-HSA-5663205   1/348
# 332  Reactome_2016        Signaling by GPCR Homo sapiens R-HSA-372790  4/1293
# 333  Reactome_2016      GPCR ligand binding Homo sapiens R-HSA-500792   1/447
# 334  Reactome_2016  GPCR downstream signaling Homo sapiens R-HSA-3...   2/983
#
#       P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0    0.001068               1.0            0                     0
# 1    0.005857               1.0            0                     0
# 2    0.007217               1.0            0                     0
# 3    0.009709               1.0            0                     0
# 4    0.011153               1.0            0                     0
# ..        ...               ...          ...                   ...
# 330  0.750417               1.0            0                     0
# 331  0.763617               1.0            0                     0
# 332  0.784795               1.0            0                     0
# 333  0.843905               1.0            0                     0
# 334  0.916406               1.0            0                     0
#
#      Odds Ratio  Combined Score                 Genes
# 0     14.932802      102.166288       COG3;STX6;RAB9A
# 1     17.421603       89.547899           CAB39;MLST8
# 2      7.621951       37.585809  NUP107;MLST8;HSPA12B
# 3      6.838386       31.693570  NUP107;RAD21;CSNK2A2
# 4     12.507817       56.235669           CAB39;MLST8
# ..          ...             ...                   ...
# 330    0.728067        0.209047                  GOT2
# 331    0.700869        0.189016                NUP107
# 332    0.754532        0.182848  C3;RAP1A;ERBB3;MCF2L
# 333    0.545643        0.092604                    C3
# 334    0.496241        0.043320              C3;MCF2L
#
# [335 rows x 10 columns]

# %%
enr = gp.enrichr(gene_list = list(only_brca), description='up_in_colon', gene_sets='Reactome_2016', 
                       outdir='test/enrichr_kegg__pos_neg_corr')
enr.res2d.head(20)
# Out:
#          Gene_set                                               Term  \
# 0   Reactome_2016  Mitochondrial translation Homo sapiens R-HSA-5...
# 1   Reactome_2016  Mitochondrial translation termination Homo sap...
# 2   Reactome_2016  Mitochondrial translation initiation Homo sapi...
# 3   Reactome_2016  Mitochondrial translation elongation Homo sapi...
# 4   Reactome_2016  Organelle biogenesis and maintenance Homo sapi...
# 5   Reactome_2016  The citric acid (TCA) cycle and respiratory el...
# 6   Reactome_2016  Respiratory electron transport, ATP synthesis ...
# 7   Reactome_2016  Respiratory electron transport Homo sapiens R-...
# 8   Reactome_2016  Mitochondrial protein import Homo sapiens R-HS...
# 9   Reactome_2016              Metabolism Homo sapiens R-HSA-1430728
# 10  Reactome_2016  Pyruvate metabolism and Citric Acid (TCA) cycl...
# 11  Reactome_2016  Metabolism of amino acids and derivatives Homo...
# 12  Reactome_2016  Glyoxylate metabolism and glycine degradation ...
# 13  Reactome_2016  Citric acid cycle (TCA cycle) Homo sapiens R-H...
# 14  Reactome_2016  Mitochondrial tRNA aminoacylation Homo sapiens...
# 15  Reactome_2016  Branched-chain amino acid catabolism Homo sapi...
# 16  Reactome_2016      tRNA Aminoacylation Homo sapiens R-HSA-379724
# 17  Reactome_2016  Formation of ATP by chemiosmotic coupling Homo...
# 18  Reactome_2016       Pyruvate metabolism Homo sapiens R-HSA-70268
# 19  Reactome_2016    Complex I biogenesis Homo sapiens R-HSA-6799198
#
#      Overlap       P-value  Adjusted P-value  Old P-value  \
# 0      66/90  3.796919e-83      5.809287e-80            0
# 1      64/84  1.610094e-82      1.231722e-79            0
# 2      63/84  1.892694e-80      9.652738e-78            0
# 3      63/84  1.892694e-80      7.239553e-78            0
# 4     72/326  2.084285e-43      6.377913e-41            0
# 5     48/153  7.104833e-37      1.811732e-34            0
# 6     32/109  6.325246e-24      1.382518e-21            0
# 7      25/88  1.392401e-18      2.662967e-16            0
# 8      20/54  1.058407e-17      1.799292e-15            0
# 9   118/1908  1.897211e-16      2.902733e-14            0
# 10     17/48  7.317555e-15      1.017805e-12            0
# 11    34/335  1.387588e-10      1.769175e-08            0
# 12     10/25  6.905584e-10      8.127341e-08            0
# 13      9/19  7.964128e-10      8.703654e-08            0
# 14      9/21  2.408661e-09      2.456834e-07            0
# 15      9/23  6.365397e-09      6.086911e-07            0
# 16     11/42  1.664763e-08      1.498287e-06            0
# 17      7/16  1.299289e-07      1.104395e-05            0
# 18      8/27  5.478564e-07      4.411686e-05            0
# 19     10/49  9.408276e-07      7.197331e-05            0
#
#     Old Adjusted P-value  Odds Ratio  Combined Score  \
# 0                      0   25.867137     4909.074895
# 1                      0   26.874948     5061.511644
# 2                      0   26.455026     4856.317630
# 3                      0   26.455026     4856.317630
# 4                      0    7.790437      765.618720
# 5                      0   11.066155      921.089997
# 6                      0   10.355484      553.164017
# 7                      0   10.020843      412.012004
# 8                      0   13.064211      510.643175
# 9                      0    2.181477       78.971586
# 10                     0   12.492651      406.617066
# 11                     0    3.579984       81.259485
# 12                     0   14.109347      297.615811
# 13                     0   16.708438      350.056867
# 14                     0   15.117158      299.987829
# 15                     0   13.802622      260.488464
# 16                     0    9.238263      165.466514
# 17                     0   15.432099      244.695660
# 18                     0   10.451368      150.680019
# 19                     0    7.198647       99.892063
#
#                                                 Genes
# 0   MRPS15;MRPS16;GFM2;MRPS12;MRPL38;MRPL39;MRPS10...
# 1   MRPS15;MRPS16;GFM2;MRPS12;MRPL38;MRPL39;MRPS10...
# 2   MRPS15;MRPS16;MRPS12;MRPL38;MRPL39;MRPS10;MRPL...
# 3   MRPS15;MRPS16;MRPS12;MRPL38;MRPL39;MRPS10;MRPL...
# 4   MRPS15;MRPS16;GFM2;MRPS12;MRPL38;MRPL39;MRPS10...
# 5   ATP5S;COX19;COX7B;UQCRB;ATP5A1;ATP5C1;ATP5J;DL...
# 6   ATP5S;COX19;COX7B;UQCRB;ATP5A1;ATP5C1;ATP5J;ET...
# 7   COX19;COX7B;UQCRB;ETFA;ETFB;ECSIT;COX6A1;COX5B...
# 8   HSPA9;DNAJC19;COX19;TIMM8A;TOMM40;TIMM9;ATP5A1...
# 9   ATP5C1;ENO2;NUDT5;COX6A1;GLS;GCSH;PSMD9;ABHD10...
# 10  PDHX;PDHA1;MDH2;DLST;PDHB;SDHA;LDHB;PDPR;SUCLA...
# 11  GCDH;PSMD12;HIBADH;TAT;DLST;PDHB;HSD17B10;GLS;...
# 12  GCSH;PDHX;PDHA1;DBT;OGDH;DLST;PDHB;DLAT;DLD;DH...
# 13   SUCLA2;MDH2;IDH3B;OGDH;DLST;SUCLG1;ACO2;SDHA;DLD
# 14  LARS2;SARS2;KARS;MARS2;PARS2;NARS2;VARS2;CARS2...
# 15  HIBADH;AUH;IVD;MCCC1;DBT;HSD17B10;DLD;HIBCH;ACAT1
# 16  YARS;LARS2;SARS2;KARS;PPA1;PARS2;MARS2;NARS2;V...
# 17        ATP5S;ATP5B;ATP5A1;ATP5C1;ATP5J;ATP5H;ATP5O
# 18            LDHB;PDHX;PDPR;PDHA1;PDHB;DLAT;HAGH;DLD
# 19  NDUFA7;NDUFA6;NDUFAF7;NDUFAF2;NDUFC2;NDUFC1;ND...

# %%
enr = gp.enrichr(gene_list = list(only_endo), description='up_in_colon', gene_sets='Reactome_2016', 
                       outdir='test/enrichr_kegg__pos_neg_corr')
enr.res2d
# Out:
#           Gene_set                                               Term  \
# 0    Reactome_2016    Laminin interactions Homo sapiens R-HSA-3000157
# 1    Reactome_2016            Axon guidance Homo sapiens R-HSA-422475
# 2    Reactome_2016  Extracellular matrix organization Homo sapiens...
# 3    Reactome_2016   Developmental Biology Homo sapiens R-HSA-1266738
# 4    Reactome_2016      Collagen formation Homo sapiens R-HSA-1474290
# ..             ...                                                ...
# 602  Reactome_2016  Post-translational protein modification Homo s...
# 603  Reactome_2016  Generic Transcription Pathway Homo sapiens R-H...
# 604  Reactome_2016  GPCR downstream signaling Homo sapiens R-HSA-3...
# 605  Reactome_2016           Gene Expression Homo sapiens R-HSA-74160
# 606  Reactome_2016  Transmembrane transport of small molecules Hom...
#
#      Overlap       P-value  Adjusted P-value  Old P-value  \
# 0       6/23  1.281744e-07          0.000196            0
# 1     21/515  2.039402e-07          0.000156            0
# 2     15/283  4.791302e-07          0.000244            0
# 3     25/786  1.420606e-06          0.000543            0
# 4       7/85  3.759602e-05          0.011504            0
# ..       ...           ...               ...          ...
# 602    3/521  9.229476e-01          1.000000            0
# 603    5/812  9.414143e-01          1.000000            0
# 604    6/983  9.575112e-01          1.000000            0
# 605  10/1631  9.849200e-01          1.000000            0
# 606    1/594  9.985645e-01          1.000000            0
#
#      Old Adjusted P-value  Odds Ratio  Combined Score  \
# 0                       0   24.154589      383.330298
# 1                       0    3.775620       58.165089
# 2                       0    4.907735       71.413886
# 3                       0    2.945057       39.653505
# 4                       0    7.625272       77.690943
# ..                    ...         ...             ...
# 602                     0    0.533163        0.042750
# 603                     0    0.570151        0.034421
# 604                     0    0.565163        0.024538
# 605                     0    0.567704        0.008626
# 606                     0    0.155880        0.000224
#
#                                                  Genes
# 0                   LAMA2;LAMC3;LAMA1;LAMB1;LAMC1;NID1
# 1    PDGFRA;PRNP;LAMA1;LAMB1;AP2B1;ARPC5;LAMC1;RPS6...
# 2    COL28A1;LAMA2;LAMC3;LAMA1;MMP3;LAMB1;LAMC1;NID...
# 3    SMARCD3;LAMA1;LAMC1;FOXO1;RPS6KA4;AKT2;GPC1;AP...
# 4     COL28A1;COL1A1;ADAMTS2;COL1A2;COL5A1;MMP3;COL6A3
# ..                                                 ...
# 602                                  ADAMTS2;MITF;GAS6
# 603                  ZNF331;NOTCH2;SMARCD3;AKT2;GTF2H3
# 604                PIK3CA;AKT2;PDE2A;ARHGEF1;SOS1;JAK1
# 605  ZNF331;NOTCH2;SMARCD3;AKT2;MAPKAPK2;SNRPE;ADAR...
# 606                                               ANO6
#
# [607 rows x 10 columns]

# %%
brca = sig.drop(columns=['Difference_In_Median_Endo', 'P_Value_Endo','Difference_In_Median','P_Value'])
brca['cancer_type'] = "brca"
brca.columns = ['Difference_In_Median', 'P_Value','cancer_type']
brca.head()

endo = sig.drop(columns=['Difference_In_Median_Brca', 'P_Value_Brca','Difference_In_Median','P_Value'])
endo['cancer_type'] = "endo"
endo.columns = ['Difference_In_Median', 'P_Value','cancer_type']
endo.head()

colon = sig.drop(columns=['Difference_In_Median_Brca', 'P_Value_Brca','Difference_In_Median_Endo','P_Value_Endo'])
colon['cancer_type'] = "colon"
colon.head()

c_and_e = colon.append(endo)
df = c_and_e.append(brca)

df["comparison"] = df.index
df
# Out:
#           Difference_In_Median   P_Value cancer_type comparison
# A2ML1                      NaN       NaN       colon      A2ML1
# AADAT                      NaN       NaN       colon      AADAT
# AAGAB                   0.1390  0.039189       colon      AAGAB
# AASDHPPT                   NaN       NaN       colon   AASDHPPT
# AATF                       NaN       NaN       colon       AATF
# ...                        ...       ...         ...        ...
# ZNF654                  0.4929  0.048872        brca     ZNF654
# ZNF768                     NaN       NaN        brca     ZNF768
# ZNHIT3                     NaN       NaN        brca     ZNHIT3
# ZNRD1                      NaN       NaN        brca      ZNRD1
# ZW10                    0.6900  0.002517        brca       ZW10
#
# [4014 rows x 4 columns]

# %%
get = df['comparison'].isin(brca_genes)
brca_df = df[get]
brca_df.head()
# Out:
#         Difference_In_Median  P_Value cancer_type comparison
# AADAT                    NaN      NaN       colon      AADAT
# AATF                     NaN      NaN       colon       AATF
# ABHD10                   NaN      NaN       colon     ABHD10
# ABRACL                   NaN      NaN       colon     ABRACL
# ACADM                    NaN      NaN       colon      ACADM

# %%
plot_utils.plotCircleHeatMap(brca_df, circle_var = 'P_Value', color_var='Difference_In_Median', y_axis= 'comparison', x_axis = 'cancer_type',
                   plot_width=700)
# Out:
# /Users/hannahboekweg/anaconda3/lib/python3.7/site-packages/plot_utils/__init__.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["size2"] = df[circle_var].apply(lambda x: -1*(np.log(x)))
# /Users/hannahboekweg/anaconda3/lib/python3.7/site-packages/plot_utils/__init__.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['size'] = (df["size2"])*3
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1029">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="7696a476-a890-40a8-ab45-e82bb02ea116" data-root-id="1004"></div>

# %%
get = df['comparison'].isin(endo_genes)
endo_df = df[get]
endo_df.head()
# Out:
#          Difference_In_Median  P_Value cancer_type comparison
# ABL1                      NaN      NaN       colon       ABL1
# ACE                       NaN      NaN       colon        ACE
# ACP5                      NaN      NaN       colon       ACP5
# ACTR8                     NaN      NaN       colon      ACTR8
# ADAMTS2                   NaN      NaN       colon    ADAMTS2

# %%
plot_utils.plotCircleHeatMap(endo_df, circle_var = 'P_Value', color_var='Difference_In_Median', y_axis= 'comparison', x_axis = 'cancer_type',
                   plot_width=700)
# Out:
# /Users/hannahboekweg/anaconda3/lib/python3.7/site-packages/plot_utils/__init__.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["size2"] = df[circle_var].apply(lambda x: -1*(np.log(x)))
# /Users/hannahboekweg/anaconda3/lib/python3.7/site-packages/plot_utils/__init__.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['size'] = (df["size2"])*3
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1128">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1e5c5990-cb8f-40ba-83c2-569a3398b8a1" data-root-id="1103"></div>

# %%
get = df['comparison'].isin(colon_genes)
colon_df = df[get]
colon_df.head()
# Out:
#          Difference_In_Median   P_Value cancer_type comparison
# ABHD16A               -0.1912  0.035684       colon    ABHD16A
# ACOT9                 -0.2495  0.029555       colon      ACOT9
# AIFM1                 -0.2925  0.045817       colon      AIFM1
# APPL2                 -0.2115  0.017324       colon      APPL2
# ARL8B                 -0.2673  0.041403       colon      ARL8B

# %%
plot_utils.plotCircleHeatMap(colon_df, circle_var = 'P_Value', color_var='Difference_In_Median', y_axis= 'comparison', x_axis = 'cancer_type',
                   plot_width=700)
# Out:
# /Users/hannahboekweg/anaconda3/lib/python3.7/site-packages/plot_utils/__init__.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["size2"] = df[circle_var].apply(lambda x: -1*(np.log(x)))
# /Users/hannahboekweg/anaconda3/lib/python3.7/site-packages/plot_utils/__init__.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['size'] = (df["size2"])*3
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1237">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f8782b9d-8a2a-4175-b9f5-afe8383d7b1a" data-root-id="1212"></div>
