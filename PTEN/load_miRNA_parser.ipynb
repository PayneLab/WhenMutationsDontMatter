# %% [markdown]
# ## miRNA for datafreeze

# %% [markdown]
# This notebook combines the miRNA data from the WashU pipeline. The format of the output file is for the datafreeze according to Yize's instructions: rows are miRNA identifiers and columns are Patient_IDs. Normal samples have a ".A" appended to the Patient_ID and tumor samples have a ".T". Replicates have a ".1" appended to the Patient_ID.

# %%
import pandas as pd
import numpy as np
import warnings
from functools import reduce
import re
import glob

# %%
def average_replicates(df, common = '\.', to_drop = '\.\d$'):
    """Returns a df with one row for each patient_ID (all replicates for a patient are averaged)

    Parameters:
    df (pandas.DataFrame): The df containing replicates (duplicate entries for the same tissue_type).
    common: regex string that is common between replicates (identifies duplicate entries)
    to_drop: regex string to drop to find each patient_ID that has replicates (used to slice out all replicates)
    
    Returns:
    pandas.DataFrame: df with with replicate rows averaged and one row for each patient_ID.
    """
    replicate_df = df[df.index.str.contains(common)]
    patient_ids = pd.Series(replicate_df.index) # create series of replicate IDs to prep removing appended ".i"
    ids = patient_ids.replace(to_drop, '', regex=True)
    id_list = list(set(ids)) #id_list contains only patient_IDs of replicates (without #s)

    for patient_ID in id_list:
        id_df = df[df.index.str.contains(patient_ID)] # slice out replicates for a single patient
        vals = list(id_df.mean(axis=0)) 
        df.loc[patient_ID] = vals # add new row to original df with averages of replicates 

    df = df[~ df.index.str.contains(common)] # drop unaveraged replicate cols (averaged rows are kept)
    return df

# %%
''' Adds '_i' to duplicate col names where the int i increases by one with each duplicate 
Returns a df with unique column names. '''

def rename_duplicate_index(df):
    cols = pd.Series(df.index[:])

    for dup in cols[cols.duplicated()].unique(): 
        cols[cols[cols == dup].index.values.tolist()] = [dup + '.' + str(i) if i != 0 else dup for i in range(sum(cols == dup))]

    # rename the columns with the cols list.
    df.index=cols
    return df

# %%
ca = 'PDA'

# %%
file_path = '../../../miRNA/datafreeze/'

li = [ca+"_mature_miRNA_combined.tsv", ca+"_precursor_miRNA_combined.tsv",
                ca+"_total_miRNA_combined.tsv"]

# %%
d ={}
for file_name in li:
    if 'miRNA_combined' in file_name:
        miRNA_type = file_name.split('_')[1] # get type of miRNA data (precursor, mature, or total)
        print(miRNA_type)
        if miRNA_type == 'mature':
            df = pd.read_csv(file_path+file_name, delimiter = '\t', index_col = ['Name', 'ID','Alias', 'Derives_from'])
        else:
            df = pd.read_csv(file_path+file_name, delimiter = '\t', index_col = ['Name', 'ID','Alias'])
        df = df.transpose()
        #df = average_replicates(df, common = '\.\d$')
        
        df.index = df.index.str.replace('\.T$','', regex = True)
        df.index = df.index.str.replace('\.A$','.N', regex = True)
        df.index.name = 'Patient_ID'
        
        # Sort
        normal = df.loc[df.index.str.contains('\.N$', regex =True)]
        normal = normal.sort_values(by=["Patient_ID"])
        tumor = df.loc[~ df.index.str.contains('\.N$', regex =True)]
        tumor = tumor.sort_values(by=["Patient_ID"])
    
        d[miRNA_type+'_miRNA'] = df
# Out:
# mature
# precursor
# total

# %%
df = d['precursor_miRNA']
df
#df[df.index.str.contains('C3N-00326')]
# Out:
# Name        hsa-let-7a-1 hsa-let-7a-2 hsa-let-7a-3  hsa-let-7b  hsa-let-7c  \
# ID             MI0000060    MI0000061    MI0000062   MI0000063   MI0000064
# Alias          MI0000060    MI0000061    MI0000062   MI0000063   MI0000064
# Patient_ID
# C3L-00017     299.581512   330.466204   234.723659  271.785290  101.919484
# C3L-00102     324.193293   379.453513   187.884749  206.304823  114.204455
# C3L-00189     113.321904    98.699723    51.177634  124.288539    7.311091
# C3L-00277     315.800554   202.736158   140.355802  374.282139   35.088950
# C3L-00401      27.565675    58.577060    44.794222   99.925573   20.674256
# ...                  ...          ...          ...         ...         ...
# C3N-03069.N    74.722459          NaN    32.023911  138.770282   42.698548
# C3N-03173.N    29.848391    25.584336    36.244475   23.452308   10.660140
# C3N-03440.N    44.677671    73.108916    44.677671  113.724981    8.123213
# C3N-03780.N    79.138185    59.353639    49.461366   79.138185   13.189698
# C3N-04283.N    40.343353    71.376701    58.963362  105.513385    6.206670
#
# Name        hsa-let-7d hsa-let-7e hsa-let-7f-1 hsa-let-7f-2  hsa-let-7g  ...  \
# ID           MI0000065  MI0000066    MI0000067    MI0000068   MI0000433  ...
# Alias        MI0000065  MI0000066    MI0000067    MI0000068   MI0000433  ...
# Patient_ID                                                               ...
# C3L-00017    30.884692  12.353877   287.227636   219.281313  151.334991  ...
# C3L-00102    18.420073  33.156132   202.620808   158.412632  125.256500  ...
# C3L-00189     7.311091  32.899908    91.388632    47.522089    7.311091  ...
# C3L-00277    42.886495  19.493861   144.254574   152.052119  128.659485  ...
# C3L-00401    10.337128   6.891419    75.805607    17.228547   34.457094  ...
# ...                ...        ...          ...          ...         ...  ...
# C3N-03069.N        NaN        NaN    85.397096    21.349274   64.047822  ...
# C3N-03173.N   2.132028   4.264056    29.848391    14.924196   21.320280  ...
# C3N-03440.N  16.246426   8.123213    32.492852    24.369639   24.369639  ...
# C3N-03780.N        NaN   3.297424    75.840761    26.379395   23.081971  ...
# C3N-04283.N  34.136683   3.103335    49.653357    15.516674   12.413339  ...
#
# Name        hsa-mir-9900 hsa-mir-9901 hsa-mir-9902-1 hsa-mir-9902-2  \
# ID             MI0031828    MI0031829      MI0031830      MI0041071
# Alias          MI0031828    MI0031829      MI0031830      MI0041071
# Patient_ID
# C3L-00017            NaN          NaN            NaN            NaN
# C3L-00102            NaN    25.788103            NaN            NaN
# C3L-00189            NaN     3.655545            NaN            NaN
# C3L-00277            NaN     3.898772            NaN            NaN
# C3L-00401            NaN    10.337128            NaN            NaN
# ...                  ...          ...            ...            ...
# C3N-03069.N          NaN    42.698548            NaN            NaN
# C3N-03173.N          NaN     2.132028       2.132028            NaN
# C3N-03440.N          NaN     4.061606            NaN            NaN
# C3N-03780.N          NaN    19.784546            NaN            NaN
# C3N-04283.N          NaN     6.206670            NaN            NaN
#
# Name        hsa-mir-9903 hsa-mir-9983 hsa-mir-9985 hsa-mir-9986 hsa-mir-99a  \
# ID             MI0031831    MI0033670    MI0032313    MI0032316   MI0000101
# Alias          MI0031831    MI0033670    MI0032313    MI0032316   MI0000101
# Patient_ID
# C3L-00017            NaN          NaN     3.088469          NaN   49.415507
# C3L-00102            NaN          NaN          NaN          NaN   58.944235
# C3L-00189            NaN          NaN          NaN          NaN         NaN
# C3L-00277            NaN          NaN     3.898772          NaN   27.291406
# C3L-00401       3.445709          NaN          NaN          NaN   24.119966
# ...                  ...          ...          ...          ...         ...
# C3N-03069.N          NaN          NaN          NaN          NaN   10.674637
# C3N-03173.N          NaN          NaN          NaN          NaN         NaN
# C3N-03440.N          NaN          NaN          NaN          NaN    4.061606
# C3N-03780.N          NaN          NaN     6.594849          NaN   16.487122
# C3N-04283.N          NaN          NaN          NaN          NaN    6.206670
#
# Name        hsa-mir-99b
# ID            MI0000746
# Alias         MI0000746
# Patient_ID
# C3L-00017     33.973161
# C3L-00102     44.208176
# C3L-00189      7.311091
# C3L-00277     42.886495
# C3L-00401     20.674256
# ...                 ...
# C3N-03069.N   21.349274
# C3N-03173.N   10.660140
# C3N-03440.N    8.123213
# C3N-03780.N    9.892273
# C3N-04283.N   18.620009
#
# [183 rows x 1703 columns]

# %%
df = d['total_miRNA']
df
# Out:
# Name         hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3    hsa-let-7b  \
# ID              MI0000060     MI0000061     MI0000062     MI0000063
# Alias           MI0000060     MI0000061     MI0000062     MI0000063
# Patient_ID
# C3L-00017    29414.580663  29037.787421  29145.883843  11377.920534
# C3L-00102    27862.203114  27534.325807  27913.779320  11597.278250
# C3L-00189    41059.084578  40730.085503  40741.052139  15612.833888
# C3L-00277    25887.847917  25119.789778  25533.059640  13852.337899
# C3L-00401    25818.700554  26053.008793  26332.111255  11432.863798
# ...                   ...           ...           ...           ...
# C3N-03069.N  61357.813834  61315.115286  61902.220325  53768.146883
# C3N-03173.N  23906.429557  24160.140884  23859.524942   8270.136471
# C3N-03440.N  40477.969847  40689.173382  40266.766311  18500.617364
# C3N-03780.N  47413.665186  47476.316249  48178.667643  22890.720059
# C3N-04283.N  51065.374852  51462.601712  51924.998603  29652.364431
#
# Name           hsa-let-7c    hsa-let-7d    hsa-let-7e  hsa-let-7f-1  \
# ID              MI0000064     MI0000065     MI0000066     MI0000067
# Alias           MI0000064     MI0000065     MI0000066     MI0000067
# Patient_ID
# C3L-00017     5469.678954   8582.855907   7498.803218  25467.517025
# C3L-00102     5275.509039   7080.676238   8841.635260  18383.233312
# C3L-00189     5772.105996   8930.497118  14819.580563  25552.261503
# C3L-00277     5103.492910   7368.679603   7914.507722  17809.591760
# C3L-00401     3635.223420   7229.098327   7787.303250  19630.206467
# ...                   ...           ...           ...           ...
# C3N-03069.N  10194.278395  10226.302306  15147.309991  30230.572161
# C3N-03173.N   2778.032437   8182.723325   6649.795219  21910.851383
# C3N-03440.N   5726.865090   6445.769431   6616.356901  25831.817000
# C3N-03780.N   7646.727141   8306.212018  10578.137417  26742.111737
# C3N-04283.N   7345.593575   9673.094708  10641.335179  26406.276184
#
# Name         hsa-let-7f-2    hsa-let-7g  ... hsa-mir-9900 hsa-mir-9901  \
# ID              MI0000068     MI0000433  ...    MI0031828    MI0031829
# Alias           MI0000068     MI0000433  ...    MI0031828    MI0031829
# Patient_ID                               ...
# C3L-00017    25035.131337  12668.900659  ...          NaN          NaN
# C3L-00102    18342.709151   9991.047844  ...          NaN    25.788103
# C3L-00189    25537.639322   8250.565696  ...          NaN     3.655545
# C3L-00277    17139.002928  10230.378454  ...          NaN     7.797545
# C3L-00401    20205.639937  12090.994294  ...          NaN    10.337128
# ...                   ...           ...  ...          ...          ...
# C3N-03069.N  30721.605465  10322.374039  ...          NaN    53.373185
# C3N-03173.N  21516.426209  11037.508768  ...          NaN     4.264056
# C3N-03440.N  26416.688329  11697.426566  ...          NaN     4.061606
# C3N-03780.N  27075.151599  10845.228792  ...          NaN    19.784546
# C3N-04283.N  25729.749188   7665.237064  ...          NaN     9.310005
#
# Name        hsa-mir-9902-1 hsa-mir-9902-2 hsa-mir-9903 hsa-mir-9983  \
# ID               MI0031830      MI0041071    MI0031831    MI0033670
# Alias            MI0031830      MI0041071    MI0031831    MI0033670
# Patient_ID
# C3L-00017              NaN            NaN          NaN          NaN
# C3L-00102              NaN            NaN          NaN          NaN
# C3L-00189              NaN            NaN          NaN          NaN
# C3L-00277              NaN            NaN          NaN          NaN
# C3L-00401              NaN            NaN     3.445709          NaN
# ...                    ...            ...          ...          ...
# C3N-03069.N            NaN            NaN          NaN          NaN
# C3N-03173.N       2.132028            NaN          NaN          NaN
# C3N-03440.N            NaN            NaN          NaN          NaN
# C3N-03780.N            NaN            NaN          NaN          NaN
# C3N-04283.N            NaN            NaN          NaN          NaN
#
# Name        hsa-mir-9985 hsa-mir-9986  hsa-mir-99a hsa-mir-99b
# ID             MI0032313    MI0032316    MI0000101   MI0000746
# Alias          MI0032313    MI0032316    MI0000101   MI0000746
# Patient_ID
# C3L-00017      43.238569          NaN  5435.705792  200.750498
# C3L-00102      33.156132          NaN  4815.007202  232.092926
# C3L-00189      18.277726          NaN  5157.974389  149.877356
# C3L-00277      58.481584          NaN  4397.815128  916.211485
# C3L-00401      27.565675          NaN  1995.065744  182.622598
# ...                  ...          ...          ...         ...
# C3N-03069.N    74.722459          NaN  2359.094791   85.397096
# C3N-03173.N    46.904615          NaN  1396.478316   91.677202
# C3N-03440.N    77.170522          NaN  1998.310372   89.355342
# C3N-03780.N    56.056214          NaN  2318.089340  181.358341
# C3N-04283.N    34.136683          NaN  2225.091083  139.650068
#
# [183 rows x 1877 columns]

# %%
df = d['mature_miRNA']
df
# Out:
# Name         hsa-let-7a-2-3p hsa-let-7a-3p                hsa-let-7a-5p  \
# ID              MIMAT0010195  MIMAT0004481 MIMAT0004481_1  MIMAT0000062
# Alias           MIMAT0010195  MIMAT0004481   MIMAT0004481  MIMAT0000062
# Derives_from       MI0000061     MI0000062      MI0000060     MI0000061
# Patient_ID
# C3L-00017                NaN     86.477138      83.388668  28707.321216
# C3L-00102           7.368029     51.576206      51.576206  27147.504264
# C3L-00189                NaN     29.244362      51.177634  40631.385781
# C3L-00277                NaN     74.076673      62.380356  24917.053620
# C3L-00401                NaN     62.022769      55.131350  25994.431734
# ...                      ...           ...            ...           ...
# C3N-03069.N              NaN    128.095645     138.770282  61315.115286
# C3N-03173.N              NaN     55.432727      40.508531  24134.556549
# C3N-03440.N              NaN    142.156226      97.478555  40616.064466
# C3N-03780.N              NaN     59.353639      72.543336  47416.962611
# C3N-04283.N              NaN    111.720054      68.273367  51391.225010
#
# Name                                       hsa-let-7b-3p hsa-let-7b-5p  \
# ID           MIMAT0000062_1 MIMAT0000062_2  MIMAT0004482  MIMAT0000063
# Alias          MIMAT0000062   MIMAT0000062  MIMAT0004482  MIMAT0000063
# Derives_from      MI0000062      MI0000060     MI0000063     MI0000063
# Patient_ID
# C3L-00017      28824.683046   29031.610482    101.919484  11004.215760
# C3L-00102      27674.318365   27486.433616     88.416353  11302.557075
# C3L-00189      40660.630143   40894.585041    146.221811  15342.323538
# C3L-00277      25318.627164   25509.667006     74.076673  13403.979087
# C3L-00401      26225.294264   25736.003528    137.828376  11195.109849
# ...                     ...            ...           ...           ...
# C3N-03069.N    61742.100769   61144.321093    234.842015  53394.534586
# C3N-03173.N    23767.847739   23836.072634    123.657622   8123.026542
# C3N-03440.N    40079.932415   40335.813621    223.388355  18163.504029
# C3N-03780.N    48069.852638   47261.983665    220.927434  22590.654440
# C3N-04283.N    51754.315187   50956.758132    279.300136  29267.550910
#
# Name         hsa-let-7c-3p hsa-let-7c-5p  ... hsa-miR-9899 hsa-miR-9901  \
# ID            MIMAT0026472  MIMAT0000064  ... MIMAT0039319 MIMAT0039321
# Alias         MIMAT0026472  MIMAT0000064  ... MIMAT0039319 MIMAT0039321
# Derives_from     MI0000064     MI0000064  ...    MI0031827    MI0031829
# Patient_ID                                ...
# C3L-00017        12.353877   5355.405593  ...          NaN          NaN
# C3L-00102              NaN   5161.304583  ...          NaN          NaN
# C3L-00189        10.966636   5753.828270  ...          NaN          NaN
# C3L-00277              NaN   5068.403960  ...          NaN     3.898772
# C3L-00401              NaN   3614.549163  ...          NaN          NaN
# ...                    ...           ...  ...          ...          ...
# C3N-03069.N            NaN  10151.579846  ...          NaN    10.674637
# C3N-03173.N       2.132028   2765.240269  ...          NaN     2.132028
# C3N-03440.N       4.061606   5714.680270  ...          NaN          NaN
# C3N-03780.N            NaN   7633.537444  ...          NaN          NaN
# C3N-04283.N            NaN   7339.386905  ...          NaN     3.103335
#
# Name         hsa-miR-9903 hsa-miR-9983-3p hsa-miR-9985 hsa-miR-9986  \
# ID           MIMAT0039323    MIMAT0041993 MIMAT0039763 MIMAT0039766
# Alias        MIMAT0039323    MIMAT0041993 MIMAT0039763 MIMAT0039766
# Derives_from    MI0031831       MI0033670    MI0032313    MI0032316
# Patient_ID
# C3L-00017             NaN             NaN    40.150100          NaN
# C3L-00102             NaN             NaN    33.156132          NaN
# C3L-00189             NaN             NaN    18.277726          NaN
# C3L-00277             NaN             NaN    54.582812          NaN
# C3L-00401             NaN             NaN    27.565675          NaN
# ...                   ...             ...          ...          ...
# C3N-03069.N           NaN             NaN    74.722459          NaN
# C3N-03173.N           NaN             NaN    46.904615          NaN
# C3N-03440.N           NaN             NaN    77.170522          NaN
# C3N-03780.N           NaN             NaN    49.461366          NaN
# C3N-04283.N           NaN             NaN    34.136683          NaN
#
# Name         hsa-miR-99a-3p hsa-miR-99a-5p hsa-miR-99b-3p hsa-miR-99b-5p
# ID             MIMAT0004511   MIMAT0000097   MIMAT0004678   MIMAT0000689
# Alias          MIMAT0004511   MIMAT0000097   MIMAT0004678   MIMAT0000689
# Derives_from      MI0000101      MI0000101      MI0000746      MI0000746
# Patient_ID
# C3L-00017         71.034792    5315.255494      15.442346     151.334991
# C3L-00102         99.468397    4656.594570      44.208176     143.676573
# C3L-00189         18.277726    5139.696663      40.210998     102.355268
# C3L-00277         27.291406    4343.232316      27.291406     846.033584
# C3L-00401         10.337128    1960.608650      55.131350     106.816991
# ...                     ...            ...            ...            ...
# C3N-03069.N       32.023911    2316.396243            NaN      64.047822
# C3N-03173.N       10.660140    1385.818176      23.452308      57.564755
# C3N-03440.N        8.123213    1986.125552      12.184819      69.047310
# C3N-03780.N        9.892273    2291.709945      65.948488     105.517580
# C3N-04283.N       15.516674    2203.367739      12.413339     108.616720
#
# [183 rows x 2386 columns]

# %%
df
df.index = df.index.str.replace('\.T$','', regex = True)
df.index = df.index.str.replace('\.A$','.N', regex = True)
df
# Out:
# Name         hsa-let-7a-2-3p hsa-let-7a-3p                hsa-let-7a-5p  \
# ID              MIMAT0010195  MIMAT0004481 MIMAT0004481_1  MIMAT0000062
# Alias           MIMAT0010195  MIMAT0004481   MIMAT0004481  MIMAT0000062
# Derives_from       MI0000061     MI0000062      MI0000060     MI0000061
# Patient_ID
# C3L-00104                NaN    125.272610     108.189982  38561.187129
# C3L-00365                NaN     28.594917      39.318011  21299.638989
# C3L-00674                NaN     15.936594      21.248791  30869.181815
# C3L-00677                NaN      6.501063      19.503189  21290.981075
# C3L-01040                NaN     56.855655      45.484524  21667.690068
# ...                      ...           ...            ...           ...
# C3N-03183                NaN     61.862685      41.241790  29680.341757
# C3N-03184                NaN     66.734428      77.001263  28339.031427
# C3N-03186                NaN     37.422193      70.686365  27767.267224
# C3N-03188                NaN     67.080035      37.914803  17878.287651
# C3N-03473          12.479136     77.994603      43.676978  16771.959380
#
# Name                                       hsa-let-7b-3p hsa-let-7b-5p  \
# ID           MIMAT0000062_1 MIMAT0000062_2  MIMAT0004482  MIMAT0000063
# Alias          MIMAT0000062   MIMAT0000062  MIMAT0004482  MIMAT0000063
# Derives_from      MI0000062      MI0000060     MI0000063     MI0000063
# Patient_ID
# C3L-00104      38549.798710   38709.236577    216.379963  22133.392553
# C3L-00365      21760.732030   22161.060871     89.359116  12767.630554
# C3L-00674      29982.044771   30502.640162     69.058572  15442.559204
# C3L-00677      20978.930055   21466.509774    117.019133   8373.369046
# C3L-01040      20883.082031   21633.576676     68.226786   7175.183644
# ...                     ...            ...           ...           ...
# C3N-03183      29195.750721   28645.860183    134.035818   8468.314276
# C3N-03184      28362.131806   27856.490180    128.335438  11624.623977
# C3N-03186      28029.222575   27343.149036    108.108558  12174.686797
# C3N-03188      17910.369407   17621.633603     81.662652   6801.332268
# C3N-03473      16263.434570   16285.273059     74.874819   3940.287332
#
# Name         hsa-let-7c-3p hsa-let-7c-5p  ... hsa-miR-98-5p hsa-miR-9851-5p  \
# ID            MIMAT0026472  MIMAT0000064  ...  MIMAT0000096    MIMAT0048639
# Alias         MIMAT0026472  MIMAT0000064  ...  MIMAT0000096    MIMAT0048639
# Derives_from     MI0000064     MI0000064  ...     MI0000100       MI0039502
# Patient_ID                                ...
# C3L-00104              NaN   8063.000735  ...    609.280423             NaN
# C3L-00365         7.148729   7420.381027  ...    368.159560             NaN
# C3L-00674         5.312198   8972.302200  ...    605.590557             NaN
# C3L-00677              NaN   7612.744684  ...    721.617985             NaN
# C3L-01040        11.371131   4804.302836  ...    466.216370             NaN
# ...                    ...           ...  ...           ...             ...
# C3N-03183         3.436816   7213.876488  ...    780.157200             NaN
# C3N-03184         5.133418   5510.723709  ...    372.172770             NaN
# C3N-03186         4.158021   3966.752461  ...    573.806960             NaN
# C3N-03188              NaN   2726.949258  ...    784.544760             NaN
# C3N-03473        12.479136   2227.525855  ...    408.691719             NaN
#
# Name         hsa-miR-9899 hsa-miR-9901 hsa-miR-9983-3p hsa-miR-9985  \
# ID           MIMAT0039319 MIMAT0039321    MIMAT0041993 MIMAT0039763
# Alias        MIMAT0039319 MIMAT0039321    MIMAT0041993 MIMAT0039763
# Derives_from    MI0031827    MI0031829       MI0033670    MI0032313
# Patient_ID
# C3L-00104             NaN          NaN             NaN          NaN
# C3L-00365             NaN          NaN             NaN     3.574365
# C3L-00674             NaN          NaN             NaN    10.624396
# C3L-00677             NaN          NaN             NaN     6.501063
# C3L-01040             NaN     5.685565             NaN    11.371131
# ...                   ...          ...             ...          ...
# C3N-03183             NaN          NaN             NaN    27.494527
# C3N-03184             NaN          NaN             NaN     2.566709
# C3N-03186        4.158021     8.316043             NaN     4.158021
# C3N-03188             NaN          NaN             NaN     2.916523
# C3N-03473             NaN          NaN             NaN     6.239568
#
# Name         hsa-miR-99a-3p hsa-miR-99a-5p hsa-miR-99b-3p hsa-miR-99b-5p
# ID             MIMAT0004511   MIMAT0000097   MIMAT0004678   MIMAT0000689
# Alias          MIMAT0004511   MIMAT0000097   MIMAT0004678   MIMAT0000689
# Derives_from      MI0000101      MI0000101      MI0000746      MI0000746
# Patient_ID
# C3L-00104        182.214706    5540.465900      11.388419     222.074173
# C3L-00365        225.184973    7445.401580      60.764199     175.143868
# C3L-00674         84.995166   11357.479043      58.434177    2204.562116
# C3L-00677         97.515944   13073.637540     182.029762     143.023384
# C3L-01040         85.283482    4400.627686      79.597917     216.051488
# ...                     ...            ...            ...            ...
# C3N-03183        158.093530    9399.691374      44.678606     175.277609
# C3N-03184        125.768729    6873.646061      84.701389      77.001263
# C3N-03186         74.844386    2956.353249      66.528343     174.636901
# C3N-03188         49.580896    2219.474209     134.160070     166.241826
# C3N-03473         62.395682    3497.277988      56.156114     124.791364
#
# [98 rows x 2067 columns]

# %%
elif 'miRNA_combined' in file_name:
                miRNA_type = file_name.split('_')[1] # get type of miRNA data (precursor, mature, or total)
                if miRNA_type == 'mature':
                    df = pd.read_csv(file_path, delimiter = '\t', index_col = ['Name', 'ID','Alias', 'Derives_from'])
                else:
                    df = pd.read_csv(file_path, delimiter = '\t', index_col = ['Name', 'ID','Alias'])
                df = df.transpose()
                df.index = df.index.str.replace('\.T$','', regex = True)
                df.index = df.index.str.replace('\.A$','.N', regex = True)
                df.index.name = 'Patient_ID'                
                # Sort
                normal = df.loc[df.index.str.contains('\.N$', regex =True)]
                normal = normal.sort_values(by=["Patient_ID"])
                tumor = df.loc[~ df.index.str.contains('\.N$', regex =True)]
                tumor = tumor.sort_values(by=["Patient_ID"])
                all_df = tumor.append(normal)
                self._data[miRNA_type+'_miRNA'] = all_df
                
            elif file_name == "GBM_xCell.txt":
                df = pd.read_csv(file_path, sep = '\t', index_col = 0) 
                df = df.transpose()
                df.columns.name = 'Name'
                df.index.name = 'Patient_ID'
                df.index = df.index.str.replace(r'-T$', '', regex=True) # remove label for tumor samples
                df.index = df.index.str.replace(r'-A$', '.N', regex=True) # change label for normal samples
                self._data["xcell"] = df
                
            elif file_name == "CIBERSORT.Output_Abs_GBM.txt":
                df = pd.read_csv(file_path, sep = '\t', index_col = 0) 
                df.index.name = 'Patient_ID'
                df.columns.name = 'Name'
                df.index = df.index.str.replace(r'-T$', '', regex=True) 
                df.index = df.index.str.replace(r'-A$', '.N', regex=True)
                self._data["cibersort"] = df

# %%
d['total_miRNA']
# Out:
# Empty DataFrame
# Columns: [(hsa-let-7a-1, MI0000060, MI0000060), (hsa-let-7a-2, MI0000061, MI0000061), (hsa-let-7a-3, MI0000062, MI0000062), (hsa-let-7b, MI0000063, MI0000063), (hsa-let-7c, MI0000064, MI0000064), (hsa-let-7d, MI0000065, MI0000065), (hsa-let-7e, MI0000066, MI0000066), (hsa-let-7f-1, MI0000067, MI0000067), (hsa-let-7f-2, MI0000068, MI0000068), (hsa-let-7g, MI0000433, MI0000433), (hsa-let-7i, MI0000434, MI0000434), (hsa-mir-1-1, MI0000651, MI0000651), (hsa-mir-1-2, MI0000437, MI0000437), (hsa-mir-100, MI0000102, MI0000102), (hsa-mir-101-1, MI0000103, MI0000103), (hsa-mir-101-2, MI0000739, MI0000739), (hsa-mir-10226, MI0033056, MI0033056), (hsa-mir-10392, MI0033416, MI0033416), (hsa-mir-10393, MI0033417, MI0033417), (hsa-mir-10394, MI0033418, MI0033418), (hsa-mir-10395, MI0033419, MI0033419), (hsa-mir-10396a, MI0033420, MI0033420), (hsa-mir-10396b, MI0033426, MI0033426), (hsa-mir-10397, MI0033421, MI0033421), (hsa-mir-10398, MI0033422, MI0033422), (hsa-mir-10399, MI0033423, MI0033423), (hsa-mir-103a-1, MI0000109, MI0000109), (hsa-mir-103a-2, MI0000108, MI0000108), (hsa-mir-10400, MI0033424, MI0033424), (hsa-mir-10401, MI0033425, MI0033425), (hsa-mir-10401, MI0033425_2, MI0033425), (hsa-mir-10401, MI0033425_3, MI0033425), (hsa-mir-10401, MI0033425_4, MI0033425), (hsa-mir-105-1, MI0000111, MI0000111), (hsa-mir-105-2, MI0000112, MI0000112), (hsa-mir-10522, MI0033668, MI0033668), (hsa-mir-10523, MI0033669, MI0033669), (hsa-mir-10525, MI0033672, MI0033672), (hsa-mir-10526, MI0033673, MI0033673), (hsa-mir-10527, MI0033674, MI0033674), (hsa-mir-106a, MI0000113, MI0000113), (hsa-mir-106b, MI0000734, MI0000734), (hsa-mir-107, MI0000114, MI0000114), (hsa-mir-10a, MI0000266, MI0000266), (hsa-mir-10b, MI0000267, MI0000267), (hsa-mir-11181, MI0035972, MI0035972), (hsa-mir-11399, MI0036558, MI0036558), (hsa-mir-11400, MI0036559, MI0036559), (hsa-mir-11401, MI0036560, MI0036560), (hsa-mir-1178, MI0006271, MI0006271), (hsa-mir-1179, MI0006272, MI0006272), (hsa-mir-1180, MI0006273, MI0006273), (hsa-mir-1181, MI0006274, MI0006274), (hsa-mir-1182, MI0006275, MI0006275), (hsa-mir-1183, MI0006276, MI0006276), (hsa-mir-1184-1, MI0006277, MI0006277), (hsa-mir-1184-2, MI0015971, MI0015971), (hsa-mir-1184-3, MI0015972, MI0015972), (hsa-mir-1185-1, MI0003844, MI0003844), (hsa-mir-1185-2, MI0003821, MI0003821), (hsa-mir-1193, MI0014205, MI0014205), (hsa-mir-1197, MI0006656, MI0006656), (hsa-mir-1199, MI0020340, MI0020340), (hsa-mir-1200, MI0006332, MI0006332), (hsa-mir-1202, MI0006334, MI0006334), (hsa-mir-1203, MI0006335, MI0006335), (hsa-mir-1204, MI0006337, MI0006337), (hsa-mir-1206, MI0006339, MI0006339), (hsa-mir-1207, MI0006340, MI0006340), (hsa-mir-1208, MI0006341, MI0006341), (hsa-mir-12113, MI0039715, MI0039715), (hsa-mir-12114, MI0039716, MI0039716), (hsa-mir-12115, MI0039717, MI0039717), (hsa-mir-12116, MI0039718, MI0039718), (hsa-mir-12117, MI0039719, MI0039719), (hsa-mir-12118, MI0039720, MI0039720), (hsa-mir-12119, MI0039721, MI0039721), (hsa-mir-12120, MI0039722, MI0039722), (hsa-mir-12121, MI0039723, MI0039723), (hsa-mir-12122, MI0039724, MI0039724), (hsa-mir-12124, MI0039726, MI0039726), (hsa-mir-12125, MI0039727, MI0039727), (hsa-mir-12126, MI0039728, MI0039728), (hsa-mir-12127, MI0039729, MI0039729), (hsa-mir-12128, MI0039730, MI0039730), (hsa-mir-12129, MI0039731, MI0039731), (hsa-mir-12131, MI0039733, MI0039733), (hsa-mir-12132, MI0039734, MI0039734), (hsa-mir-12133, MI0039735, MI0039735), (hsa-mir-12135, MI0039739, MI0039739), (hsa-mir-12136, MI0039740, MI0039740), (hsa-mir-122, MI0000442, MI0000442), (hsa-mir-1224, MI0003764, MI0003764), (hsa-mir-1225, MI0006311, MI0006311), (hsa-mir-1226, MI0006313, MI0006313), (hsa-mir-1227, MI0006316, MI0006316), (hsa-mir-1228, MI0006318, MI0006318), (hsa-mir-1229, MI0006319, MI0006319), (hsa-mir-122b, MI0017383, MI0017383), (hsa-mir-1231, MI0006321, MI0006321), ...]
# Index: []
#
# [0 rows x 1795 columns]

# %% [markdown]
# # Test created files

# %%
import cptac.pancan as pc

# %%
g = pc.PancanGbm()
l = pc.PancanLuad()
ls = pc.PancanLscc()
e = pc.PancanUcec()
r = pc.PancanCcrcc()
h = pc.PancanHnscc()
b = pc.PancanBrca()
o = pc.PancanOv()
c = pc.PancanCoad()
# Out:
# ---------------------------------------------------------------------------
# MissingFileError                          Traceback (most recent call last)
# <ipython-input-82-670967670e32> in <module>
#       5 r = pc.PancanCcrcc()
#       6 h = pc.PancanHnscc()
# ----> 7 b = pc.PancanBrca()
#       8 o = pc.PancanOv()
#       9 c = pc.PancanCoad()
#
# ~/anaconda3/lib/python3.8/site-packages/cptac/pancan/pancanbrca.py in __init__(self, versions, no_internet)
#      42         #self._datasets["pdc"] = PdcBrca(no_internet=no_internet, version=get_version("pdc"))
#      43         self._datasets["umich"] = UmichBrca(no_internet=no_internet, version=get_version("umich"))
# ---> 44         self._datasets["washu"] = WashuBrca(no_internet=no_internet, version=get_version("washu"))
#
# ~/anaconda3/lib/python3.8/site-packages/cptac/pancan/washubrca.py in __init__(self, no_internet, version)
#      47
#      48         # Call the parent class __init__ function
# ---> 49         super().__init__(cancer_type="washubrca", version=version, valid_versions=valid_versions, data_files=data_files, no_internet=no_internet)
#      50
#      51         # Load the data into dataframes in the self._data dict
#
# ~/anaconda3/lib/python3.8/site-packages/cptac/dataset.py in __init__(self, cancer_type, version, valid_versions, data_files, no_internet, attempt_update_index)
#      52         # Get the paths to the data files
#      53         version_data_files = data_files[self._version] # Get the data files for this version from the data files dictionary
# ---> 54         self._data_files_paths = get_version_files_paths(self._cancer_type, self._version, version_data_files)
#      55
#      56         # Initialize dataframe and definitions dicts as empty for this parent class
#
# ~/anaconda3/lib/python3.8/site-packages/cptac/file_tools.py in get_version_files_paths(dataset, version, data_files)
#     108         file_path = os.path.join(version_path, data_file)
#     109         if not os.path.isfile(file_path): # Check that the file exists
# --> 110             raise MissingFileError(f"Missing data file '{data_file}'. Call \"cptac.download(dataset='{dataset}', version='{version}')\" to download it. Dataset loading aborted.")
#     111         data_files_paths.append(file_path)
#     112
#
# MissingFileError: Missing data file 'BR_prospective.dnp.annotated.exonic.addrecovercases.maf.gz'. Call "cptac.download(dataset='washubrca', version='1.0')" to download it. Dataset loading aborted.

# %%
pc.pancan_download('pancanbrca')
# Out:
# Please login to Box on the webpage that was just opened and grant access for cptac to download files through your account. If you accidentally closed the browser window, press Ctrl+C and call the download function again.

# %%
b = pc.PancanBrca()

# %%
ca = b

# %%
xc = ca.get_deconvolution('washu','xcell')
ciber = ca.get_deconvolution('washu','cibersort')
# Out:
# ---------------------------------------------------------------------------
# DataSourceNotFoundError                   Traceback (most recent call last)
# <ipython-input-93-b5430015150e> in <module>
# ----> 1 xc = ca.get_deconvolution('washu','xcell')
#       2 ciber = ca.get_deconvolution('washu','cibersort')
#
# ~/anaconda3/lib/python3.8/site-packages/cptac/pancan/pancandataset.py in get_deconvolution(self, decon_type, source, tissue_type, imputed)
#      65     def get_deconvolution(self, source, decon_type, tissue_type="both", imputed=False):
#      66         """Get a deconvolution dataframe from the specified data source."""
# ---> 67         return self._get_dataframe(decon_type, source, tissue_type, imputed=imputed)
#      68
#      69     # Help functions
#
# ~/anaconda3/lib/python3.8/site-packages/cptac/pancan/pancandataset.py in _get_dataframe(self, name, source, tissue_type, imputed)
#      86             return self._datasets[source]._get_dataframe(name, tissue_type)
#      87         else:
# ---> 88             raise ex.DataSourceNotFoundError(f"Data source {source} not found for the {self._cancer_type} dataset.")
#
# DataSourceNotFoundError: Data source xcell not found for the pancanbrca dataset.

# %%
decon = {'xcell':xc, 'cibersort':ciber}

for decon_type in decon:
    print(decon_type)
    df = xc
    print('num IDs:', len(df.index))
    # check tumor/normal counts
    tumor = df.loc[~ df.index.str.contains('\.N$', regex = True)]
    print('Tumor:', len(tumor))
    normal = df.loc[df.index.str.contains('\.N$', regex = True)]
    print('Normal:', len(normal))

    # check for duplicate indices 
    if True in (df.index.duplicated()):
        print('Duplicates present')
    else:
        print('NO dup index')

    print('\n')

# %%
pre = ca.get_miRNA('washu', 'precursor')
mat = ca.get_miRNA('washu', 'mature')
tot = ca.get_miRNA('washu', 'total')

all_list = {'precursor':pre, 'mature':mat, 'total':tot}

# %%
for miRNA_type in all_list:
    df = all_list[miRNA_type]
    print(miRNA_type)
    print(df.columns.names)
    
    print('num IDs:', len(df.index))
    # check tumor/normal counts
    tumor = df.loc[~ df.index.str.contains('\.N$', regex = True)]
    print('Tumor:', len(tumor))
    normal = df.loc[df.index.str.contains('\.N$', regex = True)]
    print('Normal:', len(normal))

    # check for duplicate indices 
    if True in (df.index.duplicated()):
        print('Duplicates present')
    else:
        print('NO dup index')
        
    print('\n')

    all_df
# Out:
# precursor
# ['Name', 'ID', 'Alias']
# num IDs: 100
# Tumor: 100
# Normal: 0
# NO dup index
#
#
# mature
# ['Name', 'ID', 'Alias', 'Derives_from']
# num IDs: 99
# Tumor: 99
# Normal: 0
# NO dup index
#
#
# total
# ['Name', 'ID', 'Alias']
# num IDs: 99
# Tumor: 99
# Normal: 0
# NO dup index

# %%
df
# Out:
# Name       hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3    hsa-let-7b  \
# ID            MI0000060     MI0000061     MI0000062     MI0000063
# Alias         MI0000060     MI0000061     MI0000062     MI0000063
# C3L-00104  38885.757074  38595.352386  38880.062864  22406.714612
# C3L-00365  22253.994353  21374.700647  21892.983522  12985.666798
# C3L-00674  31033.859949  31230.411270  30199.844884  15856.910638
# C3L-00677  21538.021467  21375.494893  20998.433244   8581.403059
# C3L-01040  21718.860158  21679.061199  20996.793341   7334.379477
# ...                 ...           ...           ...           ...
# C3N-03183  28721.470132  29735.330811  29281.671117   8712.328202
# C3N-03184  27992.525744  28385.232184  28469.933574  11837.660804
# C3N-03186  27472.047701  27858.743695  28124.857068  12390.903912
# C3N-03188  17682.880592  17889.953744  18000.781628   6915.076675
# C3N-03473  16341.429173  16800.037437  16366.387446   4040.120424
#
# Name        hsa-let-7c   hsa-let-7d    hsa-let-7e  hsa-let-7f-1  hsa-let-7f-2  \
# ID           MI0000064    MI0000065     MI0000066     MI0000067     MI0000068
# Alias        MI0000064    MI0000065     MI0000066     MI0000067     MI0000068
# C3L-00104  8193.967554  7191.786672  10141.387223  16422.100366  15778.654686
# C3L-00365  7502.591414  2859.491725   9579.297280   9218.286450   9139.650427
# C3L-00674  9041.360773  5933.725019  17370.887031  17429.321207  17264.643073
# C3L-00677  7697.258502  8951.963646  11630.401571  17708.895404  17669.889027
# C3L-01040  4849.787360  5264.833640  14759.728003  13002.888267  12832.321303
# ...                ...          ...           ...           ...           ...
# C3N-03183  7251.681462  6784.274505   9279.402819  22318.682187  22191.520001
# C3N-03184  5536.390797  3557.458342   7702.692991  12209.833575  12084.064845
# C3N-03186  3995.858611  6124.765592   9733.928208  16557.241402  16386.762523
# C3N-03188  2729.865782  4231.875266  11368.607710  15527.569894  15979.631001
# C3N-03473  2249.364344  3494.158204   6442.354189  13121.811971  12625.766297
#
# Name        hsa-let-7g  ... hsa-mir-9900 hsa-mir-9901 hsa-mir-9902-1  \
# ID           MI0000433  ...    MI0031828    MI0031829      MI0031830
# Alias        MI0000433  ...    MI0031828    MI0031829      MI0031830
# C3L-00104  6815.968841  ...          NaN          NaN            NaN
# C3L-00365  3942.524216  ...          NaN    10.723094            NaN
# C3L-00674  5354.695452  ...          NaN     5.312198            NaN
# C3L-00677  8626.910500  ...          NaN    19.503189            NaN
# C3L-01040  4866.844056  ...          NaN     5.685565            NaN
# ...                ...  ...          ...          ...            ...
# C3N-03183  9709.004801  ...          NaN     3.436816       3.436816
# C3N-03184  4884.446772  ...          NaN          NaN            NaN
# C3N-03186  6274.454364  ...          NaN    20.790107            NaN
# C3N-03188  5413.067191  ...          NaN          NaN            NaN
# C3N-03473  5075.888748  ...          NaN          NaN            NaN
#
# Name      hsa-mir-9902-2 hsa-mir-9903 hsa-mir-9983 hsa-mir-9985 hsa-mir-9986  \
# ID             MI0041071    MI0031831    MI0033670    MI0032313    MI0032316
# Alias          MI0041071    MI0031831    MI0033670    MI0032313    MI0032316
# C3L-00104            NaN          NaN          NaN          NaN          NaN
# C3L-00365            NaN          NaN          NaN     3.574365          NaN
# C3L-00674            NaN          NaN          NaN    15.936594          NaN
# C3L-00677            NaN          NaN          NaN    13.002126          NaN
# C3L-01040            NaN          NaN          NaN    11.371131          NaN
# ...                  ...          ...          ...          ...          ...
# C3N-03183            NaN          NaN          NaN    27.494527          NaN
# C3N-03184            NaN          NaN          NaN     2.566709          NaN
# C3N-03186            NaN          NaN          NaN     4.158021          NaN
# C3N-03188            NaN          NaN          NaN     2.916523          NaN
# C3N-03473            NaN          NaN          NaN     6.239568          NaN
#
# Name        hsa-mir-99a  hsa-mir-99b
# ID            MI0000101    MI0000746
# Alias         MI0000101    MI0000746
# C3L-00104   5745.457444   318.875735
# C3L-00365   7734.925117   275.226079
# C3L-00674  11506.220584  2401.113437
# C3L-00677  13229.663050   364.059524
# C3L-01040   4491.596734   329.762798
# ...                 ...          ...
# C3N-03183   9599.026694   240.577110
# C3N-03184   7014.815043   177.102904
# C3N-03186   3051.987742   266.113373
# C3N-03188   2280.721198   335.400176
# C3N-03473   3581.512159   202.785967
#
# [99 rows x 1795 columns]

# %%
# check tumor/normal counts
tumor = all_df.loc[~ all_df.index.str.contains('.A$')]
print('Tumor:', len(tumor))
normal = all_df.loc[all_df.index.str.contains('.A$')]
print('Normal:', len(normal))

# check for duplicate indices 
if True in (all_df.index.duplicated()):
    print('Duplicates present')
else:
    print('NO dup index')

all_df
# Out:
# ccRCC mature
# Tumor: 110
# Normal: 75
# NO dup index
# Name         hsa-let-7a-2-3p hsa-let-7a-3p                hsa-let-7a-5p  \
# ID              MIMAT0010195  MIMAT0004481 MIMAT0004481_1  MIMAT0000062
# Alias           MIMAT0010195  MIMAT0004481   MIMAT0004481  MIMAT0000062
# Derives_from       MI0000061     MI0000062      MI0000060     MI0000061
# C3L-00004.T              NaN     57.081886      48.300058  33300.694204
# C3L-00010.T              NaN     41.253197      75.005813  46274.836300
# C3L-00011.T              NaN     22.135035      38.736311  38481.757964
# C3L-00026.T              NaN     43.049636      32.287227  30000.215248
# C3L-00079.T              NaN     57.970268      96.617113  42144.384613
# ...                      ...           ...            ...           ...
# C3N-01646.A              NaN     90.432266      83.475938  32757.349361
# C3N-01648.A              NaN     84.388186     111.238972  30690.448792
# C3N-01649.A              NaN     59.224665      71.915664  33555.002792
# C3N-01651.A              NaN     93.273638      76.617631  35097.537576
# C3N-01808.A              NaN     87.405372     111.684641  36564.580430
#
# Name                                       hsa-let-7b-3p hsa-let-7b-5p  \
# ID           MIMAT0000062_1 MIMAT0000062_2  MIMAT0004482  MIMAT0000063
# Alias          MIMAT0000062   MIMAT0000062  MIMAT0004482  MIMAT0000063
# Derives_from      MI0000062      MI0000060     MI0000063     MI0000063
# C3L-00004.T    32962.593801   33630.012778    127.336515  12610.705927
# C3L-00010.T    46473.601704   45971.062757    138.760754  17836.382320
# C3L-00011.T    38005.854717   37568.687780    420.565661  58525.031957
# C3L-00026.T    30511.429678   29881.828749     91.480477  10783.933876
# C3L-00079.T    43033.262051   44224.873110    161.028521  14924.123361
# ...                     ...            ...           ...           ...
# C3N-01646.A    33320.811943   33310.377450    139.126563  14114.389860
# C3N-01648.A    30644.418872   30767.165324     99.731492  12159.570387
# C3N-01649.A    34659.119752   33774.980117    287.662656  15051.525458
# C3N-01651.A    35377.358491   35450.644921    193.209679  13211.544611
# C3N-01808.A    36826.796545   36812.228983    233.080991  17471.362601
#
# Name         hsa-let-7c-3p hsa-let-7c-5p  ... hsa-miR-9851-5p hsa-miR-9898  \
# ID            MIMAT0026472  MIMAT0000064  ...    MIMAT0048639 MIMAT0039318
# Alias         MIMAT0026472  MIMAT0000064  ...    MIMAT0048639 MIMAT0039318
# Derives_from     MI0000064     MI0000064  ...       MI0039502    MI0031826
# C3L-00004.T            NaN   6862.999082  ...             NaN          NaN
# C3L-00010.T            NaN   8441.904248  ...             NaN          NaN
# C3L-00011.T            NaN   7155.149993  ...             NaN          NaN
# C3L-00026.T            NaN   5811.700891  ...             NaN     5.381205
# C3L-00079.T            NaN   5513.616572  ...             NaN          NaN
# ...                    ...           ...  ...             ...          ...
# C3N-01646.A      10.434492   5161.595503  ...             NaN          NaN
# C3N-01648.A      11.507480   4188.722670  ...             NaN          NaN
# C3N-01649.A       4.230333   5283.686143  ...             NaN     4.230333
# C3N-01651.A       3.331201   4563.745869  ...             NaN     3.331201
# C3N-01808.A            NaN   5618.223049  ...             NaN          NaN
#
# Name         hsa-miR-9899 hsa-miR-9901 hsa-miR-9903 hsa-miR-9985  \
# ID           MIMAT0039319 MIMAT0039321 MIMAT0039323 MIMAT0039763
# Alias        MIMAT0039319 MIMAT0039321 MIMAT0039323 MIMAT0039763
# Derives_from    MI0031827    MI0031829    MI0031831    MI0032313
# C3L-00004.T           NaN          NaN          NaN    30.736400
# C3L-00010.T           NaN          NaN          NaN    33.752616
# C3L-00011.T           NaN    11.067517          NaN          NaN
# C3L-00026.T           NaN    16.143614          NaN    37.668432
# C3L-00079.T           NaN          NaN          NaN    25.764563
# ...                   ...          ...          ...          ...
# C3N-01646.A           NaN     6.956328          NaN    48.694297
# C3N-01648.A           NaN          NaN          NaN    38.358266
# C3N-01649.A           NaN          NaN          NaN    50.763998
# C3N-01651.A           NaN          NaN          NaN    36.643215
# C3N-01808.A           NaN     4.855854          NaN    58.270248
#
# Name         hsa-miR-99a-3p hsa-miR-99a-5p hsa-miR-99b-3p hsa-miR-99b-5p
# ID             MIMAT0004511   MIMAT0000097   MIMAT0004678   MIMAT0000689
# Alias          MIMAT0004511   MIMAT0000097   MIMAT0004678   MIMAT0000689
# Derives_from      MI0000101      MI0000101      MI0000746      MI0000746
# C3L-00004.T       48.300058    9343.865673      61.472800    2415.002876
# C3L-00010.T       30.002325    8141.880996     112.508719    2430.188340
# C3L-00011.T             NaN    1610.323780      55.337587     254.552900
# C3L-00026.T       69.955659    7130.096001     150.673727    3024.236945
# C3L-00079.T       57.970268    2228.634736      64.411409     193.234226
# ...                     ...            ...            ...            ...
# C3N-01646.A       69.563282    5373.763513      48.694297     163.473712
# C3N-01648.A       65.209053    5082.470272      46.029919     161.104718
# C3N-01649.A       67.685331    5419.056805      71.915664     249.589658
# C3N-01651.A       26.649611    4437.160217      76.617631     169.891270
# C3N-01808.A       97.117079    5108.358381      72.837810     286.495385
#
# [185 rows x 2338 columns]

# %%
test = '\.1'
all_df.loc[all_df.index.str.contains(test)]
# Out:
# Empty DataFrame
# Columns: [(hsa-let-7a-2-3p, MIMAT0010195, MIMAT0010195, MI0000061), (hsa-let-7a-3p, MIMAT0004481, MIMAT0004481, MI0000062), (hsa-let-7a-3p, MIMAT0004481_1, MIMAT0004481, MI0000060), (hsa-let-7a-5p, MIMAT0000062, MIMAT0000062, MI0000061), (hsa-let-7a-5p, MIMAT0000062_1, MIMAT0000062, MI0000062), (hsa-let-7a-5p, MIMAT0000062_2, MIMAT0000062, MI0000060), (hsa-let-7b-3p, MIMAT0004482, MIMAT0004482, MI0000063), (hsa-let-7b-5p, MIMAT0000063, MIMAT0000063, MI0000063), (hsa-let-7c-3p, MIMAT0026472, MIMAT0026472, MI0000064), (hsa-let-7c-5p, MIMAT0000064, MIMAT0000064, MI0000064), (hsa-let-7d-3p, MIMAT0004484, MIMAT0004484, MI0000065), (hsa-let-7d-5p, MIMAT0000065, MIMAT0000065, MI0000065), (hsa-let-7e-3p, MIMAT0004485, MIMAT0004485, MI0000066), (hsa-let-7e-5p, MIMAT0000066, MIMAT0000066, MI0000066), (hsa-let-7f-1-3p, MIMAT0004486, MIMAT0004486, MI0000067), (hsa-let-7f-2-3p, MIMAT0004487, MIMAT0004487, MI0000068), (hsa-let-7f-5p, MIMAT0000067, MIMAT0000067, MI0000067), (hsa-let-7f-5p, MIMAT0000067_1, MIMAT0000067, MI0000068), (hsa-let-7g-3p, MIMAT0004584, MIMAT0004584, MI0000433), (hsa-let-7g-5p, MIMAT0000414, MIMAT0000414, MI0000433), (hsa-let-7i-3p, MIMAT0004585, MIMAT0004585, MI0000434), (hsa-let-7i-5p, MIMAT0000415, MIMAT0000415, MI0000434), (hsa-miR-1-3p, MIMAT0000416, MIMAT0000416, MI0000437), (hsa-miR-1-3p, MIMAT0000416_1, MIMAT0000416, MI0000651), (hsa-miR-1-5p, MIMAT0031892, MIMAT0031892, MI0000651), (hsa-miR-100-3p, MIMAT0004512, MIMAT0004512, MI0000102), (hsa-miR-100-5p, MIMAT0000098, MIMAT0000098, MI0000102), (hsa-miR-101-2-5p, MIMAT0037312, MIMAT0037312, MI0000739), (hsa-miR-101-3p, MIMAT0000099, MIMAT0000099, MI0000103), (hsa-miR-101-3p, MIMAT0000099_1, MIMAT0000099, MI0000739), (hsa-miR-101-5p, MIMAT0004513, MIMAT0004513, MI0000103), (hsa-miR-10226, MIMAT0041128, MIMAT0041128, MI0033056), (hsa-miR-10392-3p, MIMAT0041616, MIMAT0041616, MI0033416), (hsa-miR-10392-5p, MIMAT0041615, MIMAT0041615, MI0033416), (hsa-miR-10393-3p, MIMAT0041618, MIMAT0041618, MI0033417), (hsa-miR-10393-5p, MIMAT0041617, MIMAT0041617, MI0033417), (hsa-miR-10394-3p, MIMAT0041620, MIMAT0041620, MI0033418), (hsa-miR-10394-5p, MIMAT0041619, MIMAT0041619, MI0033418), (hsa-miR-10395-3p, MIMAT0041622, MIMAT0041622, MI0033419), (hsa-miR-10395-5p, MIMAT0041621, MIMAT0041621, MI0033419), (hsa-miR-10396a-3p, MIMAT0041624, MIMAT0041624, MI0033420), (hsa-miR-10396a-5p, MIMAT0041623, MIMAT0041623, MI0033420), (hsa-miR-10396b-3p, MIMAT0041636, MIMAT0041636, MI0033426), (hsa-miR-10396b-5p, MIMAT0041635, MIMAT0041635, MI0033426), (hsa-miR-10397-3p, MIMAT0041626, MIMAT0041626, MI0033421), (hsa-miR-10397-5p, MIMAT0041625, MIMAT0041625, MI0033421), (hsa-miR-10398-3p, MIMAT0041628, MIMAT0041628, MI0033422), (hsa-miR-10398-5p, MIMAT0041627, MIMAT0041627, MI0033422), (hsa-miR-10399-3p, MIMAT0041630, MIMAT0041630, MI0033423), (hsa-miR-10399-5p, MIMAT0041629, MIMAT0041629, MI0033423), (hsa-miR-103a-1-5p, MIMAT0037306, MIMAT0037306, MI0000109), (hsa-miR-103a-2-5p, MIMAT0009196, MIMAT0009196, MI0000108), (hsa-miR-103a-3p, MIMAT0000101, MIMAT0000101, MI0000108), (hsa-miR-103a-3p, MIMAT0000101_1, MIMAT0000101, MI0000109), (hsa-miR-10400-3p, MIMAT0041632, MIMAT0041632, MI0033424), (hsa-miR-10400-5p, MIMAT0041631, MIMAT0041631, MI0033424), (hsa-miR-10401-3p, MIMAT0041634, MIMAT0041634, MI0033425), (hsa-miR-10401-3p, MIMAT0041634_1, MIMAT0041634, MI0033425), (hsa-miR-10401-3p, MIMAT0041634_2, MIMAT0041634, MI0033425), (hsa-miR-10401-3p, MIMAT0041634_3, MIMAT0041634, MI0033425), (hsa-miR-10401-5p, MIMAT0041633, MIMAT0041633, MI0033425), (hsa-miR-10401-5p, MIMAT0041633_1, MIMAT0041633, MI0033425), (hsa-miR-10401-5p, MIMAT0041633_2, MIMAT0041633, MI0033425), (hsa-miR-10401-5p, MIMAT0041633_3, MIMAT0041633, MI0033425), (hsa-miR-105-3p, MIMAT0004516, MIMAT0004516, MI0000111), (hsa-miR-105-3p, MIMAT0004516_1, MIMAT0004516, MI0000112), (hsa-miR-105-5p, MIMAT0000102, MIMAT0000102, MI0000111), (hsa-miR-105-5p, MIMAT0000102_1, MIMAT0000102, MI0000112), (hsa-miR-10523-5p, MIMAT0041992, MIMA ...
# Index: []
#
# [0 rows x 2386 columns]

# %%
# check na (first col in LSCC has lots of na)
# no na in file, but na appear when combining when a miRNA was not included in some files
all_df.columns = all_df.columns.droplevel(['ID','Alias','Derives_from'])
all_df.iloc[:,0].dropna()
# Out:
# Patient_ID
# C3L-01663       4.727194
# C3L-03678       4.113043
# C3L-04014       8.284798
# C3N-02283       7.457622
# C3N-02288      19.479634
# C3N-03441       5.603591
# C3L-00923.N     3.308104
# C3L-02130.N     2.990037
# C3L-02358.N     2.943982
# C3L-02552.N     4.337586
# C3L-02625.N     4.738640
# C3L-02968.N     2.691254
# C3N-04124.N     8.639831
# Name: hsa-let-7a-2-3p, dtype: float64

# %%
ident = 'total'
for can in cancer_names:
    df = pd.read_csv('~/Documents/miRNA/datafreeze/'+can+'_'+ ident +'_miRNA_combined.tsv', delimiter = '\t')
    print(can)
    # check tumor/normal counts
    tumor = [col for col in df.columns if '.N' not in col]
    if ident == 'mature':
        print('Tumor:', len(tumor) - 4)
    else:
        print('Tumor:', len(tumor) - 3)
    normal = [col for col in df.columns if '.N' in col]
    print('Normal:', len(normal))
    #print(df.head())
# Out:
# GBM
# Tumor: 99
# Normal: 0
# HNSCC
# Tumor: 111
# Normal: 61
# LSCC
# Tumor: 109
# Normal: 97
# LUAD
# Tumor: 110
# Normal: 101
# EC
# Tumor: 95
# Normal: 15
# PDA
# Tumor: 145
# Normal: 38
# ccRCC
# Tumor: 110
# Normal: 75

# %%
# total and precursor have same num of tumor and normal
# mature is off by a couple

# %%
# Check patient_IDs
new = {}
for can in cancer_names:
    #print(can)
    for i in identifier_list:
        #print(i)
        df = pd.read_csv('~/Documents/miRNA/datafreeze/'+can+'_'+ i +'_miRNA_combined.tsv', delimiter = '\t')
        if i == 'mature':
            new[can+'_'+i] = list(df.columns[4:]) # 'Name', 'ID', 'Alias', 'Derives_from'
        else:
            new[can+'_'+i] = list(df.columns[3:])
        #print(list(df.columns[0:6]))
print('done')
# Out:
# done

# %%
#for can in cancer_names:
can = 'PDA'
t = new[can+'_total'] 
m = new[can+'_mature'] 
p = new[can+'_precursor']

l3 = {'total':t,'pre':p, 'mature':m}

for l in l3:
    print(l, len(l3[l]))
# Out:
# total 183
# pre 183
# mature 183

# %%
n = set(t) ^ set(p) 
print('total vs pre:', n, '\n')

n2 = set(t) ^ set(m) 
print('total vs mature:', n2, '\n')

n3 = set(m) ^ set(p) 
print('mature vs pre:', n3)
# Out:
# total vs pre: set()
#
# total vs mature: set()
#
# mature vs pre: set()

# %%
p
# Out:
# ['C3L-00017',
#  'C3L-00102',
#  'C3L-00189',
#  'C3L-00277',
#  'C3L-00401',
#  'C3L-00589',
#  'C3L-00598',
#  'C3L-00599',
#  'C3L-00622',
#  'C3L-00625',
#  'C3L-00640',
#  'C3L-00819',
#  'C3L-00881',
#  'C3L-00928',
#  'C3L-01031',
#  'C3L-01036',
#  'C3L-01037',
#  'C3L-01051',
#  'C3L-01052',
#  'C3L-01053',
#  'C3L-01054',
#  'C3L-01124',
#  'C3L-01328',
#  'C3L-01453',
#  'C3L-01598',
#  'C3L-01637',
#  'C3L-01662',
#  'C3L-01687',
#  'C3L-01689',
#  'C3L-01703',
#  'C3L-01971',
#  'C3L-02109',
#  'C3L-02112',
#  'C3L-02115',
#  'C3L-02116',
#  'C3L-02118',
#  'C3L-02463',
#  'C3L-02604',
#  'C3L-02606',
#  'C3L-02610',
#  'C3L-02613',
#  'C3L-02701',
#  'C3L-02809',
#  'C3L-02890',
#  'C3L-02897',
#  'C3L-02899',
#  'C3L-03123',
#  'C3L-03129',
#  'C3L-03356',
#  'C3L-03371',
#  'C3L-03388',
#  'C3L-03394',
#  'C3L-03395',
#  'C3L-03628',
#  'C3L-03630',
#  'C3L-03632',
#  'C3L-03635',
#  'C3L-03639',
#  'C3L-03743',
#  'C3L-04027',
#  'C3L-04072',
#  'C3L-04080',
#  'C3L-04473',
#  'C3L-04475',
#  'C3L-04479',
#  'C3L-04495',
#  'C3L-04848',
#  'C3L-04853',
#  'C3N-00198',
#  'C3N-00249',
#  'C3N-00302',
#  'C3N-00303',
#  'C3N-00436',
#  'C3N-00511',
#  'C3N-00512',
#  'C3N-00513',
#  'C3N-00514',
#  'C3N-00516',
#  'C3N-00517',
#  'C3N-00518',
#  'C3N-00709',
#  'C3N-00957',
#  'C3N-01011',
#  'C3N-01012',
#  'C3N-01165',
#  'C3N-01166',
#  'C3N-01167',
#  'C3N-01168',
#  'C3N-01375',
#  'C3N-01379',
#  'C3N-01380',
#  'C3N-01381',
#  'C3N-01382',
#  'C3N-01383',
#  'C3N-01388',
#  'C3N-01502',
#  'C3N-01714',
#  'C3N-01715',
#  'C3N-01716',
#  'C3N-01719',
#  'C3N-01900',
#  'C3N-01907',
#  'C3N-01997',
#  'C3N-01998',
#  'C3N-02010',
#  'C3N-02295',
#  'C3N-02573',
#  'C3N-02579',
#  'C3N-02585',
#  'C3N-02589',
#  'C3N-02592',
#  'C3N-02768',
#  'C3N-02940',
#  'C3N-02944',
#  'C3N-02971',
#  'C3N-02998',
#  'C3N-03000',
#  'C3N-03006',
#  'C3N-03007',
#  'C3N-03039',
#  'C3N-03061',
#  'C3N-03069',
#  'C3N-03086',
#  'C3N-03173',
#  'C3N-03190',
#  'C3N-03211',
#  'C3N-03426',
#  'C3N-03428',
#  'C3N-03430',
#  'C3N-03439',
#  'C3N-03440',
#  'C3N-03665',
#  'C3N-03666',
#  'C3N-03670',
#  'C3N-03754',
#  'C3N-03780',
#  'C3N-03839',
#  'C3N-03840',
#  'C3N-03853',
#  'C3N-03884',
#  'C3N-04119',
#  'C3N-04126',
#  'C3N-04282',
#  'C3N-04283',
#  'C3N-04284',
#  'C3L-00017.N',
#  'C3L-00102.N',
#  'C3L-00589.N',
#  'C3L-00622.N',
#  'C3L-00640.N',
#  'C3L-00819.N',
#  'C3L-01328.N',
#  'C3L-01453.N',
#  'C3L-01637.N',
#  'C3L-01689.N',
#  'C3L-01703.N',
#  'C3L-02112.N',
#  'C3L-02463.N',
#  'C3L-02606.N',
#  'C3L-02610.N',
#  'C3L-02613.N',
#  'C3L-02809.N',
#  'C3L-02899.N',
#  'C3L-03123.N',
#  'C3L-03743.N',
#  'C3L-04027.N',
#  'C3L-04072.N',
#  'C3L-04080.N',
#  'C3L-04475.N',
#  'C3N-00436.N',
#  'C3N-00517.N',
#  'C3N-00518.N',
#  'C3N-01011.N',
#  'C3N-01719.N',
#  'C3N-01998.N',
#  'C3N-02010.N',
#  'C3N-02589.N',
#  'C3N-02768.N',
#  'C3N-03069.N',
#  'C3N-03173.N',
#  'C3N-03440.N',
#  'C3N-03780.N',
#  'C3N-04283.N']

# %%
dif = list(n2)[0]

if dif in t:
    print('in total')
if dif in m:
    print('in mature')
if dif in p:
    print('in pre')
# Out:
# in total
# in pre

# %%
dif
# Out:
# 'Derives_from'
