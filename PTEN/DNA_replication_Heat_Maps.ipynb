# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import sys
sys.path.append('C:\\Users\\brittany henderson\\GitHub\\WhenMutationsDontMatter\\')
import plot_utils as pu

# %% [markdown]
# # GSEA

# %%
df = pd.read_csv('sig_pval_all_proteins.csv')

prot_list = list(df.Proteomics) # list of genes with a sig pval in >= 1 cancer

prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head()
# Out:
#                                               Term Overlap       P-value  \
# 0                Spliceosome Homo sapiens hsa03040  84/134  1.760059e-41
# 1              RNA transport Homo sapiens hsa03013  76/172  3.577573e-24
# 2            DNA replication Homo sapiens hsa03030   22/36  1.580044e-11
# 3  mRNA surveillance pathway Homo sapiens hsa03015   34/91  3.038588e-09
# 4            Mismatch repair Homo sapiens hsa03430   15/23  7.918079e-09
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0      5.156972e-39            0                     0    4.851901
# 1      5.241145e-22            0                     0    3.419973
# 2      1.543176e-09            0                     0    4.729962
# 3      2.225765e-07            0                     0    2.891845
# 4      4.639994e-07            0                     0    5.047786
#
#    Combined Score                                              Genes  \
# ...

# %% [markdown]
# # DNA Replication HeatMap

# %%
hm_df = pd.read_csv('heat_map_df.csv') # long df plottable with HeatMap function

# %%
d = prot_enr.res2d.Genes[2]
dna = d.split(';')
print('total genes:',len(dna))
d_1 = dna[0:16]
d_2 = dna[16:32]
# Out:
# total genes: 22

# %%
bool_df = hm_df.Proteomics.isin(d_1)
plot_df = hm_df[bool_df]
plot_df.head()
# Out:
#     Proteomics   P_Value   Medians Cancer      size
# 131       PCNA  0.000019 -0.631486    Gbm  1.087410
# 133      POLD2  0.000020 -0.405249    Gbm  1.081765
# 178      POLD3  0.000036 -0.483613    Gbm  1.022357
# 179       RFC5  0.000037 -0.481635    Gbm  1.021302
# 220       MCM7  0.000053 -1.036455    Gbm  0.984818

# %%
pu.plotCircleHeatMap(plot_df, circle_var = 'size', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer')
# Out:
# C:\Users\brittany henderson\GitHub\WhenMutationsDontMatter\plot_utils.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['size'] = np.where(df[circle_var]<0, np.abs(df[circle_var]), df[circle_var])*50
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1612">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="2070df25-81f2-42db-b9c6-9b577db32a36" data-root-id="1589"></div>

# %% [markdown]
# posNeg HeatMap

# %%
# df of only genes that have a pos and neg value for change in median
pos_neg_df = pd.read_csv('pos_neg_df.csv')

# %%
# get list of genes involved in spliceosome and with a posNeg change in median
get = pos_neg_df.Proteomics.isin(dna)

dna_pn = pos_neg_df[get]
len(dna_pn.Proteomics.unique())
# Out:
# 10

# %%
pu.plotCircleHeatMap(dna_pn, circle_var = 'size', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1348">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="fd6cbc32-98eb-4e45-879e-c6c98799494b" data-root-id="1325"></div>
