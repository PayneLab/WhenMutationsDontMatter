# %% [markdown]
# ## test miRNA and deconvolution

# %%
import pandas as pd
import numpy as np

import cptac.pancan as pc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-129c88fd4082> in <module>
#       2 import numpy as np
#       3
# ----> 4 import cptac.pancan as pc
#
# ~/anaconda3/lib/python3.8/site-packages/cptac/pancan/__init__.py in <module>
#      10 #   limitations under the License.
#      11
# ---> 12 from .file_download import download, download_pdc_id, list_pdc_datasets
#      13
#      14 from .pdcbrca import PdcBrca
#
# ~/anaconda3/lib/python3.8/site-packages/cptac/pancan/file_download.py in <module>
#      20 from cptac.exceptions import DatasetAlreadyInstalledWarning, InvalidParameterError, NoInternetError, PdcDownloadError
#      21
# ---> 22 from .pancanbrca import SOURCES as BRCA_SOURCES
#      23 from .pancanccrcc import SOURCES as CCRCC_SOURCES
#      24 from .pancancoad import SOURCES as COAD_SOURCES
#
# ~/anaconda3/lib/python3.8/site-packages/cptac/pancan/pancanbrca.py in <module>
#      17 from .pdcbrca import PdcBrca
#      18 from .umichbrca import UmichBrca
# ---> 19 from .washubrca import WashuBrca
#      20 from .bcmbrca import BcmBrca
#      21
#
# ~/anaconda3/lib/python3.8/site-packages/cptac/pancan/washubrca.py in <module>
#      15 import warnings
#      16 import datetime
# ---> 17 from gtfparse import read_gtf
#      18
#      19 from cptac.dataset import Dataset
#
# ModuleNotFoundError: No module named 'gtfparse'

# %%
g = pc.PancanGbm()
l = pc.PancanLuad()
ls = pc.PancanLscc()
e = pc.PancanUcec()
r = pc.PancanCcrcc()
h = pc.PancanHnscc()
b = pc.PancanBrca()
o = pc.PancanOv()
c = pc.PancanCoad()
# Out:
# Loading pdchnscc v0.0...
# /Users/brittanyhenderson/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
g = pc.PancanGbm()

# %%
pc.download('pancangbm')
# Out:
# Please login to Box on the webpage that was just opened and grant access for cptac to download files through your account. If you accidentally closed the browser window, press Ctrl+C and call the download function again.
# True

# %% [markdown]
# # Check Deconvolution

# %%
ca = r

# %%
xc = ca.get_deconvolution('washu','xcell')
ciber = ca.get_deconvolution('washu','cibersort')

# %%
decon = {'xcell':xc, 'cibersort':ciber}

for decon_type in decon:
    print(decon_type)
    df = xc
    print('num IDs:', len(df.index))
    # check tumor/normal counts
    tumor = df.loc[~ df.index.str.contains('\.N$', regex = True)]
    print('Tumor:', len(tumor))
    normal = df.loc[df.index.str.contains('\.N$', regex = True)]
    print('Normal:', len(normal))

    # check for duplicate indices 
    if True in (df.index.duplicated()):
        print('Duplicates present')
    else:
        print('NO dup index')

    print('\n')

# %%
xc
#ciber

# %% [markdown]
# # Check miRNA

# %%
ca = g

# %%
pre = ca.get_miRNA('washu', 'precursor')
mat = ca.get_miRNA('washu', 'mature')
tot = ca.get_miRNA('washu', 'total')

all_list = {'precursor':pre, 'mature':mat, 'total':tot}

# %%
for miRNA_type in all_list:
    df = all_list[miRNA_type]
    print(miRNA_type)
    print(df.columns.names)
    
    print('num IDs:', len(df.index))
    # check tumor/normal counts
    tumor = df.loc[~ df.index.str.contains('\.N$', regex = True)]
    print('Tumor:', len(tumor))
    normal = df.loc[df.index.str.contains('\.N$', regex = True)]
    print('Normal:', len(normal))

    # check for duplicate indices 
    if True in (df.index.duplicated()):
        print('Duplicates present')
    else:
        print('NO dup index')
        
    print('\n')
# Out:
# precursor
# ['Name', 'ID', 'Alias']
# num IDs: 98
# Tumor: 98
# Normal: 0
# NO dup index
#
#
# mature
# ['Name', 'ID', 'Alias', 'Derives_from']
# num IDs: 98
# Tumor: 98
# Normal: 0
# NO dup index
#
#
# total
# ['Name', 'ID', 'Alias']
# num IDs: 98
# Tumor: 98
# Normal: 0
# NO dup index

# %%
# GBM duplicate = C3N-02788
# HNSCC duplicate = C3L-02617 and C3N-02727
# EC duplicate = C3N-00326

pre[pre.index.str.contains('C3N-02788')]
# Out:
# Name       hsa-let-7a-1 hsa-let-7a-2 hsa-let-7a-3 hsa-let-7b hsa-let-7c  \
# ID            MI0000060    MI0000061    MI0000062  MI0000063  MI0000064
# Alias         MI0000060    MI0000061    MI0000062  MI0000063  MI0000064
# Patient_ID
# C3N-02788     49.916025    58.970249    35.694418  64.210658  41.226927
#
# Name       hsa-let-7d hsa-let-7e hsa-let-7f-1 hsa-let-7f-2 hsa-let-7g  ...  \
# ID          MI0000065  MI0000066    MI0000067    MI0000068  MI0000433  ...
# Alias       MI0000065  MI0000066    MI0000067    MI0000068  MI0000433  ...
# Patient_ID                                                             ...
# C3N-02788   14.221608   8.116201    56.094457    32.537828    6.75133  ...
#
# Name       hsa-mir-9900 hsa-mir-9901 hsa-mir-9902-1 hsa-mir-9902-2  \
# ID            MI0031828    MI0031829      MI0031830      MI0041071
# Alias         MI0031828    MI0031829      MI0031830      MI0041071
# Patient_ID
# C3N-02788           NaN     8.043176            NaN            NaN
#
# Name       hsa-mir-9903 hsa-mir-9983 hsa-mir-9985 hsa-mir-9986 hsa-mir-99a  \
# ID            MI0031831    MI0033670    MI0032313    MI0032316   MI0000101
# Alias         MI0031831    MI0033670    MI0032313    MI0032316   MI0000101
# Patient_ID
# C3N-02788           NaN          NaN          NaN          NaN   15.586478
#
# Name       hsa-mir-99b
# ID           MI0000746
# Alias        MI0000746
# Patient_ID
# C3N-02788    24.994525
#
# [1 rows x 1489 columns]

# %%
# precursor should not have derives from #see bottom (sorted) - GBM
pre[pre.index.str.contains('Derives_from')]
# Out:
# Empty DataFrame
# Patient_ID                                                             ...
# C3L-00104   34.165257  11.388419    85.413143    34.165257  11.388419  ...
# C3L-00365    7.148729  17.871823    92.933481    46.466741  17.871823  ...
# C3L-00674   79.682968  47.809781   127.492749   239.048904  26.560989  ...
# C3L-00677   13.002126  52.008503   110.518070    26.004252  19.503189  ...
# C3L-01040   17.056696  17.056696    56.855655    11.371131   5.685565  ...
# ...               ...        ...          ...          ...        ...  ...
# C3N-03183         NaN   3.436816    51.552238    37.804974  10.310448  ...
# C3N-03184    2.566709  10.266835    35.933923    17.966961  12.833544  ...
# C3N-03186    8.316043  16.632086    49.896257    20.790107   8.316043  ...
# C3N-03188   11.666093   8.749570    23.332186    29.165233   5.833047  ...
# C3N-03473    9.359352  12.479136    24.958273     6.239568  12.479136  ...
#
# Name       hsa-mir-9900 hsa-mir-9901 hsa-mir-9902-1 hsa-mir-9902-2  \
# ID            MI0031828    MI0031829      MI0031830      MI0041071
# Alias         MI0031828    MI0031829      MI0031830      MI0041071
# Patient_ID
# C3L-00104           NaN          NaN            NaN            NaN
# C3L-00365           NaN    10.723094            NaN            NaN
# C3L-00674           NaN     5.312198            NaN            NaN
# C3L-00677           NaN    19.503189            NaN            NaN
# C3L-01040           NaN          NaN            NaN            NaN
# ...                 ...          ...            ...            ...
# C3N-03183           NaN     3.436816       3.436816            NaN
# C3N-03184           NaN          NaN            NaN            NaN
# C3N-03186           NaN    12.474064            NaN            NaN
# C3N-03188           NaN          NaN            NaN            NaN
# C3N-03473           NaN          NaN            NaN            NaN
#
# Name       hsa-mir-9903 hsa-mir-9983 hsa-mir-9985 hsa-mir-9986 hsa-mir-99a  \
# ID            MI0031831    MI0033670    MI0032313    MI0032316   MI0000101
# Alias         MI0031831    MI0033670    MI0032313    MI0032316   MI0000101
# Patient_ID
# C3L-00104           NaN          NaN          NaN          NaN   22.776838
# C3L-00365           NaN          NaN          NaN          NaN   64.338564
# C3L-00674           NaN          NaN     5.312198          NaN   63.746374
# C3L-00677           NaN          NaN     6.501063          NaN   58.509566
# C3L-01040           NaN          NaN          NaN          NaN    5.685565
# ...                 ...          ...          ...          ...         ...
# C3N-03183           NaN          NaN          NaN          NaN   41.241790
# C3N-03184           NaN          NaN          NaN          NaN   15.400253
# C3N-03186           NaN          NaN          NaN          NaN   20.790107
# C3N-03188           NaN          NaN          NaN          NaN   11.666093
# C3N-03473           NaN          NaN          NaN          NaN   21.838489
#
# Name       hsa-mir-99b
# ID           MI0000746
# Alias        MI0000746
# Patient_ID
# C3L-00104    85.413143
# C3L-00365    39.318011
# C3L-00674   138.117145
# C3L-00677    39.006378
# C3L-01040    34.113393
# ...                ...
# C3N-03183    20.620895
# C3N-03184    15.400253
# C3N-03186    24.948129
# C3N-03188    34.998279
# C3N-03473    21.838489
#
# [98 rows x 1489 columns]

# %%
tot

# %%
mat
