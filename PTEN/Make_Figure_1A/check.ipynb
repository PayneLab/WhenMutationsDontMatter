# %% [markdown]
# # Make PTEN Figure 1A: Mutation Frequency

# %% [markdown]
# This notebook creates a histogram that shows the frequency of different PTEN mutations found across 9 cancers.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u
import plot_utils as p

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step 1: Create dataframe with Mutation Types

# %% [markdown]
# For each cancer type, create a data frame that has the mutation type for each sample.

# %% [markdown]
# First, load in the cancer data sets from cptac.

# %%
en = cptac.Endometrial()
hn = cptac.Hnscc()
l = cptac.Luad()
ls = cptac.Lscc()
o = cptac.Ovarian()
c = cptac.Ccrcc()
col = cptac.Colon()
g = cptac.Gbm()
b = cptac.Brca()

# %%
cancer = {'Gbm':g, 'Hnscc':hn, 'Luad': l, 'Lscc': ls, 'Brca': b, 'Ov': o, 'Colon': col, 'Endo': en, "Ccrcc": c}
all_df = pd.DataFrame()
for c in cancer:
    test = u.get_frequently_mutated(cancer[c]) #hn, ls, l (KRAS), col  # MUC16, MUC4, CTNNB1
    twenty = test[test['Missense_Mut'] > .2]
    twenty = twenty.assign(cancer = c)
    all_df = all_df.append(twenty)
# Out:
# Warning: New mutation name not classified. Counts will be affected.

# %%
mis = all_df[['Gene','Missense_Mut','cancer']]
#print(mis.Gene.value_counts())
all_df.loc[all_df['Gene'] == 'MUC16']
# Out:
#       Gene  Unique_Samples_Mut  Missense_Mut  Truncation_Mut  Non-Coding  \
# 54   MUC16            0.336364      0.300000        0.072727         NaN
# 97   MUC16            0.305556      0.277778        0.027778         NaN
# 242  MUC16            0.364486      0.327103        0.065421         NaN
#
#     cancer
# 54    Luad
# 97    Lscc
# 242  Colon

# %%
mut = col.get_somatic_mutation()
mut.loc[mut['Gene'] == 'KRAS']
# Out:
# Name        Gene           Mutation Location
# Patient_ID
# 01CO008     KRAS  nonsynonymous SNV     G12V
# 05CO020     KRAS  nonsynonymous SNV     G12D
# 05CO026     KRAS  nonsynonymous SNV     Q61H
# 05CO028     KRAS  nonsynonymous SNV     G12D
# 05CO033     KRAS  nonsynonymous SNV     G12D
# 05CO053     KRAS  nonsynonymous SNV     G13D
# 05CO054     KRAS  nonsynonymous SNV    A146V
# 09CO005     KRAS  nonsynonymous SNV     G12D
# 09CO006     KRAS  nonsynonymous SNV     L19F
# 09CO011     KRAS  nonsynonymous SNV     G12D
# 09CO013     KRAS  nonsynonymous SNV     G12V
# 09CO014     KRAS  nonsynonymous SNV    A146T
# 09CO019     KRAS  nonsynonymous SNV     G12V
# 09CO022     KRAS  nonsynonymous SNV     G12D
# 11CO005     KRAS  nonsynonymous SNV     Q61H
# 11CO008     KRAS  nonsynonymous SNV    A146T
# 11CO020     KRAS  nonsynonymous SNV    K117N
# 11CO021     KRAS  nonsynonymous SNV     G12V
# 11CO043     KRAS  nonsynonymous SNV     G12D
# 11CO044     KRAS  nonsynonymous SNV     G12V
# 11CO045     KRAS  nonsynonymous SNV     G12D
# 11CO052     KRAS  nonsynonymous SNV     V14I
# 11CO057     KRAS  nonsynonymous SNV     G12V
# 11CO058     KRAS  nonsynonymous SNV     Q61L
# 11CO062     KRAS  nonsynonymous SNV     G12D
# 11CO070     KRAS  nonsynonymous SNV     G13D
# 14CO005     KRAS  nonsynonymous SNV     G13D
# 15CO001     KRAS  nonsynonymous SNV    K117N
# 16CO006     KRAS  nonsynonymous SNV    A146T
# 16CO012     KRAS  nonsynonymous SNV     G13D
# 20CO001     KRAS  nonsynonymous SNV     G12C
# 20CO004     KRAS  nonsynonymous SNV     G12V
# 20CO007     KRAS  nonsynonymous SNV     G12D
# 21CO007     KRAS  nonsynonymous SNV     G12C
# 27CO004     KRAS  nonsynonymous SNV     G12D

# %%
cancer = {'Gbm':g, 'Hnscc':hn, 'Luad': l, 'Lscc': ls, 'Brca': b, 'Ov': o, 'Colon': col, 'Endo': en}
all_df = pd.DataFrame()
for c_name in cancer:
    test = cancer[c_name].get_somatic_mutation()
    test = test[test['Gene'] == 'KRAS']
    if c_name == 'Colon':
        test = test[test['Mutation'] == 'nonsynonymous SNV']
    else:
        test = test[test['Mutation'] == 'Missense_Mutation']
    test = test.assign(cancer = c_name)
    nt = test.Location.value_counts()
    nt = nt.to_frame()
    nt['Cancer'] = c_name
    all_df = all_df.append(nt)
all_df.loc[all_df['Location'] > 1]
# Out:
#         Location Cancer
# p.G12C        16   Luad
# p.G12D         6   Luad
# p.G12V         5   Luad
# p.G12S         2   Luad
# p.G13C         2   Luad
# p.G12V         2   Lscc
# G12D          11  Colon
# G12V           7  Colon
# G13D           4  Colon
# A146T          3  Colon
# K117N          2  Colon
# Q61H           2  Colon
# G12C           2  Colon
# p.G12V        10   Endo
# p.G13D         7   Endo
# p.G12D         6   Endo
# p.G12C         4   Endo

# %%
cnv = c.get_CNV()
cnv['KRAS']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-1231f0c8481d> in <module>
# ----> 1 cnv = c.get_CNV()
#       2 cnv['KRAS']
#
# AttributeError: 'str' object has no attribute 'get_CNV'

# %% [markdown]
# Next, call get_geneotype_all_vars for PTEN for each cancer type. This returns a df with columns for Mutation (type of mutation), Location (location of the mutation), and Mutation_Status (wildtype, single, or multiple mutations).  For samples with multiple mutations, a single mutation was reported based on the following priority: deletion, truncation, missense, amplification, inframe, silent, and wildtype.

# %%
gene = "MUC16"

# %%
endo = en.get_genotype_all_vars(gene) 
gbm = g.get_genotype_all_vars(gene)
hnscc = hn.get_genotype_all_vars(gene)
#ovar = o.get_genotype_all_vars(gene)
#cc = c.get_genotype_all_vars(gene)
colon = col.get_genotype_all_vars(gene)
#ld = l.get_genotype_all_vars(gene)
lscc = ls.get_genotype_all_vars(gene)
#brca = b.get_genotype_all_vars(gene)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-80-18b0b9c35a01> in <module>
#       5 #cc = c.get_genotype_all_vars(gene)
#       6 colon = col.get_genotype_all_vars(gene)
# ----> 7 ld = l.get_genotype_all_vars(gene)
#       8 lscc = ls.get_genotype_all_vars(gene)
#       9 #brca = b.get_genotype_all_vars(gene)
#
# ~\Anaconda3\envs\Research\lib\site-packages\cptac\dataset.py in get_genotype_all_vars(self, mutations_genes, mutations_filter, show_location, mutation_hotspot)
#     402             return pd.Series([sortedcol, location],index=['mutations', 'locations'])
#     403
# --> 404         df = combined.apply(sort, axis=1)
#     405         combined['Mutation'] = df['mutations']
#     406         combined['Location'] = df['locations']
#
# ~\Anaconda3\envs\Research\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~\Anaconda3\envs\Research\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\Anaconda3\envs\Research\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     311
#     312         # compute the result using the series generator
# --> 313         results, res_index = self.apply_series_generator()
#     314
#     315         # wrap results
#
# ~\Anaconda3\envs\Research\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     339         else:
#     340             for i, v in enumerate(series_gen):
# --> 341                 results[i] = self.f(v)
#     342                 keys.append(v.name)
#     343
#
# ~\Anaconda3\envs\Research\lib\site-packages\cptac\dataset.py in sort(row)
#     394                             chosen_indices += [index for index, value in enumerate(sample_mutations_list) if value == mutation]
#     395
# --> 396                 soonest_mutation = sample_mutations_list[chosen_indices[0]]
#     397                 soonest_location = sample_locations_list[chosen_indices[0]]
#     398                 chosen_indices.clear()
#
# IndexError: list index out of range

# %%
# example
endo.head()
# Out:
# Name              Mutation     Location  Mutation_Status
# Patient_ID
# C3L-00006   Wildtype_Tumor  No_mutation   Wildtype_Tumor
# C3L-00008   Wildtype_Tumor  No_mutation   Wildtype_Tumor
# C3L-00032   Wildtype_Tumor  No_mutation   Wildtype_Tumor
# C3L-00090   Wildtype_Tumor  No_mutation   Wildtype_Tumor
# C3L-00098         Deletion     Deletion  Single_mutation

# %% [markdown]
# # Step 2: Match Mutation Labels

# %% [markdown]
# The mutation types in the Colon dataset were named differently. We changed these names to match the other cancers. Nonframeshift insertion was changed to match In_Frame_Ins. Frameshift deletion was canged to match Frame_Shift_Del. Nonsynonymous snv represents a missense mutation in this case.

# %%
colon["Mutation"] = colon['Mutation'].replace(['nonsynonymous SNV'], 'Missense')
colon["Mutation"] = colon['Mutation'].replace(['nonframeshift insertion'], 'In_Frame_Ins')
colon["Mutation"] = colon['Mutation'].replace(['frameshift deletion'], 'Frame_Shift_Del')
colon["Mutation"] = colon['Mutation'].replace(['frameshift insertion'], 'Frame_Shift_Ins')


colon.Mutation.value_counts()
# Out:
# Deletion           55
# Wildtype_Tumor     29
# Missense           17
# Amplification       3
# Frame_Shift_Del     1
# Frame_Shift_Ins     1
# Name: Mutation, dtype: int64

# %% [markdown]
# We simplified labels for the final figure. We grouped mutations together to create the Indel and Truncation categories. In_Frame_Indel includes: In_Frame_Ins and In_Frame_Del. Truncation includes: Nonsense_Mutation, Frame_Shift_Del, and Frame_Shift_Ins.

# %%
# Simplify mutation names, create truncation and indel groups
dfs = [endo, gbm, hnscc, colon, lscc]
for df in dfs:
    df['Mutation'].where(df['Mutation'] != 'Missense_Mutation', 'Missense', inplace = True) # replace when false
    df['Mutation'].where(df['Mutation'] != 'Wildtype_Tumor', 'Wildtype', inplace = True)
    df["Mutation"].where(df['Mutation'] != 'In_Frame_Del', 'Indel', inplace = True)
    df["Mutation"].where(df['Mutation'] != 'Nonsense_Mutation', 'Truncation', inplace = True)
    df["Mutation"].where(df['Mutation'] != 'Frame_Shift_Del', 'Truncation', inplace = True)
    df["Mutation"].where(df['Mutation'] != 'Frame_Shift_Ins', 'Truncation', inplace = True)
    df = df.loc[df['Mutation'] != 'Silent'] # Drop silent
    print(df.Mutation.value_counts())
# Out:
# Wildtype         69
# Missense         13
# Truncation        5
# Amplification     4
# Deletion          4
# Name: Mutation, dtype: int64
# Wildtype         55
# Amplification    31
# Missense          7
# Deletion          1
# Name: Mutation, dtype: int64
# Wildtype         72
# Deletion         15
# Missense         13
# Amplification     4
# Truncation        3
# Name: Mutation, dtype: int64
# Deletion         55
# Wildtype         29
# Missense         17
# Amplification     3
# Truncation        2
# Name: Mutation, dtype: int64
# Deletion         40
# Wildtype         29
# Missense         22
# Amplification    12
# Truncation        2
# Name: Mutation, dtype: int64

# %% [markdown]
# The get_genotype_all_var function created the No_Mutation label when no somatic mutations were found for PTEN in the Luad dataset. This is the same as Wildtype_Tumor.

# %%
ld["Mutation"] = ld['Mutation'].replace(['No_Mutation'], 'Wildtype')

# %% [markdown]
# # Step 3: Create Figure

# %% [markdown]
# Create a list of the mutation dataframes. Create a list of cancer names for the figure legend. Call the plot_mutations function.

# %%
#[endo, gbm, hnscc,
dfs = [endo, gbm, hnscc, colon, lscc]  #ovar, colon, ld, brca, lscc] [endo, gbm, hnscc, colon, lscc]
for df in dfs:
    df = df.loc[df['Mutation'] != 'Silent']
names = ['Endometrial', 'Glioblastoma', 'Head and Neck',  'Colon', 
         'Lung Squamous']
p.figure1_plot_mutations(dfs, names) #save_to_path = "Step1_PTEN.png")

# %% [markdown]
# # Calculate percentage of PTEN deletion in tumors

# %% [markdown]
# The manuscript mentions the percentages of PTEN deletions for the 7 cancers with frequent deletions.

# %%
cancer_dfs = {'Endo':endo, 'Gbm':gbm, 'Hnscc':hnscc, 'Ov':ovar, 'Kidney':cc, 'Colon':colon, 
              'Luad':ld, 'Brca':brca, 'Lscc':lscc}
for cancer in cancer_dfs:
    df = cancer_dfs[cancer]
    vc = df.Mutation.value_counts()
    total = len(df)
    cnv_del = vc.Deletion
    print(cancer)
    print('total_tumor_samples:',total)
    print(cnv_del,'/',total,'=', cnv_del/total,'\n')

# %% [markdown]
# # Calculate percentage of PTEN truncation in tumors

# %% [markdown]
# The manuscript mentions the exact percentage of PTEN truncation mutations for Endometrial.

# %%
cancer_dfs = {'Endo':endo}
for cancer in cancer_dfs:
    df = cancer_dfs[cancer]
    vc = df.Mutation.value_counts()
    total = len(df)
    cnv_del = vc.Truncation
    print(cancer)
    print('total_tumor_samples:',total)
    print(cnv_del,'/',total,'=', cnv_del/total,'\n')
