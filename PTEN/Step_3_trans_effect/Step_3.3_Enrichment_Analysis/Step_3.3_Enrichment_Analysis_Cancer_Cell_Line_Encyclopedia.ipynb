# %% [markdown]
# # Run a Gene Set Enrichment Analysis using KEGG_2016

# %% [markdown]
# This notebook looks at the significant genes in at least one cancer. GSEA is used to recognize pathways with multiple significant genes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as p

# %% [markdown]
# # Step 1: Run GSEA for significant genes in at least 1 cancer

# %% [markdown]
# First read in sig_pval_all_proteins.csv into a df. This csv file contains only genes with a significant p-value in at least one cancer. Then run GSEA using a list of genes from the df.

# %%
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'
df = pd.read_csv(root+R'\sig_pval_heatmap.csv')

prot_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='Cancer_Cell_Line_Encyclopedia', 
                       outdir='/Enrichr')
#gp.get_library_name()
# Out:
# 2020-05-11 12:49:05,620 Warning: No enrich terms using library Cancer_Cell_Line_Encyclopedia when cutoff = 0.05

# %%
prot_enr.res2d.head()
# Out:
#                                          Term Overlap   P-value  \
# 0  OCIAML3 HAEMATOPOIETIC AND LYMPHOID TISSUE  73/346  0.000059
# 1  OCIAML5 HAEMATOPOIETIC AND LYMPHOID TISSUE  56/295  0.004962
# 2    MV411 HAEMATOPOIETIC AND LYMPHOID TISSUE  65/352  0.005098
# 3     PL21 HAEMATOPOIETIC AND LYMPHOID TISSUE  58/316  0.008844
# 4    MOLM6 HAEMATOPOIETIC AND LYMPHOID TISSUE  47/247  0.009019
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.056926            0                     0    1.561678
# 1          1.000000            0                     0    1.405111
# 2          1.000000            0                     0    1.366833
# 3          1.000000            0                     0    1.358581
# 4          1.000000            0                     0    1.408463
#
#    Combined Score                                              Genes  \
# 0       15.211053  ARHGAP9;CD86;TRAF3IP3;ANKRD13D;ELL;MAST3;DENND...
# 1        7.455368  FAAH;ITGAM;LST1;ITGB2;ITGAL;KIAA0930;PSTPIP1;R...
# 2        7.215400  ARHGAP9;ANKRD13D;MAST3;SPPL2B;LST1;TREM2;ITGAL...
# 3        6.423400  CPNE9;IPO11;TRAF3IP3;LST1;GIMAP1;ITGB2;OLA1;IT...
# 4        6.631680  ARHGAP9;CSF1R;TRAF3IP3;ITGAM;LST1;ICAM3;PLD4;D...
#
#                         Gene_set
# 0  Cancer_Cell_Line_Encyclopedia
# 1  Cancer_Cell_Line_Encyclopedia
# 2  Cancer_Cell_Line_Encyclopedia
# 3  Cancer_Cell_Line_Encyclopedia
# 4  Cancer_Cell_Line_Encyclopedia

# %% [markdown]
# # Run GSEA for significant genes in multiple cancers

# %%
df = pd.read_csv(root+R'\mult_sig_pval_heatmap.csv')

mult_sig_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = mult_sig_list, description='Tumor_partition', gene_sets='Cancer_Cell_Line_Encyclopedia', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head()
# Out:
#                                          Term Overlap       P-value  \
# 0  OCIAML3 HAEMATOPOIETIC AND LYMPHOID TISSUE  24/346  2.378002e-07
# 1    MOTN1 HAEMATOPOIETIC AND LYMPHOID TISSUE  27/478  2.380123e-06
# 2     PL21 HAEMATOPOIETIC AND LYMPHOID TISSUE  20/316  9.556842e-06
# 3   MOLT16 HAEMATOPOIETIC AND LYMPHOID TISSUE  19/331  6.050261e-05
# 4     HL60 HAEMATOPOIETIC AND LYMPHOID TISSUE  19/336  7.384750e-05
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.000230            0                     0    3.375385
# 1          0.001151            0                     0    2.748679
# 2          0.003080            0                     0    3.079861
# 3          0.014627            0                     0    2.793276
# 4          0.014282            0                     0    2.751709
#
#    Combined Score                                              Genes  \
# 0       51.480815  CCR1;ARHGAP9;KDM3A;TRAF3IP3;PRKCB;MAST3;ITGB2;...
# 1       35.590882  TRAF3IP3;RGS14;MAST3;WAS;PIK3CD;RASAL3;STK10;P...
# 2       35.597811  CCR1;TRAF3IP3;PRKCB;ITGB2;WAS;CYBB;APOBR;PRAM1...
# 3       27.130594  ARHGAP9;TRAF3IP3;PRKCB;WAS;APOBR;LIME1;ARHGAP2...
# 4       26.178406  ARHGAP9;VPS18;AKAP8;WAS;CYBB;APOBR;RASAL3;PRAM...
#
#                         Gene_set
# 0  Cancer_Cell_Line_Encyclopedia
# 1  Cancer_Cell_Line_Encyclopedia
# 2  Cancer_Cell_Line_Encyclopedia
# 3  Cancer_Cell_Line_Encyclopedia
# 4  Cancer_Cell_Line_Encyclopedia
