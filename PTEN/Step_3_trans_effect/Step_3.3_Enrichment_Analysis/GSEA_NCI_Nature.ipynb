# %% [markdown]
# # Run a Gene Set Enrichment Analysis using NCI_Nature

# %% [markdown]
# This notebook looks at the significant genes in at least one cancer. GSEA is used to recognize pathways with multiple significant genes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as p

# %% [markdown]
# # Step 1: Run GSEA for significant genes in at least 1 cancer

# %% [markdown]
# First read in sig_pval_all_proteins.csv into a df. This csv file contains only genes with a significant p-value in at least one cancer. Then run GSEA using a list of genes from the df.

# %%
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'
df = pd.read_csv(root+R'\sig_pval_heatmap.csv')

prot_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
print(len(prot_list))
prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='NCI-Nature_2016', 
                       outdir='/Enrichr')
#gp.get_library_name() #Cancer_Cell_Line_Encyclopedia #NCI-60_Cancer_Cell_Lines
# Out:
# 2611

# %%
prot_enr.res2d.head()
# Out:
#                                                 Term Overlap   P-value  \
# 0  Regulation of RAC1 activity Homo sapiens 351aa...   17/38  0.000002
# 1  Class I PI3K signaling events Homo sapiens 12b...   19/48  0.000004
# 2  Signaling events mediated by TCPTP Homo sapien...   15/42  0.000160
# 3  FAS (CD95) signaling pathway Homo sapiens 79cc...   14/38  0.000180
# 4  Fanconi anemia pathway Homo sapiens 6befb873-6...   16/47  0.000187
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.000347            0                     0    3.426798
# 1          0.000406            0                     0    3.032044
# 2          0.011169            0                     0    2.735679
# 3          0.009425            0                     0    2.822069
# 4          0.007809            0                     0    2.607626
#
#    Combined Score                                              Genes  \
# 0       45.605952  DOCK6;ARHGAP9;RASGRF2;RAP1GDS1;VAV1;DEF6;EPS8;...
# 1       37.774182  HSP90AA1;SYK;PLEKHA1;PDPK1;PTEN;PIK3CD;PIK3R1;...
# 2       23.905352  CSF1R;STAT1;PIK3CD;EIF2AK2;PIK3R1;EGFR;VEGFA;P...
# 3       24.327490  SYK;CHUK;RFC1;PDPK1;CLTC;PIK3CD;PIK3R1;MAPK10;...
# 4       22.387464  FANCI;RFC5;RFC3;WDR48;RFC4;RFC2;RMI1;TOP3A;RPA...
#
#           Gene_set
# 0  NCI-Nature_2016
# 1  NCI-Nature_2016
# 2  NCI-Nature_2016
# 3  NCI-Nature_2016
# 4  NCI-Nature_2016

# %% [markdown]
# # Run GSEA for significant genes in multiple cancers

# %%
df = pd.read_csv(root+R'\mult_sig_pval_heatmap.csv')

mult_sig_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = mult_sig_list, description='Tumor_partition', gene_sets='NCI-Nature_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head(7)
# Out:
#                                                 Term Overlap       P-value  \
# 0  Class I PI3K signaling events Homo sapiens 12b...    9/48  4.663251e-08
# 1  BCR signaling pathway Homo sapiens acbf44e2-61...   10/64  5.157805e-08
# 2  TCR signaling in naive CD4+ T cells Homo sapie...    8/64  6.491915e-06
# 3  IL8- and CXCR2-mediated signaling events Homo ...    6/34  1.255370e-05
# 4  ATR signaling pathway Homo sapiens 8991cbac-61...    6/39  2.852864e-05
# 5  CXCR4-mediated signaling events Homo sapiens 4...   8/100  1.683610e-04
# 6  FAS (CD95) signaling pathway Homo sapiens 79cc...    5/38  2.900838e-04
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.000010            0                     0   12.057878
# 1          0.000005            0                     0   10.048232
# 2          0.000452            0                     0    8.038585
# 3          0.000656            0                     0   11.348591
# 4          0.001192            0                     0    9.893643
# 5          0.005865            0                     0    5.144695
# 6          0.008661            0                     0    8.461669
#
#    Combined Score                                              Genes  \
# 0      203.548648  ZAP70;SYK;PIK3CA;PTEN;BLNK;PLCG2;BTK;PIK3CD;CYTH1
# 1      168.611028  MAP4K1;PPP3CB;PTPRC;SYK;CHUK;PIK3CA;PTEN;BLNK;...
# 2       96.020522         MAP4K1;ZAP70;CD4;PTPRC;CHUK;PRKCB;PTEN;WAS
# 3      128.074465                  GNG2;PRKCB;RAC2;ELMO1;DOCK2;GNAI2
# 4      103.533042                    RFC3;RFC4;MCM7;RFC2;TOPBP1;MCM2
# 5       44.704308       PAK1;CD4;PTPRC;GNG2;PIK3CA;PTEN;PIK3CD;GNAI2
# 6       68.923173                         SYK;CHUK;PIK3CA;BTK;PIK3CD
#
#           Gene_set
# 0  NCI-Nature_2016
# 1  NCI-Nature_2016
# 2  NCI-Nature_2016
# 3  NCI-Nature_2016
# 4  NCI-Nature_2016
# 5  NCI-Nature_2016
# 6  NCI-Nature_2016
