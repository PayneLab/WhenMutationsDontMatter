# %% [markdown]
# # Run a Gene Set Enrichment Analysis using NCI-60_Cancer_Cell_Lines

# %% [markdown]
# This notebook looks at the significant genes in at least one cancer. GSEA is used to recognize pathways with multiple significant genes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as p

# %% [markdown]
# # Step 1: Run GSEA for significant genes in at least 1 cancer

# %% [markdown]
# First read in sig_pval_all_proteins.csv into a df. This csv file contains only genes with a significant p-value in at least one cancer. Then run GSEA using a list of genes from the df.

# %%
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'
df = pd.read_csv(root+R'\sig_pval_heatmap.csv')

prot_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='NCI-60_Cancer_Cell_Lines', 
                       outdir='/Enrichr')
#gp.get_library_name()

# %%
prot_enr.res2d.head()
# Out:
#        Term  Overlap       P-value  Adjusted P-value  Old P-value  \
# 0       RL7  145/521  2.118519e-18      1.970223e-16            0
# 1    HCT116  142/574  1.754155e-13      8.156821e-12            0
# 2   RS11846   95/360  4.459175e-11      1.382344e-09            0
# 3    JURKAT   90/374  2.027554e-08      4.714063e-07            0
# 4  HEK 293T  115/529  1.015175e-07      1.888225e-06            0
#
#    Old Adjusted P-value  Odds Ratio  Combined Score  \
# 0                     0    2.060037       83.834866
# 1                     0    1.831138       53.783491
# 2                     0    1.953286       46.553579
# 3                     0    1.781212       31.552119
# 4                     0    1.609114       25.911619
#
#                                                Genes                  Gene_set
# 0  ITSN2;WIPF1;GMFG;TMEM97;IKZF1;RCBTB1;CCDC28A;L...  NCI-60_Cancer_Cell_Lines
# 1  ZNF330;NUP188;NUDT2;CWC25;PWP2;IPO4;YY1;EIF4EN...  NCI-60_Cancer_Cell_Lines
# 2  FKBP11;CD86;DOCK6;RBM25;TRAF3IP3;KLHL36;WIPF1;...  NCI-60_Cancer_Cell_Lines
# 3  SMG1;TRAF3IP3;NUP188;SPPL2B;PTEN;GIMAP4;IKZF1;...  NCI-60_Cancer_Cell_Lines
# 4  RIF1;MPI;SMC2;CCDC28A;PCMT1;PNN;RASSF1;RBMX2;C...  NCI-60_Cancer_Cell_Lines

# %% [markdown]
# # Run GSEA for significant genes in multiple cancers

# %%
df = pd.read_csv(root+R'\mult_sig_pval_heatmap.csv')

mult_sig_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = mult_sig_list, description='Tumor_partition', gene_sets='NCI-60_Cancer_Cell_Lines', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head()
# Out:
#       Term Overlap       P-value  Adjusted P-value  Old P-value  \
# 0      RL7  43/521  8.715981e-15      8.105863e-13            0
# 1  RS11846  31/360  1.928718e-11      8.968540e-10            0
# 2   JURKAT  25/374  2.680127e-07      8.308393e-06            0
# 3   HCT116  28/574  2.389210e-05      5.554914e-04            0
# 4    MOLT4  22/426  7.853627e-05      1.460775e-03            0
#
#    Old Adjusted P-value  Odds Ratio  Combined Score  \
# 0                     0    4.016233      130.019995
# 1                     0    4.190322      103.381859
# 2                     0    3.252794       49.222034
# 3                     0    2.373746       25.261320
# 4                     0    2.513051       23.753230
#
#                                                Genes                  Gene_set
# 0  TOP2B;USP14;USP34;PTEN;WAS;STK4;STK10;PTDSS1;P...  NCI-60_Cancer_Cell_Lines
# 1  TRAF3IP3;RGS19;CAB39;GMPR2;PTEN;NAT10;ADO;INPP...  NCI-60_Cancer_Cell_Lines
# 2  TRAF3IP3;PTEN;SMC2;PCM1;EXOSC9;ARHGDIB;NUP210;...  NCI-60_Cancer_Cell_Lines
# 3  PWP2;USP39;ELAVL1;NUP160;DHX30;CHAF1B;EMG1;PUF...  NCI-60_Cancer_Cell_Lines
# 4  CPSF4;RFC4;RGS19;ITGA4;MCM7;LIG3;USP39;CORO1A;...  NCI-60_Cancer_Cell_Lines
