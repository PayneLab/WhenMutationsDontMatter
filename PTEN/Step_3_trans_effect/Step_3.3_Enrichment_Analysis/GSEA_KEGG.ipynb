# %% [markdown]
# # Run a Gene Set Enrichment Analysis using KEGG_2016

# %% [markdown]
# This notebook looks at the significant genes in at least one cancer. GSEA is used to recognize pathways with multiple significant genes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as p

# %% [markdown]
# # Step 1: Run GSEA for significant genes in at least 1 cancer

# %% [markdown]
# First read in sig_pval_all_proteins.csv into a df. This csv file contains only genes with a significant p-value in at least one cancer. Then run GSEA using a list of genes from the df.

# %%
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'
df = pd.read_csv(root+R'\sig_pval_heatmap.csv')

prot_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head(25)
# Out:
#                                                  Term   Overlap       P-value  \
# 0                   Spliceosome Homo sapiens hsa03040    88/134  2.936551e-44
# 1                 RNA transport Homo sapiens hsa03013    77/172  1.113872e-23
# 2               DNA replication Homo sapiens hsa03030     23/36  3.613010e-12
# 3     mRNA surveillance pathway Homo sapiens hsa03015     38/91  2.801846e-11
# 4               Mismatch repair Homo sapiens hsa03430     15/23  1.473843e-08
# 5   Ribosome biogenesis in eukaryotes Homo sapiens...     33/89  1.975247e-08
# 6   Fc gamma R-mediated phagocytosis Homo sapiens ...     33/93  6.811503e-08
# 7   Epstein-Barr virus infection Homo sapiens hsa0...    55/202  1.726504e-07
# 8         Pyrimidine metabolism Homo sapiens hsa00240    34/105  5.332798e-07
# 9    Osteoclast differentiation Homo sapiens hsa04380    39/132  1.146033e-06
# 10            Purine metabolism Homo sapiens hsa00230    46/176  5.676728e-06
# 11                    Phagosome Homo sapiens hsa04145    41/154  1.104864e-05
# 12           Metabolic pathways Homo sapiens hsa01100  219/1239  1.121025e-05
# 13                  Endocytosis Homo sapiens hsa04144    59/259  3.063775e-05
# 14     Herpes simplex infection Homo sapiens hsa05168    45/185  4.974185e-05
# 15                     Ribosome Homo sapiens hsa03010    36/137  4.986118e-05
# 16  B cell receptor signaling pathway Homo sapiens...     23/73  5.729734e-05
# 17   Non-small cell lung cancer Homo sapiens hsa05223     19/56  8.127438e-05
# 18  Inositol phosphate metabolism Homo sapiens hsa...     21/71  3.175476e-04
# 19                   Cell cycle Homo sapiens hsa04110    31/124  4.180408e-04
# 20  Natural killer cell mediated cytotoxicity Homo...    33/135  4.301966e-04
# 21  Phosphatidylinositol signaling system Homo sap...     26/98  4.467227e-04
# 22                  Influenza A Homo sapiens hsa05164    40/175  5.031604e-04
# 23               RNA polymerase Homo sapiens hsa03020     12/32  5.897313e-04
# 24         Base excision repair Homo sapiens hsa03410     12/33  8.138012e-04
#
#     Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0       8.604095e-42            0                     0    4.860965
# 1       1.631823e-21            0                     0    3.313652
# 2       3.528707e-10            0                     0    4.729007
# 3       2.052353e-09            0                     0    3.090914
# 4       8.636717e-07            0                     0    4.827342
# 5       9.645788e-07            0                     0    2.744534
# 6       2.851101e-06            0                     0    2.626489
# 7       6.323322e-06            0                     0    2.015375
# 8       1.736122e-05            0                     0    2.396814
# 9       3.357876e-05            0                     0    2.186932
# 10      1.512074e-04            0                     0    1.934594
# 11      2.697709e-04            0                     0    1.970642
# 12      2.526618e-04            0                     0    1.308330
# 13      6.412044e-04            0                     0    1.686153
# 14      9.716241e-04            0                     0    1.800468
# 15      9.130829e-04            0                     0    1.945031
# 16      9.875365e-04            0                     0    2.332113
# 17      1.322966e-03            0                     0    2.511367
# 18      4.896918e-03            0                     0    2.189302
# 19      6.124297e-03            0                     0    1.850481
# 20      6.002266e-03            0                     0    1.809359
# 21      5.949534e-03            0                     0    1.963776
# 22      6.409826e-03            0                     0    1.691868
# 23      7.199636e-03            0                     0    2.775722
# 24      9.537751e-03            0                     0    2.691609
#
#     Combined Score                                              Genes  \
# 0       487.246193  RBM25;EIF4A3;DDX42;HNRNPU;PRPF19;USP39;EFTUD2;...
# 1       175.131871  CYFIP2;NUP107;NUP188;RPP30;EIF4A3;PHAX;PNN;XPO...
# 2       124.592696  RFC5;FEN1;RFC3;PCNA;RFC4;MCM7;RFC1;RFC2;PRIM1;...
# 3        75.103503  SMG1;RBM8A;RNMT;CSTF3;EIF4A3;MSI1;PPP2R2A;MSI2...
# 4        87.050531  RFC5;RFC3;PCNA;RFC4;RFC1;RFC2;RPA1;MLH1;POLD3;...
# 5        48.687995  NVL;WDR3;RPP30;HEATR1;NAT10;NMD3;PWP2;WDR43;NO...
# 6        43.342505  WAS;PIK3CD;ASAP1;PIK3R1;PLD1;PIK3CG;PAK1;SCIN;...
# 7        31.383421  ATF2;CDKN1B;AKAP8L;PIK3CD;ITGAL;PIK3CG;ICAM1;P...
# 8        34.620103  DTYMK;PRIM1;NUDT2;NT5C2;POLD3;POLR2B;POLD1;POL...
# 9        29.915493  CSF1R;PIK3CD;TREM2;PIK3R1;PIK3CG;RELB;PPP3CB;A...
# 10       23.368222  PDE1B;PDE1A;GMPR2;PRIM1;GMPS;ADK;NUDT2;NTPCR;N...
# 11       22.491340  ATP6V1A;RAB5B;ITGAM;TFRC;ITGB2;CORO1A;CTSS;TUB...
# 12       14.913243  PGAP1;EPRS;ENO2;NADSYN1;GLS;SCP2;FLAD1;ANPEP;P...
# 13       17.524653  TFRC;WIPF1;SH3KBP1;CLTC;ARRB1;ARRB2;ZFYVE27;CA...
# 14       17.840234  SP100;CUL1;C3;IFIH1;NXF1;HLA-DMA;TBK1;C1QBP;CA...
# 15       19.268001  RPL4;RPL10;RPL12;RPLP0;MRPL17;MRPL15;RPL10A;RP...
# 16       22.778347  VAV3;MAP2K1;SYK;CHUK;CD81;PRKCB;PIK3CD;NFATC2;...
# 17       23.651252  PRKCG;MAP2K1;PDPK1;PRKCB;PIK3CD;PIK3R1;STK4;FH...
# 18       17.634568  MTMR2;ISYNA1;PTEN;PIK3CD;PIK3CG;PIK3C2B;MTMR7;...
# 19       14.396617  HDAC2;CDKN1B;PCNA;MCM7;PRKDC;HDAC1;CUL1;BUB1B;...
# 20       14.024830  SHC3;ITGB2;PIK3CD;PIK3R1;ITGAL;PIK3CG;ICAM1;PP...
# 21       15.147728  MTMR2;ITPR1;PTEN;PIK3CD;PIK3R1;PIK3CG;MTMR7;PI...
# 22       12.849067  ATF2;PIK3CD;ADAR;PIK3R1;PIK3CG;ICAM1;IFIH1;NXF...
# 23       20.639832  POLR3B;POLR2B;POLR3C;POLR1A;POLR2C;POLR1B;POLR...
# 24       19.147552  POLB;POLD3;POLE4;FEN1;PCNA;PARP1;NTHL1;POLD1;T...
#
#      Gene_set
# 0   KEGG_2016
# 1   KEGG_2016
# 2   KEGG_2016
# 3   KEGG_2016
# 4   KEGG_2016
# 5   KEGG_2016
# 6   KEGG_2016
# 7   KEGG_2016
# 8   KEGG_2016
# 9   KEGG_2016
# 10  KEGG_2016
# 11  KEGG_2016
# 12  KEGG_2016
# 13  KEGG_2016
# 14  KEGG_2016
# 15  KEGG_2016
# 16  KEGG_2016
# 17  KEGG_2016
# 18  KEGG_2016
# 19  KEGG_2016
# 20  KEGG_2016
# 21  KEGG_2016
# 22  KEGG_2016
# 23  KEGG_2016
# 24  KEGG_2016

# %% [markdown]
# # Run GSEA for significant genes in multiple cancers

# %%
df = pd.read_csv(root+R'\mult_sig_pval_heatmap.csv')

mult_sig_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = mult_sig_list, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head()
# Out:
#                                                 Term Overlap       P-value  \
# 0                  Spliceosome Homo sapiens hsa03040  21/134  4.645154e-13
# 1              DNA replication Homo sapiens hsa03030   12/36  3.876348e-12
# 2                RNA transport Homo sapiens hsa03013  19/172  2.855921e-09
# 3  Ribosome biogenesis in eukaryotes Homo sapiens...   14/89  3.615167e-09
# 4              Mismatch repair Homo sapiens hsa03430    8/23  1.112006e-08
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0      1.361030e-10            0                     0    7.626103
# 1      5.678850e-10            0                     0   16.220600
# 2      2.789283e-07            0                     0    5.375431
# 3      2.648110e-07            0                     0    7.654665
# 4      6.516354e-07            0                     0   16.925844
#
#    Combined Score                                              Genes  \
# 0      216.564409  DDX5;NCBP1;NCBP2;DDX23;DDX42;THOC3;PRPF40A;THO...
# 1      426.214559  RFC5;RFC3;PCNA;RFC4;MCM7;RFC1;RFC2;MCM3;MCM4;M...
# 2      105.755548  RANBP2;EIF5B;NUP210;NUP155;NCBP1;NUP133;NCBP2;...
# 3      148.792361  UTP6;IMP3;WDR3;HEATR1;NAT10;WDR75;IMP4;PWP2;UT...
# 4      309.988622            RFC5;MSH6;RFC3;PCNA;RFC4;RFC1;MSH2;RFC2
#
#     Gene_set
# 0  KEGG_2016
# 1  KEGG_2016
# 2  KEGG_2016
# 3  KEGG_2016
# 4  KEGG_2016

# %%
prot_enr.res2d.Genes[1]
# Out:
# 'RFC5;RFC3;PCNA;RFC4;MCM7;RFC1;RFC2;MCM3;MCM4;MCM5;MCM6;MCM2'
