# %% [markdown]
# # Run a Gene Set Enrichment Analysis using KEGG_2016

# %% [markdown]
# This notebook looks at the significant genes in at least one cancer. GSEA is used to recognize pathways with multiple significant genes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as p

# %% [markdown]
# # Step 1: Run GSEA for significant genes in at least 1 cancer

# %% [markdown]
# First read in sig_pval_all_proteins.csv into a df. This csv file contains only genes with a significant p-value in at least one cancer. Then run GSEA using a list of genes from the df.

# %%
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'
df = pd.read_csv(root+R'\sig_pval_heatmap.csv')

prot_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head(25)
# Out:
#                                                  Term Overlap       P-value  \
# 0                   Spliceosome Homo sapiens hsa03040  21/134  4.645154e-13
# 1               DNA replication Homo sapiens hsa03030   12/36  3.876348e-12
# 2                 RNA transport Homo sapiens hsa03013  19/172  2.855921e-09
# 3   Ribosome biogenesis in eukaryotes Homo sapiens...   14/89  3.615167e-09
# 4               Mismatch repair Homo sapiens hsa03430    8/23  1.112006e-08
# 5   B cell receptor signaling pathway Homo sapiens...   11/73  2.739215e-07
# 6   Fc gamma R-mediated phagocytosis Homo sapiens ...   12/93  4.488603e-07
# 7     mRNA surveillance pathway Homo sapiens hsa03015   11/91  2.616639e-06
# 8   Chemokine signaling pathway Homo sapiens hsa04062  15/187  7.883292e-06
# 9   Inositol phosphate metabolism Homo sapiens hsa...    9/71  1.446393e-05
# 10  Natural killer cell mediated cytotoxicity Homo...  12/135  2.296501e-05
# 11  Leukocyte transendothelial migration Homo sapi...  11/118  3.224708e-05
# 12  Phosphatidylinositol signaling system Homo sap...   10/98  3.371629e-05
# 13                   Cell cycle Homo sapiens hsa04110  11/124  5.106827e-05
# 14   Osteoclast differentiation Homo sapiens hsa04380  11/132  9.029663e-05
# 15     Primary immunodeficiency Homo sapiens hsa05340    6/37  9.840957e-05
# 16  NF-kappa B signaling pathway Homo sapiens hsa0...    9/93  1.255920e-04
# 17   Nucleotide excision repair Homo sapiens hsa03420    6/47  3.823370e-04
# 18  Fc epsilon RI signaling pathway Homo sapiens h...    7/68  4.846980e-04
# 19        Ras signaling pathway Homo sapiens hsa04014  13/227  8.816634e-04
# 20          Platelet activation Homo sapiens hsa04611   9/122  9.461645e-04
# 21  T cell receptor signaling pathway Homo sapiens...   8/104  1.373698e-03
# 22       mTOR signaling pathway Homo sapiens hsa04150    6/60  1.425116e-03
# 23       VEGF signaling pathway Homo sapiens hsa04370    6/61  1.553675e-03
# 24  Vasopressin-regulated water reabsorption Homo ...    5/44  2.009359e-03
#
#     Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0       1.361030e-10            0                     0    7.626103
# 1       5.678850e-10            0                     0   16.220600
# 2       2.789283e-07            0                     0    5.375431
# 3       2.648110e-07            0                     0    7.654665
# 4       6.516354e-07            0                     0   16.925844
# 5       1.337650e-05            0                     0    7.332600
# 6       1.878801e-05            0                     0    6.278942
# 7       9.583440e-05            0                     0    5.882196
# 8       2.566449e-04            0                     0    3.903353
# 9       4.237931e-04            0                     0    6.168397
# 10      6.117045e-04            0                     0    4.325493
# 11      7.873663e-04            0                     0    4.536270
# 12      7.599132e-04            0                     0    4.965490
# 13      1.068786e-03            0                     0    4.316773
# 14      1.763794e-03            0                     0    4.055150
# 15      1.802125e-03            0                     0    7.891103
# 16      2.164614e-03            0                     0    4.709206
# 17      6.223597e-03            0                     0    6.212145
# 18      7.474553e-03            0                     0    5.009303
# 19      1.291637e-02            0                     0    2.786799
# 20      1.320125e-02            0                     0    3.589805
# 21      1.829516e-02            0                     0    3.743215
# 22      1.815473e-02            0                     0    4.866180
# 23      1.896778e-02            0                     0    4.786407
# 24      2.354968e-02            0                     0    5.529750
#
#     Combined Score                                              Genes  \
# 0       216.564409  DDX5;NCBP1;NCBP2;DDX23;DDX42;THOC3;PRPF40A;THO...
# 1       426.214559  RFC5;RFC3;PCNA;RFC4;MCM7;RFC1;RFC2;MCM3;MCM4;M...
# 2       105.755548  RANBP2;EIF5B;NUP210;NUP155;NCBP1;NUP133;NCBP2;...
# 3       148.792361  UTP6;IMP3;WDR3;HEATR1;NAT10;WDR75;IMP4;PWP2;UT...
# 4       309.988622            RFC5;MSH6;RFC3;PCNA;RFC4;RFC1;MSH2;RFC2
# 5       110.798698  PPP3CB;SYK;CHUK;PIK3CA;PRKCB;INPP5D;BLNK;RAC2;...
# 6        91.776495  PAK1;PTPRC;SYK;PIK3CA;MYO10;PRKCB;INPP5D;RAC2;...
# 7        75.607508  CPSF4;NCBP1;CPSF1;NCBP2;RNMT;CPSF3;CPSF2;PPP2R...
# 8        45.867384  CCR1;CHUK;PRKCB;WAS;PIK3CD;GNAI2;PREX1;PAK1;RA...
# 9        68.739711  PIK3CA;SYNJ1;INPP5D;PTEN;PLCG2;PIK3CD;PIP4K2A;...
# 10       46.202925  ZAP70;PPP3CB;PAK1;SYK;PIK3CA;PRKCB;ITGB2;PLCG2...
# 11       46.914476  RAP1A;ITGA4;PIK3CA;PRKCB;ITGB2;PLCG2;RAC2;PECA...
# 12       51.132278  SYNJ1;PIK3CA;PRKCB;INPP5D;PLCG2;PTEN;PIP4K2A;P...
# 13       42.659846  HDAC2;PCNA;MCM7;PRKDC;MCM3;BUB1B;MCM4;MCM5;MCM...
# 14       37.763222  PPP3CB;SYK;CHUK;PIK3CA;BTK;PLCG2;BLNK;CYBB;PIK...
# 15       72.806254                     ZAP70;CD4;PTPRC;IGLL1;BLNK;BTK
# 16       42.300317    ZAP70;SYK;CHUK;PARP1;PRKCB;BLNK;BTK;PLCG2;NFKB2
# 17       48.884659                      RFC5;RFC3;PCNA;RFC4;RFC1;RFC2
# 18       38.230923            SYK;PIK3CA;INPP5D;RAC2;BTK;PLCG2;PIK3CD
# 19       19.601510  CHUK;PRKCB;PIK3CD;RASAL3;STK4;ZAP70;PAK1;RAP1A...
# 20       24.996150  APBB1IP;RAP1A;SYK;PIK3CA;BTK;PLCG2;PIK3CD;PLCB...
# 21       24.668722     ZAP70;PPP3CB;PAK1;CD4;PTPRC;CHUK;PIK3CA;PIK3CD
# 22       31.890522             PIK3CA;CAB39;PRKCB;RPS6KA1;PTEN;PIK3CD
# 23       30.954324              PPP3CB;PIK3CA;PRKCB;RAC2;PLCG2;PIK3CD
# 24       34.339414                    DCTN6;DCTN5;DCTN1;DCTN4;ARHGDIB
#
#      Gene_set
# 0   KEGG_2016
# 1   KEGG_2016
# 2   KEGG_2016
# 3   KEGG_2016
# 4   KEGG_2016
# 5   KEGG_2016
# 6   KEGG_2016
# 7   KEGG_2016
# 8   KEGG_2016
# 9   KEGG_2016
# 10  KEGG_2016
# 11  KEGG_2016
# 12  KEGG_2016
# 13  KEGG_2016
# 14  KEGG_2016
# 15  KEGG_2016
# 16  KEGG_2016
# 17  KEGG_2016
# 18  KEGG_2016
# 19  KEGG_2016
# 20  KEGG_2016
# 21  KEGG_2016
# 22  KEGG_2016
# 23  KEGG_2016
# 24  KEGG_2016

# %% [markdown]
# # Run GSEA for significant genes in multiple cancers

# %%
df = pd.read_csv(root+R'\mult_sig_pval_heatmap.csv')

mult_sig_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = mult_sig_list, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head()
# Out:
#                                                 Term Overlap       P-value  \
# 0                  Spliceosome Homo sapiens hsa03040  21/134  4.645154e-13
# 1              DNA replication Homo sapiens hsa03030   12/36  3.876348e-12
# 2                RNA transport Homo sapiens hsa03013  19/172  2.855921e-09
# 3  Ribosome biogenesis in eukaryotes Homo sapiens...   14/89  3.615167e-09
# 4              Mismatch repair Homo sapiens hsa03430    8/23  1.112006e-08
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0      1.361030e-10            0                     0    7.626103
# 1      5.678850e-10            0                     0   16.220600
# 2      2.789283e-07            0                     0    5.375431
# 3      2.648110e-07            0                     0    7.654665
# 4      6.516354e-07            0                     0   16.925844
#
#    Combined Score                                              Genes  \
# 0      216.564409  DDX5;NCBP1;NCBP2;DDX23;DDX42;THOC3;PRPF40A;THO...
# 1      426.214559  RFC5;RFC3;PCNA;RFC4;MCM7;RFC1;RFC2;MCM3;MCM4;M...
# 2      105.755548  RANBP2;EIF5B;NUP210;NUP155;NCBP1;NUP133;NCBP2;...
# 3      148.792361  UTP6;IMP3;WDR3;HEATR1;NAT10;WDR75;IMP4;PWP2;UT...
# 4      309.988622            RFC5;MSH6;RFC3;PCNA;RFC4;RFC1;MSH2;RFC2
#
#     Gene_set
# 0  KEGG_2016
# 1  KEGG_2016
# 2  KEGG_2016
# 3  KEGG_2016
# 4  KEGG_2016
