# %% [markdown]
# # Create Heat Map for significant Processing pre-mRNA genes

# %% [markdown]
# This notebook looks at the significant genes in at least one cancer in the DNA Replication pathway. Pancancer heat maps are created with circle size showing significance and color showing differences in median.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as p

# %% [markdown]
# # Step 1: Run GSEA for significant genes in at least 1 cancer

# %% [markdown]
# First read in sig_pval_all_proteins.csv into a df. This csv file contains only genes with a significant p-value in at least one cancer. Then run GSEA using a list of genes from the df.

# %%
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'
sig_df = pd.read_csv(root+R'\sig_pval_heatmap.csv')

prot_list = list(sig_df.Proteomics) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='Reactome_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head()
# Out:
#                                                 Term   Overlap       P-value  \
# 0  Processing of Capped Intron-Containing Pre-mRN...   123/193  3.047452e-59
# 1           Gene Expression Homo sapiens R-HSA-74160  452/1631  6.421603e-57
# 2  mRNA Splicing - Major Pathway Homo sapiens R-H...    92/134  8.907630e-49
# 3             mRNA Splicing Homo sapiens R-HSA-72172    92/144  1.076002e-44
# 4      Infectious disease Homo sapiens R-HSA-5663205   124/348  5.502170e-26
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0      4.662602e-56            0                     0    4.717289
# 1      4.912526e-54            0                     0    2.051300
# 2      4.542892e-46            0                     0    5.081918
# 3      4.115706e-42            0                     0    4.729007
# 4      1.683664e-23            0                     0    2.637467
#
#    Combined Score                                              Genes  \
# 0      635.599053  NUP107;NUP188;EIF4A3;HNRNPU;EFTUD2;SNRPD2;SNRP...
# 1      265.412919  TDRKH;RPL4;ATF2;MDC1;NUP107;HNRNPU;EHMT1;PHAX;...
# 2      562.262229  EIF4A3;HNRNPU;YBX1;PRPF19;USP39;ELAVL1;EFTUD2;...
# 3      478.767028  EIF4A3;HNRNPU;YBX1;PRPF19;USP39;ELAVL1;EFTUD2;...
# 4      153.400560  RPL4;NUP107;NUP188;RPL10A;RPL9;PSMD8;RPS15;PSM...
#
#         Gene_set
# 0  Reactome_2016
# 1  Reactome_2016
# 2  Reactome_2016
# 3  Reactome_2016
# 4  Reactome_2016

# %% [markdown]
# # Step 2: Get the list of significant genes

# %%
index = 0
trans = prot_enr.res2d.Genes[index]
genes = trans.split(';')
print(prot_enr.res2d.Term[index])
print('total genes:',len(genes))
# Out:
# Processing of Capped Intron-Containing Pre-mRNA Homo sapiens R-HSA-72203
# total genes: 123

# %% [markdown]
# # Step 3: Create HeatMap

# %% [markdown]
# Slice out genes from the DNA Replication pathway from the df with genes sig in > 1 cancer.

# %%
# sig > 1 cancer
bool_df = sig_df.Proteomics.isin(genes)
plot_df = sig_df[bool_df]
len(plot_df.Proteomics.unique())
# Out:
# 123

# %%
p.plotCircleHeatMap(plot_df, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                    plot_height=400, plot_width= 800)
# Out:
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\plot_utils\__init__.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["size2"] = df[circle_var].apply(lambda x: -1*(np.log(x)))
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\plot_utils\__init__.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['size'] = (df["size2"])*3
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1027">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a41fe07e-e431-40ca-a10d-7834ca0aaf6c" data-root-id="1004"></div>

# %% [markdown]
# # Step 4: Create a HeatMap with both +/- differences in median

# %% [markdown]
#  Read in the pos_neg_df.csv to create a df with only genes that have a pos and neg difference in median in different cancers. Slice out the genes that have a pos and neg difference in median in the pathway using the list of genes with a significant p-value in the pathway.

# %%
pos_neg_df = pd.read_csv(root+R'\pos_neg_df.csv')

# %%
get = pos_neg_df.Proteomics.isin(genes) # bool df where True has both pos and neg
genes_pn = pos_neg_df[get] # Keep only genes with pos and neg
genes_pn.Proteomics.unique()
# Out:
# array(['USP39', 'HNRNPD', 'NUP37', 'YBX1', 'NUP153', 'DDX39A', 'CD2BP2',
#        'HNRNPA1', 'GTF2F1', 'HNRNPU', 'ALYREF', 'HNRNPA3', 'NUP210'],
#       dtype=object)

# %%
p.plotCircleHeatMap(genes_pn, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                    plot_height=400, plot_width=600)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1124">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="0b59205b-5960-450f-b718-617784564b59" data-root-id="1101"></div>

# %% [markdown]
# # Sig in multiple cancers

# %%
mult_sig_df = pd.read_csv(root+R'\mult_sig_pval_heatmap.csv')

mult_sig_list = list(mult_sig_df.Proteomics.unique()) # list of genes with a sig pval in > 1 cancer
enr2 = gp.enrichr(gene_list = mult_sig_list, description='Tumor_partition', gene_sets='Reactome_2016', 
                       outdir='/Enrichr')

# %%
enr2.res2d.head()
# Out:
#                                                 Term   Overlap       P-value  \
# 0           Gene Expression Homo sapiens R-HSA-74160  101/1631  1.775164e-24
# 1  Processing of Capped Intron-Containing Pre-mRN...    36/193  3.337592e-24
# 2       Cell Cycle, Mitotic Homo sapiens R-HSA-69278    47/462  1.082883e-19
# 3              Cell Cycle Homo sapiens R-HSA-1640170    48/566  7.248901e-17
# 4  mRNA Splicing - Major Pathway Homo sapiens R-H...    24/134  4.208022e-16
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0      2.716001e-21            0                     0    3.013392
# 1      2.553258e-21            0                     0    9.076813
# 2      5.522702e-17            0                     0    4.950443
# 3      2.772705e-14            0                     0    4.126796
# 4      1.287655e-13            0                     0    8.715546
#
#    Combined Score                                              Genes  \
# 0      164.796815  EHMT1;EPRS;PWP2;EFTUD2;PSMD9;SNRPD2;KHSRP;TXNL...
# 1      490.663374  DDX5;DHX9;DDX23;USP39;PRPF8;ELAVL1;NUP160;EFTU...
# 2      216.183318  TOP2A;AHCTF1;PCNA;MCM7;DCTN1;NCAPG;BUB1B;SMC4;...
# 3      153.364511  TOP2A;AHCTF1;PCNA;MCM7;DCTN1;NCAPG;BUB1B;SMC4;...
# 4      308.568418  DDX5;CPSF1;NCBP1;DHX9;NCBP2;CPSF3;CPSF2;DDX23;...
#
#         Gene_set
# 0  Reactome_2016
# 1  Reactome_2016
# 2  Reactome_2016
# 3  Reactome_2016
# 4  Reactome_2016

# %%
index2 = 1
trans2 = enr2.res2d.Genes[index2]
genes_mult = trans2.split(';')
print(enr2.res2d.Term[index2])
print('total genes:',len(genes_mult))
# Out:
# Processing of Capped Intron-Containing Pre-mRNA Homo sapiens R-HSA-72203
# total genes: 36

# %%
bool_df = mult_sig_df.Proteomics.isin(genes_mult)
plot_df2 = mult_sig_df[bool_df]
plot_df2.Proteomics.unique()
# Out:
# array(['NCBP2', 'USP39', 'DDX23', 'PRPF6', 'NCBP1', 'TPR', 'PRPF8',
#        'EFTUD2', 'THOC2', 'SNRNP200', 'DDX39A', 'NUP160', 'SNRPD2',
#        'POLR2B', 'SRSF3', 'RANBP2', 'SNRNP40', 'HNRNPH1', 'NUP155',
#        'PRPF3', 'CPSF2', 'THOC3', 'CPSF3', 'THOC7', 'NUP85', 'PRPF31',
#        'DDX5', 'RAE1', 'TXNL4A', 'ELAVL1', 'SNRPG', 'CPSF1', 'DHX9',
#        'HNRNPL', 'NUP133', 'NUP210'], dtype=object)

# %%
p.plotCircleHeatMap(plot_df2, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                    plot_height=400, plot_width=800)
# Out:
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\plot_utils\__init__.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["size2"] = df[circle_var].apply(lambda x: -1*(np.log(x)))
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\plot_utils\__init__.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['size'] = (df["size2"])*3
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1475">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ec63ace7-076a-4d2a-ba26-e8fa6f9b3430" data-root-id="1452"></div>

# %%
get = pos_neg_df.Proteomics.isin(genes_mult) # bool df where True has both pos and neg
genes_pn_mult = pos_neg_df[get] # Keep only genes with pos and neg
genes_pn_mult.Proteomics.unique()
# Out:
# array(['USP39', 'DDX39A', 'NUP210'], dtype=object)

# %%
p.plotCircleHeatMap(genes_pn_mult, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                    plot_height=400, plot_width=400)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1759">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="443808dd-db4f-4d2c-862d-086bd38f6113" data-root-id="1736"></div>

# %% [markdown]
# # Check other pathways the genes (+/- and sig in mult. cancers) are part of

# %%
gnm = list(genes_pn_mult.Proteomics.unique())
print(gnm)
enr3 = gp.enrichr(gene_list = gnm, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='/Enrichr')
# Out:
# ['USP39', 'DDX39A', 'NUP210']
# 2020-06-12 10:37:06,277 Warning: No enrich terms using library KEGG_2016 when cutoff = 0.05

# %%
enr3.res2d.head()
# Out:
#                                   Term Overlap   P-value  Adjusted P-value  \
# 0    Spliceosome Homo sapiens hsa03040   1/134  0.019966               1.0
# 1  RNA transport Homo sapiens hsa03013   1/172  0.025580               1.0
#
#    Old P-value  Old Adjusted P-value  Odds Ratio  Combined Score   Genes  \
# 0            0                     0   49.751244      194.711483   USP39
# 1            0                     0   38.759690      142.091094  NUP210
#
#     Gene_set
# 0  KEGG_2016
# 1  KEGG_2016

# %%
# Look at p-values 
certain_gene = 'PRPF6'
all_df = pd.read_csv(root+R'\all_heatmap.csv')
gene_df = all_df.loc[all_df['Proteomics'] == certain_gene]
gene_df
# Out:
#       Proteomics   P_Value   Medians Cancer
# 212        PRPF6  0.000050  0.391870    Gbm
# 12025      PRPF6  0.006819  0.140160  Hnscc
# 27881      PRPF6  0.359535  0.144750   Luad
# 33350      PRPF6  0.000535  0.502100   Lscc
# 46555      PRPF6  0.161801  0.068850   Brca
# 57251      PRPF6  0.338623 -0.006257     Ov
# 64224      PRPF6  0.000959 -0.193600     En
# 81255      PRPF6  0.803451 -0.063000  Colon
