# %% [markdown]
# # Create Heat Map for significant Aurora B Signaling genes

# %% [markdown]
# This notebook looks at the significant genes in at least one cancer in the DNA Replication pathway. Pancancer heat maps are created with circle size showing significance and color showing differences in median.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as p

# %% [markdown]
# # Step 1: Run GSEA for significant genes in at least 1 cancer

# %% [markdown]
# First read in sig_pval_all_proteins.csv into a df. This csv file contains only genes with a significant p-value in at least one cancer. Then run GSEA using a list of genes from the df.

# %%
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'
sig_df = pd.read_csv(root+R'\sig_pval_heatmap.csv')

prot_list = list(sig_df.Proteomics) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='NCI-Nature_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head()
# Out:
#                                                 Term Overlap       P-value  \
# 0  Regulation of RAC1 activity Homo sapiens 351aa...   20/38  1.112561e-08
# 1  Class I PI3K signaling events Homo sapiens 12b...   19/48  6.480058e-06
# 2  ATR signaling pathway Homo sapiens 8991cbac-61...   15/39  8.941964e-05
# 3  E2F transcription factor network Homo sapiens ...   22/72  1.368548e-04
# 4  BCR signaling pathway Homo sapiens acbf44e2-61...   20/64  1.935528e-04
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.000002            0                     0    3.895750
# 1          0.000677            0                     0    2.929928
# 2          0.006230            0                     0    2.846894
# 3          0.007151            0                     0    2.261699
# 4          0.008091            0                     0    2.313101
#
#    Combined Score                                              Genes  \
# 0       71.346824  DOCK6;ARHGAP9;VAV3;RASGRF2;RAP1GDS1;VAV1;DEF6;...
# 1       35.003214  HSP90AA1;SYK;PLEKHA1;PDPK1;PTEN;PIK3CD;PIK3R1;...
# 2       26.539231  RFC5;RFC3;TIPIN;RFC4;MCM7;RFC2;PLK1;RPA1;FANCD...
# 3       20.121410  PRMT5;RANBP1;RRM1;CDKN1B;CBX5;RRM2;APAF1;HDAC1...
# 4       19.776925  MAP4K1;MAP2K1;SYK;CSNK2A1;CHUK;PDPK1;PTEN;PIK3...
#
#           Gene_set
# 0  NCI-Nature_2016
# 1  NCI-Nature_2016
# 2  NCI-Nature_2016
# 3  NCI-Nature_2016
# 4  NCI-Nature_2016

# %% [markdown]
# # Step 2: Get the list of significant genes

# %%
index = 2
trans = prot_enr.res2d.Genes[index]
genes = trans.split(';')
print(prot_enr.res2d.Term[index])
print('total genes:',len(genes))
# Out:
# ATR signaling pathway Homo sapiens 8991cbac-618b-11e5-8ac5-06603eb7f303
# total genes: 15

# %% [markdown]
# # Step 3: Create HeatMap

# %% [markdown]
# Slice out genes from the DNA Replication pathway from the df with genes sig in > 1 cancer.

# %%
# sig > 1 cancer
bool_df = sig_df.Proteomics.isin(genes)
plot_df = sig_df[bool_df]
len(plot_df.Proteomics.unique())
# Out:
# 15

# %%
p.plotCircleHeatMap(plot_df, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                    plot_height=400, plot_width= 800)
# Out:
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\plot_utils\__init__.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["size2"] = df[circle_var].apply(lambda x: -1*(np.log(x)))
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\plot_utils\__init__.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['size'] = (df["size2"])*3
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1027">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="53c93c4f-9e68-415a-bffa-bad45b7321a0" data-root-id="1004"></div>

# %% [markdown]
# # Step 4: Create a HeatMap with both +/- differences in median

# %% [markdown]
#  Read in the pos_neg_df.csv to create a df with only genes that have a pos and neg difference in median in different cancers. Slice out the genes that have a pos and neg difference in median in the pathway using the list of genes with a significant p-value in the pathway.

# %%
pos_neg_df = pd.read_csv(root+R'\pos_neg_df.csv')

# %%
get = pos_neg_df.Proteomics.isin(genes) # bool df where True has both pos and neg
genes_pn = pos_neg_df[get] # Keep only genes with pos and neg
genes_pn.Proteomics.unique()
# Out:
# array(['RFC5', 'MCM2', 'MCM7', 'RFC2', 'TIPIN', 'RFC4', 'TOPBP1', 'CHEK1',
#        'PLK1'], dtype=object)

# %%
p.plotCircleHeatMap(genes_pn, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                    plot_height=400, plot_width=600)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1124">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="7ed37ab3-430e-4a0e-8f72-012dd0b0903b" data-root-id="1101"></div>

# %% [markdown]
# # Sig in multiple cancers

# %%
mult_sig_df = pd.read_csv(root+R'\mult_sig_pval_heatmap.csv')

mult_sig_list = list(mult_sig_df.Proteomics.unique()) # list of genes with a sig pval in > 1 cancer
enr2 = gp.enrichr(gene_list = mult_sig_list, description='Tumor_partition', gene_sets='NCI-Nature_2016', 
                       outdir='/Enrichr')

# %%
enr2.res2d.head()
# Out:
#                                                 Term Overlap       P-value  \
# 0  Class I PI3K signaling events Homo sapiens 12b...   10/48  3.923280e-08
# 1  BCR signaling pathway Homo sapiens acbf44e2-61...   10/64  6.779369e-07
# 2  ATR signaling pathway Homo sapiens 8991cbac-61...    8/39  1.046196e-06
# 3  Aurora B signaling Homo sapiens 304a75af-618c-...    8/39  1.046196e-06
# 4  IL8- and CXCR2-mediated signaling events Homo ...    7/34  4.898355e-06
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.000008            0                     0   10.137875
# 1          0.000071            0                     0    7.603406
# 2          0.000073            0                     0    9.981908
# 3          0.000055            0                     0    9.981908
# 4          0.000205            0                     0   10.018606
#
#    Combined Score                                              Genes  \
# 0      172.888814  ZAP70;RAP1A;SYK;PIK3CA;PTEN;BLNK;PLCG2;BTK;PIK...
# 1      108.000392  MAP4K1;PPP3CB;PTPRC;SYK;CHUK;PIK3CA;PTEN;BLNK;...
# 2      137.454359        RFC5;RFC3;RFC4;MCM7;RFC2;FANCD2;TOPBP1;MCM2
# 3      137.454359       NSUN2;NCL;NCAPG;NCAPD2;SMC4;NCAPH;NDC80;SMC2
# 4      122.493600            GNG2;PRKCB;RAC2;ELMO1;DOCK2;PLCB2;GNAI2
#
#           Gene_set
# 0  NCI-Nature_2016
# 1  NCI-Nature_2016
# 2  NCI-Nature_2016
# 3  NCI-Nature_2016
# 4  NCI-Nature_2016

# %%
index2 = 3
trans2 = enr2.res2d.Genes[index2]
genes_mult = trans2.split(';')
print(enr2.res2d.Term[index2])
print('total genes:',len(genes_mult))
# Out:
# Aurora B signaling Homo sapiens 304a75af-618c-11e5-8ac5-06603eb7f303
# total genes: 8

# %%
bool_df = mult_sig_df.Proteomics.isin(genes_mult)
plot_df2 = mult_sig_df[bool_df]
plot_df2.Proteomics.unique()
# Out:
# array(['NSUN2', 'NCL', 'SMC4', 'SMC2', 'NCAPD2', 'NCAPG', 'NDC80',
#        'NCAPH'], dtype=object)

# %%
p.plotCircleHeatMap(plot_df2, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                    plot_height=400, plot_width=800)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1475">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="45f3ecba-4903-4d06-9192-731a2e500cc3" data-root-id="1452"></div>

# %%
get = pos_neg_df.Proteomics.isin(genes_mult) # bool df where True has both pos and neg
genes_pn_mult = pos_neg_df[get] # Keep only genes with pos and neg
genes_pn_mult.Proteomics.unique()
# Out:
# array(['NCL', 'SMC4', 'SMC2', 'NCAPD2', 'NCAPG', 'NDC80'], dtype=object)

# %%
p.plotCircleHeatMap(genes_pn_mult, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                    plot_height=400, plot_width=600)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1759">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="22fed189-672f-4e1b-a5db-0d4bbbdcffbf" data-root-id="1736"></div>

# %% [markdown]
# # Check other pathways the genes (+/- and sig in mult. cancers) are part of

# %%
gnm = list(genes_pn_mult.Proteomics.unique())
print(gnm)
enr3 = gp.enrichr(gene_list = gnm, description='Tumor_partition', gene_sets='NCI-Nature_2016', 
                       outdir='/Enrichr')
# Out:
# ['NCL', 'SMC4', 'SMC2', 'NCAPD2', 'NCAPG', 'NDC80']

# %%
enr3.res2d.head()
# Out:
#                                                 Term Overlap       P-value  \
# 0  Aurora B signaling Homo sapiens 304a75af-618c-...    6/39  3.670697e-17
# 1  Urokinase-type plasminogen activator (uPA) and...    1/42  1.253548e-02
# 2  PLK1 signaling events Homo sapiens e5e87977-61...    1/46  1.372248e-02
# 3  Regulation of Telomerase Homo sapiens 4dfe97ca...    1/67  1.993473e-02
# 4  Validated targets of C-MYC transcriptional act...    1/79  2.346993e-02
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0      7.671758e-15            0                     0  512.820513
# 1      1.000000e+00            0                     0   79.365079
# 2      9.559991e-01            0                     0   72.463768
# 3      1.000000e+00            0                     0   49.751244
# 4      9.810432e-01            0                     0   42.194093
#
#    Combined Score                             Genes         Gene_set
# 0    19406.956354  NCL;NCAPG;NCAPD2;SMC4;NDC80;SMC2  NCI-Nature_2016
# 1      347.554963                               NCL  NCI-Nature_2016
# 2      310.776831                             NDC80  NCI-Nature_2016
# 3      194.790633                               NCL  NCI-Nature_2016
# 4      158.313720                               NCL  NCI-Nature_2016

# %%
i = 4
print(enr3.res2d.Term[i])
enr3.res2d.Genes[i]
# Out:
# FAS (CD95) signaling pathway Homo sapiens 79cc9c14-6192-11e5-8ac5-06603eb7f303
# 'SYK'

# %%
# Look at p-values 
certain_gene = 'SYK'
all_df = pd.read_csv(root+R'\all_heatmap.csv')
gene_df = all_df.loc[all_df['Proteomics'] == certain_gene]
gene_df
# Out:
#       Proteomics   P_Value   Medians Cancer
# 499          SYK  0.000320 -0.697550    Gbm
# 11632        SYK  0.001919 -0.225323  Hnscc
# 23793        SYK  0.021461 -0.489000   Luad
# 36955        SYK  0.155625 -0.475100   Lscc
# 53051        SYK  0.905056  0.020400   Brca
# 53874        SYK  0.003901  0.405618     Ov
# 66600        SYK  0.085643  0.079000     En
# 81038        SYK  0.775873  0.034700  Colon
