# %% [markdown]
# # Create Heat Map for significant mRNA Surveillance genes

# %% [markdown]
# This notebook looks at the significant genes in at least one cancer. Pancancer heat maps are created with circle size showing significance and color showing differences in median.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as pu

# %% [markdown]
# # Step 1: Run GSEA for significant genes in at least 1 cancer

# %% [markdown]
# First read in sig_pval_all_proteins.csv into a df. This csv file contains only genes with a significant p-value in at least one cancer. Then run GSEA using a list of genes from the df.

# %%
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'
sig_df = pd.read_csv(root+R'\sig_pval_heatmap.csv')

prot_list = list(sig_df.Proteomics) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='/Enrichr')
prot_enr.res2d.head()
# Out:
#                                               Term Overlap       P-value  \
# 0                Spliceosome Homo sapiens hsa03040  88/134  2.936551e-44
# 1              RNA transport Homo sapiens hsa03013  77/172  1.113872e-23
# 2            DNA replication Homo sapiens hsa03030   23/36  3.613010e-12
# 3  mRNA surveillance pathway Homo sapiens hsa03015   38/91  2.801846e-11
# 4            Mismatch repair Homo sapiens hsa03430   15/23  1.473843e-08
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0      8.604095e-42            0                     0    4.860965
# 1      1.631823e-21            0                     0    3.313652
# 2      3.528707e-10            0                     0    4.729007
# 3      2.052353e-09            0                     0    3.090914
# 4      8.636717e-07            0                     0    4.827342
#
#    Combined Score                                              Genes  \
# 0      487.246193  RBM25;EIF4A3;DDX42;HNRNPU;PRPF19;USP39;EFTUD2;...
# 1      175.131871  CYFIP2;NUP107;NUP188;RPP30;EIF4A3;PHAX;PNN;XPO...
# 2      124.592696  RFC5;FEN1;RFC3;PCNA;RFC4;MCM7;RFC1;RFC2;PRIM1;...
# 3       75.103503  SMG1;RBM8A;RNMT;CSTF3;EIF4A3;MSI1;PPP2R2A;MSI2...
# 4       87.050531  RFC5;RFC3;PCNA;RFC4;RFC1;RFC2;RPA1;MLH1;POLD3;...
#
#     Gene_set
# 0  KEGG_2016
# 1  KEGG_2016
# 2  KEGG_2016
# 3  KEGG_2016
# 4  KEGG_2016

# %% [markdown]
# # Step 2: Get the list of significant genes in the mRNA Surveillance pathway

# %%
rna = prot_enr.res2d.Genes[3]
genes = rna.split(';')
print('total genes:',len(genes))
# Out:
# total genes: 38

# %% [markdown]
# # Step 3: Create HeatMap

# %% [markdown]
# Slice out about 15 significant genes in the pathway from sig_df (sig_pval_heatmap.csv). 15 genes show up well when the plotCircleHeatMap function is called. Change the variable representing a different list of genes to visualize all the genes in the pathway.

# %%
genes_1 = genes[0:16]
genes_2 = genes[16:]

# %%
bool_df = sig_df.Proteomics.isin(genes_2)
plot_df = sig_df[bool_df]
plot_df.head()
# Out:
#     Proteomics   P_Value   Medians Cancer
# 46       NCBP2  0.000002  0.571311    Gbm
# 253      NCBP1  0.000074  0.386716    Gbm
# 430     NUDT21  0.000233  0.336463    Gbm
# 575       UPF1  0.000431  0.247959    Gbm
# 640      SYMPK  0.000574  0.220405    Gbm

# %%
pu.plotCircleHeatMap(plot_df, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                     plot_width=1000)
# Out:
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\plot_utils\__init__.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["size2"] = df[circle_var].apply(lambda x: -1*(np.log(x)))
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\plot_utils\__init__.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['size'] = (df["size2"])*3
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1027">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="069ae480-ece5-4408-98d6-99d39c809f49" data-root-id="1004"></div>

# %% [markdown]
# # Step 4: Create a HeatMap with both pos and neg differences in median

# %% [markdown]
#  Read in the pos_neg_df.csv to create a df with only genes that have a pos and neg difference in median in different cancers. Slice out the genes that have a pos and neg difference in median in the pathway using the list of genes with a significant p-value in the pathway.

# %%
pos_neg_df = pd.read_csv(root+R'\pos_neg_df.csv')

# %%
get = pos_neg_df.Proteomics.isin(genes) # bool df where True has both pos and neg
genes_pn = pos_neg_df[get] # Keep only genes with pos and neg
genes_pn.Proteomics.unique()
# Out:
# array(['PPP2R2A', 'RNMT', 'MSI2', 'ALYREF'], dtype=object)

# %%
pu.plotCircleHeatMap(genes_pn, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                    plot_width=700)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1124">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6729d2b7-37b2-42db-9d73-f4bd3551c411" data-root-id="1101"></div>
