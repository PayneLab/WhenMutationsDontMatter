# %% [markdown]
# # Create Heat Map for significant Cell Cycle genes

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as p
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'

# %% [markdown]
# # Step 1: Get df for significant genes in > 1 cancer

# %% [markdown]
# First read in sig_pval_heatmap.csv into a df. This csv file contains only genes with a significant p-values in at least one cancer.

# %%
sig_df = pd.read_csv(root+R'\sig_pval_heatmap.csv') #tp53 only sig in endo

# %% [markdown]
# # Step 2: Get the list of significant genes

# %%
narrowed_cell_cycle = ['DCTN1', 'ACTR1A', 'MAD2L1', 'MCM4', 'PCNA', 'MCM5', 'MCM2','PCM1',
              'MCM7', 'TPR', 'MCM3', 'MCM6', 'NUP153', 'RFC3', 'CDK11B', 'XPO1','PRKCB', 'RFC2', 'NUF2', 
              'RAB8A', 'RFC4', 'RANBP2', 'CENPF', 'GINS4', 'NDC80', 'OPTN', 'PPP2R2A', 'PPP2R2D',
              'TPX2', 'GINS2', 'BUB1B', 'TOP2A', 'TOPBP1', 'TP53', 'NUP210']

# %%
bool_df = sig_df.Proteomics.isin(narrowed_cell_cycle)
df = sig_df[bool_df]
df = df.loc[df['P_Value'] <= 0.05]

# %% [markdown]
# # Step 3: Create HeatMap

# %% [markdown]
# Slice out genes from the DNA Replication pathway from the df with genes sig in > 1 cancer.

# %%
p.plotCircleHeatMap(df, circle_var='P_Value', color_var='Medians', x_axis='Proteomics', y_axis='Cancer',
                    plot_height=350, plot_width=800, x_axis_lab='Proteomics', font_size=12, legend_max=0.05, 
                    save_png='PTEN_Figure_3_Cell_Cycle.png')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1052">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8f3852f1-7894-4dff-b224-b14a55cb820d" data-root-id="1053"></div>

# %%
narrowed_cell_cycle = ['DCTN1', 'ACTR1A', 'MAD2L1', 'MCM4', 'PCNA', 'MCM5', 'MCM2','PCM1',
              'MCM7', 'TPR', 'MCM3', 'MCM6', 'NUP153', 'RFC3', 'CDK11B', 'XPO1','PRKCB', 'RFC2', 'NUF2', 
              'RAB8A', 'RFC4', 'RANBP2', 'CENPF', 'GINS4', 'NDC80', 'OPTN', 'PPP2R2A', 'PPP2R2D',
              'TPX2', 'GINS2', 'BUB1B', 'TOP2A', 'TOPBP1', 'TP53', 'NUP210']

dna_synth = ['MCM4', 'PCNA', 'MCM5', 'MCM2','PCM1', 'MCM7', 'MCM3', 'RFC3', 
             'RFC2', 'RFC4', 'GINS4', 'GINS2', 'TOP2A']

dynactin = ['DCTN1','ACTR1A']
spindle = ['BUB1B', 'CENPF', 'MAD2L1', 'NDC80', 'NUF2', 'PCM1', 'TPX2','DCTN1','ACTR1A']

checkpoints = ['BUB1B','PPP2R2A', 'PPP2R2D', 'TOPBP1','MAD2L1']

np_transport = ['TPR','NUP153','NUP210', 'XPO1','RANBP2']
other_transport = ['RAB8A']
other = ['PRKCB','OPTN','CDK11B']

path_list = {'DNA_Synth':dna_synth, 'Spindle':spindle, 'Dynactin': dynactin, 'Checkpoints':checkpoints,
            'Nuclear_Pore_Transport':np_transport}

# %%
bool_df = sig_df.Proteomics.isin(narrowed_cell_cycle)
df = sig_df[bool_df]
df = df.loc[df['P_Value'] <= 0.05]
df
# Out:
#       Proteomics   P_Value   Medians Cancer
# 6          DCTN1  0.000015 -0.382988    Gbm
# 9         ACTR1A  0.000038 -0.491126    Gbm
# 106         MCM6  0.001303  1.085407    Gbm
# 107         MCM4  0.001303  1.236484    Gbm
# 114       MAD2L1  0.001303  0.546914    Gbm
# ...          ...       ...       ...    ...
# 14717       NUF2  0.034789 -0.612500     En
# 14725      CENPF  0.037588 -0.439000     En
# 14731       TP53  0.037788 -0.802600     En
# 14763        TPR  0.042634 -0.184300     En
# 14799    PPP2R2A  0.048016  0.372600     En
#
# [75 rows x 4 columns]

# %%
narrowed_cell_cycle = ['DCTN1', 'ACTR1A', 'MAD2L1', 'MCM4', 'PCNA', 'MCM5', 'MCM2','PCM1',
              'MCM7', 'TPR', 'MCM3', 'MCM6', 'NUP153', 'RFC3', 'CDK11B', 'XPO1','PRKCB', 'RFC2', 'NUF2', 
              'RAB8A', 'RFC4', 'RANBP2', 'CENPF', 'GINS4', 'NDC80', 'OPTN', 'PPP2R2A', 'PPP2R2D',
              'TPX2', 'GINS2', 'BUB1B', 'TOP2A', 'TOPBP1', 'TP53', 'NUP210']

dna_synth = ['MCM4', 'PCNA', 'MCM5', 'MCM2','PCM1', 'MCM7', 'MCM3', 'RFC3', 
             'RFC2', 'RFC4', 'GINS4', 'GINS2', 'TOP2A']

dynactin = ['DCTN1','ACTR1A']
spindle = ['BUB1B', 'CENPF', 'MAD2L1', 'NDC80', 'NUF2', 'PCM1', 'TPX2','DCTN1','ACTR1A']

checkpoints = ['BUB1B','PPP2R2A', 'PPP2R2D', 'TOPBP1','MAD2L1']

np_transport = ['TPR','NUP153','NUP210', 'XPO1','RANBP2']
other_transport = ['RAB8A']
other = ['PRKCB','OPTN','CDK11B']

path_list = {'DNA_Synth':dna_synth, 'Spindle':spindle, 'Dynactin': dynactin, 'Checkpoints':checkpoints,
            'Nuclear_Pore_Transport':np_transport}

# %%
#ADD CDK11B
df["Index"] = df["Proteomics"] + "_" + df["Cancer"]
df = df.set_index("Index")
df = df.reindex(['GINS2_Gbm', 'GINS4_Gbm', 'MCM2_Gbm', 'MCM3_Gbm', 'MCM4_Gbm', 'MCM5_Gbm', 'MCM6_Gbm', #synth
             'MCM7_Gbm', 'RFC2_Gbm', 'RFC3_Gbm', 'RFC4_Gbm', 'RFC5_Gbm',  'PCNA_Gbm', 'PCM1_Gbm', 'TOP2A_Gbm',
             'PPP2R2A_Gbm', 'PPP2R2D_Gbm', 'TOPBP1_Gbm', 'TP53_Gbm', 'MAD2L1_Gbm', 'BUB1B_Gbm', #checkpoints
             'CENPF_Gbm', 'NDC80_Gbm', 'NUF2_Gbm', 'TPX2_Gbm','DCTN1_Gbm','ACTR1A_Gbm', # mitotic
             'GINS2_Hnscc', 'GINS4_Hnscc', 'MCM2_Hnscc', 'MCM3_Hnscc', 'MCM4_Hnscc', 'MCM5_Hnscc', 'MCM6_Hnscc', #synth
             'MCM7_Hnscc', 'RFC2_Hnscc', 'RFC3_Hnscc', 'RFC4_Hnscc', 'RFC5_Hnscc',  'PCNA_Hnscc', 'PCM1_Hnscc', 'TOP2A_Hnscc', 
             'PPP2R2A_Hnscc', 'PPP2R2D_Hnscc', 'TOPBP1_Hnscc', 'TP53_Hnscc', 'MAD2L1_Hnscc', 'BUB1B_Hnscc', #checkpoints
             'CENPF_Hnscc', 'NDC80_Hnscc', 'NUF2_Hnscc', 'TPX2_Hnscc','DCTN1_Hnscc','ACTR1A_Hnscc', #mitotic
             'RFC2_En', 'RFC5_En', 'PCM1_En', 'TOP2A_En', #synth
             'PPP2R2A_En', 'TOPBP1_En', 'TP53_En', 'MAD2L1', 'BUB1B_En', #checkpoints
             'CENPF_En', 'NDC80_En', 'NUF2_En', 'TPX2_En','DCTN1_En', #mitotic
             'DCTN1_Luad', 'ACTR1A_Luad'])

# %%
df
# Out:
#           Proteomics   P_Value   Medians Cancer
# Index
# GINS2_Gbm      GINS2  0.039521  0.537816    Gbm
# GINS4_Gbm      GINS4  0.018096  0.742086    Gbm
# MCM2_Gbm        MCM2  0.002222  0.939513    Gbm
# MCM3_Gbm        MCM3  0.003362  0.926526    Gbm
# MCM4_Gbm        MCM4  0.001303  1.236484    Gbm
# ...              ...       ...       ...    ...
# CENPF_En       CENPF  0.037588 -0.439000     En
# NDC80_En       NDC80  0.015147 -0.608000     En
# NUF2_En         NUF2  0.034789 -0.612500     En
# TPX2_En         TPX2  0.021371 -0.800000     En
# DCTN1_En       DCTN1  0.016154  0.256800     En
#
# [68 rows x 4 columns]

# %%
p.plotCircleHeatMap(df, circle_var='P_Value', color_var='Medians', x_axis='Proteomics', y_axis='Cancer',
                    plot_height=350, plot_width=800, x_axis_lab='Proteomics', font_size=12, legend_max=0.05, 
                    save_png='PTEN_Figure_3_Cell_Cycle.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-ac4f6edaebe5> in <module>
#       1 p.plotCircleHeatMap(df, circle_var='P_Value', color_var='Medians', x_axis='Proteomics', y_axis='Cancer',
#       2                     plot_height=350, plot_width=800, x_axis_lab='Proteomics', font_size=12, legend_max=0.05,
# ----> 3                     save_png='PTEN_Figure_3_Cell_Cycle.png')
#
# ~\Anaconda3\envs\Research\lib\site-packages\plot_utils\__init__.py in plotCircleHeatMap(df, circle_var, color_var, x_axis, y_axis, plot_width, plot_height, font_size, x_axis_lab, y_axis_lab, show_plot, save_png, legend_min, legend_max)
#      57               fill_color={"field":color_var, "transform":exp_cmap})
#      58
# ---> 59     p.x_range.factors = sorted(df[x_axis].unique().tolist())
#      60     p.y_range.factors = sorted(df[y_axis].unique().tolist(), reverse = True)
#      61     p.xaxis.major_label_orientation = math.pi/2
#
# TypeError: '<' not supported between instances of 'float' and 'str'
