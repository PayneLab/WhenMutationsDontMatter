# %% [markdown]
# All Proteins (Pten wt median - mutated median)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import sys
sys.path.append('C:\\Users\\brittany henderson\\GitHub\\WhenMutationsDontMatter\\')
import plot_utils as p

# %%
gbm = cptac.Gbm()
endo = cptac.Endometrial()

# %%
cancer1 = "GBM"
cancer2 = "Endometrial"
gene = 'PTEN'

# %%
#GBM ttest
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot = gbm.get_proteomics()
gbm_prot_list = list(prot.columns)
prot_and_mutations = gbm.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = gbm_prot_list)  

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
gbm_prot = list(mut_status.columns[:-1]) # new prot list without na in all tumor (sometimes values in normal)
# Out:
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 82 samples for the PTEN gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 6)

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

gbm_d = {}

for prot in gbm_prot:
    dif_gbm = mut_med[prot] - wt_med[prot]
    gbm_d[prot] = dif_gbm

gbm_df = pd.DataFrame.from_dict(gbm_d, orient='index', columns=['Gbm'])
gbm_df
# Out:
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\numpy\lib\nanfunctions.py:1076: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
#                         Gbm
# A1BG_proteomics    0.040188
# A2M_proteomics     0.108524
# AAAS_proteomics    0.058545
# AACS_proteomics   -0.057941
# AADAT_proteomics   0.175684
# ...                     ...
# ZXDC_proteomics    0.061036
# ZYG11B_proteomics  0.064513
# ZYX_proteomics     0.116899
# ZZEF1_proteomics   0.031760
# ZZZ3_proteomics   -0.004215
#
# [11141 rows x 1 columns]

# %%
# CHECK
gene = 'A2M'
dif_gbm = mut_med[gene+'_proteomics'] - wt_med[gene+'_proteomics']
print(mut_med[gene+'_proteomics'],' - ', wt_med[gene+'_proteomics'], dif_gbm)
# Out:
# 0.167553332732188  -  0.05902898365572651 0.1085243490764615

# %% [markdown]
# Endo

# %%
#Endo ttest
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot = endo.get_proteomics()
en_prot_list = list(prot.columns)
prot_and_mutations = endo.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = en_prot_list)  

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
en_prot = list(mut_status.columns[:-1])

mut_status
# Out:
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 139 samples for the A2M gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 6)
# Name       A1BG_proteomics  A2M_proteomics  A2ML1_proteomics  \
# Sample_ID
# S001                -1.180         -0.8630           -0.8020
# S002                -0.685         -1.0700           -0.6840
# S003                -0.528         -1.3200            0.4350
# S005                -1.670         -1.1900           -0.4430
# S006                -0.374         -0.0206           -0.5370
# ...                    ...             ...               ...
# S099                -1.070         -0.7120            0.0462
# S100                -1.280         -0.7360           -0.5520
# S101                -0.290         -0.3200            3.1700
# S102                 0.266          1.3900           -0.0655
# S103                 0.692          0.5890            0.5870
#
# Name       A4GALT_proteomics  AAAS_proteomics  AACS_proteomics  \
# Sample_ID
# S001                  0.2220           0.2560           0.6650
# S002                  0.9840           0.1350           0.3340
# S003                     NaN          -0.2400           1.0400
# S005                  0.2430          -0.0993           0.7570
# S006                  0.3110           0.3750           0.0131
# ...                      ...              ...              ...
# S099                 -0.0471           0.2270           1.3500
# S100                  0.1140           0.2730           1.0700
# S101                 -0.9070           0.0317          -0.0425
# S102                  0.4700           0.3980          -0.1340
# S103                     NaN          -0.0835           0.1720
#
# Name       AADAT_proteomics  AAED1_proteomics  AAGAB_proteomics  \
# Sample_ID
# S001                 1.2800           -0.3390            0.4120
# S002                 1.3000            0.1390            1.3300
# S003                -0.0213           -0.0479            0.4190
# S005                 0.7400           -0.9290            0.2290
# S006                -1.1000               NaN            0.5650
# ...                     ...               ...               ...
# S099                 1.2100            0.0048            0.6820
# S100                 0.8500               NaN           -0.5360
# S101                    NaN           -0.2730           -0.0747
# S102                 0.4610            1.0400            0.3630
# S103                -0.2150            0.0140           -0.1460
#
# Name       AAK1_proteomics  ...  ZSWIM9_proteomics  ZW10_proteomics  \
# Sample_ID                   ...
# S001                -0.664  ...                NaN          0.02290
# S002                -0.367  ...                NaN          0.36300
# S003                -0.500  ...            -0.1450          0.01050
# S005                -0.223  ...            -0.0552         -0.07140
# S006                -0.101  ...                NaN         -1.22000
# ...                    ...  ...                ...              ...
# S099                -0.224  ...            -0.4010          0.55700
# S100                -0.266  ...                NaN         -0.00364
# S101                 0.124  ...            -0.5210          0.05230
# S102                 0.094  ...                NaN         -0.01220
# S103                 0.857  ...             0.2980         -0.12400
#
# Name       ZWILCH_proteomics  ZWINT_proteomics  ZXDC_proteomics  \
# Sample_ID
# S001                  0.1090               NaN           -0.332
# S002                  1.0700            0.7370           -0.564
# S003                 -0.1160               NaN            0.151
# S005                  0.0933            0.1560           -0.398
# S006                 -0.5620            0.9370           -0.646
# ...                      ...               ...              ...
# S099                  0.8270            0.3480           -0.187
# S100                  0.7630            0.0784           -0.203
# S101                  0.5150            0.5850            0.138
# S102                  0.2500            0.5530            0.387
# S103                  0.1780            0.1470           -0.114
#
# Name       ZYG11B_proteomics  ZYX_proteomics  ZZEF1_proteomics  \
# Sample_ID
# S001                -0.43300          -1.020          -0.12300
# S002                -0.00461          -1.130          -0.07570
# S003                -0.07400          -0.540           0.32000
# S005                -0.07520          -0.797          -0.03010
# S006                 0.20700          -1.850          -0.17600
# ...                      ...             ...               ...
# S099                -0.10700          -0.830           0.06200
# S100                 0.01320          -1.200          -0.35700
# S101                -0.19000          -0.966          -0.00627
# S102                 0.06420          -0.437           0.10400
# S103                 0.13700           1.240           0.00682
#
# Name       ZZZ3_proteomics  binary_mutations
# Sample_ID
# S001               -0.0859          Wildtype
# S002               -0.4730          Wildtype
# S003               -0.4190          Wildtype
# S005               -0.4670          Wildtype
# S006                0.0513          Wildtype
# ...                    ...               ...
# S099               -0.5280          Wildtype
# S100                0.0299          Wildtype
# S101               -0.2490          Wildtype
# S102               -0.4980          Wildtype
# S103               -0.0233          Wildtype
#
# [95 rows x 10994 columns]

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

en_d = {}

for prot in en_prot:
    dif_en = mut_med[prot] - wt_med[prot]
    en_d[prot] = dif_en

# %%
en_df = pd.DataFrame.from_dict(en_d, orient='index', columns=['Endo'])
en_df
# Out:
#                        Endo
# A1BG_proteomics    0.034500
# A2M_proteomics     0.016000
# A2ML1_proteomics   0.038750
# A4GALT_proteomics -0.567050
# AAAS_proteomics    0.098105
# ...                     ...
# ZXDC_proteomics    0.053000
# ZYG11B_proteomics  0.137400
# ZYX_proteomics     0.043000
# ZZEF1_proteomics   0.045950
# ZZZ3_proteomics    0.033300
#
# [10993 rows x 1 columns]

# %%
n = gbm_df.join(en_df)
m = n.transpose()
m
# Out:
#       A1BG_proteomics  A2M_proteomics  AAAS_proteomics  AACS_proteomics  \
# Gbm          0.040188        0.108524         0.058545        -0.057941
# Endo         0.034500        0.016000         0.098105        -0.128500
#
#       AADAT_proteomics  AAED1_proteomics  AAGAB_proteomics  AAK1_proteomics  \
# Gbm           0.175684          0.063785         -0.036972        -0.069487
# Endo         -0.011000         -0.010000          0.206500         0.369500
#
#       AAMDC_proteomics  AAMP_proteomics  ...  ZSCAN31_proteomics  \
# Gbm          -0.144826         -0.07142  ...           -0.096138
# Endo         -0.248000          0.05978  ...            0.081350
#
#       ZSWIM8_proteomics  ZW10_proteomics  ZWILCH_proteomics  ZWINT_proteomics  \
# Gbm           -0.049499         0.102503           0.158887         -0.246501
# Endo           0.103600        -0.008500           0.223500          0.255000
#
#       ZXDC_proteomics  ZYG11B_proteomics  ZYX_proteomics  ZZEF1_proteomics  \
# Gbm          0.061036           0.064513        0.116899           0.03176
# Endo         0.053000           0.137400        0.043000           0.04595
#
#       ZZZ3_proteomics
# Gbm         -0.004215
# Endo         0.033300
#
# [2 rows x 11141 columns]

# %% [markdown]
# Ovarian

# %%
ov = cptac.Ovarian()

# %%
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot = ov.get_proteomics()
prot = ov.reduce_multiindex(prot, levels_to_drop = 1)

ov_prot_list = list(prot.columns)
prot_and_mutations = ov.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = ov_prot_list) 
prot_and_mutations = ov.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)
prot_and_mutations
# Out:
# cptac warning: Due to dropping the specified levels, dataframe now has 1162 duplicated column headers. (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 102 samples for the A2M gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 7)
# cptac warning: Due to dropping the specified levels, dataframe now has 1162 duplicated column headers. (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 8)
# Name       A1BG_proteomics  A2M_proteomics  A2ML1_proteomics  AAAS_proteomics  \
# Sample_ID
# S002              0.133634        0.765120         -0.778849         0.118236
# S006             -0.432786       -0.461906         -0.533497         0.041800
# S007             -0.013943        0.065842               NaN        -0.010514
# S009              1.234203        1.512082         -0.703050         0.181152
# S011             -0.482872        0.343872         -1.150936         0.315155
# ...                    ...             ...               ...              ...
# S127             -0.012139        0.437837         -0.704253         0.411204
# S128              1.949941        1.803647          0.924203        -0.025210
# S129              1.523833        3.418092          0.281521        -0.148852
# S130              1.091843        1.942523          3.192955        -0.439487
# S131              1.511505        1.498532          2.861443        -0.002351
#
# Name       AACS_proteomics  AAGAB_proteomics  AAK1_proteomics  \
# Sample_ID
# S002              0.112740          0.054942         0.313055
# S006              0.604114          0.351294         0.546605
# S007              0.541935          0.169826        -0.023032
# S009              0.087719          0.226861        -0.100766
# S011              0.097235         -0.160208        -0.125165
# ...                    ...               ...              ...
# S127             -0.418927          0.016434         0.504605
# S128              0.593528         -0.427610        -0.094656
# S129             -0.051749          0.297993         0.160205
# S130              0.901140         -0.146974        -0.106039
# S131              0.351521         -0.391236        -0.038395
#
# Name       AAMDC_proteomics  AAMP_proteomics  AAR2_proteomics  ...  \
# Sample_ID                                                      ...
# S002              -0.786270        -0.384680         0.064017  ...
# S006               0.603935        -0.235374         0.059084  ...
# S007              -0.057549        -0.397627         0.199581  ...
# S009              -0.516022        -0.456512        -0.257629  ...
# S011              -0.768776        -0.372368         0.450086  ...
# ...                     ...              ...              ...  ...
# S127               0.022115        -0.163317         0.290281  ...
# S128               0.082444         0.065310        -0.322335  ...
# S129              -0.318083        -0.382827         0.420826  ...
# S130               0.361625        -0.475584        -0.291893  ...
# S131               0.286218        -0.159277         0.428637  ...
#
# Name       ZWILCH_proteomics  ZWINT_proteomics  ZYG11B_proteomics  \
# Sample_ID
# S002               -0.195793               NaN          -0.145053
# S006                0.574339               NaN           0.075401
# S007                1.020321               NaN          -0.245864
# S009                0.149523         -0.313370          -0.507473
# S011                0.007854         -0.106049           0.377063
# ...                      ...               ...                ...
# S127               -0.612827         -0.149425           0.017523
# S128                0.716779         -0.676827          -0.569823
# S129               -0.048390               NaN           0.675466
# S130                0.952951          0.874700          -0.185089
# S131                0.467271               NaN          -0.228770
#
# Name       ZYX_proteomics  ZZEF1_proteomics  ZZZ3_proteomics  \
# Sample_ID
# S002             0.590217          0.019414              NaN
# S006            -0.437564         -0.208831              NaN
# S007             0.008411          0.130504        -0.367433
# S009             0.221818          0.278313        -1.008998
# S011            -0.295592          0.011997        -0.236003
# ...                   ...               ...              ...
# S127             0.442398          0.088551        -0.614771
# S128             0.640503          0.763645        -1.370872
# S129             0.267934          0.583772         0.501873
# S130            -0.426710          0.008868        -0.278545
# S131             0.182717          0.298465        -0.591317
#
# Name            A2M_Mutation   A2M_Location  A2M_Mutation_Status  \
# Sample_ID
# S002        [Wildtype_Tumor]  [No_mutation]       Wildtype_Tumor
# S006        [Wildtype_Tumor]  [No_mutation]       Wildtype_Tumor
# S007        [Wildtype_Tumor]  [No_mutation]       Wildtype_Tumor
# S009        [Wildtype_Tumor]  [No_mutation]       Wildtype_Tumor
# S011        [Wildtype_Tumor]  [No_mutation]       Wildtype_Tumor
# ...                      ...            ...                  ...
# S127       [Wildtype_Normal]  [No_mutation]      Wildtype_Normal
# S128       [Wildtype_Normal]  [No_mutation]      Wildtype_Normal
# S129       [Wildtype_Normal]  [No_mutation]      Wildtype_Normal
# S130       [Wildtype_Normal]  [No_mutation]      Wildtype_Normal
# S131       [Wildtype_Normal]  [No_mutation]      Wildtype_Normal
#
# Name       Sample_Status
# Sample_ID
# S002               Tumor
# S006               Tumor
# S007               Tumor
# S009               Tumor
# S011               Tumor
# ...                  ...
# S127              Normal
# S128              Normal
# S129              Normal
# S130              Normal
# S131              Normal
#
# [103 rows x 10690 columns]

# %%
# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
ov_prot = list(mut_status.columns[:-1])

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

ov_dict = {}

for prot in ov_prot:
    delta_ov = mut_med[prot] - wt_med[prot]
    ov_dict[prot] = delta_ov

ov_df = pd.DataFrame.from_dict(ov_dict, orient='index', columns=['Ovarian'])
ov_df
# Out:
#                       Ovarian
# A1BG_proteomics      0.395498
# A2M_proteomics      -0.366803
# A2ML1_proteomics    -0.636105
# AAAS_proteomics    0.00318497
# AACS_proteomics       1.66682
# ...                       ...
# ZWINT_proteomics     0.468774
# ZYG11B_proteomics   -0.617178
# ZYX_proteomics      -0.666237
# ZZEF1_proteomics     0.214055
# ZZZ3_proteomics     -0.791399
#
# [10077 rows x 1 columns]

# %% [markdown]
# Breast

# %%
b = cptac.Brca()
# Out:
# Password: ········
# Wrong password. Try again: ········
# Wrong password. Try again: ········

# %% [markdown]
# No Somatic Mut in brca

# %%
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot = b.get_proteomics()
#prot = b.reduce_multiindex(prot, levels_to_drop = 1)
prot_list = list(prot.columns)
prot_and_mutations = b.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = prot_list) 
prot_and_mutations = b.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
b_prot = list(mut_status.columns[:-1])
# Out:
# cptac warning: Due to dropping the specified levels, dataframe now has 655 duplicated column headers. (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)
# ---------------------------------------------------------------------------
# DataframeNotIncludedError                 Traceback (most recent call last)
# <ipython-input-24-b05fd3e9e0bf> in <module>
#       4 prot_list = list(prot.columns)
#       5 prot_and_mutations = b.join_omics_to_mutations(
# ----> 6     mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = prot_list)
#       7 prot_and_mutations = b.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)
#       8
#
# ~\Anaconda3\envs\Research\lib\site-packages\cptac\dataset.py in join_omics_to_mutations(self, omics_df_name, mutations_genes, omics_genes, mutations_filter, show_location)
#     327         # Select the data from each dataframe
#     328         omics = self._get_omics_cols(omics_df_name, omics_genes)
# --> 329         mutations = self._get_genes_mutations(mutations_genes, mutations_filter)
#     330
#     331         mutations_were_filtered = mutations_filter is not None
#
# ~\Anaconda3\envs\Research\lib\site-packages\cptac\dataset.py in _get_genes_mutations(self, genes, mutations_filter)
#     630         pandas DataFrame: The mutations in each patient for the specified gene(s).
#     631         """
# --> 632         somatic_mutation = self.get_somatic_mutation()
#     633
#     634         # Process genes parameter
#
# ~\Anaconda3\envs\Research\lib\site-packages\cptac\dataset.py in get_somatic_mutation(self)
#     159     def get_somatic_mutation(self):
#     160         """Get the somatic_mutation dataframe."""
# --> 161         return self._get_dataframe("somatic_mutation")
#     162
#     163     def get_somatic_mutation_binary(self):
#
# ~\Anaconda3\envs\Research\lib\site-packages\cptac\dataset.py in _get_dataframe(self, name)
#     429             return return_df
#     430         else:
# --> 431             raise DataframeNotIncludedError("{} dataframe not included in this dataset.".format(name))
#     432
#     433     def _get_sample_status_map(self):
#
# DataframeNotIncludedError: somatic_mutation dataframe not included in this dataset.

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

b_dict = {}

for prot in b_prot:
    delta_b = mut_med[prot] - wt_med[prot]
    b_d[prot] = delta_b

b_df = pd.DataFrame.from_dict(gbm_d, orient='index', columns=['Breast'])
b_df

# %% [markdown]
# Colon

# %%
col = cptac.Colon()

# %%
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot = col.get_proteomics()
col_prot_list = list(prot.columns)
prot_and_mutations = col.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = col_prot_list) 
#prot_and_mutations = col.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
col_prot = list(mut_status.columns[:-1])
# Out:
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 199 samples for the A2M gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 5)
# cptac warning: proteomics data was not found for the following samples, so proteomics data columns were filled with NaN for these samples: S001, S013, S015, S017, S038, S080, S081, S090, S099, S109 (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 5)

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

col_dict = {}

for prot in col_prot:
    delta_col = mut_med[prot] - wt_med[prot]
    col_dict[prot] = delta_col

col_df = pd.DataFrame.from_dict(col_dict, orient='index', columns=['Colon'])
col_df
# Out:
#                      Colon
# A1BG_proteomics    0.06250
# A1CF_proteomics    0.08750
# A2M_proteomics     0.02800
# AAAS_proteomics    0.10350
# AACS_proteomics   -0.22550
# ...                    ...
# ZW10_proteomics    0.01840
# ZWILCH_proteomics  0.27365
# ZWINT_proteomics       NaN
# ZYX_proteomics    -0.02000
# ZZEF1_proteomics  -0.06150
#
# [8067 rows x 1 columns]

# %% [markdown]
# Kidney

# %%
r = cptac.Ccrcc()
# PROBLEM can't find A2M in somatic

# %%
r.list_data()
# Out:
# Below are the dataframes contained in this dataset:
# 	clinical
# 		Dimensions: (194, 173)
# 	CNV
# 		Dimensions: (110, 19285)
# 	medical_history
# 		Dimensions: (370, 4)
# 	methylation
# 		Dimensions: (107, 15885)
# 	phosphoproteomics
# 		Dimensions: (194, 81550)
# 	phosphoproteomics_gene
# 		Dimensions: (194, 6127)
# 	proteomics
# 		Dimensions: (194, 11710)
# 	somatic_mutation
# 		Dimensions: (8350, 3)
# 	transcriptomics
# 		Dimensions: (185, 19275)

# %%
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
p = r.get_proteomics()
prot = r.reduce_multiindex(p, levels_to_drop = 1)
k_prot_list = list(prot.columns)

prot_and_mutations = r.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = mut_genes) 
prot_and_mutations = r.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
k_prot = list(mut_status.columns[:-1])
# Out:
# cptac warning: Due to dropping the specified levels, dataframe now has 907 duplicated column headers. (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: A2ML1, A4GNT, AADACL3, AATK, ABCA10, ABCA13, ABCA4, ABCA7, ABCB11, ABCB4, ABCC11, ABCC12, ABCC8, ABCD2, ABCD4, ABCG5, ABCG8, AC005480.1, AC013461.1, AC026348.1, ACACA, ACAD10, ACER2, ACOXL, ACRBP, ACTL7B, ACTL9, ACTN3, ADAD1, ADAM12, ADAM18, ADAM19, ADAM2, ADAM23, ADAM32, ADAM33, ADAMTS10, ADAMTS12, ADAMTS14, ADAMTS16, ADAMTS18, ADAMTS20, ADAMTS3, ADAMTS8, ADCY4, ADCY8, ADGB, ADGRA1, ADGRA3, ADGRB1, ADGRB2, ADGRB3, ADGRD1, ADGRD2, ADGRE4P, ADGRF4, ADGRG2, ADGRG4, ADGRG7, ADGRL3, ADH7, ADORA2A, ADRA1B, ADTRP, AFF2, AFF3, AGAP6, AGAP9, AGBL1, AGBL2, AGBL5, AGTR2, AHI1, AIM1L, AIPL1, AK8, AKAP3, AKAP4, AKAP6, AKIRIN2, AL356053.1, AL356585.1, ALDH4A1, ALG10, ALK, ALLC, ALOX12B, ALPK3, ALS2CR11, AMBN, AMELX, AMER3, AMH, AMIGO1, AMPD1, AMY2B, ANGPT4, ANHX, ANKH, ANKMY1, ANKRD1, ANKRD30A, ANKRD30B, ANKRD30BL, ANKRD33, ANKRD34B, ANKRD34C, ANKRD35, ANKRD36B, ANKRD36C, ANKRD42, ANKRD66, ANKS1B, ANO2, ANO7, APBB3, APCDD1L, APOBEC1, APOL4, AQP8, AQP9, ARHGAP19, ARHGAP33, ARHGAP36, ARHGDIG, ARHGEF19, ARHGEF33, ARID5A, ARMC2, ARMCX4, ARNTL2, ARR3, ARRDC3, ARRDC4, ARSG, ART5, ASB4, ASTL, ASTN1, ASXL1, ASZ1, ATAD3C, ATF4, ATF7IP2, ATG9B, ATP10A, ATP12A, ATP1A2, ATP2A1, ATP4A, ATP5A1, ATP5B, ATP5F1, ATP5I, ATP8A1, ATP8A2, ATP8B2, ATPIF1, ATXN3L, ATXN7L1, AXDND1, AXIN2, AZIN1, AZIN2, B3GALNT2, B3GALT1, B3GNT4, B3GNT5, B3GNT6, B3GNT8, BACE1, BACH2, BAHCC1, BAIAP3, BARX1, BATF2, BAZ2A, BBOF1, BCDIN3D, BCL2L14, BEGAIN, BEST1, BEX4, BHMG1, BIRC8, BIVM-ERCC5, BMP3, BMP5, BMP6, BMP7, BOC, BORA, BPIFA3, BPIFB3, BRE, BRINP1, BRINP2, BTBD18, BTG4, BTLA, BVES, C10orf54, C10orf71, C10orf90, C11orf45, C11orf53, C11orf57, C11orf63, C11orf80, C12orf40, C12orf56, C12orf76, C14orf159, C14orf80, C15orf52, C15orf53, C15orf57, C15orf59, C16orf96, C17orf100, C17orf74, C18orf63, C18orf8, C19orf24, C19orf57, C1QL2, C1QL4, C1QTNF4, C1orf112, C1orf127, C1orf137, C1orf159, C1orf168, C1orf64, C1orf87, C2orf71, C2orf78, C2orf81, C3orf20, C3orf49, C3orf84, C4orf17, C5orf42, C5orf52, C5orf56, C8orf34, C9orf114, C9orf172, C9orf3, C9orf43, C9orf47, C9orf50, C9orf69, CACNA1B, CACNA1C, CACNA1D, CACNA1E, CACNA1F, CACNA1G, CACNA1H, CACNA1I, CACNA1S, CACNA2D4, CACNB1, CACNB2, CACNB4, CACNG7, CACNG8, CADM2, CADPS, CAGE1, CALML6, CALR3, CAMTA1, CAPN8, CAPN9, CAPRIN2, CAPS2, CARMIL3, CASC1, CASC5, CASP5, CASS4, CATSPER1, CATSPERB, CATSPERG, CBARP, CCDC110, CCDC112, CCDC114, CCDC129, CCDC13, CCDC138, CCDC141, CCDC146, CCDC15, CCDC153, CCDC163P, CCDC168, CCDC170, CCDC171, CCDC173, CCDC178, CCDC18, CCDC180, CCDC27, CCDC40, CCDC42, CCDC57, CCDC63, CCDC73, CCDC74B, CCDC87, CCDC96, CCER1, CCIN, CCL11, CCL3L3, CCM2L, CCNE1, CCNO, CCR3, CD1C, CD207, CD3EAP, CD80, CDC25C, CDCP2, CDH15, CDH22, CDH23, CDH24, CDH8, CDHR4, CDK5R2, CDKN2D, CEACAM16, CEACAM21, CEACAM5, CECR1, CECR5, CEL, CELF5, CEMP1, CENPJ, CEP162, CEP295, CEP57L1, CERKL, CERS1, CFAP221, CFAP43, CFAP45, CFAP52, CFAP54, CFAP58, CFAP65, CFAP74, CFAP77, CFAP99, CH17-224D4.1, CHI3L2, CHP2, CHRM2, CHRM3, CHRNA2, CHRNA4, CHRNB3, CHRNG, CHST1, CHST4, CHST5, CHST6, CHSY3, CIB3, CILP2, CIPC, CISH, CLCA1, CLCA2, CLCA4, CLCN1, CLDN11, CLDN17, CLDN34, CLEC4E, CLTA, CLUL1, CNGA1, CNGA2, CNTN2, CNTN5, CNTNAP2, CNTNAP5, COL11A1, COL11A2, COL19A1, COL24A1, COL27A1, COL6A5, COL6A6, COL9A1, COL9A3, COLQ, CORIN, CORT, COX7B2, CPA2, CPA5, CPAMD8, CPED1, CPLX4, CPNE7, CPNE9, CRAMP1, CRB1, CRCT1, CRHR2, CRISP2, CRNN, CROCC2, CRTAM, CRY1, CRYBA1, CRYGC, CSF3, CSMD1, CSMD2, CSMD3, CSN1S1, CSN2, CSNK1E, CT47B1, CTAGE1, CTAGE15, CTB-60B18.10, CTD-3074O7.11, CTNNA3, CTXN3, CUX2, CXorf21, CYLC1, CYP11B2, CYP1A1, CYP26A1, CYP26B1, CYP2A13, CYP2A6, CYP2A7, CYP2B6, CYP2D6, CYP2E1, CYP4B1, CYP7A1, CYYR1, DAB1, DAGLA, DAOA, DBNDD2, DBX1, DCAF15, DCAF8L1, DCAF8L2, DCBLD1, DCC, DCHS2, DCLRE1B, DCST1, DDX4, DDX43, DDX53, DEFB118, DEFB134, DGAT2, DGCR2, DGKB, DGKK, DHDH, DHFRL1, DHRS7C, DIO3, DISC1, DISP2, DKK2, DKK4, DLG4, D ...
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# <ipython-input-47-a37b108af1e3> in <module>
#       5
#       6 prot_and_mutations = r.join_omics_to_mutations(
# ----> 7     mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = mut_genes)
#       8 prot_and_mutations = r.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)
#       9
#
# ~\Anaconda3\envs\Research\lib\site-packages\cptac\dataset.py in join_omics_to_mutations(self, omics_df_name, mutations_genes, omics_genes, mutations_filter, show_location)
#     327         # Select the data from each dataframe
#     328         omics = self._get_omics_cols(omics_df_name, omics_genes)
# --> 329         mutations = self._get_genes_mutations(mutations_genes, mutations_filter)
#     330
#     331         mutations_were_filtered = mutations_filter is not None
#
# ~\Anaconda3\envs\Research\lib\site-packages\cptac\dataset.py in _get_genes_mutations(self, genes, mutations_filter)
#     659             gene_mutations = somatic_mutation[somatic_mutation[gene_col] == gene] # Get all the mutations for that gene
#     660             if len(gene_mutations) == 0: # If the gene doesn't match any genes in the dataframe, tell them
# --> 661                 raise InvalidParameterError("{} gene not found in somatic_mutation data.".format(gene))
#     662             gene_mutations = gene_mutations.drop(columns=[gene_col]) # Gene column is same for every sample, so we don't need it anymore.
#     663
#
# InvalidParameterError: A2M gene not found in somatic_mutation data.

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

k_dict = {}

for prot in k_prot:
    delta_k = mut_med[prot] - wt_med[prot]
    k_dict[prot] = delta_k

k_df = pd.DataFrame.from_dict(k_dict, orient='index', columns=['Kidney'])
k_df

# %% [markdown]
# Lung - no mutations data

# %%
l = cptac.Luad()

# %%
l.list_data()
# Out:
# Below are the dataframes contained in this dataset:
# 	circular_RNA
# 		Dimensions: (213, 371843)
# 	clinical
# 		Dimensions: (215, 17)
# 	CNV
# 		Dimensions: (110, 19267)
# 	derived_molecular
# 		Dimensions: (215, 28)
# 	experimental_design
# 		Dimensions: (215, 3)
# 	phosphoproteomics
# 		Dimensions: (213, 40868)
# 	proteomics
# 		Dimensions: (213, 10544)
# 	transcriptomics
# 		Dimensions: (213, 18099)

# %%
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot = l.get_proteomics()
prot_list = list(prot.columns)
prot_and_mutations = l.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = prot_list) 
prot_and_mutations = l.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
k_prot = list(mut_status.columns[:-1])

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

gbm_d = {}

for prot in gbm_prot:
    dif_gbm = mut_med[prot] - wt_med[prot]
    gbm_d[prot] = dif_gbm

gbm_df = pd.DataFrame.from_dict(gbm_d, orient='index', columns=['Gbm'])
gbm_df

# %% [markdown]
# Head and Neck

# %%
h = cptac.Hnscc()
#cptac.download(dataset='hnscc', version='0.1')

# %%
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot = h.get_proteomics()
h_prot_list = list(prot.columns)
prot_and_mutations = h.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = h_prot_list) 
#prot_and_mutations = r.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
h_prot = list(mut_status.columns[:-1])
prot
# Out:
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 196 samples for the A2M gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 5)
# Name               A1BG  A1CF           A2M         A2ML1         AAAS  \
# Sample_ID
# S001       2.090086e+05   NaN  3.169588e+05  1.278676e+05  61198.50781
# S002       5.726306e+05   NaN  5.605086e+05  2.623658e+05  30010.43555
# S003       5.954938e+05   NaN  1.107243e+06  2.557377e+04  19343.25391
# S004       3.755826e+05   NaN  4.859903e+05  3.731648e+05  18545.10938
# S005       2.923673e+05   NaN  3.238957e+05  1.154655e+05  34675.20703
# ...                 ...   ...           ...           ...          ...
# S193       2.316239e+06   NaN  8.514064e+05  5.124112e+05  24080.87695
# S194       1.735934e+06   NaN  1.926559e+06  3.774452e+05  27293.94922
# S195       9.297289e+05   NaN  1.146008e+06  1.006445e+06  36771.63672
# S196       1.177956e+06   NaN  1.022116e+06  1.381642e+06  11275.50391
# S197       4.059715e+06   NaN  3.359214e+06  2.911415e+05  10770.53809
#
# Name               AACS        AADAC         AAGAB          AAK1  \
# Sample_ID
# S001        54445.06641          NaN  138961.29690  143747.10940
# S002        71837.50781  69098.47656   75495.77344   97025.68750
# S003        73388.98438          NaN   68165.36719  134949.07810
# S004       111085.10160          NaN   67968.65625  168306.04690
# S005       153974.01560          NaN   51690.14844   94351.96875
# ...                 ...          ...           ...           ...
# S193       131624.78130  22531.23633  108717.48440   74495.31250
# S194        48265.03125  27539.27344   96342.39063  123767.98440
# S195       256401.56250  95135.33594  110969.01560   54404.17188
# S196       164977.59380          NaN   91730.07813   53541.27344
# S197        75156.27344          NaN           NaN   62914.21484
#
# Name              AAMDC  ...          ZPR1       ZRANB2       ZSCAN18  \
# Sample_ID                ...
# S001        34986.92578  ...  9.538424e+04  62996.69922           NaN
# S002       123058.08590  ...  6.145821e+04  58077.59766   7711.908691
# S003        87318.88281  ...  3.359543e+04  53673.23438   3136.051270
# S004        28307.11914  ...  4.453987e+04  58258.71875   6938.365723
# S005        63841.08984  ...  4.790249e+04  53108.20703   2420.186279
# ...                 ...  ...           ...          ...           ...
# S193        49941.30469  ...  4.447878e+04  31093.83594           NaN
# S194        98999.63281  ...  3.698473e+06  66186.18750           NaN
# S195        75059.90625  ...  6.358499e+04  44610.88672  13106.506840
# S196       161025.07810  ...  4.618612e+05  50624.80859           NaN
# S197        99082.17969  ...  4.979308e+04  56393.73047           NaN
#
# Name            ZSCAN22        ZSWIM8           ZW10       ZWILCH  \
# Sample_ID
# S001                NaN           NaN   50810.339840          NaN
# S002       1.060632e+06           NaN   36131.234380          NaN
# S003       1.264901e+05           NaN   48966.753910          NaN
# S004                NaN           NaN   32046.611330  14693.20313
# S005       2.646007e+05           NaN   32376.484380  30586.55859
# ...                 ...           ...            ...          ...
# S193                NaN           NaN   32107.490230          NaN
# S194                NaN  21487.738280   25806.683590          NaN
# S195                NaN   9764.105469   18961.500000          NaN
# S196       1.117438e+06           NaN  230930.812500          NaN
# S197                NaN           NaN    8050.824707          NaN
#
# Name            ZYG11B          ZYX         ZZEF1
# Sample_ID
# S001       4094.607666  480512.5625  37413.476560
# S002       1639.182739  469727.1563           NaN
# S003       3454.098145  610486.0000  28222.318360
# S004               NaN  802913.1250  19900.980470
# S005       2526.389893  598533.5000  12320.259770
# ...                ...          ...           ...
# S193               NaN  427802.7188           NaN
# S194       1724.240356  529307.5625  20021.916020
# S195       3363.531250  294508.5938  17253.710940
# S196               NaN  293045.5000   8667.539063
# S197               NaN  427285.4688  15949.488280
#
# [197 rows x 8206 columns]

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

h_dict = {}

for prot in h_prot:
    dif_h = mut_med[prot] - wt_med[prot]
    h_dict[prot] = dif_h

h_df = pd.DataFrame.from_dict(h_dict, orient='index', columns=['Hnscc'])
h_df
# Out:
#                            Hnscc
# A1BG_proteomics    185250.093800
# A1CF_proteomics              NaN
# A2M_proteomics     987646.879885
# A2ML1_proteomics    28202.921920
# AAAS_proteomics      5268.292970
# ...                          ...
# ZW10_proteomics    482515.375000
# ZWILCH_proteomics            NaN
# ZYG11B_proteomics            NaN
# ZYX_proteomics     303690.375000
# ZZEF1_proteomics    12335.336915
#
# [8169 rows x 1 columns]

# %% [markdown]
# Combine

# %%
dd = {'Gbm': [dif_gbm],'Hscc':['add'],'Lung':['add'],'Breast':['add'],'Endo': [dif_en],
      'Ovarian': [dif_ov], 'Colon':[dif_colon],'Kidney':[dif_k] } #list, avoid from_dict error passing in scalars -index

pan_cancer_df = pd.DataFrame.from_dict(dd, orient='index', columns=['Directionality']) #orient makes keys index
pan_cancer_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-d2e9b9b3f0bf> in <module>
#       1 dd = {'Gbm': [dif_gbm],'Hscc':['add'],'Lung':['add'],'Breast':['add'],'Endo': [dif_en],
# ----> 2       'Ovarian': [dif_ov], 'Colon':[dif_colon],'Kidney':[dif_k] } #list, avoid from_dict error passing in scalars -index
#       3
#       4 pan_cancer_df = pd.DataFrame.from_dict(dd, orient='index', columns=['Directionality']) #orient makes keys index
#       5 pan_cancer_df
#
# NameError: name 'dif_ov' is not defined

# %%
# Kidney 'A2M not found in mutations'
# Breast and Lung no mutations dataframe

n = gbm_df.join(en_df)
m = n.join(col_df)
o = m.join(ov_df)
#l = o.join(h_df)

l = o.transpose()
l
# Out:
#         A1BG_proteomics A2M_proteomics AAAS_proteomics AACS_proteomics  \
# Gbm           0.0401876       0.108524       0.0585452      -0.0579414
# Endo             0.0345          0.016        0.098105         -0.1285
# Colon            0.0625          0.028          0.1035         -0.2255
# Ovarian        0.395498      -0.366803      0.00318497         1.66682
#
#         AADAT_proteomics AAED1_proteomics AAGAB_proteomics AAK1_proteomics  \
# Gbm             0.175684        0.0637853       -0.0369724      -0.0694868
# Endo              -0.011            -0.01           0.2065          0.3695
# Colon                NaN              NaN            0.021          0.0347
# Ovarian              NaN              NaN         0.289551       -0.415378
#
#         AAMDC_proteomics AAMP_proteomics  ... ZSCAN31_proteomics  \
# Gbm            -0.144826      -0.0714202  ...          -0.096138
# Endo              -0.248         0.05978  ...            0.08135
# Colon            -0.4685         0.16715  ...                NaN
# Ovarian         0.683487       -0.290248  ...          -0.374158
#
#         ZSWIM8_proteomics ZW10_proteomics ZWILCH_proteomics ZWINT_proteomics  \
# Gbm            -0.0494993        0.102503          0.158887        -0.246501
# Endo               0.1036         -0.0085            0.2235            0.255
# Colon                 NaN          0.0184           0.27365              NaN
# Ovarian         -0.238981        0.242028          0.487466         0.468774
#
#         ZXDC_proteomics ZYG11B_proteomics ZYX_proteomics ZZEF1_proteomics  \
# Gbm           0.0610355         0.0645135       0.116899        0.0317602
# Endo              0.053            0.1374          0.043          0.04595
# Colon               NaN               NaN          -0.02          -0.0615
# Ovarian             NaN         -0.617178      -0.666237         0.214055
#
#         ZZZ3_proteomics
# Gbm         -0.00421517
# Endo             0.0333
# Colon               NaN
# Ovarian       -0.791399
#
# [4 rows x 11141 columns]

# %%
t = l.dropna(axis=1, thresh=4) # drop all na in above df 
s = t.std()

# %%
s = s.to_frame()

# %%
s.std()
# Out:
# 0    0.210779
# dtype: float64

# %%
a = s.hist(bins = 100)
plt.title("Standard Deviation Distribution for Pancancer PTEN Mutation Effect on Proteomics\n\n (Median of proteomics with Wildtype PTEN - Median of proteomics with Mutated PTEN)")
plt.xlabel('StDeV')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.rcParams['figure.figsize']=(10,8)
sns.set(font_scale = 1.3)
a = sns.distplot(s, bins = 100)

a.set_title("Standard Deviation Distribution for Pancancer PTEN Mutation Effect on Proteomics\n\n (Median of proteomics with Wildtype PTEN - Median of proteomics with Mutated PTEN)")
a.set(xlabel = 'StDeV', ylabel = 'Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'StDeV')]

# %% [markdown]
# Mean

# %%
mean_df = t.mean()

# %%
a = mean_df.hist(bins = 100)
plt.title("Distribution of the Mean between Cancers for PTEN Mutation Effect on all Proteins\n\n (Median of proteomics with Wildtype PTEN - Median of proteomics with Mutated PTEN)")
plt.xlabel('Mean')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
m_df = t.median()

# %%
a = m_df.hist(bins = 100)
plt.title("Distribution of the Medians between Cancers for PTEN Mutation Effect on all Proteins\n\n (Median of proteomics with Wildtype PTEN - Median of proteomics with Mutated PTEN)")
plt.xlabel('Median')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
