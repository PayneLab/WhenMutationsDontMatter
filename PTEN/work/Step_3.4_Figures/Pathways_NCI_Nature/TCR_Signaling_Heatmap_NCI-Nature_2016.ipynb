# %% [markdown]
# # Create Heatmaps for significant TCR Signaling genes

# %% [markdown]
# Pancancer heatmaps are created with circle size showing significance and color showing differences in median.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as p

# %% [markdown]
# # Step 1: Run GSEA for significant genes in at least 1 cancer

# %% [markdown]
# First read in sig_pval_all_proteins.csv into a df. This csv file contains only genes with a significant p-value in at least one cancer. Then run GSEA using a list of genes from the df.

# %%
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'
sig_df = pd.read_csv(root+R'\sig_pval_heatmap.csv')

prot_list = list(sig_df.Proteomics) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='NCI-Nature_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head(30)
# Out:
#                                                  Term Overlap   P-value  \
# 0   Regulation of RAC1 activity Homo sapiens 351aa...   17/38  0.000002
# 1   Class I PI3K signaling events Homo sapiens 12b...   18/48  0.000024
# 2   E2F transcription factor network Homo sapiens ...   22/72  0.000119
# 3   Signaling events mediated by TCPTP Homo sapien...   15/42  0.000213
# 4   FAS (CD95) signaling pathway Homo sapiens 79cc...   14/38  0.000236
# 5   Fanconi anemia pathway Homo sapiens 6befb873-6...   16/47  0.000250
# 6   IL8- and CXCR2-mediated signaling events Homo ...   13/34  0.000256
# 7   Netrin-mediated signaling events Homo sapiens ...   12/30  0.000268
# 8   ATR signaling pathway Homo sapiens 8991cbac-61...   14/39  0.000323
# 9   BCR signaling pathway Homo sapiens acbf44e2-61...   19/64  0.000508
# 10  IL8- and CXCR1-mediated signaling events Homo ...   11/28  0.000579
# 11  Signaling events mediated by HDAC Class I Homo...   19/66  0.000775
# 12  Signaling events mediated by HDAC Class II Hom...   12/34  0.001016
# 13  Signaling events mediated by VEGFR1 and VEGFR2...   19/68  0.001152
# 14  Internalization of ErbB1 Homo sapiens 3aa9aafa...   13/40  0.001525
# 15  Neurotrophic factor-mediated Trk receptor sign...   17/61  0.002116
# 16  Fc-epsilon receptor I signaling in mast cells ...   16/58  0.003160
# 17  Role of Calcineurin-dependent NFAT signaling i...   15/53  0.003210
# 18  Beta2 integrin cell surface interactions Homo ...   10/29  0.003216
# 19  TCR signaling in naive CD4+ T cells Homo sapie...   17/64  0.003674
# 20  Caspase Cascade in Apoptosis Homo sapiens b9d3...   15/55  0.004718
# 21  IL2-mediated signaling events Homo sapiens a2a...   15/55  0.004718
# 22  IFN-gamma pathway Homo sapiens 51b1ed75-6193-1...   12/40  0.004805
# 23  PDGFR-beta signaling pathway Homo sapiens c901...  28/128  0.005454
# 24  ErbB1 downstream signaling Homo sapiens 30d605...  24/105  0.005455
# 25  PLK1 signaling events Homo sapiens e5e87977-61...   13/46  0.005966
# 26  Regulation of Telomerase Homo sapiens 4dfe97ca...   17/67  0.006074
# 27  Signaling events mediated by Stem cell factor ...   14/52  0.007039
# 28  TCR signaling in naive CD8+ T cells Homo sapie...   14/53  0.008414
# 29  PAR1-mediated thrombin signaling events Homo s...   12/43  0.009009
#
#     Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0           0.000493            0                     0    3.342312
# 1           0.002489            0                     0    2.801644
# 2           0.008305            0                     0    2.282821
# 3           0.011105            0                     0    2.668232
# 4           0.009853            0                     0    2.752492
# 5           0.008721            0                     0    2.543336
# 6           0.007629            0                     0    2.856578
# 7           0.007008            0                     0    2.988420
# 8           0.007496            0                     0    2.681915
# 9           0.010628            0                     0    2.217968
# 10          0.010999            0                     0    2.935055
# 11          0.013492            0                     0    2.150757
# 12          0.016337            0                     0    2.636841
# 13          0.017204            0                     0    2.087499
# 14          0.021243            0                     0    2.428091
# 15          0.027637            0                     0    2.082096
# 16          0.038850            0                     0    2.060979
# 17          0.037277            0                     0    2.114448
# 18          0.035376            0                     0    2.576224
# 19          0.038390            0                     0    1.984498
# 20          0.046953            0                     0    2.037559
# 21          0.044819            0                     0    2.037559
# 22          0.043664            0                     0    2.241315
# 23          0.047499            0                     0    1.634292
# 24          0.045603            0                     0    1.707668
# 25          0.047959            0                     0    2.111384
# 26          0.047019            0                     0    1.895639
# 27          0.052544            0                     0    2.011436
# 28          0.060638            0                     0    1.973485
# 29          0.062764            0                     0    2.084944
#
#     Combined Score                                              Genes  \
# 0        43.306082  DOCK6;ARHGAP9;RASGRF2;RAP1GDS1;VAV1;DEF6;EPS8;...
# 1        29.823357  HSP90AA1;SYK;PLEKHA1;PDPK1;PTEN;PIK3CD;PIK3R1;...
# 2        20.624449  PRMT5;RANBP1;RRM1;CDKN1B;CBX5;APAF1;HDAC1;TFE3...
# 3        22.563751  CSF1R;STAT1;PIK3CD;EIF2AK2;PIK3R1;EGFR;VEGFA;P...
# 4        22.991088  SYK;CHUK;RFC1;PDPK1;CLTC;PIK3CD;PIK3R1;MAPK10;...
# 5        21.090858  FANCI;RFC5;RFC3;WDR48;RFC4;RFC2;RMI1;TOP3A;RPA...
# 6        23.630412  PRKCG;PDPK1;PRKCB;ARRB1;ARRB2;PIK3CG;GNAI2;HCK...
# 7        24.575391  PAK1;MAP2K1;MYO10;PIK3CA;UNC5B;MAP1B;CAMK2A;EL...
# 8        21.558545  RFC5;RFC3;TIPIN;RFC4;MCM7;RFC2;PLK1;RPA1;FANCD...
# 9        16.821174  MAP4K1;MAP2K1;SYK;CHUK;PDPK1;PTEN;PIK3R1;POU2F...
# 10       21.878986  PRKCG;HCK;GNG2;PDPK1;PRKCB;ARRB1;ARRB2;PLD1;PL...
# 11       15.406118  RANBP2;MBD3;PRMT5;HDAC5;HDAC2;HDAC3;HDAC1;HDAC...
# 12       18.172371  YWHAE;RANBP2;HDAC5;TUBA1B;HSP90AA1;HDAC3;XPO1;...
# 13       14.123794  HSP90AA1;MAP2K1;HSP90AB1;PDPK1;PRKCB;PRKCD;PTP...
# 14       15.748587  TSG101;SH3KBP1;UBE2D2;PIK3CD;PIK3R1;EGFR;EPN1;...
# 15       12.822256  PRKCI;MAP2K1;RGS19;SHC3;MATK;RHOG;PIK3R1;TIAM1...
# 16       11.865392  MAP2K1;SYK;CHUK;WIPF1;PRKCB;NFATC2;PIK3R1;VAV1...
# 17       12.139769  YWHAE;NUP214;PRKCG;PRKCB;PRKCD;NFATC2;RCAN1;PP...
# 18       14.786538  C3;FGB;ITGAM;FCGR2A;ITGB2;ITGAX;ICAM3;ITGAL;IC...
# 19       11.126196  MAP4K1;CHUK;PDPK1;PRKCB;PTEN;WAS;RASGRP2;VAV1;...
# 20       10.914022  GSN;APAF1;PARP1;LMNB1;KRT18;CASP6;CFL2;CASP3;A...
# 21       10.914022  MAP2K1;SYK;PRKCB;STAT1;PIK3R1;STAM;IKZF3;DOK2;...
# 22       11.964319  MAP2K1;RAP1A;PIK3CA;STAT1;IFNGR1;CAMK2A;PRKCD;...
# 23        8.516827  CYFIP2;USP6NL;YWHAE;PTEN;PIK3CD;PTPRJ;PIK3R1;E...
# 24        8.899076  CYFIP2;USP6NL;YWHAE;MAP3K2;ATF2;MAP2K1;PDPK1;S...
# 25       10.813760  NUDC;ODF2;PLK1;BUB1B;NDC80;GOLGA2;TPX2;PAK1;KI...
# 26        9.674794  YWHAE;HSP90AA1;HDAC2;XRCC6;CDKN1B;HDAC1;XRCC5;...
# 27        9.969163  MAP4K1;MAP2K1;PDPK1;STAT1;PTEN;MATK;MITF;PIK3R...
# 28        9.429074  CHUK;PDPK1;PRKCB;RASGRP2;VAV1;ZAP70;RAP1A;PTPR...
# 29        9.819069  PRKCG;GNG2;PIK3CA;PRKCB;ARHGDIA;PRKCD;ARRB1;AR...
#
#            Gene_set
# 0   NCI-Nature_2016
# 1   NCI-Nature_2016
# 2   NCI-Nature_2016
# 3   NCI-Nature_2016
# 4   NCI-Nature_2016
# 5   NCI-Nature_2016
# 6   NCI-Nature_2016
# 7   NCI-Nature_2016
# 8   NCI-Nature_2016
# 9   NCI-Nature_2016
# 10  NCI-Nature_2016
# 11  NCI-Nature_2016
# 12  NCI-Nature_2016
# 13  NCI-Nature_2016
# 14  NCI-Nature_2016
# 15  NCI-Nature_2016
# 16  NCI-Nature_2016
# 17  NCI-Nature_2016
# 18  NCI-Nature_2016
# 19  NCI-Nature_2016
# 20  NCI-Nature_2016
# 21  NCI-Nature_2016
# 22  NCI-Nature_2016
# 23  NCI-Nature_2016
# 24  NCI-Nature_2016
# 25  NCI-Nature_2016
# 26  NCI-Nature_2016
# 27  NCI-Nature_2016
# 28  NCI-Nature_2016
# 29  NCI-Nature_2016

# %% [markdown]
# # Step 2: Get the list of significant genes

# %%
i = 8
trans = prot_enr.res2d.Genes[i]
genes = trans.split(';')
print(prot_enr.res2d.Term[i])
print('total genes:',len(genes))
# Out:
# ATR signaling pathway Homo sapiens 8991cbac-618b-11e5-8ac5-06603eb7f303
# total genes: 14

# %% [markdown]
# # Step 3: Create HeatMap

# %% [markdown]
# Slice out genes from the DNA Replication pathway from the df with genes sig in > 1 cancer.

# %%
# sig > 1 cancer
bool_df = sig_df.Proteomics.isin(genes)
plot_df = sig_df[bool_df]
len(plot_df.Proteomics.unique())
# Out:
# 14

# %%
# Only include p-values < a 
a = 0.05
plot_df = plot_df.loc[plot_df['P_Value'] <= a]

# %%
p.plotCircleHeatMap(plot_df, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                    plot_height=200, plot_width= 300)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1231">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="bed2d3c6-594b-4c84-abe3-9803488ad0d3" data-root-id="1232"></div>

# %% [markdown]
# # Step 4: Create a HeatMap with both +/- differences in median

# %% [markdown]
#  Read in the pos_neg_df.csv to create a df with only genes that have a pos and neg difference in median in different cancers. Slice out the genes that have a pos and neg difference in median in the pathway using the list of genes with a significant p-value in the pathway.

# %%
pos_neg_df = pd.read_csv(root+R'\pos_neg_df.csv')

# %%
get = pos_neg_df.Proteomics.isin(genes) # bool df where True has both pos and neg
genes_pn = pos_neg_df[get] # Keep only genes with pos and neg
genes_pn.Proteomics.unique()
# Out:
# array(['RFC5', 'MCM2', 'MCM7', 'RFC2', 'TIPIN', 'RFC4', 'TOPBP1', 'CHEK1',
#        'PLK1'], dtype=object)

# %%
# Only include p-values < a
genes_pn = genes_pn.loc[genes_pn['P_Value'] <= a]

# %%
p.plotCircleHeatMap(genes_pn, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                    plot_height=400, plot_width=400)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4011">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d788ace7-1ee3-493d-85ca-3b9656a3a47f" data-root-id="4012"></div>

# %% [markdown]
# # Sig in multiple cancers

# %%
mult_sig_df = pd.read_csv(root+R'\mult_sig_pval_heatmap.csv')

mult_sig_list = list(mult_sig_df.Proteomics.unique()) # list of genes with a sig pval in > 1 cancer
enr2 = gp.enrichr(gene_list = mult_sig_list, description='Tumor_partition', gene_sets='NCI-Nature_2016', 
                       outdir='/Enrichr')

# %%
enr2.res2d.iloc[[2]]
# Out:
#                                                 Term Overlap   P-value  \
# 2  TCR signaling in naive CD4+ T cells Homo sapie...    8/64  0.000014
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 2          0.000982            0                     0    7.225434
#
#    Combined Score                                       Genes         Gene_set
# 2       80.708757  MAP4K1;ZAP70;CD4;PTPRC;CHUK;PRKCB;PTEN;WAS  NCI-Nature_2016

# %%
i = 2
trans2 = enr2.res2d.Genes[i]
genes_mult = trans2.split(';')
print(enr2.res2d.Term[i])
print('total genes:',len(genes_mult))
# Out:
# TCR signaling in naive CD4+ T cells Homo sapiens 0c2862fa-6196-11e5-8ac5-06603eb7f303
# total genes: 8

# %%
bool_df = mult_sig_df.Proteomics.isin(genes_mult)
plot_df2 = mult_sig_df[bool_df]
plot_df2.Proteomics.unique()
# Out:
# array(['PTEN', 'CHUK', 'PRKCB', 'WAS', 'PTPRC', 'CD4', 'ZAP70', 'MAP4K1'],
#       dtype=object)

# %%
# Only include p-values < a
plot_df2 = plot_df2.loc[plot_df2['P_Value'] <= a]

# %%
p.plotCircleHeatMap(plot_df2, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                    plot_height=300, plot_width=400, legend_min= 1e-4, legend_max=0.05)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3652">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6ca255c5-7f46-4411-a06f-f39dfd06c8d8" data-root-id="3653"></div>

# %%
get = pos_neg_df.Proteomics.isin(genes_mult) # bool df where True has both pos and neg
genes_pn_mult = pos_neg_df[get] # Keep only genes with pos and neg
genes_pn_mult.Proteomics.unique()
# Out:
# array(['MAP4K1'], dtype=object)

# %%
# Only include p-values < a
genes_pn_mult = genes_pn_mult.loc[genes_pn_mult['P_Value'] <= a]

# %%
p.plotCircleHeatMap(genes_pn_mult, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                    plot_height=400, plot_width=400)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2396">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="505135d7-0569-458d-b811-109d35858054" data-root-id="2397"></div>

# %% [markdown]
# # Check other pathways the genes (+/- and sig in mult. cancers) are part of

# %%
enr3 = gp.enrichr(gene_list = genes_mult, description='Tumor_partition', gene_sets='NCI-Nature_2016', 
                       outdir='/Enrichr')

# %%
enr3.res2d.head()
# Out:
#                                                 Term Overlap       P-value  \
# 0  Signaling events mediated by TCPTP Homo sapien...   15/42  3.941340e-42
# 1  SHP2 signaling Homo sapiens 85755aa4-6195-11e5...    8/57  1.650498e-17
# 2  EGF receptor (ErbB1) signaling pathway Homo sa...    6/34  7.493580e-14
# 3  IL2-mediated signaling events Homo sapiens a2a...    6/55  1.602335e-12
# 4  IL4-mediated signaling events Homo sapiens cff...    6/60  2.761855e-12
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0      8.237400e-40            0                     0  476.190476
# 1      1.724771e-15            0                     0  187.134503
# 2      5.220527e-12            0                     0  235.294118
# 3      8.372202e-11            0                     0  145.454545
# 4      1.154456e-10            0                     0  133.333333
#
#    Combined Score                                              Genes  \
# 0    45398.596743  CSF1R;STAT1;EIF2AK2;PIK3CD;PIK3R1;EGFR;VEGFA;P...
# 1     7231.414128      PIK3CA;STAT1;GRB2;PIK3R1;JAK3;EGFR;VEGFA;JAK1
# 2     7111.092855               PIK3CA;STAT1;PIK3CD;GRB2;PIK3R1;EGFR
# 3     3950.481299                 PIK3CA;STAT1;GRB2;PIK3R1;JAK3;JAK1
# 4     3548.682453                 PIK3CA;STAT6;GRB2;PIK3R1;JAK3;JAK1
#
#           Gene_set
# 0  NCI-Nature_2016
# 1  NCI-Nature_2016
# 2  NCI-Nature_2016
# 3  NCI-Nature_2016
# 4  NCI-Nature_2016

# %%
i = 4
print(enr3.res2d.Term[i])
enr3.res2d.Genes[i]
# Out:
# IL4-mediated signaling events Homo sapiens cff33f50-6193-11e5-8ac5-06603eb7f303
# 'PIK3CA;STAT6;GRB2;PIK3R1;JAK3;JAK1'

# %%
# Look at p-values 
certain_gene = 'SYK'
all_df = pd.read_csv(root+R'\all_heatmap.csv')
gene_df = all_df.loc[all_df['Proteomics'] == certain_gene]
gene_df
# Out:
#       Proteomics   P_Value   Medians Cancer
# 499          SYK  0.000320 -0.697550    Gbm
# 11499        SYK  0.001919 -0.225323  Hnscc
# 23264        SYK  0.021461 -0.489000   Luad
# 40690        SYK  0.675254  0.222300   Lscc
# 53912        SYK  0.905056  0.020400   Brca
# 54758        SYK  0.003901  0.405618     Ov
# 67986        SYK  0.085643  0.079000     En
# 82040        SYK  0.775873  0.034700  Colon
