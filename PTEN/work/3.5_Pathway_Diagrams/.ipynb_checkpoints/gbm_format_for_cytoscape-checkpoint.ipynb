# %% [markdown]
# # Format csv for cytoscape (add exp

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as pu

# %%
en = cptac.Endometrial()

# %%
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'
endo = pd.read_csv(root+R'\endo_pval_medians.csv')
endo = endo.replace('_proteomics','',regex=True)

# %%
def replace(items, a, b): 
    return [b if x == a else x for x in items]

# %%
# covert gene name to equivilent name in endo dataset
dna_rep = u.get_proteins_in_pathway('DNA Replication')
dna_rep = replace(dna_rep,'ORC1L','ORC1')
dna_rep = replace(dna_rep,'ORC2L','ORC2')
dna_rep = replace(dna_rep,'ORC3L','ORC3')
dna_rep = replace(dna_rep,'ORC4L','ORC4')
dna_rep = replace(dna_rep,'ORC5L','ORC5')
dna_rep = replace(dna_rep,'ORC6L','ORC6')
dna_rep = replace(dna_rep,'POLA','POLA1')
dna_rep = replace(dna_rep,'PRIM2A','PRIM2')

dna_rep
# Out:
# ['CDC7',
#  'MCM7',
#  'RPA4',
#  'UBA52',
#  'MCM4',
#  'RFC1',
#  'CDT1',
#  'POLD4',
#  'RFC2',
#  'ASK',
#  'GMNN',
#  'MCM10',
#  'CDC6',
#  'RPA1',
#  'RPA2',
#  'PCNA',
#  'MCM5',
#  'MCM2',
#  'ORC5',
#  'RFC4',
#  'MCM3',
#  'RFC3',
#  'POLD1',
#  'PRIM2',
#  'CDC45L',
#  'MCM6',
#  'UBC',
#  'POLE2',
#  'CDK2',
#  'POLD2',
#  'POLD3',
#  'ORC1',
#  'RPA3',
#  'RFC5',
#  'POLA2',
#  'ORC2',
#  'POLE',
#  'ORC3',
#  'PRIM1',
#  'POLA1',
#  'ORC4',
#  'ORC6']

# %%
b = endo['Proteomics'].isin(dna_rep)
dna_rep_df = endo[b]
dna_rep_df
# Out:
#       Proteomics  En_P_Value  En_Median
# 261         RFC2    0.000651    -0.3720
# 383         ORC4    0.001638    -0.2398
# 407         ORC5    0.001865    -0.1822
# 439         RFC4    0.002179    -0.3287
# 500         ORC3    0.002752    -0.1570
# 619         ORC2    0.004433    -0.2539
# 623         RFC5    0.004491    -0.4659
# 839         MCM2    0.007643    -0.6110
# 920         MCM6    0.009135    -0.6230
# 1070        PCNA    0.012305    -0.2350
# 1082        MCM5    0.012583    -0.6181
# 1122        MCM7    0.013850    -0.5650
# 1153        MCM3    0.015138    -0.5040
# 1166        MCM4    0.015520    -0.6710
# 1468        RFC1    0.025071    -0.2235
# 1508        ORC6    0.026642    -0.7410
# 1641        RFC3    0.031671    -0.1678
# 1697       POLA2    0.033698    -0.3501
# 1980        ORC1    0.046317    -0.2723
# 2020        RPA1    0.048571     0.1395
# 2408        POLE    0.069199    -0.2140
# 2670        CDK2    0.084629    -0.1302
# 2983       POLA1    0.104944    -0.1750
# 3814       PRIM1    0.165532    -0.2994
# 4025       UBA52    0.185192    -0.0202
# 4685        GMNN    0.243642    -0.3400
# 4952       POLD1    0.272503    -0.1977
# 5420       POLD2    0.325164    -0.1097
# 6015        RPA2    0.390145     0.1755
# 7108        RPA3    0.528124     0.1465
# 8721       PRIM2    0.726383    -0.1520
# 9871       POLD3    0.882756    -0.0428
# 10331      POLE2    0.939839     0.0458
# 10613      POLD4    0.976401     0.0023

# %%
# covert gene names to equivilent names to match shared_name in cytoscape
orc_genes = ['ORC1','ORC2','ORC3','ORC4','ORC5','ORC6']
for orc in orc_genes:
    dna_rep_df = dna_rep_df.replace(orc, orc+'L', regex=True )
dna_rep_df = dna_rep_df.replace('POLA1', 'POLA', regex=True )
dna_rep_df
# Out:
#       Proteomics  En_P_Value  En_Median
# 261         RFC2    0.000651    -0.3720
# 383        ORC4L    0.001638    -0.2398
# 407        ORC5L    0.001865    -0.1822
# 439         RFC4    0.002179    -0.3287
# 500        ORC3L    0.002752    -0.1570
# 619        ORC2L    0.004433    -0.2539
# 623         RFC5    0.004491    -0.4659
# 839         MCM2    0.007643    -0.6110
# 920         MCM6    0.009135    -0.6230
# 1070        PCNA    0.012305    -0.2350
# 1082        MCM5    0.012583    -0.6181
# 1122        MCM7    0.013850    -0.5650
# 1153        MCM3    0.015138    -0.5040
# 1166        MCM4    0.015520    -0.6710
# 1468        RFC1    0.025071    -0.2235
# 1508       ORC6L    0.026642    -0.7410
# 1641        RFC3    0.031671    -0.1678
# 1697       POLA2    0.033698    -0.3501
# 1980       ORC1L    0.046317    -0.2723
# 2020        RPA1    0.048571     0.1395
# 2408        POLE    0.069199    -0.2140
# 2670        CDK2    0.084629    -0.1302
# 2983        POLA    0.104944    -0.1750
# 3814       PRIM1    0.165532    -0.2994
# 4025       UBA52    0.185192    -0.0202
# 4685        GMNN    0.243642    -0.3400
# 4952       POLD1    0.272503    -0.1977
# 5420       POLD2    0.325164    -0.1097
# 6015        RPA2    0.390145     0.1755
# 7108        RPA3    0.528124     0.1465
# 8721       PRIM2    0.726383    -0.1520
# 9871       POLD3    0.882756    -0.0428
# 10331      POLE2    0.939839     0.0458
# 10613      POLD4    0.976401     0.0023

# %%
dna_rep_df.to_csv(root+R'\en_dna_rep.csv',index=False)

# %%
dna_rep_df.En_Median.min()
# Out:
# -0.741
