# %% [markdown]
# # trans effect of truncations in domains of PTEN in Endometrial for MCM2 Phosphoproteomics

# %% [markdown]
# This notebook creates a boxplot for the trans effect of PTEN truncations in the phosphatase domain and the C2 domain in Endometrial.

# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as p

# %%
# Step 1 - Create proteomics and truncations dataframe

def get_trunc_df(trans_gene, gene='PTEN', include_wt = False):
    prot_and_mutations = en.join_omics_to_mutations(
        mutations_genes = [gene], omics_df_name = 'phosphoproteomics', omics_genes = trans_gene, 
        mutations_filter = ['Nonsense_Mutation','Frame_Shift_Del','Frame_Shift_Ins']) 
    prot_and_mutations = u.reduce_multiindex(prot_and_mutations, flatten=True)
    if include_wt == False:
        keep = ['Nonsense_Mutation','Frame_Shift_Del','Frame_Shift_Ins']
        in_keep = prot_and_mutations['PTEN_Mutation'].isin(keep)
        trunc_mutations = prot_and_mutations[in_keep]
    else:
        keep = ['Nonsense_Mutation','Frame_Shift_Del','Frame_Shift_Ins','Wildtype_Tumor']
        in_keep = prot_and_mutations['PTEN_Mutation'].isin(keep)
        trunc_mutations = prot_and_mutations[in_keep]
    print(trunc_mutations['PTEN_Mutation'].value_counts())

    # Step 2 - Create binary column 
    trunc_mutations['Mutation'] = np.where(
                trunc_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype_Tumor', 'Truncation')

    # Step 3 - Format the dataframe correctly for the t-test(just omics and binary columns for tumors)
    tumors = trunc_mutations[trunc_mutations.Sample_Status == 'Tumor'] #drop Normal samples
    columns_to_drop = [gene+"_Mutation", gene+"_Mutation_Status", "Sample_Status"]
    e_trunc_wt = tumors.drop(columns_to_drop, axis = 1)
    return e_trunc_wt

# %%
def format_pval_annotation(pval_symbol, x1, x2, line_start = .05, line_height=.05):
    # for manual adjustment to pval annotations
    
    y, h = line_start, line_height
    plt.plot([x1, x1, x2, x2], #draw horizontal line
             [y, y+h, y+h, y], #vertical line
             lw=1.5, color= '.3')
    plt.text((x1+x2)*.5, # half between x coord
             y+h, pval_symbol, horizontalalignment='center', verticalalignment='bottom', color = "black")

# %% [markdown]
# # Step 1: Create the dfs with PTEN truncations mutation in different domains

# %% [markdown]
# First, load in cancer data sets from cptac.

# %%
en = cptac.Endometrial()

# %% [markdown]
# # Create the df for the Phosphatase Domain

# %%
t_gene = 'MCM2'
df = get_trunc_df(t_gene) 
df.Mutation.value_counts()
# Out:
# Nonsense_Mutation    25
# Frame_Shift_Del      22
# Frame_Shift_Ins       6
# Name: PTEN_Mutation, dtype: int64
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 69 samples for the PTEN gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 6)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Truncation    53
# Name: Mutation, dtype: int64

# %%
# Get sites with S41
s41_dfs = {}
all_s41 = pd.DataFrame()

cols = df.columns
bool_cols = df.columns.str.contains('S41', regex=True)
sites = list(cols[bool_cols])
sites.append('Mutation')
print(sites)
s41_df = df[sites]
# format for boxplot
s41_df = s41_df.melt(id_vars='Mutation')
s41_df['Name'] = s41_df['Name'].astype(str)
s41_df = s41_df.assign(cancer = 'En')
all_s41 = all_s41.append(s41_df)
#s41_dfs[cancer] = s41_df
all_s41
# Out:
# ['MCM2_phosphoproteomics_S41', 'Mutation']
#       Mutation                        Name     value cancer
# 0   Truncation  MCM2_phosphoproteomics_S41       NaN     En
# 1   Truncation  MCM2_phosphoproteomics_S41       NaN     En
# 2   Truncation  MCM2_phosphoproteomics_S41  0.391500     En
# 3   Truncation  MCM2_phosphoproteomics_S41 -0.039000     En
# 4   Truncation  MCM2_phosphoproteomics_S41 -0.304000     En
# 5   Truncation  MCM2_phosphoproteomics_S41       NaN     En
# 6   Truncation  MCM2_phosphoproteomics_S41       NaN     En
# 7   Truncation  MCM2_phosphoproteomics_S41 -0.294000     En
# 8   Truncation  MCM2_phosphoproteomics_S41  0.199000     En
# 9   Truncation  MCM2_phosphoproteomics_S41  0.404000     En
# 10  Truncation  MCM2_phosphoproteomics_S41  0.460000     En
# 11  Truncation  MCM2_phosphoproteomics_S41  0.169250     En
# 12  Truncation  MCM2_phosphoproteomics_S41       NaN     En
# 13  Truncation  MCM2_phosphoproteomics_S41 -0.495000     En
# 14  Truncation  MCM2_phosphoproteomics_S41 -0.570500     En
# 15  Truncation  MCM2_phosphoproteomics_S41  0.565000     En
# 16  Truncation  MCM2_phosphoproteomics_S41  0.150000     En
# 17  Truncation  MCM2_phosphoproteomics_S41 -0.651500     En
# 18  Truncation  MCM2_phosphoproteomics_S41  0.668000     En
# 19  Truncation  MCM2_phosphoproteomics_S41       NaN     En
# 20  Truncation  MCM2_phosphoproteomics_S41 -1.120000     En
# 21  Truncation  MCM2_phosphoproteomics_S41       NaN     En
# 22  Truncation  MCM2_phosphoproteomics_S41 -0.696000     En
# 23  Truncation  MCM2_phosphoproteomics_S41       NaN     En
# 24  Truncation  MCM2_phosphoproteomics_S41  0.478000     En
# 25  Truncation  MCM2_phosphoproteomics_S41 -0.226000     En
# 26  Truncation  MCM2_phosphoproteomics_S41  0.065500     En
# 27  Truncation  MCM2_phosphoproteomics_S41 -1.100000     En
# 28  Truncation  MCM2_phosphoproteomics_S41 -0.301000     En
# 29  Truncation  MCM2_phosphoproteomics_S41       NaN     En
# 30  Truncation  MCM2_phosphoproteomics_S41       NaN     En
# 31  Truncation  MCM2_phosphoproteomics_S41  0.344000     En
# 32  Truncation  MCM2_phosphoproteomics_S41 -0.048100     En
# 33  Truncation  MCM2_phosphoproteomics_S41  1.100000     En
# 34  Truncation  MCM2_phosphoproteomics_S41  0.205000     En
# 35  Truncation  MCM2_phosphoproteomics_S41  0.576000     En
# 36  Truncation  MCM2_phosphoproteomics_S41  0.280000     En
# 37  Truncation  MCM2_phosphoproteomics_S41 -0.004590     En
# 38  Truncation  MCM2_phosphoproteomics_S41  0.717550     En
# 39  Truncation  MCM2_phosphoproteomics_S41  0.688000     En
# 40  Truncation  MCM2_phosphoproteomics_S41 -0.800000     En
# 41  Truncation  MCM2_phosphoproteomics_S41       NaN     En
# 42  Truncation  MCM2_phosphoproteomics_S41  0.032100     En
# 43  Truncation  MCM2_phosphoproteomics_S41  0.385000     En
# 44  Truncation  MCM2_phosphoproteomics_S41  0.591000     En
# 45  Truncation  MCM2_phosphoproteomics_S41 -0.059500     En
# 46  Truncation  MCM2_phosphoproteomics_S41  1.305000     En
# 47  Truncation  MCM2_phosphoproteomics_S41 -0.105000     En
# 48  Truncation  MCM2_phosphoproteomics_S41  0.121985     En
# 49  Truncation  MCM2_phosphoproteomics_S41 -0.239500     En
# 50  Truncation  MCM2_phosphoproteomics_S41  0.318500     En
# 51  Truncation  MCM2_phosphoproteomics_S41  0.849000     En
# 52  Truncation  MCM2_phosphoproteomics_S41 -0.959000     En

# %% [markdown]
# Create a df with only mutations located in the phosphatase domain. (Both domains effected by the mutation).

# %%
# create new column with starting amino acid (aa) as an int
t['aa'] = t.apply(lambda x: (x['PTEN_Location_']), axis=1)
df1 = t.replace({'aa': r'^p.[A-Z]*'}, {'aa': ''}, regex=True)
df2 = df1.replace({'aa': r'\*$'}, {'aa': ''}, regex=True)
df2 = df2.replace({'aa': r'[A-Z]fs\*\d*$'}, {'aa': ''}, regex=True)
df2['aa'] = pd.to_numeric(df2["aa"])

# Keep only mutations in the domain (cutoff aa = 185)
phosphatase = df2.loc[df2['aa'] <= 185]
phosphatase.head()
# Out:
# Name        MCM2_phosphoproteomics_S108  MCM2_phosphoproteomics_S139  \
# Patient_ID
# C3L-00032                           NaN                     -0.02880
# C3L-00137                        0.1845                      0.39915
# C3L-00156                        0.5050                     -0.20175
# C3L-00586                       -0.1170                      1.33500
# C3L-00601                       -0.0148                      2.20500
#
# Name        MCM2_phosphoproteomics_S170  MCM2_phosphoproteomics_S26  \
# Patient_ID
# C3L-00032                           NaN                         NaN
# C3L-00137                           NaN                         NaN
# C3L-00156                           NaN                         NaN
# C3L-00586                           NaN                      -0.108
# C3L-00601                           NaN                       1.250
#
# Name        MCM2_phosphoproteomics_S27  MCM2_phosphoproteomics_S31  \
# Patient_ID
# C3L-00032                     -1.03000                         NaN
# C3L-00137                      0.07110                         NaN
# C3L-00156                      0.60900                         NaN
# C3L-00586                     -0.04305                      0.0219
# C3L-00601                      0.88400                      0.5180
#
# Name        MCM2_phosphoproteomics_S40  MCM2_phosphoproteomics_S41  \
# Patient_ID
# C3L-00032                          NaN                         NaN
# C3L-00137                        0.310                      0.3915
# C3L-00156                       -0.388                     -0.3040
# C3L-00586                          NaN                      0.1990
# C3L-00601                          NaN                      0.4040
#
# Name        MCM2_phosphoproteomics_S53  MCM2_phosphoproteomics_T39  \
# Patient_ID
# C3L-00032                          NaN                         NaN
# C3L-00137                          NaN                         NaN
# C3L-00156                          NaN                         NaN
# C3L-00586                        0.192                         NaN
# C3L-00601                        0.404                         NaN
#
# Name        MCM2_phosphoproteomics_T59  MCM2_phosphoproteomics_Y137  \
# Patient_ID
# C3L-00032                          NaN                          NaN
# C3L-00137                       0.3695                          NaN
# C3L-00156                      -0.3675                          NaN
# C3L-00586                          NaN                          NaN
# C3L-00601                          NaN                          NaN
#
# Name        MCM2_phosphoproteomics_Y90 PTEN_Location_    Mutation   aa
# Patient_ID
# C3L-00032                          NaN        p.W111*  Truncation  111
# C3L-00137                      -0.6800        p.Y180*  Truncation  180
# C3L-00156                      -0.0746          p.E7*  Truncation    7
# C3L-00586                          NaN          p.E7*  Truncation    7
# C3L-00601                          NaN          p.E7*  Truncation    7

# %% [markdown]
# # Create the df for the C2 domain (binds PIP3)

# %%
t2 = get_trunc_df(t_gene)
# Out:
# Nonsense_Mutation    25
# Frame_Shift_Del      22
# Frame_Shift_Ins       6
# Name: PTEN_Mutation_, dtype: int64
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 69 samples for the PTEN gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 6)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# create new column with starting amino acid (aa) as an int
t2['aa'] = t2.apply(lambda x: (x['PTEN_Location_']), axis=1)
df1 = t2.replace({'aa': r'^p.[A-Z]*'}, {'aa': ''}, regex=True)
df2 = df1.replace({'aa': r'\*$'}, {'aa': ''}, regex=True)
df2 = df2.replace({'aa': r'[A-Z]fs\*\d*$'}, {'aa': ''}, regex=True)
df2['aa'] = pd.to_numeric(df2["aa"])

# Keep only mutations in the domain (cutoff aa = 190)
c2 = df2.loc[df2['aa'] >= 190]
c2.head()
# Out:
# Name        MCM2_phosphoproteomics_S108  MCM2_phosphoproteomics_S139  \
# Patient_ID
# C3L-00006                           NaN                       0.7535
# C3L-00145                           NaN                      -0.0423
# C3L-00161                      -0.76675                       0.3230
# C3L-00413                       0.06100                       0.6620
# C3L-00563                      -0.30050                      -0.3430
#
# Name        MCM2_phosphoproteomics_S170  MCM2_phosphoproteomics_S26  \
# Patient_ID
# C3L-00006                           NaN                         NaN
# C3L-00145                           NaN                         NaN
# C3L-00161                         0.167                         NaN
# C3L-00413                         0.000                         NaN
# C3L-00563                           NaN                         NaN
#
# Name        MCM2_phosphoproteomics_S27  MCM2_phosphoproteomics_S31  \
# Patient_ID
# C3L-00006                          NaN                         NaN
# C3L-00145                       -0.179                         NaN
# C3L-00161                        0.318                         NaN
# C3L-00413                       -0.250                         NaN
# C3L-00563                          NaN                         NaN
#
# Name        MCM2_phosphoproteomics_S40  MCM2_phosphoproteomics_S41  \
# Patient_ID
# C3L-00006                          NaN                         NaN
# C3L-00145                          NaN                      -0.039
# C3L-00161                          NaN                         NaN
# C3L-00413                          NaN                         NaN
# C3L-00563                       -0.168                      -0.294
#
# Name        MCM2_phosphoproteomics_S53  MCM2_phosphoproteomics_T39  \
# Patient_ID
# C3L-00006                          NaN                         NaN
# C3L-00145                          NaN                         NaN
# C3L-00161                          NaN                         NaN
# C3L-00413                          NaN                         NaN
# C3L-00563                       -0.251                         NaN
#
# Name        MCM2_phosphoproteomics_T59  MCM2_phosphoproteomics_Y137  \
# Patient_ID
# C3L-00006                          NaN                          NaN
# C3L-00145                      -0.2520                          NaN
# C3L-00161                       0.2390                       -0.577
# C3L-00413                      -0.0687                        0.726
# C3L-00563                      -0.2510                          NaN
#
# Name        MCM2_phosphoproteomics_Y90 PTEN_Location_    Mutation   aa
# Patient_ID
# C3L-00006                          NaN        p.R233*  Truncation  233
# C3L-00145                          NaN        p.E242*  Truncation  242
# C3L-00161                          NaN    p.K267Rfs*9  Truncation  267
# C3L-00413                          NaN   p.N262Qfs*35  Truncation  262
# C3L-00563                          NaN        p.Q214*  Truncation  214

# %% [markdown]
# # Get Wildtype_Tumor df

# %%
t3 = get_trunc_df(t_gene, include_wt=True)
# Out:
# Nonsense_Mutation    25
# Frame_Shift_Del      22
# Wildtype_Tumor       20
# Frame_Shift_Ins       6
# Name: PTEN_Mutation_, dtype: int64
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 69 samples for the PTEN gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 6)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
wt = t3.loc[t3['Mutation'] == 'Wildtype_Tumor']

# %% [markdown]
# # Append dfs

# %%
# Create Domain column
c2_df = c2.assign(Domain='C2_Truncation')
ph_df = phosphatase.assign(Domain='Phosphatase_Truncation')
wt_df = wt.assign(Domain='Wildtype_Tumor')

all_df = ph_df.append(c2_df)
all_df = all_df.append(wt_df)
all_df.head()
# Out:
#             MCM2_phosphoproteomics_S108  MCM2_phosphoproteomics_S139  \
# Patient_ID
# C3L-00032                           NaN                     -0.02880
# C3L-00137                        0.1845                      0.39915
# C3L-00156                        0.5050                     -0.20175
# C3L-00586                       -0.1170                      1.33500
# C3L-00601                       -0.0148                      2.20500
#
#             MCM2_phosphoproteomics_S170  MCM2_phosphoproteomics_S26  \
# Patient_ID
# C3L-00032                           NaN                         NaN
# C3L-00137                           NaN                         NaN
# C3L-00156                           NaN                         NaN
# C3L-00586                           NaN                      -0.108
# C3L-00601                           NaN                       1.250
#
#             MCM2_phosphoproteomics_S27  MCM2_phosphoproteomics_S31  \
# Patient_ID
# C3L-00032                     -1.03000                         NaN
# C3L-00137                      0.07110                         NaN
# C3L-00156                      0.60900                         NaN
# C3L-00586                     -0.04305                      0.0219
# C3L-00601                      0.88400                      0.5180
#
#             MCM2_phosphoproteomics_S40  MCM2_phosphoproteomics_S41  \
# Patient_ID
# C3L-00032                          NaN                         NaN
# C3L-00137                        0.310                      0.3915
# C3L-00156                       -0.388                     -0.3040
# C3L-00586                          NaN                      0.1990
# C3L-00601                          NaN                      0.4040
#
#             MCM2_phosphoproteomics_S53  MCM2_phosphoproteomics_T39  \
# Patient_ID
# C3L-00032                          NaN                         NaN
# C3L-00137                          NaN                         NaN
# C3L-00156                          NaN                         NaN
# C3L-00586                        0.192                         NaN
# C3L-00601                        0.404                         NaN
#
#             MCM2_phosphoproteomics_T59  MCM2_phosphoproteomics_Y137  \
# Patient_ID
# C3L-00032                          NaN                          NaN
# C3L-00137                       0.3695                          NaN
# C3L-00156                      -0.3675                          NaN
# C3L-00586                          NaN                          NaN
# C3L-00601                          NaN                          NaN
#
#             MCM2_phosphoproteomics_Y90 PTEN_Location_    Mutation     aa  \
# Patient_ID
# C3L-00032                          NaN        p.W111*  Truncation  111.0
# C3L-00137                      -0.6800        p.Y180*  Truncation  180.0
# C3L-00156                      -0.0746          p.E7*  Truncation    7.0
# C3L-00586                          NaN          p.E7*  Truncation    7.0
# C3L-00601                          NaN          p.E7*  Truncation    7.0
#
#                             Domain
# Patient_ID
# C3L-00032   Phosphatase_Truncation
# C3L-00137   Phosphatase_Truncation
# C3L-00156   Phosphatase_Truncation
# C3L-00586   Phosphatase_Truncation
# C3L-00601   Phosphatase_Truncation

# %% [markdown]
# # Step 2: T-test

# %%
# T-test for phosphatase vs wt
phosphatase_wt = all_df.loc[all_df['Domain'] != 'C2_Truncation']
print(phosphatase_wt.Domain.unique())

# Keep sites with >= 10 measurements
phosphatase_wt = phosphatase_wt.dropna(axis = 'columns', thresh = 10)

phos_cols_df = phosphatase_wt.drop(columns=['PTEN_Location_', 'aa','Domain'])
cols = list(phos_cols_df.columns[:-1])

phos_pval = u.wrap_ttest(phosphatase_wt, 'Mutation', cols, correction_method = 'fdr_bh') #, return_all = True)
phos_pval
# Out:
# ['Phosphatase_Truncation' 'Wildtype_Tumor']

# %%
# T-test for C2 vs wt
c2_wt = all_df.loc[all_df['Domain'] != 'Phosphatase_Truncation']
print(c2_wt.Domain.unique())

# Keep sites with >= 10 measurements
c2_wt = c2_wt.dropna(axis = 'columns', thresh = 10)

c2_cols_df = c2_wt.drop(columns=['PTEN_Location_', 'aa','Domain'])
cols = list(c2_cols_df.columns[:-1])

c2_pval = u.wrap_ttest(c2_wt, 'Mutation', cols, correction_method = 'fdr_bh')#, return_all = True)
c2_pval
# Out:
# ['C2_Truncation' 'Wildtype_Tumor']
#                     Comparison  P_Value
# 0  MCM2_phosphoproteomics_S139   0.0008

# %% [markdown]
# Keep the significant phosphosites

# %%
sites = []
if phos_pval is not None:
    sites = list(phos_pval.Comparison)
if c2_pval is not None:
    c2_sites = list(c2_pval.Comparison)
    for e in c2_sites:
        sites.append(e)
    

sig_df = all_df[sites]
sig_df = sig_df.rename(columns=lambda x: re.sub('_phosphoproteomics','', x))
sig_df = sig_df.join(all_df[['Mutation', 'Domain']])
plot_df = sig_df.melt(id_vars = ['Mutation','Domain'], var_name = 'Site', value_name = 'Omics')
plot_df
# Out:
#           Mutation                  Domain       Site    Omics
# 0       Truncation  Phosphatase_Truncation  MCM2_S139 -0.02880
# 1       Truncation  Phosphatase_Truncation  MCM2_S139  0.39915
# 2       Truncation  Phosphatase_Truncation  MCM2_S139 -0.20175
# 3       Truncation  Phosphatase_Truncation  MCM2_S139  1.33500
# 4       Truncation  Phosphatase_Truncation  MCM2_S139  2.20500
# ..             ...                     ...        ...      ...
# 68  Wildtype_Tumor          Wildtype_Tumor  MCM2_S139  0.33900
# 69  Wildtype_Tumor          Wildtype_Tumor  MCM2_S139 -0.05280
# 70  Wildtype_Tumor          Wildtype_Tumor  MCM2_S139  0.34900
# 71  Wildtype_Tumor          Wildtype_Tumor  MCM2_S139 -0.00458
# 72  Wildtype_Tumor          Wildtype_Tumor  MCM2_S139  0.48200
#
# [73 rows x 4 columns]

# %% [markdown]
# # Plot

# %%
plt.rcParams['figure.figsize']=(11.7,8.5) #size of plot
sns.set(font_scale = 1.2)

boxplot = sns.boxplot(x='Site', y='Omics', data = plot_df, hue = 'Domain', 
                      hue_order = ['Wildtype_Tumor','Phosphatase_Truncation','C2_Truncation'], 
                      showfliers = False)    
boxplot.set_title('trans effect of PTEN Truncations in Both Domains on '+t_gene+' in Endometrial')
boxplot = sns.stripplot(x='Site', y='Omics', data = plot_df, hue = 'Domain',
                        hue_order = ['Wildtype_Tumor','Phosphatase_Truncation','C2_Truncation'],
                        jitter = True, color = ".3", dodge = True)
boxplot.set(xlabel = "\nPTEN Wildtype/Truncations in Both Domains", ylabel = t_gene+' Phosphoproteomics')

# format legend
handles, labels = boxplot.get_legend_handles_labels()
plt.legend(handles[0:3], labels[0:3])

# Create significance symbols:
# * P ≤ 0.05   ** P ≤ 0.01   *** P ≤ 0.001 

format_pval_annotation('ns', -.26, 0, 2.3)
format_pval_annotation('***   p-val: 0.0008', -.26, .25, 2.6)


plt.show()
plt.clf()
plt.close()
