# %% [markdown]
# # trans effect of truncations in domains of PTEN in Endometrial for MCM3 Phosphoproteomics

# %% [markdown]
# This notebook creates a boxplot for the trans effect of PTEN truncations in the phosphatase domain and the C2 domain in Endometrial.

# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as p

# %%
# Step 1 - Create proteomics and truncations dataframe

def get_trunc_df(trans_gene, include_wt = False, gene='PTEN'):
    prot_and_mutations = en.join_omics_to_mutations(
        mutations_genes = [gene], omics_df_name = 'phosphoproteomics', omics_genes = trans_gene, 
        mutations_filter = ['Nonsense_Mutation','Frame_Shift_Del','Frame_Shift_Ins']) 
    prot_and_mutations = en.reduce_multiindex(prot_and_mutations, flatten=True)
    if include_wt == False:
        keep = ['Nonsense_Mutation','Frame_Shift_Del','Frame_Shift_Ins']
        in_keep = prot_and_mutations['PTEN_Mutation_'].isin(keep)
        trunc_mutations = prot_and_mutations[in_keep]
    else:
        keep = ['Nonsense_Mutation','Frame_Shift_Del','Frame_Shift_Ins','Wildtype_Tumor']
        in_keep = prot_and_mutations['PTEN_Mutation_'].isin(keep)
        trunc_mutations = prot_and_mutations[in_keep]
    print(trunc_mutations['PTEN_Mutation_'].value_counts())

    # Step 2 - Create binary column 
    trunc_mutations['Mutation'] = np.where(
                trunc_mutations[gene+'_Mutation_Status_'] == 'Wildtype_Tumor', 'Wildtype_Tumor', 'Truncation')

    # Step 3 - Format the dataframe correctly for the t-test(just omics and binary columns for tumors)
    tumors = trunc_mutations[trunc_mutations.Sample_Status_ == 'Tumor'] #drop Normal samples
    columns_to_drop = [gene+"_Mutation_", gene+"_Mutation_Status_", "Sample_Status_"]
    e_trunc_wt = tumors.drop(columns_to_drop, axis = 1)
    return e_trunc_wt

# %%
def format_pval_annotation(pval_symbol, x1, x2, line_start = .05, line_height=.05):
    # for manual adjustment to pval annotations
    
    y, h = line_start, line_height
    plt.plot([x1, x1, x2, x2], #draw horizontal line
             [y, y+h, y+h, y], #vertical line
             lw=1.5, color= '.3')
    plt.text((x1+x2)*.5, # half between x coord
             y+h, pval_symbol, horizontalalignment='center', verticalalignment='bottom', color = "black")

# %% [markdown]
# # Step 1: Create the dfs with PTEN truncations mutation in different domains

# %% [markdown]
# First, load in cancer data sets from cptac.

# %%
en = cptac.Endometrial()

# %% [markdown]
# # Create the df for the Phosphatase Domain

# %%
t_gene = 'MCM3'
t = get_trunc_df(t_gene)
# Out:
# Nonsense_Mutation    25
# Frame_Shift_Del      22
# Frame_Shift_Ins       6
# Name: PTEN_Mutation_, dtype: int64
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 69 samples for the PTEN gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 6)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Create a df with only mutations located in the phosphatase domain. (Both domains effected by the mutation).

# %%
# create new column with starting amino acid (aa) as an int
t['aa'] = t.apply(lambda x: (x['PTEN_Location_']), axis=1)
df1 = t.replace({'aa': r'^p.[A-Z]*'}, {'aa': ''}, regex=True)
df2 = df1.replace({'aa': r'\*$'}, {'aa': ''}, regex=True)
df2 = df2.replace({'aa': r'[A-Z]fs\*\d*$'}, {'aa': ''}, regex=True)
df2['aa'] = pd.to_numeric(df2["aa"])

# Keep only mutations in the domain (cutoff aa = 185)
phosphatase = df2.loc[df2['aa'] <= 185]
phosphatase.head()
# Out:
# Name        MCM3_phosphoproteomics_S189  MCM3_phosphoproteomics_S205  \
# Patient_ID
# C3L-00032                           NaN                       0.2740
# C3L-00137                           NaN                       0.5500
# C3L-00156                           NaN                      -0.2845
# C3L-00586                        0.3650                      -0.5070
# C3L-00601                        0.0849                       1.3200
#
# Name        MCM3_phosphoproteomics_S320  MCM3_phosphoproteomics_S322  \
# Patient_ID
# C3L-00032                           NaN                          NaN
# C3L-00137                           NaN                          NaN
# C3L-00156                           NaN                          NaN
# C3L-00586                           NaN                          NaN
# C3L-00601                           NaN                          NaN
#
# Name        MCM3_phosphoproteomics_S713  MCM3_phosphoproteomics_S717  \
# Patient_ID
# C3L-00032                        -0.254                      -0.0848
# C3L-00137                         0.627                       1.0600
# C3L-00156                         0.663                      -0.1120
# C3L-00586                         1.710                       0.7025
# C3L-00601                         1.975                       1.4300
#
# Name        MCM3_phosphoproteomics_S726  MCM3_phosphoproteomics_S749  \
# Patient_ID
# C3L-00032                           NaN                          NaN
# C3L-00137                         1.060                          NaN
# C3L-00156                        -0.827                          NaN
# C3L-00586                         0.756                        0.660
# C3L-00601                         0.737                        0.691
#
# Name        MCM3_phosphoproteomics_S756  MCM3_phosphoproteomics_T208  ...  \
# Patient_ID                                                            ...
# C3L-00032                        -0.402                          NaN  ...
# C3L-00137                         0.483                          NaN  ...
# C3L-00156                         0.615                          NaN  ...
# C3L-00586                         0.598                          NaN  ...
# C3L-00601                         1.410                          NaN  ...
#
# Name        MCM3_phosphoproteomics_T719  MCM3_phosphoproteomics_T758  \
# Patient_ID
# C3L-00032                       -0.0639                       -0.220
# C3L-00137                        1.1300                        0.645
# C3L-00156                       -0.3650                       -0.119
# C3L-00586                        0.5630                        0.621
# C3L-00601                        1.5300                        1.405
#
# Name        MCM3_phosphoproteomics_T767  MCM3_phosphoproteomics_T770  \
# Patient_ID
# C3L-00032                      -0.40200                          NaN
# C3L-00137                       0.24150                          NaN
# C3L-00156                       0.25975                          NaN
# C3L-00586                       0.84400                          NaN
# C3L-00601                       1.27000                          NaN
#
# Name        MCM3_phosphoproteomics_Y204  MCM3_phosphoproteomics_Y750  \
# Patient_ID
# C3L-00032                           NaN                          NaN
# C3L-00137                           NaN                      0.65100
# C3L-00156                           NaN                     -0.68275
# C3L-00586                           NaN                      0.80850
# C3L-00601                           NaN                      1.21250
#
# Name        MCM3_phosphoproteomics_Y753  PTEN_Location_    Mutation   aa
# Patient_ID
# C3L-00032                           NaN         p.W111*  Truncation  111
# C3L-00137                           NaN         p.Y180*  Truncation  180
# C3L-00156                           NaN           p.E7*  Truncation    7
# C3L-00586                         1.265           p.E7*  Truncation    7
# C3L-00601                         1.930           p.E7*  Truncation    7
#
# [5 rows x 21 columns]

# %% [markdown]
# # Create the df for the C2 binding domain

# %%
t2 = get_trunc_df(t_gene)
# Out:
# Nonsense_Mutation    25
# Frame_Shift_Del      22
# Frame_Shift_Ins       6
# Name: PTEN_Mutation_, dtype: int64
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 69 samples for the PTEN gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 6)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# create new column with starting amino acid (aa) as an int
t2['aa'] = t2.apply(lambda x: (x['PTEN_Location_']), axis=1)
df1 = t2.replace({'aa': r'^p.[A-Z]*'}, {'aa': ''}, regex=True)
df2 = df1.replace({'aa': r'\*$'}, {'aa': ''}, regex=True)
df2 = df2.replace({'aa': r'[A-Z]fs\*\d*$'}, {'aa': ''}, regex=True)
df2['aa'] = pd.to_numeric(df2["aa"])

# Keep only mutations in the domain (cutoff aa = 190)
c2 = df2.loc[df2['aa'] >= 190]
c2.head()
# Out:
# Name        MCM3_phosphoproteomics_S189  MCM3_phosphoproteomics_S205  \
# Patient_ID
# C3L-00006                           NaN                      -0.4060
# C3L-00145                       -0.0596                      -0.2300
# C3L-00161                        0.2390                      -0.8180
# C3L-00413                       -0.5520                      -0.2060
# C3L-00563                           NaN                       0.0987
#
# Name        MCM3_phosphoproteomics_S320  MCM3_phosphoproteomics_S322  \
# Patient_ID
# C3L-00006                           NaN                          NaN
# C3L-00145                           NaN                          NaN
# C3L-00161                           NaN                          NaN
# C3L-00413                           NaN                          NaN
# C3L-00563                           NaN                          NaN
#
# Name        MCM3_phosphoproteomics_S713  MCM3_phosphoproteomics_S717  \
# Patient_ID
# C3L-00006                        1.2400                       0.4645
# C3L-00145                        0.1385                       0.0147
# C3L-00161                        0.8095                       0.5415
# C3L-00413                        0.5280                       0.2925
# C3L-00563                       -0.5380                      -0.6070
#
# Name        MCM3_phosphoproteomics_S726  MCM3_phosphoproteomics_S749  \
# Patient_ID
# C3L-00006                       1.76000                          NaN
# C3L-00145                      -0.00495                          NaN
# C3L-00161                       0.59206                          NaN
# C3L-00413                       0.00550                          NaN
# C3L-00563                      -0.48400                          NaN
#
# Name        MCM3_phosphoproteomics_S756  MCM3_phosphoproteomics_T208  ...  \
# Patient_ID                                                            ...
# C3L-00006                        0.5355                          NaN  ...
# C3L-00145                        0.0348                          NaN  ...
# C3L-00161                       -0.0423                          NaN  ...
# C3L-00413                        0.3740                          NaN  ...
# C3L-00563                        0.0915                          NaN  ...
#
# Name        MCM3_phosphoproteomics_T719  MCM3_phosphoproteomics_T758  \
# Patient_ID
# C3L-00006                        1.3600                        0.682
# C3L-00145                        0.0147                        0.194
# C3L-00161                        0.5415                        0.121
# C3L-00413                        0.7785                        0.463
# C3L-00563                       -0.6235                       -0.104
#
# Name        MCM3_phosphoproteomics_T767  MCM3_phosphoproteomics_T770  \
# Patient_ID
# C3L-00006                        0.6400                          NaN
# C3L-00145                        0.0203                          NaN
# C3L-00161                        0.4580                          NaN
# C3L-00413                        0.0971                          NaN
# C3L-00563                       -0.1040                          NaN
#
# Name        MCM3_phosphoproteomics_Y204  MCM3_phosphoproteomics_Y750  \
# Patient_ID
# C3L-00006                           NaN                       0.2290
# C3L-00145                           NaN                          NaN
# C3L-00161                           NaN                       0.2745
# C3L-00413                           NaN                       0.7900
# C3L-00563                           NaN                       0.1480
#
# Name        MCM3_phosphoproteomics_Y753  PTEN_Location_    Mutation   aa
# Patient_ID
# C3L-00006                       0.47900         p.R233*  Truncation  233
# C3L-00145                       0.00145         p.E242*  Truncation  242
# C3L-00161                       0.01850     p.K267Rfs*9  Truncation  267
# C3L-00413                      -0.01650    p.N262Qfs*35  Truncation  262
# C3L-00563                           NaN         p.Q214*  Truncation  214
#
# [5 rows x 21 columns]

# %% [markdown]
# # Get Wildtype_Tumor df

# %%
t3 = get_trunc_df(t_gene, include_wt=True)
# Out:
# Nonsense_Mutation    25
# Frame_Shift_Del      22
# Wildtype_Tumor       20
# Frame_Shift_Ins       6
# Name: PTEN_Mutation_, dtype: int64
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 69 samples for the PTEN gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 6)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
wt = t3.loc[t3['Mutation'] == 'Wildtype_Tumor']

# %% [markdown]
# # Append dfs

# %%
# Create Domain column
c2_df = c2.assign(Domain='C2_Truncation')
ph_df = phosphatase.assign(Domain='Phosphatase_Truncation')
wt_df = wt.assign(Domain='Wildtype_Tumor')

all_df = ph_df.append(c2_df)
all_df = all_df.append(wt_df)
all_df.head()
# Out:
#             MCM3_phosphoproteomics_S189  MCM3_phosphoproteomics_S205  \
# Patient_ID
# C3L-00032                           NaN                       0.2740
# C3L-00137                           NaN                       0.5500
# C3L-00156                           NaN                      -0.2845
# C3L-00586                        0.3650                      -0.5070
# C3L-00601                        0.0849                       1.3200
#
#             MCM3_phosphoproteomics_S320  MCM3_phosphoproteomics_S322  \
# Patient_ID
# C3L-00032                           NaN                          NaN
# C3L-00137                           NaN                          NaN
# C3L-00156                           NaN                          NaN
# C3L-00586                           NaN                          NaN
# C3L-00601                           NaN                          NaN
#
#             MCM3_phosphoproteomics_S713  MCM3_phosphoproteomics_S717  \
# Patient_ID
# C3L-00032                        -0.254                      -0.0848
# C3L-00137                         0.627                       1.0600
# C3L-00156                         0.663                      -0.1120
# C3L-00586                         1.710                       0.7025
# C3L-00601                         1.975                       1.4300
#
#             MCM3_phosphoproteomics_S726  MCM3_phosphoproteomics_S749  \
# Patient_ID
# C3L-00032                           NaN                          NaN
# C3L-00137                         1.060                          NaN
# C3L-00156                        -0.827                          NaN
# C3L-00586                         0.756                        0.660
# C3L-00601                         0.737                        0.691
#
#             MCM3_phosphoproteomics_S756  MCM3_phosphoproteomics_T208  ...  \
# Patient_ID                                                            ...
# C3L-00032                        -0.402                          NaN  ...
# C3L-00137                         0.483                          NaN  ...
# C3L-00156                         0.615                          NaN  ...
# C3L-00586                         0.598                          NaN  ...
# C3L-00601                         1.410                          NaN  ...
#
#             MCM3_phosphoproteomics_T758  MCM3_phosphoproteomics_T767  \
# Patient_ID
# C3L-00032                        -0.220                     -0.40200
# C3L-00137                         0.645                      0.24150
# C3L-00156                        -0.119                      0.25975
# C3L-00586                         0.621                      0.84400
# C3L-00601                         1.405                      1.27000
#
#             MCM3_phosphoproteomics_T770  MCM3_phosphoproteomics_Y204  \
# Patient_ID
# C3L-00032                           NaN                          NaN
# C3L-00137                           NaN                          NaN
# C3L-00156                           NaN                          NaN
# C3L-00586                           NaN                          NaN
# C3L-00601                           NaN                          NaN
#
#             MCM3_phosphoproteomics_Y750  MCM3_phosphoproteomics_Y753  \
# Patient_ID
# C3L-00032                           NaN                          NaN
# C3L-00137                       0.65100                          NaN
# C3L-00156                      -0.68275                          NaN
# C3L-00586                       0.80850                        1.265
# C3L-00601                       1.21250                        1.930
#
#             PTEN_Location_    Mutation     aa                  Domain
# Patient_ID
# C3L-00032          p.W111*  Truncation  111.0  Phosphatase_Truncation
# C3L-00137          p.Y180*  Truncation  180.0  Phosphatase_Truncation
# C3L-00156            p.E7*  Truncation    7.0  Phosphatase_Truncation
# C3L-00586            p.E7*  Truncation    7.0  Phosphatase_Truncation
# C3L-00601            p.E7*  Truncation    7.0  Phosphatase_Truncation
#
# [5 rows x 22 columns]

# %% [markdown]
# # Step 2: T-test

# %%
# T-test for phosphatase vs wt
phosphatase_wt = all_df.loc[all_df['Domain'] != 'C2_Truncation']
print(phosphatase_wt.Domain.unique())

# Keep sites with >= 10 measurements
phosphatase_wt = phosphatase_wt.dropna(axis = 'columns', thresh = 10)

phos_cols_df = phosphatase_wt.drop(columns=['PTEN_Location_', 'aa','Domain'])
cols = list(phos_cols_df.columns[:-1])

phos_pval = u.wrap_ttest(phosphatase_wt, 'Mutation', cols, correction_method = 'fdr_bh')#, return_all = True)
phos_pval
# Out:
# ['Phosphatase_Truncation' 'Wildtype_Tumor']

# %%
# T-test for C2 vs wt
c2_wt = all_df.loc[all_df['Domain'] != 'Phosphatase_Truncation']
print(c2_wt.Domain.unique())

c2_cols_df = c2_wt.drop(columns=['PTEN_Location_', 'aa','Domain'])
cols = list(c2_cols_df.columns[:-1])

c2_pval = u.wrap_ttest(c2_wt, 'Mutation', cols, correction_method= 'fdr_bh')#, return_all = True)
c2_pval
# Out:
# ['C2_Truncation' 'Wildtype_Tumor']
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\numpy\core\fromnumeric.py:3367: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\scipy\stats\_distn_infrastructure.py:1831: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\statsmodels\stats\multitest.py:320: RuntimeWarning: invalid value encountered in less_equal
#   reject = pvals_sorted <= ecdffactor*alpha
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\statsmodels\stats\multitest.py:328: RuntimeWarning: invalid value encountered in greater
#   pvals_corrected[pvals_corrected>1] = 1
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\statsmodels\stats\multitest.py:251: RuntimeWarning: invalid value encountered in greater
#   pvals_corrected[pvals_corrected>1] = 1
#                     Comparison   P_Value
# 0  MCM3_phosphoproteomics_S713  0.000245
# 1  MCM3_phosphoproteomics_S726  0.000255
# 2  MCM3_phosphoproteomics_T758  0.000329
# 3  MCM3_phosphoproteomics_T767  0.000349
# 4  MCM3_phosphoproteomics_T719  0.000349
# 5  MCM3_phosphoproteomics_S717  0.000475
# 6  MCM3_phosphoproteomics_S756  0.000858
# 7  MCM3_phosphoproteomics_Y750  0.014816

# %% [markdown]
# Keep the significant phosphosites

# %%
sites = []
if phos_pval is not None:
    sites = list(phos_pval.Comparison)
if c2_pval is not None:
    c2_sites = list(c2_pval.Comparison)
    for e in c2_sites:
        sites.append(e)
    

sig_df = all_df[sites]
sig_df = sig_df.rename(columns=lambda x: re.sub('_phosphoproteomics','', x))
sig_df = sig_df.join(all_df[['Mutation', 'Domain']])
plot_df = sig_df.melt(id_vars = ['Mutation','Domain'], var_name = 'Site', value_name = 'Omics')
plot_df
# Out:
#            Mutation                  Domain       Site    Omics
# 0        Truncation  Phosphatase_Truncation  MCM3_S713 -0.25400
# 1        Truncation  Phosphatase_Truncation  MCM3_S713  0.62700
# 2        Truncation  Phosphatase_Truncation  MCM3_S713  0.66300
# 3        Truncation  Phosphatase_Truncation  MCM3_S713  1.71000
# 4        Truncation  Phosphatase_Truncation  MCM3_S713  1.97500
# ..              ...                     ...        ...      ...
# 579  Wildtype_Tumor          Wildtype_Tumor  MCM3_Y750  0.86000
# 580  Wildtype_Tumor          Wildtype_Tumor  MCM3_Y750 -0.00601
# 581  Wildtype_Tumor          Wildtype_Tumor  MCM3_Y750  0.26995
# 582  Wildtype_Tumor          Wildtype_Tumor  MCM3_Y750  0.00284
# 583  Wildtype_Tumor          Wildtype_Tumor  MCM3_Y750  0.71850
#
# [584 rows x 4 columns]

# %% [markdown]
# # Plot

# %%
plt.rcParams['figure.figsize']=(25,20) #size of plot
sns.set(font_scale = 1.5)

boxplot = sns.boxplot(x='Site', y='Omics', data = plot_df, hue = 'Domain', 
                      hue_order = ['Wildtype_Tumor','Phosphatase_Truncation','C2_Truncation'], 
                      showfliers = False)    
boxplot.set_title('trans effect of PTEN Truncations in Both Domains on '+t_gene+' Phosphoproteomics')
boxplot = sns.stripplot(x='Site', y='Omics', data = plot_df, hue = 'Domain',
                        hue_order = ['Wildtype_Tumor','Phosphatase_Truncation','C2_Truncation'],
                        jitter = True, color = ".3", dodge = True)
boxplot.set(xlabel = "\nPTEN Wildtype/Truncations in Both Domains", ylabel = t_gene+' Phosphoproteomics')

# format legend
handles, labels = boxplot.get_legend_handles_labels()
plt.legend(handles[0:3], labels[0:3])

# Create significance symbols:
# * P ≤ 0.05   ** P ≤ 0.01   *** P ≤ 0.001 

format_pval_annotation('ns', -.26, 0, 2.7)
format_pval_annotation('**', -.26, .25, 2.9)
format_pval_annotation('ns', .75, 1, 3.3)
format_pval_annotation('**', .75, 1.2, 3.6)
format_pval_annotation('ns', 1.75, 2, 2)
format_pval_annotation('**', 1.75, 2.2, 2.3)
format_pval_annotation('ns', 2.75, 3, 2.4)
format_pval_annotation('**', 2.75, 3.2, 2.7)
format_pval_annotation('ns', 3.75, 4, 3.1)
format_pval_annotation('**', 3.75, 4.2, 3.4)
format_pval_annotation('ns', 4.75, 5, 3.1)
format_pval_annotation('**', 4.75, 5.2, 3.4)
format_pval_annotation('ns', 5.75, 6, 2.2)
format_pval_annotation('**', 5.75, 6.2, 2.5)
format_pval_annotation('ns', 6.75, 7, 1.5)
format_pval_annotation('**', 6.75, 7.2, 1.8)


plt.show()
plt.clf()
plt.close()

# %%
c2_pval
# Out:
#                     Comparison   P_Value
# 0  MCM3_phosphoproteomics_S713  0.000245
# 1  MCM3_phosphoproteomics_S726  0.000255
# 2  MCM3_phosphoproteomics_T758  0.000329
# 3  MCM3_phosphoproteomics_T767  0.000349
# 4  MCM3_phosphoproteomics_T719  0.000349
# 5  MCM3_phosphoproteomics_S717  0.000475
# 6  MCM3_phosphoproteomics_S756  0.000858
