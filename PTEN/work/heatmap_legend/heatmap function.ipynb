# %% [markdown]
# # Create Heat Map

# %% [markdown]
# This notebook looks at the significant genes in at least one cancer in the DNA Replication pathway. Pancancer heat maps are created with circle size showing significance and color showing differences in median.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
import scipy.stats
import re
import sys
import statsmodels.stats.multitest
from bokeh.palettes import RdBu
from bokeh.models import LinearColorMapper, ColorBar
from bokeh.models.ranges import FactorRange
from bokeh.plotting import figure, show
from bokeh.io import output_notebook, export_png, export_svgs
from bokeh.layouts import row

import cptac
import cptac.utils as u
import plot_utils as p

# %%
import gseapy as gp

# %%
def create_circle_legend_df(legend_min, legend_max):
    
    # Find middle pvals
    # Find difference between exponents of the min and max
    exp_legend_min = np.log10(legend_min)
    exp_legend_max = np.log10(legend_max)
    delta = exp_legend_min - exp_legend_max 
    # Split difference into quarters 
    num = 4
    val = delta / num
    # Find middle exponents
    exp2 = round(exp_legend_min - val)
    exp3 = round(exp_legend_max + val)
    # Create middle pvals
    pval2 = 1*10**exp2
    pval3 = 1*10**exp3
    
    # Foramat scientific notation pvals as strings for y_axis labels  
    max_str = "{:.1e}".format(legend_max, '.2f')
    pval_str_3 = "{:.1e}".format(pval3, '.2f')
    pval_str_2 = "{:.1e}".format(pval2, '.2f')
    min_str = "{:.1e}".format(legend_min, '.2f')
    
    # max to min
    data = {'P_Value':  [legend_max, pval3, pval2, legend_min],
            'y_axis': [max_str, pval_str_3, pval_str_2, min_str],
            'x_axis': ['', '', '', ''],
            'Medians': [1.5, 1.5, 1.5, 1.5]}

    fake_df = pd.DataFrame (data, columns = ['x_axis', 'y_axis', 'P_Value', 'Medians'])
    
    fake_df["size2"] = fake_df['P_Value'].apply(lambda x: -1*(np.log(x)))
    fake_df['size'] = (fake_df["size2"])*3
    
    return fake_df

# %%
def create_circle_legend(df, circle_var, color_var, legend_min, legend_max,
                         x_axis = 'x_axis', y_axis = 'y_axis', 
                         plot_height = 200, plot_width = 120):
    # Use the smallest pval
    if df[circle_var].min() < legend_min:
        legend_min = df[circle_var].min()
    circle_df = create_circle_legend_df(legend_min, legend_max)
    
    maxval = circle_df[color_var].max()
    minval = circle_df[color_var].min()
    if maxval > abs(minval):
        minval = maxval * -1 
    if maxval < abs(minval):
        maxval = minval * -1
    colors = list((RdBu[9]))
    exp_cmap = LinearColorMapper(palette=colors, low = minval, high = maxval)
    
    circle = figure(x_range = FactorRange(), y_range = FactorRange(), plot_width= plot_width, 
               plot_height=plot_height, toolbar_location=None, tools="hover")

    circle.scatter(x_axis, y_axis, source = circle_df, fill_alpha=1,  line_width=0, size="size", 
              fill_color={"field":color_var, "transform":exp_cmap})
    
    circle.x_range.factors = sorted(circle_df[x_axis].unique().tolist())
    circle.y_range.factors = circle_df[y_axis].unique().tolist() # plots in reverse order of df (max to min)
    circle.xaxis.major_label_orientation = math.pi/2
    
    circle.xaxis.axis_label = 'P-Values'
    
    return circle

# %% [markdown]
# # Step 1: Run GSEA for significant genes in at least 1 cancer

# %% [markdown]
# First read in sig_pval_all_proteins.csv into a df. This csv file contains only genes with a significant p-value in at least one cancer. Then run GSEA using a list of genes from the df.

# %%
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'
sig_df = pd.read_csv(root+R'\sig_pval_heatmap.csv')

prot_list = list(sig_df.Proteomics) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='Reactome_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head(30)
# Out:
#                                                  Term   Overlap       P-value  \
# 0            Gene Expression Homo sapiens R-HSA-74160  440/1631  6.403332e-53
# 1   Processing of Capped Intron-Containing Pre-mRN...   116/193  1.992679e-52
# 2   mRNA Splicing - Major Pathway Homo sapiens R-H...    85/134  2.432993e-41
# 3              mRNA Splicing Homo sapiens R-HSA-72172    85/144  7.488070e-38
# 4   Major pathway of rRNA processing in the nucleo...    82/166  4.309535e-29
# 5            rRNA processing Homo sapiens R-HSA-72312    85/180  2.535428e-28
# 6       Infectious disease Homo sapiens R-HSA-5663205   127/348  4.238130e-28
# 7        Cell Cycle, Mitotic Homo sapiens R-HSA-69278   145/462  3.302158e-24
# 8               Cell Cycle Homo sapiens R-HSA-1640170   163/566  1.242046e-22
# 9   Transport of Mature Transcript to Cytoplasm Ho...     46/74  1.962264e-22
# 10      Influenza Infection Homo sapiens R-HSA-168254    68/147  2.730640e-22
# 11     Influenza Life Cycle Homo sapiens R-HSA-168255    64/136  1.472133e-21
# 12  Transport of Mature mRNA derived from an Intro...     43/68  1.739344e-21
# 13  Influenza Viral RNA Transcription and Replicat...    61/128  5.756029e-21
# 14            HIV Infection Homo sapiens R-HSA-162906    83/222  1.459921e-19
# 15  Transport of Mature mRNA Derived from an Intro...     28/37  1.125061e-17
# 16  Metabolism of non-coding RNA Homo sapiens R-HS...     33/50  1.207686e-17
# 17           snRNP Assembly Homo sapiens R-HSA-191859     33/50  1.207686e-17
# 18  Transport of Mature mRNAs Derived from Intronl...     28/38  3.728557e-17
# 19     DNA strand elongation Homo sapiens R-HSA-69190     25/32  1.717948e-16
# 20          Synthesis of DNA Homo sapiens R-HSA-69239     46/97  4.694039e-16
# 21  Transport of the SLBP independent Mature mRNA ...     25/33  6.183251e-16
# 22           HIV Life Cycle Homo sapiens R-HSA-162587    57/141  1.254669e-15
# 23  Transport of the SLBP Dependant Mature mRNA Ho...     25/34  2.038196e-15
# 24  Late Phase of HIV Life Cycle Homo sapiens R-HS...    53/128  3.757830e-15
# 25  Interactions of Rev with host cellular protein...     25/35  6.224682e-15
# 26  Rev-mediated nuclear export of HIV RNA Homo sa...     24/33  1.130501e-14
# 27                 Disease Homo sapiens R-HSA-1643685   172/725  1.142882e-14
# 28           DNA Replication Homo sapiens R-HSA-69306    46/105  1.958357e-14
# 29  NS1 Mediated Effects on Host Pathways Homo sap...     26/39  2.423739e-14
#
#     Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0       9.797098e-50            0                     0    2.015489
# 1       1.524399e-49            0                     0    4.490372
# 2       1.240826e-38            0                     0    4.739099
# 3       2.864187e-35            0                     0    4.409995
# 4       1.318718e-26            0                     0    3.690519
# 5       6.465341e-26            0                     0    3.527996
# 6       9.263341e-26            0                     0    2.726504
# 7       6.315378e-22            0                     0    2.344810
# 8       2.111478e-20            0                     0    2.151557
# 9       3.002265e-20            0                     0    4.644166
# 10      3.798072e-20            0                     0    3.455996
# 11      1.876969e-19            0                     0    3.515788
# 12      2.047074e-19            0                     0    4.724340
# 13      6.290518e-19            0                     0    3.560422
# 14      1.489119e-17            0                     0    2.793230
# 15      1.075840e-15            0                     0    5.653767
# 16      1.086917e-15            0                     0    4.930893
# 17      1.026533e-15            0                     0    4.930893
# 18      3.002470e-15            0                     0    5.504984
# 19      1.314230e-14            0                     0    5.836758
# 20      3.419943e-14            0                     0    3.542972
# 21      4.300170e-14            0                     0    5.659886
# 22      8.346280e-14            0                     0    3.020212
# 23      1.299350e-13            0                     0    5.493419
# 24      2.299792e-13            0                     0    3.093482
# 25      3.662986e-13            0                     0    5.336464
# 26      6.406172e-13            0                     0    5.433491
# 27      6.245032e-13            0                     0    1.772442
# 28      1.033202e-12            0                     0    3.273031
# 29      1.236107e-12            0                     0    4.980700
#
#     Combined Score                                              Genes  \
# 0       242.221802  TDRKH;RPL4;ATF2;MDC1;NUP107;HNRNPU;EHMT1;PHAX;...
# 1       534.556067  NUP107;NUP188;EIF4A3;HNRNPU;EFTUD2;SNRPD2;SNRP...
# 2       443.185660  EIF4A3;HNRNPU;YBX1;PRPF19;USP39;ELAVL1;EFTUD2;...
# 3       376.988047  EIF4A3;HNRNPU;YBX1;PRPF19;USP39;ELAVL1;EFTUD2;...
# 4       241.043035  LTV1;RPL4;DDX47;RPP30;WDR3;RPLP0;PWP2;RPL10A;R...
# 5       224.175973  LTV1;RPL4;DDX47;RPP30;WDR3;RPLP0;NAT10;PWP2;RP...
# 6       171.846789  RPL4;NUP107;NUP188;RPL10A;RPL9;PSMD8;RPS15;PSM...
# 7       126.777933  ANKLE2;NUP107;NUP188;ZWILCH;BUB1B;PPP2R2A;SMC4...
# 8       108.524761  MDC1;ANKLE2;NUP107;NUP188;ZWILCH;BUB1B;PPP2R2A...
# 9       232.128295  NUP205;NUP107;SEH1L;NUP188;EIF4A3;NUP160;NXF1;...
# 10      171.598263  RPL4;NUP107;NUP188;RPLP0;RPL10A;RPL9;RPS15;RPS...
# 11      168.643828  RPL4;NUP107;NUP188;RPLP0;RPL10A;RPL9;RPS15;RPS...
# 12      225.827144  NUP205;NUP107;SEH1L;NUP188;EIF4A3;NUP160;NXF1;...
# 13      165.930051  RPL4;NUP107;NUP188;RPLP0;RPL10A;RPL9;RPS15;RPS...
# 14      121.144449  FEN1;NUP107;ELL;NUP188;PSMD8;PSMD9;XPO1;PSMD5;...
# 15      220.644541  NUP205;NUP107;SEH1L;NUP188;NUP160;NXF1;NUP85;T...
# 16      192.084116  NUP205;NUP107;SEH1L;NUP188;DDX20;PHAX;NUP160;S...
# 17      192.084116  NUP205;NUP107;SEH1L;NUP188;DDX20;PHAX;NUP160;S...
# 18      208.242122  NUP205;NUP107;SEH1L;NUP188;NUP160;NXF1;NUP85;T...
# 19      211.875647  FEN1;PCNA;MCM7;PRIM1;POLD3;POLD1;POLD2;GINS1;R...
# 20      125.049438  PSMD10;FEN1;PSMD11;CDKN1B;PCNA;MCM7;PRIM1;PSMB...
# 21      198.206480  NUP205;NUP107;SEH1L;NUP188;NUP160;NXF1;NUP85;T...
# 22      103.629210  FEN1;NUP107;NUP188;ELL;XPO1;NELFB;NELFE;NUP214...
# 23      185.824294  NUP205;NUP107;SEH1L;NUP188;NUP160;NXF1;NUP85;T...
# 24      102.749786  NUP107;NUP188;ELL;XPO1;NELFB;NELFE;NUP214;NDC1...
# 25      174.557095  NUP205;NUP107;SEH1L;NUP188;NUP160;XPO1;NUP85;T...
# 26      174.488568  RANBP2;NUP214;NDC1;RANBP1;NUP205;NUP107;SEH1L;...
# 27       56.900069  RPL4;SEMA5B;NUP107;NUP188;HDAC11;RPL10A;RPL9;P...
# 28      103.310239  PSMD10;FEN1;PSMD11;CDKN1B;PCNA;MCM7;PRIM1;PSMB...
# 29      156.149321  NUP205;NUP107;SEH1L;NUP188;NUP160;PABPN1;NUP85...
#
#          Gene_set
# 0   Reactome_2016
# 1   Reactome_2016
# 2   Reactome_2016
# 3   Reactome_2016
# 4   Reactome_2016
# 5   Reactome_2016
# 6   Reactome_2016
# 7   Reactome_2016
# 8   Reactome_2016
# 9   Reactome_2016
# 10  Reactome_2016
# 11  Reactome_2016
# 12  Reactome_2016
# 13  Reactome_2016
# 14  Reactome_2016
# 15  Reactome_2016
# 16  Reactome_2016
# 17  Reactome_2016
# 18  Reactome_2016
# 19  Reactome_2016
# 20  Reactome_2016
# 21  Reactome_2016
# 22  Reactome_2016
# 23  Reactome_2016
# 24  Reactome_2016
# 25  Reactome_2016
# 26  Reactome_2016
# 27  Reactome_2016
# 28  Reactome_2016
# 29  Reactome_2016

# %% [markdown]
# # Step 2: Get the list of significant genes

# %%
index = 7
trans = prot_enr.res2d.Genes[index]
genes = trans.split(';')
print(prot_enr.res2d.Term[index])
genes = genes[:20]
print('total genes:',len(genes))
# Out:
# Cell Cycle, Mitotic Homo sapiens R-HSA-69278
# total genes: 20

# %% [markdown]
# # Step 3: Create HeatMap

# %% [markdown]
# Slice out genes from the DNA Replication pathway from the df with genes sig in > 1 cancer.

# %%
# sig > 1 cancer
bool_df = sig_df.Proteomics.isin(genes)
plot_df = sig_df[bool_df]
len(plot_df.Proteomics.unique())
# Out:
# 20

# %%
# Only include p-values < a certain cutoff
a = 0.05
plot_df = plot_df.loc[plot_df['P_Value'] <= a]

# %%
def plotCircleHeatMap (df, circle_var, color_var, x_axis, y_axis,plot_width= 1000, font_size=12,
                       plot_height = 650, legend_min = 1e-6, legend_max = 0.01,
                       x_axis_lab = "no_label", y_axis_lab = "no_label", 
                       show_plot = True, save_png = "plot.png"):
  
    # circle_var designed for pvalues. Normalized by taking log 10 of values and multiplying by 5 
    #added a new column to make the plot size
    
    df["size2"] = df[circle_var].apply(lambda x: -1*(np.log(x)))
    df['size'] = (df["size2"])*3
    #find values to set color bar min/ max as 
    maxval = df[color_var].max()
    minval = df[color_var].min()
    if maxval > abs(minval):
        minval = maxval * -1 
    if maxval < abs(minval):
        maxval = minval * -1
    colors = list((RdBu[9]))
    exp_cmap = LinearColorMapper(palette=colors, low = minval, high = maxval)
    p = figure(x_range = FactorRange(), y_range = FactorRange(), plot_width= plot_width, 
               plot_height=plot_height, 
               toolbar_location=None, tools="hover")

    p.scatter(x_axis,y_axis,source=df, fill_alpha=1,  line_width=0, size="size", 
              fill_color={"field":color_var, "transform":exp_cmap})
    
    p.x_range.factors = sorted(df[x_axis].unique().tolist())
    p.y_range.factors = sorted(df[y_axis].unique().tolist(), reverse = True)
    p.xaxis.major_label_orientation = math.pi/2
    
    # font size
    p.axis.major_label_text_font_size = str(font_size)+"pt"
    
    if (x_axis_lab != "no_label" ):
        p.xaxis.axis_label = x_axis_lab
        p.xaxis.axis_label_text_font_size = '12pt'
    if (y_axis_lab != "no_label" ):   ### change to y
        p.yaxis.axis_label = y_axis_lab
        p.yaxis.axis_label_text_font_size = '12pt'

    bar = ColorBar(color_mapper=exp_cmap, location=(0,0))
    p.add_layout(bar, "right")
    
    # Create Circle Legend
    circle_legend = create_circle_legend(df, circle_var, color_var, 
                                         legend_min = legend_min, legend_max = legend_max)
    
    if show_plot:
        output_notebook()
        show(row(p, circle_legend))
      
    if save_png != "plot.png":
        export_png(row(p, circle_legend), filename= save_png)

# %%
p.plotCircleHeatMap(plot_df, circle_var = 'P_Value', color_var='Medians', x_axis= 'Proteomics', y_axis = 'Cancer',
                    plot_height=300, plot_width= 500, font_size= 10, legend_min = 5e-3, legend_max = 0.05, 
                    x_axis_lab= 'Proteomics', save_png = 'test4.png')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2351">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1ba91f0f-e95e-4816-a46d-574254a03f11" data-root-id="2352"></div>
