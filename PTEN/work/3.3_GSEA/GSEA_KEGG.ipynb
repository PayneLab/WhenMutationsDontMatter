# %% [markdown]
# # Run a Gene Set Enrichment Analysis using KEGG_2016

# %% [markdown]
# This notebook looks at the significant genes in at least one cancer. GSEA is used to recognize pathways with multiple significant genes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as p

# %% [markdown]
# # Step 1: Run GSEA for significant genes in at least 1 cancer

# %% [markdown]
# First read in sig_pval_all_proteins.csv into a df. This csv file contains only genes with a significant p-value in at least one cancer. Then run GSEA using a list of genes from the df.

# %%
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'
df = pd.read_csv(root+R'\sig_pval_heatmap.csv')

prot_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head(5)
# Out:
#                                                 Term Overlap       P-value  \
# 0  Ribosome biogenesis in eukaryotes Homo sapiens...   13/89  1.180367e-09
# 1              DNA replication Homo sapiens hsa03030    9/36  3.083251e-09
# 2  B cell receptor signaling pathway Homo sapiens...   11/73  1.626924e-08
# 3  Fc gamma R-mediated phagocytosis Homo sapiens ...   12/93  2.188722e-08
# 4                RNA transport Homo sapiens hsa03013  15/172  8.324097e-08
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0      3.458475e-07            0                     0    9.393403
# 1      4.516962e-07            0                     0   16.077170
# 2      1.588963e-06            0                     0    9.690349
# 3      1.603239e-06            0                     0    8.297894
# 4      4.877921e-06            0                     0    5.608315
#
#    Combined Score                                              Genes  \
# 0      193.104322  UTP6;IMP3;WDR3;HEATR1;NAT10;WDR75;IMP4;PWP2;UT...
# 1      315.068832       RFC3;PCNA;RFC4;MCM7;RFC2;MCM3;MCM4;MCM5;MCM2
# 2      173.786622  PPP3CB;SYK;CHUK;PIK3CA;PRKCB;INPP5D;BLNK;RAC2;...
# 3      146.352976  PAK1;PTPRC;SYK;PIK3CA;MYO10;PRKCB;INPP5D;RAC2;...
# 4       91.424098  RANBP2;NUP210;NUP155;NCBP1;NUP133;THOC3;THOC2;...
#
#     Gene_set
# 0  KEGG_2016
# 1  KEGG_2016
# 2  KEGG_2016
# 3  KEGG_2016
# 4  KEGG_2016

# %% [markdown]
# # Run GSEA for significant genes in multiple cancers

# %%
df = pd.read_csv(root+R'\mult_sig_pval_heatmap.csv')

mult_sig_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = mult_sig_list, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head(25)
# Out:
#                                                  Term Overlap       P-value  \
# 0   Ribosome biogenesis in eukaryotes Homo sapiens...   13/89  1.180367e-09
# 1               DNA replication Homo sapiens hsa03030    9/36  3.083251e-09
# 2   B cell receptor signaling pathway Homo sapiens...   11/73  1.626924e-08
# 3   Fc gamma R-mediated phagocytosis Homo sapiens ...   12/93  2.188722e-08
# 3       146.352976  PAK1;PTPRC;SYK;PIK3CA;MYO10;PRKCB;INPP5D;RAC2;...
# 4        91.424098  RANBP2;NUP210;NUP155;NCBP1;NUP133;THOC3;THOC2;...
# 5       230.353683                      MSH6;RFC3;PCNA;RFC4;MSH2;RFC2
# 6        63.594102  PPP3CB;SYK;CHUK;PIK3CA;BTK;PLCG2;BLNK;CYBB;PIK...
# 7        61.050378  ZAP70;PPP3CB;PAK1;SYK;PIK3CA;PRKCB;ITGB2;PLCG2...
# 8        80.881160  PIK3CA;SYNJ1;INPP5D;PTEN;PLCG2;PIK3CD;PIP4K2A;...
# 9        69.336352    ZAP70;SYK;CHUK;PARP1;PRKCB;BLNK;BTK;PLCG2;NFKB2
# 10      112.391310                     ZAP70;CD4;PTPRC;IGLL1;BLNK;BTK
# 11       63.291627  SYNJ1;PIK3CA;PRKCB;INPP5D;PLCG2;PTEN;PIP4K2A;P...
# 12       55.073337  ORC5;PCNA;MCM7;PRKDC;MCM3;BUB1B;MCM4;MCM5;MCM2...
# 13       41.983686  CCR1;PAK1;GNG2;CHUK;PIK3CA;PRKCB;ELMO1;RAC2;WA...
# 14       47.759173  DDX5;PRPF6;NCBP1;PUF60;PRPF3;HNRNPU;THOC3;PRPF...
# 15       52.875034  CPSF4;NCBP1;CPSF1;RNMT;CPSF3;PPP2R2D;SYMPK;PPP...
# 16       61.785866            SYK;PIK3CA;INPP5D;RAC2;BTK;PLCG2;PIK3CD
# 17       45.371445  PIK3CA;PRKCB;ITGB2;PLCG2;RAC2;PECAM1;CYBB;PIK3...
# 18       41.641413     ZAP70;PPP3CB;PAK1;CD4;PTPRC;CHUK;PIK3CA;PIK3CD
# 19       28.328547  ZAP70;PAK1;GNG2;CHUK;PIK3CA;PRKCB;PLCG2;RAC2;P...
# 20       51.493448             PIK3CA;CAB39;PRKCB;RPS6KA1;PTEN;PIK3CD
# 21       50.076458              PPP3CB;PIK3CA;PRKCB;RAC2;PLCG2;PIK3CD
# 22       54.440364                    DCTN6;DCTN5;DCTN1;DCTN4;ARHGDIB
# 23       31.935945  PIK3CA;PRKCB;PPP2R2D;PTEN;RAC2;PIK3CD;PPP2R2A;...
# 24       21.310192  ACAP2;ZFYVE27;ACAP1;TFRC;SH3KBP1;GBF1;WAS;VPS3...
#
#      Gene_set
# 0   KEGG_2016
# 1   KEGG_2016
# 2   KEGG_2016
# 3   KEGG_2016
# 4   KEGG_2016
# 5   KEGG_2016
# 6   KEGG_2016
# 7   KEGG_2016
# 8   KEGG_2016
# 9   KEGG_2016
# 10  KEGG_2016
# 11  KEGG_2016
# 12  KEGG_2016
# 13  KEGG_2016
# 14  KEGG_2016
# 15  KEGG_2016
# 16  KEGG_2016
# 17  KEGG_2016
# 18  KEGG_2016
# 19  KEGG_2016
# 20  KEGG_2016
# 21  KEGG_2016
# 22  KEGG_2016
# 23  KEGG_2016
# 24  KEGG_2016

# %%
prot_enr.res2d.Genes[1]
# Out:
# 'RFC3;PCNA;RFC4;MCM7;RFC2;MCM3;MCM4;MCM5;MCM2'
