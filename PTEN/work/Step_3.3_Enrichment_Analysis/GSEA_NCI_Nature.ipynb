# %% [markdown]
# # Run a Gene Set Enrichment Analysis using NCI_Nature

# %% [markdown]
# This notebook looks at the significant genes in at least one cancer. GSEA is used to recognize pathways with multiple significant genes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as p

# %% [markdown]
# # Step 1: Run GSEA for significant genes in at least 1 cancer

# %% [markdown]
# First read in sig_pval_all_proteins.csv into a df. This csv file contains only genes with a significant p-value in at least one cancer. Then run GSEA using a list of genes from the df.

# %%
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'
df = pd.read_csv(root+R'\sig_pval_heatmap.csv')

prot_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
print(len(prot_list))
prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='NCI-Nature_2016', 
                       outdir='/Enrichr')
#gp.get_library_name() #Cancer_Cell_Line_Encyclopedia #NCI-60_Cancer_Cell_Lines
# Out:
# 2627

# %%
prot_enr.res2d.head()
# Out:
#                                                 Term Overlap   P-value  \
# 0  Regulation of RAC1 activity Homo sapiens 351aa...   17/38  0.000002
# 1  Class I PI3K signaling events Homo sapiens 12b...   18/48  0.000018
# 2  Fanconi anemia pathway Homo sapiens 6befb873-6...   17/47  0.000053
# 3  Signaling events mediated by TCPTP Homo sapien...   15/42  0.000172
# 4  FAS (CD95) signaling pathway Homo sapiens 79cc...   14/38  0.000193
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.000378            0                     0    3.405926
# 1          0.001919            0                     0    2.854968
# 2          0.003727            0                     0    2.753728
# 3          0.008977            0                     0    2.719017
# 4          0.008052            0                     0    2.804880
#
#    Combined Score                                              Genes  \
# 0       45.034375  DOCK6;ARHGAP9;RASGRF2;RAP1GDS1;VAV1;DEF6;EPS8;...
# 1       31.134524  HSP90AA1;SYK;PLEKHA1;PDPK1;PIK3CD;PIK3R1;ADAP1...
# 2       27.085369  FANCI;RFC5;RFC3;WDR48;RFC4;RFC2;RMI1;TOP3A;RPA...
# 3       23.571504  CSF1R;STAT1;PIK3CD;EIF2AK2;PIK3R1;EGFR;VEGFA;P...
# 4       23.995020  SYK;CHUK;RFC1;PDPK1;CLTC;PIK3CD;PIK3R1;MAPK10;...
#
#           Gene_set
# 0  NCI-Nature_2016
# 1  NCI-Nature_2016
# 2  NCI-Nature_2016
# 3  NCI-Nature_2016
# 4  NCI-Nature_2016

# %% [markdown]
# # Run GSEA for significant genes in multiple cancers

# %%
df = pd.read_csv(root+R'\mult_sig_pval_heatmap.csv')

mult_sig_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = mult_sig_list, description='Tumor_partition', gene_sets='NCI-Nature_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head(30)
# Out:
#                                                  Term Overlap   P-value  \
# 0   BCR signaling pathway Homo sapiens acbf44e2-61...    9/64  0.000001
# 1   Class I PI3K signaling events Homo sapiens 12b...    8/48  0.000001
# 2   IL8- and CXCR2-mediated signaling events Homo ...    6/34  0.000018
# 3   ATR signaling pathway Homo sapiens 8991cbac-61...    6/39  0.000041
# 4   CXCR3-mediated signaling events Homo sapiens 3...    6/43  0.000073
# 5   TCR signaling in naive CD4+ T cells Homo sapie...    7/64  0.000090
# 6   FAS (CD95) signaling pathway Homo sapiens 79cc...    5/38  0.000392
# 7   Fc-epsilon receptor I signaling in mast cells ...    6/58  0.000392
# 8   PLK1 signaling events Homo sapiens e5e87977-61...    5/46  0.000959
# 9   CXCR4-mediated signaling events Homo sapiens 4...   7/100  0.001396
# 10  Netrin-mediated signaling events Homo sapiens ...    4/30  0.001453
# 11  Nongenotropic Androgen signaling Homo sapiens ...    4/30  0.001453
# 12  Alternative NF-kappaB pathway Homo sapiens 557...     2/6  0.003943
# 13  Internalization of ErbB1 Homo sapiens 3aa9aafa...    4/40  0.004256
# 14  Signaling events mediated by TCPTP Homo sapien...    4/42  0.005079
# 15  PAR1-mediated thrombin signaling events Homo s...    4/43  0.005528
# 16  Fanconi anemia pathway Homo sapiens 6befb873-6...    4/47  0.007588
# 17  Validated targets of C-MYC transcriptional act...    5/79  0.010132
# 18  IL8- and CXCR1-mediated signaling events Homo ...    3/28  0.010922
# 19  TRAIL signaling pathway Homo sapiens 3a79fddf-...    3/28  0.010922
# 20  TCR signaling in naive CD8+ T cells Homo sapie...    4/53  0.011531
# 21  Role of Calcineurin-dependent NFAT signaling i...    4/53  0.011531
# 22  BARD1 signaling events Homo sapiens 75b04491-6...    3/29  0.012035
# 23  Sumoylation by RanBP2 regulates transcriptiona...    2/11  0.013686
# 24  Thromboxane A2 receptor signaling Homo sapiens...    4/56  0.013916
# 25  Osteopontin-mediated events Homo sapiens 94bf7...    3/31  0.014450
# 26  EGF receptor (ErbB1) signaling pathway Homo sa...    3/34  0.018550
# 27  Signaling events mediated by HDAC Class II Hom...    3/34  0.018550
# 28  JNK signaling in the CD4+ TCR pathway Homo sap...    2/14  0.021915
# 29  Regulation of RAC1 activity Homo sapiens 351aa...    3/38  0.024918
#
#     Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0           0.000222            0                     0    8.471386
# 1           0.000117            0                     0   10.040161
# 2           0.001266            0                     0   10.630758
# 3           0.002148            0                     0    9.267841
# 4           0.003037            0                     0    8.405716
# 5           0.003134            0                     0    6.588855
# 6           0.011690            0                     0    7.926443
# 7           0.010228            0                     0    6.231824
# 8           0.022281            0                     0    6.547931
# 9           0.029167            0                     0    4.216867
# 10          0.027612            0                     0    8.032129
# 11          0.025311            0                     0    8.032129
# 12          0.063392            0                     0   20.080321
# 13          0.063534            0                     0    6.024096
# 14          0.070770            0                     0    5.737235
# 15          0.072211            0                     0    5.603811
# 16          0.093282            0                     0    5.126891
# 17          0.117645            0                     0    3.812719
# 18          0.120144            0                     0    6.454389
# 19          0.114137            0                     0    6.454389
# 20          0.114756            0                     0    4.546488
# 21          0.109540            0                     0    4.546488
# 22          0.109363            0                     0    6.231824
# 23          0.119185            0                     0   10.952903
# 24          0.116339            0                     0    4.302926
# 25          0.116156            0                     0    5.829771
# 26          0.143591            0                     0    5.315379
# 27          0.138462            0                     0    5.315379
# 28          0.157942            0                     0    8.605852
# 29          0.173593            0                     0    4.755866
#
#     Combined Score                                              Genes  \
# 0       116.542158  MAP4K1;PPP3CB;PTPRC;SYK;CHUK;PIK3CA;BLNK;BTK;P...
# 1       137.556168       ZAP70;SYK;PIK3CA;BLNK;PLCG2;BTK;PIK3CD;CYTH1
# 2       116.042320                  GNG2;PRKCB;RAC2;ELMO1;DOCK2;GNAI2
# 3        93.598766                    RFC3;RFC4;MCM7;RFC2;TOPBP1;MCM2
# 4        80.105650               GNG2;PIK3CA;ITGB2;PIK3CD;ITGAL;GNAI2
# 5        61.381742              MAP4K1;ZAP70;CD4;PTPRC;CHUK;PRKCB;WAS
# 6        62.186786                         SYK;CHUK;PIK3CA;BTK;PIK3CD
# 7        48.891679                    SYK;CHUK;PIK3CA;WIPF1;PRKCB;BTK
# 8        45.502340                         TPX2;PAK1;BUB1B;ECT2;NDC80
# 9        27.723639            PAK1;CD4;PTPRC;GNG2;PIK3CA;PIK3CD;GNAI2
# 10       52.481617                            PAK1;MYO10;PIK3CA;ELMO1
# 11       52.481617                            GNG2;PIK3CA;PLCG2;GNAI2
# 12      111.160536                                         CHUK;NFKB2
# 13       32.888299                        PIK3CA;SYNJ1;SH3KBP1;PIK3CD
# 14       30.307579                          CSF1R;PIK3CA;PIK3CD;KPNA2
# 15       29.128084                            GNG2;PIK3CA;PRKCB;GNAI2
# 16       25.025613                              RFC3;RFC4;RFC2;TOPBP1
# 17       17.508189                             DDX18;TFRC;NCL;CAD;TK1
# 18       29.154215                                   GNG2;PRKCB;GNAI2
# 19       29.154215                                 CHUK;PIK3CA;PIK3CD
# 20       20.289873                             ZAP70;PTPRC;CHUK;PRKCB
# 21       20.289873                            PPP3CB;XPO1;PRKCB;KPNA2
# 22       27.544158                                  PCNA;PRKDC;TOPBP1
# 23       47.002871                                        RANBP2;XPO1
# 24       18.393726                               GNG2;SYK;PRKCB;GNAI2
# 25       24.701097                                    SYK;CHUK;PIK3CA
# 26       21.193937                                 PAK1;PIK3CA;PIK3CD
# 27       21.193937                                   RANBP2;XPO1;GNG2
# 28       32.879206                                       MAP4K1;PRKCB
# 29       17.559509                                   ELMO1;DOCK2;DEF6
#
#            Gene_set
# 0   NCI-Nature_2016
# 1   NCI-Nature_2016
# 2   NCI-Nature_2016
# 3   NCI-Nature_2016
# 4   NCI-Nature_2016
# 5   NCI-Nature_2016
# 6   NCI-Nature_2016
# 7   NCI-Nature_2016
# 8   NCI-Nature_2016
# 9   NCI-Nature_2016
# 10  NCI-Nature_2016
# 11  NCI-Nature_2016
# 12  NCI-Nature_2016
# 13  NCI-Nature_2016
# 14  NCI-Nature_2016
# 15  NCI-Nature_2016
# 16  NCI-Nature_2016
# 17  NCI-Nature_2016
# 18  NCI-Nature_2016
# 19  NCI-Nature_2016
# 20  NCI-Nature_2016
# 21  NCI-Nature_2016
# 22  NCI-Nature_2016
# 23  NCI-Nature_2016
# 24  NCI-Nature_2016
# 25  NCI-Nature_2016
# 26  NCI-Nature_2016
# 27  NCI-Nature_2016
# 28  NCI-Nature_2016
# 29  NCI-Nature_2016
