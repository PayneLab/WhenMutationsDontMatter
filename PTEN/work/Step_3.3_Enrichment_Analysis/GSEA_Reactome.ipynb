# %% [markdown]
# # Run a Gene Set Enrichment Analysis using Reactome_2016

# %% [markdown]
# This notebook looks at the significant genes in at least one cancer. GSEA is used to recognize pathways with multiple significant genes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import plot_utils as p

# %% [markdown]
# # Step 1: Run GSEA for significant genes in at least 1 cancer

# %% [markdown]
# First read in sig_pval_all_proteins.csv into a df. This csv file contains only genes with a significant p-value in at least one cancer. Then run GSEA using a list of genes from the df.

# %%
root = R'~\Github\WhenMutationsDontMatter\PTEN\Step_3_trans_effect\csv'
df = pd.read_csv(root+R'\sig_pval_heatmap.csv')

prot_list = list(df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
prot_enr = gp.enrichr(gene_list = prot_list, description='Tumor_partition', gene_sets='Reactome_2016', 
                       outdir='/Enrichr')

# %%
prot_enr.res2d.head(5)
# Out:
#                                                 Term   Overlap       P-value  \
# 0           Gene Expression Homo sapiens R-HSA-74160  436/1631  1.394069e-53
# 1  Processing of Capped Intron-Containing Pre-mRN...   116/193  2.653563e-53
# 2  mRNA Splicing - Major Pathway Homo sapiens R-H...    85/134  5.487084e-42
# 3             mRNA Splicing Homo sapiens R-HSA-72172    85/144  1.737521e-38
# 4  Major pathway of rRNA processing in the nucleo...    79/166  3.014256e-27
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0      2.132925e-50            0                     0    2.035178
# 1      2.029976e-50            0                     0    4.575838
# 2      2.798413e-39            0                     0    4.829299
# 3      6.646018e-36            0                     0    4.493931
# 4      9.223625e-25            0                     0    3.623172
#
#    Combined Score                                              Genes  \
# 0      247.690927  TDRKH;RPL4;ATF2;MDC1;NUP107;HNRNPU;EHMT1;PHAX;...
# 1      553.955964  NUP107;NUP188;EIF4A3;HNRNPU;EFTUD2;SNRPD2;SNRP...
# 2      458.813188  EIF4A3;HNRNPU;YBX1;PRPF19;USP39;ELAVL1;EFTUD2;...
# 3      390.728271  EIF4A3;HNRNPU;YBX1;PRPF19;USP39;ELAVL1;EFTUD2;...
# 4      221.254218  LTV1;RPL4;DDX47;RPP30;WDR3;RPLP0;PWP2;RPL10A;R...
#
#         Gene_set
# 0  Reactome_2016
# 1  Reactome_2016
# 2  Reactome_2016
# 3  Reactome_2016
# 4  Reactome_2016

# %% [markdown]
# # Run GSEA for significant genes in multiple cancers

# %%
mult_df = pd.read_csv(root+R'\mult_sig_pval_heatmap.csv')

mult_sig_list = list(mult_df.Proteomics.unique()) # list of genes with a sig pval in >= 1 cancer
enr2 = gp.enrichr(gene_list = mult_sig_list, description='Tumor_partition', gene_sets='Reactome_2016', 
                       outdir='/Enrichr')

# %%
enr2.res2d.head(40)
# Out:
#                                                  Term  Overlap       P-value  \
# 0            Gene Expression Homo sapiens R-HSA-74160  76/1631  7.790079e-17
# 1        Cell Cycle, Mitotic Homo sapiens R-HSA-69278   37/462  2.324896e-15
# 2   Processing of Capped Intron-Containing Pre-mRN...   24/193  1.716598e-14
# 3               Cell Cycle Homo sapiens R-HSA-1640170   38/566  2.579814e-13
# 4   rRNA modification in the nucleus Homo sapiens ...    14/58  4.819842e-13
# 10      8.092681e-08            0                     0    4.267752
# 11      1.450187e-07            0                     0   10.630758
# 12      1.526109e-07            0                     0    6.024096
# 13      1.873859e-07            0                     0    6.835854
# 14      1.961035e-07            0                     0    4.961021
# 15      1.996402e-07            0                     0   13.691128
# 16      2.345292e-07            0                     0    6.169255
# 17      3.022627e-07            0                     0    7.059488
# 18      2.898536e-07            0                     0    2.258549
# 19      5.430090e-07            0                     0   14.653207
# 20      8.555922e-07            0                     0   13.901761
# 21      1.118961e-06            0                     0    7.603228
# 22      1.254334e-06            0                     0   13.223626
# 23      1.438534e-06            0                     0   16.064257
# 24      1.834617e-06            0                     0   15.546055
# 25      2.102469e-06            0                     0    4.884402
# 26      2.904538e-06            0                     0   14.603870
# 27      2.800805e-06            0                     0   14.603870
# 28      3.485548e-06            0                     0   14.174344
# 29      3.693265e-06            0                     0    7.452490
# 30      4.166153e-06            0                     0   13.769363
# 31      5.456684e-06            0                     0    7.157342
# 32      6.996667e-06            0                     0    6.315585
# 33      7.924396e-06            0                     0    6.884682
# 34      1.638660e-05            0                     0    5.844273
# 35      1.626102e-05            0                     0   11.474469
# 36      1.585621e-05            0                     0    9.511731
# 37      1.924691e-05            0                     0   14.056225
# 38      1.875340e-05            0                     0   14.056225
# 39      2.146437e-05            0                     0    6.902610
#
#     Combined Score                                              Genes  \
# 0       104.116894  DDX47;WDR3;WDR4;HNRNPU;NAT10;ZC3H8;ADAR;PPP2R2...
# 1       162.561772  TOP2A;AHCTF1;PCNA;MCM7;DCTN1;BUB1B;PPP2R2A;ORC...
# 2       237.436894  RANBP2;DDX5;NUP210;CPSF1;NUP155;NCBP1;NUP133;D...
# 3       117.231872  TOP2A;AHCTF1;PCNA;MCM7;DCTN1;BUB1B;PPP2R2A;ORC...
# 4       412.393134  UTP6;DDX47;IMP3;WDR3;HEATR1;NAT10;WDR75;IMP4;P...
# 5       556.681245  GINS2;RFC3;PCNA;RFC4;MCM7;RFC2;GINS4;MCM3;MCM4...
# 6       282.577399  RANBP2;NCBP1;NUP210;NUP133;CPSF1;NUP155;CPSF3;...
# 7       778.305972               GINS2;MCM7;GINS4;MCM3;MCM4;MCM5;MCM2
# 8       355.707959  RANBP2;CPSF1;NCBP1;NUP210;NUP133;NUP155;NUP85;...
# 9       341.739289  RANBP2;CPSF1;NCBP1;NUP210;NUP133;NUP155;NUP85;...
# 10       90.753104  AHCTF1;WIPF1;WAS;PIK3R4;BUB1B;ARHGAP15;KLC4;PA...
# 11      218.935358  RANBP2;DDX39A;NCBP1;NUP210;NUP133;NUP155;NUP85...
# 12      123.273784  UTP6;IMP3;DDX47;WDR3;HEATR1;WDR75;NAT10;IMP4;P...
# 13      137.975297  RANBP2;SUPT16H;NUP210;NUP155;NCBP1;NUP133;RNMT...
# 14       99.565679  RANBP2;AHCTF1;NUP133;WIPF1;PIK3R4;WAS;BUB1B;CY...
# 15      273.647088  TOP2A;RANBP2;TOP2B;PCNA;NUP210;NUP133;NUP155;N...
# 16      121.938387  UTP6;IMP3;DDX47;WDR3;HEATR1;WDR75;IMP4;PWP2;WD...
# 17      137.339660  RANBP2;SUPT16H;NUP210;NUP155;NCBP1;NUP133;RNMT...
# 18       43.911788  SH3KBP1;WIPF1;ITGB2;PIK3CD;ADAR;ITGAL;IFIT2;AC...
# 19      274.944442       ORC5;RFC3;RFC4;MCM7;RFC2;MCM3;MCM4;MCM5;MCM2
# 20      253.845772  RANBP2;CPSF4;NUP210;NUP133;NUP155;NUP85;TPR;KP...
# 21      136.440623  RANBP2;CPSF4;NUP210;CPSF1;NUP155;NUP133;NSUN2;...
# 22      235.201162  RANBP2;CPSF4;NUP210;NUP133;NUP155;NUP85;TPR;KP...
# 23      282.841044    RANBP2;XPO1;NUP210;NUP133;NUP155;NUP85;TPR;RAE1
# 24      269.301546    RANBP2;XPO1;NUP210;NUP133;NUP155;NUP85;TPR;RAE1
# 25       83.754434  RANBP2;SUPT16H;NUP210;NUP155;NCBP1;NUP133;RNMT...
# 26      245.146730   RANBP2;NCBP1;NUP210;NUP133;NUP155;NUP85;TPR;RAE1
# 27      245.146730    RANBP2;XPO1;NUP210;NUP133;NUP155;NUP85;TPR;RAE1
# 28      234.338943   RANBP2;NCBP1;NUP210;NUP133;NUP155;NUP85;TPR;RAE1
# 29      122.525093  ORC5;GINS2;RFC3;RFC4;PCNA;MCM7;RFC2;GINS4;MCM3...
# 30      224.269238    RANBP2;XPO1;NUP210;NUP133;NUP155;NUP85;TPR;RAE1
# 31      114.416961  TOP2A;RANBP2;TOP2B;PCNA;NUP210;NUP155;NUP133;P...
# 32       99.196316  SUPT16H;CPSF1;NCBP1;RNMT;CPSF3;THOC3;THOC2;SSR...
# 33      107.072130  ORC5;GINS2;RFC3;RFC4;PCNA;MCM7;RFC2;GINS4;MCM3...
# 34       86.476074  DDX5;CPSF1;NCBP1;DHX9;CPSF3;HNRNPU;USP39;ELAVL...
# 35      169.549558  RANBP2;NUP210;NUP133;NUP155;POLR2B;NUP85;TPR;RAE1
# 36      140.526835  RANBP2;CPSF4;NUP210;NUP133;CPSF1;NUP155;NUP85;...
# 37      204.568633         RANBP2;NUP210;NUP133;NUP155;NUP85;TPR;RAE1
# 38      204.568633         RANBP2;NUP210;NUP133;NUP155;NUP85;TPR;RAE1
# 39       99.351066  TOP2A;RANBP2;TOP2B;PCNA;NUP210;NUP133;PARP1;NU...
#
#          Gene_set
# 0   Reactome_2016
# 1   Reactome_2016
# 2   Reactome_2016
# 3   Reactome_2016
# 4   Reactome_2016
# 5   Reactome_2016
# 6   Reactome_2016
# 7   Reactome_2016
# 8   Reactome_2016
# 9   Reactome_2016
# 10  Reactome_2016
# 11  Reactome_2016
# 12  Reactome_2016
# 13  Reactome_2016
# 14  Reactome_2016
# 15  Reactome_2016
# 16  Reactome_2016
# 17  Reactome_2016
# 18  Reactome_2016
# 19  Reactome_2016
# 20  Reactome_2016
# 21  Reactome_2016
# 22  Reactome_2016
# 23  Reactome_2016
# 24  Reactome_2016
# 25  Reactome_2016
# 26  Reactome_2016
# 27  Reactome_2016
# 28  Reactome_2016
# 29  Reactome_2016
# 30  Reactome_2016
# 31  Reactome_2016
# 32  Reactome_2016
# 33  Reactome_2016
# 34  Reactome_2016
# 35  Reactome_2016
# 36  Reactome_2016
# 37  Reactome_2016
# 38  Reactome_2016
# 39  Reactome_2016
