# %%
import pandas as pd
import cptac.pancan as pc

# %%
# cancers with aliquot_to_patient mapping (5)
g = pc.PancanGbm()
l = pc.PancanLuad()
ls = pc.PancanLscc()
e = pc.PancanUcec()
r = pc.PancanCcrcc()

# %%
# others (4)
h = pc.PancanHnscc()
b = pc.PancanBrca()
o = pc.PancanOv()
c = pc.PancanCoad()

# %%
pc.download('pancanluad')
# Out:
# Please login to Box on the webpage that was just opened and grant access for cptac to download files through your account. If you accidentally closed the browser window, press Ctrl+C and call the download function again.
# True

# %%
l = pc.PancanLuad()

# %%
ca = l
p = ca.get_proteomics('umich')
#p.index[~ p.index.str.contains('C3[NL]-')]
p
# Out:
# Name                  ARF5-201          M6PR-201          ESRRA-201  \
# Database_ID ENSG00000004059.11 ENSG00000003056.8 ENSG00000173153.16
# Patient_ID
# 11LU013               0.786285         -0.332452          -0.008182
# 11LU016               0.768472         -0.403172           0.726123
# 11LU022               0.252194         -0.114091           0.106217
# 11LU035               0.686262         -0.137407          -0.570236
# C3L-00001            -0.013909         -0.007751          -0.171399
# ...                        ...               ...                ...
# C3N-02582.N          -0.119078         -0.437606                NaN
# C3N-02586.N          -0.152329          0.182687          -0.316086
# C3N-02587.N          -0.085025          0.027486                NaN
# C3N-02588.N          -0.244213         -0.146324           0.024431
# C3N-02729.N          -0.060250         -0.157012           0.111823
#
# Name                FKBP4-201        NDUFAF7-201          FUCA2-201  \
# Database_ID ENSG00000004478.8 ENSG00000003509.16 ENSG00000001036.14
# Patient_ID
# 11LU013              0.664553          -0.083248           0.717903
# 11LU016             -0.146830           0.002308           0.487517
# 11LU022              0.647038           0.023058          -0.057407
# 11LU035              0.187284           0.006600           0.463262
# C3L-00001            0.473614          -0.132759           0.242113
# ...                       ...                ...                ...
# C3N-02582.N         -0.281114          -0.018965           0.024498
# C3N-02586.N         -0.427822          -0.151765          -0.337271
# C3N-02587.N         -0.337103          -0.070958          -0.538341
# C3N-02588.N         -0.287575          -0.126789          -0.130155
# C3N-02729.N         -0.302339          -0.090347          -0.254534
#
# Name                HS3ST1-201         SEMA3F-201           CFTR-201  \
# Database_ID ENSG00000002587.10 ENSG00000001617.12 ENSG00000001626.16
# Patient_ID
# 11LU013               0.395759                NaN          -1.204550
# 11LU016               1.262676          -0.498287          -0.570044
# 11LU022              -0.121067          -0.396348          -1.024969
# 11LU035              -0.037442                NaN          -0.789793
# C3L-00001            -0.880477          -0.570674                NaN
# ...                        ...                ...                ...
# C3N-02582.N          -0.096989           0.407268                NaN
# C3N-02586.N           0.121682           0.068960           0.753150
# C3N-02587.N          -0.284389           0.268453                NaN
# C3N-02588.N                NaN           0.081470           0.300853
# C3N-02729.N          -0.768017           0.317653           1.217847
#
# Name               CYP51A1-201  ...          GBF1-204         CTNND1-240  \
# Database_ID ENSG00000001630.17  ... ENSG00000107862.5 ENSG00000198561.15
# Patient_ID                      ...
# 11LU013               0.387524  ...          0.246809           0.461351
# 11LU016              -0.258518  ...         -0.030711           0.272718
# 11LU022              -0.941190  ...          0.165939          -0.210486
# 11LU035              -0.639767  ...          0.139759          -0.007299
# C3L-00001            -0.205331  ...          0.363547          -0.396643
# ...                        ...  ...               ...                ...
# C3N-02582.N           0.107239  ...         -0.091362           0.114516
# C3N-02586.N           0.564148  ...         -0.009443          -0.144387
# C3N-02587.N          -0.160976  ...         -0.106454           0.680137
# C3N-02588.N           0.230514  ...         -0.118602           0.397573
# C3N-02729.N          -0.148305  ...         -0.087645           0.358975
#
# Name                   WIZ-212           LDB1-204            WIZ-211  \
# Database_ID ENSG00000011451.21 ENSG00000198728.11 ENSG00000011451.21
# Patient_ID
# 11LU013              -0.553253          -0.122195           0.138115
# 11LU016               0.488027          -0.320011           0.212130
# 11LU022              -0.334806          -0.246996           0.219102
# 11LU035                    NaN          -0.590554           0.060887
# C3L-00001             1.158235          -0.238417           0.194351
# ...                        ...                ...                ...
# C3N-02582.N           0.081166           0.095400          -0.080278
# C3N-02586.N                NaN           0.267154          -0.070546
# C3N-02587.N          -0.047025           0.433628          -0.060068
# C3N-02588.N          -0.334428           0.077482          -0.083333
# C3N-02729.N          -0.005601           0.203077          -0.075617
#
# Name                TSGA10-219           RFX7-204        SWSAP1-202  \
# Database_ID ENSG00000135951.16 ENSG00000181827.15 ENSG00000173928.4
# Patient_ID
# 11LU013              -0.974209          -0.120763               NaN
# 11LU016              -0.842905           0.095945               NaN
# 11LU022                    NaN          -0.299151               NaN
# 11LU035              -1.672911          -0.355487               NaN
# C3L-00001            -0.864266          -0.674254               NaN
# ...                        ...                ...               ...
# C3N-02582.N           1.167836          -0.230083          0.024321
# C3N-02586.N           0.338783          -0.040338         -0.106744
# C3N-02587.N           1.687939          -0.391530               NaN
# C3N-02588.N           1.331652          -0.365233               NaN
# C3N-02729.N          -0.292496                NaN          1.114007
#
# Name                 TUG1-217           SVIL-215
# Database_ID ENSG00000253352.9 ENSG00000197321.15
# Patient_ID
# 11LU013             -0.644736                NaN
# 11LU016                   NaN                NaN
# 11LU022                   NaN                NaN
# 11LU035                   NaN                NaN
# C3L-00001                 NaN                NaN
# ...                       ...                ...
# C3N-02582.N               NaN                NaN
# C3N-02586.N               NaN           0.521248
# C3N-02587.N          0.222601           0.318727
# C3N-02588.N               NaN                NaN
# C3N-02729.N         -0.344713                NaN
#
# [213 rows x 13302 columns]

# %%
# Check tumor/normal counts
tumor = p.loc[~ p.index.str.contains('\.N$')]
normal = p.loc[p.index.str.contains('\.N$')]
print('tumor:', len(tumor))
print('normal:', len(normal))

    # Check if there are duplicates in index
if True in set(p.index.duplicated()):
    print('duplicates in index')
    print(p.index[p.index.duplicated()])
else:
    print('NO duplicates in index')

# Check if there are duplicates in columns
if True in set(p.columns.duplicated()):
    print('duplicates in columns')
    print(set(p.columns.duplicated()))
.N', 'C3N-00180.N', 'C3N-00199.N', 'C3N-00203.N', 'C3N-00217.N', 'C3N-00223.N', 'C3N-00293.N', 'C3N-00433.N', 'C3N-00545.N', 'C3N-00546.N', 'C3N-00547.N', 'C3N-00549.N', 'C3N-00550.N', 'C3N-00551.N', 'C3N-00552.N', 'C3N-00556.N', 'C3N-00559.N', 'C3N-00560.N', 'C3N-00572.N', 'C3N-00574.N', 'C3N-00578.N', 'C3N-00579.N', 'C3N-00580.N', 'C3N-00704.N', 'C3N-00737.N', 'C3N-00738.N', 'C3N-00959.N', 'C3N-01016.N', 'C3N-01021.N', 'C3N-01023.N', 'C3N-01024.N', 'C3N-01030.N', 'C3N-01071.N', 'C3N-01072.N', 'C3N-01405.N', 'C3N-01410.N', 'C3N-01413.N', 'C3N-01414.N', 'C3N-01415.N', 'C3N-01416.N', 'C3N-01488.N', 'C3N-01489.N', 'C3N-01799.N', 'C3N-01823.N', 'C3N-02000.N', 'C3N-02002.N', 'C3N-02003.N', 'C3N-02067.N', 'C3N-02087.N', 'C3N-02089.N', 'C3N-02145.N', 'C3N-02149.N', 'C3N-02155.N', 'C3N-02158.N', 'C3N-02379.N', 'C3N-02380.N', 'C3N-02421.N', 'C3N-02423.N', 'C3N-02424.N', 'C3N-02433.N', 'C3N-02529.N', 'C3N-02572.N', 'C3N-02582.N', 'C3N-02586.N', 'C3N-02587.N', 'C3N-02588.N', 'C3N-02729.N']

# %%
cancers = {'GBM':g, 'LUAD':l, 'LSCC':ls, 'UCEC':e, 'CCRCC':r, 'HNSCC':h, 'BR':b, 'OV':o, 'CO':c}

# %%
for ca_name in cancers:
    print(ca_name)
    p = cancers[ca_name].get_proteomics(source = 'umich')
    
    # Check tumor/normal counts
    tumor = p.loc[~ p.index.str.contains('\.N$')]
    normal = p.loc[p.index.str.contains('\.N$')]
    print('tumor:', len(tumor))
    print('normal:', len(normal))
    
        # Check if there are duplicates in index
    if True in set(p.index.duplicated()):
        print('duplicates in index')
        print(p.index[p.index.duplicated()])
    else:
        print('NO duplicates in index')
        
    # Check if there are duplicates in columns
    if True in set(p.columns.duplicated()):
        print('duplicates in columns')
        print(set(p.columns.duplicated()))
    else:
        print('NO duplicates in columns')
    
    print(p.index.to_list())
    print('\n')

# %%
p = e.get_proteomics('umich')
p

# %%
# Check tumor/normal counts
tumor = p.loc[~ p.index.str.contains('\.N$')]
normal = p.loc[p.index.str.contains('\.N$')]
print('tumor:', len(tumor))
print('normal:', len(normal))

# %%
# Check if there are duplicates in index
if True in set(p.index.duplicated()):
    print('duplicates')
    print(p.index[p.index.duplicated()])
else:
    print('NO duplicates in index')

# %%
p.loc[p.index[p.index.duplicated()]]

# %%
# Check if there are duplicates in columns
if True in set(p.columns.duplicated()):
    print('duplicates')
    print(set(p.columns.duplicated()))
else:
    print('NO duplicates in columns')

# %%
# check all ids mapped
p.index.to_list()
