# %%
import pandas as pd
import numpy as np
import warnings
from functools import reduce
import re
import cptac
import cptac.pancan as pc

# %%
pc.download('broadlscc')
# Out:
# Please login to Box on the webpage that was just opened and grant access for cptac to download files through your account. If you accidentally closed the browser window, press Ctrl+C and call the download function again.
# True

# %% [markdown]
# # Check

# %%
g = pc.PancanGbm()
l = pc.PancanLuad()
ls = pc.PancanLscc()
e = pc.PancanUcec()
r = pc.PancanCcrcc()
h = pc.PancanHnscc()
b = pc.PancanBrca()
o = pc.PancanOv()
c = pc.PancanCoad()

# %%
e = pc.PancanUcec()

# %%
ca = e

clin = ca.get_clinical()
clin.index
# Out:
# Index([   'C3L-00006.N',      'C3L-00006',      'C3L-00008',      'C3L-00032',
#             'C3L-00084',      'C3L-00090',      'C3L-00098',      'C3L-00136',
#             'C3L-00137',      'C3L-00139',
#        ...
#        ('NX18', 'NX18'),   ('NX2', 'NX2'),   ('NX3', 'NX3'),   ('NX4', 'NX4'),
#          ('NX5', 'NX5'),   ('NX6', 'NX6'),   ('NX7', 'NX7'),   ('NX8', 'NX8'),
#          ('NX9', 'NX9'),            'Ref'],
#       dtype='object', length=304)

# %%
file_name = "clinical_Pan-cancer.Dec2020.tsv"
file_path = "../../../input/clinical_Pan-cancer.Dec2020.tsv"

# %% [markdown]
# # Find patient_IDs in common with cptac (to assign sample type)

# %%
b = cptac.Brca()

# %%
p = b.get_clinical()
p.index.to_series().replace('X', '', regex = True).to_list()
p
# Out:
# Name       Replicate_Measurement_IDs Sample_Tumor_Normal  Age.in.Month  \
# Patient_ID
# CPT000814                  CPT000814               Tumor           NaN
# CPT001846                  CPT001846               Tumor           NaN
# X01BR001                    X01BR001               Tumor         660.0
# X01BR008                    X01BR008               Tumor           NaN
# X01BR009                    X01BR009               Tumor           NaN
# ...                              ...                 ...           ...
# X21BR001                    X21BR001               Tumor           NaN
# X21BR002                    X21BR002               Tumor           NaN
# X21BR010      X21BR010|X21BR010.REP1               Tumor         852.0
# X22BR005                    X22BR005               Tumor         552.0
# X22BR006                    X22BR006               Tumor         660.0
#
# Name        Gender                       Race Human.Readable.Label Experiment  \
# Patient_ID
# CPT000814      NaN  black.or.african.american       CPT000814 0004         13
# CPT001846      NaN                      white       CPT001846 0005         12
# X01BR001    female  black.or.african.american       [17]-af938b_D2          2
# X01BR008       NaN                        NaN       [cf]-467c39_D1         16
# X01BR009       NaN                        NaN       [0e]-051582_D1         16
# ...            ...                        ...                  ...        ...
# X21BR001       NaN                      white          [1f]-d9108c         16
# X21BR002       NaN                      white          [32]-22665e         16
# X21BR010    female                      white       [68]-4d3e43_D2       3|17
# X22BR005    female                      white       [12]-1af490_D2          6
# X22BR006    female  black.or.african.american       [a2]-5d5f11_D2         10
#
# Name          Channel       Stage  PAM50  ... ER.IHC.Score PR.IHC.Score  \
# Patient_ID                                ...
# CPT000814        127C   Stage IIA  Basal  ...          NaN          NaN
# CPT001846        128C   Stage III  Basal  ...          NaN          NaN
# X01BR001         129N   Stage IIB  Basal  ...            0            0
# X01BR008         127C         NaN  Basal  ...          NaN          NaN
# X01BR009         127N         NaN  Basal  ...          NaN          NaN
# ...               ...         ...    ...  ...          ...          ...
# X21BR001         128N         NaN   LumB  ...          NaN          NaN
# X21BR002         128C         NaN   LumA  ...          NaN          NaN
# X21BR010    129C|128C   Stage IIA   LumA  ...           3+           3+
# X22BR005         129N   Stage IIB   LumA  ...           3+           3+
# X22BR006         130N  Stage IIIA   LumA  ...           2+           3+
#
# Name       Coring.or.Excision Ischemia.Time.in.Minutes Ischemia.Decade  \
# Patient_ID
# CPT000814                 NaN                      NaN             NaN
# CPT001846                 NaN                      NaN             NaN
# X01BR001               coring                      0.0             1.0
# X01BR008                  NaN                      NaN             NaN
# X01BR009                  NaN                      NaN             NaN
# ...                       ...                      ...             ...
# X21BR001                  NaN                      NaN             NaN
# X21BR002                  NaN                      NaN             NaN
# X21BR010             excision                     18.0             2.0
# X22BR005             excision                     20.0             2.0
# X22BR006             excision                     25.0             3.0
#
# Name       Necrosis  Tumor.Cellularity  Total.Cellularity  In.CR  QC.status
# Patient_ID
# CPT000814       NaN                NaN                NaN    NaN    QC.pass
# CPT001846       NaN                NaN                NaN    NaN    QC.pass
# X01BR001       10.0               70.0               50.0    yes    QC.pass
# X01BR008        0.0               90.0               60.0     no    QC.pass
# X01BR009        0.0               80.0               70.0     no    QC.pass
# ...             ...                ...                ...    ...        ...
# X21BR001        0.0               60.0               80.0     no    QC.pass
# X21BR002        0.0               65.0               60.0     no    QC.pass
# X21BR010        0.0               60.0               55.0    yes    QC.pass
# X22BR005       15.0               65.0               75.0     no    QC.pass
# X22BR006        NaN                NaN                NaN     no    QC.pass
#
# [122 rows x 23 columns]

# %%
br_cptac = ['CPT000814','CPT001846','01BR001','01BR008','01BR009','01BR010','01BR015','01BR017','01BR018','01BR020',
 '01BR023','01BR025','01BR026','01BR027','01BR030','01BR031','01BR032','01BR033','01BR040','01BR042','01BR043',
 '03BR002','03BR004','03BR005','03BR006','03BR010','03BR011','03BR013','05BR001','05BR003','05BR004','05BR005',
 '05BR009','05BR016','05BR026','05BR029','05BR038','05BR042','05BR043','05BR044','05BR045','06BR003','06BR005',
 '06BR006','06BR014','09BR001','09BR004','09BR005','09BR007','11BR003','11BR004','11BR006','11BR009','11BR010',
 '11BR011','11BR012','11BR013','11BR014','11BR015','11BR016','11BR017','11BR018','11BR019','11BR020','11BR022',
 '11BR023','11BR024','11BR025','11BR027','11BR028','11BR030','11BR031','11BR032','11BR036','11BR038','11BR040',
 '11BR042','11BR043','11BR044','11BR047','11BR049','11BR050','11BR051','11BR053','11BR054','11BR055','11BR056',
 '11BR058','11BR059','11BR060','11BR072','11BR073','11BR074','11BR075','11BR080','13BR009','14BR005','14BR008',
 '14BR014','15BR003','16BR012','18BR002','18BR003','18BR004','18BR006','18BR007','18BR009','18BR010','18BR016',
 '18BR017','18BR019','20BR001','20BR002','20BR005','20BR006','20BR007','20BR008','21BR001','21BR002','21BR010',
 '22BR005','22BR006']

# %%
df = pd.read_csv(file_path, sep="\t") # take care of nan, are blanks = ''?
df = df.loc[df['tumor_code'] == 'BR'] 
df = df.set_index("case_id")
df = df.loc[df['discovery_study'] != 'No'] # Keep only discovery study = 'yes' or 'nan' 
df.index.name = 'Patient_ID'
all_clinical = df.sort_values(by=["Patient_ID"])
ids = all_clinical.index.to_list()

# %%
common = []
unique = []
for i in ids:
    if i in br_cptac:
        common.append(i)
    else:
        unique.append(i)

# %%
unique
# Out:
# ['01BR028',
#  '03BR009',
#  '03BR012',
#  '05BR031',
#  '06BR009',
#  '11BR057',
#  '11BR069',
#  '11BR076',
#  '14BR007',
#  '14BR020',
#  '21BR003',
#  '22BR003']

# %%
o = cptac.Ovarian()

# %%
p = o.get_clinical()
ov_cptac = p.index.to_list()

# %%
df = pd.read_csv(file_path, sep="\t") # take care of nan, are blanks = ''?
df = df.loc[df['tumor_code'] == 'OV'] 
df = df.set_index("case_id")
df = df.loc[df['discovery_study'] != 'No'] # Keep only discovery study = 'yes' or 'nan' 
df.index.name = 'Patient_ID'
all_clinical = df.sort_values(by=["Patient_ID"])
ids = all_clinical.index.to_list()
len(ids)
# Out:
# 110

# %%
common = []
unique = []
for i in ids:
    if i in ov_cptac:
        common.append(i)
    else:
        unique.append(i)

# %%
common
len(common)
# Out:
# 110

# %%
file_name = "clinical_Pan-cancer.Dec2020.tsv"
file_path = "../../../input/clinical_Pan-cancer.Dec2020.tsv"

# %%
# make Sample_Tumor_Normal column
if tumor_codes[filter_type] not in ('HCC','CO','OV'): # sample types not distinguished 
    if tumor_codes[filter_type] in ('GBM', 'BR'): # only has tumor samples 
        df['Sample_Tumor_Normal'] = 'Tumor'
    else:
        # Get list of patient_IDs with normal sample. Add suffix to distinguish. 
        normal = df.loc[df['discovery_study/type_of_analyzed_samples'].isin(['Normal', 'Tumor_and_Normal'])]
        normal = normal.sort_values(by=["Patient_ID"])
        normal['Sample_Tumor_Normal'] = 'Normal'
        normal = normal[['Sample_Tumor_Normal']] # keep only Sample_Tumor_Normal col
        indices = list(normal.index) 
        indices = [e+'.N' for e in indices] # Add ".N" to indices
        normal.index = indices
        # tumor samples
        tumor = df.loc[df['discovery_study/type_of_analyzed_samples'].isin(['Tumor', 'Tumor_and_Normal'])]
        tumor = tumor.sort_values(by=["Patient_ID"])
        tumor['Sample_Tumor_Normal'] = 'Tumor'
        df = tumor.append(normal) # append only the annotated patient_ID for normals (other information is with tumor and normals have nan for values in clinical table)

# %%
def load_clin(filter_type):
    data = {}
    # Get tumor_code
    tumor_codes = {'pancanbrca': 'BR', 'pancanccrcc':'CCRCC', 
                   'pancanucec':'UCEC','pancangbm':'GBM','pancanhnscc':'HNSCC',
                   'pancanlscc': 'LSCC','pancanluad':'LUAD', 'pancanpda':'PDA',
                   'pancanhcc':'HCC','pancancolon':'CO','pancanovarian':'OV'}

    if file_name == "clinical_Pan-cancer.Dec2020.tsv": #.gz
        df = pd.read_csv(file_path, sep="\t") # take care of nan, are blanks = ''?
        df = df.loc[df['tumor_code'] == tumor_codes[filter_type]] 
        df = df.set_index("case_id")
        df = df.loc[df['discovery_study'] != 'No'] # Keep only discovery study = 'yes' or 'nan' 
        df.index.name = 'Patient_ID'
        all_clinical = df.sort_values(by=["Patient_ID"])
        
        
        # make Sample_Tumor_Normal column
        if tumor_codes[filter_type] not in ('HCC','CO','OV'): # sample types not distinguished so can't make sample_tumor_normal col
            if tumor_codes[filter_type] == 'GBM': # only has tumor samples in clinical file
                all_clinical['Sample_Tumor_Normal'] = 'Tumor'
                # list of PT normal?
                
            elif tumor_codes[filter_type] == 'BR': # only has tumor samples in clinical file
                ids = all_clinical.index.to_series()
                all_clinical['Sample_Tumor_Normal'] =  ids.apply(lambda x: 'Tumor' if x in br_cptac else '')
                
                # list of PT normal?
                
            else:
                # Get list of patient_IDs with normal sample. Add suffix to distinguish. 
                sample_types = ['Tumor_and_Normal', 'Tumor', 'Normal']
                normal = all_clinical.loc[all_clinical['discovery_study/type_of_analyzed_samples'].isin(['Normal', 'Tumor_and_Normal'])]
                normal = normal.sort_values(by=["Patient_ID"])
                normal['Sample_Tumor_Normal'] = 'Normal'
                normal = normal[['Sample_Tumor_Normal']] # keep only Sample_Tumor_Normal col
                indices = list(normal.index) 
                indices = [e+'.N' for e in indices] # Add ".N" to indices
                normal.index = indices

                tumor = all_clinical.loc[all_clinical['discovery_study/type_of_analyzed_samples'].isin(['Tumor', 'Tumor_and_Normal'])]
                tumor = tumor.sort_values(by=["Patient_ID"])
                tumor['Sample_Tumor_Normal'] = 'Tumor'
                all_clinical = tumor.append(normal) # can append only the annotated patient_ID because other information is with tumor (normals will only have nan for everything in clinical table)
            
        data['clinical'] = all_clinical
    return all_clinical

# %%
df = load_clin('pancanbrca')

print(df.Sample_Tumor_Normal.value_counts())
df
# Out:
# Tumor    114
#           12
# Name: Sample_Tumor_Normal, dtype: int64
#            tumor_code discovery_study  \
# Patient_ID
# 01BR001            BR             NaN
# 01BR015            BR             NaN
# 01BR017            BR             NaN
# 01BR018            BR             NaN
# 01BR025            BR             NaN
# ...               ...             ...
# 21BR003            BR             NaN
# 21BR010            BR             NaN
# 22BR003            BR             NaN
# 22BR005            BR             NaN
# 22BR006            BR             NaN
#
#            discovery_study/type_of_analyzed_samples consent/age consent/sex  \
# Patient_ID
# 01BR001                                         NaN          55      Female
# 01BR015                                         NaN          35      Female
# 01BR017                                         NaN          45      Female
# 01BR018                                         NaN          66      Female
# 01BR025                                         NaN          62      Female
# ...                                             ...         ...         ...
# 21BR003                                         NaN          46      Female
# 21BR010                                         NaN          71      Female
# 22BR003                                         NaN          30      Female
# 22BR005                                         NaN          46      Female
# 22BR006                                         NaN          55      Female
#
#                          consent/race       consent/ethnicity  \
# Patient_ID
# 01BR001     Black or African American  Not Hispanic or Latino
# 01BR015                         White  Not Hispanic or Latino
# 01BR017                         White  Not Hispanic or Latino
# 01BR018                         White  Not Hispanic or Latino
# 01BR025     Black or African American  Not Hispanic or Latino
# ...                               ...                     ...
# 21BR003                         White      Hispanic or Latino
# 21BR010                         White      Hispanic or Latino
# 22BR003                         White  Not Hispanic or Latino
# 22BR005                         White  Not Hispanic or Latino
# 22BR006     Black or African American  Not Hispanic or Latino
#
#            consent/ethnicity_race_ancestry_identified  \
# Patient_ID
# 01BR001                                           NaN
# 01BR015                                           NaN
# 01BR017                                           NaN
# 01BR018                                           NaN
# 01BR025                                           NaN
# ...                                               ...
# 21BR003                                           NaN
# 21BR010                                           NaN
# 22BR003                                           NaN
# 22BR005                                           NaN
# 22BR006                                           NaN
#
#            consent/collection_in_us consent/participant_country  ...  \
# Patient_ID                                                       ...
# 01BR001                         NaN                         NaN  ...
# 01BR015                         NaN                         NaN  ...
# 01BR017                         NaN                         NaN  ...
# 01BR018                         NaN                         NaN  ...
# 01BR025                         NaN                         NaN  ...
# ...                             ...                         ...  ...
# 21BR003                         NaN                         NaN  ...
# 21BR010                         NaN                         NaN  ...
# 22BR003                         NaN                         NaN  ...
# 22BR005                         NaN                         NaN  ...
# 22BR006                         NaN                         NaN  ...
#
#            follow-up/additional_treatment_for_new_tumor_pharmaceutical  \
# Patient_ID
# 01BR001                                                   NaN
# 01BR015                                                   NaN
# 01BR017                                                   NaN
# 01BR018                                                   NaN
# 01BR025                                                   NaN
# ...                                                       ...
# 21BR003                                                   NaN
# 21BR010                                                   NaN
# 22BR003                                                   NaN
# 22BR005                                                   NaN
# 22BR006                                                   NaN
#
#            follow-up/additional_treatment_for_new_tumor_immunological  \
# Patient_ID
# 01BR001                                                   NaN
# 01BR015                                                   NaN
# 01BR017                                                   NaN
# 01BR018                                                   NaN
# 01BR025                                                   NaN
# ...                                                       ...
# 21BR003                                                   NaN
# 21BR010                                                   NaN
# 22BR003                                                   NaN
# 22BR005                                                   NaN
# 22BR006                                                   NaN
#
#            follow-up/days_from_date_of_initial_pathologic_diagnosis_to_date_of_additional_surgery_for_new_tumor  \
# Patient_ID
# 01BR001                                                   NaN
# 01BR015                                                   NaN
# 01BR017                                                   NaN
# 01BR018                                                   NaN
# 01BR025                                                   NaN
# ...                                                       ...
# 21BR003                                                   NaN
# 21BR010                                                   NaN
# 22BR003                                                   NaN
# 22BR005                                                   NaN
# 22BR006                                                   NaN
#
#            follow-up/cause_of_death  \
# Patient_ID
# 01BR001                         NaN
# 01BR015                         NaN
# 01BR017                         NaN
# 01BR018                         NaN
# 01BR025                         NaN
# ...                             ...
# 21BR003                         NaN
# 21BR010                         NaN
# 22BR003                         NaN
# 22BR005                         NaN
# 22BR006                         NaN
#
#            follow-up/days_from_date_of_initial_pathologic_diagnosis_to_date_of_death  \
# Patient_ID
# 01BR001                                                   NaN
# 01BR015                                                   NaN
# 01BR017                                                   NaN
# 01BR018                                                   NaN
# 01BR025                                                   NaN
# ...                                                       ...
# 21BR003                                                   NaN
# 21BR010                                                   NaN
# 22BR003                                                   NaN
# 22BR005                                                   NaN
# 22BR006                                                 282.0
#
#            Recurrence-free survival Overall survial  \
# Patient_ID
# 01BR001                         NaN           421.0
# 01BR015                         NaN           347.0
# 01BR017                         NaN           413.0
# 01BR018                         NaN           384.0
# 01BR025                         NaN           601.0
# ...                             ...             ...
# 21BR003                         NaN             NaN
# 21BR010                         NaN           327.0
# 22BR003                         NaN             NaN
# 22BR005                         NaN           348.0
# 22BR006                         NaN           282.0
#
#            Recurrence status (1, yes; 0, no)  \
# Patient_ID
# 01BR001                                    0
# 01BR015                                    0
# 01BR017                                    0
# 01BR018                                    0
# 01BR025                                    0
# ...                                      ...
# 21BR003                                    0
# 21BR010                                    0
# 22BR003                                    0
# 22BR005                                    0
# 22BR006                                    0
#
#            Survial status (1, dead; 0, alive) Sample_Tumor_Normal
# Patient_ID
# 01BR001                                   0.0               Tumor
# 01BR015                                   0.0               Tumor
# 01BR017                                   0.0               Tumor
# 01BR018                                   0.0               Tumor
# 01BR025                                   0.0               Tumor
# ...                                       ...                 ...
# 21BR003                                   NaN
# 21BR010                                   0.0               Tumor
# 22BR003                                   NaN
# 22BR005                                   0.0               Tumor
# 22BR006                                   1.0               Tumor
#
# [126 rows x 114 columns]

# %%
        # Separate out demographic, previous_cancer, medical_conditions, cancer_diagnosis, and followup dfs
        demographic_df = all_clinical[['discovery_study', 'discovery_study/type_of_analyzed_samples', 'consent/age', 
                          'consent/sex', 'consent/race', 'consent/ethnicity', 'consent/ethnicity_race_ancestry_identified',
                          'consent/collection_in_us', 'consent/participant_country', 'consent/maternal_grandmother_country',
                          'consent/maternal_grandfather_country', 'consent/paternal_grandmother_country', 
                          'consent/paternal_grandfather_country', 'consent/deaf_or_difficulty_hearing', 
                          'consent/blind_or_difficulty_seeing', 
                          'consent/difficulty_concentrating_remembering_or_making_decisions',
                          'consent/difficulty_walking_or_climbing_stairs', 'consent/difficulty_dressing_or_bathing',
                          'consent/difficulty_doing_errands', 'consent/consent_form_signed', 'consent/case_stopped',
                          'medications/medication_name_vitamins_supplements', 'medications/history_source',
                          'medical_history/height_at_time_of_surgery_cm', 'medical_history/weight_at_time_of_surgery_kg',
                          'medical_history/bmi', 'medical_history/history_of_cancer', 'medical_history/alcohol_consumption', 
                          'medical_history/tobacco_smoking_history', 
                          'medical_history/age_at_which_the_participant_started_smoking',
                          'medical_history/age_at_which_the_participant_stopped_smoking', 
                          'medical_history/on_the_days_participant_smoked_how_many_cigarettes_did_he_she_usually_smoke',
                          'medical_history/number_of_pack_years_smoked', 
                          'medical_history/was_the_participant_exposed_to_secondhand_smoke',
                          'medical_history/exposure_to_secondhand_smoke_in_household_during_participants_childhood',
                          'medical_history/exposure_to_secondhand_smoke_in_participants_current_household',    'medical_history/number_of_years_participant_has_consumed_more_than_2_drinks_per_day_for_men_and_more_than_1_drink_per_day_for_women']]         
        data['demographic'] = demographic_df

        # Create previous_cancer df
        previous_cancer_df = all_clinical[['cancer_history/cancer_type', 'cancer_history/history_source', 
                                        'cancer_history/history_of_any_treatment',
                                        'cancer_history/medical_record_documentation_of_this_history_of_cancer_and_treatment']]
        # include previous_cancer if it's not empty
        previous_cancer_df = previous_cancer_df.dropna(how='all')
        if len(previous_cancer_df.index) != 0: 
            data['previous_cancer'] = previous_cancer_df
        #else:
        #    print('no data for previous_cancer for', tumor_codes[filter_type])


        # Create medical_conditions df
        medical_conditions_df = all_clinical[['general_medical_history/medical_condition',
                                         'general_medical_history/history_of_treatment',
                                         'general_medical_history/history_source']]
        # include general_medical if it's not empty
        medical_conditions_df = medical_conditions_df.dropna(how='all')
        if len(medical_conditions_df.index) != 0: 
            data['medical_conditions'] = medical_conditions_df
        #else:
        #    print('no data for medical_conditions for', tumor_codes[filter_type])


        # Create cancer_diagnosis df    
        cancer_diagnosis_df = all_clinical[['baseline/tumor_site', 'baseline/tumor_site_other', 'baseline/tumor_laterality',
                               'baseline/tumor_focality', 'baseline/tumor_size_cm', 'baseline/histologic_type',
                               'cptac_path/histologic_grade', 'baseline/tumor_necrosis', 'baseline/margin_status',
                               'baseline/ajcc_tnm_cancer_staging_edition', 'baseline/pathologic_staging_primary_tumor',
                               'baseline/pathologic_staging_regional_lymph_nodes', 'baseline/number_of_lymph_nodes_examined',
                               'baseline/ihc_staining_done', 'baseline/he_staining_done', 
                               'baseline/number_of_positive_lymph_nodes_by_he_staining',
                               'baseline/clinical_staging_distant_metastasis', 'baseline/pathologic_staging_distant_metastasis',
                               'baseline/specify_distant_metastasis_documented_sites', 'baseline/residual_tumor',
                               'baseline/tumor_stage_pathological', 'baseline/paraneoplastic_syndrome_present',
                               'baseline/performance_status_assessment_ecog_performance_status_score', 
                               'baseline/performance_status_assessment_karnofsky_performance_status_score',
                               'baseline/number_of_positive_lymph_nodes_by_ihc_staining', 'baseline/perineural_invasion',
                               'procurement/blood_collection_minimum_required_blood_collected', 
                               'procurement/blood_collection_number_of_blood_tubes_collected',
                               'procurement/tumor_tissue_collection_tumor_type', 
                               'procurement/tumor_tissue_collection_number_of_tumor_segments_collected', 
                               'procurement/tumor_tissue_collection_clamps_used', 
                               'procurement/tumor_tissue_collection_frozen_with_oct',
                               'procurement/normal_adjacent_tissue_collection_number_of_normal_segments_collected', 
                               'Recurrence-free survival', 'Overall survial', 'Recurrence status (1, yes; 0, no)',
                               'Survial status (1, dead; 0, alive)', 'Sample_Tumor_Normal']]
        data['cancer_diagnosis'] = cancer_diagnosis_df # Maps dataframe name to dataframe (self._data)

        # Create followup df
        followup_df = all_clinical[['follow-up/follow_up_period','follow-up/is_this_patient_lost_to_follow-up',
                       'follow-up/vital_status_at_date_of_last_contact', 
                       'follow-up/days_from_date_of_initial_pathologic_diagnosis_to_date_of_last_contact',
                       'follow-up/adjuvant_post-operative_radiation_therapy',
                       'follow-up/adjuvant_post-operative_pharmaceutical_therapy', 
                       'follow-up/adjuvant_post-operative_immunological_therapy', 
                       'follow-up/tumor_status_at_date_of_last_contact_or_death',
                       'follow-up/measure_of_success_of_outcome_at_the_completion_of_initial_first_course_treatment',
                       'follow-up/measure_of_success_of_outcome_at_last_available_follow-up',
                       'follow-up/eastern_cooperative_oncology_group_at_last_available_follow-up',
                       'follow-up/karnofsky_score_preoperative_at_last_available_follow-up', 
                       'follow-up/performance_status_scale_timing_at_last_available_follow-up',
                       'follow-up/measure_of_success_of_outcome_at_first_NTE', 
                       'follow-up/eastern_cooperative_oncology_group_at_first_NTE',
                       'follow-up/karnofsky_score_preoperative_at_first_NTE', 
                       'follow-up/performance_status_scale_timing_at_first_NTE',
                       'follow-up/new_tumor_after_initial_treatment', 
                       'follow-up/days_from_date_of_initial_pathologic_diagnosis_to_date_of_new_tumor_after_initial_treatment',
                       'follow-up/type_of_new_tumor', 'follow-up/site_of_new_tumor', 'follow-up/other_site_of_new_tumor',
                       'follow-up/diagnostic_evidence_of_recurrence_or_relapse', 'follow-up/additional_surgery_for_new_tumor',
                       'follow-up/residual_tumor_after_surgery_for_new_tumor', 
                       'follow-up/additional_treatment_for_new_tumor_radiation',
                       'follow-up/additional_treatment_for_new_tumor_pharmaceutical', 
                       'follow-up/additional_treatment_for_new_tumor_immunological',
                       'follow-up/days_from_date_of_initial_pathologic_diagnosis_to_date_of_additional_surgery_for_new_tumor',
                       'follow-up/cause_of_death', 'follow-up/days_from_date_of_initial_pathologic_diagnosis_to_date_of_death']]
        data['followup'] =followup_df

        categories = {'demographic': ['consent/', 'medications/', 'medical_history/'], 
                      'cancer_diagnosis': ['baseline/', 'cptac_path/', 'procurement/'], 
                      'followup': ['follow-up/']} 

        # remove general categories from column labels
        for df_name in categories.keys():
            df = data[df_name]
            for c in categories[df_name]:
                df.columns = df.columns.str.replace(c, "")
                data[df_name] = df

        if len(medical_conditions_df.index) != 0:
            df = data['medical_conditions']
            df.columns = df.columns.str.replace('general_medical_history/', '')
            df = df.assign(medical_condition = df.medical_condition.str.split("|"))
            df = df.assign(history_of_treatment = df.history_of_treatment.str.split("|"))
            df = df.assign(history_source = df.history_source.str.split("|"))
            exploded_df = df.apply(pd.Series.explode) # explode 
            data['medical_conditions'] = exploded_df

        if len(previous_cancer_df.index) != 0:
            pc = data['previous_cancer']
            pc.columns = pc.columns.str.replace('cancer_history/', "")
            pc = pc.assign(cancer_type = pc.cancer_type.str.split("|"))
            pc = pc.assign(history_source = pc.history_source.str.split("|"))
            pc = pc.assign(history_of_any_treatment = pc.history_of_any_treatment.str.split("|"))
            pc = pc.assign(medical_record_documentation_of_this_history_of_cancer_and_treatment = 
                           pc.medical_record_documentation_of_this_history_of_cancer_and_treatment.str.split("|"))
            exploded_pc = pc.apply(pd.Series.explode)
            data['previous_cancer'] = exploded_pc

        # make lists for vals in medication cols
        dem = data['demographic'] 
        dem = dem.assign(medication_name_vitamins_supplements = dem.medication_name_vitamins_supplements.str.split("|"))
        dem = dem.assign(history_source = dem.history_source.str.split("|"))
        dem = dem.rename(columns={'history_source':'med_history_source'}) # ?? ok to rename?
        data['demographic'] = dem
        
        
        
        return data

# %%
# problems with creation of sample_tumor_normal col
# drop na from dfs without sample_t_n col (normal samples all na vals)

# %%
cancers = ['pancanbrca', 'pancanccrcc', 'pancanendometrial', 'pancangbm', 'pancanhnscc',
           'pancanlscc','pancanluad', 'pancanpda', 'pancanhcc','pancancolon','pancanovarian']

# %%
ca = cancers[3]
data = load_clin(ca)

# %%
clin = data['demographic']
#clin.Sample_Tumor_Normal.value_counts()
clin
# Out:
#           discovery_study discovery_study/type_of_analyzed_samples age  \
# C3L-00104             Yes                                    Tumor  58
# C3L-00365             Yes                                    Tumor  59
# C3L-00674             Yes                                    Tumor  45
# C3L-00677             Yes                                    Tumor  69
# C3L-01040             Yes                                    Tumor  77
# ...                   ...                                      ...  ..
# C3N-03183             Yes                                    Tumor  53
# C3N-03184             Yes                                    Tumor  35
# C3N-03186             Yes                                    Tumor  54
# C3N-03188             Yes                                    Tumor  54
# C3N-03473             Yes                                    Tumor  30
#
#               sex   race               ethnicity  \
# C3L-00104    Male  White  Not-Hispanic or Latino
# C3L-00365  Female  White  Not-Hispanic or Latino
# C3L-00674    Male  White  Not-Hispanic or Latino
# C3L-00677  Female  White  Not-Hispanic or Latino
# C3L-01040    Male    NaN                     NaN
# ...           ...    ...                     ...
# C3N-03183    Male    NaN                     NaN
# C3N-03184    Male    NaN                     NaN
# C3N-03186  Female    NaN                     NaN
# C3N-03188    Male    NaN                     NaN
# C3N-03473  Female    NaN                     NaN
#
#           ethnicity_race_ancestry_identified collection_in_us  \
# C3L-00104                          Caucasian              Yes
# C3L-00365                          Caucasian              Yes
# C3L-00674                          Caucasian              Yes
# C3L-00677                          Caucasian              Yes
# C3L-01040                          Caucasian               No
# ...                                      ...              ...
# C3N-03183                  Salar nationality               No
# C3N-03184                    Han nationality               No
# C3N-03186                    Han nationality               No
# C3N-03188                    Han nationality               No
# C3N-03473                    Han nationality               No
#
#                                     participant_country  \
# C3L-00104                                 United States
# C3L-00365                                 United States
# C3L-00674  Other: TSS did not collect this information.
# C3L-00677  Other: TSS did not collect this information.
# C3L-01040                                        Russia
# ...                                                 ...
# C3N-03183                                         China
# C3N-03184                                         China
# C3N-03186                                         China
# C3N-03188                                         China
# C3N-03473                                         China
#
#                            maternal_grandmother_country  ...  \
# C3L-00104   Other: TSS did not collect this information  ...
# C3L-00365  Other: TSS did not collect this information   ...
# C3L-00674  Other: TSS did not collect this information.  ...
# C3L-00677  Other: TSS did not collect this information.  ...
# C3L-01040                                        Russia  ...
# ...                                                 ...  ...
# C3N-03183                                         China  ...
# C3N-03184                                         China  ...
# C3N-03186                                         China  ...
# C3N-03188                                         China  ...
# C3N-03473                                         China  ...
#
#                                          alcohol_consumption  \
# C3L-00104  Alcohol consumption equal to or less than 2 dr...
# C3L-00365  Alcohol consumption equal to or less than 2 dr...
# C3L-00674          Alcohol consumption history not available
# C3L-00677          Alcohol consumption history not available
# C3L-01040          Alcohol consumption history not available
# ...                                                      ...
# C3N-03183                               Lifelong non-drinker
# C3N-03184  Alcohol consumption more than 2 drinks per day...
# C3N-03186                               Lifelong non-drinker
# C3N-03188                               Lifelong non-drinker
# C3N-03473                               Lifelong non-drinker
#
#                                      tobacco_smoking_history  \
# C3L-00104       Current reformed smoker within past 15 years
# C3L-00365       Current reformed smoker within past 15 years
# C3L-00674                      Smoking history not available
# C3L-00677  Current smoker: Includes daily and non-daily s...
# C3L-01040                      Smoking history not available
# ...                                                      ...
# C3N-03183  Lifelong non-smoker: Less than 100 cigarettes ...
# C3N-03184  Current smoker: Includes daily and non-daily s...
# C3N-03186  Lifelong non-smoker: Less than 100 cigarettes ...
# C3N-03188  Lifelong non-smoker: Less than 100 cigarettes ...
# C3N-03473  Lifelong non-smoker: Less than 100 cigarettes ...
#
#           age_at_which_the_participant_started_smoking  \
# C3L-00104                                           13
# C3L-00365                                           23
# C3L-00674                                          NaN
# C3L-00677                                           40
# C3L-01040                                          NaN
# ...                                                ...
# C3N-03183                                          NaN
# C3N-03184                                           25
# C3N-03186                                          NaN
# C3N-03188                                          NaN
# C3N-03473                                          NaN
#
#           age_at_which_the_participant_stopped_smoking  \
# C3L-00104                                           48
# C3L-00365                                           53
# C3L-00674                                          NaN
# C3L-00677                                          NaN
# C3L-01040                                          NaN
# ...                                                ...
# C3N-03183                                          NaN
# C3N-03184                                          NaN
# C3N-03186                                          NaN
# C3N-03188                                          NaN
# C3N-03473                                          NaN
#
#           on_the_days_participant_smoked_how_many_cigarettes_did_he_she_usually_smoke  \
# C3L-00104                                                 20
# C3L-00365                                                 20
# C3L-00674                                                NaN
# C3L-00677                                                 20
# C3L-01040                                                NaN
# ...                                                      ...
# C3N-03183                                                NaN
# C3N-03184                                                 30
# C3N-03186                                                NaN
# C3N-03188                                                NaN
# C3N-03473                                                NaN
#
#           number_of_pack_years_smoked  \
# C3L-00104                        35.0
# C3L-00365                        30.0
# C3L-00674                         NaN
# C3L-00677                        29.0
# C3L-01040                         NaN
# ...                               ...
# C3N-03183                         NaN
# C3N-03184                        15.0
# C3N-03186                         NaN
# C3N-03188                         NaN
# C3N-03473                         NaN
#
#              was_the_participant_exposed_to_secondhand_smoke  \
# C3L-00104  Exposure to secondhand smoke history not avail...
# C3L-00365  Exposure to secondhand smoke history not avail...
# C3L-00674  Exposure to secondhand smoke history not avail...
# C3L-00677  Exposure to secondhand smoke history not avail...
# C3L-01040  Exposure to secondhand smoke history not avail...
# ...                                                      ...
# C3N-03183         No or minimal exposure to secondhand smoke
# C3N-03184         No or minimal exposure to secondhand smoke
# C3N-03186         No or minimal exposure to secondhand smoke
# C3N-03188         No or minimal exposure to secondhand smoke
# C3N-03473         No or minimal exposure to secondhand smoke
#
#           exposure_to_secondhand_smoke_in_household_during_participants_childhood  \
# C3L-00104                                                NaN
# C3L-00365                                                NaN
# C3L-00674                                                NaN
# C3L-00677                                                NaN
# C3L-01040                                                NaN
# ...                                                      ...
# C3N-03183                                                NaN
# C3N-03184                                                NaN
# C3N-03186                                                NaN
# C3N-03188                                                NaN
# C3N-03473                                                NaN
#
#           exposure_to_secondhand_smoke_in_participants_current_household  \
# C3L-00104                                                NaN
# C3L-00365                                                NaN
# C3L-00674                                                NaN
# C3L-00677                                                NaN
# C3L-01040                                                NaN
# ...                                                      ...
# C3N-03183                                                NaN
# C3N-03184                                                NaN
# C3N-03186                                                NaN
# C3N-03188                                                NaN
# C3N-03473                                                NaN
#
#           number_of_years_participant_has_consumed_more_than_2_drinks_per_day_for_men_and_more_than_1_drink_per_day_for_women
# C3L-00104                                                NaN
# C3L-00365                                                NaN
# C3L-00674                                                NaN
# C3L-00677                                                NaN
# C3L-01040                                                NaN
# ...                                                      ...
# C3N-03183                                                NaN
# C3N-03184                                                 10
# C3N-03186                                                NaN
# C3N-03188                                                NaN
# C3N-03473                                                NaN
#
# [100 rows x 37 columns]

# %%
clin = data['demographic']
vc = clin['discovery_study/type_of_analyzed_samples'].value_counts(dropna = False)
print(ca)
print('total:',len(clin.index)) #+vc['Tumor_and_Normal'])
vc
# Out:
# pancangbm
# total: 100
# Tumor    100
# Name: discovery_study/type_of_analyzed_samples, dtype: int64

# %%
clin
# Out:
#            discovery_study discovery_study/type_of_analyzed_samples age  \
# Patient_ID
# 11LU013                Yes                                    Tumor  59
# 11LU016                Yes                                    Tumor  62
# 11LU022                Yes                                    Tumor  53
# 11LU035                Yes                                    Tumor  59
# C3L-00001              Yes                         Tumor_and_Normal  61
# ...                    ...                                      ...  ..
# C3N-02582              Yes                         Tumor_and_Normal  77
# C3N-02586              Yes                         Tumor_and_Normal  73
# C3N-02587              Yes                         Tumor_and_Normal  59
# C3N-02588              Yes                         Tumor_and_Normal  69
# C3N-02729              Yes                         Tumor_and_Normal  45
#
#                sex   race               ethnicity  \
# Patient_ID
# 11LU013       Male    NaN                     NaN
# 11LU016       Male    NaN                     NaN
# 11LU022       Male    NaN                     NaN
# 11LU035       Male    NaN                     NaN
# C3L-00001   Female  White  Not-Hispanic or Latino
# ...            ...    ...                     ...
# C3N-02582     Male    NaN                     NaN
# C3N-02586     Male    NaN                     NaN
# C3N-02587   Female    NaN                     NaN
# C3N-02588     Male    NaN                     NaN
# C3N-02729     Male    NaN                     NaN
#
#            ethnicity_race_ancestry_identified collection_in_us  \
# Patient_ID
# 11LU013                                 Asian               No
# 11LU016                                 Asian               No
# 11LU022                                 Asian               No
# 11LU035                                 Asian               No
# C3L-00001                           Caucasian              Yes
# ...                                       ...              ...
# C3N-02582                                 Han               No
# C3N-02586                                 Han               No
# C3N-02587                                 Han               No
# C3N-02588                                 Han               No
# C3N-02729                                 Han               No
#
#            participant_country maternal_grandmother_country  ...  \
# Patient_ID                                                   ...
# 11LU013                Vietnam         Other: Not Collected  ...
# 11LU016                Vietnam         Other: Not Collected  ...
# 11LU022                Vietnam         Other: Not Collected  ...
# 11LU035                Vietnam         Other: Not Collected  ...
# C3L-00001        United States               Other: unknown  ...
# ...                        ...                          ...  ...
# C3N-02582                China                        China  ...
# C3N-02586                China                        China  ...
# C3N-02587                China                        China  ...
# C3N-02588                China                        China  ...
# C3N-02729                China                        China  ...
#
#                                           alcohol_consumption  \
# Patient_ID
# 11LU013                                  Lifelong non-drinker
# 11LU016                                  Lifelong non-drinker
# 11LU022                                  Lifelong non-drinker
# 11LU035     Alcohol consumption equal to or less than 2 dr...
# C3L-00001   Alcohol consumption equal to or less than 2 dr...
# ...                                                       ...
# C3N-02582   Alcohol consumption equal to or less than 2 dr...
# C3N-02586   Alcohol consumption equal to or less than 2 dr...
# C3N-02587                                Lifelong non-drinker
# C3N-02588           Alcohol consumption history not available
# C3N-02729   Alcohol consumption equal to or less than 2 dr...
#
#                                       tobacco_smoking_history  \
# Patient_ID
# 11LU013     Lifelong non-smoker: Less than 100 cigarettes ...
# 11LU016     Lifelong non-smoker: Less than 100 cigarettes ...
# 11LU022     Lifelong non-smoker: Less than 100 cigarettes ...
# 11LU035     Current smoker: Includes daily and non-daily s...
# C3L-00001   Lifelong non-smoker: Less than 100 cigarettes ...
# ...                                                       ...
# C3N-02582         Current reformed smoker, more than 15 years
# C3N-02586        Current reformed smoker within past 15 years
# C3N-02587   Lifelong non-smoker: Less than 100 cigarettes ...
# C3N-02588                       Smoking history not available
# C3N-02729   Lifelong non-smoker: Less than 100 cigarettes ...
#
#            age_at_which_the_participant_started_smoking  \
# Patient_ID
# 11LU013                                             NaN
# 11LU016                                             NaN
# 11LU022                                             NaN
# 11LU035                                              39
# C3L-00001                                           NaN
# ...                                                 ...
# C3N-02582                                            16
# C3N-02586                                            23
# C3N-02587                                           NaN
# C3N-02588                                           NaN
# C3N-02729                                           NaN
#
#            age_at_which_the_participant_stopped_smoking  \
# Patient_ID
# 11LU013                                             NaN
# 11LU016                                             NaN
# 11LU022                                             NaN
# 11LU035                                             NaN
# C3L-00001                                           NaN
# ...                                                 ...
# C3N-02582                                            47
# C3N-02586                                            64
# C3N-02587                                           NaN
# C3N-02588                                           NaN
# C3N-02729                                           NaN
#
#            on_the_days_participant_smoked_how_many_cigarettes_did_he_she_usually_smoke  \
# Patient_ID
# 11LU013                                                   NaN
# 11LU016                                                   NaN
# 11LU022                                                   NaN
# 11LU035                                                     5
# C3L-00001                                                 NaN
# ...                                                       ...
# C3N-02582                                                  20
# C3N-02586                                                  20
# C3N-02587                                                 NaN
# C3N-02588                                                 NaN
# C3N-02729                                                 NaN
#
#            number_of_pack_years_smoked  \
# Patient_ID
# 11LU013                            NaN
# 11LU016                            NaN
# 11LU022                            NaN
# 11LU035                            5.0
# C3L-00001                          NaN
# ...                                ...
# C3N-02582                         31.0
# C3N-02586                         41.0
# C3N-02587                          NaN
# C3N-02588                          NaN
# C3N-02729                          NaN
#
#               was_the_participant_exposed_to_secondhand_smoke  \
# Patient_ID
# 11LU013            No or minimal exposure to secondhand smoke
# 11LU016            No or minimal exposure to secondhand smoke
# 11LU022            No or minimal exposure to secondhand smoke
# 11LU035            No or minimal exposure to secondhand smoke
# C3L-00001                                                 Yes
# ...                                                       ...
# C3N-02582   Exposure to secondhand smoke history not avail...
# C3N-02586   Exposure to secondhand smoke history not avail...
# C3N-02587   Exposure to secondhand smoke history not avail...
# C3N-02588   Exposure to secondhand smoke history not avail...
# C3N-02729   Exposure to secondhand smoke history not avail...
#
#            exposure_to_secondhand_smoke_in_household_during_participants_childhood  \
# Patient_ID
# 11LU013                                                   NaN
# 11LU016                                                   NaN
# 11LU022                                                   NaN
# 11LU035                                                   NaN
# C3L-00001                                                 NaN
# ...                                                       ...
# C3N-02582                                                 NaN
# C3N-02586                                                 NaN
# C3N-02587                                                 NaN
# C3N-02588                                                 NaN
# C3N-02729                                                 NaN
#
#            exposure_to_secondhand_smoke_in_participants_current_household  \
# Patient_ID
# 11LU013                                                   NaN
# 11LU016                                                   NaN
# 11LU022                                                   NaN
# 11LU035                                                   NaN
# C3L-00001                                                 Yes
# ...                                                       ...
# C3N-02582                                                 NaN
# C3N-02586                                                 NaN
# C3N-02587                                                 NaN
# C3N-02588                                                 NaN
# C3N-02729                                                 NaN
#
#            number_of_years_participant_has_consumed_more_than_2_drinks_per_day_for_men_and_more_than_1_drink_per_day_for_women
# Patient_ID
# 11LU013                                                   NaN
# 11LU016                                                   NaN
# 11LU022                                                   NaN
# 11LU035                                                   NaN
# C3L-00001                                                   1
# ...                                                       ...
# C3N-02582                                                 NaN
# C3N-02586                                                 NaN
# C3N-02587                                                 NaN
# C3N-02588                                                 NaN
# C3N-02729                                                 NaN
#
# [111 rows x 37 columns]

# %%
clin['discovery_study/type_of_analyzed_samples']
# Out:
# Patient_ID
# 01BR001    NaN
# 01BR015    NaN
# 01BR017    NaN
# 01BR018    NaN
# 01BR025    NaN
#           ...
# 21BR003    NaN
# 21BR010    NaN
# 22BR003    NaN
# 22BR005    NaN
# 22BR006    NaN
# Name: discovery_study/type_of_analyzed_samples, Length: 126, dtype: object

# %%
# blanks read as NaN
clin = data['clinical']
len(clin.index.unique())
clin['discovery_study/type_of_analyzed_samples'].unique() # no tumor/normal divisions: brca 
len(clin)
# Out:
# 126

# %%
#clin = clin.loc[clin['discovery_study'] == 'yes']
clin['discovery_study'].unique()
# Out:
# array([nan], dtype=object)

# %%
tl = clin['baseline/tumor_laterality']
pid = ['01BR001','01BR015','01BR017','01BR018','01BR025']
tt = tl.loc[pid]
tt.unique()
# Out:
# array([nan], dtype=object)

# %%
dem = data['demographic']
demv = dem.dropna(axis =1, how = 'all')
print('cols demographic:', len(dem.columns))
print('cols with values (not all NA):', len(demv.columns))
dem
# Out:
# cols demographic: 37
# cols with values (not all NA): 0
# Empty DataFrame
# Columns: [discovery_study, discovery_study/type_of_analyzed_samples, age, sex, race, ethnicity, ethnicity_race_ancestry_identified, collection_in_us, participant_country, maternal_grandmother_country, maternal_grandfather_country, paternal_grandmother_country, paternal_grandfather_country, deaf_or_difficulty_hearing, blind_or_difficulty_seeing, difficulty_concentrating_remembering_or_making_decisions, difficulty_walking_or_climbing_stairs, difficulty_dressing_or_bathing, difficulty_doing_errands, consent_form_signed, case_stopped, medication_name_vitamins_supplements, med_history_source, height_at_time_of_surgery_cm, weight_at_time_of_surgery_kg, bmi, history_of_cancer, alcohol_consumption, tobacco_smoking_history, age_at_which_the_participant_started_smoking, age_at_which_the_participant_stopped_smoking, on_the_days_participant_smoked_how_many_cigarettes_did_he_she_usually_smoke, number_of_pack_years_smoked, was_the_participant_exposed_to_secondhand_smoke, exposure_to_secondhand_smoke_in_household_during_participants_childhood, exposure_to_secondhand_smoke_in_participants_current_household, number_of_years_participant_has_consumed_more_than_2_drinks_per_day_for_men_and_more_than_1_drink_per_day_for_women]
# Index: []
#
# [0 rows x 37 columns]

# %%
pc = data['previous_cancer']
pcv = pc.dropna(axis =1, how = 'all')
print('cols demographic:', len(pc.columns))
print('cols with values (not all NA):', len(pcv.columns))
pc.dropna(axis = 0, how = 'all')
# Out:
# cols demographic: 4
# cols with values (not all NA): 1
#            cancer_type history_source history_of_any_treatment  \
# Patient_ID
# 01CO001            NaN            NaN                       No
# 01CO005            NaN            NaN                       No
# 01CO006            NaN            NaN                       No
# 01CO008            NaN            NaN                       No
# 01CO013            NaN            NaN                       No
# ...                ...            ...                      ...
# 21CO007            NaN            NaN                       No
# 22CO004            NaN            NaN                       No
# 22CO006            NaN            NaN                       No
# 24CO005            NaN            NaN                       No
# 27CO004            NaN            NaN                       No
#
#            medical_record_documentation_of_this_history_of_cancer_and_treatment
# Patient_ID
# 01CO001                                                   NaN
# 01CO005                                                   NaN
# 01CO006                                                   NaN
# 01CO008                                                   NaN
# 01CO013                                                   NaN
# ...                                                       ...
# 21CO007                                                   NaN
# 22CO004                                                   NaN
# 22CO006                                                   NaN
# 24CO005                                                   NaN
# 27CO004                                                   NaN
#
# [106 rows x 4 columns]

# %%
med = data['medical_conditions']
medv = med.dropna(axis =1, how = 'all')
print('cols medical_conditions:', len(med.columns))
print('cols with values (not all NA):', len(medv.columns))
med
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-86bc8c3ec101> in <module>
# ----> 1 med = data['medical_conditions']
#       2 medv = med.dropna(axis =1, how = 'all')
#       3 print('cols medical_conditions:', len(med.columns))
#       4 print('cols with values (not all NA):', len(medv.columns))
#       5 med
#
# KeyError: 'medical_conditions'

# %%
cd = data['cancer_diagnosis']
cdv = cd.dropna(axis =1, how = 'all')
print('cols cancer_diagnosis:', len(cd.columns))
print('cols with values (not all NA):', len(cdv.columns))
cd
# Out:
# cols cancer_diagnosis: 38
# cols with values (not all NA): 35
#             tumor_site tumor_site_other tumor_laterality tumor_focality  \
# C3L-00004          NaN              NaN      Left Kidney       Unifocal
# C3L-00010          NaN              NaN      Left Kidney       Unifocal
# C3L-00011          NaN              NaN     Right Kidney       Unifocal
# C3L-00026          NaN              NaN     Right Kidney       Unifocal
# C3L-00079          NaN              NaN     Right Kidney       Unifocal
# ...                ...              ...              ...            ...
# C3N-01646.N        NaN              NaN              NaN            NaN
# C3N-01648.N        NaN              NaN              NaN            NaN
# C3N-01649.N        NaN              NaN              NaN            NaN
# C3N-01651.N        NaN              NaN              NaN            NaN
# C3N-01808.N        NaN              NaN              NaN            NaN
#
#              tumor_size_cm                  histologic_type  \
# C3L-00004             12.0  Clear cell renal cell carcinoma
# C3L-00010              6.5  Clear cell renal cell carcinoma
# C3L-00011             12.0  Clear cell renal cell carcinoma
# C3L-00026              2.0  Clear cell renal cell carcinoma
# C3L-00079             14.0  Clear cell renal cell carcinoma
# ...                    ...                              ...
# C3N-01646.N            NaN                              NaN
# C3N-01648.N            NaN                              NaN
# C3N-01649.N            NaN                              NaN
# C3N-01651.N            NaN                              NaN
# C3N-01808.N            NaN                              NaN
#
#                                               histologic_grade  \
# C3L-00004    G3: Nuclei very irregular, approximately 20µm;...
# C3L-00010    G3: Nuclei very irregular, approximately 20µm;...
# C3L-00011    G4: Nuclei bizarre and multilobulated, 20µm or...
# C3L-00026    G3: Nuclei very irregular, approximately 20µm;...
# C3L-00079    G3: Nuclei very irregular, approximately 20µm;...
# ...                                                        ...
# C3N-01646.N                                                NaN
# C3N-01648.N                                                NaN
# C3N-01649.N                                                NaN
# C3N-01651.N                                                NaN
# C3N-01808.N                                                NaN
#
#              tumor_necrosis                             margin_status  \
# C3L-00004           Present  Margin(s) involved by invasive carcinoma
# C3L-00010    Not identified  Margins uninvolved by invasive carcinoma
# C3L-00011           Present  Margin(s) involved by invasive carcinoma
# C3L-00026    Not identified  Margins uninvolved by invasive carcinoma
# C3L-00079           Present  Margins uninvolved by invasive carcinoma
# ...                     ...                                       ...
# C3N-01646.N             NaN                                       NaN
# C3N-01648.N             NaN                                       NaN
# C3N-01649.N             NaN                                       NaN
# C3N-01651.N             NaN                                       NaN
# C3N-01808.N             NaN                                       NaN
#
#             ajcc_tnm_cancer_staging_edition  ...  \
# C3L-00004            Seventh Edition (2010)  ...
# C3L-00010            Seventh Edition (2010)  ...
# C3L-00011            Seventh Edition (2010)  ...
# C3L-00026            Seventh Edition (2010)  ...
# C3L-00079            Seventh Edition (2010)  ...
# ...                                     ...  ...
# C3N-01646.N                             NaN  ...
# C3N-01648.N                             NaN  ...
# C3N-01649.N                             NaN  ...
# C3N-01651.N                             NaN  ...
# C3N-01808.N                             NaN  ...
#
#                   tumor_tissue_collection_tumor_type  \
# C3L-00004    Kidney: Clear Cell Renal Cell Carcinoma
# C3L-00010    Kidney: Clear Cell Renal Cell Carcinoma
# C3L-00011    Kidney: Clear Cell Renal Cell Carcinoma
# C3L-00026    Kidney: Clear Cell Renal Cell Carcinoma
# C3L-00079    Kidney: Clear Cell Renal Cell Carcinoma
# ...                                              ...
# C3N-01646.N                                      NaN
# C3N-01648.N                                      NaN
# C3N-01649.N                                      NaN
# C3N-01651.N                                      NaN
# C3N-01808.N                                      NaN
#
#             tumor_tissue_collection_number_of_tumor_segments_collected  \
# C3L-00004                                                  1.0
# C3L-00010                                                  1.0
# C3L-00011                                                  1.0
# C3L-00026                                                  1.0
# C3L-00079                                                  1.0
# ...                                                        ...
# C3N-01646.N                                                NaN
# C3N-01648.N                                                NaN
# C3N-01649.N                                                NaN
# C3N-01651.N                                                NaN
# C3N-01808.N                                                NaN
#
#             tumor_tissue_collection_clamps_used  \
# C3L-00004                                    No
# C3L-00010                                    No
# C3L-00011                                    No
# C3L-00026                                   Yes
# C3L-00079                                    No
# ...                                         ...
# C3N-01646.N                                 NaN
# C3N-01648.N                                 NaN
# C3N-01649.N                                 NaN
# C3N-01651.N                                 NaN
# C3N-01808.N                                 NaN
#
#             tumor_tissue_collection_frozen_with_oct  \
# C3L-00004                                        No
# C3L-00010                                        No
# C3L-00011                                        No
# C3L-00026                                        No
# C3L-00079                                        No
# ...                                             ...
# C3N-01646.N                                     NaN
# C3N-01648.N                                     NaN
# C3N-01649.N                                     NaN
# C3N-01651.N                                     NaN
# C3N-01808.N                                     NaN
#
#             normal_adjacent_tissue_collection_number_of_normal_segments_collected  \
# C3L-00004                                                  1.0
# C3L-00010                                                  1.0
# C3L-00011                                                  1.0
# C3L-00026                                                  1.0
# C3L-00079                                                  1.0
# ...                                                        ...
# C3N-01646.N                                                NaN
# C3N-01648.N                                                NaN
# C3N-01649.N                                                NaN
# C3N-01651.N                                                NaN
# C3N-01808.N                                                NaN
#
#             Recurrence-free survival Overall survial  \
# C3L-00004                        NaN           384.0
# C3L-00010                        NaN           896.0
# C3L-00011                        NaN           241.0
# C3L-00026                        NaN          1458.0
# C3L-00079                        NaN           274.0
# ...                              ...             ...
# C3N-01646.N                      NaN             NaN
# C3N-01648.N                      NaN             NaN
# C3N-01649.N                      NaN             NaN
# C3N-01651.N                      NaN             NaN
# C3N-01808.N                      NaN             NaN
#
#             Recurrence status (1, yes; 0, no)  \
# C3L-00004                                 0.0
# C3L-00010                                 0.0
# C3L-00011                                 0.0
# C3L-00026                                 0.0
# C3L-00079                                 0.0
# ...                                       ...
# C3N-01646.N                               NaN
# C3N-01648.N                               NaN
# C3N-01649.N                               NaN
# C3N-01651.N                               NaN
# C3N-01808.N                               NaN
#
#             Survial status (1, dead; 0, alive) Sample_Tumor_Normal
# C3L-00004                                  0.0               Tumor
# C3L-00010                                  0.0               Tumor
# C3L-00011                                  1.0               Tumor
# C3L-00026                                  0.0               Tumor
# C3L-00079                                  1.0               Tumor
# ...                                        ...                 ...
# C3N-01646.N                                NaN              Normal
# C3N-01648.N                                NaN              Normal
# C3N-01649.N                                NaN              Normal
# C3N-01651.N                                NaN              Normal
# C3N-01808.N                                NaN              Normal
#
# [345 rows x 38 columns]

# %%
fol = data['followup']
folv = fol.dropna(axis =1, how = 'all')
print('cols followup:', len(fol.columns))
print('cols with values (not all NA):', len(folv.columns))
len(fol.index.unique())
# Out:
# cols followup: 31
# cols with values (not all NA): 13
# 106

# %%
n = dem[dem.index.str.contains('#')]
len(n)

# %%
dem.index.duplicated().any()

# %%
# Keep cols with general category name (in case need later)
def load_clin():
    data = {}
    if file_name == "clinical_Pan-cancer.Dec2020.tsv":
        df = pd.read_csv(file_path, sep = "\t") # check na_vals 
        df = df.loc[df['tumor_code'] == 'BR']
        df = df.set_index("case_id")
        df.index.name = 'Patient_ID'
        df = df.sort_values(by=["Patient_ID"])
        #self._data["clinical"] = df
        
        # Separate out demographic, general_medical_history, cancer_diagnosis, and followup dfs
        #all_clinical = self._data["clinical"]
        demographic_df = df[['discovery_study', 'discovery_study/type_of_analyzed_samples', 'consent/age', 
                          'consent/sex', 'consent/race', 'consent/ethnicity', 'consent/ethnicity_race_ancestry_identified',
                          'consent/collection_in_us', 'consent/participant_country', 'consent/maternal_grandmother_country',
                          'consent/maternal_grandfather_country', 'consent/paternal_grandmother_country', 
                          'consent/paternal_grandfather_country', 'consent/deaf_or_difficulty_hearing', 
                          'consent/blind_or_difficulty_seeing', 'consent/difficulty_concentrating_remembering_or_making_decisions',
                          'consent/difficulty_walking_or_climbing_stairs', 'consent/difficulty_dressing_or_bathing',
                          'consent/difficulty_doing_errands', 'consent/consent_form_signed', 'consent/case_stopped',
                          'medical_history/history_of_cancer', 'medical_history/alcohol_consumption', 
                          'medical_history/tobacco_smoking_history', 'medical_history/age_at_which_the_participant_started_smoking',
                          'medical_history/age_at_which_the_participant_stopped_smoking', 'medical_history/on_the_days_participant_smoked_how_many_cigarettes_did_he_she_usually_smoke',
                          'medical_history/number_of_pack_years_smoked', 'medical_history/was_the_participant_exposed_to_secondhand_smoke',
                          'medical_history/exposure_to_secondhand_smoke_in_household_during_participants_childhood',
                          'medical_history/exposure_to_secondhand_smoke_in_participants_current_household',
                          'medical_history/number_of_years_participant_has_consumed_more_than_2_drinks_per_day_for_men_and_more_than_1_drink_per_day_for_women']] # all_clinical[[
                #'''cancer_history/cancer_type
                #cancer_history/history_source
                #cancer_history/history_of_any_treatment
                #cancer_history/medical_record_documentation_of_this_history_of_cancer_and_treatment'''

        data['demographic'] = demographic_df
            
        general_medical_history_df = df[['general_medical_history/medical_condition', 'general_medical_history/history_of_treatment',
                                      'general_medical_history/history_source', 'medications/medication_name_vitamins_supplements', 
                                      'medications/history_source']]
        data['general_medical_history'] = general_medical_history_df
            
        cancer_diagnosis_df = df[['baseline/tumor_site', 'baseline/tumor_site_other', 'baseline/tumor_laterality',
                               'baseline/tumor_focality', 'baseline/tumor_size_cm', 'baseline/histologic_type',
                               'cptac_path/histologic_grade', 'baseline/tumor_necrosis', 'baseline/margin_status',
                               'baseline/ajcc_tnm_cancer_staging_edition', 'baseline/pathologic_staging_primary_tumor',
                               'baseline/pathologic_staging_regional_lymph_nodes', 'baseline/number_of_lymph_nodes_examined',
                               'baseline/ihc_staining_done', 'baseline/he_staining_done', 'baseline/number_of_positive_lymph_nodes_by_he_staining',
                               'baseline/clinical_staging_distant_metastasis', 'baseline/pathologic_staging_distant_metastasis',
                               'baseline/specify_distant_metastasis_documented_sites', 'baseline/residual_tumor',
                               'baseline/tumor_stage_pathological', 'baseline/paraneoplastic_syndrome_present',
                               'baseline/performance_status_assessment_ecog_performance_status_score', 'baseline/performance_status_assessment_karnofsky_performance_status_score',
                               'baseline/number_of_positive_lymph_nodes_by_ihc_staining', 'baseline/perineural_invasion',
                               'procurement/blood_collection_minimum_required_blood_collected', 'procurement/blood_collection_number_of_blood_tubes_collected',
                               'procurement/tumor_tissue_collection_tumor_type', 'procurement/tumor_tissue_collection_number_of_tumor_segments_collected', 
                               'procurement/tumor_tissue_collection_clamps_used', 'procurement/tumor_tissue_collection_frozen_with_oct',
                               'procurement/normal_adjacent_tissue_collection_number_of_normal_segments_collected', 
                               'Recurrence-free survival', 'Overall survial', 'Recurrence status (1, yes; 0, no)',
                               'Survial status (1, dead; 0, alive)']]
        data['cancer_diagnosis'] = cancer_diagnosis_df # Maps dataframe name to dataframe (self._data)
            
        followup_df = df[['follow-up/follow_up_period','follow-up/is_this_patient_lost_to_follow-up',
                       'follow-up/vital_status_at_date_of_last_contact', 'follow-up/days_from_date_of_initial_pathologic_diagnosis_to_date_of_last_contact',
                       'follow-up/adjuvant_post-operative_radiation_therapy','follow-up/adjuvant_post-operative_pharmaceutical_therapy', 
                       'follow-up/adjuvant_post-operative_immunological_therapy', 'follow-up/tumor_status_at_date_of_last_contact_or_death',
                       'follow-up/measure_of_success_of_outcome_at_the_completion_of_initial_first_course_treatment',
                       'follow-up/measure_of_success_of_outcome_at_last_available_follow-up','follow-up/eastern_cooperative_oncology_group_at_last_available_follow-up',
                       'follow-up/karnofsky_score_preoperative_at_last_available_follow-up', 'follow-up/performance_status_scale_timing_at_last_available_follow-up',
                       'follow-up/measure_of_success_of_outcome_at_first_NTE', 'follow-up/eastern_cooperative_oncology_group_at_first_NTE',
                       'follow-up/karnofsky_score_preoperative_at_first_NTE', 'follow-up/performance_status_scale_timing_at_first_NTE',
                       'follow-up/new_tumor_after_initial_treatment', 'follow-up/days_from_date_of_initial_pathologic_diagnosis_to_date_of_new_tumor_after_initial_treatment',
                       'follow-up/type_of_new_tumor', 'follow-up/site_of_new_tumor', 'follow-up/other_site_of_new_tumor',
                       'follow-up/diagnostic_evidence_of_recurrence_or_relapse', 'follow-up/additional_surgery_for_new_tumor',
                       'follow-up/residual_tumor_after_surgery_for_new_tumor', 'follow-up/additional_treatment_for_new_tumor_radiation',
                       'follow-up/additional_treatment_for_new_tumor_pharmaceutical', 'follow-up/additional_treatment_for_new_tumor_immunological',
                       'follow-up/days_from_date_of_initial_pathologic_diagnosis_to_date_of_additional_surgery_for_new_tumor',
                       'follow-up/cause_of_death', 'follow-up/days_from_date_of_initial_pathologic_diagnosis_to_date_of_death']]
        data['followup'] =followup_df
        return data
