# %% [markdown]
# # Flagship vs Pancan Make Figure 4

# %% [markdown]
# This notebooks takes all the trans genes that have positive and negative results and runs a GSEA using Reactome. It then takes a subset of genes from the top hit (Hemostasis) pathway and maps them on a large circle heat map. This heatmap focuses on coagulation and urokinase related genes. The notebook does this with both the flagship and harmonzied paper

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas.util.testing as tm
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest

import gseapy as gp
from gseapy.plot import barplot, dotplot

import plot_utils as p
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Flagship Figure 4

# %% [markdown]
# # Step 1: Find Trans proteins with opposite effects in different cancers

# %% [markdown]
# Load df with all of the genes that are FDR significant. This dataframe was made in the Make_Supplemental_Tables notebook. See
# https://github.com/PayneLab/WhenMutationsDontMatter/blob/master/EGFR/Make_Tables/Make_Supplemental_Tables.ipynb

# %%
FDR_sig = pd.read_csv("csv_files/Supplemental_Table_EGFR_sig_only.csv")
FDR_sig = FDR_sig.set_index("Comparison")

# %%
FDR_sig.max(axis=1)
FDR_sig.min(axis = 1)
# Out:
# Comparison
# PHLDA1      9.649849e-19
# CDH4        4.744022e-10
# GRB2       -5.890078e-01
# PHLDA3      2.351012e-14
# GLA        -5.623150e-01
#                 ...
# IGLV2-23   -2.778010e-01
# SCN10A     -3.648703e-01
# PCYT1A      4.976210e-02
# NCBP1       4.976210e-02
# IGHV3-43   -2.451771e-01
# Length: 6443, dtype: float64

# %%
def HasPosNeg(row):
    hasPos = False
    hasNeg= False

    for item in row:
        if pd.isnull(item):
            continue
        if item < 0:
            hasNeg = True
        if item > 0:
            hasPos = True
            
    if hasPos & hasNeg:
        return True
    return False

# %% [markdown]
# Subset data frame to include only trans genes that have opposite effects in different cancers by using apply function

# %%
col = ["Correlation_GBM","Correlation_ccRCC","Correlation_BR","Correlation_LUAD","Correlation_HNSCC","Correlation_LSCC"]
FDR_corr = FDR_sig[col]
FDR_corr["Pos_Neg"] = FDR_corr.apply(HasPosNeg, axis = 1)
FDR_corr_True = FDR_corr[FDR_corr['Pos_Neg']==True]
FDR_corr_True.head(20)
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#             Correlation_GBM  Correlation_ccRCC  Correlation_BR  \
# Comparison
# CTSC              -0.548303                NaN        0.316126
# SHC1              -0.521169           0.361057             NaN
# HSD17B11          -0.521630                NaN        0.405826
# CTSB              -0.514005                NaN        0.244299
# EPB41L3_3         -0.510933                NaN        0.315277
# SCPEP1            -0.509046          -0.394109        0.384739
# DAB2              -0.500648                NaN        0.410470
# OSTF1             -0.500063          -0.456002        0.308680
# PLA2G15           -0.498087                NaN        0.271834
# SUB1               0.498468          -0.289319       -0.260239
# RIN2              -0.476346                NaN             NaN
# PPP2R3A           -0.472942                NaN             NaN
# MTARC2             0.462465                NaN       -0.368477
# SIPA1L3            0.459726                NaN       -0.339048
# CLIC2             -0.456175          -0.284262        0.349172
# CTSL              -0.455014          -0.297184        0.341089
# ABI3              -0.454118                NaN        0.295132
# CHDH               0.452909                NaN       -0.278932
# DOCK11            -0.451561                NaN        0.423667
# SVIL              -0.450803                NaN        0.229614
#
#             Correlation_LUAD  Correlation_HNSCC  Correlation_LSCC  Pos_Neg
# Comparison
# CTSC                0.282860                NaN               NaN     True
# SHC1                     NaN                NaN               NaN     True
# HSD17B11                 NaN                NaN               NaN     True
# CTSB                     NaN                NaN               NaN     True
# EPB41L3_3                NaN                NaN               NaN     True
# SCPEP1                   NaN                NaN               NaN     True
# DAB2                     NaN                NaN               NaN     True
# OSTF1                    NaN                NaN               NaN     True
# PLA2G15                  NaN                NaN               NaN     True
# SUB1                     NaN                NaN               NaN     True
# RIN2                0.323776           0.330241               NaN     True
# PPP2R3A             0.310082                NaN               NaN     True
# MTARC2                   NaN                NaN               NaN     True
# SIPA1L3                  NaN                NaN               NaN     True
# CLIC2                    NaN          -0.440518               NaN     True
# CTSL                     NaN                NaN               NaN     True
# ABI3                     NaN          -0.447131               NaN     True
# CHDH                     NaN          -0.357081               NaN     True
# DOCK11                   NaN                NaN               NaN     True
# SVIL                     NaN                NaN               NaN     True

# %%
def Pvalue_sig(row):
    numSig = 0

    for item in row:
        if pd.isnull(item):
            continue
        if item < 0.05:
            numSig += 1
            
    return numSig

# %%
df = FDR_corr_True.drop("Pos_Neg",axis = 1)
diff = df.max(axis=1) - df.min(axis = 1)
diff.sort_values(ascending = False).head(20)
# Out:
# Comparison
# CELSR1      1.085044
# ARHGAP10    1.055842
# RARA        1.014943
# CRYBG3      0.967890
# FAM89A      0.962051
# MRTFB       0.954529
# CA12        0.948078
# ARFGEF3     0.946863
# GLIPR2      0.944892
# LPIN1       0.942117
# CYRIA       0.938610
# JPT2        0.935680
# PLA2G4A     0.933300
# HSD17B11    0.927456
# CTNND2      0.921279
# PREX1       0.917569
# SLC9A3R1    0.911895
# DAB2        0.911117
# METTL26     0.900342
# MPP1        0.897000
# dtype: float64

# %%
abs_val = FDR_corr_True.abs()
abs_val.sum(1).sort_values(ascending = False).head(20)
# Out:
# Comparison
# CELSR1     2.811137
# PFKP       2.780631
# CRYBG1     2.757146
# FAM89A     2.682271
# TANC2      2.673555
# GMFG       2.669330
# UPP1       2.540427
# FERMT1     2.539596
# CA12       2.537178
# GPRC5C     2.535036
# CLIC2      2.530128
# JPT2       2.526792
# RBM47      2.504163
# SEMA4D     2.499493
# KBTBD11    2.455456
# CDK6       2.447587
# ARRB2      2.446843
# WIPF1      2.442668
# ITGB1      2.441911
# LCP1       2.440666
# dtype: float64

# %% [markdown]
# The manuscript mentions 945 of trans proteins that opposite effects in different cancers. Here is the derivation of that number

# %%
pos_neg_prot = FDR_corr_True.index.tolist()
pos_neg_prot
#print("Total number of trans proteins with opposite effects in different cancers is " + str(len(pos_neg_prot)))
# Out:
# ['CTSC',
#  'SHC1',
#  'HSD17B11',
#  'CTSB',
#  'EPB41L3_3',
#  'SCPEP1',
#  'DAB2',
#  'OSTF1',
#  'PLA2G15',
#  'SUB1',
#  'RIN2',
#  'PPP2R3A',
#  'MTARC2',
#  'SIPA1L3',
#  'CLIC2',
#  'CTSL',
#  'ABI3',
#  'CHDH',
#  'DOCK11',
#  'SVIL',
#  'GSTO1',
#  'FCGR2A',
#  'NIBAN2',
#  'TES',
#  'GBA',
#  'SNAPIN',
#  'COL1A2',
#  'COL1A1',
#  'PHLDB2',
#  'ALDH7A1',
#  'CTNND2',
#  'RAB3IL1',
#  'CDKN2C',
#  'COL6A3',
#  'TMEM87B',
#  'EML4',
#  'NPC2',
#  'ENG',
#  'STAMBPL1',
#  'EHBP1L1',
#  'APBB1IP',
#  'ITGB1',
#  'KYNU',
#  'PTER',
#  'TNS3',
#  'PCMTD2',
#  'RGS12',
#  'DOK3',
#  'VAMP8',
#  'FBN1',
#  'EMB',
#  'APC',
#  'ACSL1',
#  'FHOD1',
#  'OTULIN',
#  'CAPZA1',
#  'ARHGAP10',
#  'LIG4',
#  'FHL2',
#  'TNFAIP8L2',
#  'TWF2',
#  'TNFAIP8',
#  'LUZP1',
#  'FBXL17',
#  'GMFG',
#  'PLCG2',
#  'PPM1F',
#  'RALGAPB',
#  'SYK',
#  'WIPF1',
#  'IGKV3-20',
#  'DAPK3',
#  'SULF1',
#  'NOVA1',
#  'CTSS',
#  'DLGAP4',
#  'HCK',
#  'DNAJC21',
#  'CHST3',
#  'PAPSS2',
#  'LETM1',
#  'TPD52L2',
#  'MAP3K3',
#  'TUT7',
#  'DIAPH2',
#  'RASSF5',
#  'PLIN2',
#  'STAT6',
#  'SDR39U1',
#  'AMPD3',
#  'CDK6',
#  'LAIR1',
#  'MANBA',
#  'UAP1',
#  'ILK',
#  'CD14',
#  'PIK3AP1',
#  'EHD4',
#  'MYOF',
#  'DNMBP',
#  'MLKL',
#  'CTHRC1',
#  'ABI2',
#  'M6PR',
#  'KIF13A',
#  'NNT',
#  'CRTC1',
#  'ELP6',
#  'PFN1',
#  'IRF2BP1',
#  'PPFIBP1',
#  'RSU1',
#  'ARHGAP35',
#  'CD300A',
#  'HAAO',
#  'IGHV3-7',
#  'INPP4A',
#  'BDH1',
#  'CSF1R',
#  'UPP1',
#  'ACTR3',
#  'MVP',
#  'CD163',
#  'COL3A1',
#  'IL4I1',
#  'GIMAP8',
#  'NAP1L4',
#  'ERLIN1',
#  'CYTH4',
#  'SKAP2',
#  'LRRC25',
#  'RBM47',
#  'AOC3',
#  'CARD6',
#  'REL',
#  'CD40',
#  'ALDH1L1',
#  'MGAT1',
#  'EXD2',
#  'ERBIN',
#  'TBC1D2',
#  'FCGR3A',
#  'NUDT5',
#  'PLEKHO2',
#  'CRTAP',
#  'SALL2',
#  'DPYD',
#  'VCL',
#  'STING1',
#  'IGLV2-8',
#  'LRRFIP1_1',
#  'PROCR',
#  'PLAUR',
#  'C1QB',
#  'ZNF185_1',
#  'MYL6',
#  'TTC19',
#  'DUSP23',
#  'MAPK14',
#  'GPRC5C',
#  'LGMN',
#  'IKBIP_1',
#  'SRPX2',
#  'IGKV4-1',
#  'SH3GLB1_1',
#  'FLNB',
#  'MYO5C',
#  'TBC1D17',
#  'CRYBG1',
#  'CYP7B1',
#  'IGKV1-27',
#  'MXRA5',
#  'IGLV2-11',
#  'NRBF2',
#  'SLC2A5',
#  'TLE5',
#  'RASSF1',
#  'VASP',
#  'USP4',
#  'MACROH2A2',
#  'DGKA',
#  'PICALM',
#  'CD84',
#  'DOK2',
#  'LYAR',
#  'BICD2',
#  'TFPI',
#  'SH3KBP1_1',
#  'PTPN12',
#  'SEPTIN9_1',
#  'ACSL4',
#  'ACAD8',
#  'NDRG2',
#  'BORCS5',
#  'EEPD1',
#  'NEDD4',
#  'STARD13',
#  'IGKV3D-15',
#  'TLN1',
#  'CNNM4',
#  'SOGA1',
#  'TP53I3',
#  'PRRX1',
#  'STMN3',
#  'ANXA6_1',
#  'SIPA1',
#  'TCEA2',
#  'EPM2AIP1',
#  'SATB2',
#  'FETUB',
#  'LCP1',
#  'PTPRJ',
#  'BRIX1',
#  'SGCE',
#  'ALDH6A1',
#  'BTBD2',
#  'P4HA1_1',
#  'EVI2B',
#  'CDCA7L',
#  'CAV2',
#  'USP30',
#  'TGFB1',
#  'SHBG',
#  'G6PD',
#  'DBNL_1',
#  'ANKMY2',
#  'CUL2',
#  'LRATD2',
#  'ADI1',
#  'ELP4',
#  'POSTN',
#  'XPNPEP1',
#  'MRC1',
#  'CUTC',
#  'LRCH1',
#  'ARPC4',
#  'BCL10',
#  'FERMT3',
#  'CCDC71L',
#  'COL11A1',
#  'CAVIN3',
#  'CYP2S1',
#  'TLR2',
#  'SLFN5',
#  'TRIM24',
#  'COL12A1',
#  'PPP2R5E',
#  'RHBDF2',
#  'GC',
#  'FES',
#  'PSME4',
#  'FAM89A',
#  'UQCR10',
#  'ISLR',
#  'IPO11',
#  'HEPH',
#  'RIN3',
#  'GTF2F2',
#  'SH3BP1',
#  'UBASH3B',
#  'COL5A2',
#  'TSPAN14',
#  'ADGRE2',
#  'LARS2',
#  'IGF2R',
#  'DDR1',
#  'THBD',
#  'MRPS35',
#  'LAMP2_1',
#  'ECHDC1',
#  'CD109',
#  'MYL6_1',
#  'SOX10',
#  'IKBIP',
#  'FOXO1',
#  'PAFAH1B3',
#  'MKNK1',
#  'FN3K',
#  'IGKV3D-20',
#  'MFAP2',
#  'C1QC',
#  'CSTA',
#  'CES1',
#  'FAP',
#  'TANC2',
#  'TPM1_2',
#  'EARS2',
#  'DNASE1L1',
#  'EIF1AY',
#  'TBC1D8B',
#  'ERP44',
#  'PGM2',
#  'TTC39B',
#  'HDHD2',
#  'CD33',
#  'IDH2',
#  'FGB',
#  'LIMS1_1',
#  'SUGP2',
#  'SERPING1',
#  'CNN2',
#  'ZDHHC3',
#  'GUCY1A1',
#  'SLC25A20',
#  'NGLY1',
#  'IGLV1-51',
#  'ASPH',
#  'EEF1A2',
#  'GFPT2',
#  'GGCX',
#  'IGHV6-1',
#  'FNDC3B',
#  'TWF1',
#  'S100A11',
#  'MMS19',
#  'CP',
#  'HK3',
#  'ITGB5',
#  'CD248',
#  'SPTBN4',
#  'PITPNA',
#  'RASGRP2',
#  'PREX1',
#  'IFI16',
#  'SCCPDH',
#  'RPL14',
#  'PRPH',
#  'GPNMB',
#  'ANTXR2',
#  'A2M',
#  'ITGA3',
#  'RSL1D1',
#  'FYN',
#  'PIP4K2B',
#  'TMEM184C',
#  'ZNF776',
#  'CEMIP2',
#  'ABAT',
#  'LOXL2',
#  'RELB',
#  'NME4',
#  'B3GAT3',
#  'RPTOR',
#  'ARRB2',
#  'AKAP5',
#  'ASPSCR1',
#  'KIAA0930',
#  'RB1',
#  'HIBCH',
#  'PRR36',
#  'SLFN11',
#  'RPL7A',
#  'COL15A1',
#  'EIF2AK2',
#  'GNG7',
#  'AFAP1L2',
#  'PECAM1',
#  'DLAT',
#  'TRAF1',
#  'MST1',
#  'SERPINF2',
#  'NUMB',
#  'LRMP',
#  'RCN3',
#  'PI4KA',
#  'F13A1',
#  'LACC1',
#  'GOLM1',
#  'CLEC3B',
#  'PLEK',
#  'ZBTB20',
#  'NOC3L',
#  'XRCC1',
#  'ACAT1',
#  'TMEM63A',
#  'PACSIN1',
#  'PDIA5',
#  'FABP4',
#  'C8A',
#  'C1QA',
#  'SYN2',
#  'C9',
#  'DDX18',
#  'SLC9A3R2_1',
#  'PTGIS',
#  'ALDH5A1',
#  'MTIF3',
#  'ZNF24',
#  'VIM',
#  'N4BP1',
#  'PDLIM7',
#  'BECN1',
#  'ADAMTS2',
#  'SERPINA1',
#  'AMOTL1',
#  'RRP12',
#  'GSK3A',
#  'SHROOM3',
#  'F10',
#  'CREG1',
#  'PRXL2B',
#  'CAPZB_1',
#  'GAMT',
#  'FCGR2B',
#  'DMAC2L',
#  'GLRX3',
#  'BAG2',
#  'C6',
#  'CRYBG3',
#  'SLC12A2',
#  'P4HA2',
#  'A1BG',
#  'REXO2',
#  'PDHB',
#  'CERS2',
#  'JPT2',
#  'KIAA1671',
#  'TTC28',
#  'STARD5',
#  'PFKP',
#  'CFAP36',
#  'USP11',
#  'RHOB',
#  'CTPS2',
#  'EMC2',
#  'TNK1',
#  'NBEA',
#  'IFT88',
#  'OGA',
#  'CMIP',
#  'TBC1D10C',
#  'SNX18',
#  'KBTBD11',
#  'EPS15',
#  'RBKS',
#  'CYRIA',
#  'PFAS',
#  'KIFBP',
#  'EMC8',
#  'ALKBH5',
#  'MICALL1',
#  'GEMIN5',
#  'FBXO4',
#  'CELF2',
#  'IFT46',
#  'WWC1',
#  'ERBB3',
#  'MTCL1',
#  'TCEA3',
#  'TACC1',
#  'PDK1',
#  'WIPF2',
#  'PFKFB2_1',
#  'ARFGEF3',
#  'DCTPP1',
#  'MPI',
#  'DENND6A',
#  'ZC3HC1',
#  'LPIN1',
#  'CELSR1',
#  'PLEKHA2',
#  'NAGK',
#  'CCDC86',
#  'EIF4EBP1',
#  'CAMK1',
#  'GNG2',
#  'GLUL',
#  'CCDC9B',
#  'TBC1D9B',
#  'RUNX3',
#  'NECAP2',
#  'ADPRS',
#  'MBP',
#  'UNC119B',
#  'AKAP12',
#  'FAHD2A',
#  'ME1',
#  'GLIPR2',
#  'SEMA4D',
#  'CETN3',
#  'NPEPL1',
#  'ZNF516',
#  'CYB5R2',
#  'IPO4',
#  'PLA2G4A',
#  'HSD3B7',
#  'ENPEP',
#  'CRABP2',
#  'ADAL',
#  'FPGT',
#  'SOD2',
#  'KTN1',
#  'DHX36',
#  'ATG3',
#  'TTC26',
#  'TTC7B',
#  'INTS3',
#  'SYNE3',
#  'PAN2',
#  'TBCA',
#  'TIFA',
#  'OSCP1',
#  'PDCD6',
#  'PLCL2',
#  'ALDH1L2',
#  'BTBD8',
#  'DYNC2LI1',
#  'TMSB4X',
#  'IMPDH2',
#  'DCTD',
#  'HYI',
#  'IFT74',
#  'FOLR1',
#  'PTPN7',
#  'CLIC5',
#  'ASTN2',
#  'ADGRE5',
#  'METTL26',
#  'PPIP5K2',
#  'MARK3',
#  'MAP1B',
#  'TBL1X',
#  'BST2',
#  'NPEPPS',
#  'CETN2',
#  'CBR3',
#  'MMP2',
#  'IFT172',
#  'EPB41L2',
#  'HOOK1',
#  'WDR35',
#  'WARS1',
#  'LBH',
#  'S100A16',
#  'DNAL4',
#  'PARD6B',
#  'TTC39A',
#  'ADH1C',
#  'ABI1_1',
#  'CAMK4',
#  'TUBB2B',
#  'PHYKPL',
#  'VRK1',
#  'KCTD9',
#  'FMNL2',
#  'XPO4',
#  'ABCB1',
#  'SC5D',
#  'PDK4',
#  'HSPB1',
#  'UBXN2A',
#  'MAP7D1_1',
#  'PGD',
#  'ERGIC1',
#  'PREPL',
#  'NCF4',
#  'DIS3',
#  'RRP8',
#  'VDR',
#  'HSP90AA1',
#  'MIGA1',
#  'LRCH3',
#  'ASRGL1',
#  'FNBP1L',
#  'MBOAT2',
#  'FUT8',
#  'PTPN2',
#  'NLE1',
#  'CNKSR1',
#  'TMEM106B',
#  'ELOB',
#  'BLVRA',
#  'PAFAH1B1',
#  'CEP170B_1',
#  'RARA',
#  'SDC4',
#  'MID2',
#  'F12',
#  'KRI1',
#  'CRLF3',
#  'AMFR',
#  'GALNT10',
#  'IQSEC2',
#  'ELAC2',
#  'TSPAN13',
#  'ODR4',
#  'SLC30A9',
#  'SPAG1',
#  'DCAF5',
#  'MRTFB',
#  'SAMD12',
#  'CLDN3',
#  'IGLV3-1',
#  'ACAA2',
#  'DCTN1_2',
#  'KIT',
#  'DIS3L',
#  'ZNRF2',
#  'NCF1',
#  'GIPC2',
#  'WBP4',
#  'VEZT',
#  'GALNT6',
#  'ZSCAN18',
#  'PLA2G2A',
#  'CCDC50_1',
#  'DNAJB4',
#  'CHIT1',
#  'LPL',
#  'ALDH1A1',
#  'LCMT1',
#  'ARHGEF1_1',
#  'GSPT1',
#  'CCL21',
#  'ADH1A',
#  'AIFM2',
#  'PIGR',
#  'AHCYL1',
#  'FAAH',
#  'MLLT1',
#  'NCOA2',
#  'MDH1',
#  'ENO3',
#  'F9',
#  'GOLGA5',
#  'CHCHD10',
#  'AKAP9_1',
#  'DHX29',
#  'YIF1A',
#  'SNRK',
#  'IGLV3-27',
#  'DCTN5',
#  'TBC1D10B',
#  'ELOC',
#  'NID1',
#  'MTMR6',
#  'LAMA3_1',
#  'SRGN',
#  'TINAGL1',
#  'SRCIN1',
#  'MYCBP2',
#  'PEX1',
#  'EXOSC10',
#  'ACTR1A',
#  'SGTB',
#  'GCC1',
#  'AOX1',
#  'ANKRD50',
#  'ISG15',
#  'LMBRD2',
#  'GULP1',
#  'DCAF7',
#  'SPTBN1_1',
#  'AKR1C1',
#  'MYO6_1',
#  'ZMYM3',
#  'IGKV1-5',
#  'BPI',
#  'IGKV3-7',
#  'ITIH5',
#  'IGHD',
#  'VPS37C',
#  'PTPRF',
#  'LTBP1',
#  'ARFGEF1',
#  'CAMSAP3',
#  'EOGT',
#  'RASA1',
#  'CCDC88C',
#  'STAT5A',
#  'CLU',
#  'DEPTOR',
#  'MISP3',
#  'CD209',
#  'CEP170B',
#  'DCTN2_1',
#  'AVL9',
#  'NOS1AP',
#  'CA12',
#  'CAPRIN1',
#  'IGHV3-48',
#  'SCYL2',
#  'SLC39A9',
#  'RRM2B',
#  'PSTPIP1',
#  'CUX1_1',
#  'AIF1L',
#  'PDXDC1',
#  'TMC4',
#  'MSRA',
#  'CRTAC1',
#  'PLSCR3',
#  'ARMC9',
#  'SERPINB5',
#  'FERMT1',
#  'USP16',
#  'LAMA5',
#  'DNAAF5',
#  'LBP',
#  'FAM174A',
#  'SMIM29',
#  'PITPNB',
#  'COL4A1',
#  'TOP2B',
#  'C8G',
#  'APOA2',
#  'PAIP1_1',
#  'CARMIL2',
#  'CRLF1',
#  'AUTS2',
#  'IGLV1-40',
#  'MACO1',
#  'SULF2',
#  'CBL',
#  'BAG3',
#  'KRT19',
#  'CSNK1A1',
#  'IGKV1D-13',
#  'CHN1',
#  'ANP32E',
#  'VANGL1',
#  'SYTL1',
#  'CRYM',
#  'CCDC82',
#  'KIAA1522',
#  'KIF13A_1',
#  'CAND2',
#  'DLG5',
#  'ZNF385A',
#  'TUBA8',
#  'CTNND1_1',
#  'FKBP5',
#  'COMMD2',
#  'EED',
#  'MARK2_1',
#  'FABP7',
#  'CORO2A',
#  'S100A14',
#  'RNGTT',
#  'SLC9A3R1',
#  'SYF2',
#  'IGFBP2',
#  'BHLHE40',
#  'BCL3',
#  'LENG8',
#  'ITPRID2_1',
#  'RAB3D',
#  'PPP1R1B',
#  'DAPK1',
#  'GALNT7',
#  'KITLG',
#  'LNX2',
#  'NCOA7',
#  'SNTB1',
#  'PARN',
#  'PALM2AKAP2',
#  'COG5',
#  'ACSL5',
#  'COG7',
#  'C17orf75',
#  'VAV2',
#  'SLC39A6',
#  'CRNKL1',
#  'CPN2',
#  'KIF16B',
#  'TMOD1',
#  'ADD1',
#  'ARHGAP26',
#  'RASSF2',
#  'LYN',
#  'MAPRE2',
#  'APOB',
#  'GTF3C1',
#  'PDE2A',
#  'S100A4',
#  'DNAJC19',
#  'ADD3',
#  'IGF1R',
#  'MYO19',
#  'SPTAN1',
#  'CASP10',
#  'CHL1',
#  'TMEM181',
#  'ELP2',
#  'SCAMP1',
#  'MPP1',
#  'APOE',
#  'TSR3',
#  'SPTAN1_1',
#  'IGKC',
#  'CDK9',
#  'LILRB5',
#  'PID1',
#  'TMOD2',
#  'CRABP1',
#  'CCND1',
#  'IGHV3-38',
#  'HPGD',
#  'RPS6KA3',
#  'ANO1',
#  'ACADL',
#  'SH3BP4',
#  'GASK1B',
#  'PYGM',
#  'IGHG2',
#  'IGHV2-26',
#  'SOD3',
#  'ZEB2',
#  'SRPK2',
#  'MBOAT7',
#  'SHANK3',
#  'PRKCI',
#  'IGHG1',
#  'EIF4E2',
#  'IGHA1',
#  'IGHV3-73',
#  'ACSM3',
#  'STX11',
#  'COL6A6',
#  'DARS2',
#  'LYVE1',
#  'IGHV3-35',
#  'IGKV1-16',
#  'GYPA',
#  'HBQ1',
#  'IGHV4-28',
#  'RASIP1',
#  'SORBS2',
#  'MPEG1',
#  'IGLL1',
#  'MED23',
#  'KRT7',
#  'ADPRH',
#  'WDR11',
#  'FARP2',
#  'INTS1',
#  'IGLV1-47',
#  'LYN_1',
#  'TTI2',
#  'MEST',
#  'PLPP3',
#  'GTF3C3',
#  'MTREX',
#  'CCDC97',
#  'KCTD12',
#  'SERINC1',
#  'SPART',
#  'HSPB6',
#  'TCN2',
#  'IGHV3-15',
#  'TBCEL',
#  'CERS5',
#  'DHX15',
#  'ANKRD13A',
#  'GNPAT',
#  'SORBS1',
#  'RHBDD2',
#  'NAV1',
#  'CDC23',
#  'DPP4',
#  'CDC42BPB',
#  'GTF3C4',
#  'EXOC5',
#  'ITGA7_1',
#  'EIF4G1',
#  'TNS1',
#  'STXBP6',
#  'SASH1',
#  'INTS7',
#  'SORBS1_2',
#  'FBXO3',
#  'HEATR6',
#  'IGHA2',
#  'SRSF8',
#  'MGLL',
#  'CDH5',
#  'VPS37B',
#  'CCNK',
#  'PPFIA1',
#  'DENND1C',
#  'NUP188',
#  'SELL',
#  'PRKDC',
#  'TRMT5',
#  'LAMB2',
#  'PAG1',
#  'PRMT1',
#  'NUP37',
#  'IGHV3-64D',
#  'FGF2',
#  'CNOT1',
#  'LMOD1',
#  'UBR5',
#  'MICALL2',
#  'C12orf57',
#  'PPP1R12B',
#  'GRK3',
#  'RECQL5',
#  'DHX9',
#  'IGLV3-19',
#  'SLIT3',
#  'BRF1',
#  'LZTS2',
#  'TNPO2',
#  'POSTN_2',
#  'KIAA0753',
#  'MED7',
#  'JCHAIN',
#  'KIAA0319L',
#  'METTL7A',
#  'RFC3',
#  'TGFB3',
#  'MACF1_1',
#  'MGME1',
#  'NUP88',
#  'ABCA8',
#  'MYH11',
#  'CELF1',
#  'IGHV5-51',
#  'GPD1']

# %% [markdown]
# # Run GSEA

# %%
pos_neg_enr = gp.enrichr(gene_list = pos_neg_prot, description='Tumor_partition', gene_sets='Reactome_2016')
pos_neg_enr.res2d.head(10)
# Out:
#         Gene_set                                               Term   Overlap  \
# 0  Reactome_2016  Fcgamma receptor (FCGR) dependent phagocytosis...    23/120
# 1  Reactome_2016     Innate Immune System Homo sapiens R-HSA-168249    75/807
# 2  Reactome_2016  Platelet activation, signaling and aggregation...    35/253
# 3  Reactome_2016            Immune System Homo sapiens R-HSA-168256  119/1547
# 4  Reactome_2016         FCGR activation Homo sapiens R-HSA-2029481     14/49
# 5  Reactome_2016  Extracellular matrix organization Homo sapiens...    36/283
# 6  Reactome_2016  Binding and Uptake of Ligands by Scavenger Rec...     16/74
# 7  Reactome_2016      Collagen formation Homo sapiens R-HSA-1474290     17/85
# 8  Reactome_2016   Platelet degranulation Homo sapiens R-HSA-114608    19/105
# 9  Reactome_2016               Hemostasis Homo sapiens R-HSA-109582    53/552
#
#         P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0  5.116037e-09          0.000002            0                     0
# 1  5.116718e-09          0.000002            0                     0
# 2  5.957088e-09          0.000002            0                     0
# 3  1.509957e-08          0.000004            0                     0
# 4  2.579549e-08          0.000006            0                     0
# 5  3.363738e-08          0.000006            0                     0
# 6  1.929421e-07          0.000030            0                     0
# 7  2.667340e-07          0.000034            0                     0
# 8  2.816681e-07          0.000034            0                     0
# 9  3.541015e-07          0.000038            0                     0
#
#    Odds Ratio  Combined Score  \
# 0    5.017975       95.797590
# 1    2.224755       42.472249
# 2    3.421811       64.804598
# 3    1.836454       33.071972
# 4    8.408389      146.920330
# 5    3.105080       53.431061
# 6    5.804699       89.745737
# 7    5.263566       79.674671
# 8    4.657435       70.245932
# 9    2.276278       33.811111
#
#                                                Genes
# 0  LYN;ACTR3;HSP90AA1;AHCYL1;SYK;WIPF1;WIPF2;IGKV...
# 1  GSK3A;AHCYL1;WIPF1;WIPF2;ARRB2;C8A;CLU;FGF2;CT...
# 2  SERPINA1;SHC1;DGKA;PLEK;F13A1;A1BG;ARRB2;RASGR...
# 3  AHCYL1;NCF1;NUP188;WIPF1;WIPF2;NCF4;CLU;FGF2;N...
# 4  LYN;SYK;IGKV1-5;IGLV2-11;HCK;FCGR3A;IGHG1;IGHG...
# 5  DDR1;ITGB1;LAMA5;COL15A1;SDC4;ITGB5;COL11A1;CO...
# 6  HSP90AA1;CD163;IGKV1-5;IGLV2-11;COL1A1;COL3A1;...
# 7  COL15A1;CRTAP;COL11A1;COL12A1;CTSS;LOXL2;COL1A...
# 8  SRGN;FGB;TGFB1;SERPINA1;TGFB3;SERPINF2;PLEK;F1...
# 9  ITGB1;CD84;SERPINA1;DGKA;PLEK;F13A1;ARRB2;CLU;...

# %%
pos_neg_df = pos_neg_enr.res2d
fcgr = pos_neg_df.iloc[2,9]
fcgr = fcgr.split(';')

# %%
#get just the clotting cascade genes and add urokinase genes 
pos_neg_df = pos_neg_enr.res2d
coag = pos_neg_df.iloc[2,9]
coag = coag.split(';')
upa = ["F3","PLAUR","PLAU","PLG","MMP9","MMP12","SERPINE1"]
coag_upa =  coag + upa
len(coag_upa)

# %% [markdown]
# # Step 3 Make Data frame for Figure 4

# %%
#Get append version of the df with all cancer type, fdr sig trans results
df_FDR_append = pd.read_csv("csv_files/sig_prot_heatmap_EGFR.csv")
 
#coag_upa =  ["F2""F3","F9","F10","F11","F13A1","PLAUR","PLAU","PLG","MMP9","MMP12","SERPINE1"]
#subset dataframe to include genes only desired for figure 
df_FDR_append= df_FDR_append[df_FDR_append.Comparison.isin(fcgr)]
df_FDR_append
# Out:
#      Comparison  Correlation   P_Value Cancer
# 12         SHC1    -0.521169  0.000022    GBM
# 137     APBB1IP    -0.419095  0.001191    GBM
# 243       PLCG2    -0.390149  0.002829    GBM
# 248         SYK    -0.389025  0.002931    GBM
# 402        PFN1    -0.361363  0.006317    GBM
# ...         ...          ...       ...    ...
# 8633    PLA2G4A    -0.324576  0.013817  ccRCC
# 8733     TMSB4X    -0.310140  0.019902  ccRCC
# 8803      PLCG2    -0.302984  0.023092  ccRCC
# 8879        SYK    -0.293638  0.028987  ccRCC
# 9079      ARRB2    -0.272475  0.047724  ccRCC
#
# [89 rows x 4 columns]

# %% [markdown]
# Set add new column to be unique index and order the new index. This way genes will be grouped by coagulation factors, regulators, and urokinase genes.

# %%
df_FDR_append["Index"] = df_FDR_append["Comparison"] + " " + df_FDR_append["Cancer"]
'''
df_FDR_append = df_FDR_append.set_index("Index")
df_ordered = df_FDR_append.reindex(["F2 GBM","F3 GBM","F9 GBM","F10 GBM","F11 GBM","F13A1 GBM","F13B GBM","KLKB1 GBM","VWF CO","FGA GBM","FGB GBM","FGG GBM","SERPINC1 GBM", "SERPIND1 GBM","SERPING1 GBM","A2M GBM","PROS1 GBM","PROC OV","PROCR GBM","THBD GBM","KNG1 GBM","PLAUR GBM","PLAU GBM","PLG GBM","MMP9 BR","MMP12 BR","SERPINE1 GBM",
                                "F2 BR","F9 BR","F10 BR","F11 BR","F13A1 BR","F13B BR","FGA BR","FGB BR","FGG BR", "SERPIND1 BR","SERPING1 BR","A2M BR","PROS1 BR","PROCR BR","KLKB1 BR", "PLAUR BR","PLAU BR","PLG BR","SERPINE1 BR",
                               "VWF HNSCC","THBD HNSCC","PLAUR HNSCC","PLAU HNSCC","SERPINE1 HNSCC",
                               "F9 LUAD","F13A1 LUAD", "F13B LUAD", "SERPIND1 LUAD","PROS1 LUAD","PROC LUAD","VWF LUAD",
                                "PROCR ccRCC",
                                "SERPIND1 OV","PROC OV",
                               "F3 CO","SERPINC1 CO", "SERPIND1 CO","A2M CO","KNG1 CO","KLKB1 CO"])
'''
df_FDR_append
# Out:
#      Comparison  Correlation   P_Value Cancer          Index
# 12         SHC1    -0.521169  0.000022    GBM       SHC1 GBM
# 137     APBB1IP    -0.419095  0.001191    GBM    APBB1IP GBM
# 243       PLCG2    -0.390149  0.002829    GBM      PLCG2 GBM
# 248         SYK    -0.389025  0.002931    GBM        SYK GBM
# 402        PFN1    -0.361363  0.006317    GBM       PFN1 GBM
# ...         ...          ...       ...    ...            ...
# 8633    PLA2G4A    -0.324576  0.013817  ccRCC  PLA2G4A ccRCC
# 8733     TMSB4X    -0.310140  0.019902  ccRCC   TMSB4X ccRCC
# 8803      PLCG2    -0.302984  0.023092  ccRCC    PLCG2 ccRCC
# 8879        SYK    -0.293638  0.028987  ccRCC      SYK ccRCC
# 9079      ARRB2    -0.272475  0.047724  ccRCC    ARRB2 ccRCC
#
# [89 rows x 5 columns]

# %% [markdown]
# # Step 4: Plot Figure 4

# %%
legend_min = df_FDR_append["P_Value"].min()
#Make plot using plot utils
p.plotCircleHeatMap(df_FDR_append, circle_var = "P_Value",color_var = "Correlation", x_axis = "Comparison", y_axis = "Cancer", plot_width= 700, plot_height = 500, legend_min = legend_min, legend_max = 0.05, font_size = 10, show_legend = True)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1243">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="28ea52d8-36cf-4eda-8073-fffd6f2508f8" data-root-id="1244"></div>
# Figure(id='1191', ...)

# %% [markdown]
# # Check if blanks are due to no data

# %% [markdown]
# The follow code chunks show that the following cancers/genes don't have data: colon THBD, Kidney MMP12, and Ovarian MMP12. (As mentioned in EGFR Figure 2 legend)

# %%
#Get append version of the df with all proteins 
df_all_prot_append = pd.read_csv("Make_Tables/csv_files/all_prot_heatmap_EGFR.csv")
df_all_prot_append

# %%
#subset dataframe to include genes only desired for figure 
df_all_comp_coag = df_all_prot_append[df_all_prot_append.Comparison.isin(coag_upa)]
print("Number of rows in data frame " + str(len(df_all_comp_coag)))

# %% [markdown]
# Our figure includes 27 genes for 8 cancers. If all data was present there would be 216 rows. However, the data frame only has 212 rows. 4 genes are missing.

# %%
def find_missing_genes(test_list, full_list):
    for gene in full_list:
        if (gene not in test_list):
            print(gene)

# %%
#Get list of genes for colon, kidney, and ovarian
colon = df_all_prot_append[df_all_prot_append["Cancer"] == "CO"]
colon_list = colon.Comparison.to_list()

Kidney = df_all_prot_append[df_all_prot_append["Cancer"] == "ccRCC"]
Kidney_list = Kidney.Comparison.to_list()

Ovarian = df_all_prot_append[df_all_prot_append["Cancer"] == "OV"]
Ovarian_list = Ovarian.Comparison.to_list()

# %%
#Show the 3 missing genes 
print("Ovarian missing genes: ")
find_missing_genes(Ovarian_list, coag_upa)
print("Kidney missing genes: ")
find_missing_genes(Kidney_list, coag_upa)
print("Colon missing genes: ")
find_missing_genes(colon_list, coag_upa)
