# %% [markdown]
# Interacting Proteins

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re
import sys 

import cptac
import cptac.utils as u

import sys
sys.path.append('C:\\Users\\brittany henderson\\GitHub\\WhenMutationsDontMatter\\')
import plot_utils as p

# %%
gbm = cptac.Gbm()
endo = cptac.Endometrial()

# %%
ip = u.get_interacting_proteins('PTEN')
len(ip)
# Out:
# 28

# %%
cancer1 = "GBM"
cancer2 = "Endometrial"
gene = 'PTEN'

# %%
#GBM ttest
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot_and_mutations = gbm.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = ip)  

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
gbm_prot = list(mut_status.columns[:-1]) # new prot list without na in all tumor (sometimes values in normal)
mut_status
# Out:
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: PIK3R3 (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 4)
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 82 samples for the PTEN gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 4)
# Name       MDM2_proteomics  CSNK2A1_proteomics  PDGFRB_proteomics  \
# Sample_ID
# S001             -0.886531            0.221578          -0.108555
# S002                   NaN            0.169391          -0.109383
# S003                   NaN           -0.208625           0.414121
# S004             -0.564682           -0.292558          -0.141799
# S005             -0.243835            0.132716           0.812053
# ...                    ...                 ...                ...
# S100                   NaN           -0.015279           0.121787
# S101                   NaN            0.312023           0.361701
# S102              0.137052           -0.069012           0.606401
# S104                   NaN            0.276126          -0.108478
# S105                   NaN            0.154969          -0.228369
#
# Name       PIK3R2_proteomics  PIK3C3_proteomics  CSNK2A2_proteomics  \
# Sample_ID
# S001               -0.068085           0.081642           -0.273672
# S002                0.079710          -0.027524           -0.035616
# S003                0.078025           0.062739           -0.105403
# S004                0.024117           0.087752           -0.189861
# S005               -0.029297          -0.057555            0.239919
# ...                      ...                ...                 ...
# S100               -0.116620          -0.092783           -0.022308
# S101               -0.023912          -0.160911            0.266436
# S102                0.626821          -0.029083           -0.161898
# S104               -0.135303           0.173834            0.246281
# S105                0.186960          -0.073499            0.064866
#
# Name       SLC9A3R1_proteomics  USP13_proteomics  PIK3CA_proteomics  \
# Sample_ID
# S001                  0.616424         -0.423661           0.124542
# S002                  0.450206          0.155746          -0.211025
# S003                  0.307356         -0.021276          -0.573919
# S004                 -0.040643         -0.322976          -0.360962
# S005                 -0.155468         -0.049040           0.137414
# ...                        ...               ...                ...
# S100                  0.128944         -0.096330          -0.218186
# S101                 -1.291855          0.276721          -0.049803
# S102                  0.075817          0.091852           0.815177
# S104                  0.090879         -0.405654           0.143824
# S105                 -0.275365          0.252806           0.163076
#
# Name       TP53_proteomics  ...  PIK3CD_proteomics  ROCK1_proteomics  \
# Sample_ID                   ...
# S001              0.044573  ...          -0.315003         -0.319701
# S002              0.117856  ...          -0.629943          0.013908
# S003             -0.120887  ...           0.085276         -0.048311
# S004              1.832557  ...          -0.382652         -0.046639
# S005             -0.288708  ...          -0.537787          0.237764
# ...                    ...  ...                ...               ...
# S100             -0.343235  ...           0.395350          0.141372
# S101                   NaN  ...          -0.556546         -0.158482
# S102                   NaN  ...          -0.009546         -0.222781
# S104             -1.062906  ...          -0.255032         -0.256044
# S105                   NaN  ...           0.002891         -0.191965
#
# Name       SHC1_proteomics  NEDD4_proteomics  INPP4B_proteomics  \
# Sample_ID
# S001             -0.095985         -0.437514           0.060124
# S002              0.003049          0.179955          -0.639545
# S003              0.051279          0.265735           0.669283
# S004              0.288725          0.706601           0.451016
# S005             -0.337079          0.133808          -0.024038
# ...                    ...               ...                ...
# S100              0.557741          0.418850           0.010608
# S101             -0.282123          0.028673          -0.219639
# S102              0.061741          0.013211           0.348604
# S104             -0.240227         -0.209677           0.055190
# S105              0.123735          0.013306          -0.077057
#
# Name       PIK3R1_proteomics  AKT1_proteomics  MVP_proteomics  \
# Sample_ID
# S001               -0.379646        -0.065930        0.147936
# S002               -0.283144        -0.285929        0.371665
# S003                0.061201        -0.222607        0.329753
# S004               -0.496340        -0.370584       -0.518407
# S005               -0.146416         0.004573       -0.741119
# ...                      ...              ...             ...
# S100               -0.093624        -0.002002       -0.090315
# S101               -0.164426         0.501695       -0.994267
# S102                0.443719         0.196700        0.086260
# S104                0.084610        -0.198548       -0.012143
# S105               -0.166501        -0.055991       -0.740250
#
# Name       MAGI3_proteomics  binary_mutations
# Sample_ID
# S001               0.311427           Mutated
# S002               0.259059          Wildtype
# S003               0.128442           Mutated
# S004              -0.099551           Mutated
# S005              -0.017146          Wildtype
# ...                     ...               ...
# S100              -0.079546           Mutated
# S101              -0.364258          Wildtype
# S102               0.541898          Wildtype
# S104               0.260033          Wildtype
# S105              -0.134775          Wildtype
#
# [99 rows x 28 columns]

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

gbm_d = {}

for prot in gbm_prot:
    dif_gbm = mut_med[prot] - wt_med[prot]
    gbm_d[prot] = dif_gbm

gbm_df = pd.DataFrame.from_dict(gbm_d, orient='index', columns=['Gbm'])
gbm_df
# Out:
#                           Gbm
# MDM2_proteomics      0.187632
# CSNK2A1_proteomics  -0.030599
# PDGFRB_proteomics    0.076573
# PIK3R2_proteomics   -0.064189
# PIK3C3_proteomics   -0.025622
# CSNK2A2_proteomics  -0.081351
# SLC9A3R1_proteomics  0.071166
# USP13_proteomics    -0.037459
# PIK3CA_proteomics   -0.181610
# TP53_proteomics     -0.197015
# EGFR_proteomics      0.435094
# PIK3CB_proteomics   -0.074708
# PTK2_proteomics      0.007034
# USP7_proteomics     -0.079862
# XIAP_proteomics     -0.053186
# PTEN_proteomics     -0.396874
# PREX2_proteomics    -0.075445
# MAST2_proteomics     0.021543
# PIK3CD_proteomics   -0.102957
# ROCK1_proteomics     0.057412
# SHC1_proteomics      0.190225
# NEDD4_proteomics     0.058732
# INPP4B_proteomics   -0.003368
# PIK3R1_proteomics   -0.052673
# AKT1_proteomics      0.044326
# MVP_proteomics      -0.027570
# MAGI3_proteomics     0.010564

# %% [markdown]
# Endo

# %%
#Endo ttest
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot_and_mutations = endo.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = ip)  

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
en_prot = list(mut_status.columns[:-1])

mut_status
# Out:
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MDM2, PIK3R3 (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 4)
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 69 samples for the PTEN gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 4)
# Name       CSNK2A1_proteomics  PDGFRB_proteomics  PIK3R2_proteomics  \
# Sample_ID
# S001                  0.01510            -0.4940             0.0540
# S002                  0.04990            -0.5450             0.0165
# S003                 -0.28000             0.0143             0.0502
# S005                  0.06880            -0.1460             0.1380
# S006                  0.35000            -1.3400             0.0690
# ...                       ...                ...                ...
# S099                 -0.21200            -0.7660             0.1080
# S100                 -0.00398            -1.1200            -0.0944
# S101                 -0.07130            -0.7420            -0.1340
# S102                  0.28900            -0.8020            -0.4200
# S103                  0.08870             0.2880             0.1840
#
# Name       PIK3C3_proteomics  CSNK2A2_proteomics  SLC9A3R1_proteomics  \
# Sample_ID
# S001                -0.41600              0.2670                0.404
# S002                 0.01280              0.0528                1.380
# S003                -0.00815             -0.2410                0.659
# S005                -0.02940             -0.0641                0.735
# S006                 0.04510             -0.0431               -1.150
# ...                      ...                 ...                  ...
# S099                 0.36700             -0.2410                1.150
# S100                -0.28300              0.1530                0.027
# S101                 0.18900              0.1240                0.758
# S102                 0.28500              0.0649                0.207
# S103                 0.26800             -0.0830                0.595
#
# Name       USP13_proteomics  PIK3CA_proteomics  TP53_proteomics  \
# Sample_ID
# S001                -0.0543            -0.4500           0.2950
# S002                 0.0627            -0.2150           0.2770
# S003                -0.2780            -0.1780          -0.8710
# S005                -0.6070            -0.3920          -0.3430
# S006                -0.0664             0.2870           3.0100
# ...                     ...                ...              ...
# S099                 0.5140            -0.4860          -0.2570
# S100                 1.0900             0.0820           1.2000
# S101                -0.2650            -0.0312          -0.0333
# S102                -0.5340             0.1040           0.2920
# S103                 0.2470             0.6810           1.5100
#
# Name       EGFR_proteomics  ...  PIK3CD_proteomics  ROCK1_proteomics  \
# Sample_ID                   ...
# S001                 0.383  ...           -0.25200           -0.3670
# S002                -0.424  ...           -1.03000           -0.2730
# S003                 0.410  ...            0.45700            0.1800
# S005                 0.865  ...           -0.45600           -0.0574
# S006                -1.760  ...            0.00543           -0.1640
# ...                    ...  ...                ...               ...
# S099                -0.173  ...           -0.12900           -0.1760
# S100                -1.560  ...            0.20500           -0.3270
# S101                -0.597  ...            0.74600           -0.1740
# S102                -0.325  ...            0.69100            0.2800
# S103                -0.205  ...            0.58300            0.4740
#
# Name       SHC1_proteomics  NEDD4_proteomics  INPP4B_proteomics  \
# Sample_ID
# S001               -0.1250           -0.8590             -0.540
# S002               -0.6750           -1.3100             -0.988
# S003               -0.0194           -0.7620              1.320
# S005               -0.3780           -1.3000             -0.807
# S006                0.1030           -0.0684              0.201
# ...                    ...               ...                ...
# S099               -0.4970           -0.9740              0.152
# S100                0.8070           -0.4740              0.820
# S101               -0.1530           -0.8110             -0.224
# S102                0.2510            0.1600              0.296
# S103               -0.0868            0.4280             -0.129
#
# Name       PIK3R1_proteomics  AKT1_proteomics  MVP_proteomics  \
# Sample_ID
# S001                   0.481          -0.2550          -0.167
# S002                  -0.855           0.0453          -0.924
# S003                   0.266          -0.0722           0.273
# S005                  -0.135           0.0968           0.152
# S006                  -0.612          -0.6410           1.200
# ...                      ...              ...             ...
# S099                   0.218           0.0217          -0.707
# S100                   0.117           0.1720           0.396
# S101                  -0.333          -0.2300           0.310
# S102                  -0.446          -0.2150           1.820
# S103                   0.244           0.2330           0.186
#
# Name       MAGI3_proteomics  binary_mutations
# Sample_ID
# S001                -0.3070           Mutated
# S002                 0.3780           Mutated
# S003                 0.4150           Mutated
# S005                -0.1250           Mutated
# S006                -0.2160          Wildtype
# ...                     ...               ...
# S099                -0.0286           Mutated
# S100                 0.4750          Wildtype
# S101                 0.2760          Wildtype
# S102                 0.0052          Wildtype
# S103                -0.0173          Wildtype
#
# [95 rows x 27 columns]

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

en_d = {}

for prot in en_prot:
    dif_en = mut_med[prot] - wt_med[prot]
    en_d[prot] = dif_en

# %%
en_df = pd.DataFrame.from_dict(en_d, orient='index', columns=['Endo'])
en_df
# Out:
#                          Endo
# CSNK2A1_proteomics  -0.093110
# PDGFRB_proteomics    0.069500
# PIK3R2_proteomics    0.040800
# PIK3C3_proteomics   -0.044095
# CSNK2A2_proteomics  -0.127198
# SLC9A3R1_proteomics  0.404600
# USP13_proteomics    -0.005550
# PIK3CA_proteomics   -0.396000
# TP53_proteomics     -0.779800
# EGFR_proteomics      0.461500
# PIK3CB_proteomics    0.079315
# PTK2_proteomics     -0.016900
# USP7_proteomics      0.064550
# XIAP_proteomics      0.089150
# PTEN_proteomics     -0.545100
# PREX2_proteomics     0.498000
# MAST2_proteomics     0.041500
# PIK3CD_proteomics   -0.131850
# ROCK1_proteomics     0.016350
# SHC1_proteomics     -0.226550
# NEDD4_proteomics    -0.093500
# INPP4B_proteomics    0.206200
# PIK3R1_proteomics    0.295000
# AKT1_proteomics     -0.030500
# MVP_proteomics      -0.066500
# MAGI3_proteomics    -0.004210

# %% [markdown]
# Ovarian

# %%
ov = cptac.Ovarian()

# %%
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot_and_mutations = ov.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = ip) 
prot_and_mutations = ov.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
ov_prot = list(mut_status.columns[:-1])
# Out:
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MDM2, PIK3R3 (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 99 samples for the PTEN gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)
# cptac warning: Due to dropping the specified levels, dataframe now has 2 duplicated column headers. (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 4)

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

ov_dict = {}

for prot in ov_prot:
    delta_ov = mut_med[prot] - wt_med[prot]
    ov_dict[prot] = delta_ov

ov_df = pd.DataFrame.from_dict(ov_dict, orient='index', columns=['Ovarian'])
ov_df

#ov_df = ov_df.replace(to_replace = "NP_", value = '',regex= True)
#ov_df
# Out:
#                                                                Ovarian
# AKT1_proteomics                                              -0.334056
# CSNK2A1_proteomics                                           -0.187129
# CSNK2A2_proteomics                                           0.0283537
# EGFR_proteomics                                               0.106881
# INPP4B_proteomics                                             0.282097
# MAGI3_proteomics                                             -0.309116
# MAST2_proteomics                                              0.169835
# MVP_proteomics                                               0.0991483
# NEDD4_proteomics     NEDD4_proteomics    0.171027
# NEDD4_proteomics ...
# PDGFRB_proteomics                                            -0.134127
# PIK3C3_proteomics                                           -0.0229978
# PIK3CA_proteomics                                            0.0712056
# PIK3CB_proteomics                                             0.059846
# PIK3CD_proteomics                                              0.55994
# PIK3R1_proteomics                                             0.147344
# PIK3R2_proteomics                                             0.316172
# PREX2_proteomics                                              0.269105
# PTEN_proteomics                                              -0.121002
# PTK2_proteomics                                               0.191384
# ROCK1_proteomics                                             0.0561998
# SHC1_proteomics                                              0.0853117
# SLC9A3R1_proteomics                                         0.00500734
# TP53_proteomics                                              -0.095678
# USP13_proteomics                                             -0.110064
# USP7_proteomics                                               0.123103
# XIAP_proteomics                                              0.0113851

# %% [markdown]
# Breast

# %%
b = cptac.Brca()
# Out:
# Password: ········
# Wrong password. Try again: ········
# Wrong password. Try again: ········

# %% [markdown]
# No Somatic Mut in brca

# %%
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot = b.get_proteomics()
#prot = b.reduce_multiindex(prot, levels_to_drop = 1)
prot_list = list(prot.columns)
prot_and_mutations = b.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = prot_list) 
prot_and_mutations = b.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
b_prot = list(mut_status.columns[:-1])
# Out:
# cptac warning: Due to dropping the specified levels, dataframe now has 655 duplicated column headers. (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)
# ---------------------------------------------------------------------------
# DataframeNotIncludedError                 Traceback (most recent call last)
# <ipython-input-24-b05fd3e9e0bf> in <module>
#       4 prot_list = list(prot.columns)
#       5 prot_and_mutations = b.join_omics_to_mutations(
# ----> 6     mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = prot_list)
#       7 prot_and_mutations = b.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)
#       8
#
# ~\Anaconda3\envs\Research\lib\site-packages\cptac\dataset.py in join_omics_to_mutations(self, omics_df_name, mutations_genes, omics_genes, mutations_filter, show_location)
#     327         # Select the data from each dataframe
#     328         omics = self._get_omics_cols(omics_df_name, omics_genes)
# --> 329         mutations = self._get_genes_mutations(mutations_genes, mutations_filter)
#     330
#     331         mutations_were_filtered = mutations_filter is not None
#
# ~\Anaconda3\envs\Research\lib\site-packages\cptac\dataset.py in _get_genes_mutations(self, genes, mutations_filter)
#     630         pandas DataFrame: The mutations in each patient for the specified gene(s).
#     631         """
# --> 632         somatic_mutation = self.get_somatic_mutation()
#     633
#     634         # Process genes parameter
#
# ~\Anaconda3\envs\Research\lib\site-packages\cptac\dataset.py in get_somatic_mutation(self)
#     159     def get_somatic_mutation(self):
#     160         """Get the somatic_mutation dataframe."""
# --> 161         return self._get_dataframe("somatic_mutation")
#     162
#     163     def get_somatic_mutation_binary(self):
#
# ~\Anaconda3\envs\Research\lib\site-packages\cptac\dataset.py in _get_dataframe(self, name)
#     429             return return_df
#     430         else:
# --> 431             raise DataframeNotIncludedError("{} dataframe not included in this dataset.".format(name))
#     432
#     433     def _get_sample_status_map(self):
#
# DataframeNotIncludedError: somatic_mutation dataframe not included in this dataset.

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

b_dict = {}

for prot in b_prot:
    delta_b = mut_med[prot] - wt_med[prot]
    b_d[prot] = delta_b

b_df = pd.DataFrame.from_dict(gbm_d, orient='index', columns=['Breast'])
b_df

# %% [markdown]
# Colon

# %%
col = cptac.Colon()

# %%
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot_and_mutations = col.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = ip) 
#prot_and_mutations = col.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
col_prot = list(mut_status.columns[:-1])
# Out:
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MAGI3, MAST2, MDM2, PIK3R3, PREX2 (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 201 samples for the PTEN gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)
# cptac warning: proteomics data was not found for the following samples, so proteomics data columns were filled with NaN for these samples: S001, S013, S015, S017, S038, S080, S081, S090, S099, S109 (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

col_dict = {}

for prot in col_prot:
    delta_col = mut_med[prot] - wt_med[prot]
    col_dict[prot] = delta_col

col_df = pd.DataFrame.from_dict(col_dict, orient='index', columns=['Colon'])
col_df
# Out:
#                        Colon
# CSNK2A1_proteomics  -0.09475
# PDGFRB_proteomics   -0.07800
# PIK3R2_proteomics    0.05960
# PIK3C3_proteomics    0.19635
# CSNK2A2_proteomics   0.00835
# SLC9A3R1_proteomics -0.09150
# USP13_proteomics     0.03150
# PIK3CA_proteomics   -0.15480
# TP53_proteomics     -0.50300
# EGFR_proteomics     -0.08550
# PIK3CB_proteomics    0.21570
# PTK2_proteomics     -0.08625
# USP7_proteomics     -0.03975
# XIAP_proteomics     -0.16760
# PTEN_proteomics     -0.36100
# PIK3CD_proteomics    0.06260
# ROCK1_proteomics     0.11925
# SHC1_proteomics      0.19810
# NEDD4_proteomics    -0.15400
# INPP4B_proteomics   -0.46950
# PIK3R1_proteomics    0.18755
# AKT1_proteomics     -0.08970
# MVP_proteomics      -0.08880

# %% [markdown]
# Kidney

# %%
r = cptac.Ccrcc()

# %% [markdown]
# 189 / 194 samples missing mutation status.
# Only 5 mutations recorded.

# %%
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot_and_mutations = r.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = ip) 
prot_and_mutations = r.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
k_prot = list(mut_status.columns[:-1])
prot_and_mutations['PTEN_Mutation_Status'].value_counts()
# Out:
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: PIK3R3 (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 189 samples for the PTEN gene (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)
# Wildtype_Tumor       105
# Wildtype_Normal       84
# Single_mutation        4
# Multiple_mutation      1
# Name: PTEN_Mutation_Status, dtype: int64

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

k_dict = {}

for prot in k_prot:
    delta_k = mut_med[prot] - wt_med[prot]
    k_dict[prot] = delta_k

k_df = pd.DataFrame.from_dict(k_dict, orient='index', columns=['Kidney'])
k_df
# Out:
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\numpy\lib\nanfunctions.py:1076: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
#                        Kidney
# AKT1_proteomics     -0.016091
# CSNK2A1_proteomics  -0.028320
# CSNK2A2_proteomics  -0.045960
# EGFR_proteomics      0.146783
# INPP4B_proteomics   -0.050288
# MAGI3_proteomics     0.211432
# MAST2_proteomics     0.089637
# MDM2_proteomics           NaN
# MVP_proteomics      -0.123192
# NEDD4_proteomics    -0.321282
# PDGFRB_proteomics   -0.256534
# PIK3C3_proteomics   -0.011575
# PIK3CA_proteomics   -0.065119
# PIK3CB_proteomics    0.025018
# PIK3CD_proteomics   -0.098004
# PIK3R1_proteomics    0.212820
# PIK3R2_proteomics    0.128528
# PREX2_proteomics    -0.330395
# PTEN_proteomics     -0.307498
# PTK2_proteomics           NaN
# ROCK1_proteomics    -0.024704
# SHC1_proteomics           NaN
# SLC9A3R1_proteomics -0.183116
# TP53_proteomics     -0.159571
# USP13_proteomics    -0.142806
# USP7_proteomics      0.132559
# XIAP_proteomics      0.023484

# %% [markdown]
# Lung - no mutations data

# %%
l = cptac.Luad()

# %%
l.list_data()
# Out:
# Below are the dataframes contained in this dataset:
# 	circular_RNA
# 		Dimensions: (213, 371843)
# 	clinical
# 		Dimensions: (215, 17)
# 	CNV
# 		Dimensions: (110, 19267)
# 	derived_molecular
# 		Dimensions: (215, 28)
# 	experimental_design
# 		Dimensions: (215, 3)
# 	phosphoproteomics
# 		Dimensions: (213, 40868)
# 	proteomics
# 		Dimensions: (213, 10544)
# 	transcriptomics
# 		Dimensions: (213, 18099)

# %%
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot = l.get_proteomics()
prot_list = list(prot.columns)
prot_and_mutations = l.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = prot_list) 
prot_and_mutations = l.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
k_prot = list(mut_status.columns[:-1])

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

gbm_d = {}

for prot in gbm_prot:
    dif_gbm = mut_med[prot] - wt_med[prot]
    gbm_d[prot] = dif_gbm

gbm_df = pd.DataFrame.from_dict(gbm_d, orient='index', columns=['Gbm'])
gbm_df

# %% [markdown]
# Head and Neck

# %%
h = cptac.Hnscc()

# %%
n = h.get_somatic_mutation()
n.loc[n['Gene'] == 'PTEN']
# Out:
# Empty DataFrame
# Columns: [Gene, Mutation, Location]
# Index: []

# %%
# Step 1 - Create dataframe in order to do comparisons with wrap_ttest
prot_and_mutations = h.join_omics_to_mutations(
    mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = ip) 
#prot_and_mutations = r.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)

# Step 2 - Create binary column 
prot_and_mutations['binary_mutations'] = np.where(
            prot_and_mutations[gene+'_Mutation_Status'] == 'Wildtype_Tumor', 'Wildtype', 'Mutated')

# Step 3 - Format the dataframe correctly for the T-test(just omics and binary columns for tumors)
tumors = prot_and_mutations[prot_and_mutations.Sample_Status == 'Tumor'] #drop Normal samples
columns_to_drop = [gene+"_Mutation", gene+"_Location", gene+"_Mutation_Status", "Sample_Status"]
mut_status = tumors.drop(columns_to_drop, axis = 1)
mut_status = mut_status.dropna(axis=1,how='all')
h_prot = list(mut_status.columns[:-1])
prot
# Out:
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MAST2, MDM2, PIK3R3, PREX2 (C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\ipykernel_launcher.py, line 3)
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# <ipython-input-97-994add5cf885> in <module>
#       1 # Step 1 - Create dataframe in order to do comparisons with wrap_ttest
#       2 prot_and_mutations = h.join_omics_to_mutations(
# ----> 3     mutations_genes = [gene], omics_df_name = 'proteomics', omics_genes = ip)
#       4 #prot_and_mutations = r.reduce_multiindex(prot_and_mutations, levels_to_drop = 1)
#       5
#
# ~\Anaconda3\envs\Research\lib\site-packages\cptac\dataset.py in join_omics_to_mutations(self, omics_df_name, mutations_genes, omics_genes, mutations_filter, show_location)
#     327         # Select the data from each dataframe
#     328         omics = self._get_omics_cols(omics_df_name, omics_genes)
# --> 329         mutations = self._get_genes_mutations(mutations_genes, mutations_filter)
#     330
#     331         mutations_were_filtered = mutations_filter is not None
#
# ~\Anaconda3\envs\Research\lib\site-packages\cptac\dataset.py in _get_genes_mutations(self, genes, mutations_filter)
#     659             gene_mutations = somatic_mutation[somatic_mutation[gene_col] == gene] # Get all the mutations for that gene
#     660             if len(gene_mutations) == 0: # If the gene doesn't match any genes in the dataframe, tell them
# --> 661                 raise InvalidParameterError("{} gene not found in somatic_mutation data.".format(gene))
#     662             gene_mutations = gene_mutations.drop(columns=[gene_col]) # Gene column is same for every sample, so we don't need it anymore.
#     663
#
# InvalidParameterError: PTEN gene not found in somatic_mutation data.

# %%
mut_df = mut_status.loc[mut_status['binary_mutations'] == 'Mutated']
wt_df = mut_status.loc[mut_status['binary_mutations'] == 'Wildtype']

mut_med = mut_df.median()
wt_med = wt_df.median()

h_dict = {}

for prot in h_prot:
    dif_h = mut_med[prot] - wt_med[prot]
    h_dict[prot] = dif_h

h_df = pd.DataFrame.from_dict(h_dict, orient='index', columns=['Hnscc'])
h_df
# Out:
#                            Hnscc
# A1BG_proteomics    185250.093800
# A1CF_proteomics              NaN
# A2M_proteomics     987646.879885
# A2ML1_proteomics    28202.921920
# AAAS_proteomics      5268.292970
# ...                          ...
# ZW10_proteomics    482515.375000
# ZWILCH_proteomics            NaN
# ZYG11B_proteomics            NaN
# ZYX_proteomics     303690.375000
# ZZEF1_proteomics    12335.336915
#
# [8169 rows x 1 columns]

# %% [markdown]
# Combine

# %%
# Breast and Lung no mutations dataframe
# HN - PTEN not found in mutation data

n = gbm_df.join(en_df)
m = n.join(ov_df)
o = m.join(col_df)
l = o.join(k_df)

p = l.transpose()
ip_df = p.dropna(axis = 1,thresh=4)
ip_df = ip_df.drop('NEDD4_proteomics', axis = 1) # fix -2 values for ov
#ip_df = ip_df.reset_index()
#ip_df = ip_df.rename(columns = {'index':'Cancer'})
ip_df.index.name = 'Cancer'
ip_df
# Out:
#         CSNK2A1_proteomics PDGFRB_proteomics PIK3R2_proteomics  \
# Cancer
# Gbm             -0.0305989         0.0765728        -0.0641894
# Endo              -0.09311            0.0695            0.0408
# Ovarian          -0.187129         -0.134127          0.316172
# Colon             -0.09475            -0.078            0.0596
# Kidney          -0.0283196         -0.256534          0.128528
#
#         PIK3C3_proteomics CSNK2A2_proteomics SLC9A3R1_proteomics  \
# Cancer
# Gbm             -0.025622         -0.0813515           0.0711665
# Endo            -0.044095          -0.127198              0.4046
# Ovarian        -0.0229978          0.0283537          0.00500734
# Colon             0.19635            0.00835             -0.0915
# Kidney         -0.0115752         -0.0459595           -0.183116
#
#         USP13_proteomics PIK3CA_proteomics TP53_proteomics EGFR_proteomics  \
# Cancer
# Gbm            -0.037459          -0.18161       -0.197015        0.435094
# Endo            -0.00555            -0.396         -0.7798          0.4615
# Ovarian        -0.110064         0.0712056       -0.095678        0.106881
# Colon             0.0315           -0.1548          -0.503         -0.0855
# Kidney         -0.142806        -0.0651189       -0.159571        0.146783
#
#          ... PREX2_proteomics MAST2_proteomics PIK3CD_proteomics  \
# Cancer   ...
# Gbm      ...       -0.0754449        0.0215432         -0.102957
# Endo     ...            0.498           0.0415          -0.13185
# Ovarian  ...         0.269105         0.169835           0.55994
# Colon    ...              NaN              NaN            0.0626
# Kidney   ...        -0.330395        0.0896375        -0.0980044
#
#         ROCK1_proteomics SHC1_proteomics INPP4B_proteomics PIK3R1_proteomics  \
# Cancer
# Gbm             0.057412        0.190225       -0.00336814        -0.0526728
# Endo             0.01635        -0.22655            0.2062             0.295
# Ovarian        0.0561998       0.0853117          0.282097          0.147344
# Colon            0.11925          0.1981           -0.4695           0.18755
# Kidney         -0.024704             NaN        -0.0502878           0.21282
#
#         AKT1_proteomics MVP_proteomics MAGI3_proteomics
# Cancer
# Gbm           0.0443257     -0.0275698        0.0105644
# Endo            -0.0305        -0.0665         -0.00421
# Ovarian       -0.334056      0.0991483        -0.309116
# Colon           -0.0897        -0.0888              NaN
# Kidney       -0.0160906      -0.123192         0.211432
#
# [5 rows x 25 columns]

# %%
ip_df.to_csv('interacting_directionality.csv')

# %%
h = pd.read_csv('interacting_directionality.csv')

# %%
h
# Out:
#     Cancer  CSNK2A1_proteomics  PDGFRB_proteomics  PIK3R2_proteomics  \
# 0      Gbm           -0.030599           0.076573          -0.064189
# 1     Endo           -0.093110           0.069500           0.040800
# 2  Ovarian           -0.187129          -0.134127           0.316172
# 3    Colon           -0.094750          -0.078000           0.059600
# 4   Kidney           -0.028320          -0.256534           0.128528
#
#    PIK3C3_proteomics  CSNK2A2_proteomics  SLC9A3R1_proteomics  \
# 0          -0.025622           -0.081351             0.071166
# 1          -0.044095           -0.127198             0.404600
# 2          -0.022998            0.028354             0.005007
# 3           0.196350            0.008350            -0.091500
# 4          -0.011575           -0.045960            -0.183116
#
#    USP13_proteomics  PIK3CA_proteomics  TP53_proteomics  ...  \
# 0         -0.037459          -0.181610        -0.197015  ...
# 1         -0.005550          -0.396000        -0.779800  ...
# 2         -0.110064           0.071206        -0.095678  ...
# 3          0.031500          -0.154800        -0.503000  ...
# 4         -0.142806          -0.065119        -0.159571  ...
#
#    PREX2_proteomics  MAST2_proteomics  PIK3CD_proteomics  ROCK1_proteomics  \
# 0         -0.075445          0.021543          -0.102957          0.057412
# 1          0.498000          0.041500          -0.131850          0.016350
# 2          0.269105          0.169835           0.559940          0.056200
# 3               NaN               NaN           0.062600          0.119250
# 4         -0.330395          0.089637          -0.098004         -0.024704
#
#    SHC1_proteomics  INPP4B_proteomics  PIK3R1_proteomics  AKT1_proteomics  \
# 0         0.190225          -0.003368          -0.052673         0.044326
# 1        -0.226550           0.206200           0.295000        -0.030500
# 2         0.085312           0.282097           0.147344        -0.334056
# 3         0.198100          -0.469500           0.187550        -0.089700
# 4              NaN          -0.050288           0.212820        -0.016091
#
#    MVP_proteomics  MAGI3_proteomics
# 0       -0.027570          0.010564
# 1       -0.066500         -0.004210
# 2        0.099148         -0.309116
# 3       -0.088800               NaN
# 4       -0.123192          0.211432
#
# [5 rows x 26 columns]

# %%
stdev = ip_df.std()

# %%
stdev = stdev.to_frame()

# %%
stdev.loc[stdev[0] > .2]
# Out:
#                             0
# SLC9A3R1_proteomics  0.224830
# TP53_proteomics      0.288288
# EGFR_proteomics      0.232285
# PREX2_proteomics     0.366354
# PIK3CD_proteomics    0.290797
# INPP4B_proteomics    0.293609
# MAGI3_proteomics     0.214709

# %%
d_stdev = stdev.std()
d_stdev
# Out:
# 0    0.086052
# dtype: float64

# %%
a = stdev.hist(bins = 20)
plt.title("Standard Deviation Distribution for Pancancer PTEN Mutation Effect on Interacting Proteins\n")
plt.xlabel('StDeV')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.rcParams['figure.figsize']=(10,8)
sns.set(font_scale = 1.3)
a = sns.distplot(stdev, bins = 20)

a.set_title("Standard Deviation Distribution for Pancancer PTEN Mutation Effect on Proteomics\n\n (Median of proteomics with Wildtype PTEN - Median of proteomics with Mutated PTEN)")
a.set(xlabel = 'StDeV', ylabel = 'Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'StDeV')]

# %% [markdown]
# Mean

# %%
mean_df = stdev.mean()

# %%
a = mean_df.hist(bins = 20)
plt.title("Distribution of the Mean between Cancers for PTEN Mutation Effect on all Proteins\n\n (Median of proteomics with Wildtype PTEN - Median of proteomics with Mutated PTEN)")
plt.xlabel('Mean')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
m_df = stdev.median()

# %%
a = m_df.hist(bins = 20)
plt.title("Distribution of the Medians between Cancers for PTEN Mutation Effect on all Proteins\n\n (Median of proteomics with Wildtype PTEN - Median of proteomics with Mutated PTEN)")
plt.xlabel('Median')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
