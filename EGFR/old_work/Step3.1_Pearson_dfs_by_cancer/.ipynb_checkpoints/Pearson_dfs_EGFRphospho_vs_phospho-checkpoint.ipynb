# %% [markdown]
# # Pan Cancer EGFR

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest
#sys.path.append('C:\\Users\\brittany\\henderson\\GitHub\\GBM_for_CPTAC\\')
#import cis_functions as f
#sys.path.append(R'C:\Users\Lindsey\Documents\GitHub\WhenMutationsDontMatter\\')
#import plot_utils as p


import cptac
import cptac.utils as u
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
'''
@Param df: Dataframe. Contains numeric values (such as proteomics) for linear regression
@Param label_column: String. Name of column that will be your x axis and will be compared to all values in df unless otherwise specified. 
@Param alpha: significant level
@Param comparison_columns: columns that will be looped through and used as y axis for linear regression. 
All other columns beside label column unless specified here. 
@Param correction_method: String. Specifies method of adjustment for multiple testing. See -
https://www.statsmodels.org/stable/generated/statsmodels.stats.multitest.multipletests.html
    - for documentation and available methods.

This function will return a data frame will all significant linear regressions. The data frame includes the comparison, slope, R-squared, and P-value. 
'''
def wrap_lin_regression(df,label_column, alpha=.05,comparison_columns=None,correction_method='bonferroni',return_all = True):
    

    #df = df.dropna(axis=1, how="all")
    
    '''If no comparison columns specified, use all columns except the specified labed column'''
    if not comparison_columns:
        comparison_columns = list(df.columns)
        comparison_columns.remove(label_column)
    '''Store comparisons,p-values, correlation in their own array'''
    comparisons = []
    pvals = []
    correlation=[]
    
    
    '''Format results in a pandas dataframe'''
    newdf = pd.DataFrame(columns=['Comparison','Correlation','P_value'])
    for inter_gene in comparison_columns:
        #create subset df with interacting gene/ gene (otherwise drop NaN drops everything)
        df_subset = df[[label_column,inter_gene]]
        #do a linear regression to see if it's a meaningful association
        #dropna will remove rows with nan
        df_subset = df_subset.dropna(axis=0, how="any")
        count_row = df_subset.shape[0]
        if count_row > 20:
            x1 = df_subset[[label_column]].values
            y1 = df_subset[[inter_gene]].values
            x1 = x1[:,0]
            y1 = y1[:,0]

            #slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x1,y1)
            corr, pval = scipy.stats.pearsonr(x1,y1)

            comparisons.append(inter_gene)
            pvals.append(pval)
            correlation.append(corr)
            #slope_val.append(slope)
        
    '''Correct for multiple testing to determine if each comparison meets the new cutoff'''
    results = statsmodels.stats.multitest.multipletests(pvals=pvals, alpha=alpha, method=correction_method)
    reject = results[0]
        
    if return_all:
        for i in range(0,len(comparisons)):
            newdf = newdf.append({'Comparison': comparisons[i],"Correlation": correlation[i],'P_value': pvals[i]}, ignore_index=True)
        
    '''Else only add significant comparisons'''
    if (return_all == False):
            for i in range(0, len(reject)):
                if reject[i]:
                    newdf = newdf.append({'Comparison': comparisons[i],"Slope": slope_val[i], 'R_squared': r_squared[i], 'P_value': pvals[i]}, ignore_index=True)
                    
    '''Sort dataframe by ascending p-value'''
    newdf = newdf.sort_values(by='P_value', ascending=True)
    '''If results df is not empty, return it, else return None'''
    return newdf

# %%
interacting_genes = ['CD81', 'CLEC4G', 'NFKBIA', 'MAPK1', 'FOXC1', 'FHIT', 'RAPGEF1', 'SP1', 'MAG', 'ADH7', 'PIP5K2C', 'TMSB4X', 'COL6A3', 'CRK', 'SLC39A6', 'TGFBR2', 'ELK4', 'PRKCD', 'PLD2', 'EPS15', 'GNG11', 'RASSF5', 'GPX2', 'TEAD4', 'ENC1', 'SLC5A3', 'PIK3C2G', 'NOX4', 'CSPG4', 'COMP', 'IL10RB', 'TSC2', 'LBR', 'GSK3B', 'COL4A1', 'CDK2', 'SLC6A9', 'PIK3CA', 'CACNG3', 'CYP2C19', 'BCAN', 'PPP1R12C', 'PIK3CG', 'VCL', 'VTN', 'ACADM', 'COL11A2', 'TCF7L2', 'HSPA8', 'TYRO3', 'AMIGO2', 'IFNA7', 'SFRP1', 'IL1A', 'GNAI2', 'HAVCR1', 'PRKD1', 'SLC2A5', 'CACNB4', 'PRKD2', 'NR3C1', 'ALK', 'ICAM2', 'G6PC3', 'SQSTM1', 'CREB5', 'ITGA5', 'JUNB', 'CHRM2', 'NTF4', 'PLA2G4E', 'SLC39A8', 'TGFB2', 'MYL7', 'CDH3', 'IFNGR1', 'CES2', 'SKP1', 'PLA1A', 'LDHA', 'STAT5', 'MAPT', 'SLC39A9', 'IL6', 'SLC5A8', 'IFNG', 'SLC39A13', 'MAP4K3', 'PPP2R1B', 'ITGAE', 'HDC', 'PLA2G4A', 'FOXM1', 'HLA-DOA', 'SEMA6A', 'IRS4', 'PLCE1', 'APC2', 'CTNNA2', 'NOTCH3', 'CDK6', 'ANGPT1', 'GRB10', 'LRP6', 'NFKB1', 'EDN2', 'UGT1A4', 'LAMTOR3', 'LAMB3', 'PLTP', 'IKKA', 'APOA2', 'TNFSF13B', 'TOP1', 'THBS3', 'FZD5', 'RPS6KA5', 'RPS6KB2', 'TEK', 'HSPA6', 'PLCB3', 'BCL2L11', 'MYL9', 'COL9A2', 'PSAT1', 'NOTCH4', 'TEAD2', 'SGK3', 'RGMA', 'HLA-F', 'IFNLR1', 'SLC6A3', 'NFATC1', 'EFNA1', 'CRABP1', 'PLA2G16', 'HIF3A', 'CACNB2', 'WNT5A', 'IL10RA', 'PRLR', 'IL11RA', 'MYH10', 'ARRB2', 'RAC2', 'FLNB', 'MAPK6', 'SMAD2', 'CBR1', 'MKNK2', 'PIK3R2', 'TSC1', 'CALML6', 'PPP3R2', 'TPM3', 'CEBPB', 'PFKL', 'CDH18', 'C1QB', 'DVL3', 'ITGA6', 'FGD1', 'ROS', 'HEY1', 'ZAP70', 'PFKFB1', 'PPP2R2B', 'BCL2L1', 'PIK3C2A', 'ACTG1', 'MYLPF', 'KLK15', 'LAMB4', 'CTSB', 'AJUBA', 'SLC39A4', 'TXN', 'DBI', 'RALA', 'HLA-DRA', 'TTC9', 'CSF2RA', 'COL1A2', 'CASP3', 'WNT3', 'CSF2RB', 'IFNAR2', 'SLIT2', 'ENPP3', 'JAG1', 'CUL1', 'FAM91A1', 'GNGT1', 'NFKB2', 'UGT2B4', 'CFL2', 'CDH17', 'BCL2', 'SGK2', 'SRMS', 'TIE1', 'VPS16', 'PIP5K1B', 'SLC5A12', 'GATA4', 'RALGDS', 'C3orf10', 'RASGRP2', 'TNXB', 'LAMB2', 'HLA-A', 'CPT2', 'LAMC1', 'COL5A2', 'CXCL10', 'NOG', 'CSF1R', 'CDH4', 'IL11', 'ABCG5', 'ITGAL', 'PRKCG', 'HNF1A', 'RALB', 'JAK1', 'AKT1S1', 'HLA-DQA2', 'CSF3R', 'MDM4', 'MGST3', 'ADAM17', 'GCLC', 'PPP2CB', 'IKBKG', 'USF', 'FGF23', 'ABCC4', 'ITGB7', 'RFC4', 'TCL1B', 'SLC6A17', 'PRKAA2', 'ANG3', 'LPAR6', 'NTRK2', 'FOXC2', 'PPP2R5E', 'SYNGAP1', 'SOS1', 'IFNAR1', 'IL21R', 'TGFB3', 'WAS', 'GSTM5', 'PTPN7', 'APOC3', 'AQP1', 'IL27RA', 'CACNG5', 'CASP8', 'ELK1', 'DLL4', 'JAK3', 'ACOX1', 'PARVB', 'GJA1', 'PRB1', 'MAP2K6', 'THBS1', 'FOXO3', 'RGL2', 'CCKBR', 'S100P', 'IFNA10', 'SLC5A4', 'WNT3A', 'ARHGEF28', 'GNG2', 'CDH15', 'IFNA13', 'SOS2', 'JMJD7-PLA2G4B', 'BRAP', 'GPAM', 'RAP1A', 'HLA-DMA', 'PPM1B', 'NFATC3', 'GNA13', 'PRKAR2B', 'PPP1R14A', 'SLC5A7', 'C1QBP', 'GYS1', 'PLOD2', 'WASF1', 'ABCC5', 'HLA-DRB1', 'RASGRP3', 'G6PC2', 'VEGFC', 'HLA-G', 'EPOR', 'SMARCA1', 'COL9A1', 'CYP7A1', 'CBL', 'GSN', 'UGT2B7', 'PCK1', 'CACNA1B', 'EPHA4', 'CXCL8', 'PELO', 'PGK2', 'CD209', 'FGF17', 'GNG7', 'HSPA1L', 'ITGAV', 'TNFRSF1A', 'FN1', 'CHRM5', 'NOS1', 'CACNG4', 'MAPK7', 'PRKAR2A', 'CTNNA1', 'STK4', 'PLA2G12B', 'ACTR2', 'RICTOR', 'NOTCH1', 'CLDN1', 'EHHADH', 'BHLHE41', 'CYP1A2', 'S100A6', 'FTL', 'SMC1A', 'PLCG1', 'LRRC8A', 'ERK2', 'CREB3L1', 'SMAD3', 'RAC3', 'EPB41L4B', 'BDKRB2', 'EGR1', 'VPS11', 'SLC2A2', 'SLC9A1', 'FZD10', 'PRKAR1B', 'KAT5', 'ITGA3', 'CCNE1', 'SLC6A8', 'MAPK11', 'PPP2R1A', 'REL', 'DUSP1', 'HEYL', 'PRKCH', 'RTN4R', 'COL4A2', 'FAS', 'ERBB2', 'DIAPH1', 'RAB7A', 'DUSP3', 'MAPKAPK3', 'CAV1', 'CUL4A', 'AIP', 'BCR', 'WASF2', 'NRG1', 'ITGA1', 'BMP4', 'CYCS', 'SNAI2', 'BRIX1', 'PDYN', 'ARHGEF4', 'CACNA1I', 'RAPGEF5', 'CACNA2D4', 'VCAN', 'PPP2CA', 'RAD51', 'CACNA2D3', 'RXRB', 'GNG3', 'CALML5', 'CAB39', 'MAPK14', 'GSTA2', 'ITGA9', 'MMP2', 'F2', 'KITLG', 'FIGF', 'RASGRP4', 'VPS33A', 'ARNT', 'MAPK15', 'WNT7B', 'MSN', 'VAV2', 'CDH11', 'PGD', 'COL4A5', 'DNER', 'CD48', 'PPP5C', 'IL3', 'PARP1', 'EFNA2', 'PLA2G10', 'PRDX1', 'PARVG', 'OMG', 'EFNA5', 'UPK3A', 'PPP2R3B', 'APEX1', 'GPR153', 'ECSIT', 'ITGB1', 'PRKCZ', 'BAD', 'DDB1', 'CACNA1A', 'RAB9A', 'AXIN2', 'ABHD2', 'IGF1R', 'PPP2R2D', 'SLC7A5', 'MAP3K12', 'ITGA4', 'SOCS3', 'PPP1R12B', 'NCKAP1', 'PLA2G4F', 'CDH12', 'IRS2', 'SLC39A7', 'PTEN', 'LRP5', 'RXRA', 'PIK3R6', 'CXCL2', 'PPP2R2C', 'ALDH3A1', 'ANGPT4', 'CTNNA3', 'CTSL', 'DKK4', 'CLTCL1', 'UGT1A1', 'COL6A1', 'MMP7', 'PDK1', 'TFAP2A', 'CYP2B6', 'RXRG', 'SHC2', 'NFI', 'LEF1', 'AGER', 'SLC6A16', 'TLR4', 'MPL', 'PIK3C3', 'ATR', 'WNT10B', 'SLC2A12', 'SLC6A5', 'WNT11', 'PDLIM5', 'GNG8', 'PLCB1', 'TAB1', 'SRC', 'FGF10', 'PRKACG', 'ANGPT2', 'MYLK3', 'TNN', 'ATF4', 'SLC39A2', 'TTBK1', 'SLC6A14', 'PPP1CC', 'MAX', 'BUB1B-PAK6', 'GNA11', 'CCND3', 'CDH5', 'MGST1', 'ALDOB', 'G6PD', 'NCOA2', 'PFN1', 'RASGRF1', 'TSPAN8', 'DSCC1', 'TAOK2', 'MAP3K13', 'ITGA11', 'PPM1A', 'SGK1', 'CDKN1A', 'PPARA', 'NOS3', 'CDH8', 'MAPK13', 'HDAC7', 'CHUK', 'SDS', 'MCL1', 'FRAT2', 'BRAF', 'MAP3K11', 'CFL1', 'PLA2G4D', 'MGST2', 'IL9R', 'IL1B', 'FGFR1', 'ABL1', 'ARL5B', 'PTPRZ1', 'PDGFC', 'NTN1', 'IGF1', 'RHOC', 'DVL2', 'GADD45G', 'IL17B', 'YES1', 'MAP3K14', 'FOLR1', 'PLK2', 'DUSP16', 'GRB7', 'ERAS', 'ENAH', 'ITGA2B', 'TGFBR3', 'SLC5A9', 'SLCO2B1', 'SCD', 'SLC5A2', 'FOXO1', 'MAP3K6', 'SLC5A5', 'SSH1', 'DUSP2', 'DNAJC15', 'MAPKAP1', 'ORAI1', 'PLCB4', 'SLC2A6', 'GSR', 'ELAVL1', 'MAPK8', 'SOD3', 'CHRM1', 'TNS4', 'TLN2', 'FGF3', 'AKT1', 'CREB3', 'HEY2', 'PIK3AP1', 'SDSL', 'FKBP1A', 'MYL10', 'PTPRD', 'TESK2', 'STOM', 'FASN', 'IL6R', 'PRKAB2', 'CHRM3', 'CDH2', 'MMP12', 'VPS39', 'IL12B', 'GADD45A', 'BAIAP2', 'ITGAM', 'NBN', 'GNB3', 'TLN1', 'KEAP1', 'VASP', 'FLT4', 'CSNK1A1', 'LAMA2', 'IFNA6', 'CHAD', 'MAPK8IP1', 'VEGFB', 'HK2', 'VIL2', 'MP1', 'ARHGEF6', 'CLTB', 'MYL2', 'HSPA2', 'SLC39A5', 'PIK3C2B', 'PPP3R1', 'VWF', 'GADD45B', 'NEDD4', 'TP53', 'MST1', 'PAK7', 'ACTB', 'SMAD7', 'TGFA', 'ABCG8', 'SOX9', 'MSH2', 'IL2RB', 'SETD2', 'PTGES3', 'MYC', 'SLC7A11', 'FLT3', 'SHC3', 'CSNK2A2', 'RNF144B', 'LAT', 'HLA-DQB1', 'IFNA4', 'HES5', 'EPO', 'ETNK2', 'RBX1', 'FGF12', 'MAPK4', 'CSN2', 'CSNK1A1L', 'IL15RA', 'PLA2G2C', 'RASSF1', 'CDKN2B', 'RAD50', 'HES1', 'MYL12B', 'CCND2', 'LPAR5', 'WNT9B', 'ACTN4', 'MAPK8IP2', 'CYP8B1', 'ALDOC', 'KLF6', 'RALBP1', 'SLC19A2', 'PPP2R4', 'DKK2', 'GLUT1', 'ABL2', 'FZD4', 'PLA2G3', 'COL3A1', 'PLA2G6', 'SOD1', 'PKM2', 'RASGRP1', 'CDH20', 'AHCTF1', 'CYP1B1', 'TCF4', 'SLC2A1', 'ITGB8', 'JUN', 'COL4A6', 'IL20RB', 'GNB5', 'FGF9', 'FGF6', 'MAP3K8', 'MBL2', 'FGF22', 'LAMA5', 'AXIN1', 'TOP2A', 'MOS', 'MYB', 'CES1', 'RAB2A', 'RASAL1', 'GNB1', 'SHMT2', 'TNK2', 'CCL1', 'LDHB', 'ESR1', 'SMAD9', 'CSNK2A3', 'SPRY1', 'SLIT3', 'MFGE8', 'UGT1A6', 'IL6ST', 'PDPK1', 'SMAD4', 'BHLHE40', 'ARPC5', 'RAC1', 'LAMB1', 'ABCB4', 'GPR115', 'ITGB5', 'NRIP1', 'RAF1', 'PTPRT', 'CACNA1G', 'EFCAB3', 'EIF2S1', 'BST2', 'MIF', 'PFKFB4', 'KCNJ2', 'LGALS3', 'VPS18', 'CNTFR', 'GIT1', 'PLA2G12A', 'MDM2', 'ERRFI1', 'PLA2G2F', 'CACNG2', 'IL5RA', 'PSPH', 'SETD7', 'RASA4B', 'PRDX6', 'AKAP13', 'HSP90AA1', 'DNAJB1', 'VIM', 'CDH1', 'CACNA1F', 'SLC26A2', 'FOXO4', 'CPT1A', 'GNG13', 'MAP3K4', 'SLC2A9', 'GGT1', 'PTPN1', 'TACR1', 'PPP3CB', 'COL2A1', 'GYS2', 'DDIT3', 'DIAP1', 'NF1', 'BID', 'RAB5B', 'CDH22', 'DAPK3', 'JAK2', 'ZYX', 'THBD', 'GNGT2', 'NLK', 'NPC2', 'FAK', 'FZD1', 'PTPN11', 'CEBPZ', 'MYL1', 'MYLK4', 'POU5F1', 'PSMC5', 'PAK6', 'CD44', 'RPS6KA3', 'RAB8A', 'GPX3', 'FGD4', 'PRKCB', 'FGFBP1', 'PDGFD', 'ATM', 'PFKM', 'HLA-DMB', 'EXOC2', 'SLC10A1', 'LTB4R', 'PLA2G4C', 'CHTF18', 'AHRR', 'UGT1A9', 'RPS6', 'PRKAA1', 'HRAS', 'SERPINA1', 'CASP9', 'HBEGF', 'GCC1', 'ELF5', 'IRS1', 'RIN1', 'CSH1', 'CSK', 'HLA-DRB4', 'DAB2IP', 'LAMC3', 'SLC9A3', 'UGT1A7', 'RAPGEF2', 'SLC39A11', 'SHMT1', 'RASA3', 'HSPA1B', 'CREB3L4', 'STAT3', 'CACNB3', 'STAT1', 'COL6A5', 'LAMA1', 'E2F2', 'ITGB4', 'PDK4', 'B3GNT5', 'SLCO1B1', 'SLC27A1', 'RASA2', 'GRIN1', 'COL6A6', 'SMAD6', 'BAAT', 'GDNF', 'SHOC2', 'IL2RA', 'NGF', 'ETS1', 'ALOX5AP', 'FGF20', 'COL9A3', 'PLD1', 'MAPK3', 'ILK', 'CYP4A11', 'LIF', 'F2R', 'HIF1A', 'FGF4', 'ITGA8', 'IL2RG', 'CCL20', 'PTPRC', 'IFNB1', 'CAV3', 'HSPA1A', 'PTPN5', 'ABCC2', 'CSF3', 'GNAI3', 'CPEB4', 'SLC2A3', 'VEGFA', 'COX-2', 'RGL1', 'CLEC6A', 'MET', 'TSC22D3', 'MEF2D', 'FGF2', 'GSTM2', 'LIPE', 'IL1R2', 'WNT6', 'F2RL3', 'NPC1', 'PIP5K1A', 'MAPK9', 'HLA-DQB2', 'HSPB1', 'ROCK2', 'TNFRSF11A', 'MAP3K5', 'PITX2', 'ENO1', 'MAPKAPK5', 'JUND', 'E2F1', 'CDH7', 'CSNK2B', 'AQP4', 'DLL3', 'ARAF', 'NF2', 'PHLPP2', 'RDX', 'PPP3CC', 'FGF21', 'VAV3', 'CACNG6', 'HLA-DPB1', 'RB1', 'CRTC2', 'PXN', 'DUSP9', 'WNT16', 'CALM1', 'PCK2', 'IL3RA', 'MAP2K4', 'FGF8', 'ITGB6', 'CXCR7', 'ITGA10', 'PRKAG1', 'LPAR3', 'PEBP1', 'PTK2', 'TSG101', 'TNR', 'SLC6A4', 'CYP2C9', 'PGM2', 'GNAQ', 'ARHGEF1', 'VEGFD', 'ATF2', 'COL1A1', 'SLC6A19', 'SLC6A18', 'TRAF6', 'CREB3L2', 'MAP3K1', 'FGF16', 'SLC6A6', 'MDH1', 'PHLPP1', 'CALM2', 'IL4R', 'IQGAP1', 'TJP1', 'NTF3', 'PTGS2', 'TYMP', 'SDPR', 'LATS2', 'CSF1', 'NQO1', 'PKN2', 'FOXA1', 'NTRK1', 'PGM1', 'ANKRD1', 'E2F3', 'WNT5B', 'LDHD', 'MYLK2', 'PPARD', 'PPARGC1A', 'STMN1', 'STK11', 'DUSP8', 'HCK', 'HLA-DQA1', 'RAB11B', 'CD14', 'FZD3', 'MAP2K2', 'RAP1B', 'PARVA', 'KDM5C', 'MEF2C', 'FGF1', 'GSTM4', 'IFNA8', 'CACNA1C', 'SLC2A10', 'FANCI', 'TCF7', 'GCLM', 'CD19', 'TPCN2', 'DNAJC7', 'PIAS3', 'PPP2R3C', 'TAOK3', 'CALML4', 'ME1', 'MGAM', 'PIK3R1', 'MKNK1', 'DUSP7', 'MYL3', 'GSTA3', 'ARHGEF7', 'GPI', 'DOCK1', 'EFNA3', 'PRKCQ', 'ANXA2', 'PPP2R2A', 'COL6A2', 'IL12A', 'RASA1', 'HLA-DRB3', 'GSTM1', 'CACNA1S', 'PAK4', 'PLCG2', 'SRGN', 'INS', 'FZD6', 'DIAP3', 'VDR', 'SLC6A1', 'OTUD5', 'DEPTOR', 'GNG10', 'IL4', 'PLCB2', 'TXK', 'PAK2', 'TEAD3', 'TIAM1', 'ENO2', 'FGFR2', 'ZEB1', 'CYP4F12', 'MAP2K7', 'CCNE2', 'MAP2K5', 'FZD7', 'IL7', 'CBP', 'XYLT1', 'APC', 'KAT2B', 'CDH16', 'SLC6A2', 'PLA2G1B', 'NR1I3', 'TNFSF13', 'AHR', 'SLC2A7', 'RRAS', 'RTN4', 'IFNA16', 'PLAC8', 'RASAL3', 'IFNA2', 'GNAL', 'APOA1', 'ACACA', 'WNT1', 'STK3', 'PLA2G2A', 'FGF11', 'RASGRF2', 'CLEC4M', 'GSTA4', 'MTDH', 'VAV1', 'BLK', 'SMAD5', 'FKBP5', 'AGTR1', 'PKN3', 'SLC6A20', 'NCOA6', 'ANG1', 'NOTCH2', 'ITGAX', 'SLC5A11', 'CDH10', 'MAP3K2', 'CDC42EP3', 'LRRK2', 'CCR2', 'SERPINE1', 'CSNK2A1', 'SELP', 'FGR', 'PLA2G2D', 'NGFR', 'FKHR', 'NR1H3', 'MSH6', 'ITGB2', 'FLNC', 'ITGA7', 'PRKCA', 'PIK3R4', 'PGF', 'PLA2G2E', 'STAT5A', 'SRXN1', 'PPP1CA', 'CACNG8', 'PIK3CD', 'SLC39A10', 'DAPK1', 'PIK3R5', 'TCL1A', 'MAPK10', 'LAMA4', 'FOS', 'FZD8', 'UGT1A3', 'EP300', 'MERTK', 'CLTA', 'KSR2', 'COL11A1', 'RIPK4', 'ERK1', 'GAPDH', 'NR0B2', 'CACNG7', 'MYL12A', 'DDIT4', 'VPS4A', 'TOX2', 'THEM4', 'CAMK1', 'BAK1', 'CYP2A6', 'ACAA1', 'THBS4', 'SERPINB9', 'GHR', 'PPP2R5A', 'TNFSF11', 'PKLR', 'CDKN2C', 'GFAP', 'TCF7L1', 'LPAR1', 'BRCA1', 'CCNG1', 'LTB', 'PLXNA2', 'MAPK8IP3', 'PAK1', 'DVL1', 'DAXX', 'SRPX2', 'CRABP2', 'FTH1', 'CBR3', 'INHBB', 'PGK1', 'CDC42', 'BIRC5', 'FABP1', 'MYLK', 'KLF4', 'FGF13', 'ASGR1', 'FZD9', 'MLST8', 'BIRC3', 'PPP1R14C', 'RASAL2', 'NAV3', 'CYP3A4', 'BLVRB', 'SCIN', 'FCGR2A', 'CTF1', 'CDKN1B', 'AFDN', 'CDC37', 'CYP3A7', 'VPS41', 'ITGAD', 'ERBB1', 'MAP2K3', 'PIP5KL1', 'PDGFRB', 'ERBB4', 'AMPK', 'BAX', 'AGTR2', 'PIK3R3', 'FLT3LG', 'ANGPTL4', 'GRIN2A', 'CDH13', 'SULT2A1', 'HLA-C', 'CAB39L', 'SLC6A15', 'JAG2', 'PFKFB2', 'PTK6', 'RAB5A', 'WNT2B', 'RRAS2', 'SULT1A1', 'NCOA3', 'ETS2', 'SLIT1', 'TRAF2', 'KIT', 'GAS6', 'BMPR1A', 'SLC39A14', 'YY1', 'NCK1', 'CASP7', 'ARHGAP35', 'COL5A1', 'RASA4', 'GAP43', 'FLT1', 'MBP', 'WNT2', 'CSH2', 'TNK1', 'HMOX1', 'SLC6A7', 'KRAS', 'PRKAB1', 'AKT2', 'PRKAG2', 'RFC3', 'ITGB3', 'CAP2', 'PPP1CB', 'RGS2', 'IRF7', 'PRKRA', 'IFNGR2', 'TYK2', 'NR1I2', 'MEF2B', 'HLA-DOB', 'NCAN', 'UBE2T', 'CRKL', 'TAB2', 'LIMK1', 'LATS1', 'CALM3', 'HGF', 'IL7R', 'ENO3', 'MAFF', 'MYL5', 'NR1H4', 'CACNG1', 'ZFP36', 'SLC2A13', 'IL20RA', 'SPINK13', 'GNB2', 'EIF2AK2', 'HSP90AB1', 'LPAR2', 'DDB2', 'SRF', 'BRCA2', 'FASLG', 'RHEB', 'GNAS', 'FZD2', 'TNFAIP3', 'HLA-DRB5', 'NOS2', 'EIF4EBP1', 'ICAM1', 'CEBP', 'PGBD5', 'ARRB1', 'CDH24', 'PKM', 'RARB', 'ICAM3', 'MAP3K7', 'SSH2', 'BMPR2', 'SELENOP', 'CREBBP', 'EGF', 'ANXA1', 'MAP4K1', 'NCOA1', 'GJB2', 'LEP', 'CDC25B', 'EIF4E1B', 'PRKAR1A', 'P23', 'DCAF1', 'TRIM28', 'GAST', 'STYK1', 'CHGA', 'WNT4', 'BMPR1B', 'ZAK', 'SLC5A10', 'GRB2', 'RHOB', 'IFNA5', 'KDR', 'COL4A3', 'IFNA17', 'C11orf13', 'LILRB3', 'IL22RA1', 'COL5A3', 'ABCB11', 'IGFBP1', 'SCNN1A', 'PRKCI', 'GSTP1', 'PRRG4', 'CHTF8', 'KPNA1', 'SLC2A8', 'ACTN1', 'SLC2A11', 'CHST11', 'ERK', 'RELB', 'CES4A', 'CD300A', 'GSTA1', 'CDH9', 'XIAP', 'SPRY2', 'RPS6KB1', 'PRL', 'EPHA3', 'TXNRD1', 'ATF6B', 'PRKAG3', 'DLL1', 'G6PC', 'ACAN', 'PIK3IP1', 'MRE11A', 'CREB1', 'HLA-E', 'PGR', 'RHOD', 'KLK8', 'YAP1', 'HAVCR2', 'NR4A1', 'CYFIP2', 'IL2', 'CTGF', 'TXNRD3', 'DAPK2', 'HLA-B', 'TIMD4', 'SYK', 'BTG2', 'RAB10', 'PIP5K2B', 'SSPN', 'IL1R1', 'CXCL1', 'IBSP', 'GH2', 'PDGFRA', 'INSR', 'CD47', 'KTN1', 'GSTM3', 'PIK3CB', 'CD63', 'GH1', 'THBS2', 'PBRM1', 'RPS6KA4', 'TNC', 'RELA', 'COL4A4', 'PRKD3', 'SPP1', 'PPP2R5B', 'VHL', 'IL12RB2', 'MAFG', 'LIN28B', 'CAPN2', 'ITGA2', 'VIL1', 'HLA-DPA1', 'CREB3L3', 'CDK4', 'ULK1', 'STRADA', 'PAK3', 'YY1AP1', 'EIF4E', 'SCP2', 'IRF3', 'ARG1', 'PPP1R12A', 'EFNA4', 'PIP5K1C', 'CDKN2A', 'BCAR1', 'CACNA1E', 'SERTAD2', 'E2F5', 'TNF', 'GAB1', 'PTGR1', 'CHRM4', 'BDKRB1', 'EIF4B', 'SREBF1', 'CACNA2D2', 'IGF2', 'CES5A', 'MSK1', 'SLC27A5', 'C5', 'CACNA1H', 'AKT3', 'PIP5K2A', 'GNG5', 'FGFR4', 'LDHC', 'NFE2L2', 'GNA12', 'RHOA', 'FGF14', 'AMOT', 'PMP2', 'FLNA', 'SLC39A12', 'MTOR', 'PHGDH', 'PDGFB', 'ERBB3', 'PPP2R3A', 'PRKACA', 'FGFR3', 'PNCK', 'GNB4', 'CLEC10A', 'IL8', 'EPAS1', 'MAP4K2', 'ALAS1', 'BMP2', 'LPAR4', 'IFNA14', 'CALML3', 'TAZ', 'GAB2', 'KSR1', 'SHH', 'TGFB1', 'BAP1', 'ATP2C2', 'PPP2R5C', 'RAB14', 'TGFBR1', 'ABCB1', 'IP6K3', 'PLA2G4B', 'CACNB1', 'PDE4B', 'CCND1', 'CD36', 'DUSP6', 'EIF4G', 'FRAT1', 'CEBPA', 'RAB5C', 'ANG4', 'TAOK1', 'RELN', 'FGF19', 'RS1', 'GRIN2B', 'FGF5', 'SLC5A1', 'WNT7A', 'FGF18', 'ROCK1', 'CDK1', 'EGFR', 'PFKFB3', 'F2RL2', 'ESR2', 'ARHGAP5', 'SLC6A11', 'GRLF1', 'GRB14', 'PAK5', 'OSMR', 'MRAS', 'BIRC2', 'CACYBP', 'CYP3A5', 'WNT10A', 'SORBS2', 'MMP1', 'PRKCE', 'SEC14L1', 'CDH6', 'PPP3CA', 'USF2', 'DDX58', 'GNG12', 'FYN', 'BDNF', 'DUSP4', 'IKBKB', 'TLR2', 'PRKACB', 'PTPRR', 'GNG4', 'ATAD2', 'PTPRA', 'AIF1', 'LIFR', 'EPHA2', 'VEGF', 'RPTOR', 'PPP2R5D', 'SLC5A6', 'ACLY', 'CCL2', 'UBE2C', 'HTR7', 'PDGFA', 'ACACB', 'IFNA21', 'SLC2A14', 'HK1', 'PPP5D1', 'TEAD1', 'CDKN1C', 'PFKP', 'PLA2G5', 'MMP9', 'SLC39A1', 'SLC2A4', 'CTNNB1', 'VEGFR2', 'SNURF', 'RBL2', 'CLTC', 'MAP4K4', 'AXL', 'CACNA2D1', 'TFF2', 'OSM', 'SAV1', 'SERPINB2', 'APOA5', 'CDH19', 'HK3', 'NRAS', 'ARF6', 'ANG2', 'TBC1D1', 'MAP2K1', 'IKBKE', 'PKN1', 'CAV2', 'DUSP10', 'ZIC2', 'LAMC2', 'TBK1', 'CACNA1D', 'ALDOA', 'POLK', 'CYP1A1', 'FGF7', 'GSTT2', 'VGLL4', 'GSTA5', 'CETN3', 'SLC6A13', 'ABI2', 'SHC1', 'EML4', 'LAMA3', 'SHC4', 'STAT5B', 'HSP90B1', 'RAD17', 'MAPKAPK2', 'PPARG', 'SMAD1', 'GSTT1', 'ABCC3', 'LMNB2', 'ACVR1', 'MAPK12', 'SSH3', 'CEP290', 'TPI1', 'CES3', 'MYOF', 'SLC39A3', 'EIF4E2']

# %% [markdown]
# # GBM

# %%
#load GBM data 
#cptac.download(dataset='gbm')
brain = cptac.Gbm()
# Out:
# cptac warning: The GBM dataset is under publication embargo until March 01, 2021. CPTAC is a community resource project and data are made available rapidly after generation for community research use. The embargo allows exploring and utilizing the data, but analysis may not be published until after the embargo date. Please see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details. (/Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py, line 3)

# %%
#merge proteomics and mutations genes 
#select tumor only and drop extra columns
#filter for genes only interacting genes.

df1 = brain.join_omics_to_omics(df1_name="proteomics",df2_name="phosphoproteomics",
genes1 = ["EGFR"])
df1.columns = df1.columns.droplevel(2)
df1.columns = df1.columns.droplevel(2)
df1.columns =df1.columns.map('_'.join)
df2 = brain.get_clinical()
df2 = df2[["Sample_Tumor_Normal"]]

df3= pd.concat([df1, df2], axis=1, sort=False)
df3 = df3.loc[df3['Sample_Tumor_Normal'] == "Tumor"]

df3 = df3.loc[:,~df3.columns.duplicated()]
phospho_sites = df3.columns.values.tolist()

phospho_sites.remove('EGFR_proteomics_')
phospho_sites.remove('Sample_Tumor_Normal')
phospho_sites.remove('LCOR_phosphoproteomics_S583')

phospho_sites.remove('MTMR3_phosphoproteomics_S1102')
df3
# Out:
#            EGFR_proteomics_  A2M_phosphoproteomics_S273  \
# C3L-00104          1.054962                         NaN
# C3L-00365          2.219562                         NaN
# C3L-00674          0.137329                         NaN
# C3L-00677         -0.768478                         NaN
# C3L-01040         -1.249435                         NaN
# ...                     ...                         ...
# C3L-03747               NaN                         NaN
# C3N-01370               NaN                         NaN
# C3N-01817               NaN                         NaN
# C3N-01850               NaN                         NaN
# C3N-03187               NaN                         NaN
#
#            AAAS_phosphoproteomics_S495  AAAS_phosphoproteomics_S525  \
# C3L-00104                     0.053418                     0.118623
# C3L-00365                    -0.093105                     0.069499
# C3L-00674                    -1.084975                          NaN
# C3L-00677                    -0.260149                     0.336969
# C3L-01040                    -0.344549                    -0.082962
# ...                                ...                          ...
# C3L-03747                          NaN                          NaN
# C3N-01370                          NaN                          NaN
# C3N-01817                          NaN                          NaN
# C3N-01850                          NaN                          NaN
# C3N-03187                          NaN                          NaN
#
#            AAAS_phosphoproteomics_S525S541  AAAS_phosphoproteomics_S541  \
# C3L-00104                              NaN                          NaN
# C3L-00365                              NaN                          NaN
# C3L-00674                              NaN                     1.368630
# C3L-00677                              NaN                     0.411596
# C3L-01040                              NaN                          NaN
# ...                                    ...                          ...
# C3L-03747                              NaN                          NaN
# C3N-01370                              NaN                          NaN
# C3N-01817                              NaN                          NaN
# C3N-01850                              NaN                          NaN
# C3N-03187                              NaN                          NaN
#
#            AAED1_phosphoproteomics_S12  AAGAB_phosphoproteomics_S189  \
# C3L-00104                          NaN                           NaN
# C3L-00365                    -1.221096                           NaN
# C3L-00674                          NaN                           NaN
# C3L-00677                          NaN                      0.812857
# C3L-01040                          NaN                           NaN
# ...                                ...                           ...
# C3L-03747                          NaN                           NaN
# C3N-01370                          NaN                           NaN
# C3N-01817                          NaN                           NaN
# C3N-01850                          NaN                           NaN
# C3N-03187                          NaN                           NaN
#
#            AAGAB_phosphoproteomics_S196S199  AAGAB_phosphoproteomics_S199  \
# C3L-00104                               NaN                           NaN
# C3L-00365                               NaN                           NaN
# C3L-00674                               NaN                           NaN
# C3L-00677                          0.118422                           NaN
# C3L-01040                               NaN                           NaN
# ...                                     ...                           ...
# C3L-03747                               NaN                           NaN
# C3N-01370                               NaN                           NaN
# C3N-01817                               NaN                           NaN
# C3N-01850                               NaN                           NaN
# C3N-03187                               NaN                           NaN
#
#            ...  ZZZ3_phosphoproteomics_S397  ZZZ3_phosphoproteomics_S397S420  \
# C3L-00104  ...                          NaN                              NaN
# C3L-00365  ...                          NaN                              NaN
# C3L-00674  ...                    -1.037834                              NaN
# C3L-00677  ...                          NaN                              NaN
# C3L-01040  ...                          NaN                              NaN
# ...        ...                          ...                              ...
# C3L-03747  ...                          NaN                              NaN
# C3N-01370  ...                          NaN                              NaN
# C3N-01817  ...                          NaN                              NaN
# C3N-01850  ...                          NaN                              NaN
# C3N-03187  ...                          NaN                              NaN
#
#            ZZZ3_phosphoproteomics_S397S426  ZZZ3_phosphoproteomics_S397Y399  \
# C3L-00104                              NaN                              NaN
# C3L-00365                              NaN                              NaN
# C3L-00674                              NaN                              NaN
# C3L-00677                              NaN                              NaN
# C3L-01040                              NaN                              NaN
# ...                                    ...                              ...
# C3L-03747                              NaN                              NaN
# C3N-01370                              NaN                              NaN
# C3N-01817                              NaN                              NaN
# C3N-01850                              NaN                              NaN
# C3N-03187                              NaN                              NaN
#
#            ZZZ3_phosphoproteomics_S606  ZZZ3_phosphoproteomics_S777  \
# C3L-00104                          NaN                          NaN
# C3L-00365                          NaN                          NaN
# C3L-00674                     0.064722                     0.216607
# C3L-00677                          NaN                          NaN
# C3L-01040                          NaN                          NaN
# ...                                ...                          ...
# C3L-03747                          NaN                          NaN
# C3N-01370                          NaN                          NaN
# C3N-01817                          NaN                          NaN
# C3N-01850                          NaN                          NaN
# C3N-03187                          NaN                          NaN
#
#            ZZZ3_phosphoproteomics_T418  ZZZ3_phosphoproteomics_Y399  \
# C3L-00104                          NaN                          NaN
# C3L-00365                          NaN                          NaN
# C3L-00674                          NaN                          NaN
# C3L-00677                          NaN                          NaN
# C3L-01040                          NaN                          NaN
# ...                                ...                          ...
# C3L-03747                          NaN                          NaN
# C3N-01370                          NaN                          NaN
# C3N-01817                          NaN                          NaN
# C3N-01850                          NaN                          NaN
# C3N-03187                          NaN                          NaN
#
#            ZZZ3_phosphoproteomics_Y399S426  Sample_Tumor_Normal
# C3L-00104                              NaN                Tumor
# C3L-00365                              NaN                Tumor
# C3L-00674                              NaN                Tumor
# C3L-00677                              NaN                Tumor
# C3L-01040                              NaN                Tumor
# ...                                    ...                  ...
# C3L-03747                              NaN                Tumor
# C3N-01370                              NaN                Tumor
# C3N-01817                              NaN                Tumor
# C3N-01850                              NaN                Tumor
# C3N-03187                              NaN                Tumor
#
# [105 rows x 86556 columns]

# %%
df =(wrap_lin_regression(df3,"EGFR_proteomics_",comparison_columns = phospho_sites, return_all = True))
df.to_csv("GBM_EGFR_all_phospho.csv")
df
# Out:
#                                 Comparison  Correlation       P_value
# 11823         EGFR_phosphoproteomics_S1166     0.836375  4.540027e-27
# 11831         EGFR_phosphoproteomics_T1046     0.823906  2.067960e-25
# 11839         EGFR_phosphoproteomics_Y1172     0.819459  3.490814e-25
# 11826          EGFR_phosphoproteomics_S991     0.790899  2.079575e-22
# 11840         EGFR_phosphoproteomics_Y1197     0.807444  4.155461e-22
# ...                                    ...          ...           ...
# 15404          GMPS_phosphoproteomics_S313    -0.000064  9.997020e-01
# 2385           ANXA6_phosphoproteomics_Y10     0.000042  9.997074e-01
# 11130  DOCK11_phosphoproteomics_S1237S1240    -0.000051  9.997090e-01
# 44065           VAT1_phosphoproteomics_S18     0.000040  9.998165e-01
# 30144  PPP1R13L_phosphoproteomics_S102S113     0.000012  9.999400e-01
#
# [46398 rows x 3 columns]

# %% [markdown]
# # Kidney

# %%
#cptac.download(dataset='ccrcc')
kidney = cptac.Ccrcc()

# %%
df1 = kidney.join_omics_to_omics(df1_name="proteomics",df2_name="phosphoproteomics",
genes1 = ["EGFR"])
df1.columns = df1.columns.droplevel(2)
df1.columns = df1.columns.droplevel(2)
df1.columns =df1.columns.map('_'.join)
df2 = kidney.get_clinical()
df2 = df2[["Sample_Tumor_Normal"]]

df3= pd.concat([df1, df2], axis=1, sort=False)
df3 = df3.loc[df3['Sample_Tumor_Normal'] == "Tumor"]

df3 = df3.loc[:,~df3.columns.duplicated()]
phospho_sites = df3.columns.values.tolist()

phospho_sites.remove('EGFR_proteomics_')
phospho_sites.remove('Sample_Tumor_Normal')
#phospho_sites.remove('LCOR_phosphoproteomics_S583')

#phospho_sites.remove('MTMR3_phosphoproteomics_S1102')
df3
# Out:
#             EGFR_proteomics_  A1BG_phosphoproteomics_S302  \
# Patient_ID
# C3L-00004           0.254999                          NaN
# C3L-00010           0.526561                          NaN
# C3L-00011           0.268540                          NaN
# C3L-00026           0.578659                          NaN
# C3L-00079           0.662720                    -0.324594
# ...                      ...                          ...
# C3N-01646           0.013371                          NaN
# C3N-01648          -0.105850                          NaN
# C3N-01649           0.180939                          NaN
# C3N-01651           0.554559                          NaN
# C3N-01808           0.602952                          NaN
#
#             A1BG_phosphoproteomics_T171  A1BG_phosphoproteomics_T171Y180Y184  \
# Patient_ID
# C3L-00004                           NaN                                  NaN
# C3L-00010                           NaN                                  NaN
# C3L-00011                           NaN                                  NaN
# C3L-00026                           NaN                                  NaN
# C3L-00079                           NaN                                  NaN
# ...                                 ...                                  ...
# C3N-01646                           NaN                                  NaN
# C3N-01648                           NaN                                  NaN
# C3N-01649                           NaN                                  NaN
# C3N-01651                           NaN                                  NaN
# C3N-01808                           NaN                                  NaN
#
#             A1CF_phosphoproteomics_T491  A2M_phosphoproteomics_S710  \
# Patient_ID
# C3L-00004                      0.265550                         NaN
# C3L-00010                      0.197179                         NaN
# C3L-00011                     -0.653431                   -0.234516
# C3L-00026                           NaN                         NaN
# C3L-00079                     -0.530613                         NaN
# ...                                 ...                         ...
# C3N-01646                           NaN                    0.888674
# C3N-01648                     -0.694130                         NaN
# C3N-01649                     -0.633383                         NaN
# C3N-01651                      0.467653                    0.407549
# C3N-01808                      0.464454                         NaN
#
#             A2M_phosphoproteomics_S879T885S889  A2M_phosphoproteomics_S928  \
# Patient_ID
# C3L-00004                                  NaN                         NaN
# C3L-00010                                  NaN                         NaN
# C3L-00011                                  NaN                         NaN
# C3L-00026                                  NaN                         NaN
# C3L-00079                                  NaN                         NaN
# ...                                        ...                         ...
# C3N-01646                                  NaN                         NaN
# C3N-01648                                  NaN                         NaN
# C3N-01649                                  NaN                         NaN
# C3N-01651                                  NaN                         NaN
# C3N-01808                                  NaN                         NaN
#
#             AAAS_phosphoproteomics_S462  AAAS_phosphoproteomics_Y452  ...  \
# Patient_ID                                                            ...
# C3L-00004                      0.288098                     0.540065  ...
# C3L-00010                      0.464613                          NaN  ...
# C3L-00011                      0.606817                     0.141970  ...
# C3L-00026                     -0.316857                    -0.176404  ...
# C3L-00079                      0.173482                     0.159497  ...
# ...                                 ...                          ...  ...
# C3N-01646                      0.428071                     0.800620  ...
# C3N-01648                     -0.156157                     0.277809  ...
# C3N-01649                     -0.039409                     0.547987  ...
# C3N-01651                      0.378086                     1.037915  ...
# C3N-01808                     -0.012906                    -0.034295  ...
#
#             ZZZ3_phosphoproteomics_S396  ZZZ3_phosphoproteomics_S396T415  \
# Patient_ID
# C3L-00004                     -0.126627                          0.11534
# C3L-00010                           NaN                              NaN
# C3L-00011                           NaN                              NaN
# C3L-00026                           NaN                              NaN
# C3L-00079                           NaN                              NaN
# ...                                 ...                              ...
# C3N-01646                     -0.034223                              NaN
# C3N-01648                           NaN                              NaN
# C3N-01649                           NaN                              NaN
# C3N-01651                     -0.163245                              NaN
# C3N-01808                           NaN                              NaN
#
#             ZZZ3_phosphoproteomics_S397  ZZZ3_phosphoproteomics_S426  \
# Patient_ID
# C3L-00004                           NaN                          NaN
# C3L-00010                           NaN                          NaN
# C3L-00011                           NaN                          NaN
# C3L-00026                           NaN                          NaN
# C3L-00079                           NaN                          NaN
# ...                                 ...                          ...
# C3N-01646                           NaN                          NaN
# C3N-01648                       0.15955                          NaN
# C3N-01649                           NaN                     0.433068
# C3N-01651                           NaN                          NaN
# C3N-01808                           NaN                     0.220782
#
#             ZZZ3_phosphoproteomics_S468  ZZZ3_phosphoproteomics_S777  \
# Patient_ID
# C3L-00004                           NaN                          NaN
# C3L-00010                           NaN                    -0.086545
# C3L-00011                           NaN                          NaN
# C3L-00026                      0.475135                          NaN
# C3L-00079                     -0.589953                          NaN
# ...                                 ...                          ...
# C3N-01646                           NaN                          NaN
# C3N-01648                           NaN                          NaN
# C3N-01649                     -0.721719                          NaN
# C3N-01651                           NaN                          NaN
# C3N-01808                      0.097481                          NaN
#
#             ZZZ3_phosphoproteomics_S89  ZZZ3_phosphoproteomics_Y399  \
# Patient_ID
# C3L-00004                          NaN                          NaN
# C3L-00010                          NaN                          NaN
# C3L-00011                     0.007086                          NaN
# C3L-00026                          NaN                          NaN
# C3L-00079                          NaN                    -0.157496
# ...                                ...                          ...
# C3N-01646                          NaN                          NaN
# C3N-01648                          NaN                          NaN
# C3N-01649                          NaN                          NaN
# C3N-01651                          NaN                          NaN
# C3N-01808                          NaN                          NaN
#
#             ZZZ3_phosphoproteomics_Y399T428  Sample_Tumor_Normal
# Patient_ID
# C3L-00004                               NaN                Tumor
# C3L-00010                               NaN                Tumor
# C3L-00011                               NaN                Tumor
# C3L-00026                               NaN                Tumor
# C3L-00079                               NaN                Tumor
# ...                                     ...                  ...
# C3N-01646                               NaN                Tumor
# C3N-01648                               NaN                Tumor
# C3N-01649                               NaN                Tumor
# C3N-01651                               NaN                Tumor
# C3N-01808                               NaN                Tumor
#
# [110 rows x 77456 columns]

# %%
df =(wrap_lin_regression(df3,"EGFR_proteomics_",comparison_columns = phospho_sites, return_all = True))
df.to_csv("Kidney_EGFR_all_phospho.csv")
df
# Out:
#                              Comparison  Correlation       P_value
# 9954       EGFR_phosphoproteomics_S1113     0.640306  4.996706e-14
# 9964        EGFR_phosphoproteomics_T640     0.600529  4.068052e-12
# 9968       EGFR_phosphoproteomics_Y1119     0.642668  1.477123e-11
# 14139  HIF1A_phosphoproteomics_S475T479     0.662293  4.264192e-10
# 37726      USP11_phosphoproteomics_S648    -0.523648  4.356763e-09
# ...                                 ...          ...           ...
# 33979   SVIL_phosphoproteomics_S221S226     0.000036  9.998746e-01
# 19246        MBD3_phosphoproteomics_S85    -0.000013  9.998920e-01
# 17565   LMNA_phosphoproteomics_S407T409     0.000006  9.999567e-01
# 32118       SNX2_phosphoproteomics_S117     0.000004  9.999745e-01
# 101        ABCF3_phosphoproteomics_S155    -0.000004  9.999769e-01
#
# [40199 rows x 3 columns]

# %% [markdown]
# # Ovarian

# %%
#cptac.download(dataset='ovarian')
Ovar = cptac.Ovarian()

# %%
df1 = Ovar.join_omics_to_omics(df1_name="proteomics",df2_name="phosphoproteomics",
genes1 = ["EGFR"])
df1.columns = df1.columns.droplevel(2)
df1.columns = df1.columns.droplevel(2)
df1.columns =df1.columns.map('_'.join)
df2 = Ovar.get_clinical()
df2 = df2[["Sample_Tumor_Normal"]]

df3= pd.concat([df1, df2], axis=1, sort=False)
df3 = df3.loc[df3['Sample_Tumor_Normal'] == "Tumor"]

df3 = df3.loc[:,~df3.columns.duplicated()]
phospho_sites = df3.columns.values.tolist()

phospho_sites.remove('EGFR_proteomics_')
phospho_sites.remove('Sample_Tumor_Normal')
#phospho_sites.remove('LCOR_phosphoproteomics_S583')

#phospho_sites.remove('MTMR3_phosphoproteomics_S1102')
df3
# Out:
#          EGFR_proteomics_  AAAS_phosphoproteomics_S495  \
# 01OV007         -0.064895                          NaN
# 01OV017         -0.247334                          NaN
# 01OV018         -0.039963                          NaN
# 01OV023          0.147606                       -1.137
# 01OV026         -0.285889                       -0.987
# ...                   ...                          ...
# 17OV012               NaN                          NaN
# 17OV019               NaN                          NaN
# 17OV034               NaN                          NaN
# 22OV001               NaN                          NaN
# 26OV010               NaN                          NaN
#
#          AAGAB_phosphoproteomics_S311  AAK1_phosphoproteomics_S18  \
# 01OV007                           NaN                         NaN
# 01OV017                           NaN                         NaN
# 01OV018                           NaN                         NaN
# 01OV023                           NaN                         NaN
# 01OV026                           NaN                         NaN
# ...                               ...                         ...
# 17OV012                           NaN                         NaN
# 17OV019                           NaN                         NaN
# 17OV034                           NaN                         NaN
# 22OV001                           NaN                         NaN
# 26OV010                           NaN                         NaN
#
#          AAK1_phosphoproteomics_S20  AAK1_phosphoproteomics_S21  \
# 01OV007                         NaN                         NaN
# 01OV017                         NaN                         NaN
# 01OV018                         NaN                         NaN
# 01OV023                         NaN                         NaN
# 01OV026                         NaN                      -2.269
# ...                             ...                         ...
# 17OV012                         NaN                         NaN
# 17OV019                         NaN                         NaN
# 17OV034                         NaN                         NaN
# 22OV001                         NaN                         NaN
# 26OV010                         NaN                         NaN
#
#          AAK1_phosphoproteomics_S624  AAK1_phosphoproteomics_S637  \
# 01OV007                          NaN                          NaN
# 01OV017                          NaN                          NaN
# 01OV018                          NaN                          NaN
# 01OV023                          NaN                          NaN
# 01OV026                       -3.363                          NaN
# ...                              ...                          ...
# 17OV012                          NaN                          NaN
# 17OV019                          NaN                          NaN
# 17OV034                          NaN                          NaN
# 22OV001                          NaN                          NaN
# 26OV010                          NaN                          NaN
#
#          AAK1_phosphoproteomics_S642  AAK1_phosphoproteomics_S668S678  ...  \
# 01OV007                       -1.829                              NaN  ...
# 01OV017                       -2.095                              NaN  ...
# 01OV018                       -1.748                              NaN  ...
# 01OV023                          NaN                           -2.185  ...
# 01OV026                          NaN                              NaN  ...
# ...                              ...                              ...  ...
# 17OV012                          NaN                              NaN  ...
# 17OV019                          NaN                              NaN  ...
# 17OV034                          NaN                              NaN  ...
# 22OV001                          NaN                              NaN  ...
# 26OV010                          NaN                              NaN  ...
#
#          ZZEF1_phosphoproteomics_S1518  ZZEF1_phosphoproteomics_S2444  \
# 01OV007                            NaN                         -0.584
# 01OV017                            NaN                         -0.502
# 01OV018                         -3.242                            NaN
# 01OV023                            NaN                         -0.268
# 01OV026                            NaN                         -2.055
# ...                                ...                            ...
# 17OV012                            NaN                            NaN
# 17OV019                            NaN                            NaN
# 17OV034                            NaN                            NaN
# 22OV001                            NaN                            NaN
# 26OV010                            NaN                            NaN
#
#          ZZZ3_phosphoproteomics_S113  ZZZ3_phosphoproteomics_S135  \
# 01OV007                          NaN                          NaN
# 01OV017                          NaN                          NaN
# 01OV018                          NaN                          NaN
# 01OV023                          NaN                          NaN
# 01OV026                          NaN                          NaN
# ...                              ...                          ...
# 17OV012                          NaN                          NaN
# 17OV019                          NaN                          NaN
# 17OV034                          NaN                          NaN
# 22OV001                          NaN                          NaN
# 26OV010                          NaN                          NaN
#
#          ZZZ3_phosphoproteomics_S314  ZZZ3_phosphoproteomics_S391  \
# 01OV007                       -2.533                          NaN
# 01OV017                       -3.276                          NaN
# 01OV018                          NaN                       -0.847
# 01OV023                          NaN                       -0.455
# 01OV026                          NaN                          NaN
# ...                              ...                          ...
# 17OV012                          NaN                          NaN
# 17OV019                          NaN                          NaN
# 17OV034                          NaN                          NaN
# 22OV001                          NaN                          NaN
# 26OV010                          NaN                          NaN
#
#          ZZZ3_phosphoproteomics_S89  ZZZ3_phosphoproteomics_S90  \
# 01OV007                         NaN                         NaN
# 01OV017                         NaN                         NaN
# 01OV018                         NaN                         NaN
# 01OV023                         NaN                         NaN
# 01OV026                         NaN                         NaN
# ...                             ...                         ...
# 17OV012                         NaN                         NaN
# 17OV019                         NaN                         NaN
# 17OV034                         NaN                         NaN
# 22OV001                         NaN                         NaN
# 26OV010                         NaN                         NaN
#
#          ZZZ3_phosphoproteomics_S91  Sample_Tumor_Normal
# 01OV007                      -1.320                Tumor
# 01OV017                      -0.264                Tumor
# 01OV018                         NaN                Tumor
# 01OV023                      -1.129                Tumor
# 01OV026                      -1.301                Tumor
# ...                             ...                  ...
# 17OV012                         NaN                Tumor
# 17OV019                         NaN                Tumor
# 17OV034                         NaN                Tumor
# 22OV001                         NaN                Tumor
# 26OV010                         NaN                Tumor
#
# [111 rows x 38195 columns]

# %%
df =(wrap_lin_regression(df3,"EGFR_proteomics_",comparison_columns = phospho_sites, return_all = True))
df.to_csv("Ovar_EGFR_all_phospho.csv")
df
# Out:
#                            Comparison  Correlation   P_value
# 9596       SAV1_phosphoproteomics_S94     0.596355  0.000005
# 10356   SORBS2_phosphoproteomics_S378     0.466413  0.000009
# 6251      MDC1_phosphoproteomics_S780     0.582111  0.000022
# 3864       FLNA_phosphoproteomics_S11     0.662220  0.000027
# 7036       NHS_phosphoproteomics_S739     0.637454  0.000029
# ...                               ...          ...       ...
# 932    ARHGEF15_phosphoproteomics_S42    -0.000060  0.999657
# 4902      IRS2_phosphoproteomics_T350    -0.000050  0.999767
# 11333   TGOLN2_phosphoproteomics_S154    -0.000062  0.999783
# 366     AHNAK_phosphoproteomics_S5400    -0.000048  0.999783
# 4745   IGF2BP2_phosphoproteomics_S168     0.000021  0.999909
#
# [12989 rows x 3 columns]

# %% [markdown]
# # Colon

# %%
#cptac.download(dataset='colon')
colon = cptac.Colon()

# %%
df1 = colon.join_omics_to_omics(df1_name="proteomics",df2_name="phosphoproteomics",
genes1 = ["EGFR"])
df1.columns = df1.columns.droplevel(2)
#df1.columns = df1.columns.droplevel(2)
df1.columns =df1.columns.map('_'.join)
df2 = colon.get_clinical()
df2 = df2[["Sample_Tumor_Normal"]]

df3= pd.concat([df1, df2], axis=1, sort=False)
df3 = df3.loc[df3['Sample_Tumor_Normal'] == "Tumor"]

df3 = df3.loc[:,~df3.columns.duplicated()]
phospho_sites = df3.columns.values.tolist()

phospho_sites.remove('EGFR_proteomics_')
phospho_sites.remove('Sample_Tumor_Normal')
#phospho_sites.remove('LCOR_phosphoproteomics_S583')

#phospho_sites.remove('MTMR3_phosphoproteomics_S1102')
df3
# Out:
#          EGFR_proteomics_  AAAS_phosphoproteomics_S495  \
# 01CO005           -0.1540                          NaN
# 01CO006            0.0916                      -0.3650
# 01CO008           -0.3250                       0.7250
# 01CO013           -0.5470                       0.2265
# 01CO014            0.0184                       0.5600
# ...                   ...                          ...
# 13CO001               NaN                          NaN
# 14CO001               NaN                          NaN
# 14CO002               NaN                          NaN
# 16CO012               NaN                          NaN
# 24CO005               NaN                          NaN
#
#          AAAS_phosphoproteomics_S525  AAAS_phosphoproteomics_S541  \
# 01CO005                          NaN                       -0.240
# 01CO006                          NaN                          NaN
# 01CO008                        0.137                        0.137
# 01CO013                          NaN                          NaN
# 01CO014                          NaN                          NaN
# ...                              ...                          ...
# 13CO001                          NaN                          NaN
# 14CO001                          NaN                          NaN
# 14CO002                          NaN                          NaN
# 16CO012                          NaN                          NaN
# 24CO005                          NaN                          NaN
#
#          AAED1_phosphoproteomics_S12  AAGAB_phosphoproteomics_S310  \
# 01CO005                       -0.460                           NaN
# 01CO006                       -0.424                        -0.015
# 01CO008                          NaN                           NaN
# 01CO013                       -1.278                         0.403
# 01CO014                       -0.382                           NaN
# ...                              ...                           ...
# 13CO001                          NaN                           NaN
# 14CO001                          NaN                           NaN
# 14CO002                          NaN                           NaN
# 16CO012                          NaN                           NaN
# 24CO005                          NaN                           NaN
#
#          AAGAB_phosphoproteomics_S311  AAK1_phosphoproteomics_S20  \
# 01CO005                           NaN                      -0.231
# 01CO006                        -0.015                         NaN
# 01CO008                           NaN                         NaN
# 01CO013                         0.075                      -0.223
# 01CO014                           NaN                         NaN
# ...                               ...                         ...
# 13CO001                           NaN                         NaN
# 14CO001                           NaN                         NaN
# 14CO002                           NaN                         NaN
# 16CO012                           NaN                         NaN
# 24CO005                           NaN                         NaN
#
#          AAK1_phosphoproteomics_S21  AAK1_phosphoproteomics_S26  ...  \
# 01CO005                         NaN                         NaN  ...
# 01CO006                      -0.485                         NaN  ...
# 01CO008                         NaN                         NaN  ...
# 01CO013                      -0.701                         NaN  ...
# 01CO014                      -0.259                         NaN  ...
# ...                             ...                         ...  ...
# 13CO001                         NaN                         NaN  ...
# 14CO001                         NaN                         NaN  ...
# 14CO002                         NaN                         NaN  ...
# 16CO012                         NaN                         NaN  ...
# 24CO005                         NaN                         NaN  ...
#
#          ZZEF1_phosphoproteomics_S1518  ZZEF1_phosphoproteomics_S1537  \
# 01CO005                        -0.6750                         -1.404
# 01CO006                        -0.2875                          0.222
# 01CO008                        -0.1470                            NaN
# 01CO013                         0.0430                          0.554
# 01CO014                        -0.1290                         -0.919
# ...                                ...                            ...
# 13CO001                            NaN                            NaN
# 14CO001                            NaN                            NaN
# 14CO002                            NaN                            NaN
# 16CO012                            NaN                            NaN
# 24CO005                            NaN                            NaN
#
#          ZZEF1_phosphoproteomics_S1540  ZZEF1_phosphoproteomics_T1521  \
# 01CO005                         -1.404                            NaN
# 01CO006                          0.222                         -0.701
# 01CO008                            NaN                            NaN
# 01CO013                          0.554                          0.127
# 01CO014                         -0.919                            NaN
# ...                                ...                            ...
# 13CO001                            NaN                            NaN
# 14CO001                            NaN                            NaN
# 14CO002                            NaN                            NaN
# 16CO012                            NaN                            NaN
# 24CO005                            NaN                            NaN
#
#          ZZZ3_phosphoproteomics_S113  ZZZ3_phosphoproteomics_S391  \
# 01CO005                       -0.572                          NaN
# 01CO006                        0.624                          NaN
# 01CO008                          NaN                          NaN
# 01CO013                        1.263                          NaN
# 01CO014                        0.032                          NaN
# ...                              ...                          ...
# 13CO001                          NaN                          NaN
# 14CO001                          NaN                          NaN
# 14CO002                          NaN                          NaN
# 16CO012                          NaN                          NaN
# 24CO005                          NaN                          NaN
#
#          ZZZ3_phosphoproteomics_S606  ZZZ3_phosphoproteomics_S90  \
# 01CO005                        0.205                         NaN
# 01CO006                          NaN                         NaN
# 01CO008                          NaN                         NaN
# 01CO013                          NaN                         NaN
# 01CO014                        0.026                         NaN
# ...                              ...                         ...
# 13CO001                          NaN                         NaN
# 14CO001                          NaN                         NaN
# 14CO002                          NaN                         NaN
# 16CO012                          NaN                         NaN
# 24CO005                          NaN                         NaN
#
#          ZZZ3_phosphoproteomics_S91  Sample_Tumor_Normal
# 01CO005                         NaN                Tumor
# 01CO006                         NaN                Tumor
# 01CO008                       -0.03                Tumor
# 01CO013                         NaN                Tumor
# 01CO014                         NaN                Tumor
# ...                             ...                  ...
# 13CO001                         NaN                Tumor
# 14CO001                         NaN                Tumor
# 14CO002                         NaN                Tumor
# 16CO012                         NaN                Tumor
# 24CO005                         NaN                Tumor
#
# [110 rows x 31264 columns]

# %%
df =(wrap_lin_regression(df3,"EGFR_proteomics_",comparison_columns = phospho_sites, return_all = True))
df.to_csv("Colon_EGFR_all_phospho.csv")
df
# Out:
#                            Comparison   Correlation       P_value
# 10298     NRBP1_phosphoproteomics_S49  5.944902e-01  1.417846e-07
# 18266   ZC3H13_phosphoproteomics_S198 -5.049624e-01  2.850161e-07
# 893     ANKS1A_phosphoproteomics_S382 -5.175621e-01  4.620559e-07
# 12960   RBM12B_phosphoproteomics_S280 -4.935741e-01  1.027604e-06
# 12959   RBM12B_phosphoproteomics_S278 -5.034072e-01  1.431433e-06
# ...                               ...           ...           ...
# 5866      GAB1_phosphoproteomics_T365 -4.042992e-05  9.998189e-01
# 4303     DOCK7_phosphoproteomics_S900 -2.027453e-05  9.998576e-01
# 11574  PLEKHA6_phosphoproteomics_S251 -7.480675e-06  9.999488e-01
# 15701    STIM1_phosphoproteomics_S567 -7.272453e-06  9.999690e-01
# 14659      SMG9_phosphoproteomics_S53  8.949538e-07  9.999950e-01
#
# [18720 rows x 3 columns]

# %% [markdown]
# # Brca

# %%
#cptac.download(dataset='brca')
brca = cptac.Brca()

# %%
df1 = brca.join_omics_to_omics(df1_name="proteomics",df2_name="phosphoproteomics",
genes1 = ["EGFR"])
df1.columns = df1.columns.droplevel(2)
df1.columns = df1.columns.droplevel(2)
df1.columns =df1.columns.map('_'.join)
df2 = brca.get_clinical()
df2 = df2[["Sample_Tumor_Normal"]]

df3= pd.concat([df1, df2], axis=1, sort=False)
df3 = df3.loc[df3['Sample_Tumor_Normal'] == "Tumor"]

df3 = df3.loc[:,~df3.columns.duplicated()]
phospho_sites = df3.columns.values.tolist()

phospho_sites.remove('EGFR_proteomics_')
phospho_sites.remove('Sample_Tumor_Normal')
df3
# Out:
#             EGFR_proteomics_  A2M_phosphoproteomics_S710  \
# Patient_ID
# CPT000814            -0.4834                         NaN
# CPT001846             4.1062                         NaN
# X01BR001              1.2191                         NaN
# X01BR008              0.0613                         NaN
# X01BR009              1.6974                         NaN
# ...                      ...                         ...
# X21BR001             -1.5217                         NaN
# X21BR002             -0.9455                         NaN
# X21BR010             -0.7098                     -0.7266
# X22BR005             -1.7568                     -0.7618
# X22BR006             -1.1921                         NaN
#
#             AAAS_phosphoproteomics_S495  AAAS_phosphoproteomics_S541  \
# Patient_ID
# CPT000814                        1.9431                          NaN
# CPT001846                        0.2274                          NaN
# X01BR001                        -2.2853                      -0.8967
# X01BR008                         1.3714                          NaN
# X01BR009                         0.2682                          NaN
# ...                                 ...                          ...
# X21BR001                         0.9424                          NaN
# X21BR002                         0.2955                          NaN
# X21BR010                        -0.1201                      -0.1477
# X22BR005                        -0.3378                       3.2472
# X22BR006                        -0.9958                          NaN
#
#             AAED1_phosphoproteomics_S12  AAGAB_phosphoproteomics_S310S311  \
# Patient_ID
# CPT000814                           NaN                            0.0127
# CPT001846                        0.5472                            0.6895
# X01BR001                         4.1225                            0.4842
# X01BR008                        -0.0636                           -0.6224
# X01BR009                            NaN                           -0.6207
# ...                                 ...                               ...
# X21BR001                         0.4838                            0.0477
# X21BR002                        -0.0053                            0.1169
# X21BR010                         1.8818                            0.8338
# X22BR005                            NaN                            1.0000
# X22BR006                        -0.4590                           -1.0934
#
#             AAGAB_phosphoproteomics_S311  AAK1_phosphoproteomics_S14  \
# Patient_ID
# CPT000814                        -0.4495                         NaN
# CPT001846                        -0.7680                         NaN
# X01BR001                         -1.2458                     -0.0310
# X01BR008                         -1.2732                     -1.1351
# X01BR009                         -2.3561                     -0.3078
# ...                                  ...                         ...
# X21BR001                         -0.3365                     -0.4697
# X21BR002                          0.5654                     -0.7218
# X21BR010                          0.2280                     -0.0877
# X22BR005                          1.8410                         NaN
# X22BR006                          1.3237                         NaN
#
#             AAK1_phosphoproteomics_S18  AAK1_phosphoproteomics_S21  ...  \
# Patient_ID                                                          ...
# CPT000814                      -1.1852                     -0.8333  ...
# CPT001846                       0.6895                      0.3903  ...
# X01BR001                        0.8805                      0.7448  ...
# X01BR008                       -0.8652                      0.0031  ...
# X01BR009                        0.3785                      0.6990  ...
# ...                                ...                         ...  ...
# X21BR001                       -0.4213                      0.1117  ...
# X21BR002                       -0.2368                      0.2974  ...
# X21BR010                       -0.4698                     -0.2266  ...
# X22BR005                       -0.6455                      0.6330  ...
# X22BR006                       -0.4364                      0.1788  ...
#
#             ZZZ3_phosphoproteomics_S113  ZZZ3_phosphoproteomics_S314  \
# Patient_ID
# CPT000814                        0.0735                       0.2238
# CPT001846                       -0.8199                          NaN
# X01BR001                         0.1092                          NaN
# X01BR008                         0.3824                          NaN
# X01BR009                        -0.7779                          NaN
# ...                                 ...                          ...
# X21BR001                         0.2035                          NaN
# X21BR002                        -1.2871                          NaN
# X21BR010                        -0.4731                       0.1700
# X22BR005                         1.6131                       0.9179
# X22BR006                        -0.9958                       0.9177
#
#             ZZZ3_phosphoproteomics_S381  ZZZ3_phosphoproteomics_S391  \
# Patient_ID
# CPT000814                       -0.6702                      -8.8556
# CPT001846                       -0.8790                      -4.0222
# X01BR001                            NaN                      -1.6299
# X01BR008                            NaN                       1.3333
# X01BR009                            NaN                       0.5267
# ...                                 ...                          ...
# X21BR001                            NaN                       0.9078
# X21BR002                            NaN                      -0.4611
# X21BR010                        -1.5727                      -2.2380
# X22BR005                            NaN                       1.3874
# X22BR006                        -2.6165                          NaN
#
#             ZZZ3_phosphoproteomics_S397  ZZZ3_phosphoproteomics_S397T428N429  \
# Patient_ID
# CPT000814                           NaN                              -0.8493
# CPT001846                           NaN                               1.1806
# X01BR001                        -0.2017                              -0.3953
# X01BR008                         0.7840                               0.1078
# X01BR009                        -0.6661                               0.5539
# ...                                 ...                                  ...
# X21BR001                         0.7330                               1.5429
# X21BR002                        -0.3007                               0.4122
# X21BR010                         0.9095                               0.3844
# X22BR005                            NaN                               0.0792
# X22BR006                            NaN                              -0.2273
#
#             ZZZ3_phosphoproteomics_S606  ZZZ3_phosphoproteomics_S82  \
# Patient_ID
# CPT000814                       -0.1744                     -0.0273
# CPT001846                       -1.2700                     -0.8983
# X01BR001                        -2.1328                     -0.8815
# X01BR008                         0.4824                         NaN
# X01BR009                        -0.3728                         NaN
# ...                                 ...                         ...
# X21BR001                         0.6015                         NaN
# X21BR002                        -0.6325                         NaN
# X21BR010                         0.1160                     -3.4806
# X22BR005                         1.0615                         NaN
# X22BR006                        -0.3249                         NaN
#
#             ZZZ3_phosphoproteomics_S89  Sample_Tumor_Normal
# Patient_ID
# CPT000814                      -6.8916                Tumor
# CPT001846                      -3.6228                Tumor
# X01BR001                       -2.1191                Tumor
# X01BR008                       -0.9748                Tumor
# X01BR009                       -0.8354                Tumor
# ...                                ...                  ...
# X21BR001                       -2.2315                Tumor
# X21BR002                       -0.4046                Tumor
# X21BR010                        0.0170                Tumor
# X22BR005                        0.3436                Tumor
# X22BR006                        0.8567                Tumor
#
# [122 rows x 38597 columns]

# %%
df =(wrap_lin_regression(df3,"EGFR_proteomics_",comparison_columns = phospho_sites, return_all = True))
df.to_csv("Brca_EGFR_all_phospho.csv")
df
# Out:
#                                  Comparison  Correlation       P_value
# 9437           EGFR_phosphoproteomics_S1166     0.758593  9.308668e-23
# 9440            EGFR_phosphoproteomics_T693     0.744355  2.773845e-17
# 22470     PARD6B_phosphoproteomics_S291N301    -0.639906  2.000658e-13
# 18184           MAPT_phosphoproteomics_S508    -0.598498  1.617844e-12
# 17178       LRBA_phosphoproteomics_S979N988    -0.596900  1.918647e-12
# ...                                     ...          ...           ...
# 32294  STK26_phosphoproteomics_S304S306S309     0.000057  9.996682e-01
# 8526             DLC1_phosphoproteomics_S22     0.000038  9.997380e-01
# 5252          CCDC15_phosphoproteomics_S709     0.000035  9.998113e-01
# 29720          SIPA1_phosphoproteomics_S839     0.000002  9.999852e-01
# 24937         PPP1R3E_phosphoproteomics_S16     0.000001  9.999936e-01
#
# [38565 rows x 3 columns]

# %% [markdown]
# # LUAD

# %%
#cptac.download(dataset='luad')
luad = cptac.Luad()
# Out:
# cptac warning: The LUAD dataset is under publication embargo until July 01, 2020. CPTAC is a community resource project and data are made available rapidly after generation for community research use. The embargo allows exploring and utilizing the data, but analysis may not be published until after the embargo date. Please see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details. (/Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py, line 2)

# %%
df1 = luad.join_omics_to_omics(df1_name="proteomics",df2_name="phosphoproteomics",
genes1 = ["EGFR"])
df1.columns = df1.columns.droplevel(2)
df1.columns = df1.columns.droplevel(2)
df1.columns =df1.columns.map('_'.join)
df2 = luad.get_clinical()
df2 = df2[["Sample_Tumor_Normal"]]

df3= pd.concat([df1, df2], axis=1, sort=False)
df3 = df3.loc[df3['Sample_Tumor_Normal'] == "Tumor"]

df3 = df3.loc[:,~df3.columns.duplicated()]
phospho_sites = df3.columns.values.tolist()

phospho_sites.remove('EGFR_proteomics_')
phospho_sites.remove('Sample_Tumor_Normal')
df3
# Out:
#             EGFR_proteomics_  AAAS_phosphoproteomics_S495  \
# Patient_ID
# C3L-00001             7.5892                      -0.7127
# C3L-00009            -1.8777                       0.6344
# C3L-00080            -1.2350                       1.0390
# C3L-00083            -2.8551                      -0.4906
# C3L-00093            -1.9872                       1.0305
# ...                      ...                          ...
# C3N-02729             0.6061                       0.0377
# X11LU013              5.1657                       0.4598
# X11LU016              0.6080                       0.8232
# X11LU022              1.0362                       0.7228
# X11LU035             -2.1088                      -0.1317
#
#             AAAS_phosphoproteomics_S541  AAED1_phosphoproteomics_S12  \
# Patient_ID
# C3L-00001                        0.2683                       0.9238
# C3L-00009                           NaN                       1.3945
# C3L-00080                           NaN                      -0.2910
# C3L-00083                           NaN                       0.8506
# C3L-00093                       -0.5968                       0.3249
# ...                                 ...                          ...
# C3N-02729                           NaN                      -0.4162
# X11LU013                            NaN                      -1.3742
# X11LU016                         0.5637                       0.3794
# X11LU022                        -0.4196                       0.0563
# X11LU035                        -0.1646                       0.2135
#
#             AAGAB_phosphoproteomics_S310S311  AAGAB_phosphoproteomics_S311  \
# Patient_ID
# C3L-00001                             0.1711                           NaN
# C3L-00009                            -2.3271                       -0.4007
# C3L-00080                                NaN                        0.2226
# C3L-00083                                NaN                        0.3430
# C3L-00093                             1.0423                       -0.2167
# ...                                      ...                           ...
# C3N-02729                                NaN                       -1.3180
# X11LU013                             -0.4182                        1.1134
# X11LU016                                 NaN                        1.0695
# X11LU022                              0.8353                        1.3252
# X11LU035                              1.6560                        3.0491
#
#             AAK1_phosphoproteomics_S20  AAK1_phosphoproteomics_S618T620S624  \
# Patient_ID
# C3L-00001                       1.0165                                  NaN
# C3L-00009                       1.5299                                  NaN
# C3L-00080                       0.5386                                  NaN
# C3L-00083                       0.2118                                  NaN
# C3L-00093                       1.1706                               1.0851
# ...                                ...                                  ...
# C3N-02729                       1.2554                              -0.2403
# X11LU013                       -0.3382                                  NaN
# X11LU016                       -0.5345                              -0.8673
# X11LU022                        1.1244                               0.7530
# X11LU035                        0.0943                              -0.0660
#
#             AAK1_phosphoproteomics_S624  AAK1_phosphoproteomics_S678  ...  \
# Patient_ID                                                            ...
# C3L-00001                       -0.2064                      -0.0278  ...
# C3L-00009                       -0.1799                       1.5237  ...
# C3L-00080                       -1.0926                          NaN  ...
# C3L-00083                        2.5134                       1.7586  ...
# C3L-00093                           NaN                       0.4152  ...
# ...                                 ...                          ...  ...
# C3N-02729                       -2.7458                      -1.0661  ...
# X11LU013                            NaN                       1.5914  ...
# X11LU016                            NaN                       1.1221  ...
# X11LU022                            NaN                      -0.7750  ...
# X11LU035                         0.8772                          NaN  ...
#
#             ZZEF1_phosphoproteomics_T1477  ZZEF1_phosphoproteomics_T1521  \
# Patient_ID
# C3L-00001                             NaN                            NaN
# C3L-00009                             NaN                            NaN
# C3L-00080                             NaN                            NaN
# C3L-00083                          1.4610                        -0.7684
# C3L-00093                             NaN                         0.5577
# ...                                   ...                            ...
# C3N-02729                             NaN                            NaN
# X11LU013                              NaN                            NaN
# X11LU016                           0.5167                        -0.1302
# X11LU022                              NaN                         0.9056
# X11LU035                           0.5340                            NaN
#
#             ZZEF1_phosphoproteomics_T2224T2226  ZZEF1_phosphoproteomics_T66  \
# Patient_ID
# C3L-00001                                  NaN                          NaN
# C3L-00009                                  NaN                       0.3657
# C3L-00080                              -1.6473                      -0.6087
# C3L-00083                                  NaN                          NaN
# C3L-00093                                  NaN                          NaN
# ...                                        ...                          ...
# C3N-02729                               3.2071                          NaN
# X11LU013                               -3.5768                          NaN
# X11LU016                               -1.0723                       0.1143
# X11LU022                                   NaN                          NaN
# X11LU035                                   NaN                          NaN
#
#             ZZZ3_phosphoproteomics_S113  ZZZ3_phosphoproteomics_S391  \
# Patient_ID
# C3L-00001                       -1.0721                      -0.3262
# C3L-00009                       -0.1195                       0.9010
# C3L-00080                       -0.3008                       0.7575
# C3L-00083                       -0.2718                       0.7937
# C3L-00093                        0.0422                       0.4389
# ...                                 ...                          ...
# C3N-02729                       -0.2763                      -1.3520
# X11LU013                        -1.2122                      -0.3557
# X11LU016                        -0.1998                       0.1237
# X11LU022                         1.1886                      -1.8792
# X11LU035                         1.3231                      -0.7482
#
#             ZZZ3_phosphoproteomics_S397N429  ZZZ3_phosphoproteomics_S606  \
# Patient_ID
# C3L-00001                           -0.1611                          NaN
# C3L-00009                            0.2720                       0.7177
# C3L-00080                               NaN                       0.1502
# C3L-00083                            0.3386                       0.4415
# C3L-00093                               NaN                       0.1586
# ...                                     ...                          ...
# C3N-02729                               NaN                          NaN
# X11LU013                                NaN                      -0.5020
# X11LU016                                NaN                      -0.5815
# X11LU022                                NaN                      -0.5501
# X11LU035                                NaN                      -2.1578
#
#             ZZZ3_phosphoproteomics_S89  Sample_Tumor_Normal
# Patient_ID
# C3L-00001                       0.6164                Tumor
# C3L-00009                      -0.9776                Tumor
# C3L-00080                       0.1946                Tumor
# C3L-00083                      -1.7661                Tumor
# C3L-00093                       0.0303                Tumor
# ...                                ...                  ...
# C3N-02729                      -1.1201                Tumor
# X11LU013                       -2.0238                Tumor
# X11LU016                       -1.0779                Tumor
# X11LU022                       -0.5140                Tumor
# X11LU035                       -0.9434                Tumor
#
# [110 rows x 40814 columns]

# %%
df =(wrap_lin_regression(df3,"EGFR_proteomics_",comparison_columns = phospho_sites, return_all = True))
df.to_csv("luad_EGFR_all_phospho.csv")
df
# Out:
#                               Comparison  Correlation       P_value
# 10038       EGFR_phosphoproteomics_S1064     0.808056  1.430853e-26
# 10044        EGFR_phosphoproteomics_T693     0.760275  5.838451e-22
# 10047       EGFR_phosphoproteomics_Y1197     0.694622  2.994042e-15
# 10046       EGFR_phosphoproteomics_Y1172     0.656540  6.792539e-14
# 10041        EGFR_phosphoproteomics_S991     0.637149  7.252109e-14
# ...                                  ...          ...           ...
# 8544    DCLK1_phosphoproteomics_S347S352    -0.000016  9.998996e-01
# 32322       SNTB2_phosphoproteomics_S129     0.000011  9.999078e-01
# 39903  ZDHHC5_phosphoproteomics_S587S593     0.000017  9.999210e-01
# 34059     STK11IP_phosphoproteomics_S389     0.000012  9.999331e-01
# 39718      ZC3H14_phosphoproteomics_S252     0.000007  9.999506e-01
#
# [40812 rows x 3 columns]

# %% [markdown]
# # HNSCC

# %%
#cptac.download(dataset='hnscc')
Hnscc = cptac.Hnscc()

# %%
df1 = Hnscc.join_omics_to_omics(df1_name="proteomics",df2_name="phosphoproteomics",
genes1 = ["EGFR"])
df1.columns = df1.columns.droplevel(2)
df1.columns = df1.columns.droplevel(2)
df1.columns =df1.columns.map('_'.join)
df2 = Hnscc.get_clinical()
df2 = df2[["Sample_Tumor_Normal"]]

df3= pd.concat([df1, df2], axis=1, sort=False)
df3 = df3.loc[df3['Sample_Tumor_Normal'] == "Tumor"]

df3 = df3.loc[:,~df3.columns.duplicated()]

df3 = df3.dropna(axis=1, how="all")
phospho_sites = df3.columns.values.tolist()


phospho_sites.remove('EGFR_proteomics_')
phospho_sites.remove('Sample_Tumor_Normal')
df3
# Out:
#            EGFR_proteomics_  A2M_phosphoproteomics_S710  \
# C3L-00977         26.415671                         NaN
# C3L-00987         26.388105                         NaN
# C3L-00994         26.832596                         NaN
# C3L-00995         25.865444                   14.950532
# C3L-00997         26.094205                         NaN
# ...                     ...                         ...
# C3N-04279         27.028592                         NaN
# C3N-04280         26.149398                         NaN
# C3N-04611         25.375399                         NaN
# C3N-00300               NaN                         NaN
# C3N-01643               NaN                         NaN
#
#            A2M_phosphoproteomics_S928  A2ML1_phosphoproteomics_S658  \
# C3L-00977                         NaN                           NaN
# C3L-00987                         NaN                           NaN
# C3L-00994                         NaN                           NaN
# C3L-00995                         NaN                           NaN
# C3L-00997                         NaN                           NaN
# ...                               ...                           ...
# C3N-04279                         NaN                           NaN
# C3N-04280                         NaN                           NaN
# C3N-04611                         NaN                           NaN
# C3N-00300                         NaN                           NaN
# C3N-01643                         NaN                           NaN
#
#            A2ML1_phosphoproteomics_S698  AAAS_phosphoproteomics_S462  \
# C3L-00977                           NaN                    23.810752
# C3L-00987                           NaN                    24.303142
# C3L-00994                           NaN                    23.834852
# C3L-00995                           NaN                    24.188308
# C3L-00997                           NaN                    24.178120
# ...                                 ...                          ...
# C3N-04279                     13.404450                    24.128939
# C3N-04280                     16.816393                    23.876969
# C3N-04611                           NaN                    24.459120
# C3N-00300                           NaN                          NaN
# C3N-01643                           NaN                          NaN
#
#            AAAS_phosphoproteomics_S478  AAAS_phosphoproteomics_S508  \
# C3L-00977                    16.462169                          NaN
# C3L-00987                          NaN                          NaN
# C3L-00994                    16.514470                          NaN
# C3L-00995                          NaN                          NaN
# C3L-00997                          NaN                    17.683328
# ...                                ...                          ...
# C3N-04279                    16.820011                          NaN
# C3N-04280                          NaN                          NaN
# C3N-04611                    17.185842                    19.174044
# C3N-00300                          NaN                          NaN
# C3N-01643                          NaN                          NaN
#
#            AAAS_phosphoproteomics_T488S508  AAED1_phosphoproteomics_S12  ...  \
# C3L-00977                              NaN                    19.304315  ...
# C3L-00987                              NaN                    19.581772  ...
# C3L-00994                              NaN                    20.286625  ...
# C3L-00995                              NaN                    19.822521  ...
# C3L-00997                              NaN                    19.792555  ...
# ...                                    ...                          ...  ...
# C3N-04279                              NaN                    20.094552  ...
# C3N-04280                              NaN                    19.311999  ...
# C3N-04611                              NaN                    19.753071  ...
# C3N-00300                              NaN                          NaN  ...
# C3N-01643                              NaN                          NaN  ...
#
#            ZZZ3_phosphoproteomics_S113  ZZZ3_phosphoproteomics_S130S131S135  \
# C3L-00977                    22.742364                                  NaN
# C3L-00987                    21.936262                                  NaN
# C3L-00994                    21.773755                                  NaN
# C3L-00995                    22.155548                                  NaN
# C3L-00997                    22.094004                                  NaN
# ...                                ...                                  ...
# C3N-04279                    22.849759                                  NaN
# C3N-04280                    23.035371                                  NaN
# C3N-04611                    22.716190                                  NaN
# C3N-00300                          NaN                                  NaN
# C3N-01643                          NaN                                  NaN
#
#            ZZZ3_phosphoproteomics_S135  ZZZ3_phosphoproteomics_S314  \
# C3L-00977                          NaN                          NaN
# C3L-00987                          NaN                          NaN
# C3L-00994                          NaN                          NaN
# C3L-00995                          NaN                          NaN
# C3L-00997                          NaN                          NaN
# ...                                ...                          ...
# C3N-04279                          NaN                          NaN
# C3N-04280                          NaN                          NaN
# C3N-04611                          NaN                    17.425659
# C3N-00300                          NaN                          NaN
# C3N-01643                          NaN                          NaN
#
#            ZZZ3_phosphoproteomics_S381T388  ZZZ3_phosphoproteomics_S391  \
# C3L-00977                              NaN                    20.726809
# C3L-00987                        10.553611                          NaN
# C3L-00994                              NaN                    20.389204
# C3L-00995                              NaN                    20.849815
# C3L-00997                              NaN                    20.776460
# ...                                    ...                          ...
# C3N-04279                              NaN                          NaN
# C3N-04280                              NaN                          NaN
# C3N-04611                              NaN                    21.417648
# C3N-00300                              NaN                          NaN
# C3N-01643                              NaN                          NaN
#
#            ZZZ3_phosphoproteomics_S396  ZZZ3_phosphoproteomics_S91  \
# C3L-00977                          NaN                         NaN
# C3L-00987                          NaN                         NaN
# C3L-00994                          NaN                         NaN
# C3L-00995                          NaN                         NaN
# C3L-00997                    14.551561                         NaN
# ...                                ...                         ...
# C3N-04279                          NaN                         NaN
# C3N-04280                          NaN                         NaN
# C3N-04611                          NaN                         NaN
# C3N-00300                          NaN                         NaN
# C3N-01643                          NaN                         NaN
#
#            ZZZ3_phosphoproteomics_T301  Sample_Tumor_Normal
# C3L-00977                          NaN                Tumor
# C3L-00987                          NaN                Tumor
# C3L-00994                          NaN                Tumor
# C3L-00995                          NaN                Tumor
# C3L-00997                          NaN                Tumor
# ...                                ...                  ...
# C3N-04279                          NaN                Tumor
# C3N-04280                          NaN                Tumor
# C3N-04611                          NaN                Tumor
# C3N-00300                          NaN                Tumor
# C3N-01643                          NaN                Tumor
#
# [111 rows x 59913 columns]

# %%
df =(wrap_lin_regression(df3,"EGFR_proteomics_",comparison_columns = phospho_sites, return_all = True))
df.to_csv("Hnscc_EGFR_all_phospho.csv")
df
# Out:
#                            Comparison  Correlation       P_value
# 7791     EGFR_phosphoproteomics_Y1197     0.841558  4.871114e-29
# 7782      EGFR_phosphoproteomics_S991     0.754687  2.631905e-21
# 7787      EGFR_phosphoproteomics_T693     0.723745  6.088243e-19
# 7790     EGFR_phosphoproteomics_Y1172     0.833804  7.375490e-17
# 7780     EGFR_phosphoproteomics_S1166     0.790180  1.136463e-15
# ...                               ...          ...           ...
# 26589    SRRM1_phosphoproteomics_S628    -0.000048  9.996015e-01
# 18414   NRIP1_phosphoproteomics_T1013    -0.000048  9.996859e-01
# 20659  PLEKHG3_phosphoproteomics_S870    -0.000041  9.997673e-01
# 7732     EEF2K_phosphoproteomics_S492     0.000044  9.998376e-01
# 19915    PHF14_phosphoproteomics_T287     0.000014  9.999361e-01
#
# [32565 rows x 3 columns]

# %% [markdown]
# # Lscc

# %%
Lscc = cptac.Lscc()

# %%
df1 = Lscc.join_omics_to_omics(df1_name="proteomics",df2_name="phosphoproteomics",
genes1 = ["EGFR"])
df1.columns = df1.columns.droplevel(2)
df1.columns = df1.columns.droplevel(2)
df1.columns =df1.columns.map('_'.join)
df2 = Lscc.get_clinical()
df2 = df2[["Sample_Tumor_Normal"]]

df3= pd.concat([df1, df2], axis=1, sort=False)
df3 = df3.loc[df3['Sample_Tumor_Normal'] == "Tumor"]

df3 = df3.loc[:,~df3.columns.duplicated()]
phospho_sites = df3.columns.values.tolist()

phospho_sites.remove('EGFR_proteomics_')
phospho_sites.remove('Sample_Tumor_Normal')
df3
# Out:
#            EGFR_proteomics_  A4GALT_phosphoproteomics_T324  \
# C3L-00081            1.3122                            NaN
# C3L-00415           -1.4779                            NaN
# C3L-00445            0.4224                            NaN
# C3L-00568           -1.0816                         0.9270
# C3L-00603            1.4508                            NaN
# ...                     ...                            ...
# C3N-04155            0.2056                        -1.6357
# C3N-04162           -0.1384                         0.3511
# C3L-00503               NaN                            NaN
# C3N-00309               NaN                            NaN
# C3N-00839               NaN                            NaN
#
#            AAAS_phosphoproteomics_S495  AAED1_phosphoproteomics_S12  \
# C3L-00081                       1.4658                      -0.3928
# C3L-00415                      -1.3706                      -1.4682
# C3L-00445                       0.5106                          NaN
# C3L-00568                       0.9634                          NaN
# C3L-00603                       0.9622                      -0.3333
# ...                                ...                          ...
# C3N-04155                       1.4479                          NaN
# C3N-04162                       1.0060                          NaN
# C3L-00503                          NaN                          NaN
# C3N-00309                          NaN                          NaN
# C3N-00839                          NaN                          NaN
#
#            AAGAB_phosphoproteomics_S310S311  AAGAB_phosphoproteomics_S311  \
# C3L-00081                               NaN                           NaN
# C3L-00415                            0.8167                        0.4114
# C3L-00445                            0.3627                        1.9174
# C3L-00568                           -0.6045                        1.5058
# C3L-00603                            0.2873                        0.5218
# ...                                     ...                           ...
# C3N-04155                            0.7692                        1.0117
# C3N-04162                           -0.0960                        0.7152
# C3L-00503                               NaN                           NaN
# C3N-00309                               NaN                           NaN
# C3N-00839                               NaN                           NaN
#
#            AAK1_phosphoproteomics_S18  AAK1_phosphoproteomics_S21  \
# C3L-00081                      0.0176                     -0.0391
# C3L-00415                      1.3812                      1.5283
# C3L-00445                      0.1257                     -0.2341
# C3L-00568                      0.8369                      0.3980
# C3L-00603                      0.4575                      0.5404
# ...                               ...                         ...
# C3N-04155                      0.3880                     -0.0797
# C3N-04162                     -0.3916                     -0.5466
# C3L-00503                         NaN                         NaN
# C3N-00309                         NaN                         NaN
# C3N-00839                         NaN                         NaN
#
#            AAK1_phosphoproteomics_S618T620S624  AAK1_phosphoproteomics_S624  \
# C3L-00081                               0.5031                       0.9853
# C3L-00415                               1.5884                      -2.4650
# C3L-00445                              -0.5839                          NaN
# C3L-00568                              -0.6754                       1.9850
# C3L-00603                              -0.0373                      -0.9639
# ...                                        ...                          ...
# C3N-04155                               0.2368                      -0.1207
# C3N-04162                               0.0891                       0.2874
# C3L-00503                                  NaN                          NaN
# C3N-00309                                  NaN                          NaN
# C3N-00839                                  NaN                          NaN
#
#            ...  ZZZ3_phosphoproteomics_S314  ZZZ3_phosphoproteomics_S381  \
# C3L-00081  ...                          NaN                       1.9162
# C3L-00415  ...                      -2.3599                      -0.3572
# C3L-00445  ...                       1.8083                          NaN
# C3L-00568  ...                          NaN                          NaN
# C3L-00603  ...                       0.3488                       1.9718
# ...        ...                          ...                          ...
# C3N-04155  ...                          NaN                          NaN
# C3N-04162  ...                          NaN                          NaN
# C3L-00503  ...                          NaN                          NaN
# C3N-00309  ...                          NaN                          NaN
# C3N-00839  ...                          NaN                          NaN
#
#            ZZZ3_phosphoproteomics_S391  ZZZ3_phosphoproteomics_S397N422  \
# C3L-00081                       0.0644                              NaN
# C3L-00415                       0.4609                           0.1847
# C3L-00445                       0.6222                              NaN
# C3L-00568                       0.1986                           0.7660
# C3L-00603                       0.9637                              NaN
# ...                                ...                              ...
# C3N-04155                       0.6085                           0.1597
# C3N-04162                       1.3497                           1.5468
# C3L-00503                          NaN                              NaN
# C3N-00309                          NaN                              NaN
# C3N-00839                          NaN                              NaN
#
#            ZZZ3_phosphoproteomics_S397T428N429  ZZZ3_phosphoproteomics_S606  \
# C3L-00081                              -0.5079                       0.6333
# C3L-00415                              -0.1381                      -0.5674
# C3L-00445                                  NaN                      -0.0649
# C3L-00568                                  NaN                       0.5590
# C3L-00603                              -0.0831                       1.0581
# ...                                        ...                          ...
# C3N-04155                                  NaN                       0.3660
# C3N-04162                               1.5528                       1.4038
# C3L-00503                                  NaN                          NaN
# C3N-00309                                  NaN                          NaN
# C3N-00839                                  NaN                          NaN
#
#            ZZZ3_phosphoproteomics_S82  ZZZ3_phosphoproteomics_S89  \
# C3L-00081                         NaN                     -1.9627
# C3L-00415                         NaN                     -0.5089
# C3L-00445                      0.2649                         NaN
# C3L-00568                      1.1532                     -0.9744
# C3L-00603                      2.5538                      0.1829
# ...                               ...                         ...
# C3N-04155                      1.3503                     -0.6546
# C3N-04162                         NaN                     -1.2088
# C3L-00503                         NaN                         NaN
# C3N-00309                         NaN                         NaN
# C3N-00839                         NaN                         NaN
#
#            ZZZ3_phosphoproteomics_T428N429  Sample_Tumor_Normal
# C3L-00081                           0.0360                Tumor
# C3L-00415                           0.0481                Tumor
# C3L-00445                              NaN                Tumor
# C3L-00568                           1.5806                Tumor
# C3L-00603                              NaN                Tumor
# ...                                    ...                  ...
# C3N-04155                          -0.1537                Tumor
# C3N-04162                              NaN                Tumor
# C3L-00503                              NaN                Tumor
# C3N-00309                              NaN                Tumor
# C3N-00839                              NaN                Tumor
#
# [113 rows x 42672 columns]

# %%
df =(wrap_lin_regression(df3,"EGFR_proteomics_",comparison_columns = phospho_sites, return_all = True))
df.to_csv("Lscc_EGFR_all_phospho.csv")
df
# Out:
#                                    Comparison  Correlation       P_value
# 10555            EGFR_phosphoproteomics_S1064     0.892423  2.202225e-37
# 10563             EGFR_phosphoproteomics_T693     0.815182  2.274316e-27
# 10553            EGFR_phosphoproteomics_S1039     0.800521  9.217794e-26
# 10564            EGFR_phosphoproteomics_Y1172     0.800729  5.791519e-22
# 10554  EGFR_phosphoproteomics_S1042S1045N1053     0.773589  3.975640e-20
# ...                                       ...          ...           ...
# 41423       ZBTB7A_phosphoproteomics_T517S526     0.000017  9.998748e-01
# 12561              FGA_phosphoproteomics_S294    -0.000024  9.998838e-01
# 26988             PNKP_phosphoproteomics_T118     0.000009  9.999259e-01
# 33258         SLC39A10_phosphoproteomics_T536     0.000003  9.999827e-01
# 12458       FBXO28_phosphoproteomics_M328S330    -0.000002  9.999868e-01
#
# [42670 rows x 3 columns]
