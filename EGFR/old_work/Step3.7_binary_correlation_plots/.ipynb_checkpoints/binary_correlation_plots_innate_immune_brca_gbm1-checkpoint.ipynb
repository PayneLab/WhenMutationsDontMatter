# %% [markdown]
# # Binary_correlation_plots

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import gseapy as gp
import re

import cptac
import cptac.utils as u

import plot_utils as p

# %% [markdown]
# # Select two cancers for the plot

# %%
g = cptac.Gbm()
brca = cptac.Brca()
# Out:
# cptac warning: The GBM dataset is under publication embargo until March 01, 2021. CPTAC is a community resource project and data are made available rapidly after generation for community research use. The embargo allows exploring and utilizing the data, but analysis may not be published until after the embargo date. Please see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details. (/Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py, line 1)

# %%
def create_prot_list(df):
    df = df.loc[:,~df.columns.duplicated()]
    prot_genes_list = df.columns.values.tolist()
    prot_genes_list.remove('EGFR_proteomics')
    prot_genes_list.remove('EGFR_Mutation')
    prot_genes_list.remove('EGFR_Location')
    prot_genes_list.remove('EGFR_Mutation_Status')
    prot_genes_list.remove('Sample_Status')
    return prot_genes_list

# %% [markdown]
# # Calculate FDR-bh (lowest sig p-value = cutoff)

# %% [markdown]
# Gbm Pearson Correlation

# %%
gene = 'EGFR'
df1 = g.join_omics_to_mutations(omics_df_name="proteomics", mutations_genes= gene)
#f1.columns = df1.columns.droplevel(1)
df1_tumor = df1.loc[df1['Sample_Status'] == "Tumor"]
prot_genes_list = create_prot_list(df1_tumor)
# Out:
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 93 samples for the EGFR gene (/Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py, line 2)

# %%
# Get only sig genes
g_sig= p.wrap_pearson_corr(df1_tumor,"EGFR_proteomics",comparison_columns= prot_genes_list,correction_method='fdr_bh', return_all = False)
g_sig
# get_smallest p-value
cutoff_gbm = g_sig.P_value[-1:]
cutoff_gbm
# Out:
# 1571    0.007423
# Name: P_value, dtype: float64

# %% [markdown]
# Brca Pearson Correlation

# %%
gene = 'EGFR'

df1 = brca.join_omics_to_mutations(omics_df_name="proteomics", mutations_genes= gene)
df1.columns = df1.columns.droplevel(1)
df1_tumor = df1.loc[df1['Sample_Status'] == "Tumor"]
prot_genes_list = create_prot_list(df1_tumor)
# Out:
# cptac warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 118 samples for the EGFR gene (/Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py, line 3)

# %%
# Get only sig sites
brca_sig= p.wrap_pearson_corr(df1_tumor,"EGFR_proteomics",comparison_columns= prot_genes_list,correction_method='fdr_bh', return_all = False)
brca_sig
# get_smallest p-value
cutoff_brca = brca_sig.P_value[-1:]
cutoff_brca
# Out:
# 2057    0.013554
# Name: P_value, dtype: float64

# %% [markdown]
# Read in data frame that has all pearson correlations/ pvalues for all egfr trans genes. Subset down for just brca/gbm

# %%
prot_df = pd.read_csv("../Step3.2_combining_pearson_dfs/csv_files/pancan_EGFR_all_return_all_wide.csv")
prot_df = prot_df[["Comparison","Correlation_Gbm","P_value_Gbm","Correlation_Brca","P_value_Brca"]]

prot_df
# Out:
#                Comparison  Correlation_Gbm   P_value_Gbm  Correlation_Brca  \
# 0         EGFR_proteomics         1.000000  0.000000e+00          1.000000
# 1       PHLDA1_proteomics         0.816848  6.553435e-25          0.364797
# 2         GRB2_proteomics        -0.610889  1.886384e-11         -0.177379
# 3        SOCS2_proteomics         0.562720  1.343464e-09               NaN
# 4         CDH4_proteomics         0.559180  1.790048e-09               NaN
# ...                   ...              ...           ...               ...
# 14047     TFR2_proteomics              NaN           NaN               NaN
# 14048    MYBL2_proteomics              NaN           NaN               NaN
# 14049  ZSCAN12_proteomics              NaN           NaN               NaN
# 14050   ZNF836_proteomics              NaN           NaN               NaN
# 14051    DDX43_proteomics              NaN           NaN               NaN
#
#        P_value_Brca
# 0          0.000000
# 1          0.000190
# 2          0.057899
# 3               NaN
# 4               NaN
# ...             ...
# 14047           NaN
# 14048           NaN
# 14049           NaN
# 14050           NaN
# 14051           NaN
#
# [14052 rows x 5 columns]

# %% [markdown]
# # Create df with p-values for all genes in a pathway

# %%
# get a list of genes in a complete Pathway 
#This one is from Reactomes Hemostasis pathway
hemostasis_genes = pd.read_csv("~/Downloads/reactome_hemostasis.csv")
heme_genes = hemostasis_genes.Gene.unique()

heme_all_genes = []
for gene in heme_genes:
    gene += "_proteomics"
    heme_all_genes.append(gene)

# %%
# Merge dfs of both cancers and keep only genes in a complete pathway
heme_bool = prot_df.Comparison.isin(heme_all_genes)
df = prot_df[heme_bool]
df
# Out:
#                Comparison  Correlation_Gbm   P_value_Gbm  Correlation_Brca  \
# 2         GRB2_proteomics        -0.610889  1.886384e-11         -0.177379
# 12        SHC1_proteomics        -0.540524  7.695118e-09          0.090908
# 22       TOR4A_proteomics        -0.513847  5.340485e-08          0.089115
# 44      DOCK10_proteomics        -0.489715  2.685098e-07               NaN
# 53     APBB1IP_proteomics        -0.483056  4.103970e-07          0.114010
# ...                   ...              ...           ...               ...
# 13696     PSG1_proteomics              NaN           NaN               NaN
# 13732    CALM1_proteomics              NaN           NaN               NaN
# 13898   KCNMB1_proteomics              NaN           NaN               NaN
# 13976     NFE2_proteomics              NaN           NaN               NaN
# 14024    TRPC6_proteomics              NaN           NaN               NaN
#
#        P_value_Brca
# 2          0.057899
# 12         0.333927
# 22         0.447068
# 44              NaN
# 53         0.225044
# ...             ...
# 13696           NaN
# 13732           NaN
# 13898           NaN
# 13976           NaN
# 14024           NaN
#
# [543 rows x 5 columns]

# %%
# Create pval only df for Color mapping
pval_df = df.drop(columns = ['Correlation_Gbm','Correlation_Brca'])
pval_df = pval_df.set_index('Comparison')
pval_df.head()
# Out:
#                      P_value_Gbm  P_value_Brca
# Comparison
# GRB2_proteomics     1.886384e-11      0.057899
# SHC1_proteomics     7.695118e-09      0.333927
# TOR4A_proteomics    5.340485e-08      0.447068
# DOCK10_proteomics   2.685098e-07           NaN
# APBB1IP_proteomics  4.103970e-07      0.225044

# %%
corr_df = df.drop(columns = ["P_value_Brca","Correlation_Brca"])
corr_df
# Out:
#                Comparison  Correlation_Gbm   P_value_Gbm
# 2         GRB2_proteomics        -0.610889  1.886384e-11
# 12        SHC1_proteomics        -0.540524  7.695118e-09
# 22       TOR4A_proteomics        -0.513847  5.340485e-08
# 44      DOCK10_proteomics        -0.489715  2.685098e-07
# 53     APBB1IP_proteomics        -0.483056  4.103970e-07
# ...                   ...              ...           ...
# 13696     PSG1_proteomics              NaN           NaN
# 13732    CALM1_proteomics              NaN           NaN
# 13898   KCNMB1_proteomics              NaN           NaN
# 13976     NFE2_proteomics              NaN           NaN
# 14024    TRPC6_proteomics              NaN           NaN
#
# [543 rows x 3 columns]

# %%
def GBM_pos(row):
    GBM_pos = False

    for item in row:
        if pd.isnull(item):
            continue
        if row['P_value_Gbm'] < 0.007264:
            if row['Correlation_Gbm'] > 0:
                GBM_pos = True
        else:
            GBM_pos = False
           
    return GBM_pos

# %%
corr_df['GBM_pos_sig'] = corr_df.apply(GBM_pos, axis=1)

corr_df = corr_df.loc[corr_df['GBM_pos_sig'] == True]
corr_df
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#               Comparison  Correlation_Gbm  P_value_Gbm  GBM_pos_sig
# 190      DGKZ_proteomics         0.426328     0.000011         True
# 284     PDGFA_proteomics         0.412905     0.000026         True
# 395     P2RY1_proteomics         0.387933     0.000073         True
# 416      YES1_proteomics         0.383762     0.000088         True
# 420   PPP2R1A_proteomics         0.383320     0.000090         True
# 454      SDC3_proteomics         0.378657     0.000111         True
# 480   SLC7A11_proteomics         0.374528     0.000134         True
# 536      DGKG_proteomics         0.366731     0.000189         True
# 573    KIF21A_proteomics         0.361513     0.000236         True
# 600    ATP1B2_proteomics         0.357573     0.000280         True
# 610     GNA12_proteomics         0.356588     0.000291         True
# 681   PPP2R5C_proteomics         0.346288     0.000446         True
# 721     ACTN2_proteomics         0.342394     0.000522         True
# 796       FYN_proteomics         0.334307     0.000720         True
# 820   PPP2R5A_proteomics         0.332076     0.000785         True
# 941        F3_proteomics         0.321497     0.001175         True
# 1049     RBSN_proteomics         0.310397     0.001767         True
# 1091    DAGLA_proteomics         0.307239     0.001979         True
# 1104     GNAS_proteomics         0.306073     0.002063         True
# 1136     DGKB_proteomics         0.303363     0.002271         True
# 1187     NOS2_proteomics         0.327766     0.002647         True
# 1306    FAM3C_proteomics         0.287897     0.003857         True
# 1319  RASGRP2_proteomics         0.286756     0.004007         True
# 1429  RASGRP1_proteomics         0.276847     0.005536         True
# 1506    PLCG1_proteomics         0.271862     0.006487         True
# 1557    GNAI3_proteomics         0.269345     0.007019         True

# %% [markdown]
# # Create the color column based on significance in both cancers

# %%
def Color(row):
    color = 'Not_sig'

    c1_cutoff = 0.007264# lowest p-value for cancer 1 (GBM)
    c2_cutoff = 0.013554 #Brca

    for item in row:
        if pd.isnull(item):
            continue
        if row['P_value_Brca'] <= c1_cutoff and row['P_value_Gbm'] <= c2_cutoff:
            color = 'Both_sig'
        elif row['P_value_Gbm'] <= c1_cutoff:
            color = 'Gbm_sig'
        elif row['P_value_Brca'] <= c2_cutoff:
            color = 'Brca_sig'
           
    return color

# %%
print('lowest p-value for GBM',cutoff_gbm, '\n')
print('lowest p-value for Brca:',cutoff_brca)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2b28b8aa836e> in <module>
# ----> 1 print('lowest p-value for GBM',cutoff_gbm, '\n')
#       2 print('lowest p-value for Brca:',cutoff_brca)
#
# NameError: name 'cutoff_gbm' is not defined

# %%
pval_df['Color'] = pval_df.apply(Color, axis=1)
color = pval_df[['Color']]
pval_df.head()
# Out:
#                      P_value_Gbm  P_value_Brca    Color
# Comparison
# GRB2_proteomics     1.886384e-11      0.057899  Gbm_sig
# SHC1_proteomics     7.695118e-09      0.333927  Gbm_sig
# TOR4A_proteomics    5.340485e-08      0.447068  Gbm_sig
# DOCK10_proteomics   2.685098e-07           NaN  Gbm_sig
# APBB1IP_proteomics  4.103970e-07      0.225044  Gbm_sig

# %% [markdown]
# # Format df for plot. Add color column and keep correlations.

# %%
color_df = color.reset_index()
plot_df = df.merge(color_df, on='Comparison')
plot_df= plot_df.drop(columns=['P_value_Gbm','P_value_Brca'])
plot_df.head()
# Out:
#            Comparison  Correlation_Gbm  Correlation_Brca    Color
# 0     GRB2_proteomics        -0.610889         -0.177379  Gbm_sig
# 1     SHC1_proteomics        -0.540524          0.090908  Gbm_sig
# 2    TOR4A_proteomics        -0.513847          0.089115  Gbm_sig
# 3   DOCK10_proteomics        -0.489715               NaN  Gbm_sig
# 4  APBB1IP_proteomics        -0.483056          0.114010  Gbm_sig

# %% [markdown]
# # Plot

# %%
def binary_corr_plot(prepared_df, x_axis_name, y_axis_name, title, save_file_name=None):
    
    color_dict = {'Both_sig':'green',
                  'Brca_sig':'yellow',
                  'Gbm_sig': 'blue',
                  'Not_sig': 'grey'}
    
    sns.set(font_scale = 1.2)
    #sns.axes_style("whitegrid")
    plt.figure(figsize=(10, 10))
    all_pvals = sns.scatterplot(x=prepared_df.columns[1], y=prepared_df.columns[2], data=prepared_df,
                               hue=prepared_df.columns[3], palette=color_dict)
    all_pvals.set_title(title)
        
    plt.xlabel(x_axis_name)
    plt.ylabel(y_axis_name)
    plt.xlim(-.7, .7) 
    plt.ylim(-.7, .7)
    
    if save_file_name is not None:
        plt.savefig(save_file_name+'.png')
    plt.show()
    #plt.clf()
    plt.close()
    return 0

# %%
binary_corr_plot(plot_df, 'Gbm Correlations', 'Brca Correlations','Correlations for the Hemostasis Pathway')
# Out:
# 0
