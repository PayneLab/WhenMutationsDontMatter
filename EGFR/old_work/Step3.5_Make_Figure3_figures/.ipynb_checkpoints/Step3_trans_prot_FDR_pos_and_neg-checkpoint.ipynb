# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math as math
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest
#sys.path.append('C:\\Users\\brittany\\henderson\\GitHub\\GBM_for_CPTAC\\')
#import cis_functions as f
#sys.path.append(R'C:\Users\Lindsey\Documents\GitHub\WhenMutationsDontMatter\\')
#import plot_utils as p


import cptac
import cptac.utils as u
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
from bokeh.palettes import RdBu
from bokeh.models import LinearColorMapper, ColumnDataSource, ColorBar
from bokeh.models.ranges import FactorRange
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.io import export_png
from bokeh.io import export_svgs


'''
@Param df: Dataframe. Contains column with x-axis categorical variables, y-axis categorical variables,
and columns for circle size and color gradient. 
@Param circle_var. String. Name of column for numeric data to base circle size off of 
@Param color_var. String. Name of column of numeric data to base color gradient off of. Can be the same or different as circle_var
@Param x_axis String. Name of column for x-axis categorical labels
@Param y_axis String. Name of column for y-axis categorical labels
@Param x_axis_lab. String. Default is no label. 
@Param y_axis_lab. String. Default is no label. 

This function creates a bokeh map that is heat map with extra variable of size of the circles. 

'''
def plotCircleHeatMap ( df, circle_var, color_var, x_axis, y_axis,x_axis_lab = "no_label", y_axis_lab = "no_label"):
  


    #added a new column to make the plot size
    df['size'] = np.where(df[circle_var]<0, np.abs(df[circle_var]), df[circle_var])*50
 

    colors = list((RdBu[9]))
    exp_cmap = LinearColorMapper(palette=colors, low = -.6, high = .6)
    p = figure(x_range = FactorRange(), y_range = FactorRange(), plot_width=1000, 
               plot_height=650, 
               toolbar_location=None, tools="hover")

    p.scatter(x_axis,y_axis,source=df, fill_alpha=1,  line_width=0, size="size", 
              fill_color={"field":color_var, "transform":exp_cmap})

    p.x_range.factors = sorted(df[x_axis].unique().tolist())
    p.y_range.factors = sorted(df[y_axis].unique().tolist(), reverse = True)
    p.xaxis.major_label_orientation = math.pi/2
    
    if (x_axis_lab != "no_label" ):
        p.xaxis.axis_label = x_axis_lab
    if (x_axis_lab != "no_label" ):   
        p.yaxis.axis_label = y_axis_lab

    bar = ColorBar(color_mapper=exp_cmap, location=(0,0))
    p.add_layout(bar, "right")
    output_notebook()
  
    show(p)

# %%
df_interacting = pd.read_csv("combining_pearson_dfs/csv_files/pancan_EGFR_pearson_interacting_prot_append.csv")
df_interacting = df_interacting.drop(['Unnamed: 0'], axis=1)
df_interacting
# Out:
#                Comparison  Correlation       P_value Cancer Type
# 0         EGFR_proteomics     1.000000  0.000000e+00         GBM
# 1         GRB2_proteomics    -0.610889  1.886384e-11         GBM
# 2         CDH4_proteomics     0.559180  1.790048e-09         GBM
# 3         SHC1_proteomics    -0.540524  7.695118e-09         GBM
# 4          WAS_proteomics    -0.501918  1.205168e-07         GBM
# ...                   ...          ...           ...         ...
# 7808      BCL2_proteomics    -0.001499  9.917570e-01        Lscc
# 7809  PPP1R12A_proteomics     0.000934  9.922710e-01        Lscc
# 7810     ARPC5_proteomics    -0.000894  9.926056e-01        Lscc
# 7811      AMOT_proteomics    -0.000791  9.934577e-01        Lscc
# 7812     APOA2_proteomics    -0.000170  9.985907e-01        Lscc
#
# [7813 rows x 4 columns]

# %%
pval_sig_3_4 = ['WAS_proteomics',
 'PPP2R3A_proteomics',
 'CTNNB1_proteomics',
 'PIK3AP1_proteomics',
 'PGM1_proteomics',
 'NFKB2_proteomics',
 'EML4_proteomics',
 'MET_proteomics',
 'ICAM1_proteomics',
 'PFKP_proteomics',
 'PRKCB_proteomics',
 'PDK1_proteomics',
 'SLC2A1_proteomics',
 'LAMC2_proteomics']
pval3_4= df_interacting[df_interacting.Comparison.isin(pval_sig_3_4)]
pval3_4
# Out:
#               Comparison  Correlation       P_value Cancer Type
# 4         WAS_proteomics    -0.501918  1.205168e-07         GBM
# 10    PPP2R3A_proteomics    -0.503777  4.157858e-07         GBM
# 22     CTNNB1_proteomics     0.460836  1.586832e-06         GBM
# 35    PIK3AP1_proteomics    -0.431734  8.125870e-06         GBM
# 36       PGM1_proteomics     0.428255  9.781084e-06         GBM
# ...                  ...          ...           ...         ...
# 7075     PFKP_proteomics     0.158388  9.839940e-02        Lscc
# 7120    NFKB2_proteomics     0.145248  1.300228e-01        Lscc
# 7588     EML4_proteomics     0.038605  6.888475e-01        Lscc
# 7721    ICAM1_proteomics     0.016023  8.680469e-01        Lscc
# 7730     PGM1_proteomics    -0.013702  8.870194e-01        Lscc
#
# [109 rows x 4 columns]

# %%
plotCircleHeatMap(pval3_4,"Correlation","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2101">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8efdf111-31fe-4d72-9a43-d60ede8fea85" data-root-id="2076"></div>

# %%
sigpvals = pval3_4[pval3_4["P_value"] < 0.0005]

# %%
#makes graph of interacting proteins that have 3 + cancers that have significant pvalues.
plotCircleHeatMap(sigpvals,"Correlation","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2668">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="989d6be6-62a8-4750-9b79-1e6e1f2eb52a" data-root-id="2643"></div>

# %%
ITG_prot = ["ITGB4_proteomics","ITGB1_proteomics","ITGA6_proteomics", "ITGAL_proteomics"]
            
itg_protdf = df_interacting[df_interacting.Comparison.isin(ITG_prot)]
itg_protdf
plotCircleHeatMap(itg_protdf,"Correlation","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3096">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="822f5d95-220c-4545-9d06-e752cd2565dc" data-root-id="3071"></div>

# %%
pathway2 = ["SHC1_phosphoproteomics_Y317","RAF1_phosphoproteomics_S621","RAF1_phosphoproteomics_S259","RAF1_phosphoproteomics_S338","RAF1_phosphoproteomics_Y340","RAF1_phosphoproteomics_Y341","MAP3K1_phosphoproteomics_S217","MAP3K1_phosphoproteomics_S221","MAPK3_phosphoproteomics_Y204","MAPK3_phosphoproteomics_T202Y204","MAPK3_phosphoproteomics_T202","MKNK1_phosphoproteomics_T197","MKNK1_phosphoproteomics_T202","ELF4_phosphoproteomics_S209","BCL2L11_phosphoproteomics_S69","RPS6KA1_phosphoproteomics_T573","RPS6KA3_phosphoproteomics_S573"]
pathway3 = ["GAB1_phosphoproteomics_Y446","GAB1_phosphoproteomics_Y472","GAB1_phosphoproteomics_Y589","PDPK1_phosphoproteomics_S241","AKT1_phosphoproteomics_S473","AKT1_phosphoproteomics_T308","CASP9_phosphoproteomics_S196","MDM2_phosphoproteomics_S166","GSK3B_phosphoproteomics_S9","FOXO_phosphoproteomics_T32","FOXO_phosphoproteomics_S253","MTOR_phosphoproteomics_S2448","TSC2_phosphoproteomics_T1462","S6K_phosphoproteomics_T389","BAD_phosphoproteomics_S134","EIF4EBP1_phosphoproteomics_T46","EIF4EBP1_phosphoproteomics_T45T46","EIF4EBP1_phosphoproteomics_T41T46"]

df3= df2[df2.Comparison.isin(pathway2)]
df3
# Out:
# Empty DataFrame
# Columns: [Comparison, Correlation, P_value, Cancer Type]
# Index: []

# %%
plotCircleHeatMap(df3,"Correlation","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2033">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="44afcc05-9d63-4e37-b6d1-83e877dc3c65" data-root-id="2008"></div>

# %%
df = pd.read_csv("pancan_EGFR_pearson_append_prot_phospho.csv")
df = df.drop(['Unnamed: 0'], axis=1)

df2 = df.drop([0])

# %%
pathway2 = ["SHC1_phosphoproteomics_Y317","RAF1_phosphoproteomics_S621","RAF1_phosphoproteomics_S259","RAF1_phosphoproteomics_S338","RAF1_phosphoproteomics_Y340","RAF1_phosphoproteomics_Y341","MAP3K1_phosphoproteomics_S217","MAP3K1_phosphoproteomics_S221","MAPK3_phosphoproteomics_Y204","MAPK3_phosphoproteomics_T202Y204","MAPK3_phosphoproteomics_T202","MKNK1_phosphoproteomics_T197","MKNK1_phosphoproteomics_T202","ELF4_phosphoproteomics_S209","BCL2L11_phosphoproteomics_S69","RPS6KA1_phosphoproteomics_T573","RPS6KA3_phosphoproteomics_S573"]
pathway3 = ["GAB1_phosphoproteomics_Y446","GAB1_phosphoproteomics_Y472","GAB1_phosphoproteomics_Y589","PDPK1_phosphoproteomics_S241","AKT1_phosphoproteomics_S473","AKT1_phosphoproteomics_T308","CASP9_phosphoproteomics_S196","MDM2_phosphoproteomics_S166","GSK3B_phosphoproteomics_S9","FOXO_phosphoproteomics_T32","FOXO_phosphoproteomics_S253","MTOR_phosphoproteomics_S2448","TSC2_phosphoproteomics_T1462","S6K_phosphoproteomics_T389","BAD_phosphoproteomics_S134","EIF4EBP1_phosphoproteomics_T46","EIF4EBP1_phosphoproteomics_T45T46","EIF4EBP1_phosphoproteomics_T41T46"]
statsigHigh_Low = ['HSD17B11_proteomics',
 'PPP2R3A_proteomics',
 'HAAO_proteomics',
 'CTNND2_proteomics',
 'EHBP1L1_proteomics',
 'MICALL1_proteomics',
 'RARA_proteomics',
 'CELSR1_proteomics']
df_prot_sig2 = df_prot_sig[df_prot_sig.Comparison.isin(statsigHigh_Low)]
df_prot_sig2
# Out:
#               Comparison  Correlation       P_value Cancer Type
# 41   HSD17B11_proteomics    -0.491843  2.340296e-07         GBM
# 54    PPP2R3A_proteomics    -0.503777  4.157858e-07         GBM
# 56       HAAO_proteomics    -0.481974  4.393106e-07         GBM
# 79     CTNND2_proteomics     0.470002  9.188543e-07         GBM
# 102   EHBP1L1_proteomics    -0.460074  1.659417e-06         GBM
# 207   MICALL1_proteomics    -0.435501  1.984850e-06      Kidney
# 356      RARA_proteomics    -0.483562  4.392067e-08        Brca
# 361  HSD17B11_proteomics     0.481667  5.044047e-08        Brca
# 393    CTNND2_proteomics    -0.468108  1.325474e-07        Brca
# 406      HAAO_proteomics     0.462999  1.887327e-07        Brca
# 431    CELSR1_proteomics    -0.452337  3.873966e-07        Brca
# 443   PPP2R3A_proteomics     0.446137  5.820667e-07        Brca
# 488   MICALL1_proteomics     0.433383  1.311735e-06        Brca
# 550   EHBP1L1_proteomics     0.420966  2.804677e-06        Brca
# ...

# %%
plotCircleHeatMap(df_prot_sig2,"Correlation","Correlation","Comparison","Cancer Type")
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2101">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="273d860c-f2ed-4c36-9c3a-e61e0d17d7fe" data-root-id="2076"></div>

# %%
pathway2 = ["GAB1_proteomics","PDPK1_phosphoproteomics_S241","AKT1_proteomics","AKT2_proteomics","AKT3_proteomics","CASP9_proteomics","MDM2_proteomics","GSK3B_proteomics","FOXO_proteomics","MTOR_proteomics","TSC2_proteomics","S6K_proteomics","BAD_proteomics","EIF4EBP1_proteomics"]
pos_neg = ['PPP2R3A_proteomics',
 'PIK3CD_proteomics',
 'RASAL3_proteomics',
 'PIK3AP1_proteomics',
 'HGF_proteomics',
 'RASSF1_proteomics',
 'FLNB_proteomics',
 'NFKB2_proteomics',
 'ITGB1_proteomics',
 'MYOF_proteomics',
 'PFN1_proteomics',
 'VCL_proteomics',
 'EML4_proteomics',
 'CDK6_proteomics',
 'HK3_proteomics',
 'MAP3K4_proteomics',
 'MET_proteomics',
 'PPP2R5A_proteomics',
 'CDH2_proteomics',
 'F2_proteomics',
 'SERPINE1_proteomics',
 'RASGRP2_proteomics',
 'MAPT_proteomics',
 'DEPTOR_proteomics',
 'C5_proteomics',
 'SELP_proteomics',
 'PRKCB_proteomics',
 'KIT_proteomics',
 'SLC5A6_proteomics',
 'PDK1_proteomics',
 'VWF_proteomics',
 'TNXB_proteomics']
pathway4 = ['PPP2R3A_proteomics',
 'PIK3CD_proteomics',
 'HCK_proteomics',
 'ITGB1_proteomics',
 'RASGRP2_proteomics',
 'MAPT_proteomics',
 'TBC1D1_proteomics',
 'UBE2T_proteomics']
df3= df2[df2.Comparison.isin(pos_neg)]
#df3.to_csv("EGFR_prot_heatmap_df.csv")
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-56e5868714e1> in <module>
#      40  'TBC1D1_proteomics',
#      41  'UBE2T_proteomics']
# ---> 42 df3= df2[df2.Comparison.isin(pos_neg)]
#      43 #df3.to_csv("EGFR_prot_heatmap_df.csv")
#      44 df3
#
# NameError: name 'df2' is not defined

# %%
df_FDR_2sig = pd.read_csv("csv_files/pancan_EGFR_all_FDR_atleast2_sig")

complement_genes = ['CFD','CPB2','ITGAM','CFH','C1S','C1R','SERPINC1','PROS1','SERPINE1','ITGB2','F13A1','PLG','C8B','C8A','CLU','KNG1','C2','C3','THBD','C5','C8G','C6','C7','PLAU','VSIG4','A2M','FGB','FGA','CR2','SERPINB2','VWF','F10','FGG','SERPINF2','F11','PLAUR','F2','F3','PROCR','F9','PROC','SERPING1','F13B','KLKB1','CFB']
gene_column_names = []
for gene in complement_genes:
    gene += "_proteomics"
    gene_column_names.append(gene)
len(gene_column_names)

df1 = df_FDR_2sig[df_FDR_2sig.Comparison.isin(gene_column_names)]
df1
# Out:
#                Comparison   P_value_Gbm  P_value_kidney  P_value_Ovar  \
# 47       PROCR_proteomics  8.763500e-07        0.002553           NaN
# 114      PLAUR_proteomics  1.122876e-05             NaN           NaN
# 141   SERPINB2_proteomics  1.749352e-05             NaN           NaN
# 182        FGB_proteomics  3.218521e-05             NaN           NaN
# 210        FGG_proteomics  4.899957e-05             NaN           NaN
# 256        FGA_proteomics  1.005188e-04             NaN           NaN
# 279         C2_proteomics  1.382574e-04             NaN      0.000607
# 288      F13A1_proteomics  1.536700e-04             NaN           NaN
# 304        F10_proteomics  1.834809e-04             NaN           NaN
# 313   SERPINF2_proteomics  2.056221e-04             NaN           NaN
# 349        C8A_proteomics  3.157269e-04             NaN      0.000048
# 356      ITGB2_proteomics  3.434888e-04             NaN           NaN
# ...

# %%
df_FDR_append = pd.read_csv("combining_pearson_dfs/csv_files/pancan_EGFR_pearson_sig_all_prot_append_FDR.csv")
df_FDR_append = df_FDR_append.drop(['Unnamed: 0'], axis=1)

df_FDR_append = df_FDR_append[df_FDR_append.Comparison.isin(gene_column_names)]
df_FDR_append
# Out:
#                 Comparison  Correlation       P_value Cancer Type
# 77        PROCR_proteomics    -0.470784  8.763500e-07         GBM
# 196       PLAUR_proteomics    -0.425639  1.122876e-05         GBM
# 244    SERPINB2_proteomics    -0.482756  1.749352e-05         GBM
# 305         FGB_proteomics    -0.404936  3.218521e-05         GBM
# 350         FGG_proteomics    -0.396275  4.899957e-05         GBM
# ...                    ...          ...           ...         ...
# 77647       CLU_proteomics    -0.034342  7.217108e-01        Lscc
# 77872  SERPINC1_proteomics    -0.030863  7.489112e-01        Lscc
# 77904     ITGB2_proteomics    -0.030324  7.531604e-01        Lscc
# 79271       A2M_proteomics     0.008291  9.314930e-01        Lscc
# 79390      CPB2_proteomics    -0.006454  9.466460e-01        Lscc
#
# [354 rows x 4 columns]

# %%
plotCircleHeatMap(df_FDR_append,"Correlation","Correlation","Comparison","Cancer Type")
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1029">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d57f8e4e-e3b0-4638-8cd5-4dfcddde169c" data-root-id="1004"></div>
