# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest
#sys.path.append('C:\\Users\\brittany\\henderson\\GitHub\\GBM_for_CPTAC\\')
#import cis_functions as f
#sys.path.append('C:\\Users\\Lindsey\\Documents\\GitHub\\WhenMutationsDontMatter\\')
#import plot_utils as p


import cptac
import cptac.utils as u

# %% [markdown]
# # GBM

# %%
df = pd.read_csv('GBM_EGFR_interacting.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#               Comparison     Slope     R_squared       P_value
# 0        EGFR_proteomics  1.000000  1.000000e+00  0.000000e+00
# 1        GRB2_proteomics -0.144746  3.731855e-01  1.886384e-11
# 2        CDH4_proteomics  0.210693  3.126820e-01  1.790048e-09
# 3        SHC1_proteomics -0.172666  2.921667e-01  7.695118e-09
# 4         WAS_proteomics -0.190787  2.519217e-01  1.205168e-07
# ...                  ...       ...           ...           ...
# 1068     GCC1_proteomics -0.000093  5.892153e-07  9.939836e-01
# 1069     MDM4_proteomics  0.000332  3.608709e-07  9.965602e-01
# 1070  ARHGEF6_proteomics -0.000072  1.172069e-07  9.973166e-01
# 1071   CALML3_proteomics  0.000052  1.066328e-07  9.975628e-01
# 1072     DLL3_proteomics  0.000137  1.271531e-07  9.976111e-01
#
# [1073 rows x 4 columns]

# %% [markdown]
# # Kidney

# %%
df2 = pd.read_csv('Kidney_EGFR_interacting.csv')

# %%
df2 = df2.drop(['Unnamed: 0'], axis=1)
df2
# Out:
#              Comparison     Slope     R_squared       P_value
# 0       EGFR_proteomics  1.000000  1.000000e+00  0.000000e+00
# 1      PLCB1_proteomics  0.909855  3.157904e-01  1.684847e-10
# 2      ENPP3_proteomics  1.082711  3.074667e-01  3.278203e-10
# 3       PGK1_proteomics  0.632780  2.835027e-01  2.138266e-09
# 4      CDC42_proteomics  0.632780  2.835027e-01  2.138266e-09
# ...                 ...       ...           ...           ...
# 1085   PARVA_proteomics  0.000694  5.130713e-07  9.940744e-01
# 1086   RPTOR_proteomics -0.000222  3.009477e-07  9.954617e-01
# 1087     FGR_proteomics -0.000792  4.453284e-07  9.958584e-01
# 1088   GSTA1_proteomics  0.001096  2.360075e-07  9.959811e-01
# 1089  PIK3R1_proteomics  0.000148  6.316275e-08  9.979209e-01
#
# [1090 rows x 4 columns]

# %%
Gbm_kidney = pd.merge(df, df2, on="Comparison", how = "outer")
Gbm_kidney = Gbm_kidney.rename(columns={"Slope_x": "Slope_Gbm", "R_squared_x": "R_squared_gbm","P_value_x": "P_value_Gbm" })
Gbm_kidney = Gbm_kidney.rename(columns={"Slope_y": "Slope_kidney", "R_squared_y": "R_squared_kidney","P_value_y": "P_value_kidney" })
#Gbm_kidney.to_csv("GBM_Kidney_EGFR_all.csv")
Gbm_kidney
# Out:
#              Comparison  Slope_Gbm  R_squared_gbm   P_value_Gbm  Slope_kidney  \
# 0       EGFR_proteomics   1.000000       1.000000  0.000000e+00      1.000000
# 1       GRB2_proteomics  -0.144746       0.373186  1.886384e-11     -0.139721
# 2       CDH4_proteomics   0.210693       0.312682  1.790048e-09      0.430426
# 3       SHC1_proteomics  -0.172666       0.292167  7.695118e-09     -0.072251
# 4        WAS_proteomics  -0.190787       0.251922  1.205168e-07     -0.321553
# ...                 ...        ...            ...           ...           ...
# 1220  UGT2B7_proteomics        NaN            NaN           NaN     -0.020317
# 1221   ABCC5_proteomics        NaN            NaN           NaN     -0.038441
# 1222  SLC5A9_proteomics        NaN            NaN           NaN      0.016336
# 1223  SLC5A1_proteomics        NaN            NaN           NaN     -0.012941
# 1224   GNG10_proteomics        NaN            NaN           NaN     -0.001860
#
#       R_squared_kidney  P_value_kidney
# 0             1.000000        0.000000
# 1             0.047274        0.022506
# 2             0.022025        0.257781
# 3             0.010417        0.288685
# 4             0.078296        0.003071
# ...                ...             ...
# 1220          0.000117        0.910602
# 1221          0.000637        0.911241
# 1222          0.000103        0.919863
# 1223          0.000036        0.950529
# 1224          0.000004        0.983552
#
# [1225 rows x 7 columns]

# %% [markdown]
# # Endometrial

# %%
df3 = pd.read_csv("Endo_EGFR_interacting.csv")
df3 = df3.drop(['Unnamed: 0'], axis=1)
df3
# Out:
#               Comparison     Slope     R_squared       P_value
# 0        EGFR_proteomics  1.000000  1.000000e+00  0.000000e+00
# 1       LPAR1_proteomics  0.763965  4.519632e-01  2.158643e-11
# 2        FZD1_proteomics  0.771063  3.742180e-01  4.532118e-11
# 3     SLC27A1_proteomics  0.482267  3.714514e-01  5.583582e-11
# 4       ITGA6_proteomics  0.685658  3.605320e-01  1.261442e-10
# ...                  ...       ...           ...           ...
# 1041      RB1_proteomics  0.000924  1.960910e-06  9.892544e-01
# 1042    ACTR2_proteomics  0.000770  1.412644e-06  9.908794e-01
# 1043   PFKFB2_proteomics -0.000949  8.390036e-07  9.929710e-01
# 1044   TXNRD3_proteomics -0.000476  7.175815e-07  9.934995e-01
# 1045   TSG101_proteomics -0.000264  5.571820e-07  9.942719e-01
#
# [1046 rows x 4 columns]

# %%
pancan = pd.merge(Gbm_kidney, df3, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Slope": "Slope_Endo", "R_squared": "R_squared_Endo","P_value": "P_value_Endo" })
pancan
# Out:
#               Comparison  Slope_Gbm  R_squared_gbm   P_value_Gbm  \
# 0        EGFR_proteomics   1.000000       1.000000  0.000000e+00
# 1        GRB2_proteomics  -0.144746       0.373186  1.886384e-11
# 2        CDH4_proteomics   0.210693       0.312682  1.790048e-09
# 3        SHC1_proteomics  -0.172666       0.292167  7.695118e-09
# 4         WAS_proteomics  -0.190787       0.251922  1.205168e-07
# ...                  ...        ...            ...           ...
# 1264   ATP2C2_proteomics        NaN            NaN           NaN
# 1265     KLF4_proteomics        NaN            NaN           NaN
# 1266     MYL2_proteomics        NaN            NaN           NaN
# 1267   CYP2A6_proteomics        NaN            NaN           NaN
# 1268  CREB3L1_proteomics        NaN            NaN           NaN
#
#       Slope_kidney  R_squared_kidney  P_value_kidney  Slope_Endo  \
# 0         1.000000          1.000000        0.000000    1.000000
# 1        -0.139721          0.047274        0.022506   -0.242075
# 2         0.430426          0.022025        0.257781         NaN
# 3        -0.072251          0.010417        0.288685   -0.089091
# 4        -0.321553          0.078296        0.003071   -0.221633
# ...            ...               ...             ...         ...
# 1264           NaN               NaN             NaN   -0.032389
# 1265           NaN               NaN             NaN    0.053374
# 1266           NaN               NaN             NaN   -0.015171
# 1267           NaN               NaN             NaN    0.016996
# 1268           NaN               NaN             NaN   -0.017218
#
#       R_squared_Endo  P_value_Endo
# 0           1.000000      0.000000
# 1           0.191263      0.000009
# 2                NaN           NaN
# 3           0.043423      0.042716
# 4           0.056790      0.020041
# ...              ...           ...
# 1264        0.001433      0.761000
# 1265        0.001063      0.771211
# 1266        0.000716      0.796820
# 1267        0.000457      0.837094
# 1268        0.000315      0.934430
#
# [1269 rows x 10 columns]

# %% [markdown]
# # Ovarian

# %%
df_Ovar = pd.read_csv("Ovar_EGFR_interacting.csv")
df_Ovar = df_Ovar.drop(['Unnamed: 0'], axis=1)
df_Ovar
# Out:
#              Comparison     Slope     R_squared   P_value
# 0       EGFR_proteomics  1.000000  1.000000e+00  0.000000
# 1     SLC2A4_proteomics  1.581427  4.594058e-01  0.000015
# 2     LGALS3_proteomics  0.759002  1.975620e-01  0.000026
# 3      DOCK1_proteomics  0.394575  1.935305e-01  0.000032
# 4      GNG12_proteomics  0.499099  1.912210e-01  0.000036
# ...                 ...       ...           ...       ...
# 1002    RGL1_proteomics -0.002146  2.292668e-06  0.992602
# 1003    TAB2_proteomics -0.000325  1.052694e-07  0.997677
# 1004  NFATC3_proteomics -0.000275  2.531437e-08  0.998861
# 1005    FGD1_proteomics -0.000373  4.965889e-08  0.998971
# 1006   CALM2_proteomics -0.000106  4.675101e-09  0.999511
#
# [1007 rows x 4 columns]

# %%
pancan = pd.merge(pancan, df_Ovar, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Slope": "Slope_Ovar", "R_squared": "R_squared_Ovar","P_value": "P_value_Ovar" })
pancan
# Out:
#              Comparison  Slope_Gbm  R_squared_gbm   P_value_Gbm  Slope_kidney  \
# 0       EGFR_proteomics   1.000000       1.000000  0.000000e+00      1.000000
# 1       GRB2_proteomics  -0.144746       0.373186  1.886384e-11     -0.139721
# 2       CDH4_proteomics   0.210693       0.312682  1.790048e-09      0.430426
# 3       SHC1_proteomics  -0.172666       0.292167  7.695118e-09     -0.072251
# 4        WAS_proteomics  -0.190787       0.251922  1.205168e-07     -0.321553
# ...                 ...        ...            ...           ...           ...
# 1284  COL6A6_proteomics        NaN            NaN           NaN           NaN
# 1285   MYLK2_proteomics        NaN            NaN           NaN           NaN
# 1286    TFF2_proteomics        NaN            NaN           NaN           NaN
# 1287  COL6A5_proteomics        NaN            NaN           NaN           NaN
# 1288  WNT10A_proteomics        NaN            NaN           NaN           NaN
#
#       R_squared_kidney  P_value_kidney  Slope_Endo  R_squared_Endo  \
# 0             1.000000        0.000000    1.000000        1.000000
# 1             0.047274        0.022506   -0.242075        0.191263
# 2             0.022025        0.257781         NaN             NaN
# 3             0.010417        0.288685   -0.089091        0.043423
# 4             0.078296        0.003071   -0.221633        0.056790
# ...                ...             ...         ...             ...
# 1284               NaN             NaN         NaN             NaN
# 1285               NaN             NaN         NaN             NaN
# 1286               NaN             NaN         NaN             NaN
# 1287               NaN             NaN         NaN             NaN
# 1288               NaN             NaN         NaN             NaN
#
#       P_value_Endo  Slope_Ovar  R_squared_Ovar  P_value_Ovar
# 0         0.000000    1.000000        1.000000      0.000000
# 1         0.000009   -0.163008        0.036134      0.085202
# 2              NaN         NaN             NaN           NaN
# 3         0.042716    0.121217        0.030659      0.113358
# 4         0.020041   -0.158033        0.008175      0.416288
# ...            ...         ...             ...           ...
# 1284           NaN    0.125340        0.003152      0.614179
# 1285           NaN    0.106930        0.003057      0.637550
# 1286           NaN   -0.072860        0.002153      0.677014
# 1287           NaN    0.089564        0.000830      0.795971
# 1288           NaN    0.127813        0.003173      0.808366
#
# [1289 rows x 13 columns]

# %% [markdown]
# # BRCA

# %%
df_Brca = pd.read_csv("Brca_EGFR_interacting.csv")
df_Brca = df_Brca.drop(['Unnamed: 0'], axis=1)
df_Brca
# Out:
#               Comparison     Slope     R_squared       P_value
# 0        EGFR_proteomics  1.000000  1.000000e+00  0.000000e+00
# 1       PSAT1_proteomics  1.051931  3.712693e-01  4.973595e-13
# 2     ANGPTL4_proteomics  0.741152  3.513292e-01  2.980158e-12
# 3     PLA2G4A_proteomics  0.518085  3.389125e-01  8.850043e-12
# 4        PFKP_proteomics  0.537796  3.109685e-01  9.562825e-11
# ..                   ...       ...           ...           ...
# 948      PAK4_proteomics -0.000565  9.031676e-07  9.919574e-01
# 949  HSP90AA1_proteomics -0.000284  8.235590e-07  9.923200e-01
# 950      TNXB_proteomics  0.000972  6.855229e-07  9.929931e-01
# 951     RASA4_proteomics  0.000206  9.491605e-08  9.973927e-01
# 952      GNG5_proteomics -0.000006  9.574159e-11  9.999172e-01
#
# [953 rows x 4 columns]

# %%
pancan = pd.merge(pancan, df_Brca, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Slope": "Slope_Brca", "R_squared": "R_squared_Brca","P_value": "P_value_Brca" })
pancan
# Out:
#                Comparison  Slope_Gbm  R_squared_gbm   P_value_Gbm  \
# 0         EGFR_proteomics   1.000000       1.000000  0.000000e+00
# 1         GRB2_proteomics  -0.144746       0.373186  1.886384e-11
# 2         CDH4_proteomics   0.210693       0.312682  1.790048e-09
# 3         SHC1_proteomics  -0.172666       0.292167  7.695118e-09
# 4          WAS_proteomics  -0.190787       0.251922  1.205168e-07
# ...                   ...        ...            ...           ...
# 1298      ZIC2_proteomics        NaN            NaN           NaN
# 1299    MAPK15_proteomics        NaN            NaN           NaN
# 1300  HLA-DQA2_proteomics        NaN            NaN           NaN
# 1301     LAMB4_proteomics        NaN            NaN           NaN
# 1302       ZAK_proteomics        NaN            NaN           NaN
#
#       Slope_kidney  R_squared_kidney  P_value_kidney  Slope_Endo  \
# 0         1.000000          1.000000        0.000000    1.000000
# 1        -0.139721          0.047274        0.022506   -0.242075
# 2         0.430426          0.022025        0.257781         NaN
# 3        -0.072251          0.010417        0.288685   -0.089091
# 4        -0.321553          0.078296        0.003071   -0.221633
# ...            ...               ...             ...         ...
# 1298           NaN               NaN             NaN         NaN
# 1299           NaN               NaN             NaN         NaN
# 1300           NaN               NaN             NaN         NaN
# 1301           NaN               NaN             NaN         NaN
# 1302           NaN               NaN             NaN         NaN
#
#       R_squared_Endo  P_value_Endo  Slope_Ovar  R_squared_Ovar  P_value_Ovar  \
# 0           1.000000      0.000000    1.000000        1.000000      0.000000
# 1           0.191263      0.000009   -0.163008        0.036134      0.085202
# 2                NaN           NaN         NaN             NaN           NaN
# 3           0.043423      0.042716    0.121217        0.030659      0.113358
# 4           0.056790      0.020041   -0.158033        0.008175      0.416288
# ...              ...           ...         ...             ...           ...
# 1298             NaN           NaN         NaN             NaN           NaN
# 1299             NaN           NaN         NaN             NaN           NaN
# 1300             NaN           NaN         NaN             NaN           NaN
# 1301             NaN           NaN         NaN             NaN           NaN
# 1302             NaN           NaN         NaN             NaN           NaN
#
#       Slope_Brca  R_squared_Brca  P_value_Brca
# 0       1.000000        1.000000      0.000000
# 1      -0.103359        0.031463      0.057899
# 2            NaN             NaN           NaN
# 3       0.035651        0.008264      0.333927
# 4       0.107548        0.023561      0.101463
# ...          ...             ...           ...
# 1298   -0.142697        0.012302      0.525886
# 1299    0.052256        0.002911      0.566876
# 1300    0.075680        0.003984      0.609084
# 1301    0.042367        0.001038      0.771134
# 1302    0.012157        0.000402      0.831480
#
# [1303 rows x 16 columns]

# %% [markdown]
# # Luad

# %%
df_Luad = pd.read_csv("Luad_EGFR_interacting.csv")
df_Luad = df_Luad.drop(['Unnamed: 0'], axis=1)
df_Luad
# Out:
#               Comparison     Slope     R_squared       P_value
# 0        EGFR_proteomics  1.000000  1.000000e+00  0.000000e+00
# 1         MET_proteomics  0.522022  2.358962e-01  7.518188e-08
# 2     RASGRP2_proteomics -0.234230  2.239157e-01  1.784433e-07
# 3      STAT5B_proteomics -0.132764  2.066476e-01  6.077744e-07
# 4      PPP3CB_proteomics -0.123260  2.013573e-01  8.806545e-07
# ...                  ...       ...           ...           ...
# 1000     STOM_proteomics  0.000906  3.132999e-06  9.853579e-01
# 1001     GJA1_proteomics -0.000907  1.160819e-06  9.910871e-01
# 1002     RHOA_proteomics -0.000094  7.681057e-08  9.977073e-01
# 1003   MAP4K4_proteomics  0.000214  9.837932e-08  9.977546e-01
# 1004     THBD_proteomics -0.000024  2.459608e-09  9.995897e-01
#
# [1005 rows x 4 columns]

# %%
pancan = pd.merge(pancan, df_Luad, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Slope": "Slope_Luad", "R_squared": "R_squared_Luad","P_value": "P_value_Luad" })
pancan
# Out:
#                Comparison  Slope_Gbm  R_squared_gbm   P_value_Gbm  \
# 0         EGFR_proteomics   1.000000       1.000000  0.000000e+00
# 1         GRB2_proteomics  -0.144746       0.373186  1.886384e-11
# 2         CDH4_proteomics   0.210693       0.312682  1.790048e-09
# 3         SHC1_proteomics  -0.172666       0.292167  7.695118e-09
# 4          WAS_proteomics  -0.190787       0.251922  1.205168e-07
# ...                   ...        ...            ...           ...
# 1314     CALM3_proteomics        NaN            NaN           NaN
# 1315  HLA-DQB2_proteomics        NaN            NaN           NaN
# 1316      IL7R_proteomics        NaN            NaN           NaN
# 1317      AGER_proteomics        NaN            NaN           NaN
# 1318      FLT3_proteomics        NaN            NaN           NaN
#
#       Slope_kidney  R_squared_kidney  P_value_kidney  Slope_Endo  \
# 0         1.000000          1.000000        0.000000    1.000000
# 1        -0.139721          0.047274        0.022506   -0.242075
# 2         0.430426          0.022025        0.257781         NaN
# 3        -0.072251          0.010417        0.288685   -0.089091
# 4        -0.321553          0.078296        0.003071   -0.221633
# ...            ...               ...             ...         ...
# 1314           NaN               NaN             NaN         NaN
# 1315           NaN               NaN             NaN         NaN
# 1316           NaN               NaN             NaN         NaN
# 1317           NaN               NaN             NaN         NaN
# 1318           NaN               NaN             NaN         NaN
#
#       R_squared_Endo  P_value_Endo  Slope_Ovar  R_squared_Ovar  P_value_Ovar  \
# 0           1.000000      0.000000    1.000000        1.000000      0.000000
# 1           0.191263      0.000009   -0.163008        0.036134      0.085202
# 2                NaN           NaN         NaN             NaN           NaN
# 3           0.043423      0.042716    0.121217        0.030659      0.113358
# 4           0.056790      0.020041   -0.158033        0.008175      0.416288
# ...              ...           ...         ...             ...           ...
# 1314             NaN           NaN         NaN             NaN           NaN
# 1315             NaN           NaN         NaN             NaN           NaN
# 1316             NaN           NaN         NaN             NaN           NaN
# 1317             NaN           NaN         NaN             NaN           NaN
# 1318             NaN           NaN         NaN             NaN           NaN
#
#       Slope_Brca  R_squared_Brca  P_value_Brca  Slope_Luad  R_squared_Luad  \
# 0       1.000000        1.000000      0.000000    1.000000        1.000000
# 1      -0.103359        0.031463      0.057899   -0.117969        0.091469
# 2            NaN             NaN           NaN         NaN             NaN
# 3       0.035651        0.008264      0.333927   -0.044624        0.018453
# 4       0.107548        0.023561      0.101463   -0.141161        0.114182
# ...          ...             ...           ...         ...             ...
# 1314         NaN             NaN           NaN   -0.015590        0.007601
# 1315         NaN             NaN           NaN    0.109471        0.006060
# 1316         NaN             NaN           NaN   -0.073571        0.005041
# 1317         NaN             NaN           NaN   -0.020178        0.001086
# 1318         NaN             NaN           NaN   -0.014606        0.000578
#
#       P_value_Luad
# 0         0.000000
# 1         0.001321
# 2              NaN
# 3         0.262164
# 4         0.000306
# ...            ...
# 1314      0.365109
# 1315      0.484233
# 1316      0.577162
# 1317      0.732554
# 1318      0.803118
#
# [1319 rows x 19 columns]

# %% [markdown]
# # HNSCC

# %%
df_hnscc = pd.read_csv("Hnscc_EGFR_interacting.csv")
df_hnscc = df_hnscc.drop(['Unnamed: 0'], axis=1)
df_hnscc
# Out:
#              Comparison     Slope     R_squared       P_value
# 0       EGFR_proteomics  1.000000  1.000000e+00  0.000000e+00
# 1       GRB2_proteomics -0.139484  2.833872e-01  2.559824e-09
# 2       JAG1_proteomics  0.348976  2.697427e-01  7.186589e-09
# 3       PKN1_proteomics -0.182289  2.585699e-01  1.651710e-08
# 4        WAS_proteomics -0.252972  2.534386e-01  2.411333e-08
# ...                 ...       ...           ...           ...
# 1135  CLEC4G_proteomics  0.000873  1.304470e-06  9.926247e-01
# 1136   LTB4R_proteomics -0.000463  3.210372e-07  9.964836e-01
# 1137    MBL2_proteomics -0.000278  1.453547e-07  9.968607e-01
# 1138   FANCI_proteomics -0.000215  1.432930e-07  9.968831e-01
# 1139  PRKAG1_proteomics -0.000033  2.534968e-08  9.986890e-01
#
# [1140 rows x 4 columns]

# %%
pancan = pd.merge(pancan, df_hnscc, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Slope": "Slope_hnscc", "R_squared": "R_squared_hnscc","P_value": "P_value_hnscc" })
pancan
# Out:
#               Comparison  Slope_Gbm  R_squared_gbm   P_value_Gbm  \
# 0        EGFR_proteomics   1.000000       1.000000  0.000000e+00
# 1        GRB2_proteomics  -0.144746       0.373186  1.886384e-11
# 2        CDH4_proteomics   0.210693       0.312682  1.790048e-09
# 3        SHC1_proteomics  -0.172666       0.292167  7.695118e-09
# 4         WAS_proteomics  -0.190787       0.251922  1.205168e-07
# ...                  ...        ...            ...           ...
# 1343    CALM1_proteomics        NaN            NaN           NaN
# 1344   UGT1A7_proteomics        NaN            NaN           NaN
# 1345  PLA2G4D_proteomics        NaN            NaN           NaN
# 1346    RAD51_proteomics        NaN            NaN           NaN
# 1347   CLEC4G_proteomics        NaN            NaN           NaN
#
#       Slope_kidney  R_squared_kidney  P_value_kidney  Slope_Endo  \
# 0         1.000000          1.000000        0.000000    1.000000
# 1        -0.139721          0.047274        0.022506   -0.242075
# 2         0.430426          0.022025        0.257781         NaN
# 3        -0.072251          0.010417        0.288685   -0.089091
# 4        -0.321553          0.078296        0.003071   -0.221633
# ...            ...               ...             ...         ...
# 1343           NaN               NaN             NaN         NaN
# 1344           NaN               NaN             NaN         NaN
# 1345           NaN               NaN             NaN         NaN
# 1346           NaN               NaN             NaN         NaN
# 1347           NaN               NaN             NaN         NaN
#
#       R_squared_Endo  P_value_Endo  ...  P_value_Ovar  Slope_Brca  \
# 0           1.000000      0.000000  ...      0.000000    1.000000
# 1           0.191263      0.000009  ...      0.085202   -0.103359
# 2                NaN           NaN  ...           NaN         NaN
# 3           0.043423      0.042716  ...      0.113358    0.035651
# 4           0.056790      0.020041  ...      0.416288    0.107548
# ...              ...           ...  ...           ...         ...
# 1343             NaN           NaN  ...           NaN         NaN
# 1344             NaN           NaN  ...           NaN         NaN
# 1345             NaN           NaN  ...           NaN         NaN
# 1346             NaN           NaN  ...           NaN         NaN
# 1347             NaN           NaN  ...           NaN         NaN
#
#       R_squared_Brca  P_value_Brca  Slope_Luad  R_squared_Luad  P_value_Luad  \
# 0           1.000000      0.000000    1.000000        1.000000      0.000000
# 1           0.031463      0.057899   -0.117969        0.091469      0.001321
# 2                NaN           NaN         NaN             NaN           NaN
# 3           0.008264      0.333927   -0.044624        0.018453      0.262164
# 4           0.023561      0.101463   -0.141161        0.114182      0.000306
# ...              ...           ...         ...             ...           ...
# 1343             NaN           NaN         NaN             NaN           NaN
# 1344             NaN           NaN         NaN             NaN           NaN
# 1345             NaN           NaN         NaN             NaN           NaN
# 1346             NaN           NaN         NaN             NaN           NaN
# 1347             NaN           NaN         NaN             NaN           NaN
#
#       Slope_hnscc  R_squared_hnscc  P_value_hnscc
# 0        1.000000         1.000000   0.000000e+00
# 1       -0.139484         0.283387   2.559824e-09
# 2       -0.074915         0.024282   1.056600e-01
# 3       -0.021862         0.007381   3.744159e-01
# 4       -0.252972         0.253439   2.411333e-08
# ...           ...              ...            ...
# 1343    -0.009178         0.001650   6.749904e-01
# 1344     0.032966         0.001398   6.995134e-01
# 1345     0.046613         0.002034   7.128887e-01
# 1346     0.022714         0.002591   7.582732e-01
# 1347     0.000873         0.000001   9.926247e-01
#
# [1348 rows x 22 columns]

# %% [markdown]
# # Colon

# %%
df_colon = pd.read_csv("Colon_EGFR_interacting.csv")
df_colon = df_colon.drop(['Unnamed: 0'], axis=1)
df_colon
# Out:
#              Comparison     Slope     R_squared   P_value
# 0       EGFR_proteomics  1.000000  1.000000e+00  0.000000
# 1    PPP2R5D_proteomics -0.235705  2.071256e-01  0.000003
# 2     TBC1D1_proteomics  0.463660  1.847957e-01  0.000017
# 3       PLD1_proteomics  0.431354  1.757448e-01  0.000029
# 4     PPP1CC_proteomics  0.387365  1.603133e-01  0.000048
# ..                  ...       ...           ...       ...
# 825  LAMTOR3_proteomics  0.001138  2.029891e-06  0.988950
# 826    WASF2_proteomics -0.000841  1.801928e-06  0.989588
# 827  CYP4F12_proteomics -0.001329  6.355311e-07  0.994736
# 828   TSG101_proteomics -0.000172  2.013677e-07  0.996519
# 829    MAPK1_proteomics -0.000173  1.593058e-07  0.996904
#
# [830 rows x 4 columns]

# %%
pancan = pd.merge(pancan, df_colon, on="Comparison", how = "outer")
pancan = pancan.rename(columns={"Slope": "Slope_colon", "R_squared": "R_squared_colon","P_value": "P_value_colon" })
pancan
# Out:
#               Comparison  Slope_Gbm  R_squared_gbm   P_value_Gbm  \
# 0        EGFR_proteomics   1.000000       1.000000  0.000000e+00
# 1        GRB2_proteomics  -0.144746       0.373186  1.886384e-11
# 2        CDH4_proteomics   0.210693       0.312682  1.790048e-09
# 3        SHC1_proteomics  -0.172666       0.292167  7.695118e-09
# 4         WAS_proteomics  -0.190787       0.251922  1.205168e-07
# ...                  ...        ...            ...           ...
# 1344   UGT1A7_proteomics        NaN            NaN           NaN
# 1345  PLA2G4D_proteomics        NaN            NaN           NaN
# 1346    RAD51_proteomics        NaN            NaN           NaN
# 1347   CLEC4G_proteomics        NaN            NaN           NaN
# 1348   CYP3A4_proteomics        NaN            NaN           NaN
#
#       Slope_kidney  R_squared_kidney  P_value_kidney  Slope_Endo  \
# 0         1.000000          1.000000        0.000000    1.000000
# 1        -0.139721          0.047274        0.022506   -0.242075
# 2         0.430426          0.022025        0.257781         NaN
# 3        -0.072251          0.010417        0.288685   -0.089091
# 4        -0.321553          0.078296        0.003071   -0.221633
# ...            ...               ...             ...         ...
# 1344           NaN               NaN             NaN         NaN
# 1345           NaN               NaN             NaN         NaN
# 1346           NaN               NaN             NaN         NaN
# 1347           NaN               NaN             NaN         NaN
# 1348           NaN               NaN             NaN         NaN
#
#       R_squared_Endo  P_value_Endo  ...  P_value_Brca  Slope_Luad  \
# 0           1.000000      0.000000  ...      0.000000    1.000000
# 1           0.191263      0.000009  ...      0.057899   -0.117969
# 2                NaN           NaN  ...           NaN         NaN
# 3           0.043423      0.042716  ...      0.333927   -0.044624
# 4           0.056790      0.020041  ...      0.101463   -0.141161
# ...              ...           ...  ...           ...         ...
# 1344             NaN           NaN  ...           NaN         NaN
# 1345             NaN           NaN  ...           NaN         NaN
# 1346             NaN           NaN  ...           NaN         NaN
# 1347             NaN           NaN  ...           NaN         NaN
# 1348             NaN           NaN  ...           NaN         NaN
#
#       R_squared_Luad  P_value_Luad  Slope_hnscc  R_squared_hnscc  \
# 0           1.000000      0.000000     1.000000         1.000000
# 1           0.091469      0.001321    -0.139484         0.283387
# 2                NaN           NaN    -0.074915         0.024282
# 3           0.018453      0.262164    -0.021862         0.007381
# 4           0.114182      0.000306    -0.252972         0.253439
# ...              ...           ...          ...              ...
# 1344             NaN           NaN     0.032966         0.001398
# 1345             NaN           NaN     0.046613         0.002034
# 1346             NaN           NaN     0.022714         0.002591
# 1347             NaN           NaN     0.000873         0.000001
# 1348             NaN           NaN          NaN              NaN
#
#       P_value_hnscc  Slope_colon  R_squared_colon  P_value_colon
# 0      0.000000e+00     1.000000         1.000000       0.000000
# 1      2.559824e-09     0.148896         0.022789       0.139949
# 2      1.056600e-01          NaN              NaN            NaN
# 3      3.744159e-01     0.112514         0.041311       0.045855
# 4      2.411333e-08     0.281327         0.079750       0.005070
# ...             ...          ...              ...            ...
# 1344   6.995134e-01          NaN              NaN            NaN
# 1345   7.128887e-01          NaN              NaN            NaN
# 1346   7.582732e-01          NaN              NaN            NaN
# 1347   9.926247e-01          NaN              NaN            NaN
# 1348            NaN     0.114074         0.007525       0.549176
#
# [1349 rows x 25 columns]

# %%
pancan.to_csv("pancan_EGFR.csv")
