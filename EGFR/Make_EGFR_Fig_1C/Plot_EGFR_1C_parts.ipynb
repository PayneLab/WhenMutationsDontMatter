# %% [markdown]
# # 2 Dimensional Histograms

# %% [markdown]
# Download data frame that has FDR corrected pvalues for all trans proteins. (See notebook EGFR_Fig_1C_data_munging in this folder) Next, calculate the total number of p values significant for each trans protein. Then calculate the mean and standard deviation of pvalues/ Pearson correlations across a trans gene.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest

import cptac
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df_fdr_pvals = pd.read_csv("Pval_corr_table_Fig_1C.csv")
df_fdr_pvals = df_fdr_pvals.drop(['Unnamed: 0'], axis=1)
df_fdr_pvals = df_fdr_pvals.set_index("Comparison")
df_fdr_pvals = df_fdr_pvals[1:] #Drop EGFR 
df_fdr_pvals
# Out:
#                     Correlation_Gbm   P_value_Gbm  Correlation_kidney  \
# Comparison
# PHLDA1_proteomics          0.816848  3.507071e-21            0.254436
# GRB2_proteomics           -0.610889  6.729990e-08           -0.217427
# SOCS2_proteomics           0.562720  3.420388e-06                 NaN
# CDH4_proteomics            0.559180  3.420388e-06            0.148407
# DAB2_proteomics           -0.556402  3.420388e-06           -0.076173
# ...                             ...           ...                 ...
# ZNF283_proteomics               NaN           NaN                 NaN
# TRIM39_proteomics               NaN           NaN                 NaN
# ADGRA3_proteomics               NaN           NaN                 NaN
# CEP57L1_proteomics              NaN           NaN                 NaN
# AIMP1_proteomics_1              NaN           NaN                 NaN
#
#                     P_value_kidney  Correlation_Ovar  P_value_Ovar  \
# Comparison
# PHLDA1_proteomics         0.060261               NaN           NaN
# GRB2_proteomics           0.120342         -0.190090      0.346111
# SOCS2_proteomics               NaN               NaN           NaN
# CDH4_proteomics           0.513490               NaN           NaN
# DAB2_proteomics           0.673774          0.076981      0.750510
# ...                            ...               ...           ...
# ZNF283_proteomics              NaN               NaN           NaN
# TRIM39_proteomics              NaN               NaN           NaN
# ADGRA3_proteomics              NaN               NaN           NaN
# CEP57L1_proteomics             NaN               NaN           NaN
# AIMP1_proteomics_1             NaN               NaN           NaN
#
#                     Correlation_Brca  P_value_Brca  Correlation_Luad  \
# Comparison
# PHLDA1_proteomics           0.364797      0.002164          0.260110
# GRB2_proteomics            -0.177379      0.142733         -0.302439
# SOCS2_proteomics                 NaN           NaN               NaN
# CDH4_proteomics                  NaN           NaN               NaN
# DAB2_proteomics             0.326055      0.003543         -0.086403
# ...                              ...           ...               ...
# ZNF283_proteomics                NaN           NaN               NaN
# TRIM39_proteomics                NaN           NaN               NaN
# ADGRA3_proteomics                NaN           NaN               NaN
# CEP57L1_proteomics               NaN           NaN               NaN
# AIMP1_proteomics_1               NaN           NaN               NaN
#
#                     P_value_Luad  Correlation_Hnscc  P_value_Hnscc  \
# Comparison
# PHLDA1_proteomics       0.074530           0.664271   8.888640e-12
# GRB2_proteomics         0.020631          -0.532341   3.320092e-06
# SOCS2_proteomics             NaN           0.020297   9.557300e-01
# CDH4_proteomics              NaN                NaN            NaN
# DAB2_proteomics         0.597546          -0.208437   1.490980e-01
# ...                          ...                ...            ...
# ZNF283_proteomics            NaN                NaN            NaN
# TRIM39_proteomics            NaN                NaN            NaN
# ADGRA3_proteomics            NaN                NaN            NaN
# CEP57L1_proteomics           NaN                NaN            NaN
# AIMP1_proteomics_1           NaN                NaN            NaN
#
#                     Correlation_Colon  P_value_Colon  Correlation_Lscc  \
# Comparison
# PHLDA1_proteomics            0.386104       0.122847          0.713420
# GRB2_proteomics              0.150960       0.347409         -0.198042
# SOCS2_proteomics                  NaN            NaN          0.472624
# CDH4_proteomics                   NaN            NaN               NaN
# DAB2_proteomics             -0.147519       0.360266         -0.072496
# ...                               ...            ...               ...
# ZNF283_proteomics                 NaN            NaN          0.002610
# TRIM39_proteomics                 NaN            NaN         -0.002379
# ADGRA3_proteomics                 NaN            NaN          0.002228
# CEP57L1_proteomics                NaN            NaN         -0.001102
# AIMP1_proteomics_1                NaN            NaN         -0.000053
#
#                     P_value_Lscc
# Comparison
# PHLDA1_proteomics   2.644826e-14
# GRB2_proteomics     2.437176e-01
# SOCS2_proteomics    1.417921e-02
# CDH4_proteomics              NaN
# DAB2_proteomics     7.501117e-01
# ...                          ...
# ZNF283_proteomics   9.941900e-01
# TRIM39_proteomics   9.945224e-01
# ADGRA3_proteomics   9.958381e-01
# CEP57L1_proteomics  9.977544e-01
# AIMP1_proteomics_1  9.997474e-01
#
# [14867 rows x 16 columns]

# %%
def Pvalue_sig(row):
    numSig = 0

    for item in row:
        if pd.isnull(item):
            continue
        if item < 0.05:
            numSig += 1
            
    return numSig

# %%
df_fdr_pvals["Num_sig"] = df_fdr_pvals.loc[:,["P_value_Gbm","P_value_kidney","P_value_Ovar","P_value_Brca","P_value_Luad","P_value_Hnscc","P_value_Lscc","P_value_Colon"]].apply(Pvalue_sig, axis = 1)
df_fdr_pvals = df_fdr_pvals.sort_values(by=['Num_sig'],ascending=False)

# %%
#Calculate mean and standard deviation for pvalues and Pearson Correlations
df_fdr_pvals["Standard_Deviation_P_value"] = df_fdr_pvals.loc[:,["P_value_Gbm","P_value_kidney","P_value_Ovar","P_value_Brca","P_value_Luad","P_value_Hnscc","P_value_Lscc","P_value_Colon"]].std(axis = 1)
df_fdr_pvals["Mean_P_value"] = df_fdr_pvals.loc[:,["P_value_Gbm","P_value_kidney","P_value_Ovar","P_value_Brca","P_value_Luad","P_value_Hnscc","P_value_Lscc","P_value_Colon"]].mean(axis = 1)
df_fdr_pvals["Standard_Deviation_Correlation"] = (df_fdr_pvals.loc[:,["Correlation_Gbm","Correlation_kidney","Correlation_Ovar","Correlation_Brca","Correlation_Luad","Correlation_Hnscc","Correlation_Lscc","Correlation_Colon"]].std(axis = 1))
df_fdr_pvals["Mean_Correlation"] = (df_fdr_pvals.loc[:,["Correlation_Gbm","Correlation_kidney","Correlation_Ovar","Correlation_Brca","Correlation_Luad","Correlation_Hnscc","Correlation_Lscc","Correlation_Colon"]].mean(axis = 1))

# %%
df_fdr_pvals_1 = df_fdr_pvals[df_fdr_pvals['Num_sig'].isin([1,2,3,4,5,6,7,8])]
df_fdr_pvals_1
# Out:
#                      Correlation_Gbm  P_value_Gbm  Correlation_kidney  \
# Comparison
# LANCL2_proteomics           0.478723     0.000091            0.188217
# CD109_proteomics           -0.361839     0.004379            0.268902
# CNNM4_proteomics           -0.372324     0.003168            0.069926
# KIF13B_proteomics          -0.143903     0.357780           -0.310972
# MYO10_proteomics            0.447478     0.000289           -0.263921
# ...                              ...          ...                 ...
# GALNT5_proteomics          -0.389439     0.057159           -0.170202
# NCOA4_proteomics           -0.357481     0.007938           -0.057011
# RPL18_proteomics           -0.202600     0.162971            0.072834
# CDKN2AIP_proteomics        -0.190028     0.197869           -0.239330
# ARHGAP18_proteomics        -0.260637     0.057918            0.002394
#
#                      P_value_kidney  Correlation_Ovar  P_value_Ovar  \
# Comparison
# LANCL2_proteomics          0.193598          0.110983      0.627956
# CD109_proteomics           0.044632          0.015377      0.961793
# CNNM4_proteomics           0.718877          0.076606      0.751602
# KIF13B_proteomics          0.016103          0.439778      0.009101
# MYO10_proteomics           0.049045          0.374118      0.035041
# ...                             ...               ...           ...
# GALNT5_proteomics          0.593842          0.023757      0.933275
# NCOA4_proteomics           0.773348         -0.086256      0.774530
# RPL18_proteomics           0.688536         -0.216584      0.270229
# CDKN2AIP_proteomics        0.079788         -0.132921      0.543529
# ARHGAP18_proteomics        0.992866          0.318474      0.078099
#
#                      Correlation_Brca  P_value_Brca  Correlation_Luad  \
# Comparison
# LANCL2_proteomics            0.300981  7.599309e-03          0.588808
# CD109_proteomics             0.265349  2.042875e-02          0.113339
# CNNM4_proteomics            -0.260055  2.329196e-02          0.270616
# KIF13B_proteomics           -0.312353  5.460232e-03         -0.272975
# MYO10_proteomics             0.515801  5.191477e-07          0.230896
# ...                               ...           ...               ...
# GALNT5_proteomics            0.162343  2.040810e-01          0.026079
# NCOA4_proteomics             0.119416  3.534835e-01          0.099871
# RPL18_proteomics             0.279736  1.384014e-02         -0.041651
# CDKN2AIP_proteomics         -0.391051  3.379276e-04         -0.098311
# ARHGAP18_proteomics          0.016583  9.150955e-01         -0.042114
#
#                      P_value_Luad  ...  P_value_Hnscc  Correlation_Colon  \
# Comparison                         ...
# LANCL2_proteomics    4.733914e-08  ...   1.970503e-21           0.320786
# CD109_proteomics     4.717738e-01  ...   8.765469e-06           0.297635
# CNNM4_proteomics     4.101591e-02  ...   3.293176e-02           0.352937
# KIF13B_proteomics    3.960258e-02  ...   2.212241e-04           0.019902
# MYO10_proteomics     8.949836e-02  ...   2.728434e-03                NaN
# ...                           ...  ...            ...                ...
# GALNT5_proteomics    8.963231e-01  ...   4.623137e-01           0.297776
# NCOA4_proteomics     5.338038e-01  ...   9.862744e-01                NaN
# RPL18_proteomics     8.236951e-01  ...   5.179845e-02           0.087287
# CDKN2AIP_proteomics  5.413388e-01  ...   1.880129e-01           0.124066
# ARHGAP18_proteomics  8.221048e-01  ...   1.622222e-02          -0.170681
#
#                      P_value_Colon  Correlation_Lscc  P_value_Lscc  Num_sig  \
# Comparison
# LANCL2_proteomics         0.026823          0.575817  2.040789e-07        6
# CD109_proteomics          0.042193          0.360461  7.836561e-03        6
# CNNM4_proteomics          0.013936          0.311652  3.142153e-02        6
# KIF13B_proteomics         0.918920         -0.363670  6.920009e-03        6
# MYO10_proteomics               NaN          0.292466  4.901629e-02        6
# ...                            ...               ...           ...      ...
# GALNT5_proteomics         0.042100          0.252618  1.086917e-01        1
# NCOA4_proteomics               NaN          0.207661  2.112708e-01        1
# RPL18_proteomics          0.619058          0.003343  9.906637e-01        1
# CDKN2AIP_proteomics       0.456418         -0.169395  3.404379e-01        1
# ARHGAP18_proteomics       0.277083         -0.140786  4.555253e-01        1
#
#                      Standard_Deviation_P_value  Mean_P_value  \
# Comparison
# LANCL2_proteomics                      0.220706      0.107008
# CD109_proteomics                       0.348547      0.194131
# CNNM4_proteomics                       0.329428      0.202031
# KIF13B_proteomics                      0.326279      0.169263
# MYO10_proteomics                       0.033619      0.032231
# ...                                         ...           ...
# GALNT5_proteomics                      0.366423      0.412223
# NCOA4_proteomics                       0.349242      0.520093
# RPL18_proteomics                       0.374336      0.452599
# CDKN2AIP_proteomics                    0.208592      0.293466
# ARHGAP18_proteomics                    0.407007      0.451864
#
#                      Standard_Deviation_Correlation  Mean_Correlation
# Comparison
# LANCL2_proteomics                          0.230333          0.420130
# CD109_proteomics                           0.266765          0.184153
# CNNM4_proteomics                           0.273997          0.091721
# KIF13B_proteomics                          0.285396         -0.173143
# MYO10_proteomics                           0.257917          0.281063
# ...                                             ...               ...
# GALNT5_proteomics                          0.227399          0.040280
# NCOA4_proteomics                           0.184929         -0.009816
# RPL18_proteomics                           0.186379          0.030842
# CDKN2AIP_proteomics                        0.144910         -0.161278
# ARHGAP18_proteomics                        0.198028         -0.073630
#
# [6230 rows x 21 columns]

# %%
counts = df_fdr_pvals_1['Num_sig'].value_counts()
counts
# Out:
# 1    4149
# 2    1460
# 3     476
# 4     113
# 5      27
# 6       5
# Name: Num_sig, dtype: int64

# %%
df_fdr_pvals_6 = df_fdr_pvals[df_fdr_pvals['Num_sig'].isin([6])]
df_fdr_pvals_6
# Out:
#                    Correlation_Gbm  P_value_Gbm  Correlation_kidney  \
# Comparison
# LANCL2_proteomics         0.478723     0.000091            0.188217
# CD109_proteomics         -0.361839     0.004379            0.268902
# CNNM4_proteomics         -0.372324     0.003168            0.069926
# KIF13B_proteomics        -0.143903     0.357780           -0.310972
# MYO10_proteomics          0.447478     0.000289           -0.263921
#
#                    P_value_kidney  Correlation_Ovar  P_value_Ovar  \
# Comparison
# LANCL2_proteomics        0.193598          0.110983      0.627956
# CD109_proteomics         0.044632          0.015377      0.961793
# CNNM4_proteomics         0.718877          0.076606      0.751602
# KIF13B_proteomics        0.016103          0.439778      0.009101
# MYO10_proteomics         0.049045          0.374118      0.035041
#
#                    Correlation_Brca  P_value_Brca  Correlation_Luad  \
# Comparison
# LANCL2_proteomics          0.300981  7.599309e-03          0.588808
# CD109_proteomics           0.265349  2.042875e-02          0.113339
# CNNM4_proteomics          -0.260055  2.329196e-02          0.270616
# KIF13B_proteomics         -0.312353  5.460232e-03         -0.272975
# MYO10_proteomics           0.515801  5.191477e-07          0.230896
#
#                    P_value_Luad  ...  P_value_Hnscc  Correlation_Colon  \
# Comparison                       ...
# LANCL2_proteomics  4.733914e-08  ...   1.970503e-21           0.320786
# CD109_proteomics   4.717738e-01  ...   8.765469e-06           0.297635
# CNNM4_proteomics   4.101591e-02  ...   3.293176e-02           0.352937
# KIF13B_proteomics  3.960258e-02  ...   2.212241e-04           0.019902
# MYO10_proteomics   8.949836e-02  ...   2.728434e-03                NaN
#
#                    P_value_Colon  Correlation_Lscc  P_value_Lscc  Num_sig  \
# Comparison
# LANCL2_proteomics       0.026823          0.575817  2.040789e-07        6
# CD109_proteomics        0.042193          0.360461  7.836561e-03        6
# CNNM4_proteomics        0.013936          0.311652  3.142153e-02        6
# KIF13B_proteomics       0.918920         -0.363670  6.920009e-03        6
# MYO10_proteomics             NaN          0.292466  4.901629e-02        6
#
#                    Standard_Deviation_P_value  Mean_P_value  \
# Comparison
# LANCL2_proteomics                    0.220706      0.107008
# CD109_proteomics                     0.348547      0.194131
# CNNM4_proteomics                     0.329428      0.202031
# KIF13B_proteomics                    0.326279      0.169263
# MYO10_proteomics                     0.033619      0.032231
#
#                    Standard_Deviation_Correlation  Mean_Correlation
# Comparison
# LANCL2_proteomics                        0.230333          0.420130
# CD109_proteomics                         0.266765          0.184153
# CNNM4_proteomics                         0.273997          0.091721
# KIF13B_proteomics                        0.285396         -0.173143
# MYO10_proteomics                         0.257917          0.281063
#
# [5 rows x 21 columns]

# %%
df_fdr_pvals_5 = df_fdr_pvals[df_fdr_pvals['Num_sig'].isin([5])]
df_fdr_pvals_5
# Out:
#                      Correlation_Gbm  P_value_Gbm  Correlation_kidney  \
# Comparison
# ERO1A_proteomics           -0.261248     0.057296            0.348134
# RIN3_proteomics            -0.391779     0.001713           -0.277693
# PGM1_proteomics             0.428255     0.000566            0.300791
# PSPH_proteomics             0.293266     0.027566            0.221429
# ALDH1L1_proteomics          0.336346     0.009176           -0.127388
# SDC1_proteomics            -0.378042     0.002673            0.134297
# IL16_proteomics            -0.426571     0.000602           -0.346052
# PSTPIP1_proteomics         -0.314915     0.016211           -0.236628
# TRIM26_proteomics          -0.266500     0.050973           -0.344002
# WIPF1_proteomics           -0.423818     0.000645           -0.402723
# LAMC2_proteomics                 NaN          NaN           -0.182217
# KCTD9_proteomics           -0.301048     0.022700            0.353481
# BIN2_proteomics            -0.373561     0.003069           -0.329527
# BAG2_proteomics            -0.275789     0.042525           -0.368578
# RCSD1_proteomics           -0.436033     0.000423           -0.317453
# EVI2B_proteomics           -0.417405     0.000764           -0.338025
# LCP1_proteomics            -0.392499     0.001683           -0.300584
# SEPT1_proteomics           -0.408656     0.003238           -0.283628
# STK10_proteomics           -0.371007     0.003290           -0.345402
# ITGB1_proteomics           -0.412364     0.000875            0.276027
# PLCG2_proteomics           -0.472453     0.000115           -0.317009
# CGGBP1_proteomics           0.140719     0.370492           -0.190078
# SERPIND1_proteomics        -0.281792     0.036751           -0.016346
# PHLDA2_proteomics           0.457000     0.016861                 NaN
# NDRG1_proteomics           -0.144688     0.355007            0.401908
# FGD3_proteomics            -0.450504     0.000258           -0.364241
# NCF1_proteomics            -0.262517     0.055659           -0.274409
#
#                      P_value_kidney  Correlation_Ovar  P_value_Ovar  \
# Comparison
# ERO1A_proteomics           0.005782          0.512158      0.003795
# RIN3_proteomics            0.036953          0.133122      0.543005
# PGM1_proteomics            0.020763          0.412561      0.017747
# PSPH_proteomics            0.112045          0.092327      0.697403
# ALDH1L1_proteomics         0.422605          0.486761      0.005212
# SDC1_proteomics            0.390785         -0.069978      0.773990
# IL16_proteomics            0.006030         -0.064840      0.794734
# PSTPIP1_proteomics         0.084463          0.409655      0.032994
# TRIM26_proteomics          0.006441          0.143842      0.504773
# WIPF1_proteomics           0.000991         -0.108786      0.637397
# LAMC2_proteomics           0.426236          0.376518      0.034303
# KCTD9_proteomics           0.004864               NaN           NaN
# BIN2_proteomics            0.009800          0.001547      0.997641
# BAG2_proteomics            0.002994          0.109751      0.633306
# RCSD1_proteomics           0.013634         -0.093976      0.691426
# EVI2B_proteomics           0.009151         -0.089518      0.706815
# LCP1_proteomics            0.020867         -0.003992      0.989697
# SEPT1_proteomics           0.031987         -0.115208      0.609086
# STK10_proteomics           0.006174         -0.071920      0.767162
# ITGB1_proteomics           0.038342          0.277472      0.132303
# PLCG2_proteomics           0.013691         -0.015869      0.960635
# CGGBP1_proteomics          0.188500         -0.492993      0.005212
# SERPIND1_proteomics        0.941701          0.366931      0.038342
# PHLDA2_proteomics               NaN               NaN           NaN
# NDRG1_proteomics           0.001020          0.257000      0.171137
# FGD3_proteomics            0.003387         -0.088150      0.721377
# NCF1_proteomics            0.039591          0.001959      0.996863
#
#                      Correlation_Brca  P_value_Brca  Correlation_Luad  \
# Comparison
# ERO1A_proteomics             0.509076  8.112740e-07          0.062699
# RIN3_proteomics              0.372472  7.109438e-04         -0.096905
# PGM1_proteomics              0.348497  1.677744e-03          0.152606
# PSPH_proteomics              0.331678  2.960361e-03          0.297952
# ALDH1L1_proteomics           0.245705  3.351053e-02          0.107236
# SDC1_proteomics              0.337332  2.454726e-03          0.315691
# IL16_proteomics              0.042915  7.687007e-01         -0.397056
# PSTPIP1_proteomics           0.285805  1.169756e-02         -0.316972
# TRIM26_proteomics            0.268657  1.871413e-02          0.286645
# WIPF1_proteomics             0.232304  4.629351e-02         -0.287583
# LAMC2_proteomics             0.387152  3.942001e-04         -0.158129
# KCTD9_proteomics             0.285201  1.189876e-02         -0.370444
# BIN2_proteomics              0.150594  2.241044e-01         -0.316128
# BAG2_proteomics              0.507778  8.767748e-07         -0.340929
# RCSD1_proteomics             0.012516  9.370184e-01         -0.377127
# EVI2B_proteomics             0.246808  3.260777e-02         -0.262767
# LCP1_proteomics              0.250106  3.000344e-02         -0.333987
# SEPT1_proteomics             0.011425  9.427400e-01         -0.374905
# STK10_proteomics             0.026556  8.608080e-01         -0.273207
# ITGB1_proteomics             0.410530  1.367060e-04         -0.063223
# PLCG2_proteomics             0.268613  1.872484e-02         -0.408153
# CGGBP1_proteomics           -0.273047  1.661132e-02         -0.357210
# SERPIND1_proteomics          0.271473  1.736161e-02         -0.306864
# PHLDA2_proteomics            0.323655  7.280803e-03          0.391343
# NDRG1_proteomics             0.563535  2.134594e-08          0.296298
# FGD3_proteomics             -0.241629  3.712247e-02         -0.274928
# NCF1_proteomics              0.263137  2.165379e-02         -0.361120
#
#                      P_value_Luad  ...  P_value_Hnscc  Correlation_Colon  \
# Comparison                         ...
# ERO1A_proteomics         0.718125  ...   1.948716e-03           0.128203
# RIN3_proteomics          0.548612  ...   4.084006e-03           0.434309
# PGM1_proteomics          0.312425  ...   7.468318e-01           0.334486
# PSPH_proteomics          0.022714  ...   1.969723e-02           0.034009
# ALDH1L1_proteomics       0.509567  ...   4.708349e-02           0.302238
# SDC1_proteomics          0.014963  ...   2.751093e-03           0.020875
# IL16_proteomics          0.001341  ...   5.446806e-05           0.300654
# PSTPIP1_proteomics       0.014645  ...   8.085505e-04           0.168948
# TRIM26_proteomics        0.029224  ...   1.090177e-03          -0.363299
# WIPF1_proteomics         0.028363  ...   2.959587e-04           0.270649
# LAMC2_proteomics         0.280600  ...   1.590196e-03           0.353783
# KCTD9_proteomics         0.003323  ...   2.178147e-02                NaN
# BIN2_proteomics          0.014855  ...   7.918809e-05           0.321243
# BAG2_proteomics          0.007632  ...   2.688296e-01           0.344380
# RCSD1_proteomics         0.002610  ...   7.918809e-05           0.315836
# EVI2B_proteomics         0.048775  ...   8.253203e-03           0.226857
# LCP1_proteomics          0.009102  ...   1.147621e-02           0.213187
# SEPT1_proteomics         0.002816  ...   9.098497e-05           0.216274
# STK10_proteomics         0.039453  ...   4.842210e-03           0.295253
# ITGB1_proteomics         0.716091  ...   5.765454e-03           0.158688
# PLCG2_proteomics         0.000869  ...   2.082000e-03           0.207982
# CGGBP1_proteomics        0.004946  ...   2.493777e-04           0.380694
# SERPIND1_proteomics      0.018535  ...   3.025398e-01           0.351169
# PHLDA2_proteomics        0.003539  ...   4.777379e-11                NaN
# NDRG1_proteomics         0.023646  ...   2.659873e-05          -0.052700
# FGD3_proteomics          0.037939  ...   1.135955e-02                NaN
# NCF1_proteomics          0.004403  ...   1.173433e-02           0.291873
#
#                      P_value_Colon  Correlation_Lscc  P_value_Lscc  Num_sig  \
# Comparison
# ERO1A_proteomics          0.440678          0.326440      0.021649        5
# RIN3_proteomics           0.011477         -0.106945      0.606829        5
# PGM1_proteomics           0.020076          0.000892      0.996914        5
# PSPH_proteomics           0.877247          0.431276      0.000643        5
# ALDH1L1_proteomics        0.038785         -0.021036      0.940476        5
# SDC1_proteomics           0.916420          0.401983      0.001928        5
# IL16_proteomics           0.040116         -0.227293      0.159880        5
# PSTPIP1_proteomics        0.550054         -0.076048      0.734400        5
# TRIM26_proteomics         0.011252         -0.088108      0.685648        5
# WIPF1_proteomics          0.067143         -0.145960      0.432947        5
# LAMC2_proteomics          0.013794          0.471949      0.000097        5
# KCTD9_proteomics               NaN          0.208221      0.209826        5
# BIN2_proteomics           0.030299         -0.114481      0.573439        5
# BAG2_proteomics           0.016930         -0.216515      0.186339        5
# RCSD1_proteomics          0.034106         -0.214103      0.192780        5
# EVI2B_proteomics          0.195583         -0.125291      0.524389        5
# LCP1_proteomics           0.160475         -0.190437      0.267855        5
# SEPT1_proteomics          0.163801         -0.326536      0.021635        5
# STK10_proteomics          0.043962         -0.147942      0.426076        5
# ITGB1_proteomics          0.317023          0.296945      0.044713        5
# PLCG2_proteomics          0.173913         -0.244466      0.124528        5
# CGGBP1_proteomics         0.009180         -0.199280      0.238990        5
# SERPIND1_proteomics       0.014485         -0.015064      0.958957        5
# PHLDA2_proteomics              NaN          0.553097      0.000026        5
# NDRG1_proteomics          0.780173          0.406972      0.001574        5
# FGD3_proteomics                NaN         -0.090277      0.676327        5
# NCF1_proteomics           0.046206          0.048504      0.845821        5
#
#                      Standard_Deviation_P_value  Mean_P_value  \
# Comparison
# ERO1A_proteomics                       0.272192      0.156159
# RIN3_proteomics                        0.288170      0.219173
# PGM1_proteomics                        0.394633      0.264625
# PSPH_proteomics                        0.355133      0.220034
# ALDH1L1_proteomics                     0.343197      0.250802
# SDC1_proteomics                        0.384979      0.263245
# IL16_proteomics                        0.349991      0.221432
# PSTPIP1_proteomics                     0.290231      0.180659
# TRIM26_proteomics                      0.271236      0.163514
# WIPF1_proteomics                       0.244051      0.151759
# LAMC2_proteomics                       0.173165      0.108145
# KCTD9_proteomics                       0.080802      0.045732
# BIN2_proteomics                        0.367667      0.231661
# BAG2_proteomics                        0.221181      0.144820
# RCSD1_proteomics                       0.369654      0.234009
# EVI2B_proteomics                       0.273915      0.190792
# LCP1_proteomics                        0.338190      0.186395
# SEPT1_proteomics                       0.357388      0.221924
# STK10_proteomics                       0.365644      0.268971
# ITGB1_proteomics                       0.249955      0.156906
# PLCG2_proteomics                       0.329422      0.161820
# CGGBP1_proteomics                      0.143099      0.104273
# SERPIND1_proteomics                    0.418119      0.291084
# PHLDA2_proteomics                      0.007005      0.005541
# NDRG1_proteomics                       0.278408      0.166573
# FGD3_proteomics                        0.332804      0.212538
# NCF1_proteomics                        0.414996      0.252742
#
#                      Standard_Deviation_Correlation  Mean_Correlation
# Comparison
# ERO1A_proteomics                           0.261795          0.250802
# RIN3_proteomics                            0.319400         -0.036438
# PGM1_proteomics                            0.187100          0.239631
# PSPH_proteomics                            0.130431          0.250907
# ALDH1L1_proteomics                         0.256733          0.132647
# SDC1_proteomics                            0.272056          0.141546
# IL16_proteomics                            0.271991         -0.199620
# PSTPIP1_proteomics                         0.310636         -0.060897
# TRIM26_proteomics                          0.290457         -0.095169
# WIPF1_proteomics                           0.283247         -0.162398
# LAMC2_proteomics                           0.278368          0.233623
# KCTD9_proteomics                           0.325695          0.079443
# BIN2_proteomics                            0.279275         -0.140851
# BAG2_proteomics                            0.336170         -0.008991
# RCSD1_proteomics                           0.265701         -0.197025
# EVI2B_proteomics                           0.255382         -0.136914
# LCP1_proteomics                            0.256059         -0.135324
# SEPT1_proteomics                           0.235578         -0.217928
# STK10_proteomics                           0.232628         -0.155109
# ITGB1_proteomics                           0.272894          0.161430
# PLCG2_proteomics                           0.287357         -0.170038
# CGGBP1_proteomics                          0.298015         -0.178506
# SERPIND1_proteomics                        0.273891          0.026431
# PHLDA2_proteomics                          0.129049          0.474826
# NDRG1_proteomics                           0.253420          0.277957
# FGD3_proteomics                            0.135548         -0.262092
# NCF1_proteomics                            0.264173         -0.076982
#
# [27 rows x 21 columns]

# %%
pd.set_option('display.max_columns', None)
df_fdr_pvals_6 = df_fdr_pvals[df_fdr_pvals['Num_sig'].isin([6])]
df_fdr_pvals_6
# Out:
#                    Correlation_Gbm  P_value_Gbm  Correlation_kidney  \
# Comparison
# LANCL2_proteomics         0.478723     0.000091            0.188217
# CD109_proteomics         -0.361839     0.004379            0.268902
# CNNM4_proteomics         -0.372324     0.003168            0.069926
# KIF13B_proteomics        -0.143903     0.357780           -0.310972
# MYO10_proteomics          0.447478     0.000289           -0.263921
#
#                    P_value_kidney  Correlation_Ovar  P_value_Ovar  \
# Comparison
# LANCL2_proteomics        0.193598          0.110983      0.627956
# CD109_proteomics         0.044632          0.015377      0.961793
# CNNM4_proteomics         0.718877          0.076606      0.751602
# KIF13B_proteomics        0.016103          0.439778      0.009101
# MYO10_proteomics         0.049045          0.374118      0.035041
#
#                    Correlation_Brca  P_value_Brca  Correlation_Luad  \
# Comparison
# LANCL2_proteomics          0.300981  7.599309e-03          0.588808
# CD109_proteomics           0.265349  2.042875e-02          0.113339
# CNNM4_proteomics          -0.260055  2.329196e-02          0.270616
# KIF13B_proteomics         -0.312353  5.460232e-03         -0.272975
# MYO10_proteomics           0.515801  5.191477e-07          0.230896
#
#                    P_value_Luad  Correlation_Hnscc  P_value_Hnscc  \
# Comparison
# LANCL2_proteomics  4.733914e-08           0.796728   1.970503e-21
# CD109_proteomics   4.717738e-01           0.514002   8.765469e-06
# CNNM4_proteomics   4.101591e-02           0.284408   3.293176e-02
# KIF13B_proteomics  3.960258e-02          -0.440949   2.212241e-04
# MYO10_proteomics   8.949836e-02           0.370603   2.728434e-03
#
#                    Correlation_Colon  P_value_Colon  Correlation_Lscc  \
# Comparison
# LANCL2_proteomics           0.320786       0.026823          0.575817
# CD109_proteomics            0.297635       0.042193          0.360461
# CNNM4_proteomics            0.352937       0.013936          0.311652
# KIF13B_proteomics           0.019902       0.918920         -0.363670
# MYO10_proteomics                 NaN            NaN          0.292466
#
#                    P_value_Lscc  Num_sig  Standard_Deviation_P_value  \
# Comparison
# LANCL2_proteomics  2.040789e-07        6                    0.220706
# CD109_proteomics   7.836561e-03        6                    0.348547
# CNNM4_proteomics   3.142153e-02        6                    0.329428
# KIF13B_proteomics  6.920009e-03        6                    0.326279
# MYO10_proteomics   4.901629e-02        6                    0.033619
#
#                    Mean_P_value  Standard_Deviation_Correlation  \
# Comparison
# LANCL2_proteomics      0.107008                        0.230333
# CD109_proteomics       0.194131                        0.266765
# CNNM4_proteomics       0.202031                        0.273997
# KIF13B_proteomics      0.169263                        0.285396
# MYO10_proteomics       0.032231                        0.257917
#
#                    Mean_Correlation
# Comparison
# LANCL2_proteomics          0.420130
# CD109_proteomics           0.184153
# CNNM4_proteomics           0.091721
# KIF13B_proteomics         -0.173143
# MYO10_proteomics           0.281063

# %%
def HasPosNeg(row):
    hasPos = False
    hasNeg= False

    for item in row:
        if pd.isnull(item):
            continue
        if item < -0.2:
            hasNeg = True
        if item > 0.2:
            hasPos = True
            
    if hasPos & hasNeg:
        return True
    return False

# %%
col = ["Correlation_Gbm","Correlation_kidney","Correlation_Ovar","Correlation_Brca","Correlation_Luad","Correlation_Hnscc","Correlation_Lscc","Correlation_Colon"]
df_fdr_pvals_6 = df_fdr_pvals_6[col]
#df_fdr_pvals_6["Pos_Neg"] = df_fdr_pvals_6.apply(HasPosNeg, axis = 1)
df_fdr_pvals_6
# Out:
#                    Correlation_Gbm  Correlation_kidney  Correlation_Ovar  \
# Comparison
# LANCL2_proteomics         0.478723            0.188217          0.110983
# CD109_proteomics         -0.361839            0.268902          0.015377
# CNNM4_proteomics         -0.372324            0.069926          0.076606
# KIF13B_proteomics        -0.143903           -0.310972          0.439778
# MYO10_proteomics          0.447478           -0.263921          0.374118
#
#                    Correlation_Brca  Correlation_Luad  Correlation_Hnscc  \
# Comparison
# LANCL2_proteomics          0.300981          0.588808           0.796728
# CD109_proteomics           0.265349          0.113339           0.514002
# CNNM4_proteomics          -0.260055          0.270616           0.284408
# KIF13B_proteomics         -0.312353         -0.272975          -0.440949
# MYO10_proteomics           0.515801          0.230896           0.370603
#
#                    Correlation_Lscc  Correlation_Colon
# Comparison
# LANCL2_proteomics          0.575817           0.320786
# CD109_proteomics           0.360461           0.297635
# CNNM4_proteomics           0.311652           0.352937
# KIF13B_proteomics         -0.363670           0.019902
# MYO10_proteomics           0.292466                NaN

# %% [markdown]
# # Step 2: Plot 2D Histogram

# %%
sns.set(rc={'xtick.labelsize':20,
            'ytick.labelsize':20}, style = "white")
g = (sns.jointplot("Mean_P_value","Standard_Deviation_P_value",data = df_fdr_pvals_1, kind="hex", bins = 10)
        .set_axis_labels("Mean P Value", "Std Dev P Value", fontsize=20))

plt.show()
g.savefig("EGFR_Fig_1C_Pvalue_sig_atleast1_cancer.png", dpi = 300)

# %%
sns.set(rc={'xtick.labelsize':20,
            'ytick.labelsize':20}, style = "white")

g = (sns.jointplot("Mean_Correlation","Standard_Deviation_Correlation",data = df_fdr_pvals_1, kind="hex", bins = 10)
        .set_axis_labels("Mean Correlaiton", "Std Dev Correlation", fontsize=20))


g.savefig("EGFR_Fig_1C_Corr_atleast1_cancer.png", dpi = 300)
plt.show()

# %% [markdown]
# # Filter for genes significant in at least 2 Cancers

# %%
df_fdr_pvals_2 = df_fdr_pvals[df_fdr_pvals['Num_sig'].isin([2,3,4,5,6,7,8])]

# %%
sns.set(rc={'xtick.labelsize':20,
            'ytick.labelsize':20}, style = "white")
g = (sns.jointplot("Mean_P_value","Standard_Deviation_P_value",data = df_fdr_pvals_2, kind="hex", bins = 10)
        .set_axis_labels("Mean P Value", "Std Dev P Value", fontsize=20))

plt.show()
g.savefig("EGFR_Fig_1C_Pvalue_atleast2_cancers.png", dpi = 300)

# %%
sns.set(rc={'xtick.labelsize':20,
            'ytick.labelsize':20}, style = "white")

g = (sns.jointplot("Mean_Correlation","Standard_Deviation_Correlation",data = df_fdr_pvals_2, kind="hex", bins = 10)
        .set_axis_labels("Mean Correlaiton", "Std Dev Correlation", fontsize=20))


g.savefig("EGFR_Fig_1C_Corr_atleast2_cancers.png", dpi = 300)
plt.show()

# %% [markdown]
# # At least 3 Cancers

# %%
df_fdr_pvals_3 = df_fdr_pvals[df_fdr_pvals['Num_sig'].isin([3,4,5,6,7,8])]

# %%
sns.set(rc={'xtick.labelsize':20,
            'ytick.labelsize':20}, style = "white")
g = (sns.jointplot("Mean_P_value","Standard_Deviation_P_value",data = df_fdr_pvals_3, kind="hex", bins = 5)
        .set_axis_labels("Mean P Value", "Std Dev P Value", fontsize=20))

plt.show()
g.savefig("EGFR_Fig_1C_Pvalue_EGFR_atleast3_cancers.png", dpi = 300)

# %%
sns.set(rc={'xtick.labelsize':20,
            'ytick.labelsize':20}, style = "white")

g = (sns.jointplot("Mean_Correlation","Standard_Deviation_Correlation",data = df_fdr_pvals_3, kind="hex", bins = 5)
        .set_axis_labels("Mean Correlaiton", "Std Dev Correlation", fontsize=20))


g.savefig("EGFR_Fig_1C_Corr_EGFR_atleast3_cancers.png", dpi = 300)
plt.show()

# %% [markdown]
# # Single Gene Example PLAU

# %%
df_fdr_pvals["Num_sig"] = df_fdr_pvals.loc[:,["P_value_Gbm","P_value_kidney","P_value_Ovar","P_value_Brca","P_value_Luad","P_value_Hnscc","P_value_Lscc","P_value_Colon"]].apply(Pvalue_sig, axis = 1)
df_fdr_pvals = df_fdr_pvals.sort_values(by=['Num_sig'],ascending=False)

# %%
df_fdr_pvals_1 = df_fdr_pvals[df_fdr_pvals['Num_sig'].isin([1,2,3,4,5,6,7,8])]
df_fdr_pvals_1
# Out:
#                      Correlation_Gbm  P_value_Gbm  Correlation_kidney  \
# Comparison
# LANCL2_proteomics           0.478723     0.000091            0.188217
# CNNM4_proteomics           -0.372324     0.003168            0.069926
# KIF13B_proteomics          -0.143903     0.357780           -0.310972
# MYO10_proteomics            0.447478     0.000289           -0.263921
# CD109_proteomics           -0.361839     0.004379            0.268902
# ...                              ...          ...                 ...
# C15orf52_proteomics              NaN          NaN                 NaN
# STAG3_proteomics                 NaN          NaN                 NaN
# TCAF2_proteomics_1               NaN          NaN                 NaN
# FKBP8_proteomics_1               NaN          NaN                 NaN
# SKP2_proteomics                  NaN          NaN                 NaN
#
#                      P_value_kidney  Correlation_Ovar  P_value_Ovar  \
# Comparison
# LANCL2_proteomics          0.193598          0.110983      0.627956
# CNNM4_proteomics           0.718877          0.076606      0.751602
# KIF13B_proteomics          0.016103          0.439778      0.009101
# MYO10_proteomics           0.049045          0.374118      0.035041
# CD109_proteomics           0.044632          0.015377      0.961793
# ...                             ...               ...           ...
# C15orf52_proteomics             NaN          0.149572      0.577432
# STAG3_proteomics                NaN         -0.123167      0.592469
# TCAF2_proteomics_1              NaN          0.135837      0.602339
# FKBP8_proteomics_1              NaN          0.104538      0.652003
# SKP2_proteomics                 NaN         -0.141931      0.661683
#
#                      Correlation_Brca  P_value_Brca  Correlation_Luad  \
# Comparison
# LANCL2_proteomics            0.300981  7.599309e-03          0.588808
# CNNM4_proteomics            -0.260055  2.329196e-02          0.270616
# KIF13B_proteomics           -0.312353  5.460232e-03         -0.272975
# MYO10_proteomics             0.515801  5.191477e-07          0.230896
# CD109_proteomics             0.265349  2.042875e-02          0.113339
# ...                               ...           ...               ...
# C15orf52_proteomics          0.272793  1.668712e-02               NaN
# STAG3_proteomics             0.330538  8.207397e-03         -0.211200
# TCAF2_proteomics_1           0.333667  2.773893e-03               NaN
# FKBP8_proteomics_1           0.298630  8.101147e-03               NaN
# SKP2_proteomics              0.412506  6.977056e-03               NaN
#
#                      P_value_Luad  Correlation_Hnscc  P_value_Hnscc  \
# Comparison
# LANCL2_proteomics    4.733914e-08           0.796728   1.970503e-21
# CNNM4_proteomics     4.101591e-02           0.284408   3.293176e-02
# KIF13B_proteomics    3.960258e-02          -0.440949   2.212241e-04
# MYO10_proteomics     8.949836e-02           0.370603   2.728434e-03
# CD109_proteomics     4.717738e-01           0.514002   8.765469e-06
# ...                           ...                ...            ...
# C15orf52_proteomics           NaN                NaN            NaN
# STAG3_proteomics     2.304907e-01                NaN            NaN
# TCAF2_proteomics_1            NaN                NaN            NaN
# FKBP8_proteomics_1            NaN                NaN            NaN
# SKP2_proteomics               NaN          -0.058233   7.612424e-01
#
#                      Correlation_Colon  P_value_Colon  Correlation_Lscc  \
# Comparison
# LANCL2_proteomics             0.320786       0.026823          0.575817
# CNNM4_proteomics              0.352937       0.013936          0.311652
# KIF13B_proteomics             0.019902       0.918920         -0.363670
# MYO10_proteomics                   NaN            NaN          0.292466
# CD109_proteomics              0.297635       0.042193          0.360461
# ...                                ...            ...               ...
# C15orf52_proteomics           0.261515       0.076422               NaN
# STAG3_proteomics                   NaN            NaN         -0.025327
# TCAF2_proteomics_1                 NaN            NaN               NaN
# FKBP8_proteomics_1                 NaN            NaN               NaN
# SKP2_proteomics                    NaN            NaN          0.046058
#
#                      P_value_Lscc  Num_sig  Standard_Deviation_P_value  \
# Comparison
# LANCL2_proteomics    2.040789e-07        6                    0.220706
# CNNM4_proteomics     3.142153e-02        6                    0.329428
# KIF13B_proteomics    6.920009e-03        6                    0.326279
# MYO10_proteomics     4.901629e-02        6                    0.033619
# CD109_proteomics     7.836561e-03        6                    0.348547
# ...                           ...      ...                         ...
# C15orf52_proteomics           NaN        1                    0.307954
# STAG3_proteomics     9.412779e-01        1                    0.410214
# TCAF2_proteomics_1            NaN        1                    0.423957
# FKBP8_proteomics_1            NaN        1                    0.455307
# SKP2_proteomics      8.634832e-01        1                    0.386463
#
#                      Mean_P_value  Standard_Deviation_Correlation  \
# Comparison
# LANCL2_proteomics        0.107008                        0.230333
# CNNM4_proteomics         0.202031                        0.273997
# KIF13B_proteomics        0.169263                        0.285396
# MYO10_proteomics         0.032231                        0.257917
# CD109_proteomics         0.194131                        0.266765
# ...                           ...                             ...
# C15orf52_proteomics      0.223514                        0.068120
# STAG3_proteomics         0.443111                        0.237669
# TCAF2_proteomics_1       0.302557                        0.139887
# FKBP8_proteomics_1       0.330052                        0.137244
# SKP2_proteomics          0.573346                        0.244353
#
#                      Mean_Correlation
# Comparison
# LANCL2_proteomics            0.420130
# CNNM4_proteomics             0.091721
# KIF13B_proteomics           -0.173143
# MYO10_proteomics             0.281063
# CD109_proteomics             0.184153
# ...                               ...
# C15orf52_proteomics          0.227960
# STAG3_proteomics            -0.007289
# TCAF2_proteomics_1           0.234752
# FKBP8_proteomics_1           0.201584
# SKP2_proteomics              0.064600
#
# [6230 rows x 21 columns]

# %% [markdown]
# In manuscript, a single gene (PLAU) from the histogram figure is mentioned. Here are the correlations and pvalues as well as the average and std dev for the p values and correlations.

# %%
rowData = df_fdr_pvals_1.loc[ 'F3_proteomics' , : ]
rowData
# Out:
# Correlation_Gbm                   0.321497
# P_value_Gbm                       0.013380
# Correlation_kidney                0.001084
# P_value_kidney                    0.997191
# Correlation_Ovar                       NaN
# P_value_Ovar                           NaN
# Correlation_Brca                 -0.007981
# P_value_Brca                      0.968144
# Correlation_Luad                 -0.032167
# P_value_Luad                      0.869082
# Correlation_Hnscc                 0.055360
# P_value_Hnscc                     0.775586
# Correlation_Colon                 0.400421
# P_value_Colon                     0.023047
# Correlation_Lscc                  0.149498
# P_value_Lscc                      0.421607
# Num_sig                           2.000000
# Standard_Deviation_P_value        0.428731
# Mean_P_value                      0.581148
# Standard_Deviation_Correlation    0.172064
# Mean_Correlation                  0.126816
# Name: F3_proteomics, dtype: float64
