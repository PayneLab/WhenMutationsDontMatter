# %% [markdown]
# # Make EGFR Figure 2

# %% [markdown]
# This notebooks takes all the trans genes that have positive and negative results and runs a GSEA using Reactome. It then takes a subset of genes from the top hit(Hemostasis) pathway and maps them on a large circle heat map. This heatmap focuses on coagulation and urokinase related genes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas.util.testing as tm
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest

import gseapy as gp
from gseapy.plot import barplot, dotplot

import cptac
import cptac.utils as u
import plot_utils as p
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Step 1: Find Trans proteins with opposite effects in different cancers

# %% [markdown]
# Load df with all of the genes that are FDR significant.

# %%
FDR_sig = pd.read_csv("Pval_corr_table_Fig_2_return_sig.csv")
FDR_sig = FDR_sig.replace(to_replace ='_proteomics', value = '', regex = True) #Remove proteomics labeling
FDR_sig= FDR_sig.drop(['Unnamed: 0'], axis=1)
FDR_sig = FDR_sig.set_index("Comparison")
FDR_sig = FDR_sig[1:] #Drop EGFR 
FDR_sig
# Out:
#             Correlation_Gbm   P_value_Gbm  Correlation_kidney  P_value_kidney  \
# Comparison
# PHLDA1             0.816848  3.507071e-21                 NaN             NaN
# GRB2              -0.610889  6.729990e-08                 NaN             NaN
# CDH4               0.559180  3.420388e-06                 NaN             NaN
# PLA2G15           -0.556624  3.420388e-06           -0.298029         0.02216
# SOCS2              0.562720  3.420388e-06                 NaN             NaN
# ...                     ...           ...                 ...             ...
# CCDC6                   NaN           NaN                 NaN             NaN
# SSR2                    NaN           NaN                 NaN             NaN
# PSMB1                   NaN           NaN                 NaN             NaN
# MRPL39                  NaN           NaN                 NaN             NaN
# MAP3K11                 NaN           NaN                 NaN             NaN
#
#             Correlation_Ovar  P_value_Ovar  Correlation_Brca  P_value_Brca  \
# Comparison
# PHLDA1                   NaN           NaN          0.364797      0.002164
# GRB2                     NaN           NaN               NaN           NaN
# CDH4                     NaN           NaN               NaN           NaN
# PLA2G15                  NaN           NaN          0.274185      0.016061
# SOCS2                    NaN           NaN               NaN           NaN
# ...                      ...           ...               ...           ...
# CCDC6                    NaN           NaN               NaN           NaN
# SSR2                     NaN           NaN               NaN           NaN
# PSMB1                    NaN           NaN               NaN           NaN
# MRPL39                   NaN           NaN               NaN           NaN
# MAP3K11                  NaN           NaN               NaN           NaN
#
#             Correlation_Luad  P_value_Luad  Correlation_hnscc  P_value_hnscc  \
# Comparison
# PHLDA1                   NaN           NaN           0.664271   8.888640e-12
# GRB2               -0.302439      0.020631          -0.532341   3.320092e-06
# CDH4                     NaN           NaN                NaN            NaN
# PLA2G15                  NaN           NaN                NaN            NaN
# SOCS2                    NaN           NaN                NaN            NaN
# ...                      ...           ...                ...            ...
# CCDC6                    NaN           NaN                NaN            NaN
# SSR2                     NaN           NaN                NaN            NaN
# PSMB1                    NaN           NaN                NaN            NaN
# MRPL39                   NaN           NaN                NaN            NaN
# MAP3K11                  NaN           NaN                NaN            NaN
#
#             Correlation_Lscc  P_value_Lscc  Correlation_Colon  P_value_Colon
# Comparison
# PHLDA1              0.713420  2.644826e-14                NaN            NaN
# GRB2                     NaN           NaN                NaN            NaN
# CDH4                     NaN           NaN                NaN            NaN
# PLA2G15                  NaN           NaN                NaN            NaN
# SOCS2               0.472624  1.417921e-02                NaN            NaN
# ...                      ...           ...                ...            ...
# CCDC6                    NaN           NaN           0.287735       0.049589
# SSR2                     NaN           NaN           0.301814       0.049589
# PSMB1                    NaN           NaN           0.287839       0.049589
# MRPL39                   NaN           NaN          -0.288110       0.049589
# MAP3K11                  NaN           NaN           0.498761       0.049785
#
# [6230 rows x 16 columns]

# %%
def HasPosNeg(row):
    hasPos = False
    hasNeg= False

    for item in row:
        if pd.isnull(item):
            continue
        if item < 0:
            hasNeg = True
        if item > 0:
            hasPos = True
            
    if hasPos & hasNeg:
        return True
    return False

def CountPosNeg(row):
    hasPos = False
    hasNeg= False
    counter = 0
    for item in row:
        if pd.isnull(item):
            continue
        if item < -0:
            hasNeg = True
            counter += 1
        if item > 0:
            hasPos = True
            counter += 1
    return counter

# %% [markdown]
# Subset data frame to include only trans genes that have opposite effects in different cancers by using apply function

# %%
col = ["Correlation_Gbm","Correlation_kidney","Correlation_Ovar","Correlation_Brca","Correlation_Luad","Correlation_hnscc","Correlation_Lscc","Correlation_Colon"]
FDR_corr = FDR_sig[col]
FDR_corr["Pos_Neg"] = FDR_corr.apply(HasPosNeg, axis = 1)
FDR_corr_False = FDR_corr[FDR_corr['Pos_Neg']==False]
FDR_corr_False = FDR_corr_False.drop(["Pos_Neg"], axis = 1)
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
FDR_corr_False["Num_corr"] = FDR_corr_False.apply(CountPosNeg, axis = 1)
FDR_corr_False.sort_values(by=['Num_corr'],ascending=False)
FDR_corr_False = FDR_corr_False[FDR_corr_False['Num_corr'].isin([2,3,4,5,6])]
FDR_corr_False
# Out:
#             Correlation_Gbm  Correlation_kidney  Correlation_Ovar  \
# Comparison
# PHLDA1             0.816848                 NaN               NaN
# GRB2              -0.610889                 NaN               NaN
# SOCS2              0.562720                 NaN               NaN
# GLA               -0.550491           -0.298348               NaN
# PHLDA3             0.525883            0.432530               NaN
# ...                     ...                 ...               ...
# S100A14                 NaN                 NaN               NaN
# MOV10                   NaN                 NaN               NaN
# ATP2B1                  NaN                 NaN               NaN
# MFSD6                   NaN                 NaN               NaN
# SART1                   NaN                 NaN               NaN
#
#             Correlation_Brca  Correlation_Luad  Correlation_hnscc  \
# Comparison
# PHLDA1              0.364797               NaN           0.664271
# GRB2                     NaN         -0.302439          -0.532341
# SOCS2                    NaN               NaN                NaN
# GLA                      NaN               NaN                NaN
# PHLDA3                   NaN               NaN           0.763784
# ...                      ...               ...                ...
# S100A14                  NaN               NaN                NaN
# MOV10                    NaN               NaN                NaN
# ATP2B1                   NaN               NaN                NaN
# MFSD6                    NaN               NaN                NaN
# SART1                    NaN               NaN                NaN
#
#             Correlation_Lscc  Correlation_Colon  Num_corr
# Comparison
# PHLDA1              0.713420                NaN         4
# GRB2                     NaN                NaN         3
# SOCS2               0.472624                NaN         2
# GLA                      NaN                NaN         2
# PHLDA3              0.682034                NaN         4
# ...                      ...                ...       ...
# S100A14             0.370227           0.351373         2
# MOV10               0.302787           0.299218         2
# ATP2B1              0.298873           0.346409         2
# MFSD6               0.295201           0.380169         2
# SART1              -0.292189          -0.306539         2
#
# [1136 rows x 9 columns]

# %% [markdown]
# The manuscript mentions the total number of trans proteins that opposite effects in different cancers. Here is the derivation of that number

# %%
same_sign_prot = FDR_corr_False.index.tolist()
print("Total number of trans proteins with same effects in different cancers is " + str(len(same_sign_prot)))
# Out:
# Total number of trans proteins with same effects in different cancers is 1136

# %% [markdown]
# # Run GSEA

# %%
same_sign_enr = gp.enrichr(gene_list = same_sign_prot, description='Tumor_partition', gene_sets='KEGG_2016', 
                       outdir='test/enrichr_KEGG')
same_sign_enr.res2d.head(10)
# Out:
#     Gene_set                                               Term   Overlap  \
# 0  KEGG_2016  Arrhythmogenic right ventricular cardiomyopath...     18/74
# 1  KEGG_2016           Metabolic pathways Homo sapiens hsa01100  114/1239
# 2  KEGG_2016  Regulation of actin cytoskeleton Homo sapiens ...    32/214
# 3  KEGG_2016  Biosynthesis of amino acids Homo sapiens hsa01230     17/74
# 4  KEGG_2016  Glycolysis / Gluconeogenesis Homo sapiens hsa0...     16/67
# 5  KEGG_2016  Bacterial invasion of epithelial cells Homo sa...     17/78
# 6  KEGG_2016  B cell receptor signaling pathway Homo sapiens...     16/73
# 7  KEGG_2016            Carbon metabolism Homo sapiens hsa01200    20/113
# 8  KEGG_2016  T cell receptor signaling pathway Homo sapiens...    19/104
# 9  KEGG_2016                Axon guidance Homo sapiens hsa04360    21/127
#
#         P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0  1.159284e-07          0.000034            0                     0
# 1  1.813751e-07          0.000027            0                     0
# 2  5.044867e-07          0.000049            0                     0
# 3  6.249417e-07          0.000046            0                     0
# 4  7.613663e-07          0.000045            0                     0
# 5  1.377343e-06          0.000067            0                     0
# 6  2.588556e-06          0.000108            0                     0
# 7  5.248171e-06          0.000192            0                     0
# 8  5.547202e-06          0.000181            0                     0
# 9  9.304350e-06          0.000273            0                     0
#
#    Odds Ratio  Combined Score  \
# 0    4.282451       68.392004
# 1    1.619889       25.145046
# 2    2.632618       38.172238
# 3    4.044537       57.778675
# 4    4.204330       59.231243
# 5    3.837125       51.783367
# 6    3.858769       49.640789
# 7    3.116041       37.883681
# 8    3.216414       38.925738
# 9    2.911168       33.725962
#
#                                                Genes
# 0  DSP;ITGA4;JUP;ITGB4;ACTN2;ITGA2;GJA1;CDH2;PKP2...
# 1  MSMO1;ENO1;NSDHL;NAMPT;ENPP1;ENPP3;ATP6V1E1;PT...
# 2  CYFIP2;NCKAP1;ITGB4;WAS;PIK3CD;IQGAP2;ITGAL;FG...
# 3  PRPS1;ARG1;PGAM1;GPT;ENO1;PFKL;PKM;CBS;PSAT1;P...
# 4  GPI;ACSS2;ADH1B;PGAM1;ENO1;HK2;LDHA;PFKL;PKM;P...
# 5  WAS;FN1;PIK3CD;SEPT1;PIK3CG;SEPT2;CD2AP;SEPT9;...
# 6  CR2;JUN;SYK;INPPL1;PIK3CD;NFATC2;PIK3CG;VAV1;P...
# 7  GPI;PRPS1;H6PD;ACSS2;ECHS1;PGAM1;GPT;ENO1;HK2;...
# 8  JUN;NFATC2;PIK3CD;CD3G;PIK3CG;VAV1;ZAP70;CD4;P...
# 9  EPHA4;SEMA4A;SEMA4D;SEMA4B;LIMK1;GNAI3;NFATC2;...

# %%
#get just the clotting cascade genes and add urokinase genes 
same_sign_df = same_sign_enr.res2d
bcell = same_sign_df.iloc[6,9]
bcell = bcell.split(';')
tcell = same_sign_df.iloc[8,9]
tcell = tcell.split(";")
immune_both =  bcell + tcell
immune = set(immune_both)
immune = list(immune)
btcell_apm = (["CD5","CD8A","BLK","BLNK","CD79A","LYN","CD3E","HLA-DMA","HLA-DMB"])

immune= immune + btcell_apm

#remove = ["CR2","NCK1","CARD11","INPPL1","JUN","KRAS"]
immune.remove("JUN")
immune.remove("KRAS")
immune.remove("CR2")
immune.remove("NCK1")
immune.remove("INPPL1")
immune.remove("CARD11")
immune
# Out:
# ['PRKCQ',
#  'PPP3CC',
#  'LCP2',
#  'INPP5D',
#  'PIK3CD',
#  'GRAP2',
#  'CD4',
#  'PTPN6',
#  'BTK',
#  'NFATC2',
#  'PIK3CG',
#  'SYK',
#  'PTPRC',
#  'ZAP70',
#  'VAV1',
#  'RAC2',
#  'LCK',
#  'GRB2',
#  'CD3G',
#  'CD5',
#  'CD8A',
#  'BLK',
#  'BLNK',
#  'CD79A',
#  'LYN',
#  'CD3E',
#  'HLA-DMA',
#  'HLA-DMB']

# %% [markdown]
# # Step 3 Make Data frame for figure 2

# %%
#Get append version of the df with all cancer type, fdr sig trans results
df_FDR_append = pd.read_csv("Pval_corr_table_Fig_2_return_sig_append.csv")
df_FDR_append = df_FDR_append.drop(['Unnamed: 0'], axis=1)

#Remove Proteomics labeling 
df_FDR_append = df_FDR_append.replace(to_replace ='_proteomics', value = '', regex = True) 

#subset dataframe to include genes only desired for figure 
df_FDR_append= df_FDR_append[df_FDR_append.Comparison.isin(immune)]
df_FDR_append
# Out:
#      Comparison  Correlation       P_value    Cancer Type
# 1          GRB2    -0.610889  6.729990e-08            GBM
# 75          SYK    -0.470849  1.202510e-04            GBM
# 82          CD4    -0.467479  1.362923e-04            GBM
# 86       PIK3CD    -0.466265  1.399080e-04            GBM
# 100        LCP2    -0.460881  1.665085e-04            GBM
# 125        VAV1    -0.447143  2.894593e-04            GBM
# 141     HLA-DMB    -0.442005  3.476225e-04            GBM
# 199       PTPRC    -0.424958  6.196952e-04            GBM
# 204         BTK    -0.423380  6.552047e-04            GBM
# 287      INPP5D    -0.408181  1.009137e-03            GBM
# 318       PTPN6    -0.402017  1.241946e-03            GBM
# 361      PIK3CG    -0.394048  1.602237e-03            GBM
# 370      NFATC2    -0.392602  1.681448e-03            GBM
# 603     HLA-DMA    -0.373678  5.056470e-03            GBM
# 605        BLNK    -0.356906  5.065055e-03            GBM
# 941        RAC2    -0.321178  1.349871e-02            GBM
# 990       PRKCQ    -0.329766  1.621074e-02            GBM
# 2270      GRAP2    -0.305290  2.127686e-02         Kidney
# 2400       VAV1    -0.285693  3.025415e-02         Kidney
# 2492      ZAP70    -0.276087  3.833890e-02         Kidney
# 2550     INPP5D    -0.271891  4.182668e-02         Kidney
# 5750     PPP3CC    -0.432271  3.644683e-04           Luad
# 5773      PRKCQ    -0.418175  6.284144e-04           Luad
# 5851      ZAP70    -0.384613  2.092847e-03           Luad
# 5893      PTPN6    -0.371990  3.159187e-03           Luad
# 5897        LCK    -0.370894  3.271948e-03           Luad
# 6002       RAC2    -0.349937  5.935190e-03           Luad
# 6094        BLK    -0.365512  8.766800e-03           Luad
# 6121     PIK3CD    -0.331760  9.676902e-03           Luad
# 6364       GRB2    -0.302439  2.063096e-02           Luad
# 6480       CD8A    -0.292478  2.581604e-02           Luad
# 6666        BTK    -0.278003  3.552087e-02           Luad
# 6762     INPP5D    -0.271933  4.007023e-02           Luad
# 6777       CD3G    -0.333706  4.093285e-02           Luad
# 6932       GRB2    -0.532341  3.320092e-06  Head and Neck
# 6978     NFATC2    -0.457536  1.111948e-04  Head and Neck
# 6980        BTK    -0.454873  1.269551e-04  Head and Neck
# 6997     INPP5D    -0.440058  2.212241e-04  Head and Neck
# 7005       VAV1    -0.439464  2.264489e-04  Head and Neck
# 7024      GRAP2    -0.428093  3.591048e-04  Head and Neck
# 7042        CD4    -0.417232  5.663144e-04  Head and Neck
# 7059      PTPN6    -0.411321  6.865751e-04  Head and Neck
# 7061      ZAP70    -0.410167  7.208683e-04  Head and Neck
# 7077      PTPRC    -0.402397  9.771626e-04  Head and Neck
# 7078     PIK3CG    -0.402484  9.771626e-04  Head and Neck
# 7121       LCP2    -0.390098  1.462062e-03  Head and Neck
# 7141        CD5    -0.396950  1.583339e-03  Head and Neck
# 7187        LYN    -0.374709  2.361831e-03  Head and Neck
# 7219      CD79A    -0.366693  3.102262e-03  Head and Neck
# 7222       CD3G    -0.381032  3.210780e-03  Head and Neck
# 7257     PPP3CC    -0.359171  3.917390e-03  Head and Neck
# 7401        LCK    -0.331149  9.506279e-03  Head and Neck
# 7603       CD3E    -0.339994  2.079403e-02  Head and Neck
# 7646        SYK    -0.298428  2.328405e-02  Head and Neck
# 7721    HLA-DMB    -0.290547  2.839009e-02  Head and Neck
# 7781      PRKCQ    -0.284462  3.293176e-02  Head and Neck
# 7876       RAC2    -0.277100  3.855935e-02  Head and Neck
# 8461     NFATC2    -0.297428  4.438700e-02           Lscc

# %% [markdown]
# Set add new column to be unique index and order the new index. This way genes will be grouped by coagulation factors, regulators, and urokinase genes.

# %%
df_FDR_append["Index"] = df_FDR_append["Comparison"] + " " + df_FDR_append["Cancer Type"]
df_FDR_append = df_FDR_append.set_index("Index")
df_ordered = df_FDR_append.reindex(['CD3E Head and Neck', 'CD3G Head and Neck','CD4 Head and Neck','CD8A Luad', 'LCK Head and Neck', 'ZAP70 Head and Neck','LCP2 Head and Neck', 'GRAP2 Head and Neck','VAV1 Head and Neck','GRB2 Head and Neck', 'NFATC2 Head and Neck','PPP3CC Head and Neck', 'RAC2 Head and Neck','CD79A Head and Neck','SYK Head and Neck','BTK Head and Neck','CD5 Head and Neck','PTPN6 Head and Neck','LYN Head and Neck','PTPRC Head and Neck','PIK3CG Head and Neck','INPP5D Head and Neck','PRKCQ Head and Neck',
                                    'CD4 GBM', 'LCP2 GBM', 'VAV1 GBM','GRB2 GBM', 'NFATC2 GBM','RAC2 GBM','SYK GBM','BTK GBM','BLNK GBM', 'PTPN6 GBM','PTPRC GBM', 'PIK3CD GBM', 'PIK3CG GBM','INPP5D GBM','PRKCQ GBM', 
                                    'CD3G Luad','LCK Luad', 'ZAP70 Luad','GRB2 Luad','PPP3CC Luad', 'RAC2 Luad','BLK Luad','BTK Luad','PTPN6 Luad','PIK3CD Luad','INPP5D Luad','PRKCQ Luad',
                                    'VAV1 Kidney',"ZAP70 Kidney", "INPP5D Kidney","GRAP2 Kidney","HLA-DMA GBM","HLA-DMB GBM", 
                                    "NFATC2 Lscc"])
                                    
df_ordered.head(40)
# Out:
#                      Comparison  Correlation       P_value    Cancer Type
# Index
# CD3E Head and Neck         CD3E    -0.339994  2.079403e-02  Head and Neck
# CD3G Head and Neck         CD3G    -0.381032  3.210780e-03  Head and Neck
# CD4 Head and Neck           CD4    -0.417232  5.663144e-04  Head and Neck
# CD8A Luad                  CD8A    -0.292478  2.581604e-02           Luad
# LCK Head and Neck           LCK    -0.331149  9.506279e-03  Head and Neck
# ZAP70 Head and Neck       ZAP70    -0.410167  7.208683e-04  Head and Neck
# LCP2 Head and Neck         LCP2    -0.390098  1.462062e-03  Head and Neck
# GRAP2 Head and Neck       GRAP2    -0.428093  3.591048e-04  Head and Neck
# VAV1 Head and Neck         VAV1    -0.439464  2.264489e-04  Head and Neck
# GRB2 Head and Neck         GRB2    -0.532341  3.320092e-06  Head and Neck
# NFATC2 Head and Neck     NFATC2    -0.457536  1.111948e-04  Head and Neck
# PPP3CC Head and Neck     PPP3CC    -0.359171  3.917390e-03  Head and Neck
# RAC2 Head and Neck         RAC2    -0.277100  3.855935e-02  Head and Neck
# CD79A Head and Neck       CD79A    -0.366693  3.102262e-03  Head and Neck
# SYK Head and Neck           SYK    -0.298428  2.328405e-02  Head and Neck
# BTK Head and Neck           BTK    -0.454873  1.269551e-04  Head and Neck
# CD5 Head and Neck           CD5    -0.396950  1.583339e-03  Head and Neck
# PTPN6 Head and Neck       PTPN6    -0.411321  6.865751e-04  Head and Neck
# LYN Head and Neck           LYN    -0.374709  2.361831e-03  Head and Neck
# PTPRC Head and Neck       PTPRC    -0.402397  9.771626e-04  Head and Neck
# PIK3CG Head and Neck     PIK3CG    -0.402484  9.771626e-04  Head and Neck
# INPP5D Head and Neck     INPP5D    -0.440058  2.212241e-04  Head and Neck
# PRKCQ Head and Neck       PRKCQ    -0.284462  3.293176e-02  Head and Neck
# CD4 GBM                     CD4    -0.467479  1.362923e-04            GBM
# LCP2 GBM                   LCP2    -0.460881  1.665085e-04            GBM
# VAV1 GBM                   VAV1    -0.447143  2.894593e-04            GBM
# GRB2 GBM                   GRB2    -0.610889  6.729990e-08            GBM
# NFATC2 GBM               NFATC2    -0.392602  1.681448e-03            GBM
# RAC2 GBM                   RAC2    -0.321178  1.349871e-02            GBM
# SYK GBM                     SYK    -0.470849  1.202510e-04            GBM
# BTK GBM                     BTK    -0.423380  6.552047e-04            GBM
# BLNK GBM                   BLNK    -0.356906  5.065055e-03            GBM
# PTPN6 GBM                 PTPN6    -0.402017  1.241946e-03            GBM
# PTPRC GBM                 PTPRC    -0.424958  6.196952e-04            GBM
# PIK3CD GBM               PIK3CD    -0.466265  1.399080e-04            GBM
# PIK3CG GBM               PIK3CG    -0.394048  1.602237e-03            GBM
# INPP5D GBM               INPP5D    -0.408181  1.009137e-03            GBM
# PRKCQ GBM                 PRKCQ    -0.329766  1.621074e-02            GBM
# CD3G Luad                  CD3G    -0.333706  4.093285e-02           Luad
# LCK Luad                    LCK    -0.370894  3.271948e-03           Luad

# %% [markdown]
# # Step 4: Plot Figure 2

# %%
legend_min = df_ordered["P_value"].min()
#Make plot using plot utils
p.plotCircleHeatMap(df_ordered, circle_var = "P_value",color_var = "Correlation", x_axis = "Comparison", y_axis = "Cancer Type", plot_width= 1000, plot_height = 500, legend_min = legend_min, legend_max = 0.05, font_size = 10, show_legend = True , save_png = "Figure2.png")
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3050">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ccbfa427-af04-4315-8740-6fd558ebdfba" data-root-id="3051"></div>

# %% [markdown]
# # Check if blanks are due to no data

# %% [markdown]
# The follow code chunks show that the following cancers/genes don't have data: colon THBD, Kidney MMP12, and Ovarian MMP12. (As mentioned in EGFR Figure 2 legend)

# %%
#Get append version of the df with all proteins 
df_all_prot_append = pd.read_csv("Pval_corr_table_Fig_2_return_all_append.csv")
df_all_prot_append = df_all_prot_append.drop(['Unnamed: 0'], axis=1)
#Remove Proteomics labeling 
df_all_prot_append = df_all_prot_append.replace(to_replace ='_proteomics', value = '', regex = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-043a7f1758aa> in <module>
#       6
#       7 #subset dataframe to include genes only desired for figure
# ----> 8 df_all_comp_coag = df_all_prot_append[df_all_prot_append.Comparison.isin(coag_upa)]
#       9 print("Number of rows in data frame " + str(len(df_all_comp_coag)))
#      10 df_all_prot_append
#
# NameError: name 'coag_upa' is not defined

# %%
#MHC class2 (CD4) molecules
mhc2 = ["HLA-DPA1","HLA-DPB1","HLA-DMA","HLA-DMB","HLA-DOA","HLA-DOB","HLA-DQ","HLA-DRA","HLA-DRB1"]
#subset dataframe to include genes only desired for figure 
df_all_mhc2 = df_all_prot_append[df_all_prot_append.Comparison.isin(mhc2)]
print("Number of missing columns" )
print(56 - len(df_all_mhc2))
#HLA-DP and HLA-DM missing for all. HLA-DRA and HLA-DRB1 consistently not sig 
df_all_mhc2
# Out:
# Number of missing columns
# 4
#       Comparison  Correlation   P_value    Cancer Type
# 141      HLA-DMB    -0.442005  0.000348            GBM
# 603      HLA-DMA    -0.373678  0.005056            GBM
# 1667    HLA-DPB1    -0.262423  0.055717            GBM
# 1681     HLA-DRA    -0.261173  0.057358            GBM
# 2494    HLA-DPA1    -0.218791  0.126822            GBM
# 2705    HLA-DRB1    -0.209905  0.146458            GBM
# 12448   HLA-DPB1    -0.222952  0.109021         Kidney
# 12942   HLA-DPA1    -0.199014  0.164162         Kidney
# 13489    HLA-DRA    -0.176880  0.229302         Kidney
# 15164    HLA-DMA     0.123195  0.443495         Kidney
# 18445   HLA-DRB1    -0.044398  0.827363         Kidney
# 18648    HLA-DMB    -0.039792  0.847542         Kidney
# 24454   HLA-DRB1     0.146296  0.495865        Ovarian
# 25596    HLA-DRA    -0.115924  0.605777        Ovarian
# 28370   HLA-DPA1    -0.052360  0.837835        Ovarian
# 28694   HLA-DPB1     0.044980  0.863132        Ovarian
# 29864    HLA-DMB     0.019519  0.947539        Ovarian
# 30661    HLA-DMA    -0.002345  0.995827        Ovarian
# 34370   HLA-DRB1     0.196824  0.098855         Breast
# 35195   HLA-DPA1     0.166702  0.172019         Breast
# 36631    HLA-DMA     0.134573  0.356425         Breast
# 37685    HLA-DMB     0.088111  0.511556         Breast
# 38265   HLA-DPB1     0.072042  0.600532         Breast
# 38956    HLA-DRA     0.052811  0.711526         Breast
# 41990    HLA-DRA     0.270801  0.040933           Luad
# 43833   HLA-DPA1     0.184269  0.196235           Luad
# 44037    HLA-DMB     0.177418  0.216594           Luad
# 44401   HLA-DPB1     0.165584  0.255514           Luad
# 45569    HLA-DOA     0.151911  0.383575           Luad
# 45873   HLA-DRB1     0.124300  0.420163           Luad
# 48784    HLA-DOB    -0.066582  0.741646           Luad
# 50193    HLA-DMA    -0.027738  0.889242           Luad
# 52379    HLA-DMB    -0.290547  0.028390  Head and Neck
# 52951    HLA-DMA    -0.252281  0.076947  Head and Neck
# 53389   HLA-DPB1    -0.221519  0.118457  Head and Neck
# 54502   HLA-DRB1    -0.175415  0.242017  Head and Neck
# 55143    HLA-DRA    -0.154935  0.313356  Head and Neck
# 56922   HLA-DPA1    -0.106554  0.524974  Head and Neck
# 63269    HLA-DOB    -0.227253  0.159880           Lscc
# 63784    HLA-DMB    -0.201418  0.232838           Lscc
# 64326   HLA-DPB1    -0.179610  0.307518           Lscc
# 65257   HLA-DRB1    -0.151224  0.414930           Lscc
# 66021    HLA-DMA    -0.132824  0.486062           Lscc
# 66928   HLA-DPA1    -0.110666  0.592151           Lscc
# 67687    HLA-DRA    -0.096418  0.648168           Lscc
# 68087    HLA-DOA    -0.147955  0.684254           Lscc
# 74659   HLA-DRB1     0.243673  0.102476          Colon
# 79534    HLA-DMB     0.037077  0.851579          Colon
# 79568   HLA-DPA1     0.036115  0.855265          Colon
# 79983    HLA-DRA    -0.022677  0.910492          Colon
# 80054    HLA-DMA     0.027898  0.917367          Colon
# 80198   HLA-DPB1    -0.015465  0.939902          Colon

# %%
#CD8 and MHC class 1 molecules
mhc1 = ["CD8A","HLA-A","HLA-B","HLA-C"]

df_all_mhc1 = df_all_prot_append[df_all_prot_append.Comparison.isin(mhc1)]
df_all_mhc1
# Out:
#       Comparison  Correlation   P_value    Cancer Type
# 4460       HLA-C     0.149001  0.338227            GBM
# 4767       HLA-B     0.140454  0.371550            GBM
# 6132        CD8A    -0.155200  0.528789            GBM
# 8068       HLA-A    -0.058388  0.749978            GBM
# 13260       CD8A    -0.240222  0.201476         Kidney
# 16995      HLA-A    -0.082140  0.673774         Kidney
# 17871      HLA-B    -0.056599  0.769694         Kidney
# 19497      HLA-C    -0.022882  0.917089         Kidney
# 26082       CD8A     0.108046  0.656611        Ovarian
# 26858      HLA-C     0.085650  0.719148        Ovarian
# 28553      HLA-B     0.048173  0.853008        Ovarian
# 28760      HLA-A     0.043865  0.866842        Ovarian
# 35058      HLA-A     0.178391  0.156305         Breast
# 36799       CD8A     0.117063  0.379066         Breast
# 36884      HLA-C     0.111106  0.393245         Breast
# 40220      HLA-B     0.018660  0.903281         Breast
# 41694       CD8A    -0.292478  0.025816           Luad
# 44338      HLA-B     0.167621  0.248299           Luad
# 47413      HLA-A    -0.097372  0.587799           Luad
# 51159      HLA-C    -0.010527  0.963644           Luad
# 52718       CD8A    -0.261069  0.055836  Head and Neck
# 56637      HLA-A    -0.114655  0.482804  Head and Neck
# 61086      HLA-C     0.016743  0.941696  Head and Neck
# 61711      HLA-B    -0.003951  0.990387  Head and Neck
# 62767      HLA-A     0.260466  0.092815           Lscc
# 62923       CD8A    -0.246814  0.120444           Lscc
# 67880      HLA-B     0.092719  0.664397           Lscc
# 73161      HLA-C    -0.005874  0.983589           Lscc
# 74959      HLA-A    -0.223933  0.137092          Colon
# 77570      HLA-B    -0.105428  0.536007          Colon
# 78243       CD8A     0.116971  0.647257          Colon
# 79644      HLA-C     0.033580  0.866157          Colon

# %%
#Remove Proteomics labeling 
df_all_prot_append = df_all_prot_append.replace(to_replace ='_proteomics', value = '', regex = True) 

#subset dataframe to include genes only desired for figure 
df_all_comp_coag = df_all_prot_append[df_all_prot_append.Comparison.isin(coag_upa)]
print("Number of rows in data frame " + str(len(df_all_comp_coag)))

# %% [markdown]
# Our Figure includes 26 genes for 8 cancers. If all data was present there would be 208 rows. However, the data frame only has 205 rows. 3 genes are missing.

# %%
def find_missing_genes(test_list, full_list):
    for gene in full_list:
        if (gene not in test_list):
            print(gene)

# %%
#Get list of genes for colon, kidney, and ovarian
colon = df_all_prot_append[df_all_prot_append["Cancer Type"] == "Colon"]
colon_list = colon.Comparison.to_list()

Kidney = df_all_prot_append[df_all_prot_append["Cancer Type"] == "Kidney"]
Kidney_list = Kidney.Comparison.to_list()

Ovarian = df_all_prot_append[df_all_prot_append["Cancer Type"] == "Ovarian"]
Ovarian_list = Ovarian.Comparison.to_list()

# %%
#Show the 3 missing genes 
print("Ovarian missing genes: ")
find_missing_genes(Ovarian_list, coag_upa)
print("Kidney missing genes: ")
find_missing_genes(Kidney_list, coag_upa)
print("Colon missing genes: ")
find_missing_genes(colon_list, coag_upa)
