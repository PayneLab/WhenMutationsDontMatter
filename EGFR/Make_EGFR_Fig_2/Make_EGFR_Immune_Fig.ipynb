# %% [markdown]
# # Make EGFR Immune Figure

# %% [markdown]
# This notebooks takes all the trans genes that have the same results and runs a GSEA using NCI-Nature_2016. Top hits included T and B cell signaling pathways. Heat map includes genes from GSEA as well as additional genes realted to the immune system.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas.util.testing as tm
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest

import gseapy as gp
from gseapy.plot import barplot, dotplot

import cptac
import cptac.utils as u
import plot_utils as p 
import warnings
warnings.filterwarnings('ignore')
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# cptac warning: Your version of cptac (0.8.2) is out-of-date. Latest is 0.8.4. Please run 'pip install --upgrade cptac' to update it. (/Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py, line 14)

# %% [markdown]
# # Step 1: Find Trans proteins with opposite effects in different cancers

# %% [markdown]
# Load df with all of the genes that are FDR significant.

# %%
FDR_sig = pd.read_csv("../Make_Tables/csv_files/Supplemental_Table_EGFR_sig_only.csv")
FDR_sig = FDR_sig.set_index("Comparison")
FDR_sig
# Out:
#             Correlation_Gbm   P_value_Gbm  Correlation_Kidney  P_value_Kidney  \
# Comparison
# PHLDA1             0.816848  3.507071e-21                 NaN             NaN
# GRB2              -0.610889  6.729990e-08                 NaN             NaN
# SOCS2              0.562720  3.420388e-06                 NaN             NaN
# CDH4               0.559180  3.420388e-06                 NaN             NaN
# DAB2              -0.556402  3.420388e-06                 NaN             NaN
# ...                     ...           ...                 ...             ...
# CLTC                    NaN           NaN                 NaN             NaN
# PLEC                    NaN           NaN                 NaN             NaN
# LRRK2                   NaN           NaN                 NaN             NaN
# MBD1                    NaN           NaN                 NaN             NaN
# RRP12                   NaN           NaN                 NaN             NaN
#
#             Correlation_Ovarian  P_value_Ovarian  Correlation_Luad  \
# Comparison
# PHLDA1                      NaN              NaN               NaN
# GRB2                        NaN              NaN         -0.302439
# SOCS2                       NaN              NaN               NaN
# CDH4                        NaN              NaN               NaN
# DAB2                        NaN              NaN               NaN
# ...                         ...              ...               ...
# CLTC                        NaN              NaN               NaN
# PLEC                        NaN              NaN               NaN
# LRRK2                       NaN              NaN               NaN
# MBD1                        NaN              NaN               NaN
# RRP12                       NaN              NaN               NaN
#
#             P_value_Luad  Correlation_Lscc  P_value_Lscc  Correlation_Brca  \
# Comparison
# PHLDA1               NaN          0.713420  2.644826e-14          0.364797
# GRB2            0.020631               NaN           NaN               NaN
# SOCS2                NaN          0.472624  1.417921e-02               NaN
# CDH4                 NaN               NaN           NaN               NaN
# DAB2                 NaN               NaN           NaN          0.326055
# ...                  ...               ...           ...               ...
# CLTC                 NaN               NaN           NaN               NaN
# PLEC                 NaN               NaN           NaN               NaN
# LRRK2                NaN               NaN           NaN               NaN
# MBD1                 NaN               NaN           NaN               NaN
# RRP12                NaN               NaN           NaN               NaN
#
#             P_value_Brca  Correlation_Colon  P_value_Colon  Correlation_Hnscc  \
# Comparison
# PHLDA1          0.002164                NaN            NaN           0.664271
# GRB2                 NaN                NaN            NaN          -0.532341
# SOCS2                NaN                NaN            NaN                NaN
# CDH4                 NaN                NaN            NaN                NaN
# DAB2            0.003543                NaN            NaN                NaN
# ...                  ...                ...            ...                ...
# CLTC                 NaN                NaN            NaN           0.267632
# PLEC                 NaN                NaN            NaN           0.267522
# LRRK2                NaN                NaN            NaN          -0.267457
# MBD1                 NaN                NaN            NaN          -0.266098
# RRP12                NaN                NaN            NaN           0.266066
#
#             P_value_Hnscc
# Comparison
# PHLDA1       8.888640e-12
# GRB2         3.320092e-06
# SOCS2                 NaN
# CDH4                  NaN
# DAB2                  NaN
# ...                   ...
# CLTC         4.813589e-02
# PLEC         4.824560e-02
# LRRK2        4.830683e-02
# MBD1         4.993781e-02
# RRP12        4.993781e-02
#
# [6230 rows x 16 columns]

# %%
def HasPosNeg(row):
    hasPos = False
    hasNeg= False

    for item in row:
        if pd.isnull(item):
            continue
        if item < 0:
            hasNeg = True
        if item > 0:
            hasPos = True
            
    if hasPos & hasNeg:
        return True
    return False

def CountPosNeg(row):
    hasPos = False
    hasNeg= False
    counter = 0
    for item in row:
        if pd.isnull(item):
            continue
        if item < -0:
            hasNeg = True
            counter += 1
        if item > 0:
            hasPos = True
            counter += 1
    return counter

# %% [markdown]
# Subset data frame to include only trans genes that have the same effects in different cancers by using apply function

# %%
col = ["Correlation_Gbm","Correlation_Kidney","Correlation_Ovarian","Correlation_Brca","Correlation_Luad","Correlation_Hnscc","Correlation_Lscc","Correlation_Colon"]
FDR_corr = FDR_sig[col]
FDR_corr["Pos_Neg"] = FDR_corr.apply(HasPosNeg, axis = 1)

FDR_corr_False = FDR_corr[FDR_corr['Pos_Neg']==False]

# %%
#Get only proteins significant in atleast two cancers
FDR_corr_False["Num_corr"] = FDR_corr_False.apply(CountPosNeg, axis = 1)
FDR_corr_False.sort_values(by=['Num_corr'],ascending=False)
FDR_corr_False = FDR_corr_False[FDR_corr_False['Num_corr'].isin([2,3,4,5,6])]
FDR_corr_False.head()
# Out:
#             Correlation_Gbm  Correlation_Kidney  Correlation_Ovarian  \
# Comparison
# PHLDA1             0.816848                 NaN                  NaN
# GRB2              -0.610889                 NaN                  NaN
# SOCS2              0.562720                 NaN                  NaN
# GLA               -0.550491           -0.298348                  NaN
# PHLDA3             0.525883            0.432530                  NaN
#
#             Correlation_Brca  Correlation_Luad  Correlation_Hnscc  \
# Comparison
# PHLDA1              0.364797               NaN           0.664271
# GRB2                     NaN         -0.302439          -0.532341
# SOCS2                    NaN               NaN                NaN
# GLA                      NaN               NaN                NaN
# PHLDA3                   NaN               NaN           0.763784
#
#             Correlation_Lscc  Correlation_Colon  Pos_Neg  Num_corr
# Comparison
# PHLDA1              0.713420                NaN    False         4
# GRB2                     NaN                NaN    False         3
# SOCS2               0.472624                NaN    False         2
# GLA                      NaN                NaN    False         2
# PHLDA3              0.682034                NaN    False         4

# %%
same_sign_prot = FDR_corr_False.index.tolist()
print("Total number of trans proteins with same effects in different cancers is " + str(len(same_sign_prot)))
# Out:
# Total number of trans proteins with same effects in different cancers is 1136

# %% [markdown]
# # Run GSEA

# %%
same_sign_enr = gp.enrichr(gene_list = same_sign_prot, description='Tumor_partition', gene_sets='NCI-Nature_2016', 
                       outdir='test/enrichr_KEGG')
same_sign_enr.res2d.head(20)
# Out:
#            Gene_set                                               Term  \
# 0   NCI-Nature_2016  CXCR4-mediated signaling events Homo sapiens 4...
# 1   NCI-Nature_2016  TCR signaling in naive CD4+ T cells Homo sapie...
# 2   NCI-Nature_2016  HIF-1-alpha transcription factor network Homo ...
# 3   NCI-Nature_2016  TCR signaling in naive CD8+ T cells Homo sapie...
# 4   NCI-Nature_2016  Integrin family cell surface interactions Homo...
# 5   NCI-Nature_2016  a6b1 and a6b4 Integrin signaling Homo sapiens ...
# 6   NCI-Nature_2016  PDGFR-beta signaling pathway Homo sapiens c901...
# 7   NCI-Nature_2016  Arf6 trafficking events Homo sapiens 7a5b8f09-...
# 8   NCI-Nature_2016  Validated transcriptional targets of TAp63 iso...
# 9   NCI-Nature_2016  Beta1 integrin cell surface interactions Homo ...
# 10  NCI-Nature_2016  Plexin-D1 Signaling Homo sapiens e3068f36-6194...
# 11  NCI-Nature_2016  BCR signaling pathway Homo sapiens acbf44e2-61...
# 12  NCI-Nature_2016  Class I PI3K signaling events Homo sapiens 12b...
# 13  NCI-Nature_2016  IL3-mediated signaling events Homo sapiens c86...
# 14  NCI-Nature_2016  Direct p53 effectors Homo sapiens 67c3b75d-619...
# 15  NCI-Nature_2016  IL8- and CXCR2-mediated signaling events Homo ...
# 16  NCI-Nature_2016  p38 signaling mediated by MAPKAP kinases Homo ...
# 17  NCI-Nature_2016  IL4-mediated signaling events Homo sapiens cff...
# 18  NCI-Nature_2016  Trk receptor signaling mediated by PI3K and PL...
# 19  NCI-Nature_2016  RAC1 signaling pathway Homo sapiens faffa4fc-6...
#
#    Overlap       P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0   29/100  1.333890e-13      2.787831e-11            0                     0
# 1    20/64  1.854077e-10      1.937511e-08            0                     0
# 2    17/66  1.054419e-07      7.345784e-06            0                     0
# 3    15/53  1.530121e-07      7.994882e-06            0                     0
# 4    10/26  7.732610e-07      3.232231e-05            0                     0
# 5    13/45  7.942656e-07      2.766692e-05            0                     0
# 6   23/128  8.028533e-07      2.397091e-05            0                     0
# 7    13/49  2.310351e-06      6.035792e-05            0                     0
# 8    13/53  5.988083e-06      1.390566e-04            0                     0
# 9    14/66  1.616497e-05      3.378478e-04            0                     0
# 10    8/24  3.431089e-05      6.519070e-04            0                     0
# 11   13/64  5.225732e-05      9.101482e-04            0                     0
# 12   11/48  6.117578e-05      9.835184e-04            0                     0
# 13    8/26  6.583151e-05      9.827704e-04            0                     0
# 14  20/136  8.482862e-05      1.181945e-03            0                     0
# 15    9/34  8.594088e-05      1.122603e-03            0                     0
# 16    7/21  1.076224e-04      1.323122e-03            0                     0
# 17   12/60  1.179090e-04      1.369055e-03            0                     0
# 18    9/36  1.392070e-04      1.531277e-03            0                     0
# 19   11/54  1.895675e-04      1.980980e-03            0                     0
#
#     Odds Ratio  Combined Score  \
# 0     5.105634      151.359100
# 1     5.501761      123.286002
# 2     4.534784       72.851793
# 3     4.982727       78.192676
# 4     6.771398       95.291503
# 5     5.086072       71.438194
# 6     3.163512       44.400192
# 7     4.670882       60.619231
# 8     4.318363       51.931507
# 9     3.734528       41.201798
# 10    5.868545       60.328918
# 11    3.576144       35.258390
# 12    4.034624       39.142954
# 13    5.417118       52.158245
# 14    2.589064       24.272156
# 15    4.660315       43.629173
# 16    5.868545       53.620199
# 17    3.521127       31.850695
# 18    4.401408       39.082520
# 19    3.586333       30.737618
#
#                                                 Genes
# 0   GNAI3;PIK3CD;CD3G;ARRB2;PIK3CG;GNAI1;GRK6;PTK2...
# 1   MAP4K1;WAS;CD3G;VAV1;ZAP70;CD4;PTPRC;STIM1;LCK...
# 2   EGLN1;JUN;TFRC;SLC2A1;ENO1;NDRG1;HK2;NT5E;LDHA...
# 3   CD3G;VAV1;ZAP70;PTPRC;STIM1;LCK;GRAP2;TRAF6;LC...
# 4   ITGA4;ITGB4;ITGA2;ITGB8;ITGA7;ITGAV;ITGA6;ITGB...
# 5   COL17A1;LAMA5;LAMB3;ITGB4;LAMC2;YWHAZ;YWHAQ;CD...
# 6   CYFIP2;STAT5A;NCKAP1;STAT5B;JUN;YES1;LRP1;SPHK...
# 7   RALA;ITGA4;ITGA2;MAPK8IP3;ACAP1;CDH1;CTNNA1;IT...
# 8   GPX2;TFAP2C;JAG1;S100A2;ITGB4;PRKCD;YWHAQ;SP1;...
# 9   COL18A1;LAMA5;ITGA4;LAMB3;ITGA2;TNC;FN1;LAMC2;...
# 10  SEMA4A;ITGA4;IQSEC1;ITGA2;ITGA7;ITGAV;ITGA6;ITGA5
# 11  MAP4K1;JUN;SYK;POU2F2;DOK1;PPP3CC;PTPRC;TRAF6;...
# 12  CYTH3;ZAP70;YES1;SYK;PLEKHA1;LCK;INPPL1;BTK;PI...
# 13  STAT5A;STAT5B;CEBPB;GRB2;PRKACA;YWHAZ;YWHAG;BC...
# 14  COL18A1;STEAP3;DDX5;JUN;GPX1;S100A2;CSE1L;HGF;...
# 15  PLCB3;RAC2;ELMO1;ARRB1;ARRB2;DOCK2;PLCB1;PLCB2...
# 16          YWHAQ;MAPKAPK2;HSPB1;SFN;LSP1;YWHAZ;YWHAG
# 17  STAT5A;SELP;STAT5B;CEBPB;SPI1;ARG1;IRF4;SP1;TF...
# 18  STAT5A;YWHAQ;PRKCD;AGAP2;SFN;KRAS;GRB2;YWHAZ;Y...
# 19  CYFIP2;MAP2K3;STAT5A;NCKAP1;JUN;CDH1;LIMK1;CTN...

# %%
#get just the clotting cascade genes and add urokinase genes 
same_sign_df = same_sign_enr.res2d
T_H_cell = same_sign_df.iloc[1,9]
T_H_cell = T_H_cell.split(';')
T_K_cell = same_sign_df.iloc[3,9]
T_K_cell = T_K_cell.split(";")
immune_both =  T_H_cell + T_K_cell
immune = set(immune_both)
immune = list(immune)
btcell_apm = (["FYB1","PLCG1","CD5","CD8A","BLK","BLNK","CD79A","INPP5D","LYN","CD3E","HLA-DMA","HLA-DMB","PRKCB","NFKB2","CHUK","PLCG2","PPP3CB","PPP3CC","MAP3K8","NFATC2","PIK3CG","SYK","BTK","RAC2","ELMO1","DOCK2","WAS"])

immune= immune + btcell_apm

immune.remove("FLNA")
immune.remove("WAS")
immune.remove("NCK1")
immune.remove("CARD11")
immune.remove("TRAF6")
immune.remove("STIM1")
immune.remove("KRAS")

# %%
cxcr4 = same_sign_df.iloc[0,9]
cxcr4 = cxcr4.split(';')

# %% [markdown]
# # Step 3 Make Data frame for figure 2

# %%
#Get append version of the df with all cancer type, fdr sig trans results
df_FDR_append = pd.read_csv("../Make_Tables/csv_files/sig_prot_heatmap_EGFR.csv")

#subset dataframe to include genes only desired for figure 
df_FDR_append= df_FDR_append[df_FDR_append.Comparison.isin(immune)]
df_FDR_append
# Out:
#      Comparison  Correlation_Gbm  P_value_Gbm  Cancer  Correlation_Hnscc  \
# 689       PRKCB              NaN          NaN  Kidney                NaN
# 737       PLCG2              NaN          NaN  Kidney                NaN
# 885       GRAP2              NaN          NaN  Kidney                NaN
# 945       DOCK2              NaN          NaN  Kidney                NaN
# 1015       VAV1              NaN          NaN  Kidney                NaN
# 1064        WAS              NaN          NaN  Kidney                NaN
# 1096      PLCG1              NaN          NaN  Kidney                NaN
# 1108      ZAP70              NaN          NaN  Kidney                NaN
# 1165     INPP5D              NaN          NaN  Kidney                NaN
# 1362      PRKCB              NaN          NaN   Colon                NaN
# 1484      NFKB2              NaN          NaN   Colon                NaN
#
#       P_value_Hnscc  Correlation_Luad  P_value_Luad  Correlation_Lscc  \
# 689             NaN               NaN           NaN               NaN
# 737             NaN               NaN           NaN               NaN
# 885             NaN               NaN           NaN               NaN
# 945             NaN               NaN           NaN               NaN
# 1015            NaN               NaN           NaN               NaN
# 1064            NaN               NaN           NaN               NaN
# 1096            NaN               NaN           NaN               NaN
# 1108            NaN               NaN           NaN               NaN
# 1165            NaN               NaN           NaN               NaN
# 1362            NaN               NaN           NaN               NaN
# 1484            NaN               NaN           NaN               NaN
#
#       P_value_Lscc  Correlation_Brca  P_value_Brca  Correlation   P_Value
# 689            NaN               NaN           NaN    -0.322809  0.011837
# 737            NaN               NaN           NaN    -0.317009  0.013691
# 885            NaN               NaN           NaN    -0.305290  0.021277
# 945            NaN               NaN           NaN    -0.293756  0.024582
# 1015           NaN               NaN           NaN    -0.285693  0.030254
# 1064           NaN               NaN           NaN    -0.279814  0.035337
# 1096           NaN               NaN           NaN    -0.287556  0.037584
# 1108           NaN               NaN           NaN    -0.276087  0.038339
# 1165           NaN               NaN           NaN    -0.271891  0.041827
# 1362           NaN               NaN           NaN     0.395927  0.006516
# 1484           NaN               NaN           NaN     0.357365  0.012480

# %%
legend_min = df_FDR_append["P_Value"].min()
#Make plot using plot utils
p.plotCircleHeatMap(df_FDR_append, circle_var = "P_Value",color_var = "Correlation", x_axis = "Comparison", y_axis = "Cancer", plot_width= 1000, plot_height = 500, legend_min = legend_min, legend_max = 0.05, font_size = 10, show_legend = True , save_png = "Figure2.png")

# %% [markdown]
# CHUK not significant in any cancer.

# %% [markdown]
# Set add new column to be unique index and order the new index. This way genes will be grouped by coagulation factors, regulators, and urokinase genes.

# %%
df_FDR_append["Index"] = df_FDR_append["Comparison"] + " " + df_FDR_append["Cancer"]
df_FDR_append = df_FDR_append.set_index("Index")
df_ordered = df_FDR_append.reindex(['CD3E Hnscc', 'CD3G Hnscc','CD4 Hnscc','CD8A Luad', 'LCK Hnscc', 'ZAP70 Hnscc','LCP2 Hnscc', 'GRAP2 Hnscc','VAV1 Hnscc','GRB2 Hnscc',"LCP2 Hnscc","FYB1 Hnscc" , "PLCG1 Gbm",'NFATC2 Hnscc','PPP3CC Hnscc', 'RAC2 Hnscc','CD79A Hnscc','SYK Hnscc','BTK Hnscc','CD5 Hnscc','PTPN6 Hnscc','LYN Hnscc','PTPRC Hnscc','PIK3CG Hnscc','INPP5D Hnscc','PRKCQ Hnscc','BLNK Gbm','BLK Luad',"HLA-DMA Gbm", "HLA-DMB Gbm","HLA-DMB Hnscc",
                                    "NFKB2 Gbm" ,"NFKB2 Luad", "PRKCB Hnscc", "PRKCB Luad", "PRKCB Kidney","PLCG2 Hnscc","PLCG2 Gbm","PLCG2 Luad","PLCG2 Kidney","ELMO1 Gbm","DOCK2 Gbm","WAS Gbm","ELMO1 Hnscc","DOCK2 Hnscc","WAS Hnscc",
                                    'CD4 Gbm', 'LCP2 Gbm', 'VAV1 Gbm','GRB2 Gbm', "FYB1 Gbm", "LCP2 Gbm", 'NFATC2 Gbm','RAC2 Gbm','SYK Gbm','BTK Gbm', 'PTPN6 Gbm','PTPRC Gbm','PIK3CG Gbm','INPP5D Gbm','PRKCQ Gbm', 
                                    'CD3G Luad','LCK Luad',"FYB1 Luad", 'ZAP70 Luad','GRB2 Luad','PPP3CC Luad', 'RAC2 Luad','BTK Luad','PTPN6 Luad','INPP5D Luad','PRKCQ Luad',"WAS Luad","DOCK2 Luad","ELMO1 Hnscc",
                                    'VAV1 Kidney',"PLCG1 Kidney","ZAP70 Kidney", "INPP5D Kidney","GRAP2 Kidney","WAS Kidney","HLA-DMA Gbm","HLA-DMB Gbm", 
                                    "NFATC2 Lscc" ,"PLCG2 Brca", "PLCG1 Brca","NFKB2 Colon", "PRKCB Colon"])

# %% [markdown]
# # Step 4: Plot Figure 2

# %%
legend_min = df_ordered["P_Value"].min()
#Make plot using plot utils
p.plotCircleHeatMap(df_ordered, circle_var = "P_Value",color_var = "Correlation", x_axis = "Comparison", y_axis = "Cancer", plot_width= 1200, plot_height = 500, legend_min = legend_min, legend_max = 0.05, font_size = 10, show_legend = True , save_png = "Figure_EGFR_immune.png")

# %% [markdown]
# # Check if blanks are due to no data

# %% [markdown]
# The follow code chunks show that the following cancers/genes don't have data: colon THBD, Kidney MMP12, and Ovarian MMP12. (As mentioned in EGFR Figure 2 legend)

# %%
#Get append version of the df with all proteins 
df_all_prot_append = pd.read_csv("../Make_Tables/csv_files/all_prot_heatmap_EGFR.csv")
df_all_prot_append

#subset dataframe to include genes only desired for figure 
df_all_immune = df_all_prot_append[df_all_prot_append.Comparison.isin(immune)]
print("Number of rows in data frame " + str(len(df_all_immune)))
#total of 37 immune proteins x 8 cancers should have 296 rows.  missing data 31 genes

# %%
def find_NA_genes (immune,cancer_list):
    checked = []
    missing = []
    for gene in immune:
        if gene in cancer_list:
            checked.append(gene)
        else:
            missing.append(gene)
    return missing

# %%
cancers = ["Gbm", "Luad","Lscc","Hnscc","Ovarian","Kidney","Brca","Colon"]
for cancer in cancers:
    cancer_check = df_all_immune[df_all_immune["Cancer"] == cancer]
    cancer_check = cancer_check.Comparison.to_list()
    print(cancer)
    print(find_NA_genes(immune,cancer_check))

# %%
#MHC class2 (CD4) molecules
mhc2 = ["HLA-DPA1","HLA-DPB1","HLA-DMA","HLA-DMB","HLA-DOA","HLA-DOB","HLA-DQ","HLA-DRA","HLA-DRB1"]
#subset dataframe to include genes only desired for figure 
df_all_mhc2 = df_all_prot_append[df_all_prot_append.Comparison.isin(mhc2)]
print("Number of missing columns" )
print(56 - len(df_all_mhc2))
#HLA-DP and HLA-DM missing for all. HLA-DRA and HLA-DRB1 consistently not sig 
df_all_mhc2

# %%
#CD8 and MHC class 1 molecules
mhc1 = ["CD28","PDCD1","CD279","CTL4","CD152"] #don't have data for pd-1 (pdcd1 or cd279) and CTLA4 (aka CD152)

df_all_mhc1 = df_all_prot_append[df_all_prot_append.Comparison.isin(mhc1)]
df_all_mhc1
