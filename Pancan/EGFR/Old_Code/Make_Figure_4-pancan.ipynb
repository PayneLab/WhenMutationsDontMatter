# %% [markdown]
# # Make Figure 4

# %% [markdown]
# This notebooks takes all the trans genes that have positive and negative results and runs a GSEA using Reactome. It then takes a subset of genes from the top hit (Hemostasis) pathway and maps them on a large circle heat map. This heatmap focuses on coagulation and urokinase related genes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas.util.testing as tm
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest

import gseapy as gp
from gseapy.plot import barplot, dotplot

import plot_utils as p 
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import math as math

import statsmodels.stats.multitest
from bokeh.palettes import RdBu
from bokeh.models import LinearColorMapper, ColumnDataSource, ColorBar
from bokeh.models.ranges import FactorRange
from bokeh.plotting import figure, show
from bokeh.io import output_notebook, export_png, export_svgs
from bokeh.layouts import row
# Out:
# C:\Users\mtstu\AppData\Local\Temp/ipykernel_14612/2106242056.py:5: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
def plotCircleHeatMap ( df, circle_var, color_var, x_axis, y_axis, plot_width= 1000, plot_height = 650, font_size = 12,    x_axis_lab = "no_label", y_axis_lab = "no_label", show_plot = True, save_png = "plot.png", legend_min = 1e-6, legend_med = .0001, legend_max = 0.01, show_legend = True):
  
    # circle_var designed for pvalues. Normalized by taking log 10 of values and multiplying by 5 
    #added a new column to make the plot size
    
    df["size2"] = df[circle_var].apply(lambda x: -1*(np.log(x)))
    df['size'] = (df["size2"])*3
    #find values to set color bar min/ max as 
    maxval = df[color_var].max()
    minval = df[color_var].min()
    if maxval > abs(minval):
        minval = maxval * -1 
    if maxval < abs(minval):
        maxval = minval * -1
    colors = list((RdBu[9]))
    exp_cmap = LinearColorMapper(palette=colors, low = minval, high = maxval)
    p = figure(x_range = FactorRange(), y_range = FactorRange(), plot_width= plot_width, 
               plot_height=plot_height, 
               toolbar_location=None, tools="hover")

    p.scatter(x_axis,y_axis,source=df, fill_alpha=1,  line_width=0, size="size", 
              fill_color={"field":color_var, "transform":exp_cmap})

    #p.x_range.factors = sorted(df[x_axis].unique().tolist())
    p.x_range.factors = df[x_axis].unique().tolist()
    p.y_range.factors = sorted(df[y_axis].unique().tolist(), reverse = True)
    p.xaxis.major_label_orientation = math.pi/2
    
    # font size
    p.axis.major_label_text_font_size = str(font_size)+"pt"
    p.axis.axis_label_text_font_size = str(font_size)+"pt"
    
    if (x_axis_lab != "no_label" ):
        p.xaxis.axis_label = x_axis_lab
    if (y_axis_lab != "no_label" ):   
        p.yaxis.axis_label = y_axis_lab

    bar = ColorBar(color_mapper=exp_cmap, location=(0,0))
    p.add_layout(bar, "right")
    
    if show_plot:  
        if show_legend:
            # Create Circle Legend
            circle_legend = create_circle_legend(circle_var, color_var, legend_min, legend_med, legend_max)
            circle_legend.axis.major_label_text_font_size = str(font_size - 1)+"pt" # font size
            output_notebook()
            show(row(p, circle_legend))
        else:
            output_notebook()
            show(p)
      
    if save_png != "plot.png":
        export_png(row(p, circle_legend), filename= save_png)
        
    return p
         

'''
@Param legend_min: Float. Lowest p-value to include in the legend.
@Param legend_max: Float. Highest p-value to include in the legend.
@Param color_var: Str. Used for column name (same as other df)

Returns: df to be used in creating the circle legend. 
'''

def create_circle_legend_df(color_var, legend_min, legend_med, legend_max):
    # Find middle pval
    
    #exp_min = abs(np.log10(legend_min))
    #exp_max = abs(np.log10(legend_max))
    #delta = (exp_min - exp_max) / 2 
    #exp_mid = -1 * (exp_max + delta)
    #pval2 = 1 * 10**exp_mid
    
    # Foramat scientific notation pvals as strings for y_axis labels  
    max_str = "{:.1e}".format(legend_max, '.2f')
    med_str = "{:.1e}".format(legend_med, '.2f')
    min_str = "{:.1e}".format(legend_min, '.2f')
    
    # max to min
    data = {'P_Value':  [legend_max, legend_med, legend_min],
            'y_axis': [max_str, med_str, min_str],
            'x_axis': ['', '', ''],
            color_var: [1.5, 1.5, 1.5]}

    fake_df = pd.DataFrame (data, columns = ['x_axis', 'y_axis', 'P_Value', color_var])
    
    fake_df["size2"] = fake_df['P_Value'].apply(lambda x: -1*(np.log(x)))
    fake_df['size'] = (fake_df["size2"])*3
    
    return fake_df

'''
@Param df: Dataframe. Same as df passed to plotCircleHeatMap.
@Param circle_var: Column Label. Same as passed to plotCircleHeatMap.
@Param color_var: Column Label. Same as passed to plotCircleHeatMap.
@Param x_axis: Column Label. Used on the x-axis.
@Param y_axis: Column Label. Used on the y-axis.
@Param legend_min: Float. Lowest p-value to include in the legend.
@Param legend_max: Float. Highest p-value to include in the legend.

Returns: df to be used in creating the circle legend. 
'''

def create_circle_legend(circle_var, color_var, legend_min, legend_med, legend_max,
                         x_axis = 'x_axis', y_axis = 'y_axis', 
                         plot_height = 200, plot_width = 140):
    # Get customized df
    circle_df = create_circle_legend_df(color_var, legend_min, legend_med, legend_max)
    
    maxval = circle_df[color_var].max()
    minval = circle_df[color_var].min()
    if maxval > abs(minval):
        minval = maxval * -1 
    if maxval < abs(minval):
        maxval = minval * -1
    colors = list((RdBu[9]))
    exp_cmap = LinearColorMapper(palette=colors, low = minval, high = maxval)
    
    circle = figure(x_range = FactorRange(), y_range = FactorRange(), plot_width= plot_width, 
               plot_height=plot_height, toolbar_location=None, tools="hover")

    circle.scatter(x_axis, y_axis, source = circle_df, fill_alpha=1,  line_width=0, size="size", 
              fill_color={"field":color_var, "transform":exp_cmap})
    
    circle.x_range.factors = sorted(circle_df[x_axis].unique().tolist())
    circle.y_range.factors = circle_df[y_axis].unique().tolist() # plots in reverse order of circle_df (max to min)
    circle.xaxis.major_label_orientation = math.pi/2
    
    circle.xaxis.axis_label = 'FDR p-value'
    
    return circle

# %% [markdown]
# # Step 1: Find Trans proteins with opposite effects in different cancers

# %% [markdown]
# Load df with all of the genes that are FDR significant. This dataframe was made in the Make_Supplemental_Tables notebook. See
# https://github.com/PayneLab/WhenMutationsDontMatter/blob/master/EGFR/Make_Tables/Make_Supplemental_Tables.ipynb

# %%
FDR_sig = pd.read_csv("csv_files/Supplemental_Table_EGFR_sig_only.csv")
FDR_sig = FDR_sig.set_index("Comparison")

# %%
FDR_sig.max(axis=1)
FDR_sig.min(axis = 1)
# Out:
# Comparison
# PHLDA1      9.649849e-19
# CDH4        4.744022e-10
# GRB2       -5.890078e-01
# SOCS2       2.006861e-06
# PHLDA3      2.351012e-14
#                 ...
# VPS37B     -2.461344e-01
# SCN10A     -3.648703e-01
# PCYT1A      4.976210e-02
# NCBP1       4.976210e-02
# IGHV3-43   -2.451771e-01
# Length: 6376, dtype: float64

# %%
def HasPosNeg(row):
    hasPos = False
    hasNeg= False

    for item in row:
        if pd.isnull(item):
            continue
        if item < 0:
            hasNeg = True
        if item > 0:
            hasPos = True
            
    if hasPos & hasNeg:
        return True
    return False

# %% [markdown]
# Subset data frame to include only trans genes that have opposite effects in different cancers by using apply function

# %%
col = ["Correlation_GBM","Correlation_ccRCC","Correlation_BR","Correlation_LUAD","Correlation_HNSCC","Correlation_LSCC"]
FDR_corr = FDR_sig[col]
FDR_corr["Pos_Neg"] = FDR_corr.apply(HasPosNeg, axis = 1)
FDR_corr_True = FDR_corr[FDR_corr['Pos_Neg']==True]
FDR_corr_True.head(20)
# Out:
# C:\Users\mtstu\AppData\Local\Temp/ipykernel_14612/4294753839.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FDR_corr["Pos_Neg"] = FDR_corr.apply(HasPosNeg, axis = 1)
#             Correlation_GBM  Correlation_ccRCC  Correlation_BR  \
# Comparison
# CTSC              -0.548303                NaN        0.314172
# SHC1              -0.521169           0.361057             NaN
# HSD17B11          -0.521630                NaN        0.400780
# CTSB              -0.514005                NaN        0.377784
# SCPEP1            -0.509046          -0.394109        0.388977
# DAB2              -0.500648                NaN        0.350933
# OSTF1             -0.500063          -0.456002        0.281638
# PLA2G15           -0.498087                NaN        0.289403
# SUB1               0.498468          -0.289319             NaN
# CTSZ              -0.485421                NaN        0.270165
# RIN2              -0.476346                NaN             NaN
# PPP2R3A           -0.472942                NaN             NaN
# MTARC2             0.462465                NaN       -0.305252
# SIPA1L3            0.459726                NaN       -0.282559
# CTSL              -0.455014          -0.297184        0.355121
# ARSB              -0.455541                NaN        0.263567
# CHDH               0.452909                NaN       -0.310718
# DOCK11            -0.451561                NaN        0.339243
# SVIL              -0.450803                NaN        0.236144
# GSTO1             -0.448915                NaN             NaN
#
#             Correlation_LUAD  Correlation_HNSCC  Correlation_LSCC  Pos_Neg
# Comparison
# CTSC                0.282360                NaN               NaN     True
# SHC1                     NaN                NaN               NaN     True
# HSD17B11                 NaN                NaN               NaN     True
# CTSB                     NaN                NaN               NaN     True
# SCPEP1                   NaN                NaN               NaN     True
# DAB2                     NaN                NaN               NaN     True
# OSTF1                    NaN                NaN               NaN     True
# PLA2G15                  NaN                NaN               NaN     True
# SUB1                     NaN                NaN               NaN     True
# CTSZ                     NaN                NaN               NaN     True
# RIN2                0.322491           0.330241               NaN     True
# PPP2R3A             0.313583                NaN               NaN     True
# MTARC2                   NaN                NaN               NaN     True
# SIPA1L3                  NaN                NaN               NaN     True
# CTSL                     NaN                NaN               NaN     True
# ARSB                     NaN                NaN               NaN     True
# CHDH                     NaN          -0.357081               NaN     True
# DOCK11                   NaN                NaN               NaN     True
# SVIL                     NaN                NaN               NaN     True
# GSTO1                    NaN                NaN           0.28573     True

# %%
def Pvalue_sig(row):
    numSig = 0

    for item in row:
        if pd.isnull(item):
            continue
        if item < 0.05:
            numSig += 1
            
    return numSig

# %%
df = FDR_corr_True.drop("Pos_Neg",axis = 1)
diff = df.max(axis=1) - df.min(axis = 1)
diff.sort_values(ascending = False).head(20)
# Out:
# Comparison
# CELSR1      1.025849
# ARHGAP10    1.003604
# MRTFB       0.941977
# CTNND2      0.933537
# CYRIA       0.931863
# TES         0.928830
# CRYBG3      0.927166
# HSD17B11    0.922410
# SLC9A3R1    0.915562
# ARFGEF3     0.911232
# JPT2        0.908296
# UPP1        0.905642
# SCPEP1      0.898023
# FAM89A      0.896054
# PLA2G4A     0.894060
# RARA        0.893161
# VDR         0.892795
# CTSB        0.891790
# CA12        0.885282
# SHC1        0.882226
# dtype: float64

# %%
abs_val = FDR_corr_True.abs()
abs_val.sum(1).sort_values(ascending = False).head(20)
# Out:
# Comparison
# PFKP       2.794904
# CELSR1     2.751942
# CRYBG1     2.723200
# FERMT1     2.667788
# UPP1       2.637102
# CD109      2.634134
# GMFG       2.620877
# FAM89A     2.616274
# P4HA2      2.558186
# JPT2       2.501748
# ITGB1      2.494947
# RBM47      2.494912
# CDK6       2.484177
# LCP1       2.476295
# CA12       2.469833
# IKBIP_1    2.414612
# TNK1       2.405448
# GGCX       2.403291
# WIPF1      2.402320
# BAG2       2.391618
# dtype: float64

# %% [markdown]
# The manuscript mentions 945 of trans proteins that opposite effects in different cancers. Here is the derivation of that number

# %%
pos_neg_prot = FDR_corr_True.index.tolist()
pos_neg_prot
#print("Total number of trans proteins with opposite effects in different cancers is " + str(len(pos_neg_prot)))
# Out:
# ['CTSC',
#  'SHC1',
#  'HSD17B11',
#  'CTSB',
#  'SCPEP1',
#  'DAB2',
#  'OSTF1',
#  'PLA2G15',
#  'SUB1',
#  'CTSZ',
#  'RIN2',
#  'PPP2R3A',
#  'MTARC2',
#  'SIPA1L3',
#  'CTSL',
#  'ARSB',
#  'CHDH',
#  'DOCK11',
#  'SVIL',
#  'GSTO1',
#  'FCGR2A',
#  'TES',
#  'NIBAN2',
#  'SNAPIN',
#  'GBA',
#  'COL1A1',
#  'COL1A2',
#  'PHLDB2',
#  'ALDH7A1',
#  'CTNND2',
#  'PARVG',
#  'RAB3IL1',
#  'CDKN2C',
#  'EML4',
#  'ENG',
#  'NPC2',
#  'TMEM87B',
#  'EHBP1L1',
#  'ITGB1',
#  'PWWP3A',
#  'KYNU',
#  'PTER',
#  'TNS3',
#  'PCMTD2',
#  'RGS12',
#  'DOK3',
#  'VAMP8',
#  'TBXAS1',
#  'LPXN',
#  'ACSS1',
#  'EMB',
#  'ACSL1',
#  'APC',
#  'FHOD1',
#  'OTULIN',
#  'CAPZA1',
#  'ARHGAP10',
#  'LIG4',
#  'FHL2',
#  'MFSD4B',
#  'TWF2',
#  'TNFAIP8',
#  'ARPC3',
#  'LUZP1',
#  'FBXL17',
#  'GMFG',
#  'PLCG2',
#  'PPM1F',
#  'RALGAPB',
#  'SYK',
#  'WIPF1',
#  'RASSF4',
#  'DAPK3',
#  'SULF1',
#  'CTSS',
#  'NOVA1',
#  'DNAJC21',
#  'HCK',
#  'CHST3',
#  'PAPSS2',
#  'LETM1',
#  'TPD52L2',
#  'THEMIS2',
#  'DIAPH2',
#  'RASAL2',
#  'PLIN2',
#  'STAT6',
#  'SDR39U1',
#  'AMPD3',
#  'CDK6',
#  'LAIR1',
#  'MANBA',
#  'ARPC1B',
#  'ILK',
#  'CD14',
#  'PIK3AP1',
#  'EHD4',
#  'CST3',
#  'MYOF',
#  'FCGR1A',
#  'DNMBP',
#  'MLKL',
#  'CTHRC1',
#  'ABI2',
#  'M6PR',
#  'KIF13A',
#  'NNT',
#  'CRTC1',
#  'ELP6',
#  'PFN1',
#  'IRF2BP1',
#  'PPFIBP1',
#  'ARHGAP35',
#  'RSU1',
#  'FUT11',
#  'CD300A',
#  'FCER1G',
#  'INPP4A',
#  'BDH1',
#  'HAAO',
#  'IGHV3-7',
#  'UPP1',
#  'ACTR3',
#  'MVP',
#  'CD163',
#  'COL3A1',
#  'IL4I1',
#  'NAP1L4',
#  'ERLIN1',
#  'CYTH4',
#  'SKAP2',
#  'LRRC25',
#  'RBM47',
#  'CARD6',
#  'DENND3',
#  'REL',
#  'CD40',
#  'ALDH1L1',
#  'MGAT1',
#  'EXD2',
#  'ERBIN',
#  'TBC1D2',
#  'FCGR3A',
#  'PLEKHO2',
#  'SALL2',
#  'CRTAP',
#  'DPYD',
#  'VCL',
#  'STING1',
#  'IGLV2-8',
#  'LRRFIP1_1',
#  'PROCR',
#  'PLAUR',
#  'ZNF185_1',
#  'TSPYL5',
#  'MYL6',
#  'DUSP23',
#  'TTC19',
#  'MAPK14',
#  'IKBIP_1',
#  'LGMN',
#  'SRPX2',
#  'SH3GLB1_1',
#  'FLNB',
#  'MYO5C',
#  'TBC1D17',
#  'ALOX5',
#  'CRYBG1',
#  'MXRA5',
#  'NRBF2',
#  'SLC2A5',
#  'TLE5',
#  'RASSF1',
#  'VASP',
#  'USP4',
#  'MACROH2A2',
#  'DGKA',
#  'CLDN23',
#  'PICALM',
#  'CD84',
#  'DOK2',
#  'LYAR',
#  'BICD2',
#  'SH3KBP1_1',
#  'PTPN12',
#  'UGGT1',
#  'OSTM1',
#  'SEPTIN9_1',
#  'ACAD8',
#  'NDRG2',
#  'ACSL4',
#  'EEPD1',
#  'NEDD4',
#  'STARD13',
#  'IGKV3D-15',
#  'TLN1',
#  'CNNM4',
#  'MYO1G',
#  'PRDX4',
#  'SOGA1',
#  'TP53I3',
#  'PRRX1',
#  'STMN3',
#  'ANXA6_1',
#  'SIPA1',
#  'TCEA2',
#  'EPM2AIP1',
#  'FETUB',
#  'LCP1',
#  'FKBP7',
#  'ARPC2',
#  'TGFBI',
#  'PTPRJ',
#  'BRIX1',
#  'SGCE',
#  'ALDH6A1',
#  'ARPC5',
#  'BTBD2',
#  'P4HA1_1',
#  'CDCA7L',
#  'CAV2',
#  'USP30',
#  'TGFB1',
#  'ADPGK',
#  'LILRB4',
#  'G6PD',
#  'DBNL_1',
#  'CUL2',
#  'PABPC4_1',
#  'LRATD2',
#  'ADI1',
#  'ELP4',
#  'POSTN',
#  'XPNPEP1',
#  'MRC1',
#  'ITGB2',
#  'LRCH1',
#  'ARPC4',
#  'GAREM1',
#  'BCL10',
#  'FERMT3',
#  'ARHGEF26',
#  'CCDC71L',
#  'COL11A1',
#  'CYP2S1',
#  'TLR2',
#  'SLFN5',
#  'ST6GAL1',
#  'COL12A1',
#  'RHBDF2',
#  'FES',
#  'PSME4',
#  'FAM89A',
#  'UQCR10',
#  'ISLR',
#  'IPO11',
#  'PPIB',
#  'HEPH',
#  'RIN3',
#  'GTF2F2',
#  'SH3BP1',
#  'HDLBP',
#  'UBASH3B',
#  'COL5A2',
#  'ADGRE2',
#  'LARS2',
#  'IGF2R',
#  'DDR1',
#  'AP3B2',
#  'THBD',
#  'ECHDC1',
#  'LAMP2_1',
#  'CD109',
#  'MYL6_1',
#  'SOX10',
#  'IKBIP',
#  'FOXO1',
#  'RPL27',
#  'MAT2A',
#  'PAFAH1B3',
#  'MKNK1',
#  'FN3K',
#  'MFAP2',
#  'CSTA',
#  'FAP',
#  'TPM1_2',
#  'EARS2',
#  'EIF1AY',
#  'DNASE1L1',
#  'TBC1D8B',
#  'ERP44',
#  'PGM2',
#  'TTC39B',
#  'HDHD2',
#  'CD33',
#  'IDH2',
#  'FGB',
#  'SRPRA',
#  'SUGP2',
#  'SERPING1',
#  'CNN2',
#  'HSP90B1',
#  'TLK1',
#  'ZDHHC3',
#  'SLC25A20',
#  'NGLY1',
#  'ASPH',
#  'FLVCR1',
#  'EEF1A2',
#  'GGCX',
#  'GFPT2',
#  'IGHV6-1',
#  'FNDC3B',
#  'S100A11',
#  'CP',
#  'MMS19',
#  'HK3',
#  'RASGRP2',
#  'ITGB5',
#  'SPTBN4',
#  'PITPNA',
#  'PREX1',
#  'IFI16',
#  'SCCPDH',
#  'RPL14',
#  'GPNMB',
#  'A2M',
#  'ANTXR2',
#  'ITGA3',
#  'RSL1D1',
#  'RPL7',
#  'FYN',
#  'PIP4K2B',
#  'TMEM184C',
#  'TPST2',
#  'DNAJB11',
#  'PCYT2',
#  'ZNF776',
#  'CEMIP2',
#  'ABAT',
#  'LOXL2',
#  'RELB',
#  'NME4',
#  'B3GAT3',
#  'RPTOR',
#  'ARRB2',
#  'AKAP5',
#  'ASPSCR1',
#  'KIAA0930',
#  'UXS1',
#  'HIBCH',
#  'PRR36',
#  'SLFN11',
#  'RPL7A',
#  'COL15A1',
#  'VPS26B',
#  'EIF2AK2',
#  'GNG7',
#  'AFAP1L2',
#  'PECAM1',
#  'DLAT',
#  'TRAF1',
#  'RPL22',
#  'MST1',
#  'GSTZ1',
#  'RCN3',
#  'PI4KA',
#  'F13A1',
#  'GOLM1',
#  'LACC1',
#  'PLEK',
#  'ZBTB20',
#  'XRCC1',
#  'NOC3L',
#  'ACAT1',
#  'SUMF1',
#  'PACSIN1',
#  'TMEM63A',
#  'PDIA5',
#  'C1QA',
#  'C8A',
#  'SYN2',
#  'C9',
#  'SLC9A3R2_1',
#  'DDX18',
#  'ALDH5A1',
#  'MTIF3',
#  'ZNF24',
#  'VIM',
#  'N4BP1',
#  'AVEN',
#  'RAB32',
#  'PDLIM7',
#  'BECN1',
#  'ADAMTS2',
#  'AMOTL1',
#  'RRP12',
#  'SHROOM3',
#  'F10',
#  'CREG1',
#  'PRXL2B',
#  'NAPA',
#  'GAMT',
#  'FCGR2B',
#  'DMAC2L',
#  'GLRX3',
#  'BAG2',
#  'AXL',
#  'C6',
#  'CRYBG3',
#  'LRIG1',
#  'SLC12A2',
#  'P4HA2',
#  'EEF1B2',
#  'REXO2',
#  'CERS2',
#  'PDHB',
#  'JPT2',
#  'KIAA1671',
#  'TTC28',
#  'STARD5',
#  'PFKP',
#  'CFAP36',
#  'RHOB',
#  'CTPS2',
#  'TNK1',
#  'NBEA',
#  'IFT88',
#  'OGA',
#  'SNX18',
#  'EEF1AKMT1',
#  'KBTBD11',
#  'RBKS',
#  'CYRIA',
#  'PFAS',
#  'KIFBP',
#  'EMC8',
#  'ALKBH5',
#  'MICALL1',
#  'CELF2',
#  'FBXO4',
#  'IFT46',
#  'WWC1',
#  'ERBB3',
#  'MTCL1',
#  'ENGASE',
#  'TCEA3',
#  'TACC1',
#  'PDK1',
#  'WIPF2',
#  'PFKFB2_1',
#  'ARFGEF3',
#  'DCTPP1',
#  'DENND6A',
#  'MPI',
#  'LPIN1',
#  'CELSR1',
#  'PLEKHA2',
#  'FBXW9',
#  'CAMK1',
#  'EIF4EBP1',
#  'NUDCD2',
#  'GNG2',
#  'GLUL',
#  'TBC1D9B',
#  'SEPTIN9',
#  'RUNX3',
#  'NECAP2',
#  'ADPRS',
#  'UNC119B',
#  'AKAP12',
#  'FAHD2A',
#  'ME1',
#  'GLIPR2',
#  'CETN3',
#  'NPEPL1',
#  'CYB5R2',
#  'PLA2G4A',
#  'ENPEP',
#  'HSD3B7',
#  'CRABP2',
#  'FAM118B_2',
#  'ADAL',
#  'FPGT',
#  'SOD2',
#  'KTN1',
#  'DHX36',
#  'ATG3',
#  'TTC26',
#  'C12orf29',
#  'SYNE3',
#  'PAN2',
#  'TBCA',
#  'OSCP1',
#  'ALDH1L2',
#  'BTBD8',
#  'DYNC2LI1',
#  'TMSB4X',
#  'DCTD',
#  'HYI',
#  'BBS2',
#  'FOLR1',
#  'IFT74',
#  'METTL26',
#  'ADGRE5',
#  'PPIP5K2',
#  'MARK3',
#  'MAP1B',
#  'TBL1X',
#  'MANF',
#  'NPEPPS',
#  'ALDH1B1',
#  'CETN2',
#  'CBR3',
#  'IFT172',
#  'EPB41L2',
#  'HOOK1',
#  'PLEKHM2',
#  'WDR35',
#  'WDR54',
#  'WARS1',
#  'LBH',
#  'S100A16',
#  'DNAL4',
#  'PARD6B',
#  'TTC39A',
#  'ABI1_1',
#  'TUBB2B',
#  'PHYKPL',
#  'VRK1',
#  'KCTD9',
#  'RAB19',
#  'XPO4',
#  'FMNL2',
#  'PDK4',
#  'SC5D',
#  'MAP7D1_1',
#  'PGD',
#  'ERGIC1',
#  'PREPL',
#  'NCF4',
#  'SCRN3',
#  'DIS3',
#  'VDR',
#  'RRP8',
#  'HSP90AA1',
#  'LRCH3',
#  'ASRGL1',
#  'MBOAT2',
#  'FUT8',
#  'DHX15',
#  'F9',
#  'LAMA3_1',
#  'CNKSR1',
#  'TMEM106B',
#  'ELOB',
#  'RARA',
#  'MID2',
#  'AMFR',
#  'ODR4',
#  'TSPAN13',
#  'ZNF316',
#  'IGLV3-1',
#  'DCAF5',
#  'SPAG1',
#  'SLC30A9',
#  'SAMD12',
#  'CLDN3',
#  'MRTFB',
#  'ACAA2',
#  'KIT',
#  'PRSS8',
#  'NCF1',
#  'DIS3L',
#  'GALNT6',
#  'LPL',
#  'CCDC50_1',
#  'ZSCAN18',
#  'CCL21',
#  'DNAJB4',
#  'RPL4',
#  'GSPT1',
#  'RAB11FIP4',
#  'CHIT1',
#  'AHCYL1',
#  'ARHGEF1_1',
#  'LCMT1',
#  'PIGR',
#  'AIFM2',
#  'AKAP9_1',
#  'MLLT1',
#  'FAAH',
#  'NCOA2',
#  'ENO3',
#  'DHX29',
#  'YIF1A',
#  'TBC1D10B',
#  'ELOC',
#  'GK',
#  'TINAGL1',
#  'NID1',
#  'SRGN',
#  'MTMR6',
#  'SRCIN1',
#  'MYCBP2',
#  'LMBRD2',
#  'EXOSC10',
#  'PEX1',
#  'GULP1',
#  'VPS37C',
#  'MYO6_1',
#  'SGTB',
#  'DCAF7',
#  'BPI',
#  'MISP3',
#  'IGKV3-7',
#  'AKR1C1',
#  'ARFGEF1',
#  'CAPN6',
#  'LTBP1',
#  'CAMSAP3',
#  'FCRL5',
#  'CD209',
#  'EOGT',
#  'RASA1',
#  'ANK3',
#  'PTPRF',
#  'DOCK5',
#  'CLU',
#  'NOS1AP',
#  'DEPTOR',
#  'CCDC88C',
#  'DCTN2_1',
#  'AVL9',
#  'CAPRIN1',
#  'SLC39A9',
#  'CADPS2',
#  'SCYL2',
#  'RRM2B',
#  'PSTPIP1',
#  'CA12',
#  'AIF1L',
#  'CUX1_1',
#  'TOP2B',
#  'SERPINB5',
#  'PDXDC1',
#  'TMC4',
#  'DNAAF5',
#  'ZDHHC21',
#  'FERMT1',
#  'SEMA7A',
#  'FAM174A',
#  'PLSCR3',
#  'USP16',
#  'LBP',
#  'NEK9',
#  'C8G',
#  'APOA2',
#  'ZNRF1',
#  'CRLF1',
#  'PITPNB',
#  'SMIM29',
#  'PAIP1_1',
#  'SH2B2',
#  'PCSK9',
#  'CIB1',
#  'CBL',
#  'TIMM9',
#  'DGKQ',
#  'SULF2',
#  'SLIT2',
#  'ETS1',
#  'IKZF2',
#  'BAG3',
#  'KRT19',
#  'IGKV1D-13',
#  'CHN1',
#  'ANP32E',
#  'SYTL1',
#  'CCDC82',
#  'KIAA1522',
#  'KIF13A_1',
#  'CAND2',
#  'ZNF385A',
#  'TUBA8',
#  'CTNND1_1',
#  'FKBP5',
#  'MAST4',
#  'MARK2_1',
#  'FABP7',
#  'CORO2A',
#  'RNGTT',
#  'RUFY2',
#  'SLC9A3R1',
#  'IGFBP2',
#  'BHLHE40',
#  'ATPAF1',
#  'LENG8',
#  'ITPRID2_1',
#  'RAB3D',
#  'DAPK1',
#  'KITLG',
#  'LNX2',
#  'ACSL5',
#  'NCOA7',
#  'PALM2AKAP2',
#  'SLC39A6',
#  'PARN',
#  'MYO19',
#  'ZEB2',
#  'COG5',
#  'SNTB1',
#  'ELP2',
#  'C17orf75',
#  'KIF16B',
#  'LYN',
#  'COG7',
#  'VAV2',
#  'CRNKL1',
#  'CPN2',
#  'GTF3C1',
#  'ARHGAP26',
#  'DNAJC19',
#  'IGF1R',
#  'CASP10',
#  'MPP1',
#  'MAPRE2',
#  'HPGD',
#  'RASSF2',
#  'TMOD1',
#  'GTF3C3',
#  'SCAMP1',
#  'MEST',
#  'CDK9',
#  'BRF1',
#  'S100A4',
#  'MPEG1',
#  'ADD1',
#  'TMEM181',
#  'TBCEL',
#  'PDE2A',
#  'RPS6KA3',
#  'ANO1',
#  'APOB',
#  'CHL1',
#  'ADD3',
#  'GSTCD',
#  'BTN3A3',
#  'DARS2',
#  'IGKC',
#  'CCND1',
#  'PYGM',
#  'GTF3C4',
#  'TCN2',
#  'APOE',
#  'SHANK2',
#  'PRKCI',
#  'KIAA0753',
#  'PAG1',
#  'CERS5',
#  'STX11',
#  'SPTAN1',
#  'IGHV2-26',
#  'ACADL',
#  'GASK1B',
#  'LYN_1',
#  'ACSM3',
#  'TAOK1',
#  'TMOD2',
#  'IGHG1',
#  'FBXO3',
#  'MACF1_1',
#  'PPFIA1',
#  'VAT1L',
#  'EXOC5',
#  'SRSF8',
#  'ADPRH',
#  'GYPA',
#  'MED7',
#  'CRABP1',
#  'KRT7']

# %% [markdown]
# # Run GSEA

# %%
pos_neg_enr = gp.enrichr(gene_list = pos_neg_prot, description='Tumor_partition', gene_sets='Reactome_2016')
pos_neg_enr.res2d.head(10)
# Out:
#         Gene_set                                               Term   Overlap  \
# 0  Reactome_2016  Fcgamma receptor (FCGR) dependent phagocytosis...    22/120
# 1  Reactome_2016     Innate Immune System Homo sapiens R-HSA-168249    68/807
# 2  Reactome_2016  Platelet activation, signaling and aggregation...    30/253
# 3  Reactome_2016  Regulation of actin dynamics for phagocytic cu...     17/97
# 4  Reactome_2016               Hemostasis Homo sapiens R-HSA-109582    47/552
# 5  Reactome_2016      Collagen formation Homo sapiens R-HSA-1474290     15/85
# 6  Reactome_2016              Metabolism Homo sapiens R-HSA-1430728  115/1908
# 7  Reactome_2016            Immune System Homo sapiens R-HSA-168256   97/1547
# 8  Reactome_2016  Extracellular matrix organization Homo sapiens...    29/283
# 9  Reactome_2016  Terminal pathway of complement Homo sapiens R-...       5/8
#
#         P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0  1.312739e-09      9.550146e-07            0                     0
# 1  1.981358e-09      9.550146e-07            0                     0
# 2  6.528625e-08      2.097865e-05            0                     0
# 3  1.941177e-07      4.678236e-05            0                     0
# 4  4.987805e-07      9.616488e-05            0                     0
# 5  9.218392e-07      1.481088e-04            0                     0
# 6  1.497695e-06      2.062540e-04            0                     0
# 7  2.112067e-06      2.452168e-04            0                     0
# 8  2.289368e-06      2.452168e-04            0                     0
# 9  4.551068e-06      4.387229e-04            0                     0
#
#    Odds Ratio  Combined Score  \
# 0    5.655427      115.659995
# 1    2.384937       47.792905
# 2    3.402817       56.297855
# 3    5.323348       82.271278
# 4    2.372887       34.433199
# 5    5.356863       74.443764
# 6    1.678190       22.507180
# 7    1.737843       22.709864
# 8    2.879382       37.395210
# 9   41.271478      507.645312
#
#                                                Genes
# 0  LYN;ACTR3;HSP90AA1;AHCYL1;SYK;WIPF1;WIPF2;ARPC...
# 1  AHCYL1;WIPF1;ARPC1B;WIPF2;ITGB2;ARRB2;C8A;CLU;...
# 2  SHC1;DGKA;PLEK;F13A1;ARRB2;RASGRP2;CLU;ISLR;GN...
# 3  ACTR3;HSP90AA1;SYK;WIPF1;WIPF2;ARPC1B;ARPC4;AR...
# 4  ITGB1;DOCK5;CD84;SHC1;DGKA;ITGB2;PLEK;F13A1;AR...
# 5  COL15A1;CRTAP;COL11A1;COL12A1;CTSS;LOXL2;COL1A...
# 6  RPL4;ALDH1L1;FAAH;AHCYL1;PITPNB;ALDH1L2;ENO3;R...
# 7  AHCYL1;NCF1;WIPF1;WIPF2;NCF4;CLU;NPEPPS;RPS6KA...
# 8  DDR1;ITGB1;COL15A1;ITGB5;COL11A1;COL12A1;ITGB2...
# 9                                  C8G;C6;C9;C8A;CLU

# %%
pos_neg_df = pos_neg_enr.res2d
fcgr = pos_neg_df.iloc[2,9]
fcgr = fcgr.split(';')

# %%
#get just the clotting cascade genes and add urokinase genes 
pos_neg_df = pos_neg_enr.res2d
coag = pos_neg_df.iloc[2,9]
coag = coag.split(';')
upa = ["F3","PLAUR","PLAU","PLG","MMP9","MMP12","SERPINE1"]
coag_upa =  coag + upa
len(coag_upa)
# Out:
# 37

# %% [markdown]
# # Step 3 Make Data frame for Figure 4

# %%
#Get append version of the df with all cancer type, fdr sig trans results
df_FDR_append = pd.read_csv("csv_files/sig_prot_heatmap_EGFR.csv")
 
#coag_upa =  ["F2""F3","F9","F10","F11","F13A1","PLAUR","PLAU","PLG","MMP9","MMP12","SERPINE1"]
#subset dataframe to include genes only desired for figure 
df_FDR_append= df_FDR_append[df_FDR_append.Comparison.isin(fcgr)]
df_FDR_append
# Out:
#      Comparison  Correlation   P_Value Cancer
# 12         SHC1    -0.521169  0.000022    GBM
# 243       PLCG2    -0.390149  0.002829    GBM
# 248         SYK    -0.389025  0.002931    GBM
# 402        PFN1    -0.361363  0.006317    GBM
# 432      FCER1G    -0.357066  0.007069    GBM
# ...         ...          ...       ...    ...
# 8390    PLA2G4A    -0.324576  0.013817  ccRCC
# 8489     TMSB4X    -0.310140  0.019902  ccRCC
# 8559      PLCG2    -0.302984  0.023092  ccRCC
# 8634        SYK    -0.293638  0.028987  ccRCC
# 8835      ARRB2    -0.272475  0.047724  ccRCC
#
# [76 rows x 4 columns]

# %% [markdown]
# Set add new column to be unique index and order the new index. This way genes will be grouped by coagulation factors, regulators, and urokinase genes.

# %%
df_FDR_append["Index"] = df_FDR_append["Comparison"] + " " + df_FDR_append["Cancer"]
'''
df_FDR_append = df_FDR_append.set_index("Index")
df_ordered = df_FDR_append.reindex(["F2 GBM","F3 GBM","F9 GBM","F10 GBM","F11 GBM","F13A1 GBM","F13B GBM","KLKB1 GBM","VWF CO","FGA GBM","FGB GBM","FGG GBM","SERPINC1 GBM", "SERPIND1 GBM","SERPING1 GBM","A2M GBM","PROS1 GBM","PROC OV","PROCR GBM","THBD GBM","KNG1 GBM","PLAUR GBM","PLAU GBM","PLG GBM","MMP9 BR","MMP12 BR","SERPINE1 GBM",
                                "F2 BR","F9 BR","F10 BR","F11 BR","F13A1 BR","F13B BR","FGA BR","FGB BR","FGG BR", "SERPIND1 BR","SERPING1 BR","A2M BR","PROS1 BR","PROCR BR","KLKB1 BR", "PLAUR BR","PLAU BR","PLG BR","SERPINE1 BR",
                               "VWF HNSCC","THBD HNSCC","PLAUR HNSCC","PLAU HNSCC","SERPINE1 HNSCC",
                               "F9 LUAD","F13A1 LUAD", "F13B LUAD", "SERPIND1 LUAD","PROS1 LUAD","PROC LUAD","VWF LUAD",
                                "PROCR ccRCC",
                                "SERPIND1 OV","PROC OV",
                               "F3 CO","SERPINC1 CO", "SERPIND1 CO","A2M CO","KNG1 CO","KLKB1 CO"])
'''
df_FDR_append
# Out:
#      Comparison  Correlation   P_Value Cancer          Index
# 12         SHC1    -0.521169  0.000022    GBM       SHC1 GBM
# 243       PLCG2    -0.390149  0.002829    GBM      PLCG2 GBM
# 248         SYK    -0.389025  0.002931    GBM        SYK GBM
# 402        PFN1    -0.361363  0.006317    GBM       PFN1 GBM
# 432      FCER1G    -0.357066  0.007069    GBM     FCER1G GBM
# ...         ...          ...       ...    ...            ...
# 8390    PLA2G4A    -0.324576  0.013817  ccRCC  PLA2G4A ccRCC
# 8489     TMSB4X    -0.310140  0.019902  ccRCC   TMSB4X ccRCC
# 8559      PLCG2    -0.302984  0.023092  ccRCC    PLCG2 ccRCC
# 8634        SYK    -0.293638  0.028987  ccRCC      SYK ccRCC
# 8835      ARRB2    -0.272475  0.047724  ccRCC    ARRB2 ccRCC
#
# [76 rows x 5 columns]

# %% [markdown]
# # Step 4: Plot Figure 4

# %%
legend_min = df_FDR_append["P_Value"].min()
#Make plot using plot utils
p.plotCircleHeatMap(df_FDR_append, circle_var = "P_Value",color_var = "Correlation", x_axis = "Comparison", y_axis = "Cancer", plot_width= 700, plot_height = 500, legend_min = legend_min, legend_max = 0.05, font_size = 10, show_legend = True)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1055">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="015b63a2-3435-43f6-a87a-a7384246155e" data-root-id="1056"></div>
# Figure(id='1005', ...)

# %% [markdown]
# # Check if blanks are due to no data

# %% [markdown]
# The follow code chunks show that the following cancers/genes don't have data: colon THBD, Kidney MMP12, and Ovarian MMP12. (As mentioned in EGFR Figure 2 legend)

# %%
#Get append version of the df with all proteins 
df_all_prot_append = pd.read_csv("csv_files/all_prot_heatmap_EGFR.csv")
df_all_prot_append
# Out:
#       Comparison  Correlation       P_Value Cancer
# 0           EGFR     1.000000  0.000000e+00    GBM
# 1         PHLDA1     0.789551  9.649849e-19    GBM
# 2           CDH4     0.656331  4.744022e-10    GBM
# 3           GRB2    -0.589008  3.310325e-07    GBM
# 4          SOCS2     0.565367  2.006861e-06    GBM
# ...          ...          ...           ...    ...
# 67276      RPS29     0.000111  9.997098e-01  ccRCC
# 67277       YBX1     0.000072  9.997098e-01  ccRCC
# 67278       UBL7     0.000063  9.997098e-01  ccRCC
# 67279     HEATR3     0.000043  9.997470e-01  ccRCC
# 67280     PTRHD1    -0.000027  9.997795e-01  ccRCC
#
# [67281 rows x 4 columns]

# %%
#subset dataframe to include genes only desired for figure 
df_all_comp_coag = df_all_prot_append[df_all_prot_append.Comparison.isin(coag_upa)]
print("Number of rows in data frame " + str(len(df_all_comp_coag)))
# Out:
# Number of rows in data frame 218

# %% [markdown]
# Our figure includes 27 genes for 8 cancers. If all data was present there would be 216 rows. However, the data frame only has 212 rows. 4 genes are missing.

# %%
def find_missing_genes(test_list, full_list):
    for gene in full_list:
        if (gene not in test_list):
            print(gene)

# %%
#Get list of genes for colon, kidney, and ovarian
colon = df_all_prot_append[df_all_prot_append["Cancer"] == "CO"]
colon_list = colon.Comparison.to_list()

Kidney = df_all_prot_append[df_all_prot_append["Cancer"] == "ccRCC"]
Kidney_list = Kidney.Comparison.to_list()

Ovarian = df_all_prot_append[df_all_prot_append["Cancer"] == "OV"]
Ovarian_list = Ovarian.Comparison.to_list()

# %%
#Show the 3 missing genes 
print("Ovarian missing genes: ")
find_missing_genes(Ovarian_list, coag_upa)
print("Kidney missing genes: ")
find_missing_genes(Kidney_list, coag_upa)
print("Colon missing genes: ")
find_missing_genes(colon_list, coag_upa)
# Out:
# Ovarian missing genes:
# SHC1
# DGKA
# PLEK
# F13A1
# ARRB2
# RASGRP2
# CLU
# ISLR
# GNG2
# TMSB4X
# GNG7
# PLCG2
# FYN
# A2M
# LYN
# SRGN
# FGB
# FCER1G
# TGFB1
# SYK
# PLA2G4A
# MAPK14
# VAV2
# RHOB
# DGKQ
# PECAM1
# SERPING1
# TLN1
# PFN1
# VCL
# F3
# PLAUR
# PLAU
# PLG
# MMP9
# MMP12
# SERPINE1
# Kidney missing genes:
# SRGN
# MMP12
# Colon missing genes:
# SHC1
# DGKA
# PLEK
# F13A1
# ARRB2
# RASGRP2
# CLU
# ISLR
# GNG2
# TMSB4X
# GNG7
# PLCG2
# FYN
# A2M
# LYN
# SRGN
# FGB
# FCER1G
# TGFB1
# SYK
# PLA2G4A
# MAPK14
# VAV2
# RHOB
# DGKQ
# PECAM1
# SERPING1
# TLN1
# PFN1
# VCL
# F3
# PLAUR
# PLAU
# PLG
# MMP9
# MMP12
# SERPINE1
