# %% [markdown]
# # Data munging EGFR: trans effects

# %% [markdown]
# This notebook records the pearson correlation stats for EGFR proteomics vs all proteomics for each cancer type. It records all FDR Benjamini/Hochberg corrected p values. This data is then used in the Make_Supplemental_Tables notebook.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest


import cptac
import cptac.utils as u
import plot_utils as p
import warnings
warnings.filterwarnings('ignore')
import cptac.pancan as pc
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
'''
@Param df: Data frame. Takes a data frame of proteomic data frame.
This function takes the data frame from get_proteomics and labels any duplicate columns due to mutliple isoforms.
Then it returns the list of all proteins
'''

def create_prot_list(df):
    #Add _(number) to keep track of duplicates due to multiple isoforms 
    cols = pd.Series(df.columns[:])
    for dup in cols[cols.duplicated()].unique(): 
        cols[cols[cols == dup].index.values.tolist()] = [dup + '_' + str(i) if i != 0 else dup for i in range(sum(cols == dup))]
    df.columns=cols
    #get list of proteins
    prot_genes_list = df.columns.values.tolist()
    return prot_genes_list

# %%
'''
@Param cancer: cptac data for a cancer Ex brain = cptac.Gbm()

This function makes a df with all trans effects. 
Step 1: Get proteomic data with only tumor samples.
Step 2: For each cancer type, create list of proteins by using create_prot_list function 
which extracts column names and labels duplicate columns caused by multiple isoforms.
Step 3:Use plot_utils function wrap_pearson_corr on df and compare EGFR proteomics to all other proteins in protein list.
Record all FDR corrected p values. 

'''

def make_trans_df(cancer):
    df1_tumor = cancer.get_proteomics(tissue_type= "tumor", source = "umich")
    df1_tumor = u.reduce_multiindex(df1_tumor, levels_to_drop = 1)
        
    prot_genes_list = create_prot_list(df1_tumor)
    trans_df = p.wrap_pearson_corr(df1_tumor,"EGFR",comparison_columns= prot_genes_list,correction_method='fdr_bh', return_all = True, return_corrected_pvals = True)
    return trans_df

# %%
#cptac version
cptac.version()
# Out:
# '0.9.0'

# %%
g = pc.PancanGbm()
hn = pc.PancanHnscc()
l = pc.PancanLuad()
#o = pc.PancanOv()
c = pc.PancanCcrcc()
#col = pc.PancanCoad()
b = pc.PancanBrca()
ls = pc.PancanLscc()
en = pc.PancanUcec()

# %% [markdown]
# GBM

# %%
df = g.get_proteomics(source = "umich", tissue_type = "tumor")
df = u.reduce_multiindex(df, levels_to_drop = 1)
df
# Out:
# Name            ARF5      M6PR     ESRRA     FKBP4   NDUFAF7     FUCA2  \
# Patient_ID
# C3L-00104  -0.254733 -0.138938  0.662227 -0.074868  0.213529  0.123398
# C3L-00365  -0.138512 -0.824520  0.494419  0.043783 -0.001394  0.101477
# C3L-00674  -0.351464 -0.120197 -0.084371 -0.260275  0.096193 -0.360274
# C3L-00677  -0.062869  0.094198  0.391070 -0.030638  0.742258 -0.417291
# C3L-01040  -0.365351  0.070523 -0.472543 -0.255288  0.096844  0.356271
# ...              ...       ...       ...       ...       ...       ...
# C3N-03183  -0.154099  0.377664  0.230259 -0.160996 -0.345147  0.098204
# C3N-03184   0.189578 -0.307571       NaN  0.223307 -0.245702  0.015862
# C3N-03186   0.216536  0.206218 -0.002028 -0.027721  0.022376  0.116589
# C3N-03188   0.020677  0.004811 -0.041030 -0.099233 -0.063813 -0.250591
# C3N-03473  -0.133481  0.127108 -0.305324 -0.466174  0.131691  0.606351
#
# Name          DBNDD1    HS3ST1   CYP51A1     USP28  ...     ETNK1     AP1S2  \
# Patient_ID                                          ...
# C3L-00104   2.105458       NaN -0.660264       NaN  ... -0.047874 -0.446007
# C3L-00365  -0.287232       NaN -0.402679  0.059975  ...  0.350165 -0.844985
# C3L-00674   0.227499  1.217058 -0.165751  0.010124  ... -0.167319 -0.096328
# C3L-00677  -0.013377       NaN -0.176649  0.535304  ...  0.179200  0.320945
# C3L-01040   1.182940       NaN -0.307430       NaN  ...  0.098253 -0.298907
# ...              ...       ...       ...       ...  ...       ...       ...
# C3N-03183  -0.307796  0.540155  0.365869  0.093833  ... -0.053077 -0.744983
# C3N-03184  -0.014366       NaN  0.366511       NaN  ...  0.141587  0.198692
# C3N-03186   0.412767       NaN -0.088390  0.131931  ...  0.095028 -0.032430
# C3N-03188  -0.145725 -0.562148  0.194367 -0.406621  ...  0.062744 -0.007752
# C3N-03473   0.279502       NaN  1.232326  0.290813  ...  0.155784  0.214643
#
# Name             EED     DDHD1       WIZ     ZBTB3    CTNND1       WIZ  \
# Patient_ID
# C3L-00104   0.070101  0.160090  0.129282 -0.166678       NaN -0.073448
# C3L-00365  -0.234406 -0.448783  0.078407       NaN -0.174780  1.806950
# C3L-00674  -0.118506 -0.107690  0.177530       NaN -1.513869  0.065973
# C3L-00677  -0.027522  0.104278  0.049948 -0.590267  0.162686  1.964570
# C3L-01040  -0.201144  0.440215  0.110757  0.119013       NaN  0.030719
# ...              ...       ...       ...       ...       ...       ...
# C3N-03183   0.661918 -0.397211 -0.136850       NaN       NaN       NaN
# C3N-03184   0.379313  0.257048  0.669888  0.134818 -0.042240       NaN
# C3N-03186  -0.350445 -0.037268 -0.609430       NaN -0.274836       NaN
# C3N-03188  -0.219871  0.271077 -0.312438       NaN       NaN       NaN
# C3N-03473   0.543383 -0.248307  0.943688       NaN  0.599462  0.270782
#
# Name             WIZ   MSANTD2
# Patient_ID
# C3L-00104  -0.029020 -0.009463
# C3L-00365   0.033808  0.180578
# C3L-00674  -0.126149  0.465241
# C3L-00677   0.161229  0.283810
# C3L-01040   0.066426  0.189187
# ...              ...       ...
# C3N-03183   0.565946 -0.232044
# C3N-03184   0.841351       NaN
# C3N-03186  -0.345816  0.383632
# C3N-03188  -0.199850  0.252781
# C3N-03473   0.901456  0.641179
#
# [100 rows x 13002 columns]

# %%
gbm_df = make_trans_df(g)
#Example


gbm_df = gbm_df.rename(columns={"Correlation": "Correlation_GBM","P_value": "P_value_GBM" })
gbm_df.to_csv('csv_files/trans_effects_all_prot_fdr_corrected_GBM',index=False)
gbm_df
# Out:
#       Comparison  Correlation_GBM   P_value_GBM
# 2813        EGFR         1.000000  0.000000e+00
# 2476      PHLDA1         0.789551  9.649849e-19
# 11243       CDH4         0.656331  4.744022e-10
# 5916        GRB2        -0.589008  3.310325e-07
# 7319      PHLDA3         0.561528  2.006861e-06
# ...          ...              ...           ...
# 6514       UBE2H        -0.000084  9.996825e-01
# 5567       OSBP2         0.000071  9.997027e-01
# 7294     TMEM181        -0.000058  9.997128e-01
# 6509       TPRA1        -0.000068  9.997731e-01
# 675       MRPL51         0.000005  9.999712e-01
#
# [11525 rows x 3 columns]

# %%
duplicates  = gbm_df[gbm_df.Comparison.isin(matching)]
duplicates
# Out:
#       Comparison  Correlation_GBM  P_value_GBM
# 10706  EPB41L3_3        -0.510933     0.000036
# 10922    FLOT2_1         0.729748     0.000138
# 4307     HMGA1_1        -0.477182     0.000149
# 11302  ALDH7A1_2         0.456890     0.000364
# 7004     DCLK1_1         0.435497     0.000712
# ...          ...              ...          ...
# 10558    EEF1D_1        -0.001091     0.995709
# 10591     LMO7_1        -0.001372     0.996216
# 6442       WLS_1        -0.001295     0.996578
# 8122     EPB41_1        -0.000573     0.997654
# 10110     MAP4_2         0.000123     0.999467
#
# [713 rows x 3 columns]

# %%
gbm_genes = gbm_df.Comparison.to_list()
matching = [s for s in gbm_genes if "_" in s]
matching
# Out:
# ['EPB41L3_3',
#  'FLOT2_1',
#  'HMGA1_1',
#  'ALDH7A1_2',
#  'DCLK1_1',
#  'DPF3_1',
#  'SRGAP3_1',
#  'NFIX_2',
#  'DTNA_1',
#  'KCND3_1',
#  'RALGAPA1_1',
#  'DBI_1',
#  'ABR_2',
#  'ARHGAP27_1',
#  'ALDH7A1_1',
#  'PGM1_1',
#  'ATE1_1',
#  'COL6A3_1',
#  'PML_4',
#  'ZSCAN18_1',
#  'VAPA_1',
#  'CLIP2_1',
#  'CD163_1',
#  'LRRFIP1_1',
#  'TPM3_4',
#  'ZNF185_1',
#  'OSBPL6_2',
#  'IKBIP_1',
#  'SH3GLB1_1',
#  'CLUH_1',
#  'GNAS_2',
#  'TPM3_1',
#  'SH3KBP1_1',
#  'SEPTIN9_1',
#  'COL14A1_1',
#  'ANXA6_1',
#  'P4HA1_1',
#  'ACTN2_1',
#  'DBNL_1',
#  'TCF12_1',
#  'PABPC4_1',
#  'ARHGEF4_1',
#  'MAGI1_1',
#  'NECTIN3_1',
#  'FAM126A_1',
#  'EPB41L1_2',
#  'PTPRS_1',
#  'LAMP2_1',
#  'MYL6_1',
#  'RAP1GAP_1',
#  'TPM1_2',
#  'AMER2_1',
#  'LIMS1_1',
#  'CTNNA2_1',
#  'SIRT3_1',
#  'EHBP1_1',
#  'DLG1_4',
#  'CNOT4_1',
#  'PPP2R2B_1',
#  'CTIF_1',
#  'LTBP3_1',
#  'AMDHD2_1',
#  'CDKN2A_1',
#  'GTF2I_1',
#  'MADD_2',
#  'ABI2_1',
#  'KCNAB2_1',
#  'PCDH9_1',
#  'SLC9A3R2_1',
#  'SEPTIN8_1',
#  'ITGA7_2',
#  'DLG2_2',
#  'MAP2_2',
#  'CAPZB_1',
#  'ACAN_1',
#  'SYNE1_2',
#  'RAP1GDS1_3',
#  'CPEB2_1',
#  'POSTN_2',
#  'ZC3H14_1',
#  'MYH14_1',
#  'PTPA_1',
#  'LRRFIP1_2',
#  'IQSEC1_1',
#  'PEG10_1',
#  'APP_1',
#  'ATP2B4_1',
#  'MYO5A_1',
#  'NISCH_1',
#  'NRP2_1',
#  'BAALC_1',
#  'GLS_1',
#  'NT5C3A_1',
#  'OGDH_1',
#  'GNAS_1',
#  'FBLN1_1',
#  'PITPNC1_1',
#  'CAMK2B_1',
#  'NECTIN2_1',
#  'SLC8A1_1',
#  'CASK_1',
#  'FCGR2B_1',
#  'DGKB_1',
#  'ADAR_1',
#  'WASF3_1',
#  'SYNPO2_1',
#  'RGS10_1',
#  'PLEKHA5_2',
#  'ALG13_1',
#  'PNKD_1',
#  'KLC1_1',
#  'TPM3_3',
#  'DST_1',
#  'FMNL1_1',
#  'ARHGAP21_1',
#  'NPTN_1',
#  'RGS12_1',
#  'REEP6_1',
#  'CAST_2',
#  'EPN2_1',
#  'EPS15L1_1',
#  'FBXO44_1',
#  'PPM1B_1',
#  'ARHGEF7_2',
#  'TIAL1_1',
#  'RAB6A_1',
#  'PTPRS_2',
#  'CACNA1A_2',
#  'ARRB1_1',
#  'AP2A2_1',
#  'PSMD4_1',
#  'NFIC_2',
#  'SPATS2L_2',
#  'SPTAN1_1',
#  'MAP4_3',
#  'MT1G_1',
#  'SMAP1_1',
#  'DBNL_2',
#  'LIMA1_1',
#  'PPP3CA_1',
#  'KNG1_1',
#  'ANK2_4',
#  'SEPTIN7_1',
#  'POSTN_3',
#  'MYL6_2',
#  'AFDN_1',
#  'REPS1_1',
#  'ATP2B3_1',
#  'SLC3A2_1',
#  'NRXN1_2',
#  'CARS1_1',
#  'ACIN1_1',
#  'REPS1_2',
#  'AGAP1_1',
#  'PUF60_1',
#  'ABLIM2_3',
#  'ABLIM2_1',
#  'CACNA1E_1',
#  'SYNJ1_1',
#  'RHOT1_1',
#  'SLC44A2_2',
#  'ANK2_1',
#  'SRSF10_1',
#  'SPTBN1_1',
#  'PDLIM5_1',
#  'IMMT_1',
#  'CAMK2A_2',
#  'PSMF1_1',
#  'SH3GLB2_1',
#  'AGAP2_1',
#  'RASAL1_1',
#  'LMNA_2',
#  'YBX3_1',
#  'CTNND1_1',
#  'ZMAT3_1',
#  'SYN2_1',
#  'MYH10_2',
#  'POSTN_4',
#  'MASP1_1',
#  'NTRK3_1',
#  'PRKG1_1',
#  'SUGT1_1',
#  'KLC1_3',
#  'TPM4_1',
#  'FBLN1_2',
#  'CIT_1',
#  'PLOD2_1',
#  'DNM1_2',
#  'DNM2_2',
#  'PALM2AKAP2_1',
#  'DOCK1_1',
#  'FEZ2_1',
#  'DYNC1I2_1',
#  'ADD3_1',
#  'CDK17_1',
#  'MAP3K20_1',
#  'MADD_1',
#  'SIRPA_1',
#  'MBNL1_1',
#  'TCOF1_2',
#  'PFKFB2_1',
#  'DLG2_1',
#  'DFFA_1',
#  'MALT1_1',
#  'WDR47_1',
#  'PSD3_1',
#  'NAV1_2',
#  'MYEF2_1',
#  'MAPK14_1',
#  'ARHGEF7_1',
#  'SLC12A5_1',
#  'RUFY3_1',
#  'RBPMS_1',
#  'SYT1_1',
#  'ATP8A1_1',
#  'NDUFV3_1',
#  'ABL2_2',
#  'ITIH4_1',
#  'CBFA2T2_1',
#  'ATP2C1_1',
#  'BRSK2_1',
#  'RASAL1_2',
#  'HYOU1_1',
#  'CBFB_1',
#  'DMD_1',
#  'FNBP1_1',
#  'ILF3_1',
#  'PLS3_1',
#  'SYNE1_1',
#  'PLEKHA5_1',
#  'ITGA6_1',
#  'RAB11FIP5_1',
#  'SBF1_1',
#  'CADPS2_1',
#  'EPB41L1_1',
#  'STX16_2',
#  'PDIA4_1',
#  'SCRIB_1',
#  'RAPH1_1',
#  'TACC2_1',
#  'CD99L2_1',
#  'CALD1_2',
#  'PCBP2_1',
#  'FRMD5_1',
#  'PLEC_3',
#  'LMNA_1',
#  'TAC1_1',
#  'MAP3K7_2',
#  'DTNA_2',
#  'EXOC1_1',
#  'TOR1AIP2_1',
#  'CACNA1A_1',
#  'USP47_1',
#  'SHANK2_1',
#  'TRIM9_2',
#  'ATP2B2_1',
#  'PRPF40B_1',
#  'SEMA4D_1',
#  'ZEB1_1',
#  'TOM1L2_2',
#  'FLNA_1',
#  'SLC4A4_1',
#  'POLR1D_1',
#  'AP1B1_1',
#  'TSC22D1_1',
#  'RUFY3_2',
#  'PHF20L1_1',
#  'SDCBP_1',
#  'DNM1_1',
#  'NDRG4_1',
#  'TNC_1',
#  'SYNPO_1',
#  'DNAJB6_1',
#  'DCX_1',
#  'CAMK2G_1',
#  'MYH10_1',
#  'PRKACB_1',
#  'SYNGAP1_2',
#  'GRIN1_2',
#  'RBFOX1_2',
#  'PKM_1',
#  'MASP1_2',
#  'LYN_1',
#  'FXR1_1',
#  'EPB41L3_2',
#  'GABBR1_1',
#  'SYNRG_1',
#  'EPN1_1',
#  'MAT2B_1',
#  'AP1S2_3',
#  'NCOR2_2',
#  'ATAT1_1',
#  'IMMT_2',
#  'MACF1_1',
#  'TPM1_1',
#  'SORBS1_3',
#  'TUB_1',
#  'ABLIM1_1',
#  'BCCIP_1',
#  'PFN2_1',
#  'PTK2_1',
#  'DDX54_1',
#  'PALLD_1',
#  'EXOC7_1',
#  'PPFIBP1_1',
#  'NFASC_1',
#  'CSDE1_1',
#  'CDC42_1',
#  'MAP3K7_1',
#  'CRMP1_1',
#  'TOR1AIP1_1',
#  'CALD1_1',
#  'PTPRK_1',
#  'UCHL5_1',
#  'KAZN_1',
#  'KIAA1671_1',
#  'DLG1_1',
#  'NOLC1_1',
#  'MAX_1',
#  'XRCC4_1',
#  'ACOT9_1',
#  'LRBA_1',
#  'PML_1',
#  'MAPT_1',
#  'ATXN2_1',
#  'DMTN_1',
#  'PRKD1_1',
#  'BCAT1_1',
#  'POLR2M_1',
#  'MLIP_1',
#  'ANKS1B_2',
#  'CADPS_1',
#  'TRIP12_1',
#  'MATN2_1',
#  'ESYT2_1',
#  'NAXD_1',
#  'CARMIL2_1',
#  'BAIAP2_1',
#  'PDE4B_1',
#  'TOM1L2_1',
#  'SRGAP2_1',
#  'USP28_1',
#  'PTK2B_1',
#  'TMPO_2',
#  'POLDIP3_1',
#  'WIZ_2',
#  'MCF2L_1',
#  'ATP2B1_1',
#  'NAV1_1',
#  'RNF213_1',
#  'TSC1_1',
#  'FARP1_1',
#  'SNAP25_1',
#  'CAMK2A_1',
#  'KIF1B_2',
#  'GANAB_1',
#  'RUFY2_1',
#  'MRTFB_1',
#  'BCLAF1_1',
#  'PSIP1_1',
#  'KCNAB2_2',
#  'SNPH_1',
#  'MYH11_2',
#  'FMR1_2',
#  'ITPR1_1',
#  'API5_1',
#  'SLC44A2_1',
#  'BCL7A_1',
#  'SCYL1_1',
#  'AHNAK_1',
#  'VDAC3_1',
#  'STXBP5L_1',
#  'OS9_1',
#  'BCAS1_1',
#  'EPN2_2',
#  'RAB28_1',
#  'PALM_1',
#  'FLII_1',
#  'CNOT1_1',
#  'MINDY2_1',
#  'ADD1_2',
#  'CCDC88A_2',
#  'SLC24A2_1',
#  'COPS9_1',
#  'SERPINE2_1',
#  'FMNL3_1',
#  'DCX_2',
#  'MYO9B_1',
#  'PLEKHS1_1',
#  'ANK1_2',
#  'KCNMA1_1',
#  'ARHGEF11_1',
#  'YTHDC1_1',
#  'MYO6_1',
#  'MBP_2',
#  'ANK2_2',
#  'ACP1_1',
#  'UCHL5_2',
#  'HNRNPA3_1',
#  'LIMCH1_1',
#  'CSPG5_1',
#  'DNM1L_1',
#  'RBM26_1',
#  'CD99_1',
#  'TOM1L1_1',
#  'MAP9_1',
#  'SH3GLB2_2',
#  'IQSEC2_1',
#  'CD46_1',
#  'GOLGA4_1',
#  'RPN2_1',
#  'DOCK9_1',
#  'PPP1R21_1',
#  'SPTAN1_2',
#  'ITSN1_2',
#  'PLEKHA6_1',
#  'TMPO_1',
#  'ABI1_1',
#  'NRCAM_1',
#  'DST_2',
#  'CALU_1',
#  'TJP1_1',
#  'PTBP2_1',
#  'SMARCC2_1',
#  'CSNK1A1_1',
#  'MTHFSD_1',
#  'ITGB4_1',
#  'CAST_1',
#  'PML_3',
#  'ITGA7_1',
#  'ZC3HAV1_1',
#  'MAPRE3_1',
#  'CHL1_1',
#  'CCNT2_1',
#  'RIMS2_1',
#  'SYNM_2',
#  'ENAH_1',
#  'SGIP1_1',
#  'SPATS2L_1',
#  'NCOA7_1',
#  'GOLGB1_1',
#  'AFDN_2',
#  'SPP1_1',
#  'RAPGEF2_1',
#  'CCDC9_1',
#  'RAP1GDS1_1',
#  'ADD1_1',
#  'TAX1BP1_1',
#  'SAMD4A_1',
#  'HSPH1_1',
#  'SORBS1_4',
#  'BORCS8_1',
#  'NSD3_1',
#  'HM13_1',
#  'GIT1_1',
#  'TJP2_1',
#  'CUL7_1',
#  'PYM1_1',
#  'RABGAP1L_1',
#  'ZC3H13_1',
#  'FMR1_1',
#  'KIF21B_1',
#  'STXBP1_1',
#  'NASP_1',
#  'DBN1_1',
#  'CEP170_1',
#  'DAZAP2_1',
#  'ADD2_1',
#  'MOCS2_1',
#  'SORBS1_2',
#  'PEX5L_1',
#  'GFAP_4',
#  'PDE4DIP_1',
#  'SPATA33_1',
#  'SYN1_1',
#  'TBC1D1_1',
#  'TNIK_1',
#  'DIP2C_1',
#  'FXYD6_1',
#  'OSBPL3_1',
#  'CLINT1_1',
#  'SORBS2_3',
#  'MAP4K4_1',
#  'ALB_1',
#  'DLGAP1_1',
#  'GPS1_1',
#  'CRK_1',
#  'MACROD2_1',
#  'TNIK_2',
#  'PRKACB_2',
#  'RAP1GDS1_2',
#  'TCF4_1',
#  'ACBD5_1',
#  'ANKHD1_1',
#  'PLEKHA1_1',
#  'CSNK1A1_2',
#  'PCBP2_3',
#  'NADK2_1',
#  'GSPT1_1',
#  'TPM2_1',
#  'EPB41L2_1',
#  'ADGRL3_1',
#  'SHANK2_2',
#  'MAP7D1_1',
#  'OXR1_1',
#  'HNRNPU_2',
#  'ENTPD6_1',
#  'DNAJA3_1',
#  'DCLK1_2',
#  'CCDC88A_1',
#  'KIF1B_1',
#  'PCM1_1',
#  'RBBP7_1',
#  'TNRC6B_1',
#  'TAOK2_1',
#  'FAM219A_1',
#  'DCTN4_1',
#  'TCOF1_1',
#  'ARPP21_1',
#  'DLGAP4_1',
#  'PUM1_1',
#  'MAPRE2_1',
#  'TPM1_3',
#  'COBLL1_1',
#  'PLEC_1',
#  'KTN1_1',
#  'CEP170B_1',
#  'NDRG4_2',
#  'SET_2',
#  'CSNK1D_1',
#  'HOMER2_1',
#  'PCBP2_4',
#  'DYNC2LI1_1',
#  'RTN1_1',
#  'KLC1_2',
#  'SON_1',
#  'GFAP_1',
#  'ANKFY1_1',
#  'SEC16A_1',
#  'PTAR1_1',
#  'CNKSR2_1',
#  'TPM3_2',
#  'SPTAN1_3',
#  'PLEC_5',
#  'STRADA_1',
#  'IST1_1',
#  'MRPL43_1',
#  'HM13_2',
#  'UBQLN1_1',
#  'MPZL1_1',
#  'RBFOX1_1',
#  'C2CD5_1',
#  'NFIX_1',
#  'ANKS1B_1',
#  'MBP_3',
#  'BCAS3_1',
#  'SET_1',
#  'FHL1_1',
#  'C2CD5_2',
#  'FN1_1',
#  'TRRAP_1',
#  'PPHLN1_1',
#  'MON2_1',
#  'ACTN1_1',
#  'ARFIP1_1',
#  'PPP2R5C_1',
#  'PRKCB_1',
#  'PPFIA2_1',
#  'SCG5_1',
#  'STK32A_1',
#  'CLASP2_2',
#  'DLG3_1',
#  'MACROH2A1_1',
#  'TMPO_3',
#  'SEPTIN3_1',
#  'FBXO38_1',
#  'ARMC10_1',
#  'G3BP2_1',
#  'MPRIP_1',
#  'CTNND1_2',
#  'CLASP1_1',
#  'CHPT1_1',
#  'CLASP2_1',
#  'ANK2_3',
#  'RIMS1_2',
#  'LSM14B_1',
#  'EIF4E2_1',
#  'OSBPL6_1',
#  'TNC_3',
#  'SIRPB1_1',
#  'HSPA12A_1',
#  'NEBL_1',
#  'METAP2_1',
#  'HDGFL2_1',
#  'PEG3_1',
#  'TRIM33_1',
#  'CACNA2D1_1',
#  'OGT_1',
#  'AIMP2_1',
#  'DDHD1_1',
#  'ATRN_1',
#  'RAD23A_1',
#  'APLP1_1',
#  'RANBP3_1',
#  'PALM2AKAP2_2',
#  'STAT3_1',
#  'FIP1L1_1',
#  'SMARCB1_1',
#  'YAP1_1',
#  'ADGRL3_2',
#  'KIAA1217_1',
#  'DNM2_1',
#  'CLIP1_1',
#  'MINK1_1',
#  'TPD52L2_1',
#  'MARK4_1',
#  'PRC1_1',
#  'DHX30_1',
#  'DLGAP1_2',
#  'ARL6IP4_2',
#  'HNRNPC_1',
#  'SORBS2_2',
#  'CIC_1',
#  'PLCB1_1',
#  'PLCD1_1',
#  'SMARCA1_1',
#  'PACSIN2_1',
#  'SERBP1_1',
#  'AGAP3_1',
#  'LAMA4_1',
#  'MXRA7_1',
#  'HNRNPC_2',
#  'MARK3_1',
#  'SYNM_1',
#  'STRN3_1',
#  'CUX1_1',
#  'PDCD6_1',
#  'CDC42BPA_2',
#  'EPB41L2_3',
#  'MAP4K4_2',
#  'ATP6V0A1_1',
#  'EIF2B4_1',
#  'TTC17_1',
#  'TNC_2',
#  'DDX46_1',
#  'KIF2A_1',
#  'SPTB_1',
#  'PCM1_2',
#  'RTN4_1',
#  'IST1_2',
#  'NDRG4_3',
#  'CAMK2D_1',
#  'MDH1_1',
#  'GFAP_3',
#  'RAB34_1',
#  'RAB1A_1',
#  'RAP1GAP_2',
#  'MFF_1',
#  'HBS1L_1',
#  'SORBS1_1',
#  'PDE4D_2',
#  'PLEC_4',
#  'CEP170_2',
#  'NAA15_1',
#  'ABR_1',
#  'PCBP2_2',
#  'CAMK1D_1',
#  'HCFC1_1',
#  'SCP2_1',
#  'TPM2_2',
#  'CLEC16A_1',
#  'UBAP2L_1',
#  'DCLK2_1',
#  'PIP5K1A_1',
#  'MAGI2_1',
#  'NFAT5_1',
#  'NRXN1_1',
#  'CNBP_1',
#  'RTN4_2',
#  'NTRK2_2',
#  'PLEC_6',
#  'TTYH1_1',
#  'SLMAP_1',
#  'EPB41L3_1',
#  'GNAS_3',
#  'SF1_1',
#  'CRTC3_1',
#  'ITSN1_1',
#  'SCAMP3_1',
#  'WIZ_1',
#  'GIT2_1',
#  'CUL4B_1',
#  'IRF2BP2_1',
#  'CDK13_1',
#  'EIF4G3_1',
#  'ADAM22_1',
#  'GOSR1_1',
#  'UBTF_1',
#  'MSI2_1',
#  'HNRNPR_1',
#  'UBAP2L_2',
#  'OSBPL9_1',
#  'GFAP_2',
#  'SRGAP1_1',
#  'RTN3_2',
#  'EPB41L2_2',
#  'ZMYND8_1',
#  'NFIA_1',
#  'EEF1D_1',
#  'LMO7_1',
#  'WLS_1',
#  'EPB41_1',
#  'MAP4_2']

# %% [markdown]
# Kidney

# %%
kidney_df = make_trans_df(c)

kidney_df = kidney_df.rename(columns={"Correlation": "Correlation_ccRCC","P_value": "P_value_ccRCC" })
kidney_df.to_csv('csv_files/trans_effects_all_prot_fdr_corrected_ccRCC',index=False)

# %% [markdown]
# Ovarian

# %%
#ovarian_df = make_trans_df(ovar)

#ovarian_df = ovarian_df.rename(columns={"Correlation": "Correlation_OV","P_value": "P_value_OV" })
#ovarian_df.to_csv('csv_files/trans_effects_all_prot_fdr_corrected_OV',index=False)

# %% [markdown]
# Colon

# %%
#colon_df = make_trans_df(colon)

#colon_df = colon_df.rename(columns={"Correlation": "Correlation_CO","P_value": "P_value_CO" })
#colon_df.to_csv('csv_files/trans_effects_all_prot_fdr_corrected_CO',index=False)

# %% [markdown]
# Brca

# %%
brca_df = make_trans_df(b)

brca_df = brca_df.rename(columns={"Correlation": "Correlation_BR","P_value": "P_value_BR" })
brca_df.to_csv('csv_files/trans_effects_all_prot_fdr_corrected_BR',index=False)

# %% [markdown]
# Luad

# %%
luad_df = make_trans_df(l)

luad_df = luad_df.rename(columns={"Correlation": "Correlation_LUAD","P_value": "P_value_LUAD" })
luad_df.to_csv('csv_files/trans_effects_all_prot_fdr_corrected_LUAD',index=False)

# %% [markdown]
# Hnscc

# %%
hnscc_df = make_trans_df(hn)

hnscc_df = hnscc_df.rename(columns={"Correlation": "Correlation_HNSCC","P_value": "P_value_HNSCC" })
hnscc_df.to_csv('csv_files/trans_effects_all_prot_fdr_corrected_HNSCC',index=False)

# %% [markdown]
# Lscc

# %%
lscc_df = make_trans_df(ls)

lscc_df = lscc_df.rename(columns={"Correlation": "Correlation_LSCC","P_value": "P_value_LSCC" })
lscc_df.to_csv('csv_files/trans_effects_all_prot_fdr_corrected_LSCC',index=False)

# %%
lscc_df
# Out:
#       Comparison  Correlation_LSCC  P_value_LSCC
# 2961        EGFR          1.000000  0.000000e+00
# 2613      PHLDA1          0.682116  1.398013e-12
# 7616      PHLDA3          0.651618  5.103796e-11
# 5110      PHLDA2          0.650100  3.054310e-09
# 6461      TRIM29          0.553806  7.010705e-07
# ...          ...               ...           ...
# 27       CEACAM7          0.000267  9.992219e-01
# 2660       TCF12          0.000102  9.994004e-01
# 10283       JAK3         -0.000077  9.995287e-01
# 11825       SZT2          0.000056  9.996186e-01
# 11378   SLC25A24         -0.000033  9.997296e-01
#
# [12074 rows x 3 columns]
