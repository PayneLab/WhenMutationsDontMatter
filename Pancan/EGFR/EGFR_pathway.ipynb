# %%
import pandas as pd
import numpy as np
import cptac.utils as u

# %%
prot = u.get_proteins_in_pathways('EGF/EGFR Signaling Pathway', 'wikipathways')
prot_list = list(prot.member)
print('Num interacting proteins:', len(prot_list))
prot
# Out:
# Num interacting proteins: 159
#                         pathway   member
# 0    EGF/EGFR Signaling Pathway     RAF1
# 1    EGF/EGFR Signaling Pathway    FOXO1
# 2    EGF/EGFR Signaling Pathway    PLCE1
# 3    EGF/EGFR Signaling Pathway     STAM
# 4    EGF/EGFR Signaling Pathway    PTK2B
# ..                          ...      ...
# 154  EGF/EGFR Signaling Pathway    MEF2A
# 155  EGF/EGFR Signaling Pathway   CAMK2A
# 156  EGF/EGFR Signaling Pathway  ARHGEF1
# 157  EGF/EGFR Signaling Pathway     CAV1
# 158  EGF/EGFR Signaling Pathway     PAK1
#
# [159 rows x 2 columns]

# %%
pancan = pd.read_csv('csv_files//Supplemental_Table_EGFR_sig_only.csv')

pancan["Comparison"] = pancan['Comparison'].str.replace(r"_\d","")
pancan
# Out:
#      Comparison  Correlation_GBM   P_value_GBM  Correlation_ccRCC  \
# 0        PHLDA1         0.789551  9.649849e-19                NaN
# 1          CDH4         0.656331  4.744022e-10                NaN
# 2          GRB2        -0.589008  3.310325e-07                NaN
# 3        PHLDA3         0.561528  2.006861e-06           0.364164
# 4           GLA        -0.562315  2.006861e-06          -0.273040
# ...         ...              ...           ...                ...
# 6438   IGLV2-23              NaN           NaN                NaN
# 6439     SCN10A              NaN           NaN                NaN
# 6440     PCYT1A              NaN           NaN                NaN
# 6441      NCBP1              NaN           NaN                NaN
# 6442   IGHV3-43              NaN           NaN                NaN
#
#       P_value_ccRCC  Correlation_LUAD  P_value_LUAD  Correlation_LSCC  \
# 0               NaN               NaN           NaN          0.682116
# 1               NaN               NaN           NaN               NaN
# 2               NaN               NaN           NaN               NaN
# 3          0.005159               NaN           NaN          0.651618
# 4          0.047412               NaN           NaN               NaN
# ...             ...               ...           ...               ...
# 6438            NaN               NaN           NaN               NaN
# 6439            NaN               NaN           NaN               NaN
# 6440            NaN               NaN           NaN               NaN
# 6441            NaN               NaN           NaN               NaN
# 6442            NaN               NaN           NaN               NaN
#
#       P_value_LSCC  Correlation_BR  P_value_BR  Correlation_HNSCC  \
# 0     1.398013e-12             NaN         NaN           0.583064
# 1              NaN             NaN         NaN                NaN
# 2              NaN             NaN         NaN          -0.481605
# 3     5.103796e-11             NaN         NaN           0.693125
# 4              NaN             NaN         NaN                NaN
# ...            ...             ...         ...                ...
# 6438           NaN             NaN         NaN          -0.277801
# 6439           NaN             NaN         NaN          -0.364870
# 6440           NaN             NaN         NaN           0.245333
# 6441           NaN             NaN         NaN           0.245341
# 6442           NaN             NaN         NaN          -0.245177
#
#       P_value_HNSCC
# 0      1.395609e-08
# 1               NaN
# 2      2.053150e-05
# 3      2.351012e-14
# 4               NaN
# ...             ...
# 6438   4.834886e-02
# 6439   4.918329e-02
# 6440   4.976210e-02
# 6441   4.976210e-02
# 6442   4.993180e-02
#
# [6443 rows x 13 columns]

# %%
gbm_genes = pancan.Comparison.to_list()
matching = [s for s in gbm_genes if "_" in s]
len(matching)
# Out:
# 0

# %%
pancan_mapk  = pancan[pancan.Comparison.isin(prot_list)]
pancan_mapk
# Out:
#      Comparison  Correlation_GBM   P_value_GBM  Correlation_ccRCC  \
# 2          GRB2        -0.589008  3.310325e-07                NaN
# 11         SHC1        -0.521169  2.230519e-05           0.361057
# 50          CSK        -0.461582  2.971779e-04                NaN
# 191        EPS8        -0.401471  2.064832e-03                NaN
# 296        VAV1        -0.379772  3.766116e-03          -0.317914
# ...         ...              ...           ...                ...
# 6222      CDC42              NaN           NaN                NaN
# 6244      PEBP1              NaN           NaN                NaN
# 6272       RAF1              NaN           NaN                NaN
# 6292    EPS15L1              NaN           NaN                NaN
# 6354       RALA              NaN           NaN                NaN
#
#       P_value_ccRCC  Correlation_LUAD  P_value_LUAD  Correlation_LSCC  \
# 2               NaN               NaN           NaN               NaN
# 11         0.004674               NaN           NaN               NaN
# 50              NaN         -0.353208      0.006614               NaN
# 191             NaN               NaN           NaN               NaN
# 296        0.016535               NaN           NaN               NaN
# ...             ...               ...           ...               ...
# 6222            NaN               NaN           NaN               NaN
# 6244            NaN               NaN           NaN               NaN
# 6272            NaN               NaN           NaN               NaN
# 6292            NaN               NaN           NaN               NaN
# 6354            NaN               NaN           NaN               NaN
#
#       P_value_LSCC  Correlation_BR  P_value_BR  Correlation_HNSCC  \
# 2              NaN             NaN         NaN          -0.481605
# 11             NaN             NaN         NaN                NaN
# 50             NaN             NaN         NaN          -0.352163
# 191            NaN             NaN         NaN          -0.248907
# 296            NaN             NaN         NaN          -0.285847
# ...            ...             ...         ...                ...
# 6222           NaN             NaN         NaN           0.275730
# 6244           NaN             NaN         NaN          -0.272622
# 6272           NaN             NaN         NaN          -0.268365
# 6292           NaN             NaN         NaN          -0.264682
# 6354           NaN             NaN         NaN           0.256565
#
#       P_value_HNSCC
# 2          0.000021
# 11              NaN
# 50         0.002791
# 191        0.045828
# 296        0.018249
# ...             ...
# 6222       0.023977
# 6244       0.025930
# 6272       0.028835
# 6292       0.031829
# 6354       0.038234
#
# [108 rows x 13 columns]

# %% [markdown]
# # GBM

# %%
gbm_egfr_path = pancan_mapk[["Comparison","Correlation_GBM","P_value_GBM"]].dropna()

gbm_egfr_path.to_csv('csv_files/GBM_EGFR_Path.csv', index=False)
gbm_egfr_path
# Out:
#      Comparison  Correlation_GBM   P_value_GBM
# 2          GRB2        -0.589008  3.310325e-07
# 11         SHC1        -0.521169  2.230519e-05
# 50          CSK        -0.461582  2.971779e-04
# 191        EPS8        -0.401471  2.064832e-03
# 296        VAV1        -0.379772  3.766116e-03
# 297      MAP3K3        -0.379649  3.774722e-03
# 397      INPP5D        -0.362195  6.154996e-03
# 413        GAB1         0.359722  6.593818e-03
# 429         PXN        -0.357429  6.992619e-03
# 563      MAPK14        -0.355650  1.103380e-02
# 635        DOK2        -0.348484  1.287156e-02
# 642     SH3KBP1        -0.332370  1.302297e-02
# 643      PTPN12        -0.332394  1.302297e-02
# 664       NEDD4        -0.330584  1.352452e-02
# 734        CAV2        -0.338351  1.619020e-02
# 797      RICTOR        -0.317904  1.830209e-02
# 858        ITCH         0.311114  2.186123e-02
# 916       FOXO1         0.306508  2.416846e-02
# 951       STAT1         0.303774  2.567071e-02
# 990       LIMK2        -0.300614  2.755269e-02
# 1001      PLCG1         0.299933  2.786222e-02
# 1025       ATF1        -0.298191  2.900111e-02
# 1143       STAM        -0.288458  3.632695e-02
# 1207      RAB5A         0.284106  3.976757e-02
# 1322      AP2B1         0.275939  4.751674e-02
# 1328       GJA1         0.275381  4.812716e-02

# %% [markdown]
# # HNSCC

# %%
hnscc_mapk = pancan_mapk[["Comparison","Correlation_HNSCC","P_value_HNSCC"]].dropna()
hnscc_mapk
# Out:
#      Comparison  Correlation_HNSCC  P_value_HNSCC
# 2          GRB2          -0.481605       0.000021
# 50          CSK          -0.352163       0.002791
# 191        EPS8          -0.248907       0.045828
# 296        VAV1          -0.285847       0.018249
# 397      INPP5D          -0.305820       0.010432
# 635        DOK2          -0.393739       0.000665
# 642     SH3KBP1          -0.358572       0.002264
# 643      PTPN12           0.350740       0.002924
# 734        CAV2           0.279152       0.021930
# 1328       GJA1           0.418377       0.000270
# 1450      EPS15          -0.327462       0.005654
# 1459       CAV1           0.259986       0.035467
# 1820      PRKCB          -0.337077       0.004303
# 2258     MAP4K1          -0.365970       0.001812
# 2583     STAT5A          -0.361741       0.002052
# 2854       RIN1           0.352630       0.002749
# 2925      MEF2D          -0.251325       0.043419
# 3029       RALB           0.249504       0.045194
# 3238     MAP3K4           0.364762       0.001901
# 3520       PLD1           0.269305       0.028212
# 3529       VAV2           0.246511       0.048248
# 3791        JUN           0.364643       0.001901
# 4269    RPS6KA3          -0.324072       0.006280
# 4588      PRKCI           0.289974       0.016173
# 6002       PCNA           0.318670       0.007303
# 6063      SYNJ1          -0.307510       0.009939
# 6151    RPS6KA1           0.290181       0.016150
# 6154      BCAR1           0.289707       0.016312
# 6222      CDC42           0.275730       0.023977
# 6244      PEBP1          -0.272622       0.025930
# 6272       RAF1          -0.268365       0.028835
# 6292    EPS15L1          -0.264682       0.031829
# 6354       RALA           0.256565       0.038234

# %% [markdown]
# # LUAD

# %%
gbm_mapk = pancan_mapk[["Comparison","Correlation_LUAD","P_value_LUAD"]].dropna()
gbm_mapk
# Out:
#      Comparison  Correlation_LUAD  P_value_LUAD
# 563      MAPK14          0.370171      0.003837
# 1057    RASGRP2         -0.402328      0.001410
# 1140      ARRB2         -0.279476      0.040282
# 1816      PTPN7         -0.339351      0.009538
# 1995      HSPB1          0.280445      0.039566
# 2106     PPP3CC         -0.475416      0.000060
# 2141      MAPK8         -0.418543      0.000779
# 2142       STK3          0.416443      0.000831
# 2144     PRKACB         -0.415529      0.000859
# 2258     MAP4K1         -0.356579      0.006084
# 2262      DUSP6          0.354687      0.006509
# 2267     PPP3CB         -0.353605      0.006614
# 2270      NFKB2         -0.353724      0.006614
# 2272     MAP2K6         -0.352166      0.006914
# 2340   MAPK8IP3          0.343566      0.009930
# 2387       STK4         -0.326409      0.013600
# 2425      PPM1A          0.320188      0.015888
# 2479       RAC1          0.312954      0.018856
# 2498       RAC2         -0.310210      0.020232
# 2571      RASA1          0.300210      0.025509
# 2740     MAP3K8         -0.285722      0.039358

# %% [markdown]
# # LSCC

# %%
gbm_mapk = pancan_mapk[["Comparison","Correlation_LSCC","P_value_LSCC"]].dropna()
gbm_mapk
# Out:
#      Comparison  Correlation_LSCC  P_value_LSCC
# 1129       RELB          0.286573      0.043125
# 1399      GNG12          0.316654      0.024110
# 1995      HSPB1          0.474021      0.000073
# 2895     MAP3K6          0.413747      0.001195
# 3067       DAXX         -0.328810      0.017240
# 3070      NTRK2          0.326927      0.018501
# 3178     MAP3K5          0.308349      0.027821
# 3238     MAP3K4          0.300021      0.033108
# 3374     MAP3K2          0.285148      0.044366
# 3412      RRAS2          0.280466      0.049224

# %% [markdown]
# # ccRCC

# %%
gbm_mapk = pancan_mapk[["Comparison","Correlation_ccRCC","P_value_ccRCC"]].dropna()
gbm_mapk
# Out:
#      Comparison  Correlation_ccRCC  P_value_ccRCC
# 581        FLNB           0.281238       0.038936
# 1140      ARRB2          -0.272475       0.047724
# 1367      PPM1B          -0.546690       0.000001
# 1399      GNG12           0.458236       0.000111
# 1420      MAPK1           0.432764       0.000342
# 1476        MAX          -0.389429       0.001967
# 1554     MAP4K2          -0.369629       0.004395
# 1707    PLA2G4A          -0.324576       0.013817
# 1738       TAB2          -0.318929       0.016121
# 1816      PTPN7          -0.315477       0.020449
# 1817      ARRB1          -0.307995       0.020459
# 1995      HSPB1           0.282165       0.038204
# 1996      LRRK2           0.282014       0.038259
# 2046      PRKCD          -0.275672       0.044517
