# %% [markdown]
# # Make Figure 4

# %% [markdown]
# This notebooks takes all the trans genes that have positive and negative results and runs a GSEA using Reactome. It then takes a subset of genes from the top hit (Hemostasis) pathway and maps them on a large circle heat map. This heatmap focuses on coagulation and urokinase related genes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas.util.testing as tm
import scipy.stats
import re
import sys 
import statsmodels.stats.multitest

import gseapy as gp
from gseapy.plot import barplot, dotplot

import plot_utils as p 
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import math as math
import scipy.stats
import re
import sys
import statsmodels.stats.multitest
from bokeh.palettes import RdBu
from bokeh.models import LinearColorMapper, ColumnDataSource, ColorBar
from bokeh.models.ranges import FactorRange
from bokeh.plotting import figure, show
from bokeh.io import output_notebook, export_png, export_svgs
from bokeh.layouts import row

# %%
def plotCircleHeatMap ( df, circle_var, color_var, x_axis, y_axis, plot_width= 1000, plot_height = 650, font_size = 12,    x_axis_lab = "no_label", y_axis_lab = "no_label", show_plot = True, save_png = "plot.png", legend_min = 1e-6, legend_med = .0001, legend_max = 0.01, show_legend = True):
  
    # circle_var designed for pvalues. Normalized by taking log 10 of values and multiplying by 5 
    #added a new column to make the plot size
    
    df["size2"] = df[circle_var].apply(lambda x: -1*(np.log(x)))
    df['size'] = (df["size2"])*3
    #find values to set color bar min/ max as 
    maxval = df[color_var].max()
    minval = df[color_var].min()
    if maxval > abs(minval):
        minval = maxval * -1 
    if maxval < abs(minval):
        maxval = minval * -1
    colors = list((RdBu[9]))
    exp_cmap = LinearColorMapper(palette=colors, low = minval, high = maxval)
    p = figure(x_range = FactorRange(), y_range = FactorRange(), plot_width= plot_width, 
               plot_height=plot_height, 
               toolbar_location=None, tools="hover")

    p.scatter(x_axis,y_axis,source=df, fill_alpha=1,  line_width=0, size="size", 
              fill_color={"field":color_var, "transform":exp_cmap})

    #p.x_range.factors = sorted(df[x_axis].unique().tolist())
    p.x_range.factors = df[x_axis].unique().tolist()
    p.y_range.factors = sorted(df[y_axis].unique().tolist(), reverse = True)
    p.xaxis.major_label_orientation = math.pi/2
    
    # font size
    p.axis.major_label_text_font_size = str(font_size)+"pt"
    p.axis.axis_label_text_font_size = str(font_size)+"pt"
    
    if (x_axis_lab != "no_label" ):
        p.xaxis.axis_label = x_axis_lab
    if (y_axis_lab != "no_label" ):   
        p.yaxis.axis_label = y_axis_lab

    bar = ColorBar(color_mapper=exp_cmap, location=(0,0))
    p.add_layout(bar, "right")
    
    if show_plot:  
        if show_legend:
            # Create Circle Legend
            circle_legend = create_circle_legend(circle_var, color_var, legend_min, legend_med, legend_max)
            circle_legend.axis.major_label_text_font_size = str(font_size - 1)+"pt" # font size
            output_notebook()
            show(row(p, circle_legend))
        else:
            output_notebook()
            show(p)
      
    if save_png != "plot.png":
        export_png(row(p, circle_legend), filename= save_png)
        
    return p
         

'''
@Param legend_min: Float. Lowest p-value to include in the legend.
@Param legend_max: Float. Highest p-value to include in the legend.
@Param color_var: Str. Used for column name (same as other df)

Returns: df to be used in creating the circle legend. 
'''

def create_circle_legend_df(color_var, legend_min, legend_med, legend_max):
    # Find middle pval
    
    #exp_min = abs(np.log10(legend_min))
    #exp_max = abs(np.log10(legend_max))
    #delta = (exp_min - exp_max) / 2 
    #exp_mid = -1 * (exp_max + delta)
    #pval2 = 1 * 10**exp_mid
    
    # Foramat scientific notation pvals as strings for y_axis labels  
    max_str = "{:.1e}".format(legend_max, '.2f')
    med_str = "{:.1e}".format(legend_med, '.2f')
    min_str = "{:.1e}".format(legend_min, '.2f')
    
    # max to min
    data = {'P_Value':  [legend_max, legend_med, legend_min],
            'y_axis': [max_str, med_str, min_str],
            'x_axis': ['', '', ''],
            color_var: [1.5, 1.5, 1.5]}

    fake_df = pd.DataFrame (data, columns = ['x_axis', 'y_axis', 'P_Value', color_var])
    
    fake_df["size2"] = fake_df['P_Value'].apply(lambda x: -1*(np.log(x)))
    fake_df['size'] = (fake_df["size2"])*3
    
    return fake_df

'''
@Param df: Dataframe. Same as df passed to plotCircleHeatMap.
@Param circle_var: Column Label. Same as passed to plotCircleHeatMap.
@Param color_var: Column Label. Same as passed to plotCircleHeatMap.
@Param x_axis: Column Label. Used on the x-axis.
@Param y_axis: Column Label. Used on the y-axis.
@Param legend_min: Float. Lowest p-value to include in the legend.
@Param legend_max: Float. Highest p-value to include in the legend.

Returns: df to be used in creating the circle legend. 
'''

def create_circle_legend(circle_var, color_var, legend_min, legend_med, legend_max,
                         x_axis = 'x_axis', y_axis = 'y_axis', 
                         plot_height = 200, plot_width = 140):
    # Get customized df
    circle_df = create_circle_legend_df(color_var, legend_min, legend_med, legend_max)
    
    maxval = circle_df[color_var].max()
    minval = circle_df[color_var].min()
    if maxval > abs(minval):
        minval = maxval * -1 
    if maxval < abs(minval):
        maxval = minval * -1
    colors = list((RdBu[9]))
    exp_cmap = LinearColorMapper(palette=colors, low = minval, high = maxval)
    
    circle = figure(x_range = FactorRange(), y_range = FactorRange(), plot_width= plot_width, 
               plot_height=plot_height, toolbar_location=None, tools="hover")

    circle.scatter(x_axis, y_axis, source = circle_df, fill_alpha=1,  line_width=0, size="size", 
              fill_color={"field":color_var, "transform":exp_cmap})
    
    circle.x_range.factors = sorted(circle_df[x_axis].unique().tolist())
    circle.y_range.factors = circle_df[y_axis].unique().tolist() # plots in reverse order of circle_df (max to min)
    circle.xaxis.major_label_orientation = math.pi/2
    
    circle.xaxis.axis_label = 'FDR p-value'
    
    return circle

# %% [markdown]
# # Step 1: Find Trans proteins with opposite effects in different cancers

# %% [markdown]
# Load df with all of the genes that are FDR significant. This dataframe was made in the Make_Supplemental_Tables notebook. See
# https://github.com/PayneLab/WhenMutationsDontMatter/blob/master/EGFR/Make_Tables/Make_Supplemental_Tables.ipynb

# %%
FDR_sig = pd.read_csv("Make_Tables/csv_files/Supplemental_Table_EGFR_sig_only.csv")
FDR_sig = FDR_sig.set_index("Comparison")

# %%
FDR_sig.max(axis=1)
FDR_sig.min(axis = 1)
# Out:
# Comparison
# PHLDA1    3.507071e-21
# GRB2     -6.108891e-01
# SOCS2     3.420388e-06
# CDH4      3.420388e-06
# DAB2     -5.564015e-01
#               ...
# CLTC      4.813589e-02
# PLEC      4.824560e-02
# LRRK2    -2.674570e-01
# MBD1     -2.660975e-01
# RRP12     4.993781e-02
# Length: 6230, dtype: float64

# %%
def HasPosNeg(row):
    hasPos = False
    hasNeg= False

    for item in row:
        if pd.isnull(item):
            continue
        if item < 0:
            hasNeg = True
        if item > 0:
            hasPos = True
            
    if hasPos & hasNeg:
        return True
    return False

# %% [markdown]
# Subset data frame to include only trans genes that have opposite effects in different cancers by using apply function

# %%
col = ["Correlation_GBM","Correlation_ccRCC","Correlation_OV","Correlation_BR","Correlation_LUAD","Correlation_HNSCC","Correlation_LSCC","Correlation_CO"]
FDR_corr = FDR_sig[col]
FDR_corr["Pos_Neg"] = FDR_corr.apply(HasPosNeg, axis = 1)
FDR_corr_True = FDR_corr[FDR_corr['Pos_Neg']==True]
FDR_corr_True.head(20)
# Out:
# /Users/Lindsey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#             Correlation_GBM  Correlation_ccRCC  Correlation_OV  \
# Comparison
# DAB2              -0.556402                NaN             NaN
# PLA2G15           -0.556624          -0.298029             NaN
# CTSC              -0.546285          -0.302316             NaN
# SCPEP1            -0.531494          -0.386583             NaN
# FAM129B           -0.514984                NaN             NaN
# PPP1R18           -0.497202                NaN             NaN
# NPC2              -0.498791          -0.319133             NaN
# CTSB              -0.496895                NaN             NaN
# KYNU              -0.495517                NaN             NaN
# HSD17B11          -0.491843           0.272218             NaN
# SVIL              -0.491303                NaN             NaN
# SH3BP1            -0.488480          -0.266130             NaN
# APBB1IP           -0.483056                NaN             NaN
# COL6A2            -0.482774                NaN             NaN
# PPP2R3A           -0.503777           0.285735             NaN
# CTSZ              -0.481709                NaN             NaN
# HAAO              -0.481974                NaN             NaN
# THEMIS2           -0.481065                NaN             NaN
# DOCK11            -0.473476                NaN             NaN
# FCGRT             -0.474371           0.284123             NaN
#
#             Correlation_BR  Correlation_LUAD  Correlation_HNSCC  \
# Comparison
# DAB2              0.326055               NaN                NaN
# PLA2G15           0.274185               NaN                NaN
# CTSC              0.266940          0.302760                NaN
# SCPEP1            0.399187               NaN                NaN
# FAM129B           0.344093               NaN                NaN
# PPP1R18           0.359142               NaN                NaN
# NPC2              0.279599          0.292520                NaN
# CTSB              0.341048               NaN                NaN
# KYNU              0.373575         -0.341363                NaN
# HSD17B11          0.481667               NaN          -0.402146
# SVIL              0.285215               NaN                NaN
# SH3BP1                 NaN               NaN                NaN
# APBB1IP                NaN         -0.277151          -0.382555
# COL6A2                 NaN               NaN                NaN
# PPP2R3A           0.446137          0.348490                NaN
# CTSZ              0.267472               NaN          -0.268103
# HAAO              0.462999         -0.291232                NaN
# THEMIS2           0.286755               NaN          -0.401072
# DOCK11            0.288334               NaN                NaN
# FCGRT                  NaN               NaN          -0.297207
#
#             Correlation_LSCC  Correlation_CO  Pos_Neg
# Comparison
# DAB2                     NaN             NaN     True
# PLA2G15                  NaN             NaN     True
# CTSC                     NaN             NaN     True
# SCPEP1                   NaN             NaN     True
# FAM129B             0.360092             NaN     True
# PPP1R18                  NaN             NaN     True
# NPC2                     NaN             NaN     True
# CTSB                     NaN             NaN     True
# KYNU                     NaN             NaN     True
# HSD17B11                 NaN             NaN     True
# SVIL                     NaN             NaN     True
# SH3BP1              0.335866             NaN     True
# APBB1IP                  NaN        0.404376     True
# COL6A2                   NaN        0.303509     True
# PPP2R3A                  NaN             NaN     True
# CTSZ                     NaN             NaN     True
# HAAO                     NaN             NaN     True
# THEMIS2                  NaN             NaN     True
# DOCK11                   NaN             NaN     True
# FCGRT                    NaN             NaN     True

# %%
def Pvalue_sig(row):
    numSig = 0

    for item in row:
        if pd.isnull(item):
            continue
        if item < 0.05:
            numSig += 1
            
    return numSig

# %%
df = FDR_corr_True.drop("Pos_Neg",axis = 1)
diff = df.max(axis=1) - df.min(axis = 1)
diff.sort_values(ascending = False).head(20)
# Out:
# Comparison
# AADAT       1.053837
# EHBP1       0.976850
# ARHGAP10    0.973586
# HSD17B11    0.973510
# RARA        0.959860
# CMBL        0.954009
# CELSR1      0.950254
# PPP2R3A     0.949914
# HAAO        0.944973
# TBC1D10C    0.941293
# CTNND2      0.938110
# FAM49A      0.934342
# LPIN1       0.933992
# SCPEP1      0.930681
# ACSL4       0.930283
# TES         0.921650
# DSC2        0.919490
# GLIPR2      0.917386
# CXXC5       0.917084
# CRYBG3      0.914881
# dtype: float64

# %%
abs_val = FDR_corr_True.abs()
abs_val.sum(1).sort_values(ascending = False).head(20)
# Out:
# Comparison
# MYO10       3.264387
# KIF13B      3.140698
# CD109       3.068188
# IL16        2.949050
# CGGBP1      2.940795
# RCSD1       2.912306
# CNNM4       2.851991
# PLCG2       2.845178
# BAG2        2.837454
# RIN3        2.834336
# BIN2        2.806953
# SDC1        2.803257
# WIPF1       2.779699
# ITGB1       2.743227
# MICALL1     2.735946
# PSTPIP1     2.734371
# CELSR1      2.669411
# TRIM26      2.661191
# HSD17B11    2.647874
# ALDH1L1     2.639734
# dtype: float64

# %% [markdown]
# The manuscript mentions 945 of trans proteins that opposite effects in different cancers. Here is the derivation of that number

# %%
pos_neg_prot = FDR_corr_True.index.tolist()
pos_neg_prot
#print("Total number of trans proteins with opposite effects in different cancers is " + str(len(pos_neg_prot)))
# Out:
# ['DAB2',
#  'PLA2G15',
#  'CTSC',
#  'SCPEP1',
#  'FAM129B',
#  'PPP1R18',
#  'NPC2',
#  'CTSB',
#  'KYNU',
#  'HSD17B11',
#  'SVIL',
#  'SH3BP1',
#  'APBB1IP',
#  'COL6A2',
#  'PPP2R3A',
#  'CTSZ',
#  'HAAO',
#  'THEMIS2',
#  'DOCK11',
#  'FCGRT',
#  'CD14',
#  'PLCG2',
#  'PROCR',
#  'GBA',
#  'UAP1',
#  'CTNND2',
#  'GMIP',
#  'RASAL3',
#  'REL',
#  'DNAJC21',
#  'EHBP1L1',
#  'RAB3IL1',
#  'FCGR2A',
#  'CTSL',
#  'RIN2',
#  'RGS12',
#  'PHLDB2',
#  'FCGR3A',
#  'MYO10',
#  'LIG4',
#  'ST6GAL1',
#  'ACSL1',
#  'GPSM3',
#  'CTSS',
#  'CD300A',
#  'GMFG',
#  'TES',
#  'CXXC5',
#  'RCSD1',
#  'NEDD4',
#  'OTULIN',
#  'DOK3',
#  'TPD52L2',
#  'CHDH',
#  'PIK3AP1',
#  'ARPC1B',
#  'TNS3',
#  'FHL2',
#  'CDKN2C',
#  'IL16',
#  'UPP1',
#  'HCK',
#  'FCGR2B',
#  'SERPINB8',
#  'CLDN10',
#  'PLAUR',
#  'TMED5',
#  'WIPF1',
#  'ARPC3',
#  'AHR',
#  'DPYD',
#  'LUZP1',
#  'MYO1G',
#  'RASSF1',
#  'RALGAPA1',
#  'NOVA1',
#  'ACSS1',
#  'SLFN5',
#  'FLNB',
#  'SERPINB2',
#  'EVI2B',
#  'MRC1',
#  'FHOD1',
#  'EHD4',
#  'NFKB2',
#  'RHBDF2',
#  'LRRC25',
#  'ARHGAP10',
#  'ACSL4',
#  'ITGB1',
#  'ZNF185',
#  'P2RX4',
#  'LPXN',
#  'MYOF',
#  'CAV1',
#  'CRYBG1',
#  'ARPC2',
#  'FGB',
#  'IL4I1',
#  'PFN1',
#  'LAIR1',
#  'UBASH3B',
#  'NRBF2',
#  'TBC1D8B',
#  'EHBP1',
#  'MLX',
#  'TLR2',
#  'DGKA',
#  'FGG',
#  'CD163',
#  'SALL2',
#  'RBM47',
#  'SRPRA',
#  'STAT6',
#  'KIF16B',
#  'LCP1',
#  'STARD13',
#  'RIN3',
#  'MGAT1',
#  'CAPZA1',
#  'PAPSS2',
#  'ATP13A3',
#  'ANPEP',
#  'PPP2R1A',
#  'G6PD',
#  'TPK1',
#  'DSC2',
#  'ALOX5',
#  'MTHFD2',
#  'TRAF1',
#  'BCL10',
#  'SKAP2',
#  'CAV2',
#  'FGA',
#  'ZFYVE16',
#  'EPB41L5',
#  'SDC1',
#  'IPO5',
#  'PECAM1',
#  'ACTR2',
#  'RSU1',
#  'EMB',
#  'TMEM179B',
#  'SH3GLB1',
#  'SRGAP3',
#  'SERPINA7',
#  'C2',
#  'BIN2',
#  'ARHGAP9',
#  'TXNDC5',
#  'ARSB',
#  'CNNM4',
#  'SUB1',
#  'MAPK13',
#  'F13A1',
#  'MPDZ',
#  'MVP',
#  'STK10',
#  'COL15A1',
#  'DOK2',
#  'PTPRJ',
#  'SUMF1',
#  'ZFAND1',
#  'ERBIN',
#  'VCL',
#  'CYP7B1',
#  'F10',
#  'EML4',
#  'AHCYL1',
#  'MKNK1',
#  'GC',
#  'BACH1',
#  'MNDA',
#  'CST3',
#  'ASCC1',
#  'FERMT3',
#  'CCDC50',
#  'GFPT2',
#  'HFE',
#  'ARHGEF26',
#  'S100A11',
#  'CD109',
#  'CDK6',
#  'MSRB3',
#  'TBC1D22A',
#  'SRPX2',
#  'A1BG',
#  'DAPK3',
#  'ARPC4',
#  'TSPAN14',
#  'DDR2',
#  'BICC1',
#  'CHST3',
#  'HK3',
#  'FAM114A1',
#  'ISLR',
#  'RAB6A',
#  'ITGA3',
#  'C8A',
#  'TBC1D2',
#  'ECHDC1',
#  'ITGB2',
#  'SERPING1',
#  'UNC13D',
#  'TTC39B',
#  'SHROOM2',
#  'BMP2K',
#  'TTC19',
#  'ARPC5',
#  'TP53I3',
#  'LGMN',
#  'GPNMB',
#  'PLIN2',
#  'FES',
#  'MAP3K4',
#  'PPIP5K2',
#  'N4BP1',
#  'FBLIM1',
#  'CYBA',
#  'PPP2R5C',
#  'COL6A1',
#  'FOSL2',
#  'LILRB4',
#  'FLII',
#  'PTPN2',
#  'AHNAK2',
#  'CARD9',
#  'CMIP',
#  'MET',
#  'RALGAPB',
#  'MANBA',
#  'CASP10',
#  'COL11A1',
#  'VASP',
#  'ADI1',
#  'PITPNM1',
#  'ITGB5',
#  'FETUB',
#  'TPBG',
#  'CNN2',
#  'VSIG4',
#  'LIMK2',
#  'CYP1B1',
#  'DIAPH2',
#  'SIRT3',
#  'ITPR3',
#  'USP30',
#  'EIF4EBP1',
#  'CAND1',
#  'KCTD10',
#  'CDKN2A',
#  'CARD6',
#  'TMEM173',
#  'CSTA',
#  'KIF13A',
#  'CP',
#  'NAP1L4',
#  'ARNTL',
#  'ALDH1L1',
#  'AKR1B10',
#  'MALT1',
#  'BICD2',
#  'ADPGK',
#  'THYN1',
#  'PALMD',
#  'PPFIBP1',
#  'CREG1',
#  'CFHR1',
#  'PPM1F',
#  'SNTB2',
#  'MAMDC2',
#  'A2M',
#  'CRLF3',
#  'ELP4',
#  'ITGB3',
#  'PPP2R5A',
#  'PREX1',
#  'GSN',
#  'RAB32',
#  'SUGP2',
#  'PROS1',
#  'SRPRB',
#  'RAB27A',
#  'ARHGAP29',
#  'RIOX1',
#  'ITGAM',
#  'RAB42',
#  'HEPH',
#  'CEMIP2',
#  'C1orf21',
#  'COL12A1',
#  'PTPN12',
#  'IFI16',
#  'ACAD8',
#  'RAB43',
#  'RUNX1',
#  'JUNB',
#  'MST1',
#  'IFI30',
#  'IGFALS',
#  'UBA7',
#  'CDCA7L',
#  'DDAH1',
#  'ANTXR2',
#  'CTSO',
#  'COPZ2',
#  'XRCC1',
#  'CIB1',
#  'C6',
#  'PDLIM7',
#  'THBD',
#  'TMEM43',
#  'TSC22D3',
#  'YBX3',
#  'C3',
#  'C8B',
#  'SOGA1',
#  'SHBG',
#  'SEC11C',
#  'EXD2',
#  'IKBIP',
#  'TWF2',
#  'MFAP2',
#  'NRP2',
#  'ITIH4',
#  'TMOD3',
#  'EOGT',
#  'MLXIP',
#  'ABCC1',
#  'ADSS',
#  'EPN3',
#  'NOSIP',
#  'FGD5',
#  'C1QTNF3',
#  'PSTPIP1',
#  'STON1',
#  'MS4A6A',
#  'PDP1',
#  'IMPA2',
#  'P4HA2',
#  'PLD3',
#  'F9',
#  'RIT1',
#  'M6PR',
#  'LIG3',
#  'CASK',
#  'PRRX1',
#  'HSP90B1',
#  'S100A4',
#  'FBXL17',
#  'CFB',
#  'HYI',
#  'ZBTB20',
#  'RPF2',
#  'DERL1',
#  'NEIL2',
#  'RBSN',
#  'MYL6',
#  'SIPA1',
#  'SERPINC1',
#  'COL5A2',
#  'UGGT1',
#  'GAMT',
#  'MXRA5',
#  'LRCH1',
#  'F2',
#  'TMEM109',
#  'PICALM',
#  'INPP5B',
#  'SLK',
#  'SDR39U1',
#  'SERPINE1',
#  'TRIM28',
#  'QSOX1',
#  'KXD1',
#  'CRTC1',
#  'MAP1B',
#  'BTBD11',
#  'C8G',
#  'CRYBG3',
#  'FAM160B1',
#  'KNG1',
#  'DGKB',
#  'SP4',
#  'PBX1',
#  'F11',
#  'TSPYL5',
#  'FYCO1',
#  'KCTD9',
#  'CAPG',
#  'KLKB1',
#  'GOLM1',
#  'PCIF1',
#  'SAFB2',
#  'NRP1',
#  'HABP2',
#  'ESYT1',
#  'NCF4',
#  'ABAT',
#  'PSME4',
#  'GPC6',
#  'PMM2',
#  'TLN1',
#  'ZSCAN18',
#  'AMBP',
#  'WASF2',
#  'HRG',
#  'CA12',
#  'ALDH1A3',
#  'TIMP1',
#  'USP15',
#  'EIF2AK2',
#  'SGCE',
#  'GPX8',
#  'UBE2E2',
#  'LIMS1',
#  'LYAR',
#  'P4HA1',
#  'ZCCHC8',
#  'N4BP2L2',
#  'HPX',
#  'ALDH6A1',
#  'PRR36',
#  'FRMD8',
#  'CA13',
#  'RPS6KA1',
#  'RSL1D1',
#  'CCDC71L',
#  'RCN3',
#  'PAFAH1B3',
#  'MYH9',
#  'BMP1',
#  'PLEKHO1',
#  'FBLN2',
#  'PPP1CC',
#  'RASGRP2',
#  'C1R',
#  'LAMP1',
#  'WNT5A',
#  'UPF3A',
#  'HDLBP',
#  'RBMS1',
#  'GABARAPL2',
#  'ATP11C',
#  'CELSR2',
#  'SASH1',
#  'RFTN2',
#  'RPL14',
#  'AFM',
#  'COLGALT1',
#  'C1S',
#  'AADAT',
#  'SERPIND1',
#  'P4HB',
#  'IMPDH1',
#  'LYVE1',
#  'GGCX',
#  'MAPT',
#  'ANGEL2',
#  'COL5A1',
#  'MMP2',
#  'ASPH',
#  'MCMBP',
#  'CA8',
#  'VPS4B',
#  'PDIA3',
#  'PLAU',
#  'NARF',
#  'GLUD1',
#  'MPP1',
#  'FNDC3B',
#  'FZD6',
#  'ARHGAP35',
#  'YWHAB',
#  'APLP2',
#  'ALDH5A1',
#  'AKAP5',
#  'F13B',
#  'ILK',
#  'BAG2',
#  'WDR11',
#  'RND3',
#  'EPM2AIP1',
#  'NFIB',
#  'DEPTOR',
#  'LCAT',
#  'ABCC3',
#  'CDK14',
#  'PLG',
#  'NUMB',
#  'C7',
#  'ABHD17C',
#  'RIDA',
#  'MSI2',
#  'PXN',
#  'HSPA5',
#  'BAK1',
#  'RPS9',
#  'PLCG1',
#  'FKBP11',
#  'CAST',
#  'TGFB1',
#  'LOXL2',
#  'SHPK',
#  'CIRBP',
#  'LACC1',
#  'EHHADH',
#  'COL28A1',
#  'MARK1',
#  'CPB2',
#  'GLRX3',
#  'NCF2',
#  'ALG2',
#  'RRAS',
#  'PLD1',
#  'CES2',
#  'KCTD3',
#  'GSTCD',
#  'PDIA5',
#  'SPTLC2',
#  'DYSF',
#  'CYP2S1',
#  'HMGB1',
#  'HPCAL1',
#  'NOL3',
#  'ARPC5L',
#  'EMC2',
#  'CFAP36',
#  'PDK1',
#  'PLEKHA2',
#  'KIF1BP',
#  'CTPS2',
#  'MICALL1',
#  'PFKFB2',
#  'KBTBD11',
#  'ALDH1B1',
#  'EMC8',
#  'TTC28',
#  'ALKBH5',
#  'ADPRHL2',
#  'AARSD1',
#  'XPNPEP1',
#  'FAM49A',
#  'STARD5',
#  'MPI',
#  'TBCA',
#  'SNX18',
#  'CETN3',
#  'MKRN2',
#  'IFT81',
#  'DPH2',
#  'REEP6',
#  'HOOK1',
#  'GLUL',
#  'NBEA',
#  'TCEA3',
#  'DCTPP1',
#  'KIAA1107',
#  'ADH1C',
#  'RBKS',
#  'MBOAT2',
#  'TUBB2B',
#  'DHX36',
#  'BRK1',
#  'PFAS',
#  'RAB20',
#  'ERP44',
#  'ATG3',
#  'TRIM26',
#  'FBXO4',
#  'WIPF2',
#  'TACC1',
#  'GGH',
#  'RBP1',
#  'TTC39A',
#  'CELSR1',
#  'IFT88',
#  'AKAP12',
#  'SCD5',
#  'IFT46',
#  'LPIN1',
#  'ADAL',
#  'DTD1',
#  'PKIG',
#  'SOD2',
#  'SCYL1',
#  'PHYKPL',
#  'NRAS',
#  'UCHL1',
#  'PLA2G4A',
#  'METTL26',
#  'PRKCB',
#  'ME1',
#  'GLIPR2',
#  'STX17',
#  'TSPAN8',
#  'ARFGEF3',
#  'WDR35',
#  'IFT74',
#  'GYG1',
#  'CAPRIN1',
#  'RAPGEF6',
#  'KIF13B',
#  'CHP1',
#  'ERBB3',
#  'CYB5R2',
#  'WDR60',
#  'IFT140',
#  'NPEPL1',
#  'PIGR',
#  'CHMP4C',
#  'ANXA4',
#  'CHL1',
#  'MME',
#  'SCYL2',
#  'NUDT15',
#  'FGF1',
#  'XPO4',
#  'HCCS',
#  'MANF',
#  'ATP6V1B2',
#  'CAND2',
#  'TBL1X',
#  'RRP8',
#  'FECH',
#  'DAAM2',
#  'PARD6B',
#  'HSD11B2',
#  'BCL2L13',
#  'TAOK2_1',
#  'CETN2',
#  'DNAJB11',
#  'SLC25A5',
#  'GPC4',
#  'DDX27',
#  'ANK2',
#  'KIF1C',
#  'L1CAM',
#  'ENPP6',
#  'NCKAP5L',
#  'ARHGEF6',
#  'ASRGL1',
#  'ANO10',
#  'NPEPPS',
#  'PLXNC1',
#  'KSR1',
#  'STK17A',
#  'STXBP4',
#  'LBH',
#  'RAB5A',
#  'IGF2BP2',
#  'RRP15',
#  'NCF1',
#  'ACTR3',
#  'HDDC2',
#  'KTN1',
#  'HSP90AA1',
#  'OSCP1',
#  'WDFY2',
#  'ALDH1L2',
#  'PDLIM2',
#  'MBLAC2',
#  'IFT52',
#  'NOSTRIN',
#  'CBR3',
#  'AIF1L',
#  'TATDN3',
#  'EMC3',
#  'PC',
#  'FDXR',
#  'PPP2R5D',
#  'POLR2I',
#  'ADGRE5',
#  'RNASE1',
#  'VRK1',
#  'TRPV2',
#  'MRPL51',
#  'CGGBP1',
#  'PLEKHA6',
#  'CFHR5',
#  'RCC2',
#  'LRSAM1',
#  'CFHR2',
#  'CRYL1',
#  'HNRNPAB',
#  'CMBL',
#  'UTRN',
#  'C5',
#  'TUBB3',
#  'PAPOLG',
#  'RPL7L1',
#  'SORBS2',
#  'TUBB',
#  'TMEM192',
#  'TUBB_1',
#  'CLU',
#  'CGNL1',
#  'PROC',
#  'AP1M2',
#  'LBP',
#  'GKAP1',
#  'ITIH4_1',
#  'KCTD14',
#  'INPP4B',
#  'CFH',
#  'PGRMC1',
#  'RARA',
#  'EMD',
#  'ATE1',
#  'SAMD12',
#  'CNKSR1',
#  'FAM84B',
#  'GSPT1',
#  'SPAG1',
#  'NHLRC2',
#  'SLC30A9',
#  'FOXO1',
#  'ANKHD1-EIF4EBP3',
#  'NCOA2',
#  'AKR1C1',
#  'MTMR6',
#  'AIFM2',
#  'MX2',
#  'STAU1',
#  'ISG20',
#  'CCDC50_1',
#  'ACTR1A',
#  'ARFGEF1',
#  'PLA2G2A',
#  'DHX29',
#  'ACAA2',
#  'LCMT1',
#  'STAU2',
#  'ACAP2',
#  'CD209',
#  'ARHGEF1',
#  'TSPAN13',
#  'THOC3',
#  'DNAJB4',
#  'ETS1',
#  'CHIT1',
#  'CHKB',
#  'RAB11FIP4',
#  'CCDC88C',
#  'TOMM70',
#  'DCAF5',
#  'LPL',
#  'VWF',
#  'MYO6_1',
#  'DCAF7',
#  'ZBTB7B',
#  'BPI',
#  'LYZ',
#  'NID1',
#  'PDE4D',
#  'KIT',
#  'FAAH',
#  'DOCK5',
#  'PDXDC1',
#  'PEX19',
#  'SPAG7',
#  'APOL1',
#  'ZEB2',
#  'ARMC10',
#  'ACP6',
#  'TBC1D10C',
#  'PRPF40A',
#  'FUCA2',
#  'GFOD2',
#  'TIMM13',
#  'RASA1',
#  'ZC3H14',
#  'NOS1AP',
#  'TOP1',
#  'LMBRD2',
#  'MISP3',
#  'CALD1_1',
#  'CHCHD6',
#  'GNG2',
#  'VPS33B',
#  'MLLT1',
#  'PRKCI',
#  'RPL38',
#  'CA3',
#  'RASSF2',
#  'TOMM22',
#  'CBL',
#  'STUB1',
#  'OCIAD2',
#  'VPS13B',
#  'GULP1',
#  'STK39',
#  'CPEB4',
#  'PPIB',
#  'SPTBN1',
#  'PANK3',
#  'PWWP2A',
#  'LAMA3',
#  'RNASE4',
#  'NUBP2',
#  'RRM2B',
#  'BOD1',
#  'CCL21',
#  'CD74',
#  'MOB3A',
#  'SMOC1',
#  'SERPINB5',
#  'PRG4',
#  'MYCBP2',
#  'TIMM9',
#  'PLGRKT',
#  'ERCC4',
#  'SELENOP',
#  'HPR',
#  'TMC4',
#  'PPM1A',
#  'CALML3',
#  'FHL1',
#  'LAMA2',
#  'UBR7',
#  'NT5C',
#  'NMT2',
#  'RPL4',
#  'UQCC1',
#  'NCOR2',
#  'KIAA1217',
#  'MRPL47',
#  'FGR',
#  'ARAF',
#  'KIFAP3',
#  'TBC1D10B',
#  'UBE2K',
#  'ICAM3',
#  'ERAL1',
#  'COA4',
#  'PGD',
#  'RABEP2',
#  'PLXND1',
#  'TPRKB',
#  'TINAGL1',
#  'CFP',
#  'NUBPL',
#  'PGP',
#  'NHP2',
#  'FERMT1',
#  'PIGU',
#  'ACOT8',
#  'SRGN',
#  'PITPNB',
#  'TIMM8A',
#  'MLEC',
#  'AGGF1',
#  'CSTF1',
#  'BAG3',
#  'SRC',
#  'AGAP3',
#  'BAIAP2',
#  'BHLHE40',
#  'AKR1B15',
#  'SMAD3',
#  'PARD6G',
#  'PKP4',
#  'DAPK1',
#  'C19orf33',
#  'SYTL1',
#  'ANP32E',
#  'SLC25A6',
#  'PPP1R1B',
#  'SEPT9_1',
#  'RAD54B',
#  'RXRA',
#  'RNGTT',
#  'VAPB',
#  'ARHGAP32',
#  'EPB41L2',
#  'ATP1B3',
#  'PVR',
#  'ACSL5',
#  'CXADR',
#  'MOGS',
#  'SNTB1',
#  'GLS',
#  'PALM2-AKAP2',
#  'TXNDC12',
#  'PARN',
#  'RPL22',
#  'MYO5C',
#  'MLPH',
#  'SYTL4',
#  'SYTL2',
#  'KPNA3',
#  'NCOA7',
#  'SLC5A6',
#  'SLC39A6',
#  'RAB27B',
#  'UNK',
#  'ADD1',
#  'RPS6KA3',
#  'MAPRE2',
#  'DNAJC19',
#  'GSDMD',
#  'CCND1',
#  'HMOX1',
#  'C20orf24',
#  'RAPGEF2',
#  'IGF1R',
#  'SHROOM3',
#  'SNX27',
#  'TRIM38',
#  'MED7',
#  'COG7',
#  'CHMP4A',
#  'METTL7A',
#  'IGLL1',
#  'SEC63',
#  'MYO19',
#  'ARHGAP26',
#  'PAPD5',
#  'SHANK3',
#  'STRN3',
#  'IDO1',
#  'NME1',
#  'UCHL3',
#  'TFEB',
#  'FAHD1',
#  'SLC25A13',
#  'WDR7',
#  'NGLY1',
#  'LMOD1',
#  'EEF1B2',
#  'PARP10',
#  'CRYM',
#  'SOD3',
#  'TBC1D1',
#  'CRABP1',
#  'ATP2A3',
#  'MUC5B',
#  'FBXO6',
#  'UVRAG',
#  'FAM107B',
#  'GNG7',
#  'HVCN1',
#  'PPP1R12C',
#  'TREX1',
#  'GBP4']

# %% [markdown]
# # Run GSEA

# %%
pos_neg_enr = gp.enrichr(gene_list = pos_neg_prot, description='Tumor_partition', gene_sets='Reactome_2016')
#pos_neg_enr.res2d.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-159494dadb77> in <module>
# ----> 1 pos_neg_enr = gp.enrichr(gene_list = pos_neg_prot, description='Tumor_partition', gene_sets='Reactome_2016')
#       2 #pos_neg_enr.res2d.head(5)
#
# ~/anaconda3/lib/python3.7/site-packages/gseapy/enrichr.py in enrichr(gene_list, gene_sets, organism, description, outdir, background, cutoff, format, figsize, top_term, no_plot, verbose)
#     415     enr = Enrichr(gene_list, gene_sets, organism, description, outdir,
#     416                   cutoff, background, format, figsize, top_term, no_plot, verbose)
# --> 417     enr.run()
#     418
#     419     return enr
#
# ~/anaconda3/lib/python3.7/site-packages/gseapy/enrichr.py in run(self)
#     354                 self._logger.debug("Start Enrichr using library: %s" % (self._gs))
#     355                 self._logger.info('Analysis name: %s, Enrichr Library: %s' % (self.descriptions, self._gs))
# --> 356                 shortID, res = self.get_results(genes_list)
#     357                 # Remember gene set library used
#     358             res.insert(0, "Gene_set", self._gs)
#
# ~/anaconda3/lib/python3.7/site-packages/gseapy/enrichr.py in get_results(self, gene_list)
#     169         ADDLIST_URL = 'http://amp.pharm.mssm.edu/%s/addList'%self._organism
#     170         job_id = self.send_genes(gene_list, ADDLIST_URL)
# --> 171         user_list_id = job_id['userListId']
#     172
#     173         RESULTS_URL = 'http://amp.pharm.mssm.edu/%s/export'%self._organism
#
# KeyError: 'userListId'

# %%
#get just the clotting cascade genes and add urokinase genes 
pos_neg_df = pos_neg_enr.res2d
coag = pos_neg_df.iloc[2,9]
coag = coag.split(';')
upa = ["F3","PLAUR","PLAU","PLG","MMP9","MMP12","SERPINE1"]
coag_upa =  coag + upa
len(coag_upa)

# %% [markdown]
# # Step 3 Make Data frame for Figure 4

# %%
#Get append version of the df with all cancer type, fdr sig trans results
df_FDR_append = pd.read_csv("Make_Tables/csv_files/sig_prot_heatmap_EGFR.csv")
 
coag_upa =  ["F2""F3","F9","F10","F11","F13A1","PLAUR","PLAU","PLG","MMP9","MMP12","SERPINE1"]
#subset dataframe to include genes only desired for figure 
df_FDR_append= df_FDR_append[df_FDR_append.Comparison.isin(coag_upa)]
df_FDR_append
# Out:
#      Comparison  Correlation       P_Value Cancer
# 198       PLAUR    -0.425639  6.047225e-04    GBM
# 504       F13A1    -0.371427  3.256892e-03    GBM
# 532         F10    -0.367388  3.684421e-03    GBM
# 1000         F9    -0.314237  1.641199e-02    GBM
# 1095   SERPINE1    -0.306814  1.962210e-02    GBM
# 1153        F11    -0.301704  2.232032e-02    GBM
# 1404       PLAU    -0.278913  3.947268e-02    GBM
# 1471        PLG    -0.274098  4.390179e-02    GBM
# 1646       PLAU     0.451865  1.480995e-04  HNSCC
# 1665   SERPINE1     0.440590  2.212241e-04  HNSCC
# 2524      PLAUR     0.278504  3.727126e-02  HNSCC
# 2748       PLAU     0.412139  1.281403e-03   LSCC
# 3315         F9    -0.396250  1.355375e-03   LUAD
# 4391      F13A1    -0.262430  4.900816e-02   LUAD
# 4485      MMP12     0.516447  5.068632e-07     BR
# 4583      PLAUR     0.467428  8.405657e-06     BR
# 4617   SERPINE1     0.484666  1.862617e-05     BR
# 5029       PLAU     0.369332  8.017934e-04     BR
# 5043        PLG     0.368243  8.283718e-04     BR
# 5312       MMP9     0.340592  2.205679e-03     BR
# 5752        F10     0.306660  6.487358e-03     BR
# 6034        F11     0.290356  1.026734e-02     BR
# 6268         F9     0.276574  1.510919e-02     BR
# 7060      F13A1     0.235714  4.282384e-02     BR

# %% [markdown]
# Set add new column to be unique index and order the new index. This way genes will be grouped by coagulation factors, regulators, and urokinase genes.

# %%
df_FDR_append["Index"] = df_FDR_append["Comparison"] + " " + df_FDR_append["Cancer"]
df_FDR_append = df_FDR_append.set_index("Index")
df_ordered = df_FDR_append.reindex(["F2 GBM","F3 GBM","F9 GBM","F10 GBM","F11 GBM","F13A1 GBM","F13B GBM","KLKB1 GBM","VWF CO","FGA GBM","FGB GBM","FGG GBM","SERPINC1 GBM", "SERPIND1 GBM","SERPING1 GBM","A2M GBM","PROS1 GBM","PROC OV","PROCR GBM","THBD GBM","KNG1 GBM","PLAUR GBM","PLAU GBM","PLG GBM","MMP9 BR","MMP12 BR","SERPINE1 GBM",
                                "F2 BR","F9 BR","F10 BR","F11 BR","F13A1 BR","F13B BR","FGA BR","FGB BR","FGG BR", "SERPIND1 BR","SERPING1 BR","A2M BR","PROS1 BR","PROCR BR","KLKB1 BR", "PLAUR BR","PLAU BR","PLG BR","SERPINE1 BR",
                               "VWF HNSCC","THBD HNSCC","PLAUR HNSCC","PLAU HNSCC","SERPINE1 HNSCC",
                               "F9 LUAD","F13A1 LUAD", "F13B LUAD", "SERPIND1 LUAD","PROS1 LUAD","PROC LUAD","VWF LUAD",
                                "PROCR ccRCC",
                                "SERPIND1 OV","PROC OV",
                               "F3 CO","SERPINC1 CO", "SERPIND1 CO","A2M CO","KNG1 CO","KLKB1 CO"])

# %% [markdown]
# # Step 4: Plot Figure 4

# %%
legend_min = df_ordered["P_Value"].min()
#Make plot using plot utils
plotCircleHeatMap(df_FDR_append, circle_var = "P_Value",color_var = "Correlation", x_axis = "Comparison", y_axis = "Cancer", plot_width= 700, plot_height = 500, legend_min = legend_min, legend_max = 0.05, font_size = 22, show_legend = True , save_png = "png_files/Figure4.png")
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4148">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="97729aa6-7aa1-42c5-8fad-9a7038e1de80" data-root-id="4149"></div>
# Figure(id='4096', ...)

# %% [markdown]
# # Check if blanks are due to no data

# %% [markdown]
# The follow code chunks show that the following cancers/genes don't have data: colon THBD, Kidney MMP12, and Ovarian MMP12. (As mentioned in EGFR Figure 2 legend)

# %%
#Get append version of the df with all proteins 
df_all_prot_append = pd.read_csv("Make_Tables/csv_files/all_prot_heatmap_EGFR.csv")
df_all_prot_append

# %%
#subset dataframe to include genes only desired for figure 
df_all_comp_coag = df_all_prot_append[df_all_prot_append.Comparison.isin(coag_upa)]
print("Number of rows in data frame " + str(len(df_all_comp_coag)))

# %% [markdown]
# Our figure includes 27 genes for 8 cancers. If all data was present there would be 216 rows. However, the data frame only has 212 rows. 4 genes are missing.

# %%
def find_missing_genes(test_list, full_list):
    for gene in full_list:
        if (gene not in test_list):
            print(gene)

# %%
#Get list of genes for colon, kidney, and ovarian
colon = df_all_prot_append[df_all_prot_append["Cancer"] == "CO"]
colon_list = colon.Comparison.to_list()

Kidney = df_all_prot_append[df_all_prot_append["Cancer"] == "ccRCC"]
Kidney_list = Kidney.Comparison.to_list()

Ovarian = df_all_prot_append[df_all_prot_append["Cancer"] == "OV"]
Ovarian_list = Ovarian.Comparison.to_list()

# %%
#Show the 3 missing genes 
print("Ovarian missing genes: ")
find_missing_genes(Ovarian_list, coag_upa)
print("Kidney missing genes: ")
find_missing_genes(Kidney_list, coag_upa)
print("Colon missing genes: ")
find_missing_genes(colon_list, coag_upa)
