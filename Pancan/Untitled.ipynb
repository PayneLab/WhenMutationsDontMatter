# %%
import cptac
# Out:
# cptac warning: Your version of cptac (1.5.0rc1) is out-of-date. Latest is 1.1.2. Please run 'pip install --upgrade cptac' to update it. (/usr/lib/python3.10/threading.py, line 953)

# %%
br = cptac.Brca()

# %%
br.get_transcriptomics(source="washu")
# Out:
# Name                  5S_rRNA                                      \
# Database_ID ENSG00000201285.1 ENSG00000212595.1 ENSG00000252830.2
# Patient_ID
# 01BR001                   0.0               0.0               0.0
# 01BR008                   0.0               0.0               0.0
# 01BR009                   0.0               0.0               0.0
# 01BR010                   0.0               0.0               0.0
# 01BR015                   0.0               0.0               0.0
# ...                       ...               ...               ...
# 21BR010                   0.0               0.0               0.0
# 22BR005                   0.0               0.0               0.0
# 22BR006                   0.0               0.0               0.0
# CPT000814                 0.0               0.0               0.0
# CPT001846                 0.0               0.0               0.0
#
# Name                                                               \
# ...

# %%
cptac.list_datasets()
# Out:
#    Cancers     Sources                                          Datatypes
# 0     brca         awg  somatic_mutation, acetylproteomics, CNV, phosp...
# 1     brca         bcm                                    transcriptomics
# 2     brca       broad                                    transcriptomics
# 3     brca  harmonized                                   somatic_mutation
# 4     brca        mssm                                           clinical
# ..     ...         ...                                                ...
# 77    ucec  harmonized                                   somatic_mutation
# 78    ucec        mssm                                           clinical
# 79    ucec         pdc  clinical, acetylproteomics, phosphoproteomics,...
# 80    ucec       umich                      proteomics, phosphoproteomics
# 81    ucec       washu  somatic_mutation, transcriptomics, miRNA, xcel...
#
# [82 rows x 3 columns]
